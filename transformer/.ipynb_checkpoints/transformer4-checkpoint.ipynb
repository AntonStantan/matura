# %%
import sys
import os
import numpy as np
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Dense, Layer, Dropout

print("Successfully imported libraries!")
# Out:
# Successfully imported libraries!

# %%
# List available GPUs
gpus = tf.config.list_physical_devices('GPU')
print("GPUs Available:", gpus)

# Check if TensorFlow will place operations on the GPU
print("TensorFlow Version:", tf.__version__)

# Run a quick test
with tf.device('/GPU:0'):
    a = tf.random.normal([1000, 1000])
    b = tf.random.normal([1000, 1000])
    c = tf.matmul(a, b)
    print("Test computation done on GPU")
# Out:
# GPUs Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# TensorFlow Version: 2.16.1
# Test computation done on GPU
# 2025-10-02 14:45:52.786544: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:00:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-10-02 14:45:52.833504: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:00:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-10-02 14:45:52.833694: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:00:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-10-02 14:45:52.836779: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:00:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-10-02 14:45:52.836949: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:00:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-10-02 14:45:52.837049: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:00:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-10-02 14:45:52.933089: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:00:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-10-02 14:45:52.933362: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:00:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-10-02 14:45:52.933423: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2025-10-02 14:45:52.933534: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:00:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-10-02 14:45:52.933651: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2342 MB memory:  -> device: 0, name: Orin, pci bus id: 0000:00:00.0, compute capability: 8.7

# %%
# Get the absolute path of the current script's directory
current_dir = os.path.dirname(os.path.abspath("transformer0.ipynb"))

# Get the absolute path of the parent directory (project_folder)
parent_dir = os.path.dirname(current_dir)

# Add the parent directory to the Python path
sys.path.append(parent_dir)

# Now you can import from GetXY.py
from GetXY import x_train, y_train, x_val, y_val

early_stopping = tf.keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
    monitor='mse'
)
# ... rest of your code
print("Successfully imported variables!")
# Out:
# -1 - -2 + 1
# 2543
# 2.0
#
# Expressions not in x:
# 2 - 2 + -3
# True
# 1457
# -3.0
# 15
# -4.0
# [-5.   1.   1.   0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5
#   0.5]
# Successfully imported variables!

# %%
#add a cls token at the beginning of x_train and x_val
pad_value = 15
x_train = np.pad(x_train, ((0, 0), (1, 0)), 'constant', constant_values=pad_value)
x_val = np.pad(x_val, ((0, 0), (1, 0)), 'constant', constant_values=pad_value)

# %%
#defining the positional encoder modelled after the formula in the paper that was cited. (generated by gemini)
def posEncoding(max_seq_len, d_model):
    # Create a matrix of angles according to the formula
    angle_rads = get_angles(np.arange(max_seq_len)[:, np.newaxis],
                          np.arange(d_model)[np.newaxis, :],
                          d_model)
    
    # Apply sine to even indices in the array; 2i
    angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
    
    # Apply cosine to odd indices in the array; 2i+1
    angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
    
    # Add a batch dimension
    pos_encoding = angle_rads[np.newaxis, ...]
    
    return tf.cast(pos_encoding, dtype=tf.float32)

def get_angles(pos, i, d_model):
    angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
    return pos * angle_rates

# %%
#defining the point-wise FNN
#d_ff = 2048 #(original transformer size)
def point_wise_fnn(d_model, d_ff):
    return tf.keras.Sequential([
        Dense(d_ff, activation = "relu", kernel_initializer = "glorot_uniform", bias_initializer = "zeros"),
        Dense(d_model, kernel_initializer = "glorot_uniform", bias_initializer = "zeros")
    ])

# %%
#scaled dot-product attention
class MH_Attention(Layer):
    def __init__(self, d_model, num_heads):
        super().__init__()
        #for the split_heads function:
        self.num_heads = num_heads
        self.d_model = d_model
        
        assert d_model % self.num_heads == 0
        self.depth = d_model // self.num_heads

        #for the call function:
        #This allows the model to learn the best way to project the input embeddings. (linear projection)
        self.wq = Dense(d_model, kernel_initializer = "glorot_uniform", bias_initializer = "zeros")
        self.wk = Dense(d_model, kernel_initializer = "glorot_uniform", bias_initializer = "zeros")
        self.wv = Dense(d_model, kernel_initializer = "glorot_uniform", bias_initializer = "zeros")

        #it's important to initialize this aswell as the ones above here, so that the model saves the previous weights and is able to learn.
        self.finalDense = Dense(d_model, kernel_initializer = "glorot_uniform", bias_initializer = "zeros")
        
    def SDP_Attention(self, q, k, v, mask):
        matmul_qk = tf.matmul(q, k, transpose_b=True) #calculate the dotproduct, between the query and a transposed key.
        d_k = tf.shape(k)[-1] #read the dimensionality of the key tensor (here d_model/num_heads = depth)
        d_k = tf.cast(d_k, tf.float32) #convert to float type
        scaled_qk = matmul_qk / tf.math.sqrt(d_k) #scale for purposes discussed in their paper.        

        if mask is not None:
            scaled_qk += (mask * -1e9) #masking to a big negative number
        
        softmaxed_qk = tf.nn.softmax(scaled_qk, axis = -1) #apply softmax function (axis = -1) for softmaxing all the different keys. The last entry is the number of keys (not the dimensionality of them, like it was befre.)
        output = tf.matmul(softmaxed_qk, v) #multiply the attention-weights with the values corresponding to the keys, in respect to the query.
        return output, softmaxed_qk
        
    def split_heads(self, x, batch_size):
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth)) #splits up the x data which is gonna be q, k, or v, into the individual heads. effectively adding a dimension (self.num_heads), after splitting up self.d_model
        return tf.transpose(x, perm =[0,2,1,3]) #reorganizes the dimensions into the expected order (batch_size, num_heads, seq_len, depth(the new d_model "fractions"))

    def call(self, q, k ,v, mask = None):
        batch_size = tf.shape(q)[0]

        #(linear projection)
        q = self.wq(q)
        k = self.wk(k)
        v = self.wv(v)

        #split them all up into the individual heads. (add a dimension basically)
        q = self.split_heads(q , batch_size)
        k = self.split_heads(k , batch_size)
        v = self.split_heads(v , batch_size)

        sdp_attention, attention_weights = self.SDP_Attention(q,k,v, mask = mask) #applies the sdp-attention to all of them. sdp_attention at the end has a shape of: (batch_size, num_heads, seq_len, depth)
        
        sdp_attention = tf.transpose(sdp_attention, perm=[0, 2, 1, 3]) #swap the 2nd and 3rd dimensions
        combined_attention = tf.reshape(sdp_attention, (batch_size, -1, self.d_model)) #combine back the two last dimnensions (num_heads and depth) into the original d_model

        output = self.finalDense(combined_attention)
        return output, attention_weights

# %%
class EncodingLayer(Layer):
    def __init__(self, d_model, num_heads, d_ff, rate):
        super().__init__()
        #define all the components of a Layer so the model will learn them properly here.
        self.mha = MH_Attention(d_model, num_heads)
        self.fnn = point_wise_fnn(d_model, d_ff)

        #initiate the 2 normalizations
        self.norm1 = tf.keras.layers.LayerNormalization()
        self.norm2 = tf.keras.layers.LayerNormalization()

        self.dropout1 = Dropout(rate)
        self.dropout2 = Dropout(rate)

        
    def call(self,x, training, mask = None):
        mha_out, attention_weights = self.mha(x,x,x,mask = mask) #for self-attention: q,k,v = x
        mha_out = self.dropout1(mha_out, training = training) #they apply a small dropout of 0.1 after every residual step in the paper.

        norm_out = self.norm1(x + mha_out) #first, add the vectors, then normalize them.

        fnn_out = self.fnn(norm_out) #2nd sub-layer with fnn
        fnn_out = self.dropout2(fnn_out, training = training) #again apply drop out

        norm2_out = self.norm2(norm_out + fnn_out) #again add and norm

        return norm2_out

# %%
class Encoder(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, num_layers, d_ff, rate):
        super().__init__()

        self.d_model = d_model
        self.num_layers = num_layers #amount of encoding layers
        self.layers = [EncodingLayer(d_model, num_heads, d_ff, rate) for i in range(num_layers)] #define multiple diffferent encoding layers here.

        self.dropout = Dropout(rate)
            
    def call(self, x, training, mask = None):
        x = self.dropout(x, training = training) #we want to drop out before the first layer
        for i in range(self.num_layers):
            x = self.layers[i](x, training = training, mask = mask)
        return x

# %%
class Transformer(tf.keras.Model):
    def __init__(self, embedding_layer, d_model, max_seq_len, num_heads, num_layers, d_ff, rate):
        super().__init__()
        self.embedding = embedding_layer
        self.d_model = d_model
        self.pos_enc = posEncoding(max_seq_len, d_model)
        self.Encoder = Encoder(d_model, num_heads, num_layers, d_ff, rate)
        self.dropout = tf.keras.layers.Dropout(rate)
        self.finalDense = Dense(1, activation = "linear", kernel_initializer = "glorot_uniform", bias_initializer = "zeros")
        
    def call(self, x, training, mask = None):
        seq_len = tf.shape(x)[1]
        x = tf.expand_dims(x, axis=-1) #add a dimension to x
        x = self.embedding(x)
        x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32)) #scale with √d_model
        x += self.pos_enc[:, :seq_len, :]
        
        out_Encoder = self.Encoder(x, training = training, mask = mask)

        output = out_Encoder[:,0,:] #pooling: to the first token.
        output = self.dropout(output, training = training) #another dropout

        final = self.finalDense(output) #now we can reduce back to a single neuron. This is the opposite of what we did in the embedding layer.

        return final

# %%
# Define a custom learning rate schedule class with warmup and cosine decay
class WarmupCosineDecay(tf.keras.optimizers.schedules.LearningRateSchedule):
    """
    A custom learning rate schedule that implements a linear warmup
    followed by a cosine decay.
    """
    def __init__(self, peak_lr, warmup_steps, decay_steps, alpha=0.0, name=None):
        super().__init__()
        self.peak_lr = peak_lr
        self.warmup_steps = warmup_steps
        self.decay_steps = decay_steps
        self.alpha = alpha
        self.name = name

    def __call__(self, step):
        with tf.name_scope(self.name or "WarmupCosineDecay"):
            # Ensure step is a float for calculations
            step = tf.cast(step, tf.float32)
            
            # --- 1. Warmup Phase ---
            # Linearly increase the learning rate from 0 to peak_lr
            warmup_lr = self.peak_lr * (step / self.warmup_steps)

            # --- 2. Cosine Decay Phase ---
            # Define the cosine decay schedule
            cosine_decay_schedule = tf.keras.optimizers.schedules.CosineDecay(
                initial_learning_rate=self.peak_lr,
                decay_steps=self.decay_steps,
                alpha=self.alpha
            )
            # Calculate the learning rate for the decay phase.
            # Note: The 'step' for the cosine part must be relative to its start.
            decay_lr = cosine_decay_schedule(step - self.warmup_steps)

            # --- 3. Choose the correct phase ---
            # Use tf.where to select the learning rate based on the current step
            learning_rate = tf.where(
                step < self.warmup_steps,
                warmup_lr,
                decay_lr
            )
            return learning_rate

    def get_config(self):
        return {
            "peak_lr": self.peak_lr,
            "warmup_steps": self.warmup_steps,
            "decay_steps": self.decay_steps,
            "alpha": self.alpha,
            "name": self.name
        }

# %%
import keras_tuner
from tensorflow.keras import backend as K
def build_model(hp):
    K.clear_session()
    # A smaller configuration to reduce overfitting
    # Ensure compatibility
    num_heads = hp.Choice('num_heads', [2, 4, 8])  # Powers of 2 work well
    d_model = hp.Choice('d_model', [32, 64, 128])   # Also powers of 2
    # This guarantees d_model % num_heads == 0
    num_layers = hp.Int('num_layers', 2, 6)
    d_ff = hp.Choice('d_ff', [64, 128, 256, 512])   # Multiples that work well
    if hp.Boolean("dropout"):
        dropout_rate = 0.2 
    else: 
        dropout_rate = 0
    peak_lr = hp.Float("peak learning rate", min_value = 1e-7, max_value = 1e-2, sampling="log")

    embedding_layer = Dense(d_model, kernel_initializer = "glorot_uniform", bias_initializer = "zeros")
    batch_size = 32
    num_epochs = 25
    max_seq_len = 16
    warmup_epochs = 3
    

    
    transformer_model = Transformer(
        embedding_layer = embedding_layer, 
        d_model = d_model,
        max_seq_len = max_seq_len,
        num_heads = num_heads,
        num_layers = num_layers,
        d_ff = d_ff,
        rate = dropout_rate
    )


        # Calculate steps based on your data
    # IMPORTANT: Use the actual length of your training data for this calculation
    steps_per_epoch = len(x_train) // batch_size
    warmup_steps = warmup_epochs * steps_per_epoch
    decay_steps = (num_epochs - warmup_epochs) * steps_per_epoch
    
    # Create an instance of our new scheduler
    lr_schedule = WarmupCosineDecay(
        peak_lr=peak_lr,
        warmup_steps=warmup_steps,
        decay_steps=decay_steps,
        alpha=0.1 # This means the LR will decay to 10% of peak_lr
    )

    transformer_model.compile(
        optimizer=tf.keras.optimizers.AdamW(
            learning_rate=lr_schedule,
            weight_decay = 4e-3,
            beta_1=0.85,  
            beta_2=0.999,  # Primary recommendation: lower this
            clipnorm=1.0
        ),
        loss='mse'
    )
    return transformer_model

build_model(keras_tuner.HyperParameters())
# Out:
# <Transformer name=transformer, built=False>

# %%
tuner = keras_tuner.BayesianOptimization(
    hypermodel=build_model,
    objective="val_loss",
    max_trials=50,
    executions_per_trial=1,
    overwrite=False
)
# Out:
# Reloading Tuner from ./untitled_project/tuner0.json

# %%
num_epochs = 25
batch_size = 32

train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(len(x_train)).batch(batch_size)
val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val)).batch(batch_size)

tuner.search(train_dataset, epochs = num_epochs, validation_data = (val_dataset), verbose = 0, callbacks = [early_stopping])

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in ./untitled_project
# Showing 10 best trials
# Objective(name="val_loss", direction="min")
#
# Trial 23 summary
# Hyperparameters:
# num_heads: 8
# d_model: 32
# num_layers: 3
# d_ff: 128
# dropout: False
# peak learning rate: 0.0014188984633416947
# Score: 0.13932304084300995
#
# Trial 04 summary
# Hyperparameters:
# num_heads: 2
# d_model: 64
# num_layers: 4
# d_ff: 512
# dropout: False
# peak learning rate: 0.00023727638415800082
# Score: 0.5695855617523193
#
# Trial 19 summary
# Hyperparameters:
# num_heads: 2
# d_model: 64
# num_layers: 4
# d_ff: 512
# dropout: False
# peak learning rate: 0.00017753963838400855
# Score: 1.641616940498352
#
# Trial 42 summary
# Hyperparameters:
# num_heads: 4
# d_model: 128
# num_layers: 3
# d_ff: 512
# dropout: False
# peak learning rate: 0.0004034381760009418
# Score: 6.7436699867248535
#
# Trial 20 summary
# Hyperparameters:
# num_heads: 2
# d_model: 64
# num_layers: 4
# d_ff: 512
# dropout: False
# peak learning rate: 0.0002221139550977517
# Score: 7.766565322875977
#
# Trial 06 summary
# Hyperparameters:
# num_heads: 2
# d_model: 32
# num_layers: 2
# d_ff: 256
# dropout: False
# peak learning rate: 0.0018620036258997228
# Score: 10.484166145324707
#
# Trial 07 summary
# Hyperparameters:
# num_heads: 2
# d_model: 64
# num_layers: 5
# d_ff: 256
# dropout: False
# peak learning rate: 6.836644645712527e-05
# Score: 10.627899169921875
#
# Trial 18 summary
# Hyperparameters:
# num_heads: 2
# d_model: 64
# num_layers: 4
# d_ff: 512
# dropout: False
# peak learning rate: 0.0006572830203098331
# Score: 11.503336906433105
#
# Trial 38 summary
# Hyperparameters:
# num_heads: 8
# d_model: 64
# num_layers: 6
# d_ff: 512
# dropout: False
# peak learning rate: 7.544146171497126e-06
# Score: 15.012101173400879
#
# Trial 47 summary
# Hyperparameters:
# num_heads: 2
# d_model: 32
# num_layers: 3
# d_ff: 512
# dropout: False
# peak learning rate: 0.0017666057033955919
# Score: 15.705245018005371

# %%
# Get the best hyperparameters
best_hps = tuner.get_best_hyperparameters()[0]

# %%
def build_best_model(hp, num_epochs):
    # A smaller configuration to reduce overfitting
    # Ensure compatibility
    num_heads = hp.Choice('num_heads', [2, 4, 8])  # Powers of 2 work well
    d_model = hp.Choice('d_model', [32, 64, 128])   # Also powers of 2
    # This guarantees d_model % num_heads == 0
    num_layers = hp.Int('num_layers', 2, 6)
    d_ff = hp.Choice('d_ff', [64, 128, 256, 512])   # Multiples that work well
    if hp.Boolean("dropout"):
        dropout_rate = 0.2 
    else: 
        dropout_rate = 0
    peak_lr = hp.Float("peak learning rate", min_value = 1e-7, max_value = 1e-2, sampling="log")

    embedding_layer = Dense(d_model, kernel_initializer = "glorot_uniform", bias_initializer = "zeros")
    batch_size = 32
    num_epochs = num_epochs
    max_seq_len = 16
    warmup_epochs = np.floor(num_epochs/10) + 1
    

    
    transformer_model = Transformer(
        embedding_layer = embedding_layer, 
        d_model = d_model,
        max_seq_len = max_seq_len,
        num_heads = num_heads,
        num_layers = num_layers,
        d_ff = d_ff,
        rate = dropout_rate
    )


        # Calculate steps based on your data
    # IMPORTANT: Use the actual length of your training data for this calculation
    steps_per_epoch = len(x_train) // batch_size
    warmup_steps = warmup_epochs * steps_per_epoch
    decay_steps = (num_epochs - warmup_epochs) * steps_per_epoch
    
    # Create an instance of our new scheduler
    lr_schedule = WarmupCosineDecay(
        peak_lr=peak_lr,
        warmup_steps=warmup_steps,
        decay_steps=decay_steps,
        alpha=0.1 # This means the LR will decay to 10% of peak_lr
    )
    return transformer_model, lr_schedule
num_epochs_best_model = 200

# %%
from FNN1_1 import baseline_deviation, baeline_out_deviation, baseline_long_deviation, baseline_relError, absSum
baseline_out_deviation = baeline_out_deviation
from GetXY import x_test, y_test, out_x_test, out_y_test, long_x_test, long_y_test, outsideExpr, absSum
# Out:
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1759409163.988904   39017 service.cc:145] XLA service 0xfffe7c004870 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1759409163.988966   39017 service.cc:153]   StreamExecutor device (0): Orin, Compute Capability 8.7
# 2025-10-02 14:46:04.204195: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-10-02 14:46:04.604632: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 90300
# 27/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 25.5755
# I0000 00:00:1759409165.901903   39017 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - loss: 22.6537 - val_loss: 17.9957
# Epoch 2/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.7958 - val_loss: 15.9849
# Epoch 3/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 16.0742 - val_loss: 14.7819
# Epoch 4/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14.7235 - val_loss: 13.2783
# Epoch 5/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.9494 - val_loss: 11.3681
# Epoch 6/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.5798 - val_loss: 8.7382
# Epoch 7/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.5034 - val_loss: 5.6656
# Epoch 8/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4278 - val_loss: 2.9501
# Epoch 9/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2066 - val_loss: 1.4919
# Epoch 10/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1940 - val_loss: 0.9544
# Epoch 11/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8002 - val_loss: 0.6986
# Epoch 12/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5927 - val_loss: 0.5429
# Epoch 13/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4639 - val_loss: 0.4399
# Epoch 14/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3766 - val_loss: 0.3670
# Epoch 15/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3097 - val_loss: 0.3083
# Epoch 16/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2542 - val_loss: 0.2619
# Epoch 17/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2099 - val_loss: 0.2239
# Epoch 18/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1755 - val_loss: 0.1945
# Epoch 19/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1504 - val_loss: 0.1701
# Epoch 20/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1323 - val_loss: 0.1493
# Epoch 21/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1164 - val_loss: 0.1299
# Epoch 22/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1023 - val_loss: 0.1138
# Epoch 23/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0903 - val_loss: 0.1012
# Epoch 24/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0805 - val_loss: 0.0909
# Epoch 25/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0721 - val_loss: 0.0811
# Epoch 26/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0654 - val_loss: 0.0741
# Epoch 27/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0593 - val_loss: 0.0677
# Epoch 28/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0541 - val_loss: 0.0620
# Epoch 29/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0497 - val_loss: 0.0576
# Epoch 30/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0458 - val_loss: 0.0532
# Epoch 31/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0425 - val_loss: 0.0499
# Epoch 32/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0395 - val_loss: 0.0470
# Epoch 33/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0370 - val_loss: 0.0443
# Epoch 34/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0348 - val_loss: 0.0425
# Epoch 35/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0327 - val_loss: 0.0400
# Epoch 36/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0310 - val_loss: 0.0376
# Epoch 37/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0293 - val_loss: 0.0356
# Epoch 38/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0278 - val_loss: 0.0343
# Epoch 39/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0265 - val_loss: 0.0325
# Epoch 40/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0253 - val_loss: 0.0314
# Epoch 41/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0241 - val_loss: 0.0298
# Epoch 42/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0230 - val_loss: 0.0287
# Epoch 43/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0220 - val_loss: 0.0279
# Epoch 44/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0212 - val_loss: 0.0268
# Epoch 45/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0204 - val_loss: 0.0259
# Epoch 46/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0197 - val_loss: 0.0249
# Epoch 47/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0190 - val_loss: 0.0241
# Epoch 48/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0183 - val_loss: 0.0233
# Epoch 49/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0178 - val_loss: 0.0226
# Epoch 50/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0173 - val_loss: 0.0219
# Epoch 51/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0169 - val_loss: 0.0213
# Epoch 52/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0163 - val_loss: 0.0206
# Epoch 53/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0159 - val_loss: 0.0200
# Epoch 54/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0155 - val_loss: 0.0196
# Epoch 55/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0151 - val_loss: 0.0189
# Epoch 56/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0148 - val_loss: 0.0187
# Epoch 57/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0144 - val_loss: 0.0180
# Epoch 58/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0140 - val_loss: 0.0175
# Epoch 59/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0136 - val_loss: 0.0173
# Epoch 60/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0133 - val_loss: 0.0169
# Epoch 61/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0131 - val_loss: 0.0165
# Epoch 62/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0127 - val_loss: 0.0160
# Epoch 63/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0123 - val_loss: 0.0157
# Epoch 64/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0120 - val_loss: 0.0155
# Epoch 65/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0119 - val_loss: 0.0151
# Epoch 66/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0117 - val_loss: 0.0148
# Epoch 67/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0114 - val_loss: 0.0146
# Epoch 68/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0111 - val_loss: 0.0143
# Epoch 69/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0108 - val_loss: 0.0139
# Epoch 70/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0105 - val_loss: 0.0136
# Epoch 71/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0102 - val_loss: 0.0133
# Epoch 72/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0100 - val_loss: 0.0130
# Epoch 73/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0097 - val_loss: 0.0126
# Epoch 74/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0094 - val_loss: 0.0122
# Epoch 75/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0091 - val_loss: 0.0119
# Epoch 76/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0089 - val_loss: 0.0116
# Epoch 77/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0087 - val_loss: 0.0113
# Epoch 78/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0086 - val_loss: 0.0111
# Epoch 79/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0085 - val_loss: 0.0109
# Epoch 80/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0083 - val_loss: 0.0107
# Epoch 81/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0083 - val_loss: 0.0104
# Epoch 82/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0082 - val_loss: 0.0103
# Epoch 83/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0082 - val_loss: 0.0102
# Epoch 84/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0081 - val_loss: 0.0098
# Epoch 85/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0079 - val_loss: 0.0097
# Epoch 86/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0078 - val_loss: 0.0097
# Epoch 87/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0080 - val_loss: 0.0094
# Epoch 88/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0079 - val_loss: 0.0093
# Epoch 89/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0079 - val_loss: 0.0091
# Epoch 90/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0078 - val_loss: 0.0090
# Epoch 91/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0076 - val_loss: 0.0087
# Epoch 92/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0075 - val_loss: 0.0084
# Epoch 93/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0071 - val_loss: 0.0081
# Epoch 94/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0068 - val_loss: 0.0079
# Epoch 95/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0067 - val_loss: 0.0078
# Epoch 96/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066 - val_loss: 0.0075
# Epoch 97/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066 - val_loss: 0.0076
# Epoch 98/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0066 - val_loss: 0.0074
# Epoch 99/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0066 - val_loss: 0.0075
# Epoch 100/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0068 - val_loss: 0.0076
# Epoch 101/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0067 - val_loss: 0.0072
# Epoch 102/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0067 - val_loss: 0.0071
# Epoch 103/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065 - val_loss: 0.0070
# Epoch 104/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0066 - val_loss: 0.0070
# Epoch 105/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0065 - val_loss: 0.0070
# Epoch 106/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0063 - val_loss: 0.0067
# Epoch 107/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0062 - val_loss: 0.0069
# Epoch 108/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0061 - val_loss: 0.0067
# Epoch 109/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0059 - val_loss: 0.0066
# Epoch 110/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0057 - val_loss: 0.0065
# Epoch 111/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0056 - val_loss: 0.0064
# Epoch 112/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0054 - val_loss: 0.0065
# Epoch 113/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0052 - val_loss: 0.0064
# Epoch 114/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0053 - val_loss: 0.0066
# Epoch 115/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0052 - val_loss: 0.0068
# Epoch 116/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0053 - val_loss: 0.0069
# Epoch 117/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0053 - val_loss: 0.0070
# Epoch 118/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0052 - val_loss: 0.0068
# Epoch 119/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0052 - val_loss: 0.0070
# Epoch 120/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0052 - val_loss: 0.0071
# Epoch 121/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0052 - val_loss: 0.0071
# Epoch 122/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0053 - val_loss: 0.0075
# Epoch 123/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0054 - val_loss: 0.0077
# Epoch 124/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0056 - val_loss: 0.0077
# Epoch 125/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0055 - val_loss: 0.0078
# Epoch 126/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0057 - val_loss: 0.0080
# Epoch 127/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0057 - val_loss: 0.0079
# Epoch 128/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0059 - val_loss: 0.0078
# Epoch 129/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0057 - val_loss: 0.0071
# Epoch 130/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0054 - val_loss: 0.0064
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 19.7948 - val_loss: 17.1190
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.6642 - val_loss: 15.7150
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 14.2430 - val_loss: 14.1173
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.3374 - val_loss: 11.8248
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.5835 - val_loss: 8.5499
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1598 - val_loss: 4.8334
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1210 - val_loss: 2.2549
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5531 - val_loss: 1.3389
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0256 - val_loss: 1.0230
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7967 - val_loss: 0.8289
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6349 - val_loss: 0.6641
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5085 - val_loss: 0.5451
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4191 - val_loss: 0.4579
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3525 - val_loss: 0.3971
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3029 - val_loss: 0.3502
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2626 - val_loss: 0.3139
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2302 - val_loss: 0.2811
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2026 - val_loss: 0.2551
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1798 - val_loss: 0.2331
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1599 - val_loss: 0.2146
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1434 - val_loss: 0.1992
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1301 - val_loss: 0.1866
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1190 - val_loss: 0.1747
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1090 - val_loss: 0.1632
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1006 - val_loss: 0.1536
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0931 - val_loss: 0.1448
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0869 - val_loss: 0.1371
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0812 - val_loss: 0.1301
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0764 - val_loss: 0.1241
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0723 - val_loss: 0.1191
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0685 - val_loss: 0.1142
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0652 - val_loss: 0.1098
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0623 - val_loss: 0.1055
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0593 - val_loss: 0.1015
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0568 - val_loss: 0.0982
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0545 - val_loss: 0.0946
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0523 - val_loss: 0.0914
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0502 - val_loss: 0.0882
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0483 - val_loss: 0.0847
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0464 - val_loss: 0.0821
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0449 - val_loss: 0.0797
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0433 - val_loss: 0.0770
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0418 - val_loss: 0.0747
# Epoch 44/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0403 - val_loss: 0.0723
# Epoch 45/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0390 - val_loss: 0.0703
# Epoch 46/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0378 - val_loss: 0.0682
# Epoch 47/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0366 - val_loss: 0.0660
# Epoch 48/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0355 - val_loss: 0.0643
# Epoch 49/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0344 - val_loss: 0.0628
# Epoch 50/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0333 - val_loss: 0.0616
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 23.3835 - val_loss: 19.4637
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.0635 - val_loss: 17.0108
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.1381 - val_loss: 15.7234
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.6201 - val_loss: 13.8903
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.6316 - val_loss: 11.3906
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.0195 - val_loss: 8.2868
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0845 - val_loss: 4.9398
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3119 - val_loss: 2.3363
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6741 - val_loss: 1.3253
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1225 - val_loss: 1.0274
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9067 - val_loss: 0.8763
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7582 - val_loss: 0.7565
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6486 - val_loss: 0.6668
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5623 - val_loss: 0.5960
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4913 - val_loss: 0.5401
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4321 - val_loss: 0.4890
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3786 - val_loss: 0.4488
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3309 - val_loss: 0.4047
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2890 - val_loss: 0.3592
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2512 - val_loss: 0.3209
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2201 - val_loss: 0.2845
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1940 - val_loss: 0.2543
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1723 - val_loss: 0.2269
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1540 - val_loss: 0.2048
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1389 - val_loss: 0.1817
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1259 - val_loss: 0.1628
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1148 - val_loss: 0.1478
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1051 - val_loss: 0.1334
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0968 - val_loss: 0.1226
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0894 - val_loss: 0.1129
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0829 - val_loss: 0.1054
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0770 - val_loss: 0.0984
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0722 - val_loss: 0.0933
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0675 - val_loss: 0.0884
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0635 - val_loss: 0.0841
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0600 - val_loss: 0.0805
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0570 - val_loss: 0.0771
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0542 - val_loss: 0.0741
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0516 - val_loss: 0.0715
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0493 - val_loss: 0.0693
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0472 - val_loss: 0.0676
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0452 - val_loss: 0.0657
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0434 - val_loss: 0.0640
# Epoch 44/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0416 - val_loss: 0.0625
# Epoch 45/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0402 - val_loss: 0.0607
# Epoch 46/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0385 - val_loss: 0.0592
# Epoch 47/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0369 - val_loss: 0.0576
# Epoch 48/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0354 - val_loss: 0.0558
# Epoch 49/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0341 - val_loss: 0.0543
# Epoch 50/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0329 - val_loss: 0.0528
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 19.8823 - val_loss: 15.9228
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.5107 - val_loss: 14.9218
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14.3855 - val_loss: 13.8184
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.0479 - val_loss: 12.2964
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.1918 - val_loss: 10.3761
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.8924 - val_loss: 8.2057
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.5364 - val_loss: 5.9391
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3356 - val_loss: 3.7631
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5479 - val_loss: 2.1453
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4627 - val_loss: 1.3445
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9957 - val_loss: 1.0279
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7837 - val_loss: 0.8600
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6471 - val_loss: 0.7238
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5450 - val_loss: 0.6245
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4715 - val_loss: 0.5587
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4130 - val_loss: 0.5009
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3625 - val_loss: 0.4450
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3237 - val_loss: 0.4007
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2919 - val_loss: 0.3650
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2637 - val_loss: 0.3361
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2380 - val_loss: 0.3075
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2139 - val_loss: 0.2832
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1918 - val_loss: 0.2614
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1736 - val_loss: 0.2432
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1587 - val_loss: 0.2252
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1450 - val_loss: 0.2064
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1330 - val_loss: 0.1921
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1230 - val_loss: 0.1791
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1143 - val_loss: 0.1676
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1066 - val_loss: 0.1566
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0994 - val_loss: 0.1461
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0931 - val_loss: 0.1369
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0877 - val_loss: 0.1291
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0826 - val_loss: 0.1221
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0782 - val_loss: 0.1160
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0741 - val_loss: 0.1109
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0704 - val_loss: 0.1060
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0668 - val_loss: 0.1022
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0637 - val_loss: 0.0989
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0608 - val_loss: 0.0959
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0582 - val_loss: 0.0938
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0557 - val_loss: 0.0917
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0534 - val_loss: 0.0900
# Epoch 44/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0510 - val_loss: 0.0876
# Epoch 45/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0487 - val_loss: 0.0852
# Epoch 46/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0466 - val_loss: 0.0831
# Epoch 47/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0447 - val_loss: 0.0809
# Epoch 48/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0427 - val_loss: 0.0778
# Epoch 49/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0409 - val_loss: 0.0753
# Epoch 50/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0392 - val_loss: 0.0729
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 20.1416 - val_loss: 17.4905
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.9348 - val_loss: 16.4726
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.8554 - val_loss: 15.2033
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.3533 - val_loss: 13.0979
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.9714 - val_loss: 9.8417
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.7298 - val_loss: 6.0242
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2850 - val_loss: 2.9771
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0389 - val_loss: 1.5472
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1703 - val_loss: 1.0995
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8841 - val_loss: 0.9243
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7436 - val_loss: 0.8170
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6431 - val_loss: 0.7433
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5667 - val_loss: 0.6772
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5038 - val_loss: 0.6246
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4493 - val_loss: 0.5685
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4002 - val_loss: 0.5188
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3633 - val_loss: 0.4718
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3293 - val_loss: 0.4310
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2986 - val_loss: 0.3910
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2688 - val_loss: 0.3536
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2431 - val_loss: 0.3205
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2196 - val_loss: 0.2907
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1987 - val_loss: 0.2656
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1802 - val_loss: 0.2412
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1627 - val_loss: 0.2191
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1480 - val_loss: 0.2022
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1358 - val_loss: 0.1848
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1248 - val_loss: 0.1700
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1156 - val_loss: 0.1581
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1073 - val_loss: 0.1487
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0999 - val_loss: 0.1397
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0936 - val_loss: 0.1319
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0881 - val_loss: 0.1251
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0831 - val_loss: 0.1189
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0786 - val_loss: 0.1131
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0745 - val_loss: 0.1076
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0707 - val_loss: 0.1018
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0671 - val_loss: 0.0965
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0637 - val_loss: 0.0918
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0605 - val_loss: 0.0876
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0578 - val_loss: 0.0837
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0554 - val_loss: 0.0800
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0530 - val_loss: 0.0762
# Epoch 44/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0506 - val_loss: 0.0726
# Epoch 45/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - val_loss: 0.0693
# Epoch 46/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0464 - val_loss: 0.0667
# Epoch 47/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0446 - val_loss: 0.0642
# Epoch 48/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0429 - val_loss: 0.0617
# Epoch 49/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0413 - val_loss: 0.0598
# Epoch 50/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0398 - val_loss: 0.0576
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 23.8809 - val_loss: 16.4140
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.7958 - val_loss: 14.8107
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.1397 - val_loss: 13.5864
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.5457 - val_loss: 11.9250
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.3848 - val_loss: 9.5345
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.5104 - val_loss: 6.5160
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2611 - val_loss: 3.5418
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7007 - val_loss: 1.7805
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4919 - val_loss: 1.1788
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0853 - val_loss: 0.9697
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9014 - val_loss: 0.8452
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7719 - val_loss: 0.7680
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6739 - val_loss: 0.6958
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5993 - val_loss: 0.6332
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5370 - val_loss: 0.5783
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4808 - val_loss: 0.5319
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4299 - val_loss: 0.4816
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3862 - val_loss: 0.4356
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3477 - val_loss: 0.3925
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3129 - val_loss: 0.3573
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2805 - val_loss: 0.3259
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2502 - val_loss: 0.2949
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2233 - val_loss: 0.2681
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2009 - val_loss: 0.2426
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1807 - val_loss: 0.2198
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1631 - val_loss: 0.2001
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1472 - val_loss: 0.1837
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1326 - val_loss: 0.1708
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1206 - val_loss: 0.1601
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1101 - val_loss: 0.1512
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1008 - val_loss: 0.1435
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0927 - val_loss: 0.1362
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0859 - val_loss: 0.1308
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0795 - val_loss: 0.1241
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0740 - val_loss: 0.1173
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0688 - val_loss: 0.1118
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0641 - val_loss: 0.1068
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0599 - val_loss: 0.1010
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0563 - val_loss: 0.0965
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0529 - val_loss: 0.0921
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0500 - val_loss: 0.0885
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0473 - val_loss: 0.0849
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0448 - val_loss: 0.0810
# Epoch 44/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0426 - val_loss: 0.0778
# Epoch 45/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0405 - val_loss: 0.0747
# Epoch 46/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0387 - val_loss: 0.0720
# Epoch 47/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0369 - val_loss: 0.0697
# Epoch 48/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0353 - val_loss: 0.0673
# Epoch 49/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0337 - val_loss: 0.0649
# Epoch 50/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0324 - val_loss: 0.0628
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 25.0669 - val_loss: 17.3045
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.3647 - val_loss: 15.6213
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.6317 - val_loss: 14.8740
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14.5024 - val_loss: 13.7311
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.8627 - val_loss: 11.7584
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.3097 - val_loss: 8.7405
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.7553 - val_loss: 4.8256
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1920 - val_loss: 2.0444
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3711 - val_loss: 1.1096
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9038 - val_loss: 0.8703
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7321 - val_loss: 0.7334
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6105 - val_loss: 0.6467
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5235 - val_loss: 0.5819
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4561 - val_loss: 0.5227
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4051 - val_loss: 0.4769
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3640 - val_loss: 0.4402
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3328 - val_loss: 0.4106
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3055 - val_loss: 0.3838
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2809 - val_loss: 0.3595
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2579 - val_loss: 0.3349
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2364 - val_loss: 0.3104
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2173 - val_loss: 0.2881
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1984 - val_loss: 0.2661
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1810 - val_loss: 0.2438
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1641 - val_loss: 0.2207
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1479 - val_loss: 0.1995
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1334 - val_loss: 0.1797
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1215 - val_loss: 0.1656
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1118 - val_loss: 0.1528
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1032 - val_loss: 0.1418
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0956 - val_loss: 0.1324
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0889 - val_loss: 0.1246
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0830 - val_loss: 0.1178
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0773 - val_loss: 0.1111
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0723 - val_loss: 0.1046
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0678 - val_loss: 0.0990
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0641 - val_loss: 0.0932
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0607 - val_loss: 0.0888
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0577 - val_loss: 0.0841
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0548 - val_loss: 0.0804
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0522 - val_loss: 0.0771
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0498 - val_loss: 0.0735
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0475 - val_loss: 0.0705
# Epoch 44/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0454 - val_loss: 0.0677
# Epoch 45/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0433 - val_loss: 0.0648
# Epoch 46/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0413 - val_loss: 0.0626
# Epoch 47/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0395 - val_loss: 0.0606
# Epoch 48/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0379 - val_loss: 0.0587
# Epoch 49/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0365 - val_loss: 0.0568
# Epoch 50/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0351 - val_loss: 0.0549
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 21.5120 - val_loss: 18.9446
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.3581 - val_loss: 17.4141
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.7749 - val_loss: 15.3404
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.6610 - val_loss: 12.6539
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.8734 - val_loss: 9.2247
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.5289 - val_loss: 5.3381
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3775 - val_loss: 2.4502
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5684 - val_loss: 1.2949
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9479 - val_loss: 0.9958
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7397 - val_loss: 0.8561
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6054 - val_loss: 0.7357
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5001 - val_loss: 0.6249
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4193 - val_loss: 0.5365
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3551 - val_loss: 0.4717
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3041 - val_loss: 0.4152
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2616 - val_loss: 0.3622
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2274 - val_loss: 0.3185
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2000 - val_loss: 0.2817
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1763 - val_loss: 0.2515
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1566 - val_loss: 0.2242
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1398 - val_loss: 0.1999
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1250 - val_loss: 0.1794
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1130 - val_loss: 0.1622
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1027 - val_loss: 0.1481
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0932 - val_loss: 0.1360
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0849 - val_loss: 0.1251
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0778 - val_loss: 0.1153
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0716 - val_loss: 0.1064
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0662 - val_loss: 0.0987
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0617 - val_loss: 0.0922
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0578 - val_loss: 0.0866
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0545 - val_loss: 0.0818
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0516 - val_loss: 0.0777
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0488 - val_loss: 0.0741
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0464 - val_loss: 0.0705
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0441 - val_loss: 0.0672
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0421 - val_loss: 0.0644
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0403 - val_loss: 0.0618
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0387 - val_loss: 0.0595
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0373 - val_loss: 0.0577
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0359 - val_loss: 0.0563
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0346 - val_loss: 0.0549
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0335 - val_loss: 0.0539
# Epoch 44/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0325 - val_loss: 0.0530
# Epoch 45/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0316 - val_loss: 0.0519
# Epoch 46/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0307 - val_loss: 0.0510
# Epoch 47/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0299 - val_loss: 0.0503
# Epoch 48/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0292 - val_loss: 0.0493
# Epoch 49/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0284 - val_loss: 0.0485
# Epoch 50/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0278 - val_loss: 0.0476
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 22.7045 - val_loss: 17.8053
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.0279 - val_loss: 15.9447
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.1958 - val_loss: 14.4923
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.3408 - val_loss: 12.3871
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.7436 - val_loss: 9.3796
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.2990 - val_loss: 5.5507
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7736 - val_loss: 2.4576
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7488 - val_loss: 1.4034
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1037 - val_loss: 1.1350
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8900 - val_loss: 0.9848
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7580 - val_loss: 0.8587
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6499 - val_loss: 0.7381
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5534 - val_loss: 0.6330
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4740 - val_loss: 0.5446
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4092 - val_loss: 0.4743
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3558 - val_loss: 0.4100
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3111 - val_loss: 0.3618
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2740 - val_loss: 0.3200
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2417 - val_loss: 0.2819
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2133 - val_loss: 0.2496
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1902 - val_loss: 0.2243
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1716 - val_loss: 0.2043
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1558 - val_loss: 0.1862
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1413 - val_loss: 0.1688
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1282 - val_loss: 0.1554
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1164 - val_loss: 0.1424
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1063 - val_loss: 0.1318
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0974 - val_loss: 0.1235
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0890 - val_loss: 0.1168
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0819 - val_loss: 0.1102
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0755 - val_loss: 0.1035
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0700 - val_loss: 0.0980
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0651 - val_loss: 0.0927
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0610 - val_loss: 0.0872
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0571 - val_loss: 0.0833
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0540 - val_loss: 0.0785
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0512 - val_loss: 0.0753
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - val_loss: 0.0719
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0461 - val_loss: 0.0686
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0439 - val_loss: 0.0656
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0419 - val_loss: 0.0638
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0402 - val_loss: 0.0614
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0386 - val_loss: 0.0595
# Epoch 44/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0371 - val_loss: 0.0579
# Epoch 45/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0357 - val_loss: 0.0557
# Epoch 46/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0344 - val_loss: 0.0544
# Epoch 47/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0334 - val_loss: 0.0531
# Epoch 48/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0322 - val_loss: 0.0520
# Epoch 49/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0313 - val_loss: 0.0508
# Epoch 50/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0305 - val_loss: 0.0498
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 22.6417 - val_loss: 18.0633
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 16.4094 - val_loss: 15.2626
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 14.4650 - val_loss: 13.7957
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.5724 - val_loss: 11.7636
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.1810 - val_loss: 9.1322
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.2030 - val_loss: 5.8943
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9972 - val_loss: 2.9675
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8750 - val_loss: 1.5387
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1373 - val_loss: 1.1426
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9030 - val_loss: 0.9844
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7668 - val_loss: 0.8607
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6659 - val_loss: 0.7654
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5841 - val_loss: 0.6842
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5126 - val_loss: 0.6138
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4531 - val_loss: 0.5515
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4022 - val_loss: 0.4999
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3554 - val_loss: 0.4517
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3128 - val_loss: 0.4014
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2732 - val_loss: 0.3581
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2408 - val_loss: 0.3204
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2140 - val_loss: 0.2905
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1905 - val_loss: 0.2634
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1715 - val_loss: 0.2379
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1566 - val_loss: 0.2187
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1444 - val_loss: 0.2042
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1344 - val_loss: 0.1921
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1255 - val_loss: 0.1823
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1182 - val_loss: 0.1737
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1117 - val_loss: 0.1657
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1057 - val_loss: 0.1582
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1005 - val_loss: 0.1516
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0958 - val_loss: 0.1459
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0917 - val_loss: 0.1407
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0877 - val_loss: 0.1349
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0843 - val_loss: 0.1308
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0811 - val_loss: 0.1266
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0782 - val_loss: 0.1237
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0756 - val_loss: 0.1207
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0729 - val_loss: 0.1174
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0705 - val_loss: 0.1139
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0682 - val_loss: 0.1106
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0659 - val_loss: 0.1074
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0639 - val_loss: 0.1047
# Epoch 44/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0621 - val_loss: 0.1015
# Epoch 45/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0603 - val_loss: 0.0986
# Epoch 46/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0587 - val_loss: 0.0950
# Epoch 47/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0569 - val_loss: 0.0918
# Epoch 48/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0554 - val_loss: 0.0890
# Epoch 49/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0540 - val_loss: 0.0862
# Epoch 50/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0529 - val_loss: 0.0841
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 22.3541 - val_loss: 16.3746
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 16.2175 - val_loss: 14.4965
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14.3744 - val_loss: 12.9179
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.0518 - val_loss: 10.2478
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.7038 - val_loss: 6.5086
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6894 - val_loss: 2.8366
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9800 - val_loss: 1.3079
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0966 - val_loss: 0.9559
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8352 - val_loss: 0.7886
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6780 - val_loss: 0.6684
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5693 - val_loss: 0.5791
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4873 - val_loss: 0.5022
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4160 - val_loss: 0.4394
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3587 - val_loss: 0.3910
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3115 - val_loss: 0.3455
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2674 - val_loss: 0.3026
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2293 - val_loss: 0.2638
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1983 - val_loss: 0.2323
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1743 - val_loss: 0.2063
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1544 - val_loss: 0.1844
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1376 - val_loss: 0.1686
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1244 - val_loss: 0.1559
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1132 - val_loss: 0.1431
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1039 - val_loss: 0.1310
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0959 - val_loss: 0.1198
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0889 - val_loss: 0.1100
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0825 - val_loss: 0.1017
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0765 - val_loss: 0.0938
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0716 - val_loss: 0.0859
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0669 - val_loss: 0.0801
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0627 - val_loss: 0.0752
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0588 - val_loss: 0.0709
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0550 - val_loss: 0.0669
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0516 - val_loss: 0.0635
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0481 - val_loss: 0.0603
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0449 - val_loss: 0.0570
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0421 - val_loss: 0.0540
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0397 - val_loss: 0.0514
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0374 - val_loss: 0.0491
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0355 - val_loss: 0.0472
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0339 - val_loss: 0.0456
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0325 - val_loss: 0.0446
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0312 - val_loss: 0.0444
# Epoch 44/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0299 - val_loss: 0.0442
# Epoch 45/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0284 - val_loss: 0.0443
# Epoch 46/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0271 - val_loss: 0.0438
# Epoch 47/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0258 - val_loss: 0.0428
# Epoch 48/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0245 - val_loss: 0.0417
# Epoch 49/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0233 - val_loss: 0.0395
# Epoch 50/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0220 - val_loss: 0.0368
# /home/capybara/Desktop/matura_project_python/github/matura/FNN1_1.py:246: RuntimeWarning: divide by zero encountered in divide
#   relativeError = np.where(np.array(y_test) != 0, deviation.flatten() / np.abs(np.array(y_test)), deviation.flatten())

# %%
pad_value = 15
x_test = np.pad(x_test, ((0, 0), (1, 0)), 'constant', constant_values=pad_value)
out_x_test = np.pad(out_x_test, ((0, 0), (1, 0)), 'constant', constant_values=pad_value)
long_x_test = np.pad(long_x_test, ((0, 0), (1, 0)), 'constant', constant_values=pad_value)

x_test_dataset = tf.data.Dataset.from_tensor_slices(x_test).batch(batch_size)
out_x_test_dataset = tf.data.Dataset.from_tensor_slices(out_x_test).batch(batch_size)
long_x_test_dataset = tf.data.Dataset.from_tensor_slices(long_x_test).batch(batch_size)

# %%
#debuggng: 
# Add a custom callback to track the best epoch
class BestEpochTracker(tf.keras.callbacks.Callback):
    def __init__(self):
        self.best_val_loss = float('inf')
        self.best_epoch = 0
        
    def on_epoch_end(self, epoch, logs=None):
        val_loss = logs.get('val_loss')
        if val_loss is not None and val_loss < self.best_val_loss:
            self.best_val_loss = val_loss
            self.best_epoch = epoch + 1
            print(f"New best validation loss: {val_loss:.4f} at epoch {self.best_epoch}")

best_tracker = BestEpochTracker()

# %%
n_bootstrap = 1
count = 0
bootstrap_predsInRange = []
bootstrap_predsOutRange = []
bootstrap_predsLongRange = []

for i in range(n_bootstrap):
    early_stopping = tf.keras.callbacks.EarlyStopping(
        patience=20,
        min_delta=0.001,
        restore_best_weights=True,
        monitor='val_loss',
        mode="min", 
        verbose=1
    )
    tf.random.set_seed(i * 12345)  # Different seed each iteration
    best_model, lr_schedule = build_best_model(best_hps, num_epochs_best_model)
    best_model.compile(
        optimizer=tf.keras.optimizers.AdamW(
            learning_rate=lr_schedule,
            weight_decay = 4e-3,
            beta_1=0.85,  
            beta_2=0.999,  # Primary recommendation: lower this
            clipnorm=1.0
        ),
        loss='mse',
        metrics=['mse']
    )
    best_model.fit(
        train_dataset, # Pass the TensorFlow Dataset
        validation_data=val_dataset, # Pass the TensorFlow Dataset
        epochs=num_epochs_best_model,
        callbacks=[early_stopping, best_tracker],
        verbose = 1
    )
    
    bootstrap_predsInRange.append(best_model.predict(x_test_dataset))
    bootstrap_predsOutRange.append(best_model.predict(out_x_test_dataset))
    bootstrap_predsLongRange.append(best_model.predict(long_x_test_dataset))
    print(f"Done: {count}")
    count += 1

bootstrap_predsInRange = np.array(bootstrap_predsInRange)
bootstrap_predsOutRange = np.array(bootstrap_predsOutRange)
bootstrap_predsLongRange = np.array(bootstrap_predsLongRange)
# Out:
# Epoch 1/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - loss: 26.1186 - mse: 26.1186New best validation loss: 23.1943 at epoch 1
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 54s 346ms/step - loss: 25.3364 - mse: 25.3364 - val_loss: 23.1943 - val_mse: 23.1943
# Epoch 2/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 23.6189 - mse: 23.6189New best validation loss: 18.8464 at epoch 2
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 22.3800 - mse: 22.3800 - val_loss: 18.8464 - val_mse: 18.8464
# Epoch 3/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 19.5979 - mse: 19.5979 - val_loss: 21.2660 - val_mse: 21.2660
# Epoch 4/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 17.5499 - mse: 17.5499New best validation loss: 15.4750 at epoch 4
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 17.0574 - mse: 17.0574 - val_loss: 15.4750 - val_mse: 15.4750
# Epoch 5/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 15.6467 - mse: 15.6467New best validation loss: 14.3236 at epoch 5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 15.2560 - mse: 15.2560 - val_loss: 14.3236 - val_mse: 14.3236
# Epoch 6/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 13.2306 - mse: 13.2306New best validation loss: 12.7351 at epoch 6
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 12.6920 - mse: 12.6920 - val_loss: 12.7351 - val_mse: 12.7351
# Epoch 7/200
# 57/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 11.1368 - mse: 11.1368New best validation loss: 8.5340 at epoch 7
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.1161 - mse: 9.1161 - val_loss: 8.5340 - val_mse: 8.5340
# Epoch 8/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.3474 - mse: 8.3474 - val_loss: 8.6063 - val_mse: 8.6063
# Epoch 9/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.3009 - mse: 6.3009 - val_loss: 9.4644 - val_mse: 9.4644
# Epoch 10/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.8292 - mse: 6.8292New best validation loss: 4.2610 at epoch 10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.0835 - mse: 6.0835 - val_loss: 4.2610 - val_mse: 4.2610
# Epoch 11/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.3048 - mse: 7.3048 - val_loss: 19.3465 - val_mse: 19.3465
# Epoch 12/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 11.6816 - mse: 11.6816New best validation loss: 3.5432 at epoch 12
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.0335 - mse: 8.0335 - val_loss: 3.5432 - val_mse: 3.5432
# Epoch 13/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.4873 - mse: 5.4873 - val_loss: 5.8387 - val_mse: 5.8387
# Epoch 14/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.8088 - mse: 4.8088New best validation loss: 2.1966 at epoch 14
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.0024 - mse: 4.0024 - val_loss: 2.1966 - val_mse: 2.1966
# Epoch 15/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.7647 - mse: 2.7647 - val_loss: 6.2674 - val_mse: 6.2674
# Epoch 16/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.7171 - mse: 2.7171New best validation loss: 1.1274 at epoch 16
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.2825 - mse: 3.2825 - val_loss: 1.1274 - val_mse: 1.1274
# Epoch 17/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.9559 - mse: 2.9559 - val_loss: 1.9838 - val_mse: 1.9838
# Epoch 18/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.1533 - mse: 3.1533 - val_loss: 3.1662 - val_mse: 3.1662
# Epoch 19/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.8985 - mse: 5.8985 - val_loss: 2.2345 - val_mse: 2.2345
# Epoch 20/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.1900 - mse: 3.1900 - val_loss: 1.4257 - val_mse: 1.4257
# Epoch 21/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.8310 - mse: 3.8310 - val_loss: 1.3367 - val_mse: 1.3367
# Epoch 22/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.7437 - mse: 2.7437 - val_loss: 1.5033 - val_mse: 1.5033
# Epoch 23/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.2450 - mse: 4.2450 - val_loss: 8.0556 - val_mse: 8.0556
# Epoch 24/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 7.2838 - mse: 7.2838New best validation loss: 0.7123 at epoch 24
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.2142 - mse: 5.2142 - val_loss: 0.7123 - val_mse: 0.7123
# Epoch 25/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.6888 - mse: 2.6888 - val_loss: 2.0654 - val_mse: 2.0654
# Epoch 26/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.2266 - mse: 1.2266 - val_loss: 5.3291 - val_mse: 5.3291
# Epoch 27/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.1073 - mse: 3.1073 - val_loss: 3.6943 - val_mse: 3.6943
# Epoch 28/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.1498 - mse: 2.1498New best validation loss: 0.3082 at epoch 28
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5996 - mse: 1.5996 - val_loss: 0.3082 - val_mse: 0.3082
# Epoch 29/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.7702 - mse: 0.7702 - val_loss: 0.3167 - val_mse: 0.3167
# Epoch 30/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.6432 - mse: 1.6432 - val_loss: 0.6868 - val_mse: 0.6868
# Epoch 31/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4839 - mse: 1.4839 - val_loss: 0.4472 - val_mse: 0.4472
# Epoch 32/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.1530 - mse: 4.1530 - val_loss: 1.4581 - val_mse: 1.4581
# Epoch 33/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.9311 - mse: 1.9311 - val_loss: 1.0639 - val_mse: 1.0639
# Epoch 34/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0376 - mse: 1.0376 - val_loss: 1.4148 - val_mse: 1.4148
# Epoch 35/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0846 - mse: 1.0846 - val_loss: 0.6100 - val_mse: 0.6100
# Epoch 36/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0781 - mse: 1.0781 - val_loss: 0.4614 - val_mse: 0.4614
# Epoch 37/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3783 - mse: 0.3783 - val_loss: 0.3230 - val_mse: 0.3230
# Epoch 38/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.8920 - mse: 0.8920 - val_loss: 0.3823 - val_mse: 0.3823
# Epoch 39/200
# 57/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3854 - mse: 0.3854New best validation loss: 0.1995 at epoch 39
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3714 - mse: 0.3714 - val_loss: 0.1995 - val_mse: 0.1995
# Epoch 40/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4151 - mse: 1.4151 - val_loss: 0.8279 - val_mse: 0.8279
# Epoch 41/200
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6645 - mse: 0.6645New best validation loss: 0.1780 at epoch 41
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4919 - mse: 0.4919 - val_loss: 0.1780 - val_mse: 0.1780
# Epoch 42/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3816 - mse: 0.3816 - val_loss: 0.6220 - val_mse: 0.6220
# Epoch 43/200
# 57/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3853 - mse: 0.3853New best validation loss: 0.1144 at epoch 43
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2547 - mse: 0.2547 - val_loss: 0.1144 - val_mse: 0.1144
# Epoch 44/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.8425 - mse: 0.8425 - val_loss: 0.1681 - val_mse: 0.1681
# Epoch 45/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5840 - mse: 0.5840 - val_loss: 0.2873 - val_mse: 0.2873
# Epoch 46/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5285 - mse: 0.5285 - val_loss: 0.2593 - val_mse: 0.2593
# Epoch 47/200
# 57/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1753 - mse: 0.1753New best validation loss: 0.1011 at epoch 47
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1427 - mse: 0.1427 - val_loss: 0.1011 - val_mse: 0.1011
# Epoch 48/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1570 - mse: 0.1570 - val_loss: 0.2266 - val_mse: 0.2266
# Epoch 49/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1923 - mse: 0.1923 - val_loss: 0.2876 - val_mse: 0.2876
# Epoch 50/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1314 - mse: 0.1314New best validation loss: 0.0671 at epoch 50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1093 - mse: 0.1093 - val_loss: 0.0671 - val_mse: 0.0671
# Epoch 51/200
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0778 - mse: 0.0778New best validation loss: 0.0636 at epoch 51
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0928 - mse: 0.0928 - val_loss: 0.0636 - val_mse: 0.0636
# Epoch 52/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1392 - mse: 0.1392 - val_loss: 0.1387 - val_mse: 0.1387
# Epoch 53/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2968 - mse: 0.2968 - val_loss: 0.2434 - val_mse: 0.2434
# Epoch 54/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1403 - mse: 0.1403 - val_loss: 0.1176 - val_mse: 0.1176
# Epoch 55/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1276 - mse: 0.1276New best validation loss: 0.0597 at epoch 55
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1189 - mse: 0.1189 - val_loss: 0.0597 - val_mse: 0.0597
# Epoch 56/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0935 - mse: 0.0935 - val_loss: 0.0829 - val_mse: 0.0829
# Epoch 57/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0638 - mse: 0.0638 - val_loss: 0.0994 - val_mse: 0.0994
# Epoch 58/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0649 - mse: 0.0649 - val_loss: 0.0645 - val_mse: 0.0645
# Epoch 59/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0434 - mse: 0.0434 - val_loss: 0.0863 - val_mse: 0.0863
# Epoch 60/200
# 57/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0646 - mse: 0.0646New best validation loss: 0.0322 at epoch 60
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0569 - mse: 0.0569 - val_loss: 0.0322 - val_mse: 0.0322
# Epoch 61/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1092 - mse: 0.1092 - val_loss: 0.0505 - val_mse: 0.0505
# Epoch 62/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5589 - mse: 0.5589 - val_loss: 0.1347 - val_mse: 0.1347
# Epoch 63/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0609 - mse: 0.0609 - val_loss: 0.0366 - val_mse: 0.0366
# Epoch 64/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0380 - mse: 0.0380 - val_loss: 0.0430 - val_mse: 0.0430
# Epoch 65/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0368 - mse: 0.0368 - val_loss: 0.0580 - val_mse: 0.0580
# Epoch 66/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0704 - mse: 0.0704 - val_loss: 0.6971 - val_mse: 0.6971
# Epoch 67/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0704 - mse: 0.0704 - val_loss: 0.0515 - val_mse: 0.0515
# Epoch 68/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0299 - mse: 0.0299 - val_loss: 0.0344 - val_mse: 0.0344
# Epoch 69/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0486 - mse: 0.0486 - val_loss: 0.0327 - val_mse: 0.0327
# Epoch 70/200
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0391 - mse: 0.0391New best validation loss: 0.0234 at epoch 70
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0359 - mse: 0.0359 - val_loss: 0.0234 - val_mse: 0.0234
# Epoch 71/200
# 57/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0225 - mse: 0.0225New best validation loss: 0.0131 at epoch 71
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0225 - mse: 0.0225 - val_loss: 0.0131 - val_mse: 0.0131
# Epoch 72/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0154 - mse: 0.0154New best validation loss: 0.0126 at epoch 72
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0126 - val_mse: 0.0126
# Epoch 73/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0178 - mse: 0.0178 - val_loss: 0.0798 - val_mse: 0.0798
# Epoch 74/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0302 - mse: 0.0302 - val_loss: 0.0194 - val_mse: 0.0194
# Epoch 75/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0166 - mse: 0.0166 - val_loss: 0.0195 - val_mse: 0.0195
# Epoch 76/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0166 - mse: 0.0166 - val_loss: 0.0207 - val_mse: 0.0207
# Epoch 77/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0307 - mse: 0.0307 - val_loss: 0.0407 - val_mse: 0.0407
# Epoch 78/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0284 - mse: 0.0284 - val_loss: 0.0472 - val_mse: 0.0472
# Epoch 79/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0243 - mse: 0.0243 - val_loss: 0.0212 - val_mse: 0.0212
# Epoch 80/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0141 - mse: 0.0141 - val_loss: 0.0178 - val_mse: 0.0178
# Epoch 81/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0096 - mse: 0.0096New best validation loss: 0.0096 at epoch 81
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 82/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0232 - mse: 0.0232 - val_loss: 0.0376 - val_mse: 0.0376
# Epoch 83/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0254 - mse: 0.0254 - val_loss: 0.0312 - val_mse: 0.0312
# Epoch 84/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0270 - mse: 0.0270 - val_loss: 0.0495 - val_mse: 0.0495
# Epoch 85/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0228 - mse: 0.0228 - val_loss: 0.0389 - val_mse: 0.0389
# Epoch 86/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0312 - mse: 0.0312 - val_loss: 0.0375 - val_mse: 0.0375
# Epoch 87/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0218 - val_mse: 0.0218
# Epoch 88/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0159 - val_mse: 0.0159
# Epoch 89/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0140 - mse: 0.0140 - val_loss: 0.0227 - val_mse: 0.0227
# Epoch 90/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0241 - mse: 0.0241 - val_loss: 0.0295 - val_mse: 0.0295
# Epoch 91/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 92/200
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0112 - mse: 0.0112New best validation loss: 0.0070 at epoch 92
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 93/200
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0059 - mse: 0.0059New best validation loss: 0.0070 at epoch 93
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 94/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 95/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0152 - val_mse: 0.0152
# Epoch 96/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0141 - mse: 0.0141 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 97/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.0304 - val_mse: 0.0304
# Epoch 98/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0175 - mse: 0.0175 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 99/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0251 - mse: 0.0251 - val_loss: 0.0375 - val_mse: 0.0375
# Epoch 100/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0276 - mse: 0.0276 - val_loss: 0.0360 - val_mse: 0.0360
# Epoch 101/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0194 - mse: 0.0194 - val_loss: 0.0138 - val_mse: 0.0138
# Epoch 102/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0161 - val_mse: 0.0161
# Epoch 103/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0131 - val_mse: 0.0131
# Epoch 104/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0119 - mse: 0.0119New best validation loss: 0.0066 at epoch 104
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 105/200
# 57/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0052 - mse: 0.0052New best validation loss: 0.0047 at epoch 105
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 106/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 107/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0161 - val_mse: 0.0161
# Epoch 108/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0251 - mse: 0.0251 - val_loss: 0.0152 - val_mse: 0.0152
# Epoch 109/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 110/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0083 - mse: 0.0083New best validation loss: 0.0047 at epoch 110
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 111/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 112/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 113/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 114/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0075 - mse: 0.0075New best validation loss: 0.0046 at epoch 114
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 115/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 116/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 117/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 118/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 119/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 120/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0126 - val_mse: 0.0126
# Epoch 121/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 122/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 123/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 124/200
# 57/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0031 - mse: 0.0031New best validation loss: 0.0039 at epoch 124
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 125/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0024 - mse: 0.0024New best validation loss: 0.0032 at epoch 125
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 126/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 127/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 128/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 129/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 130/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 131/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 132/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 133/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 134/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 135/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 136/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 137/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 138/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mse: 0.0017New best validation loss: 0.0028 at epoch 138
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 139/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 140/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 141/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 142/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 143/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 144/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 145/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 145: early stopping
# Restoring model weights from the end of the best epoch: 125.
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 6s 91ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step
# Done: 0

# %%
best_model.summary()
# Out:
# Model: "transformer_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_17 (Dense)                │ (None, 16, 32)         │            64 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoder_1 (Encoder)             │ ?                      │        38,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_36 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 114,628 (447.77 KB)
#  Trainable params: 38,209 (149.25 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 76,419 (298.52 KB)

# %%
bootstrap_predsInRange.shape
# Out:
# (1, 1457, 1)

# %%
predsInRange = []
predsOutRange = []
predsLongRange = []

for i in range(len(x_test)):
    counter = 0
    for j in range(n_bootstrap):
        counter += bootstrap_predsInRange[j][i]
    predsInRange.append(counter/n_bootstrap)

for i in range(len(out_x_test)):
    counter = 0
    for j in range(n_bootstrap):
        counter += bootstrap_predsOutRange[j][i]
    predsOutRange.append(counter/n_bootstrap)

for i in range(len(long_x_test)):
    counter = 0
    for j in range(n_bootstrap):
        counter += bootstrap_predsLongRange[j][i]
    predsLongRange.append(counter/n_bootstrap)

# %%
reldiffInRange = []
diffInRange = []
safe_y_test = np.where(np.isclose(y_test,0.0), 1.0, y_test)

for i in range(len(y_test)):
    diffInRange.append(abs(y_test[i] - predsInRange[i]))
    reldiffInRange.append(abs(y_test[i] - predsInRange[i])/abs(safe_y_test[i]))
print(len(diffInRange))
print("MAE in Range: ", np.mean(diffInRange))
print("MRE in Range: ", np.mean(reldiffInRange))

diffLongRange = []
for i in range(200, 300):
    diffLongRange.append(np.array(np.abs(long_y_test[i]) - np.array(predsInRange[i])))
    
NEEDdiffLongRange = []
for i in range(len(long_y_test)):
    NEEDdiffLongRange.append(np.array(np.abs(long_y_test[i]) - np.array(predsInRange[i])))
print("MAE longer Expressions: ", np.mean(NEEDdiffLongRange))

diffOutRange = []
for i in range(len(out_y_test)):
    diffOutRange.append(abs(out_y_test[i] - predsOutRange[i]))
safe_out_y_test = np.where(out_y_test == 0, 1, out_y_test)
diff_out_relError = []
for i in range(len(out_y_test)):
    diff_out_relError.append(abs(diffOutRange[i] / safe_out_y_test[i]))
print("MAE out Range: ", np.mean(diffOutRange))
print("MRE out Range: ", np.mean(diff_out_relError))
# Out:
# 1457
# MAE in Range:  0.03661414
# MRE in Range:  0.014528116
# MAE longer Expressions:  5.999146
# MAE out Range:  4.711177
# MRE out Range:  0.53417957

# %%
placeholder = absSum(outsideExpr)
diffOutRange = []
indices_with_placeholder_22 = [i for i, val in enumerate(placeholder) if val == 22] 

for i in indices_with_placeholder_22:
    diffOutRange.append(np.abs(out_y_test[i]-predsOutRange[i]))

# %%
meanDiff_InRange = np.mean(diffInRange)
meanDiff_OutRange = np.mean(diffOutRange)
meanDiff_LongRange = np.mean(diffLongRange)
meanDiff_OutRelRange = np.mean(diff_out_relError)

# %%
benchmark = 0
benchmark += baseline_deviation / (meanDiff_InRange**2) / 4
print(baseline_deviation / (meanDiff_InRange**2) / 4)

benchmark += baseline_out_deviation / (meanDiff_OutRange**2) / 4
print(baseline_out_deviation / (meanDiff_OutRange**2) / 4)

benchmark += baseline_long_deviation / (meanDiff_LongRange**2) / 4
print(baseline_long_deviation / (meanDiff_LongRange**2) / 4)

benchmark += baseline_relError / (meanDiff_OutRelRange**2) / 4
print(baseline_relError / (meanDiff_OutRelRange**2) / 4)

print(f"Benchmark: {benchmark}")
# Out:
# 1.3597050229232348
# 0.06917173029218447
# 0.12396280206294903
# 2.7390981917457458
# Benchmark: 4.2919377470241145
