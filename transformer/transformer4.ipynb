# %%
import sys
import os
import numpy as np
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Dense, Layer, Dropout

print("Successfully imported libraries!")
# Out:
# Successfully imported libraries!

# %%
# List available GPUs
gpus = tf.config.list_physical_devices('GPU')
print("GPUs Available:", gpus)

# Check if TensorFlow will place operations on the GPU
print("TensorFlow Version:", tf.__version__)

# Run a quick test
with tf.device('/GPU:0'):
    a = tf.random.normal([1000, 1000])
    b = tf.random.normal([1000, 1000])
    c = tf.matmul(a, b)
    print("Test computation done on GPU")
# Out:
# GPUs Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# TensorFlow Version: 2.16.1
# 2025-08-17 12:56:44.900542: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:00:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-08-17 12:56:48.746675: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:00:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-08-17 12:56:48.747002: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:00:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-08-17 12:56:48.752555: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:00:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-08-17 12:56:48.752874: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:00:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-08-17 12:56:48.753073: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:00:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-08-17 12:56:48.974869: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:00:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-08-17 12:56:48.975324: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:00:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-08-17 12:56:48.975420: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2025-08-17 12:56:48.975711: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:00:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-08-17 12:56:48.975916: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3537 MB memory:  -> device: 0, name: Orin, pci bus id: 0000:00:00.0, compute capability: 8.7
# Test computation done on GPU

# %%
# Get the absolute path of the current script's directory
current_dir = os.path.dirname(os.path.abspath("transformer0.ipynb"))

# Get the absolute path of the parent directory (project_folder)
parent_dir = os.path.dirname(current_dir)

# Add the parent directory to the Python path
sys.path.append(parent_dir)

# Now you can import from GetXY.py
from GetXY import x_train, y_train, x_val, y_val, early_stopping

# ... rest of your code
print("Successfully imported variables!")
# Out:
# 0 - 1 - 0
# 2543
# -1.0
#
# Expressions not in x:
# 0 + 3 + 3
# True
# 1457
# 6.0
# 15
# -4.0
# [-5.   1.   1.   0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5
#   0.5]
# Successfully imported variables!

# %%
#add a cls token at the beginning of x_train and x_val
pad_value = 15
x_train = np.pad(x_train, ((0, 0), (1, 0)), 'constant', constant_values=pad_value)
x_val = np.pad(x_val, ((0, 0), (1, 0)), 'constant', constant_values=pad_value)

# %%
#defining the positional encoder modelled after the formula in the paper that was cited. (generated by gemini)
def posEncoding(max_seq_len, d_model):
    # Create a matrix of angles according to the formula
    angle_rads = get_angles(np.arange(max_seq_len)[:, np.newaxis],
                          np.arange(d_model)[np.newaxis, :],
                          d_model)
    
    # Apply sine to even indices in the array; 2i
    angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
    
    # Apply cosine to odd indices in the array; 2i+1
    angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
    
    # Add a batch dimension
    pos_encoding = angle_rads[np.newaxis, ...]
    
    return tf.cast(pos_encoding, dtype=tf.float32)

def get_angles(pos, i, d_model):
    angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
    return pos * angle_rates

# %%
#defining the point-wise FNN
#d_ff = 2048 #(original transformer size)
def point_wise_fnn(d_model, d_ff):
    return tf.keras.Sequential([
        Dense(d_ff, activation = "relu", kernel_initializer = "glorot_uniform", bias_initializer = "zeros"),
        Dense(d_model, kernel_initializer = "glorot_uniform", bias_initializer = "zeros")
    ])

# %%
#scaled dot-product attention
class MH_Attention(Layer):
    def __init__(self, d_model, num_heads):
        super().__init__()
        #for the split_heads function:
        self.num_heads = num_heads
        self.d_model = d_model
        
        assert d_model % self.num_heads == 0
        self.depth = d_model // self.num_heads

        #for the call function:
        #This allows the model to learn the best way to project the input embeddings. (linear projection)
        self.wq = Dense(d_model, kernel_initializer = "glorot_uniform", bias_initializer = "zeros")
        self.wk = Dense(d_model, kernel_initializer = "glorot_uniform", bias_initializer = "zeros")
        self.wv = Dense(d_model, kernel_initializer = "glorot_uniform", bias_initializer = "zeros")

        #it's important to initialize this aswell as the ones above here, so that the model saves the previous weights and is able to learn.
        self.finalDense = Dense(d_model, kernel_initializer = "glorot_uniform", bias_initializer = "zeros")
        
    def SDP_Attention(self, q, k, v, mask):
        matmul_qk = tf.matmul(q, k, transpose_b=True) #calculate the dotproduct, between the query and a transposed key.
        d_k = tf.shape(k)[-1] #read the dimensionality of the key tensor (here d_model/num_heads = depth)
        d_k = tf.cast(d_k, tf.float32) #convert to float type
        scaled_qk = matmul_qk / tf.math.sqrt(d_k) #scale for purposes discussed in their paper.        

        if mask is not None:
            scaled_qk += (mask * -1e9) #masking to a big negative number
        
        softmaxed_qk = tf.nn.softmax(scaled_qk, axis = -1) #apply softmax function (axis = -1) for softmaxing all the different keys. The last entry is the number of keys (not the dimensionality of them, like it was befre.)
        output = tf.matmul(softmaxed_qk, v) #multiply the attention-weights with the values corresponding to the keys, in respect to the query.
        return output, softmaxed_qk
        
    def split_heads(self, x, batch_size):
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth)) #splits up the x data which is gonna be q, k, or v, into the individual heads. effectively adding a dimension (self.num_heads), after splitting up self.d_model
        return tf.transpose(x, perm =[0,2,1,3]) #reorganizes the dimensions into the expected order (batch_size, num_heads, seq_len, depth(the new d_model "fractions"))

    def call(self, q, k ,v, mask = None):
        batch_size = tf.shape(q)[0]

        #(linear projection)
        q = self.wq(q)
        k = self.wk(k)
        v = self.wv(v)

        #split them all up into the individual heads. (add a dimension basically)
        q = self.split_heads(q , batch_size)
        k = self.split_heads(k , batch_size)
        v = self.split_heads(v , batch_size)

        sdp_attention, attention_weights = self.SDP_Attention(q,k,v, mask = mask) #applies the sdp-attention to all of them. sdp_attention at the end has a shape of: (batch_size, num_heads, seq_len, depth)
        
        sdp_attention = tf.transpose(sdp_attention, perm=[0, 2, 1, 3]) #swap the 2nd and 3rd dimensions
        combined_attention = tf.reshape(sdp_attention, (batch_size, -1, self.d_model)) #combine back the two last dimnensions (num_heads and depth) into the original d_model

        output = self.finalDense(combined_attention)
        return output, attention_weights

# %%
class EncodingLayer(Layer):
    def __init__(self, d_model, num_heads, d_ff, rate):
        super().__init__()
        #define all the components of a Layer so the model will learn them properly here.
        self.mha = MH_Attention(d_model, num_heads)
        self.fnn = point_wise_fnn(d_model, d_ff)

        #initiate the 2 normalizations
        self.norm1 = tf.keras.layers.LayerNormalization()
        self.norm2 = tf.keras.layers.LayerNormalization()

        self.dropout1 = Dropout(rate)
        self.dropout2 = Dropout(rate)

        
    def call(self,x, training, mask = None):
        mha_out, attention_weights = self.mha(x,x,x,mask = mask) #for self-attention: q,k,v = x
        mha_out = self.dropout1(mha_out, training = training) #they apply a small dropout of 0.1 after every residual step in the paper.

        norm_out = self.norm1(x + mha_out) #first, add the vectors, then normalize them.

        fnn_out = self.fnn(norm_out) #2nd sub-layer with fnn
        fnn_out = self.dropout2(fnn_out, training = training) #again apply drop out

        norm2_out = self.norm2(norm_out + fnn_out) #again add and norm

        return norm2_out

# %%
class Encoder(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, num_layers, d_ff, rate):
        super().__init__()

        self.d_model = d_model
        self.num_layers = num_layers #amount of encoding layers
        self.layers = [EncodingLayer(d_model, num_heads, d_ff, rate) for i in range(num_layers)] #define multiple diffferent encoding layers here.

        self.dropout = Dropout(rate)
            
    def call(self, x, training, mask = None):
        x = self.dropout(x, training = training) #we want to drop out before the first layer
        for i in range(self.num_layers):
            x = self.layers[i](x, training = training, mask = mask)
        return x

# %%
class Transformer(tf.keras.Model):
    def __init__(self, embedding_layer, d_model, max_seq_len, num_heads, num_layers, d_ff, rate):
        super().__init__()
        self.embedding = embedding_layer
        self.d_model = d_model
        self.pos_enc = posEncoding(max_seq_len, d_model)
        self.Encoder = Encoder(d_model, num_heads, num_layers, d_ff, rate)
        self.dropout = tf.keras.layers.Dropout(rate)
        self.finalDense = Dense(1, activation = "linear", kernel_initializer = "glorot_uniform", bias_initializer = "zeros")
        
    def call(self, x, training, mask = None):
        seq_len = tf.shape(x)[1]
        x = tf.expand_dims(x, axis=-1) #add a dimension to x
        x = self.embedding(x)
        x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32)) #scale with √d_model
        x += self.pos_enc[:, :seq_len, :]
        
        out_Encoder = self.Encoder(x, training = training, mask = mask)

        output = out_Encoder[:,0,:] #pooling: to the first token.
        output = self.dropout(output, training = training) #another dropout

        final = self.finalDense(output) #now we can reduce back to a single neuron. This is the opposite of what we did in the embedding layer.

        return final

# %%
# Define a custom learning rate schedule class with warmup and cosine decay
class WarmupCosineDecay(tf.keras.optimizers.schedules.LearningRateSchedule):
    """
    A custom learning rate schedule that implements a linear warmup
    followed by a cosine decay.
    """
    def __init__(self, peak_lr, warmup_steps, decay_steps, alpha=0.0, name=None):
        super().__init__()
        self.peak_lr = peak_lr
        self.warmup_steps = warmup_steps
        self.decay_steps = decay_steps
        self.alpha = alpha
        self.name = name

    def __call__(self, step):
        with tf.name_scope(self.name or "WarmupCosineDecay"):
            # Ensure step is a float for calculations
            step = tf.cast(step, tf.float32)
            
            # --- 1. Warmup Phase ---
            # Linearly increase the learning rate from 0 to peak_lr
            warmup_lr = self.peak_lr * (step / self.warmup_steps)

            # --- 2. Cosine Decay Phase ---
            # Define the cosine decay schedule
            cosine_decay_schedule = tf.keras.optimizers.schedules.CosineDecay(
                initial_learning_rate=self.peak_lr,
                decay_steps=self.decay_steps,
                alpha=self.alpha
            )
            # Calculate the learning rate for the decay phase.
            # Note: The 'step' for the cosine part must be relative to its start.
            decay_lr = cosine_decay_schedule(step - self.warmup_steps)

            # --- 3. Choose the correct phase ---
            # Use tf.where to select the learning rate based on the current step
            learning_rate = tf.where(
                step < self.warmup_steps,
                warmup_lr,
                decay_lr
            )
            return learning_rate

    def get_config(self):
        return {
            "peak_lr": self.peak_lr,
            "warmup_steps": self.warmup_steps,
            "decay_steps": self.decay_steps,
            "alpha": self.alpha,
            "name": self.name
        }

# %%
import keras_tuner
from tensorflow.keras import backend as K
def build_model(hp):
    K.clear_session()
    # A smaller configuration to reduce overfitting
    # Ensure compatibility
    num_heads = hp.Choice('num_heads', [2, 4, 8])  # Powers of 2 work well
    d_model = hp.Choice('d_model', [32, 64, 128])   # Also powers of 2
    # This guarantees d_model % num_heads == 0
    num_layers = hp.Int('num_layers', 2, 6)
    d_ff = hp.Choice('d_ff', [64, 128, 256, 512])   # Multiples that work well
    if hp.Boolean("dropout"):
        dropout_rate = 0.2 
    else: 
        dropout_rate = 0
    peak_lr = hp.Float("peak learning rate", min_value = 1e-7, max_value = 1e-2, sampling="log")

    embedding_layer = Dense(d_model, kernel_initializer = "glorot_uniform", bias_initializer = "zeros")
    batch_size = 32
    num_epochs = 25
    max_seq_len = 16
    warmup_epochs = 3
    

    
    transformer_model = Transformer(
        embedding_layer = embedding_layer, 
        d_model = d_model,
        max_seq_len = max_seq_len,
        num_heads = num_heads,
        num_layers = num_layers,
        d_ff = d_ff,
        rate = dropout_rate
    )


        # Calculate steps based on your data
    # IMPORTANT: Use the actual length of your training data for this calculation
    steps_per_epoch = len(x_train) // batch_size
    warmup_steps = warmup_epochs * steps_per_epoch
    decay_steps = (num_epochs - warmup_epochs) * steps_per_epoch
    
    # Create an instance of our new scheduler
    lr_schedule = WarmupCosineDecay(
        peak_lr=peak_lr,
        warmup_steps=warmup_steps,
        decay_steps=decay_steps,
        alpha=0.1 # This means the LR will decay to 10% of peak_lr
    )

    transformer_model.compile(
        optimizer=tf.keras.optimizers.AdamW(
            learning_rate=lr_schedule,
            weight_decay = 4e-3,
            beta_1=0.85,  
            beta_2=0.999,  # Primary recommendation: lower this
            clipnorm=1.0
        ),
        loss='mse'
    )
    return transformer_model

build_model(keras_tuner.HyperParameters())
# Out:
# <Transformer name=transformer, built=False>

# %%
tuner = keras_tuner.BayesianOptimization(
    hypermodel=build_model,
    objective="val_loss",
    max_trials=50,
    executions_per_trial=1,
    overwrite=False
)
# Out:
# Reloading Tuner from ./untitled_project/tuner0.json

# %%
num_epochs = 25
batch_size = 32

train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(len(x_train)).batch(batch_size)
val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val)).batch(batch_size)

tuner.search(train_dataset, epochs = num_epochs, validation_data = (val_dataset), verbose = 0, callbacks = [early_stopping])

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in ./untitled_project
# Showing 10 best trials
# Objective(name="val_loss", direction="min")
#
# Trial 23 summary
# Hyperparameters:
# num_heads: 8
# d_model: 32
# num_layers: 3
# d_ff: 128
# dropout: False
# peak learning rate: 0.0014188984633416947
# Score: 0.13932304084300995
#
# Trial 04 summary
# Hyperparameters:
# num_heads: 2
# d_model: 64
# num_layers: 4
# d_ff: 512
# dropout: False
# peak learning rate: 0.00023727638415800082
# Score: 0.5695855617523193
#
# Trial 19 summary
# Hyperparameters:
# num_heads: 2
# d_model: 64
# num_layers: 4
# d_ff: 512
# dropout: False
# peak learning rate: 0.00017753963838400855
# Score: 1.641616940498352
#
# Trial 42 summary
# Hyperparameters:
# num_heads: 4
# d_model: 128
# num_layers: 3
# d_ff: 512
# dropout: False
# peak learning rate: 0.0004034381760009418
# Score: 6.7436699867248535
#
# Trial 20 summary
# Hyperparameters:
# num_heads: 2
# d_model: 64
# num_layers: 4
# d_ff: 512
# dropout: False
# peak learning rate: 0.0002221139550977517
# Score: 7.766565322875977
#
# Trial 06 summary
# Hyperparameters:
# num_heads: 2
# d_model: 32
# num_layers: 2
# d_ff: 256
# dropout: False
# peak learning rate: 0.0018620036258997228
# Score: 10.484166145324707
#
# Trial 07 summary
# Hyperparameters:
# num_heads: 2
# d_model: 64
# num_layers: 5
# d_ff: 256
# dropout: False
# peak learning rate: 6.836644645712527e-05
# Score: 10.627899169921875
#
# Trial 18 summary
# Hyperparameters:
# num_heads: 2
# d_model: 64
# num_layers: 4
# d_ff: 512
# dropout: False
# peak learning rate: 0.0006572830203098331
# Score: 11.503336906433105
#
# Trial 38 summary
# Hyperparameters:
# num_heads: 8
# d_model: 64
# num_layers: 6
# d_ff: 512
# dropout: False
# peak learning rate: 7.544146171497126e-06
# Score: 15.012101173400879
#
# Trial 47 summary
# Hyperparameters:
# num_heads: 2
# d_model: 32
# num_layers: 3
# d_ff: 512
# dropout: False
# peak learning rate: 0.0017666057033955919
# Score: 15.705245018005371

# %%
# Get the best hyperparameters
best_hps = tuner.get_best_hyperparameters()[0]

# %%
def build_best_model(hp, num_epochs):
    # A smaller configuration to reduce overfitting
    # Ensure compatibility
    num_heads = hp.Choice('num_heads', [2, 4, 8])  # Powers of 2 work well
    d_model = hp.Choice('d_model', [32, 64, 128])   # Also powers of 2
    # This guarantees d_model % num_heads == 0
    num_layers = hp.Int('num_layers', 2, 6)
    d_ff = hp.Choice('d_ff', [64, 128, 256, 512])   # Multiples that work well
    if hp.Boolean("dropout"):
        dropout_rate = 0.2 
    else: 
        dropout_rate = 0
    peak_lr = hp.Float("peak learning rate", min_value = 1e-7, max_value = 1e-2, sampling="log")

    embedding_layer = Dense(d_model, kernel_initializer = "glorot_uniform", bias_initializer = "zeros")
    batch_size = 32
    num_epochs = num_epochs
    max_seq_len = 16
    warmup_epochs = np.floor(num_epochs/10) + 1
    

    
    transformer_model = Transformer(
        embedding_layer = embedding_layer, 
        d_model = d_model,
        max_seq_len = max_seq_len,
        num_heads = num_heads,
        num_layers = num_layers,
        d_ff = d_ff,
        rate = dropout_rate
    )


        # Calculate steps based on your data
    # IMPORTANT: Use the actual length of your training data for this calculation
    steps_per_epoch = len(x_train) // batch_size
    warmup_steps = warmup_epochs * steps_per_epoch
    decay_steps = (num_epochs - warmup_epochs) * steps_per_epoch
    
    # Create an instance of our new scheduler
    lr_schedule = WarmupCosineDecay(
        peak_lr=peak_lr,
        warmup_steps=warmup_steps,
        decay_steps=decay_steps,
        alpha=0.1 # This means the LR will decay to 10% of peak_lr
    )
    return transformer_model, lr_schedule
num_epochs_best_model = 200

# %%
from FNN1_1 import baseline_deviation, baeline_out_deviation, baseline_long_deviation, baseline_relError, absSum
baseline_out_deviation = baeline_out_deviation
from GetXY import x_test, y_test, out_x_test, out_y_test, long_x_test, long_y_test, outsideExpr, absSum
# Out:
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1755428218.451616   67410 service.cc:145] XLA service 0xfffe640059e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1755428218.451730   67410 service.cc:153]   StreamExecutor device (0): Orin, Compute Capability 8.7
# 2025-08-17 12:56:58.501713: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-08-17 12:56:58.830473: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 90300
# 24/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 26.5995
# I0000 00:00:1755428219.692198   67410 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 22.8724 - val_loss: 16.8543
# Epoch 2/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.0003 - val_loss: 14.9933
# Epoch 3/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.6858 - val_loss: 13.9834
# Epoch 4/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14.4524 - val_loss: 12.6543
# Epoch 5/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.6113 - val_loss: 10.5065
# Epoch 6/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.0018 - val_loss: 7.8015
# Epoch 7/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.8661 - val_loss: 4.7845
# Epoch 8/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8030 - val_loss: 2.3653
# Epoch 9/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8328 - val_loss: 1.2436
# Epoch 10/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0682 - val_loss: 0.9305
# Epoch 11/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8496 - val_loss: 0.8136
# Epoch 12/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7541 - val_loss: 0.7417
# Epoch 13/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6874 - val_loss: 0.6924
# Epoch 14/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6293 - val_loss: 0.6442
# Epoch 15/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5762 - val_loss: 0.5990
# Epoch 16/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5286 - val_loss: 0.5568
# Epoch 17/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4863 - val_loss: 0.5158
# Epoch 18/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4451 - val_loss: 0.4751
# Epoch 19/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4063 - val_loss: 0.4358
# Epoch 20/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3716 - val_loss: 0.4014
# Epoch 21/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3385 - val_loss: 0.3651
# Epoch 22/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3059 - val_loss: 0.3313
# Epoch 23/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2767 - val_loss: 0.3015
# Epoch 24/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2502 - val_loss: 0.2733
# Epoch 25/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2265 - val_loss: 0.2478
# Epoch 26/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2056 - val_loss: 0.2258
# Epoch 27/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1866 - val_loss: 0.2050
# Epoch 28/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1699 - val_loss: 0.1872
# Epoch 29/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1558 - val_loss: 0.1726
# Epoch 30/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1435 - val_loss: 0.1595
# Epoch 31/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1322 - val_loss: 0.1478
# Epoch 32/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1225 - val_loss: 0.1372
# Epoch 33/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1137 - val_loss: 0.1274
# Epoch 34/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1058 - val_loss: 0.1194
# Epoch 35/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0987 - val_loss: 0.1123
# Epoch 36/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0924 - val_loss: 0.1051
# Epoch 37/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0867 - val_loss: 0.0988
# Epoch 38/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0815 - val_loss: 0.0933
# Epoch 39/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0766 - val_loss: 0.0874
# Epoch 40/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0722 - val_loss: 0.0826
# Epoch 41/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0683 - val_loss: 0.0782
# Epoch 42/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0650 - val_loss: 0.0740
# Epoch 43/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0618 - val_loss: 0.0701
# Epoch 44/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0591 - val_loss: 0.0666
# Epoch 45/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0563 - val_loss: 0.0633
# Epoch 46/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0538 - val_loss: 0.0609
# Epoch 47/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0516 - val_loss: 0.0586
# Epoch 48/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0497 - val_loss: 0.0568
# Epoch 49/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0480 - val_loss: 0.0549
# Epoch 50/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0463 - val_loss: 0.0531
# Epoch 51/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0448 - val_loss: 0.0518
# Epoch 52/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0434 - val_loss: 0.0505
# Epoch 53/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0420 - val_loss: 0.0497
# Epoch 54/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0408 - val_loss: 0.0486
# Epoch 55/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0395 - val_loss: 0.0477
# Epoch 56/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0384 - val_loss: 0.0464
# Epoch 57/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0374 - val_loss: 0.0455
# Epoch 58/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0364 - val_loss: 0.0444
# Epoch 59/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0355 - val_loss: 0.0435
# Epoch 60/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0347 - val_loss: 0.0423
# Epoch 61/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0338 - val_loss: 0.0413
# Epoch 62/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0330 - val_loss: 0.0405
# Epoch 63/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0323 - val_loss: 0.0395
# Epoch 64/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0316 - val_loss: 0.0387
# Epoch 65/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0309 - val_loss: 0.0377
# Epoch 66/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0303 - val_loss: 0.0368
# Epoch 67/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0298 - val_loss: 0.0360
# Epoch 68/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0293 - val_loss: 0.0351
# Epoch 69/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0288 - val_loss: 0.0341
# Epoch 70/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0283 - val_loss: 0.0338
# Epoch 71/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0278 - val_loss: 0.0329
# Epoch 72/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0272 - val_loss: 0.0322
# Epoch 73/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0266 - val_loss: 0.0317
# Epoch 74/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0261 - val_loss: 0.0309
# Epoch 75/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0256 - val_loss: 0.0306
# Epoch 76/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0251 - val_loss: 0.0300
# Epoch 77/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0247 - val_loss: 0.0297
# Epoch 78/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0242 - val_loss: 0.0292
# Epoch 79/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0238 - val_loss: 0.0287
# Epoch 80/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0235 - val_loss: 0.0285
# Epoch 81/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0230 - val_loss: 0.0280
# Epoch 82/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0225 - val_loss: 0.0278
# Epoch 83/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0221 - val_loss: 0.0272
# Epoch 84/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0216 - val_loss: 0.0270
# Epoch 85/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0212 - val_loss: 0.0265
# Epoch 86/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0207 - val_loss: 0.0261
# Epoch 87/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0203 - val_loss: 0.0256
# Epoch 88/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0200 - val_loss: 0.0253
# Epoch 89/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0195 - val_loss: 0.0248
# Epoch 90/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0192 - val_loss: 0.0245
# Epoch 91/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0188 - val_loss: 0.0241
# Epoch 92/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0185 - val_loss: 0.0237
# Epoch 93/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0181 - val_loss: 0.0233
# Epoch 94/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0179 - val_loss: 0.0229
# Epoch 95/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0174 - val_loss: 0.0226
# Epoch 96/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0171 - val_loss: 0.0223
# Epoch 97/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0168 - val_loss: 0.0221
# Epoch 98/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0165 - val_loss: 0.0218
# Epoch 99/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0162 - val_loss: 0.0216
# Epoch 100/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0159 - val_loss: 0.0213
# Epoch 101/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0156 - val_loss: 0.0211
# Epoch 102/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0153 - val_loss: 0.0209
# Epoch 103/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0150 - val_loss: 0.0207
# Epoch 104/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0148 - val_loss: 0.0204
# Epoch 105/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0146 - val_loss: 0.0202
# Epoch 106/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0143 - val_loss: 0.0199
# Epoch 107/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0140 - val_loss: 0.0194
# Epoch 108/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0138 - val_loss: 0.0192
# Epoch 109/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0136 - val_loss: 0.0189
# Epoch 110/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0134 - val_loss: 0.0187
# Epoch 111/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0132 - val_loss: 0.0185
# Epoch 112/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0131 - val_loss: 0.0181
# Epoch 113/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0129 - val_loss: 0.0178
# Epoch 114/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0128 - val_loss: 0.0176
# Epoch 115/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0126 - val_loss: 0.0173
# Epoch 116/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0124 - val_loss: 0.0170
# Epoch 117/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0121 - val_loss: 0.0168
# Epoch 118/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0121 - val_loss: 0.0166
# Epoch 119/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - val_loss: 0.0163
# Epoch 120/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0118 - val_loss: 0.0162
# Epoch 121/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0116 - val_loss: 0.0159
# Epoch 122/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0114 - val_loss: 0.0157
# Epoch 123/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0112 - val_loss: 0.0155
# Epoch 124/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0111 - val_loss: 0.0153
# Epoch 125/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0109 - val_loss: 0.0150
# Epoch 126/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0107 - val_loss: 0.0148
# Epoch 127/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0105 - val_loss: 0.0147
# Epoch 128/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0104 - val_loss: 0.0145
# Epoch 129/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0103 - val_loss: 0.0142
# Epoch 130/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0100 - val_loss: 0.0140
# Epoch 131/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0099 - val_loss: 0.0139
# Epoch 132/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0098 - val_loss: 0.0137
# Epoch 133/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0096 - val_loss: 0.0136
# Epoch 134/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0096 - val_loss: 0.0133
# Epoch 135/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0094 - val_loss: 0.0132
# Epoch 136/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0094 - val_loss: 0.0131
# Epoch 137/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0093 - val_loss: 0.0130
# Epoch 138/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0092 - val_loss: 0.0129
# Epoch 139/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0091 - val_loss: 0.0128
# Epoch 140/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0090 - val_loss: 0.0128
# Epoch 141/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0090 - val_loss: 0.0126
# Epoch 142/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0088 - val_loss: 0.0125
# Epoch 143/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0088 - val_loss: 0.0124
# Epoch 144/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0088 - val_loss: 0.0123
# Epoch 145/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0088 - val_loss: 0.0125
# Epoch 146/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0087 - val_loss: 0.0124
# Epoch 147/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0086 - val_loss: 0.0121
# Epoch 148/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0085 - val_loss: 0.0120
# Epoch 149/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084 - val_loss: 0.0118
# Epoch 150/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0083 - val_loss: 0.0117
# Epoch 151/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0083 - val_loss: 0.0116
# Epoch 152/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0083 - val_loss: 0.0116
# Epoch 153/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0082 - val_loss: 0.0114
# Epoch 154/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0081 - val_loss: 0.0114
# Epoch 155/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0080 - val_loss: 0.0112
# Epoch 156/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0080 - val_loss: 0.0113
# Epoch 157/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0079 - val_loss: 0.0112
# Epoch 158/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0080 - val_loss: 0.0114
# Epoch 159/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0079 - val_loss: 0.0113
# Epoch 160/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0078 - val_loss: 0.0112
# Epoch 161/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0078 - val_loss: 0.0110
# Epoch 162/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0077 - val_loss: 0.0109
# Epoch 163/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0076 - val_loss: 0.0109
# Epoch 164/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0075 - val_loss: 0.0107
# Epoch 165/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0074 - val_loss: 0.0105
# Epoch 166/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0074 - val_loss: 0.0105
# Epoch 167/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0073 - val_loss: 0.0105
# Epoch 168/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0074 - val_loss: 0.0106
# Epoch 169/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0074 - val_loss: 0.0105
# Epoch 170/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0073 - val_loss: 0.0103
# Epoch 171/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0071 - val_loss: 0.0103
# Epoch 172/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0071 - val_loss: 0.0106
# Epoch 173/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - val_loss: 0.0105
# Epoch 174/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - val_loss: 0.0106
# Epoch 175/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0071 - val_loss: 0.0105
# Epoch 176/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - val_loss: 0.0109
# Epoch 177/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0072 - val_loss: 0.0108
# Epoch 178/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0073 - val_loss: 0.0110
# Epoch 179/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0072 - val_loss: 0.0107
# Epoch 180/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - val_loss: 0.0102
# Epoch 181/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - val_loss: 0.0105
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 20.3982 - val_loss: 16.1980
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.6138 - val_loss: 14.3005
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14.1846 - val_loss: 13.2369
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.5863 - val_loss: 11.6756
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.4970 - val_loss: 9.5955
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.9747 - val_loss: 7.0527
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2193 - val_loss: 4.3565
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8593 - val_loss: 2.2806
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4949 - val_loss: 1.3444
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0066 - val_loss: 1.0311
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8244 - val_loss: 0.8772
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7079 - val_loss: 0.7684
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6034 - val_loss: 0.6678
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5146 - val_loss: 0.5794
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4400 - val_loss: 0.5020
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3740 - val_loss: 0.4402
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3155 - val_loss: 0.3853
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2676 - val_loss: 0.3359
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2307 - val_loss: 0.2941
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2018 - val_loss: 0.2607
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1775 - val_loss: 0.2346
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1573 - val_loss: 0.2128
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1406 - val_loss: 0.1937
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1275 - val_loss: 0.1777
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1165 - val_loss: 0.1642
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1075 - val_loss: 0.1527
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0997 - val_loss: 0.1418
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0929 - val_loss: 0.1331
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0871 - val_loss: 0.1256
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0817 - val_loss: 0.1194
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0771 - val_loss: 0.1144
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0731 - val_loss: 0.1101
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0696 - val_loss: 0.1060
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0661 - val_loss: 0.1021
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0630 - val_loss: 0.0985
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0600 - val_loss: 0.0957
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0574 - val_loss: 0.0921
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0550 - val_loss: 0.0889
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0529 - val_loss: 0.0859
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0510 - val_loss: 0.0828
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0493 - val_loss: 0.0799
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0476 - val_loss: 0.0770
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0460 - val_loss: 0.0744
# Epoch 44/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0445 - val_loss: 0.0719
# Epoch 45/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0432 - val_loss: 0.0697
# Epoch 46/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0420 - val_loss: 0.0676
# Epoch 47/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0407 - val_loss: 0.0653
# Epoch 48/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0395 - val_loss: 0.0633
# Epoch 49/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0382 - val_loss: 0.0615
# Epoch 50/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0371 - val_loss: 0.0596
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 21.2242 - val_loss: 16.1362
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.0443 - val_loss: 15.2336
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.9487 - val_loss: 14.4196
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14.6201 - val_loss: 13.1058
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.6301 - val_loss: 11.0781
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.6765 - val_loss: 8.1667
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3416 - val_loss: 5.3690
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7626 - val_loss: 3.2476
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2107 - val_loss: 1.9932
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4006 - val_loss: 1.3620
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9958 - val_loss: 1.0147
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7568 - val_loss: 0.7911
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5828 - val_loss: 0.6215
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4554 - val_loss: 0.5025
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3630 - val_loss: 0.4020
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2933 - val_loss: 0.3289
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2408 - val_loss: 0.2791
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2026 - val_loss: 0.2398
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1741 - val_loss: 0.2093
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1522 - val_loss: 0.1855
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1349 - val_loss: 0.1656
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1203 - val_loss: 0.1484
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1081 - val_loss: 0.1345
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0978 - val_loss: 0.1223
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0886 - val_loss: 0.1121
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0804 - val_loss: 0.1036
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0730 - val_loss: 0.0953
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0671 - val_loss: 0.0880
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0617 - val_loss: 0.0812
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0568 - val_loss: 0.0750
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0525 - val_loss: 0.0694
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0485 - val_loss: 0.0645
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0448 - val_loss: 0.0599
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0415 - val_loss: 0.0566
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0389 - val_loss: 0.0532
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0363 - val_loss: 0.0503
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0341 - val_loss: 0.0477
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0320 - val_loss: 0.0456
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0301 - val_loss: 0.0436
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0283 - val_loss: 0.0420
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0267 - val_loss: 0.0404
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0254 - val_loss: 0.0389
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0242 - val_loss: 0.0376
# Epoch 44/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0230 - val_loss: 0.0362
# Epoch 45/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0219 - val_loss: 0.0351
# Epoch 46/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0209 - val_loss: 0.0338
# Epoch 47/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0200 - val_loss: 0.0327
# Epoch 48/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0192 - val_loss: 0.0317
# Epoch 49/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0184 - val_loss: 0.0308
# Epoch 50/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0177 - val_loss: 0.0299
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 21.7168 - val_loss: 17.2419
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 16.7645 - val_loss: 14.9900
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.4837 - val_loss: 13.3931
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.0255 - val_loss: 10.8121
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.7122 - val_loss: 7.3400
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0954 - val_loss: 3.9077
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3597 - val_loss: 1.9092
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1549 - val_loss: 1.2022
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8044 - val_loss: 0.9616
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6650 - val_loss: 0.8241
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5742 - val_loss: 0.7226
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5065 - val_loss: 0.6373
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4536 - val_loss: 0.5758
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4115 - val_loss: 0.5211
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3766 - val_loss: 0.4797
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3472 - val_loss: 0.4464
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3214 - val_loss: 0.4194
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2980 - val_loss: 0.3895
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2733 - val_loss: 0.3636
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2519 - val_loss: 0.3371
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2301 - val_loss: 0.3105
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2114 - val_loss: 0.2858
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1951 - val_loss: 0.2654
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1800 - val_loss: 0.2468
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1667 - val_loss: 0.2301
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1540 - val_loss: 0.2140
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1428 - val_loss: 0.2003
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1324 - val_loss: 0.1867
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1226 - val_loss: 0.1763
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1137 - val_loss: 0.1649
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1056 - val_loss: 0.1563
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0981 - val_loss: 0.1469
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0917 - val_loss: 0.1396
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0856 - val_loss: 0.1320
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0804 - val_loss: 0.1241
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0751 - val_loss: 0.1174
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0705 - val_loss: 0.1120
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0663 - val_loss: 0.1069
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0624 - val_loss: 0.1010
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0586 - val_loss: 0.0953
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0550 - val_loss: 0.0907
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0522 - val_loss: 0.0854
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - val_loss: 0.0822
# Epoch 44/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0467 - val_loss: 0.0782
# Epoch 45/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0441 - val_loss: 0.0756
# Epoch 46/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0418 - val_loss: 0.0734
# Epoch 47/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0396 - val_loss: 0.0701
# Epoch 48/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0373 - val_loss: 0.0679
# Epoch 49/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0358 - val_loss: 0.0658
# Epoch 50/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0342 - val_loss: 0.0635
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 21.1065 - val_loss: 17.4464
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.9928 - val_loss: 15.6119
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14.5410 - val_loss: 14.2296
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.9190 - val_loss: 12.3459
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.6493 - val_loss: 9.7610
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7215 - val_loss: 6.6860
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6377 - val_loss: 3.8375
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4314 - val_loss: 2.2008
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4810 - val_loss: 1.6701
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1752 - val_loss: 1.4699
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0246 - val_loss: 1.3002
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8996 - val_loss: 1.1330
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7944 - val_loss: 0.9858
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6934 - val_loss: 0.8397
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5985 - val_loss: 0.7000
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5111 - val_loss: 0.5739
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4333 - val_loss: 0.4751
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3694 - val_loss: 0.3969
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3203 - val_loss: 0.3503
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2848 - val_loss: 0.3177
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2559 - val_loss: 0.2869
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2301 - val_loss: 0.2600
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2084 - val_loss: 0.2369
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1898 - val_loss: 0.2182
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1733 - val_loss: 0.2017
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1589 - val_loss: 0.1876
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1458 - val_loss: 0.1753
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1344 - val_loss: 0.1634
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1235 - val_loss: 0.1528
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1138 - val_loss: 0.1439
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1051 - val_loss: 0.1353
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0967 - val_loss: 0.1273
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0887 - val_loss: 0.1193
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0814 - val_loss: 0.1116
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0747 - val_loss: 0.1047
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0688 - val_loss: 0.0982
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0636 - val_loss: 0.0924
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0590 - val_loss: 0.0870
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0549 - val_loss: 0.0817
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0509 - val_loss: 0.0766
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0471 - val_loss: 0.0714
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0438 - val_loss: 0.0671
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0409 - val_loss: 0.0633
# Epoch 44/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - val_loss: 0.0598
# Epoch 45/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0362 - val_loss: 0.0567
# Epoch 46/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0342 - val_loss: 0.0539
# Epoch 47/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0324 - val_loss: 0.0515
# Epoch 48/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0308 - val_loss: 0.0492
# Epoch 49/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0293 - val_loss: 0.0472
# Epoch 50/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0280 - val_loss: 0.0453
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 25.8179 - val_loss: 18.9724
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.0314 - val_loss: 15.2691
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.8283 - val_loss: 14.0790
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.2687 - val_loss: 12.5066
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.1547 - val_loss: 10.1871
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.0342 - val_loss: 6.8708
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4367 - val_loss: 3.9303
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4932 - val_loss: 2.0081
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8175 - val_loss: 1.2278
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1606 - val_loss: 0.9819
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9018 - val_loss: 0.8442
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7528 - val_loss: 0.7437
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6512 - val_loss: 0.6650
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5703 - val_loss: 0.6006
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5048 - val_loss: 0.5444
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4473 - val_loss: 0.4917
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3957 - val_loss: 0.4449
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3533 - val_loss: 0.4045
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3167 - val_loss: 0.3687
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2851 - val_loss: 0.3339
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2561 - val_loss: 0.3006
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2301 - val_loss: 0.2714
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2078 - val_loss: 0.2466
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1882 - val_loss: 0.2251
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1711 - val_loss: 0.2064
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1564 - val_loss: 0.1892
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1429 - val_loss: 0.1737
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1306 - val_loss: 0.1604
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1189 - val_loss: 0.1474
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1085 - val_loss: 0.1363
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0991 - val_loss: 0.1263
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0907 - val_loss: 0.1163
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0827 - val_loss: 0.1079
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0759 - val_loss: 0.1003
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0704 - val_loss: 0.0934
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0653 - val_loss: 0.0873
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0606 - val_loss: 0.0824
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0565 - val_loss: 0.0778
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0530 - val_loss: 0.0736
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0498 - val_loss: 0.0697
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0471 - val_loss: 0.0660
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0444 - val_loss: 0.0630
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0420 - val_loss: 0.0600
# Epoch 44/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0396 - val_loss: 0.0574
# Epoch 45/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0376 - val_loss: 0.0555
# Epoch 46/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0358 - val_loss: 0.0534
# Epoch 47/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0341 - val_loss: 0.0515
# Epoch 48/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0326 - val_loss: 0.0497
# Epoch 49/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0313 - val_loss: 0.0485
# Epoch 50/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0300 - val_loss: 0.0472
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 21.5670 - val_loss: 16.7449
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.9708 - val_loss: 15.4926
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14.4977 - val_loss: 14.2341
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.9751 - val_loss: 12.4561
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.7632 - val_loss: 9.5897
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7076 - val_loss: 6.2013
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4594 - val_loss: 3.3602
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2047 - val_loss: 1.8442
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2338 - val_loss: 1.2560
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9122 - val_loss: 1.0101
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7639 - val_loss: 0.8665
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6615 - val_loss: 0.7559
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5785 - val_loss: 0.6676
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5083 - val_loss: 0.6064
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4544 - val_loss: 0.5562
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4113 - val_loss: 0.5138
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3749 - val_loss: 0.4722
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3424 - val_loss: 0.4315
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3122 - val_loss: 0.3950
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2841 - val_loss: 0.3618
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2575 - val_loss: 0.3283
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2317 - val_loss: 0.2991
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2073 - val_loss: 0.2704
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1856 - val_loss: 0.2408
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1646 - val_loss: 0.2136
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1460 - val_loss: 0.1901
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1301 - val_loss: 0.1714
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1171 - val_loss: 0.1563
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1064 - val_loss: 0.1442
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0971 - val_loss: 0.1354
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0895 - val_loss: 0.1266
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0828 - val_loss: 0.1179
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0770 - val_loss: 0.1106
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0722 - val_loss: 0.1036
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0677 - val_loss: 0.0971
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0636 - val_loss: 0.0922
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0602 - val_loss: 0.0862
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0569 - val_loss: 0.0820
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0539 - val_loss: 0.0775
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0510 - val_loss: 0.0737
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - val_loss: 0.0705
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0462 - val_loss: 0.0666
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0439 - val_loss: 0.0637
# Epoch 44/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0416 - val_loss: 0.0608
# Epoch 45/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0396 - val_loss: 0.0579
# Epoch 46/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0377 - val_loss: 0.0554
# Epoch 47/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0360 - val_loss: 0.0531
# Epoch 48/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0346 - val_loss: 0.0505
# Epoch 49/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0332 - val_loss: 0.0484
# Epoch 50/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0321 - val_loss: 0.0465
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 22.5142 - val_loss: 16.1535
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.0801 - val_loss: 14.5493
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.5504 - val_loss: 13.3726
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.8824 - val_loss: 11.6841
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.5117 - val_loss: 9.1995
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.2565 - val_loss: 6.0845
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8163 - val_loss: 3.1376
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3354 - val_loss: 1.4951
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2243 - val_loss: 0.9129
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8106 - val_loss: 0.6796
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6133 - val_loss: 0.5404
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4903 - val_loss: 0.4541
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4086 - val_loss: 0.3991
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3516 - val_loss: 0.3630
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3089 - val_loss: 0.3339
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2747 - val_loss: 0.3067
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2447 - val_loss: 0.2840
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2180 - val_loss: 0.2597
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1951 - val_loss: 0.2427
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1755 - val_loss: 0.2250
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1591 - val_loss: 0.2077
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1452 - val_loss: 0.1921
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1322 - val_loss: 0.1776
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1206 - val_loss: 0.1625
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1103 - val_loss: 0.1501
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1001 - val_loss: 0.1376
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0909 - val_loss: 0.1270
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0828 - val_loss: 0.1167
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0757 - val_loss: 0.1060
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0697 - val_loss: 0.0972
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0643 - val_loss: 0.0898
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0596 - val_loss: 0.0830
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0556 - val_loss: 0.0768
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0518 - val_loss: 0.0712
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0486 - val_loss: 0.0664
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0457 - val_loss: 0.0614
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0430 - val_loss: 0.0572
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0404 - val_loss: 0.0538
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0381 - val_loss: 0.0507
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0360 - val_loss: 0.0479
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0341 - val_loss: 0.0453
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0324 - val_loss: 0.0427
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0307 - val_loss: 0.0404
# Epoch 44/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0291 - val_loss: 0.0383
# Epoch 45/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0277 - val_loss: 0.0367
# Epoch 46/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0264 - val_loss: 0.0351
# Epoch 47/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0253 - val_loss: 0.0336
# Epoch 48/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0242 - val_loss: 0.0325
# Epoch 49/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0233 - val_loss: 0.0311
# Epoch 50/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0224 - val_loss: 0.0297
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 23.0890 - val_loss: 17.5656
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.6505 - val_loss: 14.6745
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.7190 - val_loss: 13.3237
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.9291 - val_loss: 11.5207
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.5188 - val_loss: 9.1426
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.5473 - val_loss: 6.3297
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3646 - val_loss: 3.6708
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8060 - val_loss: 1.9462
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5276 - val_loss: 1.3550
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0906 - val_loss: 1.1180
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8926 - val_loss: 0.9538
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7570 - val_loss: 0.8144
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6497 - val_loss: 0.7034
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5614 - val_loss: 0.6177
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4882 - val_loss: 0.5444
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4279 - val_loss: 0.4850
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3765 - val_loss: 0.4359
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3333 - val_loss: 0.3910
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2978 - val_loss: 0.3542
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2676 - val_loss: 0.3208
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2393 - val_loss: 0.2901
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2116 - val_loss: 0.2626
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1885 - val_loss: 0.2415
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1685 - val_loss: 0.2212
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1504 - val_loss: 0.2018
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1358 - val_loss: 0.1843
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1235 - val_loss: 0.1688
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1132 - val_loss: 0.1549
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1043 - val_loss: 0.1413
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0961 - val_loss: 0.1309
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0890 - val_loss: 0.1224
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0829 - val_loss: 0.1149
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0775 - val_loss: 0.1089
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0730 - val_loss: 0.1035
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0692 - val_loss: 0.0993
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0660 - val_loss: 0.0957
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0632 - val_loss: 0.0919
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0607 - val_loss: 0.0890
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0581 - val_loss: 0.0863
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0559 - val_loss: 0.0837
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0538 - val_loss: 0.0814
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0519 - val_loss: 0.0790
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0501 - val_loss: 0.0777
# Epoch 44/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0487 - val_loss: 0.0762
# Epoch 45/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0471 - val_loss: 0.0747
# Epoch 46/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0457 - val_loss: 0.0730
# Epoch 47/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0442 - val_loss: 0.0716
# Epoch 48/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0425 - val_loss: 0.0690
# Epoch 49/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0406 - val_loss: 0.0676
# Epoch 50/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0390 - val_loss: 0.0664
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 22.4285 - val_loss: 15.9843
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.0333 - val_loss: 14.3463
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14.2528 - val_loss: 12.6904
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.2215 - val_loss: 10.3871
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4154 - val_loss: 7.2275
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1203 - val_loss: 4.2148
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3224 - val_loss: 2.1158
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7076 - val_loss: 1.1495
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0610 - val_loss: 0.8282
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8158 - val_loss: 0.6903
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6756 - val_loss: 0.5960
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5708 - val_loss: 0.5241
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4857 - val_loss: 0.4571
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4209 - val_loss: 0.4057
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3720 - val_loss: 0.3606
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3302 - val_loss: 0.3213
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2951 - val_loss: 0.2925
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2666 - val_loss: 0.2678
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2407 - val_loss: 0.2436
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2178 - val_loss: 0.2234
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1989 - val_loss: 0.2054
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1834 - val_loss: 0.1901
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1690 - val_loss: 0.1761
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1559 - val_loss: 0.1638
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1442 - val_loss: 0.1518
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1324 - val_loss: 0.1402
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1212 - val_loss: 0.1300
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1121 - val_loss: 0.1213
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1036 - val_loss: 0.1130
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0956 - val_loss: 0.1062
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0880 - val_loss: 0.1002
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0812 - val_loss: 0.0948
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0753 - val_loss: 0.0903
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0701 - val_loss: 0.0864
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0653 - val_loss: 0.0828
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0611 - val_loss: 0.0792
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0575 - val_loss: 0.0757
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0542 - val_loss: 0.0727
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0513 - val_loss: 0.0699
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0486 - val_loss: 0.0671
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0462 - val_loss: 0.0642
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0439 - val_loss: 0.0612
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0419 - val_loss: 0.0586
# Epoch 44/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0400 - val_loss: 0.0564
# Epoch 45/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0383 - val_loss: 0.0542
# Epoch 46/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0366 - val_loss: 0.0522
# Epoch 47/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0351 - val_loss: 0.0503
# Epoch 48/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0338 - val_loss: 0.0488
# Epoch 49/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0326 - val_loss: 0.0472
# Epoch 50/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0314 - val_loss: 0.0458
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 19.9067 - val_loss: 16.7452
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.1109 - val_loss: 15.3690
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14.8939 - val_loss: 14.3190
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.4179 - val_loss: 12.7981
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.3041 - val_loss: 10.4628
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.3398 - val_loss: 7.3953
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9603 - val_loss: 4.2606
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3450 - val_loss: 2.0896
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2363 - val_loss: 1.3320
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9405 - val_loss: 1.0966
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8206 - val_loss: 0.9799
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7367 - val_loss: 0.8948
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6642 - val_loss: 0.8181
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5967 - val_loss: 0.7415
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5352 - val_loss: 0.6725
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4771 - val_loss: 0.6062
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4239 - val_loss: 0.5449
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3771 - val_loss: 0.4906
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3369 - val_loss: 0.4432
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3012 - val_loss: 0.4002
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2709 - val_loss: 0.3644
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2439 - val_loss: 0.3297
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2186 - val_loss: 0.2977
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1966 - val_loss: 0.2680
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1763 - val_loss: 0.2417
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1587 - val_loss: 0.2187
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1430 - val_loss: 0.1983
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1286 - val_loss: 0.1799
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1158 - val_loss: 0.1639
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1044 - val_loss: 0.1495
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0944 - val_loss: 0.1372
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0860 - val_loss: 0.1243
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0788 - val_loss: 0.1145
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0731 - val_loss: 0.1065
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0682 - val_loss: 0.0998
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0640 - val_loss: 0.0935
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0600 - val_loss: 0.0877
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0564 - val_loss: 0.0822
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0535 - val_loss: 0.0778
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0507 - val_loss: 0.0740
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0477 - val_loss: 0.0702
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0449 - val_loss: 0.0667
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0420 - val_loss: 0.0636
# Epoch 44/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0397 - val_loss: 0.0616
# Epoch 45/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0378 - val_loss: 0.0599
# Epoch 46/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0362 - val_loss: 0.0583
# Epoch 47/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0349 - val_loss: 0.0572
# Epoch 48/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0336 - val_loss: 0.0559
# Epoch 49/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0327 - val_loss: 0.0548
# Epoch 50/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0317 - val_loss: 0.0541
# /home/capybara/Desktop/matura_project_python/github/matura/FNN1_1.py:246: RuntimeWarning: divide by zero encountered in divide
#   relativeError = np.where(np.array(y_test) != 0, deviation.flatten() / np.abs(np.array(y_test)), deviation.flatten())

# %%
pad_value = 15
x_test = np.pad(x_test, ((0, 0), (1, 0)), 'constant', constant_values=pad_value)
out_x_test = np.pad(out_x_test, ((0, 0), (1, 0)), 'constant', constant_values=pad_value)
long_x_test = np.pad(long_x_test, ((0, 0), (1, 0)), 'constant', constant_values=pad_value)

x_test_dataset = tf.data.Dataset.from_tensor_slices(x_test).batch(batch_size)
out_x_test_dataset = tf.data.Dataset.from_tensor_slices(out_x_test).batch(batch_size)
long_x_test_dataset = tf.data.Dataset.from_tensor_slices(long_x_test).batch(batch_size)

# %%
#debuggng: 
# Add a custom callback to track the best epoch
class BestEpochTracker(tf.keras.callbacks.Callback):
    def __init__(self):
        self.best_val_loss = float('inf')
        self.best_epoch = 0
        
    def on_epoch_end(self, epoch, logs=None):
        val_loss = logs.get('val_loss')
        if val_loss is not None and val_loss < self.best_val_loss:
            self.best_val_loss = val_loss
            self.best_epoch = epoch + 1
            print(f"New best validation loss: {val_loss:.4f} at epoch {self.best_epoch}")

best_tracker = BestEpochTracker()

# %%
n_bootstrap = 5
count = 0
bootstrap_predsInRange = []
bootstrap_predsOutRange = []
bootstrap_predsLongRange = []

for i in range(n_bootstrap):
    early_stopping = tf.keras.callbacks.EarlyStopping(
        patience=20,
        min_delta=0.001,
        restore_best_weights=True,
        monitor='val_loss',
        mode="min", 
        verbose=1
    )
    tf.random.set_seed(i * 12345)  # Different seed each iteration
    best_model, lr_schedule = build_best_model(best_hps, num_epochs_best_model)
    best_model.compile(
        optimizer=tf.keras.optimizers.AdamW(
            learning_rate=lr_schedule,
            weight_decay = 4e-3,
            beta_1=0.85,  
            beta_2=0.999,  # Primary recommendation: lower this
            clipnorm=1.0
        ),
        loss='mse',
        metrics=['mse']
    )
    best_model.fit(
        train_dataset, # Pass the TensorFlow Dataset
        validation_data=val_dataset, # Pass the TensorFlow Dataset
        epochs=num_epochs_best_model,
        callbacks=[early_stopping, best_tracker],
        verbose = 1
    )
    
    bootstrap_predsInRange.append(best_model.predict(x_test_dataset))
    bootstrap_predsOutRange.append(best_model.predict(out_x_test_dataset))
    bootstrap_predsLongRange.append(best_model.predict(long_x_test_dataset))
    print(f"Done: {count}")
    count += 1

bootstrap_predsInRange = np.array(bootstrap_predsInRange)
bootstrap_predsOutRange = np.array(bootstrap_predsOutRange)
bootstrap_predsLongRange = np.array(bootstrap_predsLongRange)
# Out:
# Epoch 1/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - loss: 26.3515 - mse: 26.3515New best validation loss: 21.8824 at epoch 1
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 51s 342ms/step - loss: 25.6598 - mse: 25.6598 - val_loss: 21.8824 - val_mse: 21.8824
# Epoch 2/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 22.7825 - mse: 22.7825New best validation loss: 17.8525 at epoch 2
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 21.7082 - mse: 21.7082 - val_loss: 17.8525 - val_mse: 17.8525
# Epoch 3/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 19.3167 - mse: 19.3167New best validation loss: 17.0824 at epoch 3
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 19.2665 - mse: 19.2665 - val_loss: 17.0824 - val_mse: 17.0824
# Epoch 4/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 18.3659 - mse: 18.3659 - val_loss: 18.4789 - val_mse: 18.4789
# Epoch 5/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 17.7108 - mse: 17.7108New best validation loss: 15.9924 at epoch 5
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 17.5088 - mse: 17.5088 - val_loss: 15.9924 - val_mse: 15.9924
# Epoch 6/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 16.4450 - mse: 16.4450New best validation loss: 13.9678 at epoch 6
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 16.8721 - mse: 16.8721 - val_loss: 13.9678 - val_mse: 13.9678
# Epoch 7/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 17.0571 - mse: 17.0571 - val_loss: 17.6588 - val_mse: 17.6588
# Epoch 8/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 17.1177 - mse: 17.1177New best validation loss: 12.9147 at epoch 8
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 16.7808 - mse: 16.7808 - val_loss: 12.9147 - val_mse: 12.9147
# Epoch 9/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 11.7998 - mse: 11.7998 - val_loss: 16.7891 - val_mse: 16.7891
# Epoch 10/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 19.3987 - mse: 19.3987 - val_loss: 14.1607 - val_mse: 14.1607
# Epoch 11/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 12.7814 - mse: 12.7814New best validation loss: 8.9090 at epoch 11
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 11.4610 - mse: 11.4610 - val_loss: 8.9090 - val_mse: 8.9090
# Epoch 12/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.1525 - mse: 6.1525 - val_loss: 9.2922 - val_mse: 9.2922
# Epoch 13/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 7.7069 - mse: 7.7069New best validation loss: 4.0687 at epoch 13
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.6532 - mse: 7.6532 - val_loss: 4.0687 - val_mse: 4.0687
# Epoch 14/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.2255 - mse: 6.2255 - val_loss: 9.7330 - val_mse: 9.7330
# Epoch 15/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.1586 - mse: 6.1586 - val_loss: 8.5409 - val_mse: 8.5409
# Epoch 16/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.8896 - mse: 4.8896 - val_loss: 16.4442 - val_mse: 16.4442
# Epoch 17/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.6335 - mse: 5.6335 - val_loss: 9.0626 - val_mse: 9.0626
# Epoch 18/200
# 57/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.4654 - mse: 3.4654New best validation loss: 2.4876 at epoch 18
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.6130 - mse: 4.6130 - val_loss: 2.4876 - val_mse: 2.4876
# Epoch 19/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.4872 - mse: 4.4872 - val_loss: 10.4024 - val_mse: 10.4024
# Epoch 20/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.5787 - mse: 5.5787New best validation loss: 2.4842 at epoch 20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.8471 - mse: 3.8471 - val_loss: 2.4842 - val_mse: 2.4842
# Epoch 21/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.0473 - mse: 8.0473 - val_loss: 8.4003 - val_mse: 8.4003
# Epoch 22/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.6079 - mse: 8.6079 - val_loss: 6.9186 - val_mse: 6.9186
# Epoch 23/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.5279 - mse: 4.5279 - val_loss: 3.1159 - val_mse: 3.1159
# Epoch 24/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.0344 - mse: 6.0344 - val_loss: 3.5868 - val_mse: 3.5868
# Epoch 25/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.2480 - mse: 8.2480 - val_loss: 3.7006 - val_mse: 3.7006
# Epoch 26/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.4412 - mse: 9.4412 - val_loss: 8.9530 - val_mse: 8.9530
# Epoch 27/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.6741 - mse: 6.6741 - val_loss: 3.7173 - val_mse: 3.7173
# Epoch 28/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.9551 - mse: 5.9551 - val_loss: 5.0790 - val_mse: 5.0790
# Epoch 29/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.9354 - mse: 4.9354 - val_loss: 7.1541 - val_mse: 7.1541
# Epoch 30/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.6230 - mse: 2.6230 - val_loss: 5.2457 - val_mse: 5.2457
# Epoch 31/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.3747 - mse: 2.3747New best validation loss: 1.8737 at epoch 31
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.6777 - mse: 2.6777 - val_loss: 1.8737 - val_mse: 1.8737
# Epoch 32/200
# 57/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.9630 - mse: 6.9630New best validation loss: 1.4666 at epoch 32
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.9083 - mse: 4.9083 - val_loss: 1.4666 - val_mse: 1.4666
# Epoch 33/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.1407 - mse: 1.1407New best validation loss: 1.1013 at epoch 33
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4352 - mse: 1.4352 - val_loss: 1.1013 - val_mse: 1.1013
# Epoch 34/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.7056 - mse: 0.7056New best validation loss: 0.3373 at epoch 34
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.1116 - mse: 1.1116 - val_loss: 0.3373 - val_mse: 0.3373
# Epoch 35/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.6354 - mse: 0.6354 - val_loss: 0.3970 - val_mse: 0.3970
# Epoch 36/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4761 - mse: 0.4761New best validation loss: 0.2910 at epoch 36
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5176 - mse: 0.5176 - val_loss: 0.2910 - val_mse: 0.2910
# Epoch 37/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.8432 - mse: 1.8432 - val_loss: 0.4632 - val_mse: 0.4632
# Epoch 38/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.3493 - mse: 0.3493 - val_loss: 0.3082 - val_mse: 0.3082
# Epoch 39/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.4791 - mse: 0.4791 - val_loss: 2.8451 - val_mse: 2.8451
# Epoch 40/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.7179 - mse: 0.7179New best validation loss: 0.2732 at epoch 40
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.6807 - mse: 0.6807 - val_loss: 0.2732 - val_mse: 0.2732
# Epoch 41/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.1764 - mse: 1.1764New best validation loss: 0.2637 at epoch 41
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.9454 - mse: 1.9454 - val_loss: 0.2637 - val_mse: 0.2637
# Epoch 42/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2454 - mse: 0.2454New best validation loss: 0.2273 at epoch 42
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2011 - mse: 0.2011 - val_loss: 0.2273 - val_mse: 0.2273
# Epoch 43/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5412 - mse: 0.5412 - val_loss: 0.2293 - val_mse: 0.2293
# Epoch 44/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.3823 - mse: 0.3823 - val_loss: 0.2841 - val_mse: 0.2841
# Epoch 45/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2663 - mse: 0.2663New best validation loss: 0.0674 at epoch 45
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2144 - mse: 0.2144 - val_loss: 0.0674 - val_mse: 0.0674
# Epoch 46/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.6798 - mse: 0.6798 - val_loss: 0.1695 - val_mse: 0.1695
# Epoch 47/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.6273 - mse: 0.6273 - val_loss: 0.2838 - val_mse: 0.2838
# Epoch 48/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2313 - mse: 0.2313 - val_loss: 0.2360 - val_mse: 0.2360
# Epoch 49/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3414 - mse: 0.3414 - val_loss: 0.1241 - val_mse: 0.1241
# Epoch 50/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1198 - mse: 0.1198 - val_loss: 0.3465 - val_mse: 0.3465
# Epoch 51/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.9023 - mse: 1.9023 - val_loss: 0.5395 - val_mse: 0.5395
# Epoch 52/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1503 - mse: 0.1503 - val_loss: 0.1459 - val_mse: 0.1459
# Epoch 53/200
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1417 - mse: 0.1417New best validation loss: 0.0441 at epoch 53
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1360 - mse: 0.1360 - val_loss: 0.0441 - val_mse: 0.0441
# Epoch 54/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.3763 - mse: 0.3763 - val_loss: 0.0515 - val_mse: 0.0515
# Epoch 55/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0750 - mse: 0.0750 - val_loss: 0.0981 - val_mse: 0.0981
# Epoch 56/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0912 - mse: 0.0912 - val_loss: 0.1817 - val_mse: 0.1817
# Epoch 57/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1046 - mse: 0.1046 - val_loss: 0.0832 - val_mse: 0.0832
# Epoch 58/200
# 57/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0917 - mse: 0.0917New best validation loss: 0.0220 at epoch 58
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0771 - mse: 0.0771 - val_loss: 0.0220 - val_mse: 0.0220
# Epoch 59/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0382 - mse: 0.0382 - val_loss: 0.0951 - val_mse: 0.0951
# Epoch 60/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0578 - mse: 0.0578 - val_loss: 0.0347 - val_mse: 0.0347
# Epoch 61/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0408 - mse: 0.0408 - val_loss: 0.0423 - val_mse: 0.0423
# Epoch 62/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0373 - mse: 0.0373 - val_loss: 0.0480 - val_mse: 0.0480
# Epoch 63/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0361 - mse: 0.0361 - val_loss: 0.0347 - val_mse: 0.0347
# Epoch 64/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1121 - mse: 0.1121 - val_loss: 0.1036 - val_mse: 0.1036
# Epoch 65/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0715 - mse: 0.0715 - val_loss: 0.0616 - val_mse: 0.0616
# Epoch 66/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0363 - mse: 0.0363 - val_loss: 0.0563 - val_mse: 0.0563
# Epoch 67/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0613 - mse: 0.0613 - val_loss: 0.1365 - val_mse: 0.1365
# Epoch 68/200
# 57/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0743 - mse: 0.0743New best validation loss: 0.0213 at epoch 68
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0472 - mse: 0.0472 - val_loss: 0.0213 - val_mse: 0.0213
# Epoch 69/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0281 - mse: 0.0281New best validation loss: 0.0210 at epoch 69
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0306 - mse: 0.0306 - val_loss: 0.0210 - val_mse: 0.0210
# Epoch 70/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0529 - mse: 0.0529 - val_loss: 0.0442 - val_mse: 0.0442
# Epoch 71/200
# 57/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0469 - mse: 0.0469New best validation loss: 0.0117 at epoch 71
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0296 - mse: 0.0296 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 72/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0261 - mse: 0.0261 - val_loss: 0.0643 - val_mse: 0.0643
# Epoch 73/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0410 - mse: 0.0410 - val_loss: 0.0256 - val_mse: 0.0256
# Epoch 74/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0374 - mse: 0.0374 - val_loss: 0.0410 - val_mse: 0.0410
# Epoch 75/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0178 - mse: 0.0178 - val_loss: 0.0217 - val_mse: 0.0217
# Epoch 76/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0238 - mse: 0.0238 - val_loss: 0.0217 - val_mse: 0.0217
# Epoch 77/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0261 - mse: 0.0261 - val_loss: 0.0215 - val_mse: 0.0215
# Epoch 78/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0140 - mse: 0.0140 - val_loss: 0.0180 - val_mse: 0.0180
# Epoch 79/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0332 - mse: 0.0332 - val_loss: 0.0204 - val_mse: 0.0204
# Epoch 80/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0164 - mse: 0.0164 - val_loss: 0.0237 - val_mse: 0.0237
# Epoch 81/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0193 - mse: 0.0193 - val_loss: 0.0441 - val_mse: 0.0441
# Epoch 82/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0168 - mse: 0.0168 - val_loss: 0.0183 - val_mse: 0.0183
# Epoch 83/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0153 - mse: 0.0153New best validation loss: 0.0109 at epoch 83
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0141 - mse: 0.0141 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 84/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0209 - mse: 0.0209 - val_loss: 0.0239 - val_mse: 0.0239
# Epoch 85/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0220 - mse: 0.0220 - val_loss: 0.0158 - val_mse: 0.0158
# Epoch 86/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0180 - mse: 0.0180 - val_loss: 0.0143 - val_mse: 0.0143
# Epoch 87/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.0129 - val_mse: 0.0129
# Epoch 88/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0185 - mse: 0.0185 - val_loss: 0.0187 - val_mse: 0.0187
# Epoch 89/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0203 - mse: 0.0203 - val_loss: 0.0271 - val_mse: 0.0271
# Epoch 90/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0291 - mse: 0.0291 - val_loss: 0.0350 - val_mse: 0.0350
# Epoch 91/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 91: early stopping
# Restoring model weights from the end of the best epoch: 71.
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 6s 91ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step
# Done: 0
# Epoch 1/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 38s 208ms/step - loss: 28.3697 - mse: 28.3697 - val_loss: 22.5718 - val_mse: 22.5718
# Epoch 2/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 23.8496 - mse: 23.8496 - val_loss: 20.6823 - val_mse: 20.6823
# Epoch 3/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 20.7582 - mse: 20.7582 - val_loss: 17.3147 - val_mse: 17.3147
# Epoch 4/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 17.8763 - mse: 17.8763 - val_loss: 17.5578 - val_mse: 17.5578
# Epoch 5/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 15.6938 - mse: 15.6938 - val_loss: 17.2946 - val_mse: 17.2946
# Epoch 6/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 15.3061 - mse: 15.3061 - val_loss: 14.9006 - val_mse: 14.9006
# Epoch 7/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 13.6034 - mse: 13.6034 - val_loss: 17.4458 - val_mse: 17.4458
# Epoch 8/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 17.5893 - mse: 17.5893 - val_loss: 15.1614 - val_mse: 15.1614
# Epoch 9/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 11.7062 - mse: 11.7062 - val_loss: 7.6092 - val_mse: 7.6092
# Epoch 10/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.0412 - mse: 8.0412 - val_loss: 8.7390 - val_mse: 8.7390
# Epoch 11/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.3851 - mse: 4.3851 - val_loss: 3.5709 - val_mse: 3.5709
# Epoch 12/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.6726 - mse: 5.6726 - val_loss: 2.6137 - val_mse: 2.6137
# Epoch 13/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.3483 - mse: 5.3483 - val_loss: 5.5122 - val_mse: 5.5122
# Epoch 14/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.9783 - mse: 5.9783 - val_loss: 3.2224 - val_mse: 3.2224
# Epoch 15/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.0000 - mse: 7.0000 - val_loss: 13.0395 - val_mse: 13.0395
# Epoch 16/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.5980 - mse: 5.5980 - val_loss: 2.6605 - val_mse: 2.6605
# Epoch 17/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.7340 - mse: 3.7340 - val_loss: 2.3447 - val_mse: 2.3447
# Epoch 18/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.4371 - mse: 3.4371 - val_loss: 7.6119 - val_mse: 7.6119
# Epoch 19/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.8341 - mse: 4.8341 - val_loss: 4.0981 - val_mse: 4.0981
# Epoch 20/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.6105 - mse: 3.6105 - val_loss: 2.1460 - val_mse: 2.1460
# Epoch 21/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 10.2147 - mse: 10.2147 - val_loss: 4.3402 - val_mse: 4.3402
# Epoch 22/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.0956 - mse: 7.0956 - val_loss: 2.1578 - val_mse: 2.1578
# Epoch 23/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.4404 - mse: 2.4404 - val_loss: 2.2746 - val_mse: 2.2746
# Epoch 24/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.7162 - mse: 7.7162 - val_loss: 16.5333 - val_mse: 16.5333
# Epoch 25/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.7072 - mse: 4.7072 - val_loss: 4.4402 - val_mse: 4.4402
# Epoch 26/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.6526 - mse: 5.6526 - val_loss: 2.1728 - val_mse: 2.1728
# Epoch 27/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.6346 - mse: 5.6346 - val_loss: 2.4505 - val_mse: 2.4505
# Epoch 28/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.5932 - mse: 6.5932 - val_loss: 1.3266 - val_mse: 1.3266
# Epoch 29/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.2196 - mse: 2.2196 - val_loss: 12.8675 - val_mse: 12.8675
# Epoch 30/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.1089 - mse: 3.1089 - val_loss: 2.0038 - val_mse: 2.0038
# Epoch 31/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.9547 - mse: 2.9547 - val_loss: 1.2794 - val_mse: 1.2794
# Epoch 32/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.0281 - mse: 1.0281 - val_loss: 2.6427 - val_mse: 2.6427
# Epoch 33/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.4828 - mse: 2.4828 - val_loss: 0.7031 - val_mse: 0.7031
# Epoch 34/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.1063 - mse: 1.1063 - val_loss: 0.5509 - val_mse: 0.5509
# Epoch 35/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5667 - mse: 0.5667 - val_loss: 1.9663 - val_mse: 1.9663
# Epoch 36/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.7236 - mse: 0.7236 - val_loss: 0.2932 - val_mse: 0.2932
# Epoch 37/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3836 - mse: 0.3836 - val_loss: 0.2735 - val_mse: 0.2735
# Epoch 38/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.4515 - mse: 0.4515 - val_loss: 0.3386 - val_mse: 0.3386
# Epoch 39/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.8518 - mse: 2.8518 - val_loss: 1.0934 - val_mse: 1.0934
# Epoch 40/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.2685 - mse: 1.2685 - val_loss: 0.4640 - val_mse: 0.4640
# Epoch 41/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5088 - mse: 0.5088 - val_loss: 0.5547 - val_mse: 0.5547
# Epoch 42/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3961 - mse: 0.3961 - val_loss: 0.3378 - val_mse: 0.3378
# Epoch 43/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.4300 - mse: 0.4300 - val_loss: 0.2496 - val_mse: 0.2496
# Epoch 44/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.6174 - mse: 0.6174 - val_loss: 0.8379 - val_mse: 0.8379
# Epoch 45/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.0537 - mse: 3.0537 - val_loss: 0.3136 - val_mse: 0.3136
# Epoch 46/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3607 - mse: 0.3607 - val_loss: 0.1735 - val_mse: 0.1735
# Epoch 47/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5030 - mse: 0.5030 - val_loss: 0.5073 - val_mse: 0.5073
# Epoch 48/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3952 - mse: 0.3952 - val_loss: 0.1826 - val_mse: 0.1826
# Epoch 49/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2706 - mse: 0.2706 - val_loss: 0.1604 - val_mse: 0.1604
# Epoch 50/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1805 - mse: 0.1805 - val_loss: 0.2664 - val_mse: 0.2664
# Epoch 51/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1283 - mse: 0.1283 - val_loss: 0.0860 - val_mse: 0.0860
# Epoch 52/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1132 - mse: 0.1132 - val_loss: 0.1960 - val_mse: 0.1960
# Epoch 53/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1098 - mse: 0.1098 - val_loss: 0.0964 - val_mse: 0.0964
# Epoch 54/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2523 - mse: 0.2523 - val_loss: 0.1035 - val_mse: 0.1035
# Epoch 55/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1160 - mse: 0.1160 - val_loss: 0.1430 - val_mse: 0.1430
# Epoch 56/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0781 - mse: 0.0781 - val_loss: 0.0868 - val_mse: 0.0868
# Epoch 57/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0771 - mse: 0.0771 - val_loss: 0.0504 - val_mse: 0.0504
# Epoch 58/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0745 - mse: 0.0745 - val_loss: 0.0512 - val_mse: 0.0512
# Epoch 59/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1853 - mse: 0.1853 - val_loss: 0.0833 - val_mse: 0.0833
# Epoch 60/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0855 - mse: 0.0855 - val_loss: 0.0910 - val_mse: 0.0910
# Epoch 61/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3665 - mse: 0.3665 - val_loss: 0.7685 - val_mse: 0.7685
# Epoch 62/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.8773 - mse: 0.8773 - val_loss: 0.1714 - val_mse: 0.1714
# Epoch 63/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3803 - mse: 0.3803 - val_loss: 0.2277 - val_mse: 0.2277
# Epoch 64/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3283 - mse: 0.3283 - val_loss: 0.2244 - val_mse: 0.2244
# Epoch 65/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3915 - mse: 0.3915 - val_loss: 0.2750 - val_mse: 0.2750
# Epoch 66/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0057 - mse: 1.0057 - val_loss: 0.2446 - val_mse: 0.2446
# Epoch 67/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.4573 - mse: 0.4573 - val_loss: 4.9501 - val_mse: 4.9501
# Epoch 68/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.7153 - mse: 0.7153 - val_loss: 0.0872 - val_mse: 0.0872
# Epoch 69/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1848 - mse: 0.1848 - val_loss: 2.5994 - val_mse: 2.5994
# Epoch 70/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1710 - mse: 0.1710 - val_loss: 0.0593 - val_mse: 0.0593
# Epoch 71/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0523 - mse: 0.0523 - val_loss: 0.0278 - val_mse: 0.0278
# Epoch 72/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1073 - mse: 0.1073 - val_loss: 0.1602 - val_mse: 0.1602
# Epoch 73/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1633 - mse: 0.1633 - val_loss: 0.0986 - val_mse: 0.0986
# Epoch 74/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1186 - mse: 0.1186 - val_loss: 0.0440 - val_mse: 0.0440
# Epoch 75/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0295 - mse: 0.0295 - val_loss: 0.0342 - val_mse: 0.0342
# Epoch 76/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0309 - mse: 0.0309 - val_loss: 0.0270 - val_mse: 0.0270
# Epoch 77/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0291 - mse: 0.0291 - val_loss: 0.0272 - val_mse: 0.0272
# Epoch 78/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0277 - mse: 0.0277 - val_loss: 0.0242 - val_mse: 0.0242
# Epoch 79/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0159 - mse: 0.0159 - val_loss: 0.0230 - val_mse: 0.0230
# Epoch 80/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0192 - mse: 0.0192 - val_loss: 0.0182 - val_mse: 0.0182
# Epoch 81/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0276 - mse: 0.0276 - val_loss: 0.0911 - val_mse: 0.0911
# Epoch 82/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0265 - mse: 0.0265 - val_loss: 0.0139 - val_mse: 0.0139
# Epoch 83/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0154 - val_mse: 0.0154
# Epoch 84/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0197 - mse: 0.0197 - val_loss: 0.0283 - val_mse: 0.0283
# Epoch 85/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0199 - mse: 0.0199 - val_loss: 0.0126 - val_mse: 0.0126
# Epoch 86/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0739 - val_mse: 0.0739
# Epoch 87/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0165 - val_mse: 0.0165
# Epoch 88/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0319 - val_mse: 0.0319
# Epoch 89/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0208 - mse: 0.0208 - val_loss: 0.0271 - val_mse: 0.0271
# Epoch 90/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0173 - mse: 0.0173 - val_loss: 0.0219 - val_mse: 0.0219
# Epoch 91/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0422 - val_mse: 0.0422
# Epoch 92/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0263 - mse: 0.0263 - val_loss: 0.0253 - val_mse: 0.0253
# Epoch 93/200
# 57/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0152 - mse: 0.0152New best validation loss: 0.0089 at epoch 93
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0089 - val_mse: 0.0089
# Epoch 94/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 95/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 96/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0147 - val_mse: 0.0147
# Epoch 97/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0281 - val_mse: 0.0281
# Epoch 98/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0120 - val_mse: 0.0120
# Epoch 99/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0075 - mse: 0.0075New best validation loss: 0.0083 at epoch 99
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0083 - val_mse: 0.0083
# Epoch 100/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 101/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 102/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0145 - val_mse: 0.0145
# Epoch 103/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0255 - mse: 0.0255 - val_loss: 0.0324 - val_mse: 0.0324
# Epoch 104/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0148 - mse: 0.0148 - val_loss: 0.0223 - val_mse: 0.0223
# Epoch 105/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0527 - mse: 0.0527 - val_loss: 0.0728 - val_mse: 0.0728
# Epoch 106/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0231 - mse: 0.0231 - val_loss: 0.1210 - val_mse: 0.1210
# Epoch 107/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0187 - val_mse: 0.0187
# Epoch 108/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0319 - mse: 0.0319 - val_loss: 0.0155 - val_mse: 0.0155
# Epoch 109/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0206 - val_mse: 0.0206
# Epoch 110/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0168 - val_mse: 0.0168
# Epoch 111/200
# 57/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0110 - mse: 0.0110New best validation loss: 0.0071 at epoch 111
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 112/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0047 - mse: 0.0047New best validation loss: 0.0067 at epoch 112
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 113/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 114/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0045 - mse: 0.0045New best validation loss: 0.0067 at epoch 114
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 115/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 116/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0125 - val_mse: 0.0125
# Epoch 117/200
# 57/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0054 - mse: 0.0054New best validation loss: 0.0062 at epoch 117
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 118/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0097 - val_mse: 0.0097
# Epoch 119/200
# 57/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0060 - mse: 0.0060New best validation loss: 0.0052 at epoch 119
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 120/200
# 57/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0036 - mse: 0.0036New best validation loss: 0.0044 at epoch 120
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 121/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0035 - mse: 0.0035New best validation loss: 0.0042 at epoch 121
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 122/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 123/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 124/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 125/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0089 - val_mse: 0.0089
# Epoch 126/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 127/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 128/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0088 - val_mse: 0.0088
# Epoch 129/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 130/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 131/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 132/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 133/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 134/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 135/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 136/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 137/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0082 - val_mse: 0.0082
# Epoch 138/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 139/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 139: early stopping
# Restoring model weights from the end of the best epoch: 119.
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step
# Done: 1
# Epoch 1/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 39s 213ms/step - loss: 25.4475 - mse: 25.4475 - val_loss: 22.5152 - val_mse: 22.5152
# Epoch 2/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 23.5238 - mse: 23.5238 - val_loss: 20.1289 - val_mse: 20.1289
# Epoch 3/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 21.3771 - mse: 21.3771 - val_loss: 18.0998 - val_mse: 18.0998
# Epoch 4/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 19.0586 - mse: 19.0586 - val_loss: 16.9804 - val_mse: 16.9804
# Epoch 5/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 17.5231 - mse: 17.5231 - val_loss: 21.6643 - val_mse: 21.6643
# Epoch 6/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 18.1198 - mse: 18.1198 - val_loss: 15.2912 - val_mse: 15.2912
# Epoch 7/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 14.7363 - mse: 14.7363 - val_loss: 17.3225 - val_mse: 17.3225
# Epoch 8/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 15.0646 - mse: 15.0646 - val_loss: 16.9581 - val_mse: 16.9581
# Epoch 9/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 13.4847 - mse: 13.4847 - val_loss: 10.6965 - val_mse: 10.6965
# Epoch 10/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 14.2507 - mse: 14.2507 - val_loss: 15.7424 - val_mse: 15.7424
# Epoch 11/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 13.9751 - mse: 13.9751 - val_loss: 15.6007 - val_mse: 15.6007
# Epoch 12/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 11.9404 - mse: 11.9404 - val_loss: 9.6213 - val_mse: 9.6213
# Epoch 13/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 10.9616 - mse: 10.9616 - val_loss: 7.2540 - val_mse: 7.2540
# Epoch 14/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.3643 - mse: 8.3643 - val_loss: 11.4197 - val_mse: 11.4197
# Epoch 15/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 11.2386 - mse: 11.2386 - val_loss: 20.6874 - val_mse: 20.6874
# Epoch 16/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.6974 - mse: 7.6974 - val_loss: 10.9835 - val_mse: 10.9835
# Epoch 17/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.9469 - mse: 5.9469 - val_loss: 7.0181 - val_mse: 7.0181
# Epoch 18/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.7821 - mse: 6.7821 - val_loss: 5.8994 - val_mse: 5.8994
# Epoch 19/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.0852 - mse: 8.0852 - val_loss: 14.7547 - val_mse: 14.7547
# Epoch 20/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 11.6371 - mse: 11.6371 - val_loss: 20.0530 - val_mse: 20.0530
# Epoch 21/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.2498 - mse: 8.2498 - val_loss: 6.2583 - val_mse: 6.2583
# Epoch 22/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.7246 - mse: 7.7246 - val_loss: 7.5164 - val_mse: 7.5164
# Epoch 23/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.9621 - mse: 4.9621 - val_loss: 5.1508 - val_mse: 5.1508
# Epoch 24/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.3037 - mse: 6.3037 - val_loss: 3.1163 - val_mse: 3.1163
# Epoch 25/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.9647 - mse: 4.9647 - val_loss: 3.0201 - val_mse: 3.0201
# Epoch 26/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.4867 - mse: 4.4867 - val_loss: 2.5547 - val_mse: 2.5547
# Epoch 27/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.8102 - mse: 2.8102 - val_loss: 1.8826 - val_mse: 1.8826
# Epoch 28/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.1774 - mse: 2.1774 - val_loss: 1.2774 - val_mse: 1.2774
# Epoch 29/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.8811 - mse: 1.8811 - val_loss: 1.1524 - val_mse: 1.1524
# Epoch 30/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.1443 - mse: 2.1443 - val_loss: 0.9446 - val_mse: 0.9446
# Epoch 31/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.1951 - mse: 1.1951 - val_loss: 11.6339 - val_mse: 11.6339
# Epoch 32/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.5643 - mse: 2.5643 - val_loss: 1.1783 - val_mse: 1.1783
# Epoch 33/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.0453 - mse: 1.0453 - val_loss: 1.9942 - val_mse: 1.9942
# Epoch 34/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.1721 - mse: 1.1721 - val_loss: 0.9899 - val_mse: 0.9899
# Epoch 35/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.2539 - mse: 1.2539 - val_loss: 1.1335 - val_mse: 1.1335
# Epoch 36/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.6968 - mse: 0.6968 - val_loss: 0.6867 - val_mse: 0.6867
# Epoch 37/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.1173 - mse: 1.1173 - val_loss: 0.4468 - val_mse: 0.4468
# Epoch 38/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5945 - mse: 0.5945 - val_loss: 0.4037 - val_mse: 0.4037
# Epoch 39/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.6131 - mse: 0.6131 - val_loss: 1.0270 - val_mse: 1.0270
# Epoch 40/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.4916 - mse: 0.4916 - val_loss: 0.4003 - val_mse: 0.4003
# Epoch 41/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5166 - mse: 0.5166 - val_loss: 0.7408 - val_mse: 0.7408
# Epoch 42/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5317 - mse: 0.5317 - val_loss: 0.4769 - val_mse: 0.4769
# Epoch 43/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.6895 - mse: 0.6895 - val_loss: 1.1167 - val_mse: 1.1167
# Epoch 44/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.9214 - mse: 0.9214 - val_loss: 0.4309 - val_mse: 0.4309
# Epoch 45/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.8778 - mse: 0.8778 - val_loss: 0.2339 - val_mse: 0.2339
# Epoch 46/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.4032 - mse: 0.4032 - val_loss: 0.4644 - val_mse: 0.4644
# Epoch 47/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.3160 - mse: 0.3160 - val_loss: 0.4320 - val_mse: 0.4320
# Epoch 48/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.3492 - mse: 0.3492 - val_loss: 0.2490 - val_mse: 0.2490
# Epoch 49/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2764 - mse: 0.2764 - val_loss: 0.2894 - val_mse: 0.2894
# Epoch 50/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2326 - mse: 0.2326 - val_loss: 0.2223 - val_mse: 0.2223
# Epoch 51/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3160 - mse: 0.3160 - val_loss: 0.4628 - val_mse: 0.4628
# Epoch 52/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2101 - mse: 0.2101 - val_loss: 0.3780 - val_mse: 0.3780
# Epoch 53/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3852 - mse: 0.3852 - val_loss: 0.4105 - val_mse: 0.4105
# Epoch 54/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2940 - mse: 0.2940 - val_loss: 0.2614 - val_mse: 0.2614
# Epoch 55/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1930 - mse: 0.1930 - val_loss: 0.1954 - val_mse: 0.1954
# Epoch 56/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2037 - mse: 0.2037 - val_loss: 0.4251 - val_mse: 0.4251
# Epoch 57/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2547 - mse: 0.2547 - val_loss: 0.1320 - val_mse: 0.1320
# Epoch 58/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2210 - mse: 0.2210 - val_loss: 0.3478 - val_mse: 0.3478
# Epoch 59/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2083 - mse: 0.2083 - val_loss: 0.1900 - val_mse: 0.1900
# Epoch 60/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2415 - mse: 0.2415 - val_loss: 0.2063 - val_mse: 0.2063
# Epoch 61/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1410 - mse: 0.1410 - val_loss: 0.1576 - val_mse: 0.1576
# Epoch 62/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1493 - mse: 0.1493 - val_loss: 0.1289 - val_mse: 0.1289
# Epoch 63/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1523 - mse: 0.1523 - val_loss: 0.1448 - val_mse: 0.1448
# Epoch 64/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1949 - mse: 0.1949 - val_loss: 0.1745 - val_mse: 0.1745
# Epoch 65/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1654 - mse: 0.1654 - val_loss: 0.2565 - val_mse: 0.2565
# Epoch 66/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2103 - mse: 0.2103 - val_loss: 0.2153 - val_mse: 0.2153
# Epoch 67/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1406 - mse: 0.1406 - val_loss: 0.3222 - val_mse: 0.3222
# Epoch 68/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1185 - mse: 0.1185 - val_loss: 0.1410 - val_mse: 0.1410
# Epoch 69/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1644 - mse: 0.1644 - val_loss: 0.2295 - val_mse: 0.2295
# Epoch 70/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1403 - mse: 0.1403 - val_loss: 0.1488 - val_mse: 0.1488
# Epoch 71/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1638 - mse: 0.1638 - val_loss: 0.1603 - val_mse: 0.1603
# Epoch 72/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1611 - mse: 0.1611 - val_loss: 0.1176 - val_mse: 0.1176
# Epoch 73/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1715 - mse: 0.1715 - val_loss: 0.2274 - val_mse: 0.2274
# Epoch 74/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1101 - mse: 0.1101 - val_loss: 0.0887 - val_mse: 0.0887
# Epoch 75/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1024 - mse: 0.1024 - val_loss: 0.1581 - val_mse: 0.1581
# Epoch 76/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0847 - mse: 0.0847 - val_loss: 0.0913 - val_mse: 0.0913
# Epoch 77/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0937 - mse: 0.0937 - val_loss: 0.1501 - val_mse: 0.1501
# Epoch 78/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0866 - mse: 0.0866 - val_loss: 0.1270 - val_mse: 0.1270
# Epoch 79/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1030 - mse: 0.1030 - val_loss: 0.0558 - val_mse: 0.0558
# Epoch 80/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0859 - mse: 0.0859 - val_loss: 0.0638 - val_mse: 0.0638
# Epoch 81/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1016 - mse: 0.1016 - val_loss: 0.1426 - val_mse: 0.1426
# Epoch 82/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0798 - mse: 0.0798 - val_loss: 0.0809 - val_mse: 0.0809
# Epoch 83/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0828 - mse: 0.0828 - val_loss: 0.0812 - val_mse: 0.0812
# Epoch 84/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0985 - mse: 0.0985 - val_loss: 0.0858 - val_mse: 0.0858
# Epoch 85/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0816 - mse: 0.0816 - val_loss: 0.1212 - val_mse: 0.1212
# Epoch 86/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0867 - mse: 0.0867 - val_loss: 0.0656 - val_mse: 0.0656
# Epoch 87/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0592 - mse: 0.0592 - val_loss: 0.0691 - val_mse: 0.0691
# Epoch 88/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0611 - mse: 0.0611 - val_loss: 0.0557 - val_mse: 0.0557
# Epoch 89/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0516 - mse: 0.0516 - val_loss: 0.0982 - val_mse: 0.0982
# Epoch 90/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0524 - mse: 0.0524 - val_loss: 0.0510 - val_mse: 0.0510
# Epoch 91/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0544 - mse: 0.0544 - val_loss: 0.0758 - val_mse: 0.0758
# Epoch 92/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0952 - mse: 0.0952 - val_loss: 0.0963 - val_mse: 0.0963
# Epoch 93/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0642 - mse: 0.0642 - val_loss: 0.0638 - val_mse: 0.0638
# Epoch 94/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0458 - mse: 0.0458 - val_loss: 0.0783 - val_mse: 0.0783
# Epoch 95/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0517 - mse: 0.0517 - val_loss: 0.0342 - val_mse: 0.0342
# Epoch 96/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0336 - mse: 0.0336 - val_loss: 0.0304 - val_mse: 0.0304
# Epoch 97/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0317 - mse: 0.0317 - val_loss: 0.0396 - val_mse: 0.0396
# Epoch 98/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0309 - mse: 0.0309 - val_loss: 0.0367 - val_mse: 0.0367
# Epoch 99/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0260 - mse: 0.0260 - val_loss: 0.0268 - val_mse: 0.0268
# Epoch 100/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0335 - mse: 0.0335 - val_loss: 0.0465 - val_mse: 0.0465
# Epoch 101/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0620 - mse: 0.0620 - val_loss: 0.0383 - val_mse: 0.0383
# Epoch 102/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0433 - mse: 0.0433 - val_loss: 0.0586 - val_mse: 0.0586
# Epoch 103/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0335 - mse: 0.0335 - val_loss: 0.0415 - val_mse: 0.0415
# Epoch 104/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0310 - mse: 0.0310 - val_loss: 0.0155 - val_mse: 0.0155
# Epoch 105/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0271 - mse: 0.0271 - val_loss: 0.0700 - val_mse: 0.0700
# Epoch 106/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0255 - mse: 0.0255 - val_loss: 0.0291 - val_mse: 0.0291
# Epoch 107/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0314 - mse: 0.0314 - val_loss: 0.0259 - val_mse: 0.0259
# Epoch 108/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0345 - mse: 0.0345 - val_loss: 0.0392 - val_mse: 0.0392
# Epoch 109/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0221 - mse: 0.0221 - val_loss: 0.0184 - val_mse: 0.0184
# Epoch 110/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0272 - mse: 0.0272 - val_loss: 0.0379 - val_mse: 0.0379
# Epoch 111/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0189 - mse: 0.0189 - val_loss: 0.0279 - val_mse: 0.0279
# Epoch 112/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0227 - mse: 0.0227 - val_loss: 0.0478 - val_mse: 0.0478
# Epoch 113/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0367 - mse: 0.0367 - val_loss: 0.0273 - val_mse: 0.0273
# Epoch 114/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0269 - mse: 0.0269 - val_loss: 0.0355 - val_mse: 0.0355
# Epoch 115/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0278 - mse: 0.0278 - val_loss: 0.0272 - val_mse: 0.0272
# Epoch 116/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0231 - mse: 0.0231 - val_loss: 0.0192 - val_mse: 0.0192
# Epoch 117/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0253 - mse: 0.0253 - val_loss: 0.0191 - val_mse: 0.0191
# Epoch 118/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 119/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0177 - val_mse: 0.0177
# Epoch 120/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0188 - val_mse: 0.0188
# Epoch 121/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0139 - val_mse: 0.0139
# Epoch 122/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0221 - val_mse: 0.0221
# Epoch 123/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 124/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 125/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 126/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0310 - val_mse: 0.0310
# Epoch 127/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0162 - val_mse: 0.0162
# Epoch 128/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 129/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0189 - val_mse: 0.0189
# Epoch 130/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 131/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 132/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0160 - val_mse: 0.0160
# Epoch 133/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 134/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0086 - val_mse: 0.0086
# Epoch 135/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0097 - val_mse: 0.0097
# Epoch 136/200
# ...
# Epoch 64/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.3834 - mse: 5.3834 - val_loss: 0.4402 - val_mse: 0.4402
# Epoch 65/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2871 - mse: 0.2871 - val_loss: 0.5979 - val_mse: 0.5979
# Epoch 66/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3210 - mse: 0.3210 - val_loss: 0.3616 - val_mse: 0.3616
# Epoch 67/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5979 - mse: 0.5979 - val_loss: 0.4052 - val_mse: 0.4052
# Epoch 68/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.9074 - mse: 0.9074 - val_loss: 0.4578 - val_mse: 0.4578
# Epoch 69/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3129 - mse: 0.3129 - val_loss: 0.2366 - val_mse: 0.2366
# Epoch 70/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.9626 - mse: 1.9626 - val_loss: 0.2749 - val_mse: 0.2749
# Epoch 71/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2209 - mse: 0.2209 - val_loss: 0.2468 - val_mse: 0.2468
# Epoch 72/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.7204 - mse: 0.7204 - val_loss: 0.2142 - val_mse: 0.2142
# Epoch 73/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.4544 - mse: 3.4544 - val_loss: 0.4634 - val_mse: 0.4634
# Epoch 74/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0188 - mse: 1.0188 - val_loss: 0.1957 - val_mse: 0.1957
# Epoch 75/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1957 - mse: 0.1957 - val_loss: 0.2393 - val_mse: 0.2393
# Epoch 76/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1906 - mse: 0.1906 - val_loss: 0.3108 - val_mse: 0.3108
# Epoch 77/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.3750 - mse: 3.3750 - val_loss: 0.8784 - val_mse: 0.8784
# Epoch 78/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5435 - mse: 0.5435 - val_loss: 0.3023 - val_mse: 0.3023
# Epoch 79/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.8111 - mse: 0.8111 - val_loss: 0.2236 - val_mse: 0.2236
# Epoch 80/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3219 - mse: 0.3219 - val_loss: 0.1785 - val_mse: 0.1785
# Epoch 81/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2428 - mse: 0.2428 - val_loss: 0.1783 - val_mse: 0.1783
# Epoch 82/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1972 - mse: 0.1972 - val_loss: 0.1995 - val_mse: 0.1995
# Epoch 83/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1835 - mse: 0.1835 - val_loss: 0.2453 - val_mse: 0.2453
# Epoch 84/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5358 - mse: 1.5358 - val_loss: 0.1994 - val_mse: 0.1994
# Epoch 85/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1791 - mse: 0.1791 - val_loss: 0.1771 - val_mse: 0.1771
# Epoch 86/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1556 - mse: 0.1556 - val_loss: 0.1586 - val_mse: 0.1586
# Epoch 87/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1663 - mse: 0.1663 - val_loss: 0.2823 - val_mse: 0.2823
# Epoch 88/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.8092 - mse: 0.8092 - val_loss: 0.4634 - val_mse: 0.4634
# Epoch 89/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1352 - mse: 0.1352 - val_loss: 0.1653 - val_mse: 0.1653
# Epoch 90/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5697 - mse: 0.5697 - val_loss: 0.1500 - val_mse: 0.1500
# Epoch 91/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1732 - mse: 0.1732 - val_loss: 0.1600 - val_mse: 0.1600
# Epoch 92/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3119 - mse: 0.3119 - val_loss: 0.1736 - val_mse: 0.1736
# Epoch 93/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.4949 - mse: 0.4949 - val_loss: 0.1482 - val_mse: 0.1482
# Epoch 94/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2639 - mse: 0.2639 - val_loss: 0.2399 - val_mse: 0.2399
# Epoch 95/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1177 - mse: 0.1177 - val_loss: 0.1175 - val_mse: 0.1175
# Epoch 96/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.1796 - mse: 2.1796 - val_loss: 0.7639 - val_mse: 0.7639
# Epoch 97/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2452 - mse: 0.2452 - val_loss: 0.1915 - val_mse: 0.1915
# Epoch 98/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0992 - mse: 0.0992 - val_loss: 0.1052 - val_mse: 0.1052
# Epoch 99/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0799 - mse: 0.0799 - val_loss: 0.0777 - val_mse: 0.0777
# Epoch 100/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3648 - mse: 0.3648 - val_loss: 0.1171 - val_mse: 0.1171
# Epoch 101/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.4723 - mse: 0.4723 - val_loss: 0.0948 - val_mse: 0.0948
# Epoch 102/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2629 - mse: 0.2629 - val_loss: 0.1306 - val_mse: 0.1306
# Epoch 103/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1054 - mse: 0.1054 - val_loss: 0.1372 - val_mse: 0.1372
# Epoch 104/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0607 - mse: 0.0607 - val_loss: 0.0568 - val_mse: 0.0568
# Epoch 105/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0562 - mse: 0.0562 - val_loss: 0.0699 - val_mse: 0.0699
# Epoch 106/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0737 - mse: 0.0737 - val_loss: 0.0676 - val_mse: 0.0676
# Epoch 107/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0636 - mse: 0.0636 - val_loss: 0.0587 - val_mse: 0.0587
# Epoch 108/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0739 - mse: 0.0739 - val_loss: 0.1252 - val_mse: 0.1252
# Epoch 109/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0692 - mse: 0.0692 - val_loss: 0.0697 - val_mse: 0.0697
# Epoch 110/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0502 - mse: 0.0502 - val_loss: 0.0931 - val_mse: 0.0931
# Epoch 111/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0557 - mse: 0.0557 - val_loss: 0.0749 - val_mse: 0.0749
# Epoch 112/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0458 - mse: 0.0458 - val_loss: 0.0374 - val_mse: 0.0374
# Epoch 113/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0458 - mse: 0.0458 - val_loss: 0.0603 - val_mse: 0.0603
# Epoch 114/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0405 - mse: 0.0405 - val_loss: 0.0710 - val_mse: 0.0710
# Epoch 115/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0777 - mse: 0.0777 - val_loss: 0.0926 - val_mse: 0.0926
# Epoch 116/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0710 - mse: 0.0710 - val_loss: 0.0630 - val_mse: 0.0630
# Epoch 117/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0451 - mse: 0.0451 - val_loss: 0.0661 - val_mse: 0.0661
# Epoch 118/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0599 - mse: 0.0599 - val_loss: 0.0472 - val_mse: 0.0472
# Epoch 119/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0582 - mse: 0.0582 - val_loss: 0.0337 - val_mse: 0.0337
# Epoch 120/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0465 - mse: 0.0465 - val_loss: 0.0734 - val_mse: 0.0734
# Epoch 121/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0471 - mse: 0.0471 - val_loss: 0.0462 - val_mse: 0.0462
# Epoch 122/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0397 - mse: 0.0397 - val_loss: 0.0670 - val_mse: 0.0670
# Epoch 123/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0473 - mse: 0.0473 - val_loss: 0.0505 - val_mse: 0.0505
# Epoch 124/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0342 - mse: 0.0342 - val_loss: 0.0355 - val_mse: 0.0355
# Epoch 125/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0313 - mse: 0.0313 - val_loss: 0.0356 - val_mse: 0.0356
# Epoch 126/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0218 - mse: 0.0218 - val_loss: 0.0447 - val_mse: 0.0447
# Epoch 127/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0284 - mse: 0.0284 - val_loss: 0.0307 - val_mse: 0.0307
# Epoch 128/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0258 - mse: 0.0258 - val_loss: 0.0432 - val_mse: 0.0432
# Epoch 129/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0266 - mse: 0.0266 - val_loss: 0.0385 - val_mse: 0.0385
# Epoch 130/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0509 - mse: 0.0509 - val_loss: 0.0540 - val_mse: 0.0540
# Epoch 131/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0300 - mse: 0.0300 - val_loss: 0.0331 - val_mse: 0.0331
# Epoch 132/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0220 - mse: 0.0220 - val_loss: 0.0555 - val_mse: 0.0555
# Epoch 133/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0283 - mse: 0.0283 - val_loss: 0.0681 - val_mse: 0.0681
# Epoch 134/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0329 - mse: 0.0329 - val_loss: 0.0459 - val_mse: 0.0459
# Epoch 135/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0378 - mse: 0.0378 - val_loss: 0.0564 - val_mse: 0.0564
# Epoch 136/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0299 - mse: 0.0299 - val_loss: 0.0294 - val_mse: 0.0294
# Epoch 137/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0152 - mse: 0.0152 - val_loss: 0.0246 - val_mse: 0.0246
# Epoch 138/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0151 - mse: 0.0151 - val_loss: 0.0213 - val_mse: 0.0213
# Epoch 139/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0468 - val_mse: 0.0468
# Epoch 140/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0165 - mse: 0.0165 - val_loss: 0.0249 - val_mse: 0.0249
# Epoch 141/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0302 - val_mse: 0.0302
# Epoch 142/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0130 - mse: 0.0130 - val_loss: 0.0186 - val_mse: 0.0186
# Epoch 143/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0148 - mse: 0.0148 - val_loss: 0.0214 - val_mse: 0.0214
# Epoch 144/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0217 - val_mse: 0.0217
# Epoch 145/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0142 - mse: 0.0142 - val_loss: 0.0191 - val_mse: 0.0191
# Epoch 146/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0151 - mse: 0.0151 - val_loss: 0.0208 - val_mse: 0.0208
# Epoch 147/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0175 - val_mse: 0.0175
# Epoch 148/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0194 - val_mse: 0.0194
# Epoch 149/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0247 - val_mse: 0.0247
# Epoch 150/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0153 - val_mse: 0.0153
# Epoch 151/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0242 - val_mse: 0.0242
# Epoch 152/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0130 - mse: 0.0130 - val_loss: 0.0167 - val_mse: 0.0167
# Epoch 153/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0228 - val_mse: 0.0228
# Epoch 154/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0182 - val_mse: 0.0182
# Epoch 155/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 156/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0145 - val_mse: 0.0145
# Epoch 157/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0142 - val_mse: 0.0142
# Epoch 158/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0146 - val_mse: 0.0146
# Epoch 159/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0132 - val_mse: 0.0132
# Epoch 160/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0185 - val_mse: 0.0185
# Epoch 161/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0204 - val_mse: 0.0204
# Epoch 162/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0142 - val_mse: 0.0142
# Epoch 163/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0122 - val_mse: 0.0122
# Epoch 164/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 165/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0128 - val_mse: 0.0128
# Epoch 166/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 167/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 168/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 169/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0130 - val_mse: 0.0130
# Epoch 170/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 171/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 172/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0120 - val_mse: 0.0120
# Epoch 173/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 174/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0097 - val_mse: 0.0097
# Epoch 175/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 176/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0129 - val_mse: 0.0129
# Epoch 177/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 178/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 179/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 180/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 181/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 182/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 183/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0124 - val_mse: 0.0124
# Epoch 184/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 185/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 186/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 187/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0088 - val_mse: 0.0088
# Epoch 188/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0094 - val_mse: 0.0094
# Epoch 189/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 190/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 191/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 192/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 193/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0088 - val_mse: 0.0088
# Epoch 194/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 194: early stopping
# Restoring model weights from the end of the best epoch: 174.
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step
# Done: 4

# %%
best_model.summary()
# Out:
# Model: "transformer_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_97 (Dense)                │ (None, 16, 32)         │            64 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoder_5 (Encoder)             │ ?                      │        38,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_45 (Dropout)            │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_116 (Dense)               │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 114,628 (447.77 KB)
#  Trainable params: 38,209 (149.25 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 76,419 (298.52 KB)

# %%
bootstrap_predsInRange.shape
# Out:
# (5, 1457, 1)

# %%
predsInRange = []
predsOutRange = []
predsLongRange = []

for i in range(len(x_test)):
    counter = 0
    for j in range(n_bootstrap):
        counter += bootstrap_predsInRange[j][i]
    predsInRange.append(counter/n_bootstrap)

for i in range(len(out_x_test)):
    counter = 0
    for j in range(n_bootstrap):
        counter += bootstrap_predsOutRange[j][i]
    predsOutRange.append(counter/n_bootstrap)

for i in range(len(long_x_test)):
    counter = 0
    for j in range(n_bootstrap):
        counter += bootstrap_predsLongRange[j][i]
    predsLongRange.append(counter/n_bootstrap)

# %%
diffInRange = []
for i in range(len(y_test)):
    diffInRange.append(abs(y_test[i] - predsInRange[i]))
print(len(diffInRange))
diffLongRange = []
for i in range(200, 300):
    diffLongRange.append(np.array(np.abs(long_y_test[i]) - np.array(predsInRange[i])))
    long_y_test[i]
    predsLongRange[i]

diffOutRange = []
for i in range(len(out_y_test)):
    diffOutRange.append(abs(out_y_test[i] - predsOutRange[i]))
safe_out_y_test = np.where(out_y_test == 0, 1, out_y_test)
diff_out_relError = []
for i in range(len(out_y_test)):
    diff_out_relError.append(diffOutRange[i] / safe_out_y_test[i])
# Out:
# 1457

# %%
placeholder = absSum(outsideExpr)
diffOutRange = []
indices_with_placeholder_22 = [i for i, val in enumerate(placeholder) if val == 22] 

for i in indices_with_placeholder_22:
    diffOutRange.append(np.abs(out_y_test[i]-predsOutRange[i]))

# %%
meanDiff_InRange = np.mean(diffInRange)
meanDiff_OutRange = np.mean(diffOutRange)
meanDiff_LongRange = np.mean(diffLongRange)
meanDiff_OutRelRange = np.mean(diff_out_relError)

# %%
benchmark = 0
benchmark += baseline_deviation / (meanDiff_InRange**2) / 4
print(baseline_deviation / (meanDiff_InRange**2) / 4)

benchmark += baseline_out_deviation / (meanDiff_OutRange**2) / 4
print(baseline_out_deviation / (meanDiff_OutRange**2) / 4)

benchmark += baseline_long_deviation / (meanDiff_LongRange**2) / 4
print(baseline_long_deviation / (meanDiff_LongRange**2) / 4)

benchmark += baseline_relError / (meanDiff_OutRelRange**2) / 4
print(baseline_relError / (meanDiff_OutRelRange**2) / 4)

print(f"Benchmark: {benchmark}")
# Out:
# 1.2647787816065574
# 0.11860930763853801
# 0.10238755964009165
# 2.436944893548477
# Benchmark: 3.922720542433664

# %%
print(bootstrap_predsInRange[2][2])
print(x_test[0])
print(y_test[2], predsInRange[0])


print(baseline_deviation, baseline_out_deviation, baseline_long_deviation, baseline_relError)
print(meanDiff_InRange**2, meanDiff_OutRange**2, meanDiff_LongRange**2, meanDiff_OutRelRange**2)
# Out:
# [-9.035661]
# [15.   0.   1.   3.   1.   3.   0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5
#   0.5  0.5]
# -9.0 [6.037833]
# 0.005334918646456544 12.566075851479786 10.144331876139583 0.03730748928358623
# 0.0010545161580905044 26.486276881774984 24.769444432015234 0.0038272807668274927
