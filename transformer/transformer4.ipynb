# %%
import sys
import os
import numpy as np
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Dense, Layer, Dropout

print("Successfully imported libraries!")
# Out:
# Successfully imported libraries!

# %%
# List available GPUs
gpus = tf.config.list_physical_devices('GPU')
print("GPUs Available:", gpus)

# Check if TensorFlow will place operations on the GPU
print("TensorFlow Version:", tf.__version__)

# Run a quick test
with tf.device('/GPU:0'):
    a = tf.random.normal([1000, 1000])
    b = tf.random.normal([1000, 1000])
    c = tf.matmul(a, b)
    print("Test computation done on GPU")
# Out:
# GPUs Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# TensorFlow Version: 2.16.1
# 2025-11-08 11:51:22.622921: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:00:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-11-08 11:51:29.023386: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:00:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-11-08 11:51:29.023691: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:00:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-11-08 11:51:29.028815: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:00:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-11-08 11:51:29.029112: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:00:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-11-08 11:51:29.029253: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:00:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-11-08 11:51:29.133064: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:00:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-11-08 11:51:29.133403: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:00:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-11-08 11:51:29.133460: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2025-11-08 11:51:29.133593: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:00:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-11-08 11:51:29.133728: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3354 MB memory:  -> device: 0, name: Orin, pci bus id: 0000:00:00.0, compute capability: 8.7
# Test computation done on GPU

# %%
# Get the absolute path of the current script's directory
current_dir = os.path.dirname(os.path.abspath("transformer0.ipynb"))

# Get the absolute path of the parent directory (project_folder)
parent_dir = os.path.dirname(current_dir)

# Add the parent directory to the Python path
sys.path.append(parent_dir)

# Now you can import from GetXY.py
from GetXY import x_train, y_train, x_val, y_val

early_stopping = tf.keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
    monitor='mse'
)
# ... rest of your code
print("Successfully imported variables!")
# Out:
# 4 - 2 + 2
# 2543
# 4.0
#
# Expressions not in x:
# -5 - -5 + 1
# True
# 1457
# 1.0
# 15
# -4.0
# [-5.   1.   1.   0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5
#   0.5]
# Successfully imported variables!

# %%
#add a cls token at the beginning of x_train and x_val
pad_value = 15
x_train = np.pad(x_train, ((0, 0), (1, 0)), 'constant', constant_values=pad_value)
x_val = np.pad(x_val, ((0, 0), (1, 0)), 'constant', constant_values=pad_value)

# %%
#defining the positional encoder modelled after the formula in the paper that was cited. (generated by gemini)
def posEncoding(max_seq_len, d_model):
    # Create a matrix of angles according to the formula
    angle_rads = get_angles(np.arange(max_seq_len)[:, np.newaxis],
                          np.arange(d_model)[np.newaxis, :],
                          d_model)
    
    # Apply sine to even indices in the array; 2i
    angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
    
    # Apply cosine to odd indices in the array; 2i+1
    angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
    
    # Add a batch dimension
    pos_encoding = angle_rads[np.newaxis, ...]
    
    return tf.cast(pos_encoding, dtype=tf.float32)

def get_angles(pos, i, d_model):
    angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
    return pos * angle_rates

# %%
#defining the point-wise FNN
#d_ff = 2048 #(original transformer size)
def point_wise_fnn(d_model, d_ff):
    return tf.keras.Sequential([
        Dense(d_ff, activation = "relu", kernel_initializer = "glorot_uniform", bias_initializer = "zeros"),
        Dense(d_model, kernel_initializer = "glorot_uniform", bias_initializer = "zeros")
    ])

# %%
#scaled dot-product attention
class MH_Attention(Layer):
    def __init__(self, d_model, num_heads):
        super().__init__()
        #for the split_heads function:
        self.num_heads = num_heads
        self.d_model = d_model
        
        assert d_model % self.num_heads == 0
        self.depth = d_model // self.num_heads

        #for the call function:
        #This allows the model to learn the best way to project the input embeddings. (linear projection)
        self.wq = Dense(d_model, kernel_initializer = "glorot_uniform", bias_initializer = "zeros")
        self.wk = Dense(d_model, kernel_initializer = "glorot_uniform", bias_initializer = "zeros")
        self.wv = Dense(d_model, kernel_initializer = "glorot_uniform", bias_initializer = "zeros")

        #it's important to initialize this aswell as the ones above here, so that the model saves the previous weights and is able to learn.
        self.finalDense = Dense(d_model, kernel_initializer = "glorot_uniform", bias_initializer = "zeros")
        
    def SDP_Attention(self, q, k, v, mask):
        matmul_qk = tf.matmul(q, k, transpose_b=True) #calculate the dotproduct, between the query and a transposed key.
        d_k = tf.shape(k)[-1] #read the dimensionality of the key tensor (here d_model/num_heads = depth)
        d_k = tf.cast(d_k, tf.float32) #convert to float type
        scaled_qk = matmul_qk / tf.math.sqrt(d_k) #scale for purposes discussed in their paper.        

        if mask is not None:
            scaled_qk += (mask * -1e9) #masking to a big negative number
        
        softmaxed_qk = tf.nn.softmax(scaled_qk, axis = -1) #apply softmax function (axis = -1) for softmaxing all the different keys. The last entry is the number of keys (not the dimensionality of them, like it was befre.)
        output = tf.matmul(softmaxed_qk, v) #multiply the attention-weights with the values corresponding to the keys, in respect to the query.
        return output, softmaxed_qk
        
    def split_heads(self, x, batch_size):
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth)) #splits up the x data which is gonna be q, k, or v, into the individual heads. effectively adding a dimension (self.num_heads), after splitting up self.d_model
        return tf.transpose(x, perm =[0,2,1,3]) #reorganizes the dimensions into the expected order (batch_size, num_heads, seq_len, depth(the new d_model "fractions"))

    def call(self, q, k ,v, mask = None):
        batch_size = tf.shape(q)[0]

        #(linear projection)
        q = self.wq(q)
        k = self.wk(k)
        v = self.wv(v)

        #split them all up into the individual heads. (add a dimension basically)
        q = self.split_heads(q , batch_size)
        k = self.split_heads(k , batch_size)
        v = self.split_heads(v , batch_size)

        sdp_attention, attention_weights = self.SDP_Attention(q,k,v, mask = mask) #applies the sdp-attention to all of them. sdp_attention at the end has a shape of: (batch_size, num_heads, seq_len, depth)
        
        sdp_attention = tf.transpose(sdp_attention, perm=[0, 2, 1, 3]) #swap the 2nd and 3rd dimensions
        combined_attention = tf.reshape(sdp_attention, (batch_size, -1, self.d_model)) #combine back the two last dimnensions (num_heads and depth) into the original d_model

        output = self.finalDense(combined_attention)
        return output, attention_weights

# %%
class EncodingLayer(Layer):
    def __init__(self, d_model, num_heads, d_ff, rate):
        super().__init__()
        #define all the components of a Layer so the model will learn them properly here.
        self.mha = MH_Attention(d_model, num_heads)
        self.fnn = point_wise_fnn(d_model, d_ff)

        #initiate the 2 normalizations
        self.norm1 = tf.keras.layers.LayerNormalization()
        self.norm2 = tf.keras.layers.LayerNormalization()

        self.dropout1 = Dropout(rate)
        self.dropout2 = Dropout(rate)

        
    def call(self,x, training, mask = None):
        mha_out, attention_weights = self.mha(x,x,x,mask = mask) #for self-attention: q,k,v = x
        mha_out = self.dropout1(mha_out, training = training) #they apply a small dropout of 0.1 after every residual step in the paper.

        norm_out = self.norm1(x + mha_out) #first, add the vectors, then normalize them.

        fnn_out = self.fnn(norm_out) #2nd sub-layer with fnn
        fnn_out = self.dropout2(fnn_out, training = training) #again apply drop out

        norm2_out = self.norm2(norm_out + fnn_out) #again add and norm

        return norm2_out

# %%
class Encoder(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, num_layers, d_ff, rate):
        super().__init__()

        self.d_model = d_model
        self.num_layers = num_layers #amount of encoding layers
        self.layers = [EncodingLayer(d_model, num_heads, d_ff, rate) for i in range(num_layers)] #define multiple diffferent encoding layers here.

        self.dropout = Dropout(rate)
            
    def call(self, x, training, mask = None):
        x = self.dropout(x, training = training) #we want to drop out before the first layer
        for i in range(self.num_layers):
            x = self.layers[i](x, training = training, mask = mask)
        return x

# %%
class Transformer(tf.keras.Model):
    def __init__(self, embedding_layer, d_model, max_seq_len, num_heads, num_layers, d_ff, rate):
        super().__init__()
        self.embedding = embedding_layer
        self.d_model = d_model
        self.pos_enc = posEncoding(max_seq_len, d_model)
        self.Encoder = Encoder(d_model, num_heads, num_layers, d_ff, rate)
        self.dropout = tf.keras.layers.Dropout(rate)
        self.finalDense = Dense(1, activation = "linear", kernel_initializer = "glorot_uniform", bias_initializer = "zeros")
        
    def call(self, x, training, mask = None):
        seq_len = tf.shape(x)[1]
        x = tf.expand_dims(x, axis=-1) #add a dimension to x
        x = self.embedding(x)
        x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32)) #scale with √d_model
        x += self.pos_enc[:, :seq_len, :]
        
        out_Encoder = self.Encoder(x, training = training, mask = mask)

        output = out_Encoder[:,0,:] #pooling: to the first token.
        output = self.dropout(output, training = training) #another dropout

        final = self.finalDense(output) #now we can reduce back to a single neuron. This is the opposite of what we did in the embedding layer.

        return final

# %%
# Define a custom learning rate schedule class with warmup and cosine decay
class WarmupCosineDecay(tf.keras.optimizers.schedules.LearningRateSchedule):
    """
    A custom learning rate schedule that implements a linear warmup
    followed by a cosine decay.
    """
    def __init__(self, peak_lr, warmup_steps, decay_steps, alpha=0.0, name=None):
        super().__init__()
        self.peak_lr = peak_lr
        self.warmup_steps = warmup_steps
        self.decay_steps = decay_steps
        self.alpha = alpha
        self.name = name

    def __call__(self, step):
        with tf.name_scope(self.name or "WarmupCosineDecay"):
            # Ensure step is a float for calculations
            step = tf.cast(step, tf.float32)
            
            # --- 1. Warmup Phase ---
            # Linearly increase the learning rate from 0 to peak_lr
            warmup_lr = self.peak_lr * (step / self.warmup_steps)

            # --- 2. Cosine Decay Phase ---
            # Define the cosine decay schedule
            cosine_decay_schedule = tf.keras.optimizers.schedules.CosineDecay(
                initial_learning_rate=self.peak_lr,
                decay_steps=self.decay_steps,
                alpha=self.alpha
            )
            # Calculate the learning rate for the decay phase.
            # Note: The 'step' for the cosine part must be relative to its start.
            decay_lr = cosine_decay_schedule(step - self.warmup_steps)

            # --- 3. Choose the correct phase ---
            # Use tf.where to select the learning rate based on the current step
            learning_rate = tf.where(
                step < self.warmup_steps,
                warmup_lr,
                decay_lr
            )
            return learning_rate

    def get_config(self):
        return {
            "peak_lr": self.peak_lr,
            "warmup_steps": self.warmup_steps,
            "decay_steps": self.decay_steps,
            "alpha": self.alpha,
            "name": self.name
        }

# %%
import keras_tuner
from tensorflow.keras import backend as K
def build_model(hp):
    K.clear_session()
    # A smaller configuration to reduce overfitting
    # Ensure compatibility
    num_heads = hp.Choice('num_heads', [2, 4, 8])  # Powers of 2 work well
    d_model = hp.Choice('d_model', [32, 64, 128])   # Also powers of 2
    # This guarantees d_model % num_heads == 0
    num_layers = hp.Int('num_layers', 2, 6)
    d_ff = hp.Choice('d_ff', [64, 128, 256, 512])   # Multiples that work well
    if hp.Boolean("dropout"):
        dropout_rate = 0.2 
    else: 
        dropout_rate = 0
    peak_lr = hp.Float("peak learning rate", min_value = 1e-7, max_value = 1e-2, sampling="log")

    embedding_layer = Dense(d_model, kernel_initializer = "glorot_uniform", bias_initializer = "zeros")
    batch_size = 32
    num_epochs = 25
    max_seq_len = 16
    warmup_epochs = 3
    

    
    transformer_model = Transformer(
        embedding_layer = embedding_layer, 
        d_model = d_model,
        max_seq_len = max_seq_len,
        num_heads = num_heads,
        num_layers = num_layers,
        d_ff = d_ff,
        rate = dropout_rate
    )


        # Calculate steps based on your data
    # IMPORTANT: Use the actual length of your training data for this calculation
    steps_per_epoch = len(x_train) // batch_size
    warmup_steps = warmup_epochs * steps_per_epoch
    decay_steps = (num_epochs - warmup_epochs) * steps_per_epoch
    
    # Create an instance of our new scheduler
    lr_schedule = WarmupCosineDecay(
        peak_lr=peak_lr,
        warmup_steps=warmup_steps,
        decay_steps=decay_steps,
        alpha=0.1 # This means the LR will decay to 10% of peak_lr
    )

    transformer_model.compile(
        optimizer=tf.keras.optimizers.AdamW(
            learning_rate=lr_schedule,
            weight_decay = 4e-3,
            beta_1=0.85,  
            beta_2=0.999,  # Primary recommendation: lower this
            clipnorm=1.0
        ),
        loss='mse'
    )
    return transformer_model

build_model(keras_tuner.HyperParameters())
# Out:
# <Transformer name=transformer, built=False>

# %%
tuner = keras_tuner.BayesianOptimization(
    hypermodel=build_model,
    objective="val_loss",
    max_trials=50,
    executions_per_trial=1,
    overwrite=False
)
# Out:
# Reloading Tuner from ./untitled_project/tuner0.json

# %%
num_epochs = 25
batch_size = 32

train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(len(x_train)).batch(batch_size)
val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val)).batch(batch_size)

tuner.search(train_dataset, epochs = num_epochs, validation_data = (val_dataset), verbose = 0, callbacks = [early_stopping])

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in ./untitled_project
# Showing 10 best trials
# Objective(name="val_loss", direction="min")
#
# Trial 23 summary
# Hyperparameters:
# num_heads: 8
# d_model: 32
# num_layers: 3
# d_ff: 128
# dropout: False
# peak learning rate: 0.0014188984633416947
# Score: 0.13932304084300995
#
# Trial 04 summary
# Hyperparameters:
# num_heads: 2
# d_model: 64
# num_layers: 4
# d_ff: 512
# dropout: False
# peak learning rate: 0.00023727638415800082
# Score: 0.5695855617523193
#
# Trial 19 summary
# Hyperparameters:
# num_heads: 2
# d_model: 64
# num_layers: 4
# d_ff: 512
# dropout: False
# peak learning rate: 0.00017753963838400855
# Score: 1.641616940498352
#
# Trial 42 summary
# Hyperparameters:
# num_heads: 4
# d_model: 128
# num_layers: 3
# d_ff: 512
# dropout: False
# peak learning rate: 0.0004034381760009418
# Score: 6.7436699867248535
#
# Trial 20 summary
# Hyperparameters:
# num_heads: 2
# d_model: 64
# num_layers: 4
# d_ff: 512
# dropout: False
# peak learning rate: 0.0002221139550977517
# Score: 7.766565322875977
#
# Trial 06 summary
# Hyperparameters:
# num_heads: 2
# d_model: 32
# num_layers: 2
# d_ff: 256
# dropout: False
# peak learning rate: 0.0018620036258997228
# Score: 10.484166145324707
#
# Trial 07 summary
# Hyperparameters:
# num_heads: 2
# d_model: 64
# num_layers: 5
# d_ff: 256
# dropout: False
# peak learning rate: 6.836644645712527e-05
# Score: 10.627899169921875
#
# Trial 18 summary
# Hyperparameters:
# num_heads: 2
# d_model: 64
# num_layers: 4
# d_ff: 512
# dropout: False
# peak learning rate: 0.0006572830203098331
# Score: 11.503336906433105
#
# Trial 38 summary
# Hyperparameters:
# num_heads: 8
# d_model: 64
# num_layers: 6
# d_ff: 512
# dropout: False
# peak learning rate: 7.544146171497126e-06
# Score: 15.012101173400879
#
# Trial 47 summary
# Hyperparameters:
# num_heads: 2
# d_model: 32
# num_layers: 3
# d_ff: 512
# dropout: False
# peak learning rate: 0.0017666057033955919
# Score: 15.705245018005371

# %%
# Get the best hyperparameters
best_hps = tuner.get_best_hyperparameters()[0]

# %%
def build_best_model(hp, num_epochs):
    # A smaller configuration to reduce overfitting
    # Ensure compatibility
    num_heads = hp.Choice('num_heads', [2, 4, 8])  # Powers of 2 work well
    d_model = hp.Choice('d_model', [32, 64, 128])   # Also powers of 2
    # This guarantees d_model % num_heads == 0
    num_layers = hp.Int('num_layers', 2, 6)
    d_ff = hp.Choice('d_ff', [64, 128, 256, 512])   # Multiples that work well
    if hp.Boolean("dropout"):
        dropout_rate = 0.2 
    else: 
        dropout_rate = 0
    peak_lr = hp.Float("peak learning rate", min_value = 1e-7, max_value = 1e-2, sampling="log")

    embedding_layer = Dense(d_model, kernel_initializer = "glorot_uniform", bias_initializer = "zeros")
    batch_size = 32
    num_epochs = num_epochs
    max_seq_len = 16
    warmup_epochs = np.floor(num_epochs/10) + 1
    

    
    transformer_model = Transformer(
        embedding_layer = embedding_layer, 
        d_model = d_model,
        max_seq_len = max_seq_len,
        num_heads = num_heads,
        num_layers = num_layers,
        d_ff = d_ff,
        rate = dropout_rate
    )


        # Calculate steps based on your data
    # IMPORTANT: Use the actual length of your training data for this calculation
    steps_per_epoch = len(x_train) // batch_size
    warmup_steps = warmup_epochs * steps_per_epoch
    decay_steps = (num_epochs - warmup_epochs) * steps_per_epoch
    
    # Create an instance of our new scheduler
    lr_schedule = WarmupCosineDecay(
        peak_lr=peak_lr,
        warmup_steps=warmup_steps,
        decay_steps=decay_steps,
        alpha=0.1 # This means the LR will decay to 10% of peak_lr
    )
    return transformer_model, lr_schedule
num_epochs_best_model = 200

# %%
from FNN1_1 import baseline_deviation, baeline_out_deviation, baseline_long_deviation, baseline_relError, absSum
baseline_out_deviation = baeline_out_deviation
from GetXY import x_test, y_test, out_x_test, out_y_test, long_x_test, long_y_test, outsideExpr, absSum
# Out:
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1762599105.297426    5263 service.cc:145] XLA service 0xfffe60006ea0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1762599105.297517    5263 service.cc:153]   StreamExecutor device (0): Orin, Compute Capability 8.7
# 2025-11-08 11:51:45.698132: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-11-08 11:51:46.134854: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 90300
# 22/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 31.7824
# I0000 00:00:1762599107.126688    5263 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - loss: 24.4176 - val_loss: 17.0296
# Epoch 2/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.0021 - val_loss: 14.7856
# Epoch 3/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.2765 - val_loss: 13.5120
# Epoch 4/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.6080 - val_loss: 11.6603
# Epoch 5/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.2782 - val_loss: 9.1863
# Epoch 6/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.4618 - val_loss: 6.4935
# Epoch 7/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5697 - val_loss: 3.9146
# Epoch 8/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2058 - val_loss: 2.1535
# Epoch 9/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7830 - val_loss: 1.2649
# Epoch 10/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1619 - val_loss: 0.9502
# Epoch 11/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9166 - val_loss: 0.8141
# Epoch 12/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.
50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0583 - val_loss: 0.0850
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0553 - val_loss: 0.0818
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0528 - val_loss: 0.0796
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0504 - val_loss: 0.0770
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0483 - val_loss: 0.0751
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0462 - val_loss: 0.0736
# Epoch 44/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0444 - val_loss: 0.0718
# Epoch 45/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0427 - val_loss: 0.0703
# Epoch 46/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0412 - val_loss: 0.0691
# Epoch 47/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0396 - val_loss: 0.0677
# Epoch 48/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0383 - val_loss: 0.0668
# Epoch 49/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0372 - val_loss: 0.0659
# Epoch 50/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0360 - val_loss: 0.0651
# /home/capybara/Desktop/matura_project_python/github/matura/FNN1_1.py:246: RuntimeWarning: divide by zero encountered in divide
#   relativeError = np.where(np.array(y_test) != 0, deviation.flatten() / np.abs(np.array(y_test)), deviation.flatten())

# %%
pad_value = 15
x_test = np.pad(x_test, ((0, 0), (1, 0)), 'constant', constant_values=pad_value)
out_x_test = np.pad(out_x_test, ((0, 0), (1, 0)), 'constant', constant_values=pad_value)
long_x_test = np.pad(long_x_test, ((0, 0), (1, 0)), 'constant', constant_values=pad_value)

x_test_dataset = tf.data.Dataset.from_tensor_slices(x_test).batch(batch_size)
out_x_test_dataset = tf.data.Dataset.from_tensor_slices(out_x_test).batch(batch_size)
long_x_test_dataset = tf.data.Dataset.from_tensor_slices(long_x_test).batch(batch_size)

# %%
#debuggng: 
# Add a custom callback to track the best epoch
class BestEpochTracker(tf.keras.callbacks.Callback):
    def __init__(self):
        self.best_val_loss = float('inf')
        self.best_epoch = 0
        
    def on_epoch_end(self, epoch, logs=None):
        val_loss = logs.get('val_loss')
        if val_loss is not None and val_loss < self.best_val_loss:
            self.best_val_loss = val_loss
            self.best_epoch = epoch + 1
            print(f"New best validation loss: {val_loss:.4f} at epoch {self.best_epoch}")

best_tracker = BestEpochTracker()

# %%
n_bootstrap = 1
count = 0
bootstrap_predsInRange = []
bootstrap_predsOutRange = []
bootstrap_predsLongRange = []

for i in range(n_bootstrap):
    early_stopping = tf.keras.callbacks.EarlyStopping(
        patience=20,
        min_delta=0.001,
        restore_best_weights=True,
        monitor='val_loss',
        mode="min", 
        verbose=1
    )
    tf.random.set_seed(i * 12345)  # Different seed each iteration
    best_model, lr_schedule = build_best_model(best_hps, num_epochs_best_model)
    best_model.compile(
        optimizer=tf.keras.optimizers.AdamW(
            learning_rate=lr_schedule,
            weight_decay = 4e-3,
            beta_1=0.85,  
            beta_2=0.999,  # Primary recommendation: lower this
            clipnorm=1.0
        ),
        loss='mse',
        metrics=['mse']
    )
    best_model.fit(
        train_dataset, # Pass the TensorFlow Dataset
        validation_data=val_dataset, # Pass the TensorFlow Dataset
        epochs=num_epochs_best_model,
        callbacks=[early_stopping, best_tracker],
        verbose = 1
    )
    
    bootstrap_predsInRange.append(best_model.predict(x_test_dataset))
    bootstrap_predsOutRange.append(best_model.predict(out_x_test_dataset))
    bootstrap_predsLongRange.append(best_model.predict(long_x_test_dataset))
    print(f"Done: {count}")
    count += 1

bootstrap_predsInRange = np.array(bootstrap_predsInRange)
bootstrap_predsOutRange = np.array(bootstrap_predsOutRange)
bootstrap_predsLongRange = np.array(bootstrap_predsLongRange)
# Out:
# Epoch 1/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.8889 - mse: 3.8889 - val_loss: 4.0506 - val_mse: 4.0506
# Epoch 23/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.9264 - mse: 5.9264 - val_loss: 3.6690 - val_mse: 3.6690
# Epoch 24/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.2289 - mse: 4.2289New best validation loss: 3.0866 at epoch 24
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.4986 - mse: 4.4986 - val_loss: 3.0866 - val_mse: 3.0866
# Epoch 25/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.4912 - mse: 4.4912 - val_loss: 3.8910 - val_mse: 3.8910
# Epoch 26/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.1388 - mse: 5.1388New best validation loss: 1.9434 at epoch 26
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.0144 - mse: 5.0144 - val_loss: 1.9434 - val_mse: 1.9434
# Epoch 27/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.5548 - mse: 4.5548New best validation loss: 1.9166 at epoch 27
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.8810 - mse: 3.8810 - val_loss: 1.9166 - val_mse: 1.9166
# Epoch 28/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.3621 - mse: 1.3621New best validation loss: 1.2073 at epoch 28
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.4923 - mse: 1.4923 - val_loss: 1.2073 - val_mse: 1.2073
# Epoch 29/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.3550 - mse: 2.3550 - val_loss: 1.6587 - val_mse: 1.6587
# Epoch 30/200
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.3032 - mse: 1.3032New best validation loss: 0.8496 at epoch 30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.1669 - mse: 1.1669 - val_loss: 0.8496 - val_mse: 0.8496
# Epoch 31/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.3996 - mse: 1.3996 - val_loss: 1.6316 - val_mse: 1.6316
# Epoch 32/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.0016 - mse: 3.0016New best validation loss: 0.5038 at epoch 32
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.9977 - mse: 3.9977 - val_loss: 0.5038 - val_mse: 0.5038
# Epoch 33/200
# 57/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.8062 - mse: 0.8062New best validation loss: 0.4032 at epoch 33
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.8075 - mse: 0.8075 - val_loss: 0.4032 - val_mse: 0.4032
# Epoch 34/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6849 - mse: 1.6849 - val_loss: 1.5698 - val_mse: 1.5698
# Epoch 35/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.8007 - mse: 0.8007 - val_loss: 0.5840 - val_mse: 0.5840
# Epoch 36/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.6421 - mse: 0.6421 - val_loss: 8.4801 - val_mse: 8.4801
# Epoch 37/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.2527 - mse: 2.2527New best validation loss: 0.3246 at epoch 37
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.0781 - mse: 1.0781 - val_loss: 0.3246 - val_mse: 0.3246
# Epoch 38/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.4881 - mse: 0.4881 - val_loss: 0.4718 - val_mse: 0.4718
# Epoch 39/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.4786 - mse: 1.4786 - val_loss: 0.4427 - val_mse: 0.4427
# Epoch 40/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.8456 - mse: 0.8456New best validation loss: 0.3060 at epoch 40
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.6083 - mse: 0.6083 - val_loss: 0.3060 - val_mse: 0.3060
# Epoch 41/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.6304 - mse: 0.6304 - val_loss: 0.5164 - val_mse: 0.5164
# Epoch 42/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.3365 - mse: 0.3365 - val_loss: 0.4877 - val_mse: 0.4877
# Epoch 43/200
# 57/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4502 - mse: 0.4502New best validation loss: 0.1973 at epoch 43
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.4541 - mse: 0.4541 - val_loss: 0.1973 - val_mse: 0.1973
# Epoch 44/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.3017 - mse: 0.3017 - val_loss: 0.4949 - val_mse: 0.4949
# Epoch 45/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.8158 - mse: 0.8158 - val_loss: 0.3868 - val_mse: 0.3868
# Epoch 46/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2643 - mse: 0.2643 - val_loss: 0.3217 - val_mse: 0.3217
# Epoch 47/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.3233 - mse: 0.3233 - val_loss: 0.2317 - val_mse: 0.2317
# Epoch 48/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1776 - mse: 0.1776New best validation loss: 0.1610 at epoch 48
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1872 - mse: 0.1872 - val_loss: 0.1610 - val_mse: 0.1610
# Epoch 49/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.9432 - mse: 0.9432 - val_loss: 0.3633 - val_mse: 0.3633
# Epoch 50/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.3293 - mse: 0.3293 - val_loss: 0.1859 - val_mse: 0.1859
# Epoch 51/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5687 - mse: 1.5687 - val_loss: 1.9262 - val_mse: 1.9262
# Epoch 52/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.8673 - mse: 0.8673New best validation loss: 0.1050 at epoch 52
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.4560 - mse: 0.4560 - val_loss: 0.1050 - val_mse: 0.1050
# Epoch 53/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1320 - mse: 0.1320 - val_loss: 0.1343 - val_mse: 0.1343
# Epoch 54/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1747 - mse: 0.1747 - val_loss: 0.2535 - val_mse: 0.2535
# Epoch 55/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2336 - mse: 0.2336 - val_loss: 0.3065 - val_mse: 0.3065
# Epoch 56/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1365 - mse: 0.1365 - val_loss: 0.1055 - val_mse: 0.1055
# Epoch 57/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1011 - mse: 0.1011New best validation loss: 0.0620 at epoch 57
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1068 - mse: 0.1068 - val_loss: 0.0620 - val_mse: 0.0620
# Epoch 58/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0863 - mse: 0.0863New best validation loss: 0.0534 at epoch 58
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0951 - mse: 0.0951 - val_loss: 0.0534 - val_mse: 0.0534
# Epoch 59/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0781 - mse: 0.0781 - val_loss: 0.1652 - val_mse: 0.1652
# Epoch 60/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1317 - mse: 0.1317 - val_loss: 0.0758 - val_mse: 0.0758
# Epoch 61/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1789 - mse: 0.1789 - val_loss: 0.0775 - val_mse: 0.0775
# Epoch 62/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1587 - mse: 0.1587 - val_loss: 0.1321 - val_mse: 0.1321
# Epoch 63/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.0875 - mse: 1.0875New best validation loss: 0.0430 at epoch 63
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5621 - mse: 0.5621 - val_loss: 0.0430 - val_mse: 0.0430
# Epoch 64/200
# 57/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0545 - mse: 0.0545New best validation loss: 0.0274 at epoch 64
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0437 - mse: 0.0437 - val_loss: 0.0274 - val_mse: 0.0274
# Epoch 65/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0613 - mse: 0.0613 - val_loss: 0.0431 - val_mse: 0.0431
# Epoch 66/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0620 - mse: 0.0620 - val_loss: 0.0375 - val_mse: 0.0375
# Epoch 67/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0474 - mse: 0.0474 - val_loss: 0.0484 - val_mse: 0.0484
# Epoch 68/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0450 - mse: 0.0450 - val_loss: 0.0501 - val_mse: 0.0501
# Epoch 69/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0420 - mse: 0.0420 - val_loss: 0.0800 - val_mse: 0.0800
# Epoch 70/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0672 - mse: 0.0672 - val_loss: 0.0446 - val_mse: 0.0446
# Epoch 71/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0460 - mse: 0.0460 - val_loss: 0.0467 - val_mse: 0.0467
# Epoch 72/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0311 - mse: 0.0311New best validation loss: 0.0265 at epoch 72
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0301 - mse: 0.0301 - val_loss: 0.0265 - val_mse: 0.0265
# Epoch 73/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0530 - mse: 0.0530 - val_loss: 0.0542 - val_mse: 0.0542
# Epoch 74/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0473 - mse: 0.0473New best validation loss: 0.0237 at epoch 74
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0385 - mse: 0.0385 - val_loss: 0.0237 - val_mse: 0.0237
# Epoch 75/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0556 - mse: 0.0556 - val_loss: 0.0356 - val_mse: 0.0356
# Epoch 76/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0428 - mse: 0.0428 - val_loss: 0.0774 - val_mse: 0.0774
# Epoch 77/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0436 - mse: 0.0436 - val_loss: 0.0481 - val_mse: 0.0481
# Epoch 78/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0268 - mse: 0.0268 - val_loss: 0.0474 - val_mse: 0.0474
# Epoch 79/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0321 - mse: 0.0321 - val_loss: 0.0680 - val_mse: 0.0680
# Epoch 80/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0385 - mse: 0.0385 - val_loss: 0.0444 - val_mse: 0.0444
# Epoch 81/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0212 - mse: 0.0212 - val_loss: 0.0305 - val_mse: 0.0305
# Epoch 82/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0240 - mse: 0.0240 - val_loss: 0.0581 - val_mse: 0.0581
# Epoch 83/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0613 - mse: 0.0613 - val_loss: 0.0596 - val_mse: 0.0596
# Epoch 84/200
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0419 - mse: 0.0419New best validation loss: 0.0142 at epoch 84
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0299 - mse: 0.0299 - val_loss: 0.0142 - val_mse: 0.0142
# Epoch 85/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0188 - val_mse: 0.0188
# Epoch 86/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0374 - mse: 0.0374 - val_loss: 0.0345 - val_mse: 0.0345
# Epoch 87/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0187 - mse: 0.0187 - val_loss: 0.0308 - val_mse: 0.0308
# Epoch 88/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0212 - mse: 0.0212 - val_loss: 0.0236 - val_mse: 0.0236
# Epoch 89/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0251 - mse: 0.0251 - val_loss: 0.0206 - val_mse: 0.0206
# Epoch 90/200
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0138 - mse: 0.0138New best validation loss: 0.0114 at epoch 90
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 91/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0177 - mse: 0.0177 - val_loss: 0.0225 - val_mse: 0.0225
# Epoch 92/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0171 - mse: 0.0171 - val_loss: 0.0150 - val_mse: 0.0150
# Epoch 93/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0196 - val_mse: 0.0196
# Epoch 94/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0210 - mse: 0.0210 - val_loss: 0.0226 - val_mse: 0.0226
# Epoch 95/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0210 - mse: 0.0210 - val_loss: 0.0159 - val_mse: 0.0159
# Epoch 96/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0190 - mse: 0.0190 - val_loss: 0.0320 - val_mse: 0.0320
# Epoch 97/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0186 - mse: 0.0186 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 98/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0234 - val_mse: 0.0234
# Epoch 99/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0166 - mse: 0.0166 - val_loss: 0.0194 - val_mse: 0.0194
# Epoch 100/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0137 - mse: 0.0137New best validation loss: 0.0093 at epoch 100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 101/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0179 - val_mse: 0.0179
# Epoch 102/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0143 - mse: 0.0143 - val_loss: 0.0164 - val_mse: 0.0164
# Epoch 103/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0101 - mse: 0.0101New best validation loss: 0.0079 at epoch 103
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 104/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0201 - val_mse: 0.0201
# Epoch 105/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0089 - val_mse: 0.0089
# Epoch 106/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 107/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 108/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0236 - mse: 0.0236 - val_loss: 0.0149 - val_mse: 0.0149
# Epoch 109/200
# 57/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0115 - mse: 0.0115New best validation loss: 0.0074 at epoch 109
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 110/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0196 - val_mse: 0.0196
# Epoch 111/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0150 - val_mse: 0.0150
# Epoch 112/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0086 - val_mse: 0.0086
# Epoch 113/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 114/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0099 - mse: 0.0099New best validation loss: 0.0064 at epoch 114
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 115/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0216 - val_mse: 0.0216
# Epoch 116/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 117/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 118/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0055 - mse: 0.0055New best validation loss: 0.0057 at epoch 118
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 119/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0057 - mse: 0.0057New best validation loss: 0.0056 at epoch 119
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 120/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 121/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 122/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 123/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0089 - val_mse: 0.0089
# Epoch 124/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0077 - mse: 0.0077New best validation loss: 0.0055 at epoch 124
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 125/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 126/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0025 - mse: 0.0025New best validation loss: 0.0049 at epoch 126
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 127/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 128/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0086 - val_mse: 0.0086
# Epoch 129/200
# 57/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0044 - mse: 0.0044New best validation loss: 0.0042 at epoch 129
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 130/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 131/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 132/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 133/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 134/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 135/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 136/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 137/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 138/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 139/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 140/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0027 - mse: 0.0027New best validation loss: 0.0041 at epoch 140
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 141/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0026 - mse: 0.0026New best validation loss: 0.0039 at epoch 141
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 142/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 143/200
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0023 - mse: 0.0023New best validation loss: 0.0035 at epoch 143
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 144/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 145/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 146/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 147/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 148/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 149/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0020 - mse: 0.0020New best validation loss: 0.0034 at epoch 149
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 150/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 151/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0024 - mse: 0.0024New best validation loss: 0.0031 at epoch 151
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 152/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 153/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 154/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 155/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0014 - mse: 0.0014New best validation loss: 0.0028 at epoch 155
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 156/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 157/200
# 57/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0016 - mse: 0.0016New best validation loss: 0.0028 at epoch 157
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 158/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.1780e-04 - mse: 9.1780e-04 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 159/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.8756e-04 - mse: 8.8756e-04 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 160/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.3097e-04 - mse: 8.3097e-04New best validation loss: 0.0027 at epoch 160
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.1566e-04 - mse: 9.1566e-04 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 161/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 162/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 163/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 164/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.3171e-04 - mse: 8.3171e-04 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 165/200
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.3445e-04 - mse: 8.3445e-04New best validation loss: 0.0024 at epoch 165
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.9066e-04 - mse: 7.9066e-04 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 166/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.6610e-04 - mse: 8.6610e-04 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 167/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.1480e-04 - mse: 8.1480e-04 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 168/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 169/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.9602e-04 - mse: 6.9602e-04 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 170/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.6878e-04 - mse: 7.6878e-04 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 171/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.4963e-04 - mse: 6.4963e-04 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 172/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.6091e-04 - mse: 7.6091e-04 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 173/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.3397e-04 - mse: 8.3397e-04 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 174/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.4448e-04 - mse: 8.4448e-04 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 175/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 175: early stopping
# Restoring model weights from the end of the best epoch: 155.
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step
# Done: 0

# %%
best_model.summary()
# Out:
# Model: "transformer_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_17 (Dense)                │ (None, 16, 32)         │            64 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoder_1 (Encoder)             │ ?                      │        38,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_36 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 114,628 (447.77 KB)
#  Trainable params: 38,209 (149.25 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 76,419 (298.52 KB)

# %%
bootstrap_predsInRange.shape
# Out:
# (1, 1457, 1)

# %%
predsInRange = []
predsOutRange = []
predsLongRange = []

for i in range(len(x_test)):
    counter = 0
    for j in range(n_bootstrap):
        counter += bootstrap_predsInRange[j][i]
    predsInRange.append(counter/n_bootstrap)

for i in range(len(out_x_test)):
    counter = 0
    for j in range(n_bootstrap):
        counter += bootstrap_predsOutRange[j][i]
    predsOutRange.append(counter/n_bootstrap)

for i in range(len(long_x_test)):
    counter = 0
    for j in range(n_bootstrap):
        counter += bootstrap_predsLongRange[j][i]
    predsLongRange.append(counter/n_bootstrap)

# %%
reldiffInRange = []
diffInRange = []
safe_y_test = np.where(np.isclose(y_test,0.0), 1.0, y_test)

for i in range(len(y_test)):
    diffInRange.append(abs(y_test[i] - predsInRange[i]))
    reldiffInRange.append(abs(y_test[i] - predsInRange[i])/abs(safe_y_test[i]))
print(len(diffInRange))
print("MAE in Range: ", np.mean(diffInRange))
print("MRE in Range: ", np.mean(reldiffInRange))

diffLongRange = []
for i in range(200, 300):
    diffLongRange.append(np.array(np.abs(long_y_test[i]) - np.array(predsLongRange[i])))
    
NEEDdiffLongRange = []
for i in range(len(long_y_test)):
    NEEDdiffLongRange.append(np.array(np.abs(long_y_test[i]) - np.array(predsLongRange[i])))
print("MAE longer Expressions: ", np.mean(NEEDdiffLongRange))

diffOutRange = []
for i in range(len(out_y_test)):
    diffOutRange.append(abs(out_y_test[i] - predsOutRange[i]))
safe_out_y_test = np.where(out_y_test == 0, 1, out_y_test)
diff_out_relError = []
for i in range(len(out_y_test)):
    diff_out_relError.append(abs(diffOutRange[i] / safe_out_y_test[i]))
print("MAE out Range: ", np.mean(diffOutRange))
print("MRE out Range: ", np.mean(diff_out_relError))
# Out:
# 1457
# MAE in Range:  0.036552027
# MRE in Range:  0.014989576
# MAE longer Expressions:  6.2091036
# MAE out Range:  4.580289
# MRE out Range:  0.5045825

# %%
placeholder = absSum(outsideExpr)
diffOutRange = []
indices_with_placeholder_22 = [i for i, val in enumerate(placeholder) if val == 22] 

for i in indices_with_placeholder_22:
    diffOutRange.append(np.abs(out_y_test[i]-predsOutRange[i]))

# %%
meanDiff_InRange = np.mean(diffInRange)
meanDiff_OutRange = np.mean(diffOutRange)
meanDiff_LongRange = np.mean(diffLongRange)
meanDiff_OutRelRange = np.mean(diff_out_relError)

# %%
benchmark = 0
benchmark += baseline_deviation / (meanDiff_InRange**2) / 4
print(baseline_deviation / (meanDiff_InRange**2) / 4)

benchmark += baseline_out_deviation / (meanDiff_OutRange**2) / 4
print(baseline_out_deviation / (meanDiff_OutRange**2) / 4)

benchmark += baseline_long_deviation / (meanDiff_LongRange**2) / 4
print(baseline_long_deviation / (meanDiff_LongRange**2) / 4)

benchmark += baseline_relError / (meanDiff_OutRelRange**2) / 4
print(baseline_relError / (meanDiff_OutRelRange**2) / 4)

print(f"Benchmark: {benchmark}")
# Out:
# 6.453134368370181
# 0.058549262990042414
# 0.1977775768713034
# 0.03176417999292401
# Benchmark: 6.74122538822445
