# %%
import numpy as np
np.random.seed(42)

x1 = np.random.rand(4000)*10
x2 = np.random.rand(4000)*10
x3 = np.random.rand(4000)*10

x1_int = x1.astype(int) - 5
x2_int = x2.astype(int) - 5
x3_int = x3.astype(int) - 5

x1_str = x1_int.astype(str)
x2_str = x2_int.astype(str)
x3_str = x3_int.astype(str)

unique_expressions = set()

for i in range(len(x1)):
  n = np.random.rand(1)
  if n < 0.25:
    opp1 = " + "
    opp2 = " + "
  elif n > 0.25 and n < 0.5:
    opp1 = " + "
    opp2 = " - "
  elif n > 0.75:
    opp1 = " - "
    opp2 = " + "
  else:
    opp1 = " - "
    opp2 = " - "
  unique_expressions.add(x1_str[i] + opp1 + x2_str[i] + opp2 + x3_str[i])

x = list(unique_expressions) # Convert the set back to a list
print(x)
print(len(x))
diff_x = x
# Out:
# ['-1 - 0 - -3', '0 + -3 - -5', '-3 - 1 + -1', '1 + -1 - -3', '0 + -5 - -1', '-4 + -2 - 2', '1 - -1 - -4', '2 - 3 - 0', '1 - 3 - -5', '0 + 0 - 2', '3 - -4 + 0', '0 + 1 - -2', '2 + 0 + 2', '0 + 4 + 2', '4 - -3 - -3', '3 + 0 + -1', '1 - -1 - 0', '-5 - -4 - -3', '-5 + 3 - -3', '-2 - -4 + -1', '2 - -3 - 3', '-1 + 0 + 1', '-2 - 0 - 4', '-2 + -3 - -2', '4 - 4 + 1', '2 - -1 - 2', '-1 + -3 - 3', '0 + 2 + 0', '-1 - 1 + 1', '-4 - -1 - 0', '3 + -2 + -3', '-5 + -5 - -3', '-4 - 4 + 3', '1 - -2 + 2', '-5 - -2 + 0', '3 - -1 - 4', '1 - 4 + -1', '-1 - -5 - 4', '-4 - 4 + 2', '3 - -2 + 1', '3 + -4 - -5', '-4 - 2 + 0', '3 - 3 + 2', '3 - 4 + -5', '-3 - 3 + 3', '0 + 4 + -5', '1 - 3 + 1', '-5 - -3 + -4', '-3 + -1 - 4', '4 - 0 - -3', '-4 + 1 + -3', '-2 - 3 - 4', '0 + 3 - -1', '0 - 2 + -2', '2 - 0 + 3', '2 + -4 + -4', '-3 - 4 + -2', '-4 - -2 - 4', '-2 - 4 + 4', '-4 + -5 - 0', '0 + 3 - 0', '4 + -5 - 2', '1 + 4 + 4', '-5 + -3 - -3', '0 - 4 - 4', '1 - -3 + -5', '0 - -4 + 3', '-1 + -4 - 3', '-4 - -2 - 2', '1 - -3 - -5', '4 + 4 - -1', '3 - 4 + 4', '3 - -5 + -5', '-3 + 1 + -4', '-1 + 0 - -3', '-1 + -1 + -4', '3 + 4 - -1', '0 + 2 - 4', '-5 + 2 - 3', '-5 + 3 + 2', '-2 + -4 + 1', '4 + -4 - -1', '2 + -2 - 0', '1 + 0 + 4', '2 - -5 + -4', '4 + 4 - 3', '0 - 3 - 2', '-2 + -5 + -2', '-4 + 3 - -5', '4 - -4 + 4', '2 - -5 + 0', '4 - 4 + -5', '3 + -5 + 1', '4 + 1 - 0', '0 - -1 + 3', '-2 + 0 + 2', '1 + 2 - -1', '0 - 1 + 1', '1 - 3 + 2', '-2 - -1 + 0', '0 + -2 + -5', '4 + 0 + 4', '-2 - 3 - 1', '2 - 3 - 4', '-3 - 0 - 3', '2 + 1 - -4', '-2 + 4 - -1', '3 - 3 - 4', '-3 - 0 - -2', '4 - 3 - -3', '-1 - 1 + 0', '3 + -3 + -3', '4 - -1 + -5', '-3 - 1 - 3', '-4 + -5 + 2', '-1 - -2 - -5', '-2 - 4 + 1', '-1 - 4 + -3', '-4 - 2 - -4', '1 + 0 + 2', '-5 - 1 - 0', '-1 + -5 - 3', '2 + -4 - 1', '3 - -5 - 3', '-2 - 0 - 1', '2 - -3 + 4', '-1 + -3 - 1', '-4 + 3 + -5', '3 - 3 + -3', '3 + 0 + -5', '0 + -1 + -3', '1 - 3 - 4', '1 + -5 - -1', '-4 - 0 + -2', '4 + -3 - -3', '0 - -4 - -1', '1 + -5 + -1', '4 + -4 - 0', '-4 - 0 + 3', '0 - -1 - 2', '3 + -4 - 2', '4 - 0 + 4', '-5 + 2 - -2', '2 + -5 + -5', '-3 - -2 - -2', '-1 - -1 + 4', '-1 - -5 + 0', '-5 - 4 - -2', '-3 - 1 - -5', '-3 - -4 - 3', '2 + 0 + 0', '4 + 0 + 3', '4 + -1 - -1', '-4 + 4 + 2', '2 + -5 + 2', '-4 + -4 + 1', '3 + 0 - -1', '-5 + 4 + 1', '-3 - -4 + 3', '1 + -1 + 0', '-3 + 1 - 4', '-3 + -4 - 1', '-2 + 3 - -4', '1 - -3 - 4', '-4 + -5 + -4', '-2 - 4 - 1', '-2 - -1 + -5', '4 + 3 + 2', '-3 - -3 + -2', '-2 + -2 + 4', '0 - 2 - 3', '3 - 2 + 2', '2 + 3 - 2', '0 + -1 + -4', '-2 + 3 - -1', '2 + 0 + -2', '1 + -3 + -1', '-3 - 3 - 0', '0 - 2 - -3', '1 - -4 - -1', '-3 - -5 + 2', '-2 + -3 + -4', '3 - 4 - -3', '-5 + -4 + -1', '-1 - -2 - 2', '0 + 1 - 0', '3 - -3 - -4', '1 + 3 + 0', '2 - 4 + 0', '-4 + -5 - 2', '-4 - 2 + 3', '0 - -2 + -2', '3 - -2 - 4', '1 + -2 + 2', '-4 - -5 - 3', '-1 + -3 + -4', '3 - -3 - -5', '4 - 2 - -2', '3 + -3 + -1', '-5 - 1 + 2', '-4 - -2 - -2', '-1 - 0 - 2', '-3 + 4 + 2', '-1 + -1 + -1', '2 + -3 + 3', '4 + -1 - 0', '2 - 4 - -1', '-2 + 1 + 3', '-2 + -1 + -5', '0 - 1 + -4', '2 + 2 + 3', '2 + -2 - -1', '1 + -1 - -4', '4 - 1 - -2', '3 + -1 - -3', '4 + -3 - -4', '4 - -5 - 0', '-4 - -5 + -3', '1 - 0 - -5', '-3 + -5 - -3', '3 + -1 + 2', '-4 - -4 - -3', '-3 + 0 + 0', '-1 - 1 + 2', '3 - 0 - -4', '-2 + 2 + 0', '-4 - -3 + -2', '-1 + -4 + -3', '1 - 1 - 1', '-3 + -2 - -2', '2 - -5 + 3', '-5 - -4 + -3', '-3 + -3 - 1', '1 - 2 - -4', '1 + -1 - -2', '-1 + 0 + -3', '-3 - 2 + 4', '3 + 1 + -1', '-4 + 2 - -5', '-2 - -2 + 0', '2 - -2 + 0', '1 - 1 - -4', '2 - -5 - 4', '-1 - 0 + -5', '-1 - 3 + -5', '-5 + 2 - 0', '-2 - 0 + -1', '-3 + -3 - 0', '-2 + 3 + -4', '0 - -1 + -3', '-4 - 3 - 1', '3 - -1 - -4', '3 - 4 - 4', '-2 - -2 + -1', '-4 + -1 - -2', '-4 + -2 + -5', '3 - 2 + -4', '2 - 2 - -3', '3 - 3 - -2', '4 + -4 - -5', '3 + 3 + -4', '-3 - -2 + 3', '-4 + -3 + -3', '4 - -1 + -4', '3 + -1 - -4', '3 - 1 - -5', '-4 + 1 - 4', '0 - 4 - -3', '-5 + 4 + 4', '-1 + 3 + -2', '-1 + -5 + -4', '-5 + -5 - 3', '4 - -5 + -4', '-5 - 4 - -1', '2 - -1 + -1', '4 - 1 - 0', '-5 - 3 + -3 ...
# 2543

# %%
y = []

for expression in x:
  result = float(eval(expression))
  y.append(result)

print(y)
diff_y = y
# Out:
# [2.0, 2.0, -5.0, 3.0, -4.0, -8.0, 6.0, -1.0, 3.0, -2.0, 7.0, 3.0, 4.0, 6.0, 10.0, 2.0, 2.0, 2.0, 1.0, 1.0, 2.0, 0.0, -6.0, -3.0, 1.0, 1.0, -7.0, 2.0, -1.0, -3.0, -2.0, -7.0, -5.0, 5.0, -3.0, 0.0, -4.0, 0.0, -6.0, 6.0, 4.0, -6.0, 2.0, -6.0, -3.0, -1.0, -1.0, -6.0, -8.0, 7.0, -6.0, -9.0, 4.0, -4.0, 5.0, -6.0, -9.0, -6.0, -2.0, -9.0, 3.0, -3.0, 9.0, -5.0, -8.0, -1.0, 7.0, -8.0, -4.0, 9.0, 9.0, 3.0, 3.0, -6.0, 2.0, -6.0, 8.0, -2.0, -6.0, 0.0, -5.0, 1.0, 0.0, 5.0, 3.0, 5.0, -5.0, -9.0, 4.0, 12.0, 7.0, -5.0, -1.0, 5.0, 4.0, 0.0, 4.0, 0.0, 0.0, -1.0, -7.0, 8.0, -6.0, -5.0, -6.0, 7.0, 3.0, -4.0, -1.0, 4.0, -2.0, -3.0, 0.0, -7.0, -7.0, 6.0, -5.0, -8.0, -2.0, 3.0, -6.0, -9.0, -3.0, 5.0, -3.0, 9.0, -5.0, -6.0, -3.0, -2.0, -4.0, -6.0, -3.0, -6.0, 4.0, 5.0, -5.0, 0.0, -1.0, -1.0, -3.0, 8.0, -1.0, -8.0, 1.0, 4.0, 4.0, -7.0, 1.0, -2.0, 2.0, 7.0, 4.0, 2.0, -1.0, -7.0, 4.0, 0.0, 4.0, 0.0, -6.0, -8.0, 5.0, 0.0, -13.0, -7.0, -6.0, 9.0, -2.0, 0.0, -5.0, 3.0, 3.0, -5.0, 2.0, 0.0, -3.0, -6.0, 1.0, 6.0, 4.0, -9.0, 2.0, -10.0, -1.0, 1.0, 10.0, 4.0, -2.0, -11.0, -3.0, 0.0, 1.0, 1.0, -2.0, -8.0, 11.0, 4.0, -1.0, -4.0, 0.0, -3.0, 3.0, -3.0, 2.0, 3.0, -1.0, 2.0, -8.0, -5.0, 7.0, 1.0, 4.0, 5.0, 5.0, 5.0, 9.0, -2.0, 6.0, -5.0, 4.0, 3.0, -3.0, 0.0, 7.0, 0.0, -3.0, -8.0, -1.0, -3.0, 10.0, -4.0, -7.0, 3.0, 2.0, -4.0, -1.0, 3.0, 3.0, 0.0, 4.0, 4.0, 3.0, -6.0, -9.0, -3.0, -3.0, -6.0, -3.0, -2.0, -8.0, 8.0, -5.0, -1.0, -3.0, -11.0, -3.0, 3.0, 2.0, 5.0, 2.0, 2.0, -10.0, 1.0, 6.0, 7.0, -7.0, -1.0, 3.0, 0.0, -10.0, -13.0, 5.0, -8.0, 2.0, 3.0, -11.0, 4.0, -5.0, -7.0, 1.0, -11.0, 9.0, 3.0, 1.0, -1.0, 0.0, -9.0, 7.0, -6.0, -10.0, 0.0, 3.0, -7.0, 1.0, -4.0, 3.0, -5.0, -2.0, -10.0, 1.0, -1.0, 3.0, -7.0, 4.0, -6.0, -5.0, 1.0, -6.0, -7.0, -5.0, 10.0, 8.0, -1.0, 6.0, 2.0, -1.0, -3.0, 0.0, 7.0, 7.0, -4.0, -2.0, 7.0, -2.0, -4.0, 1.0, -2.0, 3.0, 0.0, 8.0, -9.0, -2.0, 0.0, -1.0, -11.0, -15.0, -6.0, 8.0, 2.0, -6.0, -1.0, -5.0, 6.0, -2.0, 10.0, 1.0, -1.0, -5.0, -3.0, 4.0, 4.0, 1.0, -3.0, -8.0, 9.0, 0.0, 4.0, 6.0, -5.0, 3.0, -1.0, -1.0, 1.0, -2.0, 4.0, 2.0, 1.0, 2.0, 3.0, 0.0, 4.0, 0.0, -5.0, -3.0, -2.0, 1.0, 3.0, -8.0, 0.0, -5.0, -6.0, -5.0, 4.0, 1.0, -4.0, 1.0, 1.0, -11.0, 5.0, -3.0, -7.0, 2.0, 12.0, 1.0, -6.0, 0.0, -4.0, -6.0, -4.0, -9.0, -3.0, -4.0, -2.0, 3.0, -9.0, -5.0, 4.0, -6.0, 8.0, -2.0, 6.0, 4.0, 1.0, 6.0, -6.0, 2.0, 3.0, 0.0, 2.0, 4.0, 4.0, 4.0, -2.0, 1.0, -5.0, -1.0, -10.0, -3.0, 6.0, 5.0, -5.0, 11.0, -8.0, -4.0, -6.0, 5.0, 1.0, 0.0, -4.0, -2.0, 0.0, -5.0, -7.0, -3.0, -1.0, 2.0, 6.0, 3.0, -1.0, 6.0, 3.0, -7.0, -1.0, 10.0, -2.0, 2.0, 4.0, -6.0, -2.0, -6.0, 6.0, -2.0, 4.0, 8.0, -6.0, -5.0, 9.0, 1.0, -8.0, -2.0, 6.0, -2.0, -4.0, 11.0, 1.0, -3.0, -4.0, 7.0, -9.0, 2.0, 10.0, 6.0, 1.0, 2.0, 0.0, -4.0, -4.0, -4.0, -2.0, -4.0, 7.0, -7.0, 4.0, -4.0, 4.0, 4.0, -7.0, 1.0, 3.0, -2.0, -2.0, -6.0, 4.0, -7.0, 3.0, 5.0, -3.0, 2.0, -5.0, -4.0, -8.0, -2.0, -1.0, -4.0, 7.0, 0.0, 6.0, 1.0, 2.0, 7.0, -6.0, -5.0, 5.0, 0.0, -6.0, 7.0, -3.0, 11.0, -10.0, -2.0, 5.0, -2.0, 6.0, -4.0, 3.0, 5.0, -12.0, 0.0, 4.0, 2.0, -3.0, 6.0, -3.0, 2.0, -2.0, 2.0, 0.0, -5.0, 4.0, -2.0, 6.0, 1.0, -3.0, -2.0, -6.0, -5.0, 3.0, -6.0, 10.0, -1.0, 4.0, 0.0, 2.0, 1.0, 0.0, 4.0, 1.0, 10.0, -4.0, 3.0, 7.0, 0.0, 6.0, 5.0, 5.0, 5.0, 0.0, -3.0, -10.0, -6.0, 7.0, -6.0, -2.0, -1.0, -9.0, -3.0, -2.0, 3.0, -8.0, 12.0, -1.0, -5.0, 0.0, -3.0, -8.0, 6.0, 1.0, 2.0, 3.0, 2.0, 2.0, -13.0, -1.0, -4.0, 0.0, 4.0, -7.0, 6.0, 5.0, -7.0, -4.0, 0.0, 1.0, 6.0, -3.0, 0.0, 6.0, 4.0, 1.0, -1.0, -3.0, 0.0, -2.0, 1.0, -2.0, -2.0, -4.0, 2.0, -1.0, 2.0, 6.0, -4.0, -1.0, 2.0, 7.0, 6.0, -10.0, -8.0, -1.0, 3.0, 1.0, -1.0, -1.0, 2.0, -1.0, -9.0, -1.0, -2.0, 4.0, -1.0, 8.0, 10.0, 5.0, 8.0, 5.0, -4.0, 5.0, -2.0, 4.0, 2.0, -2.0, 9.0, 9.0, 2.0, 13.0, -5.0, -1.0, -2.0, 2.0, -2.0, 2.0, -6.0, 0.0, 0.0, -2.0, -6.0, -2.0, 5.0, -3.0, 5.0, 1.0, 5.0, -7.0, 3.0, 2.0, -5.0, -10.0, -1.0, 0.0, -3.0, -6.0, -6.0, 0.0, 9.0, -2.0, 10.0, -4.0, -1.0, -1.0, 5.0, -8.0, -1.0, -4.0, -6.0, -4.0, -3.0, 10.0, 1.0, -2.0, 3.0, -1.0, 3.0, 1.0, -4.0, 5.0, -4.0, -4.0, -7.0, -2.0, 10 ...

# %%
def tokenizer(input_list): # Changed parameter name to avoid confusion with global x
  #tokenizer by hand
  #tokens = (len(input_list), 5)
  # Create a copy of the input list to avoid modifying the original
  tokenized_x = [expression.split(" ") for expression in input_list]


  for i in range(len(tokenized_x)):
    for j in range(len(tokenized_x[i])):
      if j % 2 == 0:  # Check if the index is even
        tokenized_x[i][j] = np.float32(tokenized_x[i][j])
      else:  # The index is uneven, it's an operator
        if tokenized_x[i][j] == "+":
          tokenized_x[i][j] = np.float32(1)
        else:
          tokenized_x[i][j] = np.float32(0)
    padding_count = 15 - len(tokenized_x[i])
    for _ in range(padding_count): # Use a throwaway variable
      tokenized_x[i].append(np.float32(0.5))
  tokenized_x = np.array(tokenized_x)
  return tokenized_x
x = tokenizer(x)

# %%
from transformers import BertTokenizer

# Load a pre-trained BERT tokenizer (e.g., 'bert-base-uncased')
# 'uncased' means the model treats "Hello" and "hello" the same.
# For case-sensitive models, use 'bert-base-cased'.
BERTtokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# You can also use AutoTokenizer which automatically detects the correct tokenizer
# based on the model name. This is generally recommended.
# from transformers import AutoTokenizer
# tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')

BERTtokenizer.tokenize("1 + 2 + allo")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# ['1', '+', '2', '+', 'all', '##o']

# %%
'''
def posTokenizer(input_list):
    tokenized_x = [expression.split(" ") for expression in input_list]

    for i in range(len(tokenized_x)):
        for j in range(len(tokenized_x[i])):
            # Get the numerical value of the token
            token_value = 0.0 # Default
            if j % 2 == 0:  # Check if the index is even (number)
                token_value = np.float32(tokenized_x[i][j])
            else:  # The index is uneven (operator)
                if tokenized_x[i][j] == "+":
                    token_value = np.float32(1)
                else:
                    token_value = np.float32(0)

            # Now store it as a [value, position] pair
            tokenized_x[i][j] = np.array([token_value, np.float32(j)]) # Store as a 2-element array

        # Padding
        padding_count = 15 - len(tokenized_x[i])
        for _ in range(padding_count):
            # For padding, you might just want a consistent padding value
            # or a specific padding for value and position.
            # Here, we'll use 0.5 for value and 0.0 for position for padding.
            # Or you could encode the padding position if needed.
            tokenized_x[i].append(np.array([np.float32(0.5), np.float32(0.0)])) # Padding as [0.5, 0.0]

    # Convert the list of lists of arrays into a 3D NumPy array
    # e.g., (batch_size, sequence_length, 2)
    tokenized_x = np.array(tokenized_x)
    return tokenized_x
diff_x = posTokenizer(diff_x)
'''
# Out:
# '\ndef posTokenizer(input_list):\n    tokenized_x = [expression.split(" ") for expression in input_list]\n\n    for i in range(len(tokenized_x)):\n        for j in range(len(tokenized_x[i])):\n            # Get the numerical value of the token\n            token_value = 0.0 # Default\n            if j % 2 == 0:  # Check if the index is even (number)\n                token_value = np.float32(tokenized_x[i][j])\n            else:  # The index is uneven (operator)\n                if tokenized_x[i][j] == "+":\n                    token_value = np.float32(1)\n                else:\n                    token_value = np.float32(0)\n\n            # Now store it as a [value, position] pair\n            tokenized_x[i][j] = np.array([token_value, np.float32(j)]) # Store as a 2-element array\n\n        # Padding\n        padding_count = 15 - len(tokenized_x[i])\n        for _ in range(padding_count):\n            # For padding, you might just want a consistent padding value\n            # or a specific padding for value and position.\n            # Here, we\'ll use 0.5 for value and 0.0 for position for padding.\n            # Or you could encode the padding position if needed.\n            tokenized_x[i].append(np.array([np.float32(0.5), np.float32(0.0)])) # Padding as [0.5, 0.0]\n\n    # Convert the list of lists of arrays into a 3D NumPy array\n    # e.g., (batch_size, sequence_length, 2)\n    tokenized_x = np.array(tokenized_x)\n    return tokenized_x\ndiff_x = posTokenizer(diff_x)\n'

# %%
def posTokenizer(input_list): # Changed parameter name to avoid confusion with global x

  tokenized_x = [expression.split(" ") for expression in input_list]
  max_sequence_length = 15  # Define a max length for consistent padding and PE

  positionally_encoded_x = []

  for i in range(len(tokenized_x)):
      current_sequence = []
      for j in range(len(tokenized_x[i])):
          token_val = tokenized_x[i][j]
          if j % 2 == 0:  # Even index: number
              encoded_val = np.float32(token_val) # No change in value for numbers, only their position matters
          else:  # Uneven index: operator
              if token_val == "+":
                  encoded_val = np.float32(1)
              else:
                  encoded_val = np.float32(0)

          positional_component = np.sin(j / (10000**(0/1))) # Always 0 for even term, effectively sin(j)
          if j % 2 != 0:
              positional_component = np.cos(j / (10000**(0/1)))
          current_sequence.append([encoded_val, np.float32(positional_component)])



      # Padding
      padding_count = max_sequence_length - len(current_sequence)
      for _ in range(padding_count):
          # For padding, we can also add a positional encoding to the padding value (0.5)
          # or simply use 0.5 without further PE for padding.
          # Let's add PE to make it consistent
          padding_position = len(current_sequence) + _
          padding_positional_component = np.sin(padding_position / (10000**(0/1)))
          if padding_position % 2 != 0:
              padding_positional_component = np.cos(padding_position / (10000**(0/1)))

          current_sequence.append([np.float32(0.5), np.float32(padding_positional_component)])

      positionally_encoded_x.append(current_sequence)

  tokenized_x = np.array(positionally_encoded_x)
  return tokenized_x
print(diff_x[0])
diff_x = posTokenizer(diff_x)
print(diff_x[0])
# Out:
# -1 - 0 - -3
# [[-1.          0.        ]
#  [ 0.          0.5403023 ]
#  [ 0.          0.9092974 ]
#  [ 0.         -0.9899925 ]
#  [-3.         -0.7568025 ]
#  [ 0.5         0.2836622 ]
#  [ 0.5         0.75390226]
#  [ 0.5        -0.91113025]
#  [ 0.5         0.0044257 ]
#  [ 0.5         0.9074468 ]
#  [ 0.5        -0.7596879 ]
#  [ 0.5        -0.27516335]
#  [ 0.5         0.9887046 ]
#  [ 0.5        -0.54772925]
#  [ 0.5        -0.53283304]]

# %%
print(posTokenizer(["1 + 2 + 3"]).shape)
print(tokenizer(["1 + 2 + 3"]).shape)
# Out:
# (1, 15, 2)
# (1, 15)

# %%
# Generate all possible expressions
all_possible_expressions = set()
for num1 in range(-5, 5): # Range -5 to 4
    for num2 in range(-5, 5): # Range -5 to 4
        for num3 in range(-5, 5): # Range -5 to 4
            for op1 in [" + ", " - "]:
                for op2 in [" + ", " - "]:
                    expression = str(num1) + op1 + str(num2) + op2 + str(num3)
                    all_possible_expressions.add(expression)

# Find expressions not in x
expressions_not_in_x = all_possible_expressions - unique_expressions
expressions_not_in_x = list(expressions_not_in_x)
print("\nExpressions not in x:")
print(list(expressions_not_in_x)) # Convert back to a list for printing
if len(expressions_not_in_x)+len(x) == 4000: print(True)
print(len(expressions_not_in_x))
# Out:
# Expressions not in x:
# ['1 - 3 + 4', '2 + 4 - 1', '2 + 3 - 1', '4 + -3 + 4', '-4 - -4 - 4', '-5 + -3 + -3', '0 + -2 - 4', '-3 - -1 + 4', '4 + -4 + 4', '-4 - -4 + -4', '0 + -1 + -2', '-2 - -1 + 2', '-2 + -3 - -3', '2 - -2 - -4', '2 - -1 - -5', '-3 - 3 - -4', '4 - 1 - 4', '3 - 2 + 3', '-4 - -2 + 0', '-3 + 4 + -5', '2 - 3 - -3', '2 - 2 - 3', '3 + 2 + -5', '-2 + 3 + 1', '4 - -2 + 4', '2 + 3 - -2', '2 + -1 + 2', '1 - 0 + -2', '4 - -2 - 2', '4 + -3 + -2', '3 + -1 + 4', '-5 - -5 - -2', '4 - 2 + -4', '0 - -4 + -1', '4 + -2 + -2', '-3 - -3 + -5', '-2 - -2 + 2', '3 - -3 - -3', '1 + 1 + -5', '-1 + -4 + -2', '-1 - -3 - -4', '0 - -5 - 1', '-3 + -2 - 4', '0 - 4 + -3', '-4 - -2 - -5', '-1 - -1 - 0', '1 - 2 - -2', '4 + -2 + 4', '4 + 3 - -2', '0 + 0 - -2', '-3 + 0 - -5', '-1 - 2 + 1', '-4 + 0 + 1', '4 - 0 - 1', '0 + 4 - -1', '-1 + 1 - -2', '-5 + 2 - -5', '-4 - 2 - -1', '-4 - -3 + -4', '-4 + -1 - -3', '-5 + 0 + -2', '-4 + 0 + -2', '-3 + 0 + 2', '-5 + -2 - 1', '4 + 2 + 0', '0 - -2 + 3', '1 - -1 - -1', '-5 - 3 + -5', '-3 - 4 + -5', '-3 + -3 + -5', '3 + -3 - -4', '2 - 4 - 0', '-5 - -3 + 0', '1 - -4 - 1', '2 - 0 + -5', '0 - -1 - -5', '-5 + 1 + 2', '-5 - -5 - 2', '-2 + -5 - 2', '-1 - 0 - 4', '2 - -1 - 3', '-2 + -3 + 0', '-5 + 3 + 0', '0 - -3 + 0', '1 + -5 - 3', '1 - 1 - -1', '4 - -2 + -4', '2 - 2 - -4', '2 - 4 - 3', '-2 - 0 - 0', '-2 + -2 + 1', '-1 - 4 - -3', '0 + 2 + -3', '2 - 1 - 2', '-4 - -1 + -5', '-2 + 2 - 2', '-1 - 0 - -1', '4 - 1 - -3', '-5 + 1 - 0', '-4 - 0 - -1', '0 - -1 + 2', '0 + 4 + -4', '1 + 4 - 0', '2 + 0 - 3', '-2 + 3 + -5', '4 - 4 + -3', '0 - -1 - -1', '4 - 2 - -1', '2 - -2 + 2', '2 + 3 + 4', '1 + -5 + -5', '2 + -3 - 1', '0 + 0 - 4', '-2 + -3 + -2', '-1 - -2 - 3', '1 - -1 + -2', '3 - 0 + -3', '-3 - 0 - 0', '-4 + 4 + 1', '3 + 3 - -4', '0 - -2 - -4', '3 + 2 - 0', '1 + 3 + 4', '-4 + -1 + 0', '0 - 3 + -1', '-2 + 1 - 4', '-1 - 1 + -2', '1 + -2 - -2', '-3 + 4 - 3', '2 - -3 + -4', '-3 - 2 + -2', '-2 - -3 - 1', '-1 - -4 - -2', '2 + -5 - 4', '1 + 0 + -2', '1 + -5 - -2', '-5 - 4 + 2', '-5 - 2 - 4', '-3 - 4 + 0', '2 - 3 - -2', '-2 + 1 - -1', '-3 + -1 - 3', '2 + -5 + -4', '4 + -5 - -5', '-2 + 4 - -5', '-4 + 2 - 2', '-2 - -1 - -5', '4 + 1 - -4', '1 + 2 - -3', '-1 + 1 + 2', '-2 - 1 - 3', '3 + -4 - -4', '4 + 0 + -4', '-4 + 3 - -2', '-3 - 1 + 4', '0 + 0 + 1', '3 + 2 + 3', '-3 + -5 - -1', '-5 + -2 + -4', '-1 - -3 - -3', '2 + -3 + -5', '-1 + -5 - 1', '-5 + -4 + -5', '2 + 1 - 1', '-1 + 2 - 2', '2 + -5 - -5', '2 + -2 - -4', '2 - -2 - 3', '4 + 0 + 2', '0 + 0 + -5', '3 + -3 + -2', '1 + 2 - 0', '1 - 0 + 1', '-2 + 4 - 3', '-4 - 4 - 4', '-4 + 4 + -4', '3 - 3 + -1', '-4 - -4 - 3', '4 + -2 + 0', '4 + 1 + -4', '-4 + -2 + -3', '4 - 3 + 2', '-3 - 2 + 1', '-4 + 1 + -4', '-2 + -2 - -5', '-2 - 2 - 1', '-5 - 4 - 4', '0 - 4 - -2', '-2 + 3 - 1', '4 + -2 - -4', '1 + 2 + -5', '-3 - -2 + -4', '2 - 0 - 4', '2 - 0 - -5', '1 - -4 + -2', '-5 - 1 + -4', '2 - -2 - -2', '-5 + 0 + 1', '1 - -3 + -1', '0 + -2 + -3', '-4 - 3 - -1', '2 + 4 + -4', '4 - -4 - 3', '1 + 1 + 3', '-2 - -3 - -2', '2 - -5 + -1', '3 + 0 + -4', '-2 + -1 - -3', '-2 - 0 + 0', '2 + 1 - -5', '2 + 1 + -3', '-5 + -4 + 2', '0 + -5 + -4', '-3 + -5 + 0', '0 + 1 + 0', '-5 - -3 + -2', '-2 + -1 - 1', '-1 + -3 - 0', '-1 + 4 + -1', '-5 + 3 - -5', '2 + -3 + -1', '-5 - 0 + 2', '4 - 4 + 3', '3 - -4 + 1', '0 - -5 + -2', '4 - 0 - -4', '-4 + 4 + 3', '4 - -5 + -5', '-4 + 1 + -1', '-3 + 0 + 3', '4 - 1 - 2', '2 + -3 + 2', '-4 - 3 + -2', '2 - -4 - 0', '-4 + 2 + -5', '3 - -5 - 0', '-3 - -4 - -5', '-1 - 2 + -1', '3 + -1 + -2', '-1 - 2 + -2', '-4 - -1 + 4', '-5 + -2 - 4', '3 + -3 + -4', '-3 - 2 - -1', '1 - 0 + -3', '-5 + -2 + -1', '-2 + -1 + 0', '4 - -2 + 1', '-1 + -3 + 1', '1 - -5 - -5', '3 - 1 + -3', '1 - 3 - 2', '3 - 0 - 3', '1 + -3 + -2', '2 + 4 + -2', '-4 - -1 + -1', '-1 - 2 + -5', '-1 + -2 + -1', '-5 + 1 - -3', '1 - -5 + 1', '-4 + -2 - 3', '4 + -3 - 2', '4 + 2 - -3', '0 + -3 - -4', '1 - 2 + 2', '-4 - 4 - -1', '2 - -1 + -4', '2 - 1 + -5', '-4 + 0 - 4', '1 + 2 + 0', '3 + 2 + -2', '1 - -3 - 0', '-3 + -3 + 1', '1 - 0 - 3', '3 - 0 + 4', '-2 - -3 + 2', '4 - 1  ...
# True
# 1457

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers
from sklearn.model_selection import train_test_split
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.layers import PReLU

tf.random.set_seed(42)


x_train, x_val, y_train, y_val = \
    train_test_split(x, y, train_size=0.75)
x_train, x_val, y_train, y_val = \
    np.array(x_train), np.array(x_val), np.array(y_train), np.array(y_val)



model = keras.Sequential([
    keras.Input(shape=(len(x[0]),)),
    layers.Dense(30),
    PReLU(),
    layers.Dense(30),
    PReLU(),
    layers.Dense(1,  activation = "linear")
])

model.compile(optimizer = "adam", loss = "mse", metrics = ["mae", "mse"])

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
    monitor='mse'
)
# Convert numpy arrays to TensorFlow Datasets
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train)).batch(32) # Use a batch size, e.g., 32
val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val)).batch(32) # Use the same batch size


history = model.fit(
    train_dataset, # Pass the TensorFlow Dataset
    validation_data=val_dataset, # Pass the TensorFlow Dataset
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['mse', 'val_mse']].plot()
plt.xlabel("Epoch")
plt.ylabel("Mean Squared Error")
plt.title("Training and Validation MSE per Epoch")
plt.show()
# Out:
# Epoch 1/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 23.1816 - mae: 3.8767 - mse: 23.1816 - val_loss: 16.2905 - val_mae: 3.2680 - val_mse: 16.2905
# Epoch 2/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 16.3625 - mae: 3.3055 - mse: 16.3625 - val_loss: 14.9327 - val_mae: 3.1405 - val_mse: 14.9327
# Epoch 3/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 14.8705 - mae: 3.1420 - mse: 14.8705 - val_loss: 13.5051 - val_mae: 2.9752 - val_mse: 13.5051
# Epoch 4/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 13.2693 - mae: 2.9540 - mse: 13.2693 - val_loss: 11.3686 - val_mae: 2.7109 - val_mse: 11.3686
# Epoch 5/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 10.8448 - mae: 2.6534 - mse: 10.8448 - val_loss: 8.5571 - val_mae: 2.3315 - val_mse: 8.5571
# Epoch 6/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.7984 - mae: 2.2405 - mse: 7.7984 - val_loss: 5.5699 - val_mae: 1.8502 - val_mse: 5.5699
# Epoch 7/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.9058 - mae: 1.7569 - mse: 4.9058 - val_loss: 3.3050 - val_mae: 1.4096 - val_mse: 3.3050
# Epoch 8/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.8519 - mae: 1.3213 - mse: 2.8519 - val_loss: 1.9096 - val_mae: 1.0609 - val_mse: 1.9096
# Epoch 9/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.6538 - mae: 0.9978 - mse: 1.6538 - val_loss: 1.2089 - val_mae: 0.8407 - val_mse: 1.2089
# Epoch 10/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0967 - mae: 0.8123 - mse: 1.0967 - val_loss: 0.8807 - val_mae: 0.7156 - val_mse: 0.8807
# Epoch 11/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.8304 - mae: 0.7069 - mse: 0.8304 - val_loss: 0.7061 - val_mae: 0.6460 - val_mse: 0.7061
# Epoch 12/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6705 - mae: 0.6318 - mse: 0.6705 - val_loss: 0.5824 - val_mae: 0.5883 - val_mse: 0.5824
# Epoch 13/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5540 - mae: 0.5726 - mse: 0.5540 - val_loss: 0.4881 - val_mae: 0.5397 - val_mse: 0.4881
# Epoch 14/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4692 - mae: 0.5256 - mse: 0.4692 - val_loss: 0.4179 - val_mae: 0.5025 - val_mse: 0.4179
# Epoch 15/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4026 - mae: 0.4877 - mse: 0.4026 - val_loss: 0.3609 - val_mae: 0.4693 - val_mse: 0.3609
# Epoch 16/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3476 - mae: 0.4538 - mse: 0.3476 - val_loss: 0.3119 - val_mae: 0.4380 - val_mse: 0.3119
# Epoch 17/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2990 - mae: 0.4234 - mse: 0.2990 - val_loss: 0.2691 - val_mae: 0.4081 - val_mse: 0.2691
# Epoch 18/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2563 - mae: 0.3948 - mse: 0.2563 - val_loss: 0.2349 - val_mae: 0.3828 - val_mse: 0.2349
# Epoch 19/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2223 - mae: 0.3702 - mse: 0.2223 - val_loss: 0.2078 - val_mae: 0.3617 - val_mse: 0.2078
# Epoch 20/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1930 - mae: 0.3465 - mse: 0.1930 - val_loss: 0.1857 - val_mae: 0.3433 - val_mse: 0.1857
# Epoch 21/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1698 - mae: 0.3254 - mse: 0.1698 - val_loss: 0.1673 - val_mae: 0.3263 - val_mse: 0.1673
# Epoch 22/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1502 - mae: 0.3059 - mse: 0.1502 - val_loss: 0.1523 - val_mae: 0.3114 - val_mse: 0.1523
# Epoch 23/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1348 - mae: 0.2898 - mse: 0.1348 - val_loss: 0.1387 - val_mae: 0.2965 - val_mse: 0.1387
# Epoch 24/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1220 - mae: 0.2761 - mse: 0.1220 - val_loss: 0.1271 - val_mae: 0.2823 - val_mse: 0.1271
# Epoch 25/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1111 - mae: 0.2639 - mse: 0.1111 - val_loss: 0.1168 - val_mae: 0.2699 - val_mse: 0.1168
# Epoch 26/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1020 - mae: 0.2528 - mse: 0.1020 - val_loss: 0.1080 - val_mae: 0.2589 - val_mse: 0.1080
# Epoch 27/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0947 - mae: 0.2429 - mse: 0.0947 - val_loss: 0.1009 - val_mae: 0.2497 - val_mse: 0.1009
# Epoch 28/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0884 - mae: 0.2343 - mse: 0.0884 - val_loss: 0.0939 - val_mae: 0.2407 - val_mse: 0.0939
# Epoch 29/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0823 - mae: 0.2260 - mse: 0.0823 - val_loss: 0.0877 - val_mae: 0.2326 - val_mse: 0.0877
# Epoch 30/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0768 - mae: 0.2185 - mse: 0.0768 - val_loss: 0.0820 - val_mae: 0.2247 - val_mse: 0.0820
# Epoch 31/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0720 - mae: 0.2117 - mse: 0.0720 - val_loss: 0.0768 - val_mae: 0.2174 - val_mse: 0.0768
# Epoch 32/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0674 - mae: 0.2053 - mse: 0.0674 - val_loss: 0.0724 - val_mae: 0.2111 - val_mse: 0.0724
# Epoch 33/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0631 - mae: 0.1989 - mse: 0.0631 - val_loss: 0.0689 - val_mae: 0.2056 - val_mse: 0.0689
# Epoch 34/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0597 - mae: 0.1936 - mse: 0.0597 - val_loss: 0.0657 - val_mae: 0.2005 - val_mse: 0.0657
# Epoch 35/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0565 - mae: 0.1888 - mse: 0.0565 - val_loss: 0.0630 - val_mae: 0.1961 - val_mse: 0.0630
# Epoch 36/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0536 - mae: 0.1842 - mse: 0.0536 - val_loss: 0.0605 - val_mae: 0.1918 - val_mse: 0.0605
# Epoch 37/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0510 - mae: 0.1797 - mse: 0.0510 - val_loss: 0.0582 - val_mae: 0.1876 - val_mse: 0.0582
# Epoch 38/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0486 - mae: 0.1753 - mse: 0.0486 - val_loss: 0.0562 - val_mae: 0.1841 - val_mse: 0.0562
# Epoch 39/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0465 - mae: 0.1711 - mse: 0.0465 - val_loss: 0.0547 - val_mae: 0.1807 - val_mse: 0.0547
# Epoch 40/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0444 - mae: 0.1668 - mse: 0.0444 - val_loss: 0.0528 - val_mae: 0.1771 - val_mse: 0.0528
# Epoch 41/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0425 - mae: 0.1631 - mse: 0.0425 - val_loss: 0.0511 - val_mae: 0.1738 - val_mse: 0.0511
# Epoch 42/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0408 - mae: 0.1596 - mse: 0.0408 - val_loss: 0.0494 - val_mae: 0.1705 - val_mse: 0.0494
# Epoch 43/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0392 - mae: 0.1563 - mse: 0.0392 - val_loss: 0.0475 - val_mae: 0.1671 - val_mse: 0.0475
# Epoch 44/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0374 - mae: 0.1528 - mse: 0.0374 - val_loss: 0.0461 - val_mae: 0.1644 - val_mse: 0.0461
# Epoch 45/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0361 - mae: 0.1498 - mse: 0.0361 - val_loss: 0.0448 - val_mae: 0.1616 - val_mse: 0.0448
# Epoch 46/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0348 - mae: 0.1470 - mse: 0.0348 - val_loss: 0.0437 - val_mae: 0.1593 - val_mse: 0.0437
# Epoch 47/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0337 - mae: 0.1445 - mse: 0.0337 - val_loss: 0.0426 - val_mae: 0.1571 - val_mse: 0.0426
# Epoch 48/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0327 - mae: 0.1422 - mse: 0.0327 - val_loss: 0.0415 - val_mae: 0.1551 - val_mse: 0.0415
# Epoch 49/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0317 - mae: 0.1398 - mse: 0.0317 - val_loss: 0.0404 - val_mae: 0.1532 - val_mse: 0.0404
# Epoch 50/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0307 - mae: 0.1374 - mse: 0.0307 - val_loss: 0.0396 - val_mae: 0.1514 - val_mse: 0.0396
# Epoch 51/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0298 - mae: 0.1351 - mse: 0.0298 - val_loss: 0.0386 - val_mae: 0.1495 - val_mse: 0.0386
# Epoch 52/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0290 - mae: 0.1330 - mse: 0.0290 - val_loss: 0.0380 - val_mae: 0.1482 - val_mse: 0.0380
# Epoch 53/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0282 - mae: 0.1312 - mse: 0.0282 - val_loss: 0.0372 - val_mae: 0.1465 - val_mse: 0.0372
# Epoch 54/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0273 - mae: 0.1291 - mse: 0.0273 - val_loss: 0.0365 - val_mae: 0.1451 - val_mse: 0.0365
# Epoch 55/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0266 - mae: 0.1271 - mse: 0.0266 - val_loss: 0.0358 - val_mae: 0.1436 - val_mse: 0.0358
# Epoch 56/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0258 - mae: 0.1250 - mse: 0.0258 - val_loss: 0.0352 - val_mae: 0.1425 - val_mse: 0.0352
# Epoch 57/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0250 - mae: 0.1230 - mse: 0.0250 - val_loss: 0.0348 - val_mae: 0.1416 - val_mse: 0.0348
# Epoch 58/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0243 - mae: 0.1213 - mse: 0.0243 - val_loss: 0.0340 - val_mae: 0.1403 - val_mse: 0.0340
# Epoch 59/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0235 - mae: 0.1194 - mse: 0.0235 - val_loss: 0.0337 - val_mae: 0.1396 - val_mse: 0.0337
# Epoch 60/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0228 - mae: 0.1176 - mse: 0.0228 - val_loss: 0.0332 - val_mae: 0.1387 - val_mse: 0.0332
# Epoch 61/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0221 - mae: 0.1160 - mse: 0.0221 - val_loss: 0.0329 - val_mae: 0.1382 - val_mse: 0.0329
# Epoch 62/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0214 - mae: 0.1142 - mse: 0.0214 - val_loss: 0.0325 - val_mae: 0.1377 - val_mse: 0.0325
# Epoch 63/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0208 - mae: 0.1127 - mse: 0.0208 - val_loss: 0.0324 - val_mae: 0.1379 - val_mse: 0.0324
# Epoch 64/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - mae: 0.1112 - mse: 0.0202 - val_loss: 0.0319 - val_mae: 0.1371 - val_mse: 0.0319
# Epoch 65/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0194 - mae: 0.1093 - mse: 0.0194 - val_loss: 0.0314 - val_mae: 0.1365 - val_mse: 0.0314
# Epoch 66/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0188 - mae: 0.1077 - mse: 0.0188 - val_loss: 0.0308 - val_mae: 0.1355 - val_mse: 0.0308
# Epoch 67/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0182 - mae: 0.1062 - mse: 0.0182 - val_loss: 0.0305 - val_mae: 0.1351 - val_mse: 0.0305
# Epoch 68/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0178 - mae: 0.1050 - mse: 0.0178 - val_loss: 0.0299 - val_mae: 0.1337 - val_mse: 0.0299
# Epoch 69/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0173 - mae: 0.1034 - mse: 0.0173 - val_loss: 0.0294 - val_mae: 0.1326 - val_mse: 0.0294
# Epoch 70/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0168 - mae: 0.1020 - mse: 0.0168 - val_loss: 0.0289 - val_mae: 0.1316 - val_mse: 0.0289
# Epoch 71/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0163 - mae: 0.1005 - mse: 0.0163 - val_loss: 0.0282 - val_mae: 0.1300 - val_mse: 0.0282
# Epoch 72/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0158 - mae: 0.0990 - mse: 0.0158 - val_loss: 0.0278 - val_mae: 0.1293 - val_mse: 0.0278
# Epoch 73/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0154 - mae: 0.0976 - mse: 0.0154 - val_loss: 0.0272 - val_mae: 0.1280 - val_mse: 0.0272
# Epoch 74/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0150 - mae: 0.0963 - mse: 0.0150 - val_loss: 0.0265 - val_mae: 0.1265 - val_mse: 0.0265
# Epoch 75/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0146 - mae: 0.0952 - mse: 0.0146 - val_loss: 0.0258 - val_mae: 0.1250 - val_mse: 0.0258
# Epoch 76/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0142 - mae: 0.0939 - mse: 0.0142 - val_loss: 0.0253 - val_mae: 0.1238 - val_mse: 0.0253
# Epoch 77/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0139 - mae: 0.0931 - mse: 0.0139 - val_loss: 0.0246 - val_mae: 0.1220 - val_mse: 0.0246
# Epoch 78/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0136 - mae: 0.0920 - mse: 0.0136 - val_loss: 0.0241 - val_mae: 0.1208 - val_mse: 0.0241
# Epoch 79/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0133 - mae: 0.0910 - mse: 0.0133 - val_loss: 0.0235 - val_mae: 0.1194 - val_mse: 0.0235
# Epoch 80/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0129 - mae: 0.0898 - mse: 0.0129 - val_loss: 0.0230 - val_mae: 0.1181 - val_mse: 0.0230
# Epoch 81/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0126 - mae: 0.0887 - mse: 0.0126 - val_loss: 0.0225 - val_mae: 0.1170 - val_mse: 0.0225
# Epoch 82/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0123 - mae: 0.0880 - mse: 0.0123 - val_loss: 0.0225 - val_mae: 0.1172 - val_mse: 0.0225
# Epoch 83/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0122 - mae: 0.0875 - mse: 0.0122 - val_loss: 0.0218 - val_mae: 0.1150 - val_mse: 0.0218
# Epoch 84/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0118 - mae: 0.0863 - mse: 0.0118 - val_loss: 0.0214 - val_mae: 0.1139 - val_mse: 0.0214
# Epoch 85/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0116 - mae: 0.0855 - mse: 0.0116 - val_loss: 0.0208 - val_mae: 0.1119 - val_mse: 0.0208
# Epoch 86/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0113 - mae: 0.0844 - mse: 0.0113 - val_loss: 0.0200 - val_mae: 0.1097 - val_mse: 0.0200
# Epoch 87/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0110 - mae: 0.0833 - mse: 0.0110 - val_loss: 0.0193 - val_mae: 0.1074 - val_mse: 0.0193
# Epoch 88/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0108 - mae: 0.0824 - mse: 0.0108 - val_loss: 0.0191 - val_mae: 0.1067 - val_mse: 0.0191
# Epoch 89/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0107 - mae: 0.0823 - mse: 0.0107 - val_loss: 0.0184 - val_mae: 0.1046 - val_mse: 0.0184
# Epoch 90/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0105 - mae: 0.0816 - mse: 0.0105 - val_loss: 0.0181 - val_mae: 0.1037 - val_mse: 0.0181
# Epoch 91/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0104 - mae: 0.0811 - mse: 0.0104 - val_loss: 0.0177 - val_mae: 0.1021 - val_mse: 0.0177
# Epoch 92/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0103 - mae: 0.0808 - mse: 0.0103 - val_loss: 0.0174 - val_mae: 0.1010 - val_mse: 0.0174

# %%
model.predict(tokenizer(["1 + 1 + 1"]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# array([[2.7969935]], dtype=float32)

# %%
y_test = []
for i in expressions_not_in_x:
  result = float(eval(i))
  y_test.append(result)
x_test = tokenizer(expressions_not_in_x)
diff_x_test = posTokenizer(expressions_not_in_x)
diff_x_test = np.array(diff_x_test)
print(diff_x_test[0])
print(y_test[0])
x_test = np.array(x_test)
store = model.predict(x_test)
print(len(store))
differences = []
for i in range(len(store)):
  differences.append(abs(store[i] - y_test[i]))
print(np.mean(differences))
plt.figure(figsize=(10, 6))
plt.plot(differences)
plt.axhline(y = np.mean(differences), color='r', linestyle='-', label='Mean Difference') # Plot a horizontal line at the mean difference
plt.xlabel("Test Sample Index")
plt.ylabel("Absolute Difference (Predicted - Actual)")
plt.title("Absolute Differences Between Predicted and Actual Values for Test Set")
plt.show()
# Out:
# [[ 1.          0.        ]
#  [ 0.          0.5403023 ]
#  [ 3.          0.9092974 ]
#  [ 1.         -0.9899925 ]
#  [ 4.         -0.7568025 ]
#  [ 0.5         0.2836622 ]
#  [ 0.5         0.75390226]
#  [ 0.5        -0.91113025]
#  [ 0.5         0.0044257 ]
#  [ 0.5         0.9074468 ]
#  [ 0.5        -0.7596879 ]
#  [ 0.5        -0.27516335]
#  [ 0.5         0.9887046 ]
#  [ 0.5        -0.54772925]
#  [ 0.5        -0.53283304]]
# 2.0
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1457
# 0.10803629

# %%
#a list of expressions outside the number range
outsideExpr = set()
range1= range(5, 9)
range2= range(-8, -4)
comboRange = list(range1) + list(range2)
for num1 in comboRange:
    for num2 in comboRange:
        for num3 in comboRange:
            for op1 in [" + ", " - "]:
                for op2 in [" + ", " - "]:
                    expression = str(num1) + op1 + str(num2) + op2 + str(num3)
                    outsideExpr.add(expression)

outsideExpr = list(outsideExpr)
print(len(tokenizer(outsideExpr)[0]))

out_x_test = tokenizer(outsideExpr)
diff_out_x_test = posTokenizer(outsideExpr)
out_y_test = []
for i in outsideExpr:
  result = float(eval(i))
  out_y_test.append(result)
# Out:
# 15

# %%
minNums = 2
maxNums = 8
amountNums = 100
num_terms = np.arange(minNums-1,maxNums)
longer_Exps = []
for j in num_terms:
  for p in range(amountNums):
    longer_Exp = ""
    for i in range(j):
      longer_Exp += str(np.random.randint(-5,6))
      longer_Exp += np.random.choice([" + ", " - "])
    longer_Exp += str(np.random.randint(-5,6))
    longer_Exps.append(longer_Exp)
print(longer_Exps)

longer_Exps = list(longer_Exps)
long_x_test = tokenizer(longer_Exps)
diff_long_x_test = posTokenizer(longer_Exps)
long_y_test = []
for i in longer_Exps:
  result = float(eval(i))
  long_y_test.append(result)
print(long_y_test[0])
print(long_x_test[0])
# Out:
# ['-2 - -1', '-3 - -1', '1 + -4', '3 - 0', '0 + -3', '4 + 3', '-2 + -3', '-1 - 2', '2 - -5', '5 - 0', '5 - 1', '3 - 2', '5 - 2', '1 - -5', '-4 + 0', '-4 - -2', '4 + 0', '2 + 0', '-4 + 5', '0 + 0', '4 + -5', '4 + -1', '0 + -2', '1 + 0', '-2 - 2', '3 - 5', '-2 - 5', '2 - 3', '-3 + 3', '-5 + -3', '3 + -5', '1 - 1', '-5 + 4', '4 - 4', '4 - -3', '2 + -5', '3 - -2', '2 - -1', '-3 - -5', '4 + 5', '0 - 1', '-3 + -5', '1 + 5', '-5 - -4', '-2 + -5', '-2 - -2', '-2 + 3', '-5 + 1', '-2 - -1', '-4 + 1', '4 + 1', '-2 - -5', '-5 - -2', '-2 - 1', '3 + 4', '-1 - 5', '-3 + 0', '-5 + -3', '-1 - 1', '1 - 3', '-5 + 3', '2 - 2', '2 - 2', '-3 + 3', '-2 + 5', '0 + 5', '5 + -5', '-3 + 3', '-3 + 5', '4 - -2', '-1 + 1', '3 + 2', '-4 - 2', '2 + -3', '3 - 1', '-5 - 4', '-1 - 3', '4 + 2', '5 - -3', '-1 - -2', '-5 + 4', '1 + -2', '0 + 3', '5 - -4', '5 + 4', '-1 + 1', '-3 - 1', '-1 - 0', '0 + 5', '-2 - 2', '3 - 3', '5 - -2', '0 - 1', '-2 - 4', '2 + 2', '4 - -3', '-1 - 4', '2 + 0', '-2 + -2', '-2 - 1', '-1 - 2 - 1', '2 + -2 - 0', '-3 + 2 + 1', '4 + 5 - -5', '4 + -4 - 2', '-1 - -1 - 5', '-2 + -5 + 0', '-2 - -3 - 3', '-3 - -4 - -5', '5 + -4 + -5', '-5 - -1 - 3', '0 - -2 + -3', '2 + -5 - 5', '-1 - -1 - -1', '2 - 2 - -2', '3 - -5 + -1', '-1 - 3 + 3', '5 - -3 - -2', '-4 - -1 - 2', '-5 + 1 - -5', '5 + -4 + -4', '-4 - 5 - 1', '0 + 0 + 3', '2 - 2 - -1', '3 - -4 + 0', '1 - -2 + 1', '-4 + -2 + -4', '4 - -5 + -3', '-5 + -1 - 1', '3 - 2 - 0', '-3 - 2 - -2', '-1 + 3 + 3', '2 - -4 - -3', '2 + -1 + 2', '0 + -1 - -5', '-5 + -3 - 0', '0 + 1 + -4', '-2 + 1 - -2', '-2 + 2 - 2', '3 + -2 - 2', '0 - 0 - -2', '3 - 1 - 5', '0 + -4 - 0', '5 - -5 + 5', '-1 + -3 - 1', '-1 + 4 + -5', '2 + 3 + -3', '0 + 4 - -2', '-3 - 0 + 5', '3 + -3 + 3', '-3 - -5 + 3', '-4 - 4 - 2', '3 + 3 - 0', '1 - -1 - 5', '-5 + 3 - -1', '-1 - 5 + -4', '1 + 1 - -1', '0 - 1 + -2', '-3 - -2 + -4', '5 - 3 + 1', '0 - -5 - 1', '-4 + 2 + 5', '5 - 5 + -2', '1 + 5 + -4', '1 + -4 - 4', '3 + -1 - 1', '-5 - 3 + -1', '0 + 5 - 2', '-2 - 4 - -4', '-1 + 0 + 0', '0 + 5 + -3', '3 + -3 + -4', '1 - 4 - -5', '0 + 5 - 0', '-5 + -2 + -3', '0 + -2 - -5', '-1 + 3 - 2', '2 + 2 - 4', '1 + 1 + 2', '-3 + 2 - 0', '-2 + 5 - 4', '3 - 4 - 4', '-1 - -2 + -4', '1 - -5 + -1', '-4 - 2 + -2', '3 + 5 - 0', '-3 + -5 - 5', '0 - -4 - -2', '3 + -1 - -3', '-5 - 2 + 5', '-5 + 5 - 1', '1 - -3 - 0', '2 - -5 + 3', '5 - 3 + 3', '5 - 0 + -5', '5 - 4 + 1', '4 - -3 - -3', '3 + -5 + 2', '-1 + -2 + 3', '3 + -1 - 5', '3 + 4 - 3 + 2', '-5 - 4 - -2 - 3', '-3 + 4 + 4 + 5', '-1 + -2 + 0 - -3', '4 - -1 - 0 - -2', '-3 + 1 + 0 - -5', '-1 + 0 + -5 + -2', '-2 - -4 - 2 - -3', '-5 - 5 + 2 - -3', '5 - 5 - -2 - -2', '5 - 3 - -5 + -5', '-1 - 0 - 0 + -5', '4 - 2 - 2 - -3', '-1 - -2 - -5 + -1', '-4 - -4 + 1 - -5', '-1 - 1 - 3 + -5', '-4 + 0 - 1 + -4', '3 - 5 + -3 + -1', '-1 - -4 - 0 - -2', '-1 + 2 - -1 - -3', '1 - -3 + 5 - 4', '4 - -2 - -2 - 2', '-3 + 5 + -4 + -2', '3 + -4 + 3 - 5', '0 + -2 - 1 + 3', '0 + 5 - -2 + -2', '-3 + 5 + 5 - -1', '-3 - -4 + -4 + 2', '2 - -1 + -4 + -2', '1 - 0 - 1 + -4', '2 - -4 - 2 - 1', '-3 + -2 + 1 - 3', '1 + -5 + -2 - 3', '-2 + -1 + -4 + -2', '-2 + 4 - 0 - 3', '-5 + 0 - 5 - -5', '3 - 5 + -1 - -5', '2 + -5 - 0 + -3', '-1 - 1 - -3 - 5', '2 - -4 - 1 - -5', '-4 - -5 - -5 + 1', '0 - 0 - -1 + 4', '1 + 3 - -3 - 0', '-3 + -5 + -2 - -4', '3 + 5 - -3 + -2', '-1 - 3 - 5 + -2', '2 - 1 + -5 - 0', '-1 + 3 + 3 + 3', '-4 + 5 - -5 + -2', '-1 - 0 + -4 - -2', '2 + 5 - -1 - -3', '1 + -3 + 2 + -4', '-3 - 1 + 4 + -4', '-2 + -1 - -5 + 1', '1 + -5 - 5 + 5', '-4 + -1 - -1 + -2', '5 + 4 - -4 + -2', '5 + 3 + -3 + 3', '2 + 0 - 4 + 5', '3 - 4 + -3 - 4', '4 - 4 + 2 + 4', '-4 - -2 - -4 + 2', '-3 - 1 + -5 + 0', '-3 + -3 + -1 - -3', '-2 + -3 - 1 - -3', '4 - -4 - 3 + -5', '-5 - 4 + -3 - -3', '-1 + -4 - 5 + -5', '5 - -3 + 1 - 5', '1 + -1 + -3 + 1', '-3 + -1 - -2 + 1', '-5 + 2 + -3 - 0', '1 + -2 - 1 - 5', '-4 + -5 - 0 - -1', '-5 - -3 + 5 + 3', '3 + 0 + -5 + 4', '-4 + -1 - -1 - -5', '-3 - -1 + -1 - 4', '-1 + 2 - 2 + -3', '5 - -5 - 3 + -1', '3 - 3 + -2 + -4', '-4 - -5 - -2 - 5', '0 - 0 + -1 + -4 ...
# -1.0
# [-2.   0.  -1.   0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5
#   0.5]

# %%
# prompt: bootstrap the model 10 times and calculate a range for predictions

n_bootstrap = 10
predictions = []
out_predictions = []
long_predictions = []

for _ in range(n_bootstrap):
  # Create bootstrap sample
  sample_indices = np.random.choice(len(x_train), size=len(x_train), replace=True)
  x_train_bootstrap = x_train[sample_indices]
  y_train_bootstrap = np.array(y_train)[sample_indices]

  # Re-compile and train the model
  bootstrap_model = keras.models.clone_model(model)
  bootstrap_model.compile(optimizer="adam", loss="mse", metrics=["mae", "mse"])

  bootstrap_train_dataset = tf.data.Dataset.from_tensor_slices((x_train_bootstrap, y_train_bootstrap)).batch(32)
  bootstrap_model.fit(
      bootstrap_train_dataset,
      epochs=50,  # Reduced epochs for quicker example, adjust as needed
      verbose=0, # Suppress output
      callbacks=[early_stopping]
  )

  # Make predictions on the test set
  predictions.append(bootstrap_model.predict(x_test))
  out_predictions.append(bootstrap_model.predict(out_x_test))
  long_predictions.append(bootstrap_model.predict(long_x_test))

# Convert predictions to a numpy array for easier processing
predictions = np.array(predictions)
out_predictions = np.array(out_predictions)
long_predictions = np.array(long_predictions)

#calculate the mean thingy
meanPredictions = []
for i in range(len(expressions_not_in_x)):
  calc = 0
  for j in range(n_bootstrap):
    calc += predictions[j][i]
  meanPredictions.append(calc/n_bootstrap)


# Calculate the lower and upper bounds of the prediction range
lower_bound = np.percentile(predictions, 5, axis=0)
upper_bound = np.percentile(predictions, 95, axis=0)

inRange = []
outOfBounds = 0
for i in range(len(x_test)):
  if y_test[i] >= lower_bound[i][0] and y_test[i] <= upper_bound[i][0]:
    inRange.append(True)
  else:
    inRange.append(False)
    outOfBounds += 1


print("Prediction Range (5th to 95th percentile):")
for i in range(len(x_test)):
  print(f"Input: {expressions_not_in_x[i]}, Actual: {y_test[i]:.2f}, Predicted Range: [{lower_bound[i][0]:.2f}, {upper_bound[i][0]:.2f}], bootstrapped prediction: {meanPredictions[i]}, in Range: {inRange[i]}")

print(f"Amount out of bounds: {outOfBounds}, Amount of expressions: {len(x_test)}, Percentage in bounds: {(1-(outOfBounds/len(x_test)))*100}%")
# Out:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Prediction Range (5th to 95th percentile):
# Input: 1 - 3 + 4, Actual: 2.00, Predicted Range: [1.51, 2.26], bootstrapped prediction: [1.8341357], in Range: True
# Input: 2 + 4 - 1, Actual: 5.00, Predicted Range: [4.86, 5.37], bootstrapped prediction: [5.09753], in Range: True
# Input: 2 + 3 - 1, Actual: 4.00, Predicted Range: [3.97, 4.45], bootstrapped prediction: [4.185437], in Range: True
# Input: 4 + -3 + 4, Actual: 5.00, Predicted Range: [4.31, 5.24], bootstrapped prediction: [4.8371344], in Range: True
# Input: -4 - -4 - 4, Actual: -4.00, Predicted Range: [-4.36, -3.61], bootstrapped prediction: [-3.9940648], in Range: True
# Input: -5 + -3 + -3, Actual: -11.00, Predicted Range: [-11.15, -10.75], bootstrapped prediction: [-10.951875], in Range: True
# Input: 0 + -2 - 4, Actual: -6.00, Predicted Range: [-6.34, -5.88], bootstrapped prediction: [-6.0187073], in Range: True
# Input: -3 - -1 + 4, Actual: 2.00, Predicted Range: [1.64, 2.29], bootstrapped prediction: [1.9853312], in Range: True
# Input: 4 + -4 + 4, Actual: 4.00, Predicted Range: [3.56, 4.06], bootstrapped prediction: [3.8461819], in Range: True
# Input: -4 - -4 + -4, Actual: -4.00, Predicted Range: [-4.24, -3.91], bootstrapped prediction: [-4.062909], in Range: True
# Input: 0 + -1 + -2, Actual: -3.00, Predicted Range: [-3.25, -2.79], bootstrapped prediction: [-2.9971051], in Range: True
# Input: -2 - -1 + 2, Actual: 1.00, Predicted Range: [0.81, 1.48], bootstrapped prediction: [1.0476162], in Range: True
# Input: -2 + -3 - -3, Actual: -2.00, Predicted Range: [-2.26, -1.89], bootstrapped prediction: [-2.0745919], in Range: True
# Input: 2 - -2 - -4, Actual: 8.00, Predicted Range: [7.80, 8.41], bootstrapped prediction: [8.080489], in Range: True
# Input: 2 - -1 - -5, Actual: 8.00, Predicted Range: [7.66, 8.25], bootstrapped prediction: [7.983529], in Range: True
# Input: -3 - 3 - -4, Actual: -2.00, Predicted Range: [-2.48, -1.75], bootstrapped prediction: [-2.0337362], in Range: True
# Input: 4 - 1 - 4, Actual: -1.00, Predicted Range: [-1.28, -0.31], bootstrapped prediction: [-0.80325425], in Range: True
# Input: 3 - 2 + 3, Actual: 4.00, Predicted Range: [3.95, 4.41], bootstrapped prediction: [4.1000338], in Range: True
# Input: -4 - -2 + 0, Actual: -2.00, Predicted Range: [-2.28, -1.91], bootstrapped prediction: [-2.054793], in Range: True
# Input: -3 + 4 + -5, Actual: -4.00, Predicted Range: [-4.44, -3.71], bootstrapped prediction: [-4.0186524], in Range: True
# Input: 2 - 3 - -3, Actual: 2.00, Predicted Range: [1.66, 2.20], bootstrapped prediction: [1.9557358], in Range: True
# Input: 2 - 2 - 3, Actual: -3.00, Predicted Range: [-3.40, -2.84], bootstrapped prediction: [-3.0786984], in Range: True
# Input: 3 + 2 + -5, Actual: 0.00, Predicted Range: [-0.13, 0.33], bootstrapped prediction: [0.12484834], in Range: True
# Input: -2 + 3 + 1, Actual: 2.00, Predicted Range: [1.97, 2.27], bootstrapped prediction: [2.1184216], in Range: True
# Input: 4 - -2 + 4, Actual: 10.00, Predicted Range: [9.62, 10.02], bootstrapped prediction: [9.790968], in Range: True
# Input: 2 + 3 - -2, Actual: 7.00, Predicted Range: [6.79, 7.47], bootstrapped prediction: [7.1248984], in Range: True
# Input: 2 + -1 + 2, Actual: 3.00, Predicted Range: [2.91, 3.24], bootstrapped prediction: [3.0637991], in Range: True
# Input: 1 - 0 + -2, Actual: -1.00, Predicted Range: [-1.43, -0.88], bootstrapped prediction: [-1.1642531], in Range: True
# Input: 4 - -2 - 2, Actual: 4.00, Predicted Range: [3.58, 4.33], bootstrapped prediction: [3.991433], in Range: True
# Input: 4 + -3 + -2, Actual: -1.00, Predicted Range: [-1.11, -0.71], bootstrapped prediction: [-0.9143046], in Range: True
# Input: 3 + -1 + 4, Actual: 6.00, Predicted Range: [5.64, 6.41], bootstrapped prediction: [5.9830394], in Range: True
# Input: -5 - -5 - -2, Actual: 2.00, Predicted Range: [1.58, 1.99], bootstrapped prediction: [1.8060818], in Range: False
# Input: 4 - 2 + -4, Actual: -2.00, Predicted Range: [-2.30, -1.52], bootstrapped prediction: [-1.9266338], in Range: True
# Input: 0 - -4 + -1, Actual: 3.00, Predicted Range: [2.80, 3.32], bootstrapped prediction: [2.9994407], in Range: True
# Input: 4 + -2 + -2, Actual: 0.00, Predicted Range: [-0.10, 0.36], bootstrapped prediction: [0.11260233], in Range: True
# Input: -3 - -3 + -5, Actual: -5.00, Predicted Range: [-5.24, -4.72], bootstrapped prediction: [-5.001034], in Range: True
# Input: -2 - -2 + 2, Actual: 2.00, Predicted Range: [1.88, 2.63], bootstrapped prediction: [2.0994945], in Range: True
# Input: 3 - -3 - -3, Actual: 9.00, Predicted Range: [8.78, 9.20], bootstrapped prediction: [9.04125], in Range: True
# Input: 1 + 1 + -5, Actual: -3.00, Predicted Range: [-3.08, -2.76], bootstrapped prediction: [-2.9382167], in Range: True
# Input: -1 + -4 + -2, Actual: -7.00, Predicted Range: [-7.20, -6.84], bootstrapped prediction: [-7.0173492], in Range: True
# Input: -1 - -3 - -4, Actual: 6.00, Predicted Range: [5.96, 6.48], bootstrapped prediction: [6.2266364], in Range: True
# Input: 0 - -5 - 1, Actual: 4.00, Predicted Range: [3.78, 4.37], bootstrapped prediction: [4.1054215], in Range: True
# Input: -3 + -2 - 4, Actual: -9.00, Predicted Range: [-9.20, -8.63], bootstrapped prediction: [-8.881348], in Range: True
# Input: 0 - 4 + -3, Actual: -7.00, Predicted Range: [-7.21, -6.71], bootstrapped prediction: [-6.93685], in Range: True
# Input: -4 - -2 - -5, Actual: 3.00, Predicted Range: [2.67, 3.02], bootstrapped prediction: [2.8948128], in Range: True
# Input: -1 - -1 - 0, Actual: 0.00, Predicted Range: [-0.45, 0.25], bootstrapped prediction: [-0.03967027], in Range: True
# Input: 1 - 2 - -2, Actual: 1.00, Predicted Range: [0.80, 1.06], bootstrapped prediction: [0.924794], in Range: True
# Input: 4 + -2 + 4, Actual: 6.00, Predicted Range: [5.41, 6.39], bootstrapped prediction: [5.866882], in Range: True
# Input: 4 + 3 - -2, Actual: 9.00, Predicted Range: [8.79, 9.28], bootstrapped prediction: [8.9910145], in Range: True
# Input: 0 + 0 - -2, Actual: 2.00, Predicted Range: [1.77, 2.16], bootstrapped prediction: [2.001322], in Range: True
# Input: -3 + 0 - -5, Actual: 2.00, Predicted Range: [1.75, 2.27], bootstrapped prediction: [1.9879059], in Range: True
# Input: -1 - 2 + 1, Actual: -2.00, Predicted Range: [-2.23, -1.80], bootstrapped prediction: [-2.02286], in Range: True
# Input: -4 + 0 + 1, Actual: -3.00, Predicted Range: [-3.33, -2.98], bootstrapped prediction: [-3.136969], in Range: True
# Input: 4 - 0 - 1, Actual: 3.00, Predicted Range: [2.56, 3.48], bootstrapped prediction: [3.0736709], in Range: True
# Input: 0 + 4 - -1, Actual: 5.00, Predicted Range: [4.76, 5.22], bootstrapped prediction: [4.9765043], in Range: True
# Input: -1 + 1 - -2, Actual: 2.00, Predicted Range: [1.81, 2.26], bootstrapped prediction: [2.068475], in Range: True
# Input: -5 + 2 - -5, Actual: 2.00, Predicted Range: [1.48, 2.17], bootstrapped prediction: [1.8394839], in Range: True
# Input: -4 - 2 - -1, Actual: -5.00, Predicted Range: [-5.51, -4.71], bootstrapped prediction: [-5.028131], in Range: True
# Input: -4 - -3 + -4, Actual: -5.00, Predicted Range: [-5.37, -4.76], bootstrapped prediction: [-5.067071], in Range: True
# Input: -4 + -1 - -3, Actual: -2.00, Predicted Range: [-2.14, -1.60], bootstrapped prediction: [-1.8848203], in Range: True
# Input: -5 + 0 + -2, Actual: -7.00, Predicted Range: [-7.22, -6.66], bootstrapped prediction: [-6.94974], in Range: True
# Input: -4 + 0 + -2, Actual: -6.00, Predicted Range: [-6.27, -5.76], bootstrapped prediction: [-6.044618], in Range: True
# Input: -3 + 0 + 2, Actual: -1.00, Predicted Range: [-1.45, -0.82], bootstrapped prediction: [-1.096591], in Range: True
# Input: -5 + -2 - 1, Actual: -8.00, Predicted Range: [-8.04, -7.21], bootstrapped prediction: [-7.7203193], in Range: True
# Input: 4 + 2 + 0, Actual: 6.00, Predicted Range: [5.73, 6.32], bootstrapped prediction: [6.0143905], in Range: True
# Input: 0 - -2 + 3, Actual: 5.00, Predicted Range: [4.79, 5.53], bootstrapped prediction: [5.1365547], in Range: True
# Input: 1 - -1 - -1, Actual: 3.00, Predicted Range: [2.79, 3.10], bootstrapped prediction: [2.934264], in Range: True
# Input: -5 - 3 + -5, Actual: -13.00, Predicted Range: [-12.90, -12.15], bootstrapped prediction: [-12.621938], in Range: False
# Input: -3 - 4 + -5, Actual: -12.00, Predicted Range: [-12.03, -11.24], bootstrapped prediction: [-11.739658], in Range: True
# Input: -3 + -3 + -5, Actual: -11.00, Predicted Range: [-11.15, -10.71], bootstrapped prediction: [-10.9844265], in Range: True
# Input: 3 + -3 - -4, Actual: 4.00, Predicted Range: [3.78, 4.20], bootstrapped prediction: [4.0059934], in Range: True
# Input: 2 - 4 - 0, Actual: -2.00, Predicted Range: [-2.45, -1.78], bootstrapped prediction: [-2.0860178], in Range: True
# Input: -5 - -3 + 0, Actual: -2.00, Predicted Range: [-2.18, -1.74], bootstrapped prediction: [-1.9171455], in Range: True
# Input: 1 - -4 - 1, Actual: 4.00, Predicted Range: [3.89, 4.39], bootstrapped prediction: [4.1285586], in Range: True
# Input: 2 - 0 + -5, Actual: -3.00, Predicted Range: [-3.23, -2.72], bootstrapped prediction: [-2.925164], in Range: True
# Input: 0 - -1 - -5, Actual: 6.00, Predicted Range: [5.48, 6.25], bootstrapped prediction: [5.952556], in Range: True
# Input: -5 + 1 + 2, Actual: -2.00, Predicted Range: [-2.26, -1.76], bootstrapped prediction: [-1.9664977], in Range: True
# Input: -5 - -5 - 2, Actual: -2.00, Predicted Range: [-2.47, -1.79], bootstrapped prediction: [-2.139283], in Range: True
# Input: -2 + -5 - 2, Actual: -9.00, Predicted Range: [-9.33, -8.79], bootstrapped prediction: [-9.059558], in Range: True
# Input: -1 - 0 - 4, Actual: -5.00, Predicted Range: [-5.26, -4.76], bootstrapped prediction: [-4.977373], in Range: True
# Input: 2 - -1 - 3, Actual: 0.00, Predicted Range: [-0.29, 0.28], bootstrapped prediction: [-0.07151038], in Range: True
# Input: -2 + -3 + 0, Actual: -5.00, Predicted Range: [-5.24, -4.74], bootstrapped prediction: [-5.028027], in Range: True
# Input: -5 + 3 + 0, Actual: -2.00, Predicted Range: [-2.22, -1.76], bootstrapped prediction: [-2.0176768], in Range: True
# Input: 0 - -3 + 0, Actual: 3.00, Predicted Range: [2.83, 3.44], bootstrapped prediction: [3.068397], in Range: True
# Input: 1 + -5 - 3, Actual: -7.00, Predicted Range: [-7.12, -6.70], bootstrapped prediction: [-6.8955445], in Range: True
# Input: 1 - 1 - -1, Actual: 1.00, Predicted Range: [0.77, 1.33], bootstrapped prediction: [1.0272688], in Range: True
# Input: 4 - -2 + -4, Actual: 2.00, Predicted Range: [1.73, 2.32], bootstrapped prediction: [1.9728773], in Range: True
# Input: 2 - 2 - -4, Actual: 4.00, Predicted Range: [3.75, 4.31], bootstrapped prediction: [4.008349], in Range: True
# Input: 2 - 4 - 3, Actual: -5.00, Predicted Range: [-5.05, -4.63], bootstrapped prediction: [-4.862305], in Range: True
# Input: -2 - 0 - 0, Actual: -2.00, Predicted Range: [-2.38, -1.51], bootstrapped prediction: [-1.9064124], in Range: True
# Input: -2 + -2 + 1, Actual: -3.00, Predicted Range: [-3.48, -2.88], bootstrapped prediction: [-3.1108162], in Range: True
# Input: -1 - 4 - -3, Actual: -2.00, Predicted Range: [-2.12, -1.41], bootstrapped prediction: [-1.8321445], in Range: True
# Input: 0 + 2 + -3, Actual: -1.00, Predicted Range: [-1.27, -0.82], bootstrapped prediction: [-1.0352167], in Range: True
# Input: 2 - 1 - 2, Actual: -1.00, Predicted Range: [-1.32, -0.72], bootstrapped prediction: [-1.0397755], in Range: True
# Input: -4 - -1 + -5, Actual: -8.00, Predicted Range: [-8.12, -7.72], bootstrapped prediction: [-7.956655], in Range: True
# Input: -2 + 2 - 2, Actual: -2.00, Predicted Range: [-2.10, -1.44], bootstrapped prediction: [-1.852418], in Range: True
# Input: -1 - 0 - -1, Actual: 0.00, Predicted Range: [-0.15, 0.28], bootstrapped prediction: [0.04951247], in Range: True
# Input: 4 - 1 - -3, Actual: 6.00, Predicted Range: [5.74, 6.26], bootstrapped prediction: [6.0064573], in Range: True
# Input: -5 + 1 - 0, Actual: -4.00, Predicted Range: [-4.29, -3.52], bootstrapped prediction: [-3.98814], in Range: True
# Input: -4 - 0 - -1, Actual: -3.00, Predicted Range: [-3.28, -2.74], bootstrapped prediction: [-2.9636164], in Range: True
# Input: 0 - -1 + 2, Actual: 3.00, Predicted Range: [2.71, 3.61], bootstrapped prediction: [3.1095512], in Range: True
# Input: 0 + 4 + -4, Actual: 0.00, Predicted Range: [-0.59, 0.20], bootstrapped prediction: [-0.21285383], in Range: True
# Input: 1 + 4 - 0, Actual: 5.00, Predicted Range: [4.72, 5.22], bootstrapped prediction: [5.0203495], in Range: True
# Input: 2 + 0 - 3, Actual: -1.00, Predicted Range: [-1.14, -0.80], bootstrapped prediction: [-0.9650915], in Range: True
# Input: -2 + 3 + -5, Actual: -4.00, Predicted Range: [-4.23, -3.74], bootstrapped prediction: [-3.9326699], in Range: True
# Input: 4 - 4 + -3, Actual: -3.00, Predicted Range: [-3.04, -2.53], bootstrapped prediction: [-2.825361], in Range: True
# Input: 0 - -1 - -1, Actual: 2.00, Predicted Range: [1.64, 2.28], bootstrapped prediction: [1.9857365], in Range: True
# Input: 4 - 2 - -1, Actual: 3.00, Predicted Range: [2.68, 3.19], bootstrapped prediction: [2.963027], in Range: True
# Input: 2 - -2 + 2, Actual: 6.00, Predicted Range: [5.95, 6.39], bootstrapped prediction: [6.1587715], in Range: True
# Input: 2 + 3 + 4, Actual: 9.00, Predicted Range: [8.65, 9.35], bootstrapped prediction: [8.9534855], in Range: True
# Input: 1 + -5 + -5, Actual: -9.00, Predicted Range: [-9.12, -8.32], bootstrapped prediction: [-8.682789], in Range: True
# Input: 2 + -3 - 1, Actual: -2.00, Predicted Range: [-2.28, -1.91], bootstrapped prediction: [-2.0729764], in Range: True
# Input: 0 + 0 - 4, Actual: -4.00, Predicted Range: [-4.18, -3.70], bootstrapped prediction: [-3.9145598], in Range: True
# Input: -2 + -3 + -2, Actual: -7.00, Predicted Range: [-7.15, -6.76], bootstrapped prediction: [-6.9817734], in Range: True
# Input: -1 - -2 - 3, Actual: -2.00, Predicted Range: [-2.17, -1.84], bootstrapped prediction: [-2.0085766], in Range: True
# Input: 1 - -1 + -2, Actual: 0.00, Predicted Range: [-0.36, 0.12], bootstrapped prediction: [-0.0996115], in Range: True
# Input: 3 - 0 + -3, Actual: 0.00, Predicted Range: [-0.19, 0.39], bootstrapped prediction: [0.063475], in Range: True
# Input: -3 - 0 - 0, Actual: -3.00, Predicted Range: [-3.27, -2.48], bootstrapped prediction: [-2.8988996], in Range: True
# Input: -4 + 4 + 1, Actual: 1.00, Predicted Range: [0.74, 1.19], bootstrapped prediction: [0.94244987], in Range: True
# Input: 3 + 3 - -4, Actual: 10.00, Predicted Range: [9.65, 10.24], bootstrapped prediction: [9.94602], in Range: True
# Input: 0 - -2 - -4, Actual: 6.00, Predicted Range: [5.82, 6.66], bootstrapped prediction: [6.2106543], in Range: True
# Input: 3 + 2 - 0, Actual: 5.00, Predicted Range: [4.70, 5.42], bootstrapped prediction: [5.0421877], in Range: True
# Input: 1 + 3 + 4, Actual: 8.00, Predicted Range: [7.55, 8.21], bootstrapped prediction: [7.8988314], in Range: True
# Input: -4 + -1 + 0, Actual: -5.00, Predicted Range: [-5.21, -4.86], bootstrapped prediction: [-5.050725], in Range: True
# Input: 0 - 3 + -1, Actual: -4.00, Predicted Range: [-4.20, -3.93], bootstrapped prediction: [-4.0660667], in Range: True
# Input: -2 + 1 - 4, Actual: -5.00, Predicted Range: [-5.02, -4.60], bootstrapped prediction: [-4.806692], in Range: True
# Input: -1 - 1 + -2, Actual: -4.00, Predicted Range: [-4.30, -3.76], bootstrapped prediction: [-4.0259924], in Range: True
# Input: 1 + -2 - -2, Actual: 1.00, Predicted Range: [0.64, 1.23], bootstrapped prediction: [0.93148327], in Range: True
# Input: -3 + 4 - 3, Actual: -2.00, Predicted Range: [-2.34, -1.86], bootstrapped prediction: [-2.1131034], in Range: True
# Input: 2 - -3 + -4, Actual: 1.00, Predicted Range: [0.75, 1.24], bootstrapped prediction: [0.9856035], in Range: True
# Input: -3 - 2 + -2, Actual: -7.00, Predicted Range: [-7.19, -6.62], bootstrapped prediction: [-6.9142637], in Range: True
# Input: -2 - -3 - 1, Actual: 0.00, Predicted Range: [-0.22, 0.18], bootstrapped prediction: [-0.01039972], in Range: True
# Input: -1 - -4 - -2, Actual: 5.00, Predicted Range: [4.79, 5.36], bootstrapped prediction: [5.071273], in Range: True
# Input: 2 + -5 - 4, Actual: -7.00, Predicted Range: [-7.09, -6.55], bootstrapped prediction: [-6.816504], in Range: True
# Input: 1 + 0 + -2, Actual: -1.00, Predicted Range: [-1.28, -0.66], bootstrapped prediction: [-1.0072582], in Range: True
# Input: 1 + -5 - -2, Actual: -2.00, Predicted Range: [-2.34, -1.74], bootstrapped prediction: [-2.0153677], in Range: True
# Input: -5 - 4 + 2, Actual: -7.00, Predicted Range: [-7.39, -6.58], bootstrapped prediction: [-7.044295], in Range: True
# Input: -5 - 2 - 4, Actual: -11.00, Predicted Range: [-11.28, -10.30], bootstrapped prediction: [-10.684628], in Range: True
# Input: -3 - 4 + 0, Actual: -7.00, Predicted Range: [-7.29, -6.82], bootstrapped prediction: [-7.008494], in Range: True
# Input: 2 - 3 - -2, Actual: 1.00, Predicted Range: [0.69, 1.14], bootstrapped prediction: [0.8903381], in Range: True
# Input: -2 + 1 - -1, Actual: 0.00, Predicted Range: [-0.24, 0.27], bootstrapped prediction: [-0.01729539], in Range: True
# Input: -3 + -1 - 3, Actual: -7.00, Predicted Range: [-7.16, -6.76], bootstrapped prediction: [-6.9038734], in Range: True
# Input: 2 + -5 + -4, Actual: -7.00, Predicted Range: [-7.11, -6.63], bootstrapped prediction: [-6.898346], in Range: True
# Input: 4 + -5 - -5, Actual: 4.00, Predicted Range: [3.85, 4.37], bootstrapped prediction: [4.167288], in Range: True
# Input: -2 + 4 - -5, Actual: 7.00, Predicted Range: [6.25, 6.94], bootstrapped prediction: [6.5859337], in Range: False
# Input: -4 + 2 - 2, Actual: -4.00, Predicted Range: [-4.11, -3.56], bootstrapped prediction: [-3.8604717], in Range: True
# Input: -2 - -1 - -5, Actual: 4.00, Predicted Range: [3.56, 4.15], bootstrapped prediction: [3.8851147], in Range: True
# Input: 4 + 1 - -4, Actual: 9.00, Predicted Range: [8.81, 9.19], bootstrapped prediction: [8.976385], in Range: True
# Input: 1 + 2 - -3, Actual: 6.00, Predicted Range: [6.07, 6.41], bootstrapped prediction: [6.228212], in Range: False
# Input: -1 + 1 + 2, Actual: 2.00, Predicted Range: [1.76, 2.15], bootstrapped prediction: [2.032159], in Range: True
# Input: -2 - 1 - 3, Actual: -6.00, Predicted Range: [-6.37, -5.91], bootstrapped prediction: [-6.162689], in Range: True
# Input: 3 + -4 - -4, Actual: 3.00, Predicted Range: [2.81, 3.24], bootstrapped prediction: [2.999223], in Range: True
# Input: 4 + 0 + -4, Actual: 0.00, Predicted Range: [-0.40, 0.45], bootstrapped prediction: [0.02586218], in Range: True
# Input: -4 + 3 - -2, Actual: 1.00, Predicted Range: [0.75, 1.24], bootstrapped prediction: [1.0087351], in Range: True
# Input: -3 - 1 + 4, Actual: 0.00, Predicted Range: [-0.15, 0.18], bootstrapped prediction: [0.0141559], in Range: True
# Input: 0 + 0 + 1, Actual: 1.00, Predicted Range: [0.75, 1.14], bootstrapped prediction: [0.96203506], in Range: True
# Input: 3 + 2 + 3, Actual: 8.00, Predicted Range: [7.97, 8.20], bootstrapped prediction: [8.074585], in Range: True
# Input: -3 + -5 - -1, Actual: -7.00, Predicted Range: [-7.09, -6.77], bootstrapped prediction: [-6.9477754], in Range: True
# Input: -5 + -2 + -4, Actual: -11.00, Predicted Range: [-11.12, -10.83], bootstrapped prediction: [-10.967905], in Range: True
# Input: -1 - -3 - -3, Actual: 5.00, Predicted Range: [4.92, 5.42], bootstrapped prediction: [5.182724], in Range: True
# Input: 2 + -3 + -5, Actual: -6.00, Predicted Range: [-6.45, -5.70], bootstrapped prediction: [-6.0384245], in Range: True
# Input: -1 + -5 - 1, Actual: -7.00, Predicted Range: [-7.39, -6.75], bootstrapped prediction: [-7.015001], in Range: True
# Input: -5 + -4 + -5, Actual: -14.00, Predicted Range: [-14.12, -13.52], bootstrapped prediction: [-13.866613], in Range: True
# Input: 2 + 1 - 1, Actual: 2.00, Predicted Range: [1.64, 2.40], bootstrapped prediction: [2.014042], in Range: True
# Input: -1 + 2 - 2, Actual: -1.00, Predicted Range: [-1.10, -0.40], bootstrapped prediction: [-0.84826803], in Range: True
# Input: 2 + -5 - -5, Actual: 2.00, Predicted Range: [1.88, 2.40], bootstrapped prediction: [2.1259186], in Range: True
# Input: 2 + -2 - -4, Actual: 4.00, Predicted Range: [3.86, 4.22], bootstrapped prediction: [4.0604353], in Range: True
# Input: 2 - -2 - 3, Actual: 1.00, Predicted Range: [0.62, 1.20], bootstrapped prediction: [0.918717], in Range: True
# Input: 4 + 0 + 2, Actual: 6.00, Predicted Range: [5.69, 6.39], bootstrapped prediction: [6.030172], in Range: True
# Input: 0 + 0 + -5, Actual: -5.00, Predicted Range: [-5.07, -4.76], bootstrapped prediction: [-4.964909], in Range: True
# Input: 3 + -3 + -2, Actual: -2.00, Predicted Range: [-2.17, -1.68], bootstrapped prediction: [-1.9982144], in Range: True
# Input: 1 + 2 - 0, Actual: 3.00, Predicted Range: [2.84, 3.30], bootstrapped prediction: [3.1072278], in Range: True
# Input: 1 - 0 + 1, Actual: 2.00, Predicted Range: [1.74, 2.35], bootstrapped prediction: [2.0591486], in Range: True
# Input: -2 + 4 - 3, Actual: -1.00, Predicted Range: [-1.37, -0.89], bootstrapped prediction: [-1.1050851], in Range: True
# Input: -4 - 4 - 4, Actual: -12.00, Predicted Range: [-11.91, -11.25], bootstrapped prediction: [-11.632938], in Range: False
# Input: -4 + 4 + -4, Actual: -4.00, Predicted Range: [-4.48, -3.39], bootstrapped prediction: [-3.9711869], in Range: True
# Input: 3 - 3 + -1, Actual: -1.00, Predicted Range: [-1.40, -0.75], bootstrapped prediction: [-1.0901061], in Range: True
# Input: -4 - -4 - 3, Actual: -3.00, Predicted Range: [-3.38, -2.75], bootstrapped prediction: [-3.0429835], in Range: True
# Input: 4 + -2 + 0, Actual: 2.00, Predicted Range: [1.89, 2.44], bootstrapped prediction: [2.1115212], in Range: True
# Input: 4 + 1 + -4, Actual: 1.00, Predicted Range: [0.61, 1.36], bootstrapped prediction: [1.001024], in Range: True
# Input: -4 + -2 + -3, Actual: -9.00, Predicted Range: [-9.10, -8.88], bootstrapped prediction: [-8.984434], in Range: True
# Input: 4 - 3 + 2, Actual: 3.00, Predicted Range: [2.86, 3.50], bootstrapped prediction: [3.1010551], in Range: True
# Input: -3 - 2 + 1, Actual: -4.00, Predicted Range: [-4.28, -3.72], bootstrapped prediction: [-3.9546611], in Range: True
# Input: -4 + 1 + -4, Actual: -7.00, Predicted Range: [-7.27, -6.85], bootstrapped prediction: [-7.0685806], in Range: True
# Input: -2 + -2 - -5, Actual: 1.00, Predicted Range: [0.57, 1.14], bootstrapped prediction: [0.79986703], in Range: True
# Input: -2 - 2 - 1, Actual: -5.00, Predicted Range: [-5.35, -4.89], bootstrapped prediction: [-5.1162777], in Range: True
# Input: -5 - 4 - 4, Actual: -13.00, Predicted Range: [-12.87, -12.07], bootstrapped prediction: [-12.493297], in Range: False
# Input: 0 - 4 - -2, Actual: -2.00, Predicted Range: [-2.18, -1.53], bootstrapped prediction: [-1.942432], in Range: True
# Input: -2 + 3 - 1, Actual: 0.00, Predicted Range: [-0.21, 0.40], bootstrapped prediction: [0.15310654], in Range: True
# Input: 4 + -2 - -4, Actual: 6.00, Predicted Range: [5.72, 6.09], bootstrapped prediction: [5.9751167], in Range: True
# Input: 1 + 2 + -5, Actual: -2.00, Predicted Range: [-2.10, -1.68], bootstrapped prediction: [-1.8853328], in Range: True
# Input: -3 - -2 + -4, Actual: -5.00, Predicted Range: [-5.32, -4.90], bootstrapped prediction: [-5.0910883], in Range: True
# Input: 2 - 0 - 4, Actual: -2.00, Predicted Range: [-2.23, -1.48], bootstrapped prediction: [-1.9653606], in Range: True
# Input: 2 - 0 - -5, Actual: 7.00, Predicted Range: [6.74, 7.26], bootstrapped prediction: [7.0086527], in Range: True
# Input: 1 - -4 + -2, Actual: 3.00, Predicted Range: [2.85, 3.31], bootstrapped prediction: [3.042069], in Range: True
# Input: -5 - 1 + -4, Actual: -10.00, Predicted Range: [-10.15, -9.65], bootstrapped prediction: [-9.891406], in Range: True
# Input: 2 - -2 - -2, Actual: 6.00, Predicted Range: [5.68, 6.17], bootstrapped prediction: [5.9516444], in Range: True
# Input: -5 + 0 + 1, Actual: -4.00, Predicted Range: [-4.21, -3.92], bootstrapped prediction: [-4.0470247], in Range: True
# Input: 1 - -3 + -1, Actual: 3.00, Predicted Range: [2.75, 3.33], bootstrapped prediction: [3.0033884], in Range: True
# Input: 0 + -2 + -3, Actual: -5.00, Predicted Range: [-5.14, -4.85], bootstrapped prediction: [-5.0331063], in Range: True
# Input: -4 - 3 - -1, Actual: -6.00, Predicted Range: [-6.69, -5.59], bootstrapped prediction: [-6.0876436], in Range: True
# Input: 2 + 4 + -4, Actual: 2.00, Predicted Range: [1.55, 2.11], bootstrapped prediction: [1.8016104], in Range: True
# Input: 4 - -4 - 3, Actual: 5.00, Predicted Range: [4.72, 5.22], bootstrapped prediction: [4.9975643], in Range: True
# Input: 1 + 1 + 3, Actual: 5.00, Predicted Range: [4.78, 5.40], bootstrapped prediction: [5.0912356], in Range: True
# Input: -2 - -3 - -2, Actual: 3.00, Predicted Range: [2.76, 3.43], bootstrapped prediction: [3.102823], in Range: True
# Input: 2 - -5 + -1, Actual: 6.00, Predicted Range: [5.69, 6.28], bootstrapped prediction: [5.9847236], in Range: True
# Input: 3 + 0 + -4, Actual: -1.00, Predicted Range: [-1.38, -0.77], bootstrapped prediction: [-1.0390698], in Range: True
# Input: -2 + -1 - -3, Actual: 0.00, Predicted Range: [-0.17, 0.30], bootstrapped prediction: [0.04355651], in Range: True
# Input: -2 - 0 + 0, Actual: -2.00, Predicted Range: [-2.28, -1.85], bootstrapped prediction: [-2.1033235], in Range: True
# Input: 2 + 1 - -5, Actual: 8.00, Predicted Range: [7.64, 8.26], bootstrapped prediction: [7.9532633], in Range: True
# Input: 2 + 1 + -3, Actual: 0.00, Predicted Range: [-0.23, 0.15], bootstrapped prediction: [-0.00208241], in Range: True
# Input: -5 + -4 + 2, Actual: -7.00, Predicted Range: [-7.36, -6.76], bootstrapped prediction: [-7.0291853], in Range: True
# Input: 0 + -5 + -4, Actual: -9.00, Predicted Range: [-9.18, -8.70], bootstrapped prediction: [-8.914438], in Range: True
# Input: -3 + -5 + 0, Actual: -8.00, Predicted Range: [-8.20, -7.50], bootstrapped prediction: [-7.9003577], in Range: True
# Input: 0 + 1 + 0, Actual: 1.00, Predicted Range: [0.85, 1.28], bootstrapped prediction: [1.1165941], in Range: True
# Input: -5 - -3 + -2, Actual: -4.00, Predicted Range: [-4.24, -3.55], bootstrapped prediction: [-3.9186432], in Range: True
# Input: -2 + -1 - 1, Actual: -4.00, Predicted Range: [-4.24, -3.68], bootstrapped prediction: [-3.9955611], in Range: True
# Input: -1 + -3 - 0, Actual: -4.00, Predicted Range: [-4.40, -3.82], bootstrapped prediction: [-4.1357126], in Range: True
# Input: -1 + 4 + -1, Actual: 2.00, Predicted Range: [1.60, 2.12], bootstrapped prediction: [1.891375], in Range: True
# Input: -5 + 3 - -5, Actual: 3.00, Predicted Range: [2.45, 3.18], bootstrapped prediction: [2.82324], in Range: True
# Input: 2 + -3 + -1, Actual: -2.00, Predicted Range: [-2.21, -1.68], bootstrapped prediction: [-1.9873981], in Range: True
# Input: -5 - 0 + 2, Actual: -3.00, Predicted Range: [-3.18, -2.55], bootstrapped prediction: [-2.9058068], in Range: True
# Input: 4 - 4 + 3, Actual: 3.00, Predicted Range: [2.62, 3.39], bootstrapped prediction: [3.11309], in Range: True
# Input: 3 - -4 + 1, Actual: 8.00, Predicted Range: [7.71, 8.09], bootstrapped prediction: [7.9175043], in Range: True
# Input: 0 - -5 + -2, Actual: 3.00, Predicted Range: [2.79, 3.34], bootstrapped prediction: [3.0097823], in Range: True
# Input: 4 - 0 - -4, Actual: 8.00, Predicted Range: [7.63, 8.21], bootstrapped prediction: [7.940165], in Range: True
# Input: -4 + 4 + 3, Actual: 3.00, Predicted Range: [2.49, 3.13], bootstrapped prediction: [2.8122091], in Range: True
# Input: 4 - -5 + -5, Actual: 4.00, Predicted Range: [3.53, 4.49], bootstrapped prediction: [4.0450277], in Range: True
# Input: -4 + 1 + -1, Actual: -4.00, Predicted Range: [-4.27, -3.81], bootstrapped prediction: [-3.9951298], in Range: True
# Input: -3 + 0 + 3, Actual: 0.00, Predicted Range: [-0.31, 0.21], bootstrapped prediction: [0.00838408], in Range: True
# Input: 4 - 1 - 2, Actual: 1.00, Predicted Range: [0.74, 1.42], bootstrapped prediction: [1.1431205], in Range: True
# Input: 2 + -3 + 2, Actual: 1.00, Predicted Range: [0.94, 1.36], bootstrapped prediction: [1.1488576], in Range: True
# Input: -4 - 3 + -2, Actual: -9.00, Predicted Range: [-9.13, -8.46], bootstrapped prediction: [-8.812838], in Range: True
# Input: 2 - -4 - 0, Actual: 6.00, Predicted Range: [5.84, 6.37], bootstrapped prediction: [6.089705], in Range: True
# Input: -4 + 2 + -5, Actual: -7.00, Predicted Range: [-7.11, -6.68], bootstrapped prediction: [-6.9257917], in Range: True
# Input: 3 - -5 - 0, Actual: 8.00, Predicted Range: [7.70, 8.17], bootstrapped prediction: [7.954783], in Range: True
# Input: -3 - -4 - -5, Actual: 6.00, Predicted Range: [5.61, 6.06], bootstrapped prediction: [5.8398347], in Range: True
# Input: -1 - 2 + -1, Actual: -4.00, Predicted Range: [-4.10, -3.71], bootstrapped prediction: [-3.9387956], in Range: True
# Input: 3 + -1 + -2, Actual: 0.00, Predicted Range: [-0.13, 0.36], bootstrapped prediction: [0.06772918], in Range: True
# Input: -1 - 2 + -2, Actual: -5.00, Predicted Range: [-5.17, -4.67], bootstrapped prediction: [-4.943791], in Range: True
# Input: -4 - -1 + 4, Actual: 1.00, Predicted Range: [0.70, 1.18], bootstrapped prediction: [0.95328236], in Range: True
# Input: -5 + -2 - 4, Actual: -11.00, Predicted Range: [-11.22, -10.50], bootstrapped prediction: [-10.810364], in Range: True
# Input: 3 + -3 + -4, Actual: -4.00, Predicted Range: [-4.40, -3.92], bootstrapped prediction: [-4.126712], in Range: True
# Input: -3 - 2 - -1, Actual: -4.00, Predicted Range: [-4.50, -3.59], bootstrapped prediction: [-4.026923], in Range: True
# Input: 1 - 0 + -3, Actual: -2.00, Predicted Range: [-2.36, -1.89], bootstrapped prediction: [-2.1557546], in Range: True
# Input: -5 + -2 + -1, Actual: -8.00, Predicted Range: [-8.10, -7.68], bootstrapped prediction: [-7.8635836], in Range: True
# Input: -2 + -1 + 0, Actual: -3.00, Predicted Range: [-3.47, -2.85], bootstrapped prediction: [-3.1057067], in Range: True
# Input: 4 - -2 + 1, Actual: 7.00, Predicted Range: [6.65, 7.15], bootstrapped prediction: [6.924646], in Range: True
# Input: -1 + -3 + 1, Actual: -3.00, Predicted Range: [-3.30, -2.76], bootstrapped prediction: [-3.0612464], in Range: True
# Input: 1 - -5 - -5, Actual: 11.00, Predicted Range: [10.36, 10.96], bootstrapped prediction: [10.71488], in Range: False
# Input: 3 - 1 + -3, Actual: -1.00, Predicted Range: [-1.28, -0.70], bootstrapped prediction: [-0.996925], in Range: True
# Input: 1 - 3 - 2, Actual: -4.00, Predicted Range: [-4.53, -4.03], bootstrapped prediction: [-4.2872553], in Range: False
# Input: 3 - 0 - 3, Actual: 0.00, Predicted Range: [-0.10, 0.38], bootstrapped prediction: [0.05160908], in Range: True
# Input: 1 + -3 + -2, Actual: -4.00, Predicted Range: [-4.14, -3.72], bootstrapped prediction: [-3.9813995], in Range: True
# Input: 2 + 4 + -2, Actual: 4.00, Predicted Range: [3.78, 4.24], bootstrapped prediction: [3.9413471], in Range: True
# Input: -4 - -1 + -1, Actual: -4.00, Predicted Range: [-4.18, -3.75], bootstrapped prediction: [-3.9666939], in Range: True
# Input: -1 - 2 + -5, Actual: -8.00, Predicted Range: [-8.35, -7.79], bootstrapped prediction: [-8.0028], in Range: True
# Input: -1 + -2 + -1, Actual: -4.00, Predicted Range: [-4.33, -3.85], bootstrapped prediction: [-4.022797], in Range: True
# Input: -5 + 1 - -3, Actual: -1.00, Predicted Range: [-1.23, -0.79], bootstrapped prediction: [-0.9948184], in Range: True
# Input: 1 - -5 + 1, Actual: 7.00, Predicted Range: [6.71, 7.19], bootstrapped prediction: [6.9347878], in Range: True
# Input: -4 + -2 - 3, Actual: -9.00, Predicted Range: [-9.26, -8.82], bootstrapped prediction: [-9.010303], in Range: True
# Input: 4 + -3 - 2, Actual: -1.00, Predicted Range: [-1.34, -0.69], bootstrapped prediction: [-1.0550772], in Range: True
# Input: 4 + 2 - -3, Actual: 9.00, Predicted Range: [8.86, 9.31], bootstrapped prediction: [9.050493], in Range: True
# Input: 0 + -3 - -4, Actual: 1.00, Predicted Range: [0.81, 1.19], bootstrapped prediction: [0.9848534], in Range: True
# Input: 1 - 2 + 2, Actual: 1.00, Predicted Range: [0.96, 1.37], bootstrapped prediction: [1.1219027], in Range: True
# Input: -4 - 4 - -1, Actual: -7.00, Predicted Range: [-7.28, -6.70], bootstrapped prediction: [-6.9596252], in Range: True
# Input: 2 - -1 + -4, Actual: -1.00, Predicted Range: [-1.27, -0.86], bootstrapped prediction: [-1.0998789], in Range: True
# Input: 2 - 1 + -5, Actual: -4.00, Predicted Range: [-4.22, -3.54], bootstrapped prediction: [-3.9379096], in Range: True
# Input: -4 + 0 - 4, Actual: -8.00, Predicted Range: [-8.15, -7.64], bootstrapped prediction: [-7.8420205], in Range: True
# Input: 1 + 2 + 0, Actual: 3.00, Predicted Range: [2.84, 3.39], bootstrapped prediction: [3.1633213], in Range: True
# Input: 3 + 2 + -2, Actual: 3.00, Predicted Range: [2.75, 3.54], bootstrapped prediction: [3.0776267], in Range: True
# Input: 1 - -3 - 0, Actual: 4.00, Predicted Range: [3.79, 4.34], bootstrapped prediction: [4.10752], in Range: True
# Input: -3 + -3 + 1, Actual: -5.00, Predicted Range: [-5.30, -4.87], bootstrapped prediction: [-5.0838747], in Range: True
# Input: 1 - 0 - 3, Actual: -2.00, Predicted Range: [-2.35, -1.85], bootstrapped prediction: [-2.0856488], in Range: True
# Input: 3 - 0 + 4, Actual: 7.00, Predicted Range: [6.49, 7.10], bootstrapped prediction: [6.838604], in Range: True
# Input: -2 - -3 + 2, Actual: 3.00, Predicted Range: [2.83, 3.50], bootstrapped prediction: [3.083259], in Range: True
# Input: 4 - 1 + -4, Actual: -1.00, Predicted Range: [-1.31, -0.49], bootstrapped prediction: [-0.87501955], in Range: True
# Input: 4 + 1 + -3, Actual: 2.00, Predicted Range: [1.62, 2.42], bootstrapped prediction: [2.0288126], in Range: True
# Input: -2 + 2 - -1, Actual: 1.00, Predicted Range: [0.80, 1.55], bootstrapped prediction: [1.1145842], in Range: True
# Input: -3 + -5 + 1, Actual: -7.00, Predicted Range: [-7.19, -6.59], bootstrapped prediction: [-6.9232078], in Range: True
# Input: -3 + 4 - -2, Actual: 3.00, Predicted Range: [2.77, 3.21], bootstrapped prediction: [2.9711976], in Range: True
# Input: -4 - 1 - -4, Actual: -1.00, Predicted Range: [-1.23, -0.71], bootstrapped prediction: [-0.98094547], in Range: True
# Input: -4 + -2 - -2, Actual: -4.00, Predicted Range: [-4.19, -3.85], bootstrapped prediction: [-4.025422], in Range: True
# Input: 3 + -4 + 3, Actual: 2.00, Predicted Range: [1.95, 2.22], bootstrapped prediction: [2.0625803], in Range: True
# Input: 0 - -3 + -1, Actual: 2.00, Predicted Range: [1.80, 2.22], bootstrapped prediction: [1.9784088], in Range: True
# Input: -3 - -2 + -5, Actual: -6.00, Predicted Range: [-6.26, -5.84], bootstrapped prediction: [-6.023628], in Range: True
# Input: -3 + 2 - -1, Actual: 0.00, Predicted Range: [-0.14, 0.46], bootstrapped prediction: [0.07691865], in Range: True
# Input: -3 + 4 - 1, Actual: 0.00, Predicted Range: [-0.32, 0.13], bootstrapped prediction: [-0.06472014], in Range: True
# Input: 3 + 4 - -5, Actual: 12.00, Predicted Range: [10.94, 11.63], bootstrapped prediction: [11.350424], in Range: False
# Input: -3 + 2 + -5, Actual: -6.00, Predicted Range: [-6.15, -5.59], bootstrapped prediction: [-5.9110417], in Range: True
# Input: 2 + -2 + 3, Actual: 3.00, Predicted Range: [2.81, 3.36], bootstrapped prediction: [3.05799], in Range: True
# Input: 2 + -1 - -1, Actual: 2.00, Predicted Range: [1.86, 2.19], bootstrapped prediction: [2.026087], in Range: True
# Input: 4 + -2 + 2, Actual: 4.00, Predicted Range: [3.86, 4.41], bootstrapped prediction: [4.1171722], in Range: True
# Input: 4 - 4 + -4, Actual: -4.00, Predicted Range: [-4.01, -3.52], bootstrapped prediction: [-3.7812836], in Range: True
# Input: 3 - 3 + -2, Actual: -2.00, Predicted Range: [-2.41, -1.81], bootstrapped prediction: [-2.06209], in Range: True
# Input: 4 + 1 - 3, Actual: 2.00, Predicted Range: [1.88, 2.29], bootstrapped prediction: [2.095343], in Range: True
# Input: -3 - -1 - 3, Actual: -5.00, Predicted Range: [-5.18, -4.77], bootstrapped prediction: [-4.986337], in Range: True
# Input: -3 + -3 - 4, Actual: -10.00, Predicted Range: [-10.11, -9.75], bootstrapped prediction: [-9.960711], in Range: True
# Input: -1 - -3 + 0, Actual: 2.00, Predicted Range: [1.85, 2.35], bootstrapped prediction: [2.0316904], in Range: True
# Input: -5 + 0 - -1, Actual: -4.00, Predicted Range: [-4.25, -3.71], bootstrapped prediction: [-3.9431548], in Range: True
# Input: 1 - 3 + 0, Actual: -2.00, Predicted Range: [-2.32, -2.04], bootstrapped prediction: [-2.1357472], in Range: False
# Input: -2 - 1 - -3, Actual: 0.00, Predicted Range: [-0.18, 0.31], bootstrapped prediction: [0.02111931], in Range: True
# Input: 4 - 2 - 3, Actual: -1.00, Predicted Range: [-1.27, -0.70], bootstrapped prediction: [-0.9202032], in Range: True
# Input: -2 - -2 + -2, Actual: -2.00, Predicted Range: [-2.37, -1.65], bootstrapped prediction: [-2.0865421], in Range: True
# Input: 1 - 3 + 3, Actual: 1.00, Predicted Range: [0.89, 1.52], bootstrapped prediction: [1.1223899], in Range: True
# Input: 3 + -1 - -2, Actual: 4.00, Predicted Range: [3.71, 4.28], bootstrapped prediction: [4.0110087], in Range: True
# Input: 3 - 4 + 1, Actual: 0.00, Predicted Range: [-0.29, 0.42], bootstrapped prediction: [0.08498372], in Range: True
# Input: -4 - -3 - -3, Actual: 2.00, Predicted Range: [1.74, 2.31], bootstrapped prediction: [2.0151546], in Range: True
# Input: -1 - -5 - 0, Actual: 4.00, Predicted Range: [3.58, 4.49], bootstrapped prediction: [4.071233], in Range: True
# Input: 3 + -5 + 3, Actual: 1.00, Predicted Range: [0.96, 1.45], bootstrapped prediction: [1.2090576], in Range: True
# Input: 3 + -2 - -2, Actual: 3.00, Predicted Range: [2.73, 3.23], bootstrapped prediction: [3.0150478], in Range: True
# Input: -4 - 1 + -5, Actual: -10.00, Predicted Range: [-10.01, -9.67], bootstrapped prediction: [-9.836993], in Range: True
# Input: -5 + 4 + -3, Actual: -4.00, Predicted Range: [-4.42, -3.37], bootstrapped prediction: [-3.9825845], in Range: True
# Input: -3 - -2 + -1, Actual: -2.00, Predicted Range: [-2.31, -1.70], bootstrapped prediction: [-2.0004299], in Range: True
# Input: 2 + 4 - -5, Actual: 11.00, Predicted Range: [10.17, 10.77], bootstrapped prediction: [10.4446125], in Range: False
# Input: 1 - 4 + 4, Actual: 1.00, Predicted Range: [0.44, 1.18], bootstrapped prediction: [0.86464465], in Range: True
# Input: -5 - 4 + -2, Actual: -11.00, Predicted Range: [-10.97, -10.09], bootstrapped prediction: [-10.669035], in Range: False
# Input: -5 + -3 + -5, Actual: -13.00, Predicted Range: [-13.16, -12.61], bootstrapped prediction: [-12.881282], in Range: True
# Input: 1 + 1 - -3, Actual: 5.00, Predicted Range: [5.02, 5.30], bootstrapped prediction: [5.177482], in Range: False
# Input: 1 + 4 - 3, Actual: 2.00, Predicted Range: [1.66, 2.15], bootstrapped prediction: [1.9038073], in Range: True
# Input: 4 - -3 - 1, Actual: 6.00, Predicted Range: [5.76, 6.35], bootstrapped prediction: [6.018429], in Range: True
# Input: -2 + 2 + 3, Actual: 3.00, Predicted Range: [2.96, 3.45], bootstrapped prediction: [3.1697283], in Range: True
# Input: 2 + -5 - 2, Actual: -5.00, Predicted Range: [-5.04, -4.67], bootstrapped prediction: [-4.8653045], in Range: True
# Input: -4 - -3 - -1, Actual: 0.00, Predicted Range: [-0.11, 0.26], bootstrapped prediction: [0.0718288], in Range: True
# Input: -5 - -4 - 1, Actual: -2.00, Predicted Range: [-2.15, -1.71], bootstrapped prediction: [-1.9449599], in Range: True
# Input: -5 + -4 - 1, Actual: -10.00, Predicted Range: [-10.15, -9.43], bootstrapped prediction: [-9.834401], in Range: True
# Input: -1 + 1 - -1, Actual: 1.00, Predicted Range: [0.76, 1.25], bootstrapped prediction: [0.96897364], in Range: True
# Input: 2 - -5 + 4, Actual: 11.00, Predicted Range: [10.26, 11.02], bootstrapped prediction: [10.680868], in Range: True
# Input: 0 - 1 + -2, Actual: -3.00, Predicted Range: [-3.31, -2.81], bootstrapped prediction: [-3.0619454], in Range: True
# Input: 4 + 3 - 3, Actual: 4.00, Predicted Range: [3.72, 4.35], bootstrapped prediction: [4.0881214], in Range: True
# Input: 0 + 4 - 1, Actual: 3.00, Predicted Range: [2.91, 3.39], bootstrapped prediction: [3.1009395], in Range: True
# Input: 1 - -2 - -3, Actual: 6.00, Predicted Range: [5.80, 6.49], bootstrapped prediction: [6.1348453], in Range: True
# Input: -3 - -2 + 1, Actual: 0.00, Predicted Range: [-0.36, 0.21], bootstrapped prediction: [-0.09287139], in Range: True
# Input: -5 - -1 - 4, Actual: -8.00, Predicted Range: [-8.26, -7.52], bootstrapped prediction: [-7.9475822], in Range: True
# Input: -3 - -2 - 2, Actual: -3.00, Predicted Range: [-3.23, -2.81], bootstrapped prediction: [-3.0364442], in Range: True
# Input: 0 + 3 - 2, Actual: 1.00, Predicted Range: [0.95, 1.61], bootstrapped prediction: [1.1567265], in Range: True
# Input: -2 - 3 - -1, Actual: -4.00, Predicted Range: [-4.55, -3.59], bootstrapped prediction: [-4.1370344], in Range: True
# Input: -4 + 3 + 0, Actual: -1.00, Predicted Range: [-1.18, -0.73], bootstrapped prediction: [-1.0111812], in Range: True
# Input: 2 + 0 - 1, Actual: 1.00, Predicted Range: [0.74, 1.33], bootstrapped prediction: [0.9673344], in Range: True
# Input: -3 + -4 - -5, Actual: -2.00, Predicted Range: [-2.37, -1.86], bootstrapped prediction: [-2.0981503], in Range: True
# Input: -5 + 4 - 4, Actual: -5.00, Predicted Range: [-5.64, -4.89], bootstrapped prediction: [-5.180726], in Range: True
# Input: 2 + -3 - -3, Actual: 2.00, Predicted Range: [1.72, 2.13], bootstrapped prediction: [1.9275137], in Range: True
# Input: -5 - -1 + 4, Actual: 0.00, Predicted Range: [-0.30, 0.15], bootstrapped prediction: [-0.11414135], in Range: True
# Input: -2 + 0 + -5, Actual: -7.00, Predicted Range: [-7.18, -6.76], bootstrapped prediction: [-6.989934], in Range: True
# Input: -5 - -1 + -2, Actual: -6.00, Predicted Range: [-6.19, -5.58], bootstrapped prediction: [-5.8557453], in Range: True
# Input: 2 + 2 + -3, Actual: 1.00, Predicted Range: [0.76, 1.39], bootstrapped prediction: [1.0689858], in Range: True
# Input: -3 + 2 + 0, Actual: -1.00, Predicted Range: [-1.20, -0.72], bootstrapped prediction: [-1.0118244], in Range: True
# Input: -3 - 3 + -4, Actual: -10.00, Predicted Range: [-10.28, -9.76], bootstrapped prediction: [-10.068569], in Range: True
# Input: -3 - 1 - -3, Actual: -1.00, Predicted Range: [-1.10, -0.69], bootstrapped prediction: [-0.9591646], in Range: True
# Input: -3 + -2 + 4, Actual: -1.00, Predicted Range: [-1.19, -0.73], bootstrapped prediction: [-0.9197739], in Range: True
# Input: 1 + 1 + 0, Actual: 2.00, Predicted Range: [1.85, 2.35], bootstrapped prediction: [2.1101508], in Range: True
# Input: 2 + 2 + -2, Actual: 2.00, Predicted Range: [1.68, 2.50], bootstrapped prediction: [2.0673301], in Range: True
# Input: -2 - 4 + -4, Actual: -10.00, Predicted Range: [-10.24, -9.61], bootstrapped prediction: [-9.963431], in Range: True
# Input: 3 - -4 - 4, Actual: 3.00, Predicted Range: [2.76, 3.13], bootstrapped prediction: [2.9718323], in Range: True
# Input: 4 - 4 - 3, Actual: -3.00, Predicted Range: [-3.05, -2.30], bootstrapped prediction: [-2.6234334], in Range: True
# Input: 2 + -1 - -3, Actual: 4.00, Predicted Range: [3.96, 4.33], bootstrapped prediction: [4.115613], in Range: True
# Input: 0 - -5 - 4, Actual: 1.00, Predicted Range: [0.64, 1.27], bootstrapped prediction: [0.95500976], in Range: True
# Input: 2 + -2 - 3, Actual: -3.00, Predicted Range: [-3.30, -2.76], bootstrapped prediction: [-3.066083], in Range: True
# Input: 2 + -1 - -4, Actual: 5.00, Predicted Range: [4.88, 5.27], bootstrapped prediction: [5.1116714], in Range: True
# Input: -1 - -2 + 4, Actual: 5.00, Predicted Range: [4.72, 5.32], bootstrapped prediction: [5.0451574], in Range: True
# Input: 2 + 2 + 1, Actual: 5.00, Predicted Range: [4.84, 5.33], bootstrapped prediction: [5.125296], in Range: True
# Input: 4 - 2 + -3, Actual: -1.00, Predicted Range: [-1.40, -0.62], bootstrapped prediction: [-0.91204584], in Range: True
# Input: -5 - -2 + -1, Actual: -4.00, Predicted Range: [-4.28, -3.68], bootstrapped prediction: [-3.9479485], in Range: True
# Input: 3 + -1 - 1, Actual: 1.00, Predicted Range: [0.75, 1.41], bootstrapped prediction: [1.0347388], in Range: True
# Input: -1 - -4 + -2, Actual: 1.00, Predicted Range: [0.82, 1.25], bootstrapped prediction: [0.989318], in Range: True
# Input: -4 + -2 + -2, Actual: -8.00, Predicted Range: [-8.07, -7.73], bootstrapped prediction: [-7.924259], in Range: True
# Input: 3 + 2 - 1, Actual: 4.00, Predicted Range: [3.75, 4.31], bootstrapped prediction: [4.1000757], in Range: True
# Input: -3 + -2 - -5, Actual: 0.00, Predicted Range: [-0.55, 0.16], bootstrapped prediction: [-0.23536988], in Range: True
# Input: -2 - 0 - -5, Actual: 3.00, Predicted Range: [2.51, 3.14], bootstrapped prediction: [2.8351882], in Range: True
# Input: 4 + 2 + -2, Actual: 4.00, Predicted Range: [3.70, 4.46], bootstrapped prediction: [4.086519], in Range: True
# Input: -3 - 3 - -2, Actual: -4.00, Predicted Range: [-4.58, -3.65], bootstrapped prediction: [-4.102465], in Range: True
# Input: 1 - 4 + -4, Actual: -7.00, Predicted Range: [-7.15, -6.72], bootstrapped prediction: [-6.9414473], in Range: True
# Input: -2 + -2 - -3, Actual: -1.00, Predicted Range: [-1.37, -0.86], bootstrapped prediction: [-1.0729744], in Range: True
# Input: 0 - 1 + -5, Actual: -6.00, Predicted Range: [-6.36, -5.72], bootstrapped prediction: [-5.9922757], in Range: True
# Input: -1 + 4 - 4, Actual: -1.00, Predicted Range: [-1.38, -0.79], bootstrapped prediction: [-1.0508957], in Range: True
# Input: -4 - 4 - -4, Actual: -4.00, Predicted Range: [-4.16, -3.54], bootstrapped prediction: [-3.8803935], in Range: True
# Input: -3 + -3 + -2, Actual: -8.00, Predicted Range: [-8.19, -7.71], bootstrapped prediction: [-8.000885], in Range: True
# Input: 0 + -2 + -2, Actual: -4.00, Predicted Range: [-4.21, -3.80], bootstrapped prediction: [-3.9691567], in Range: True
# Input: 1 - -4 - -3, Actual: 8.00, Predicted Range: [7.83, 8.26], bootstrapped prediction: [8.058573], in Range: True
# Input: 2 + -2 + -5, Actual: -5.00, Predicted Range: [-5.36, -4.72], bootstrapped prediction: [-5.0210414], in Range: True
# Input: 3 + -5 - -3, Actual: 1.00, Predicted Range: [0.90, 1.24], bootstrapped prediction: [1.0281508], in Range: True
# Input: -1 - -4 - 3, Actual: 0.00, Predicted Range: [-0.24, 0.35], bootstrapped prediction: [0.01945368], in Range: True
# Input: 1 - 2 + -1, Actual: -2.00, Predicted Range: [-2.30, -1.77], bootstrapped prediction: [-2.0525575], in Range: True
# Input: -2 - -1 - 0, Actual: -1.00, Predicted Range: [-1.39, -0.75], bootstrapped prediction: [-1.015855], in Range: True
# Input: 4 + -3 + 2, Actual: 3.00, Predicted Range: [2.89, 3.48], bootstrapped prediction: [3.1421773], in Range: True
# Input: 0 + -2 - -1, Actual: -1.00, Predicted Range: [-1.50, -0.78], bootstrapped prediction: [-1.1163228], in Range: True
# Input: -1 - 4 - -4, Actual: -1.00, Predicted Range: [-1.18, -0.42], bootstrapped prediction: [-0.935524], in Range: True
# Input: -5 + 1 - 4, Actual: -8.00, Predicted Range: [-8.11, -7.44], bootstrapped prediction: [-7.8244925], in Range: True
# Input: 0 + 2 + 1, Actual: 3.00, Predicted Range: [2.91, 3.33], bootstrapped prediction: [3.1612766], in Range: True
# Input: -5 - 2 + -5, Actual: -12.00, Predicted Range: [-11.90, -11.30], bootstrapped prediction: [-11.657804], in Range: False
# Input: -1 - 3 - -5, Actual: 1.00, Predicted Range: [0.16, 1.12], bootstrapped prediction: [0.7839023], in Range: True
# ...
# Input: -4 + 1 - 3, Actual: -6.00, Predicted Range: [-6.17, -5.73], bootstrapped prediction: [-5.908155], in Range: True
# Input: -4 - 1 - -1, Actual: -4.00, Predicted Range: [-4.36, -3.65], bootstrapped prediction: [-3.9484093], in Range: True
# Input: 1 - -4 - 3, Actual: 2.00, Predicted Range: [1.85, 2.11], bootstrapped prediction: [1.9846447], in Range: True
# Input: -4 - 4 - -5, Actual: -3.00, Predicted Range: [-3.28, -2.42], bootstrapped prediction: [-2.9222922], in Range: True
# Input: 1 - 1 + 0, Actual: 0.00, Predicted Range: [-0.50, 0.22], bootstrapped prediction: [-0.11111553], in Range: True
# Input: 2 - -5 - 0, Actual: 7.00, Predicted Range: [6.68, 7.27], bootstrapped prediction: [7.00944], in Range: True
# Input: 2 - -4 - -1, Actual: 7.00, Predicted Range: [6.86, 7.38], bootstrapped prediction: [7.0829835], in Range: True
# Input: -5 - 2 + 1, Actual: -6.00, Predicted Range: [-6.25, -5.50], bootstrapped prediction: [-5.9261217], in Range: True
# Input: 2 + -3 + 4, Actual: 3.00, Predicted Range: [2.66, 3.17], bootstrapped prediction: [2.8942187], in Range: True
# Input: 1 + 0 - -3, Actual: 4.00, Predicted Range: [4.00, 4.28], bootstrapped prediction: [4.143161], in Range: False
# Input: 4 + 4 + -5, Actual: 3.00, Predicted Range: [2.47, 3.37], bootstrapped prediction: [2.9478338], in Range: True
# Input: -1 + 2 - 4, Actual: -3.00, Predicted Range: [-3.03, -2.67], bootstrapped prediction: [-2.870819], in Range: True
# Input: 1 + 2 - -4, Actual: 7.00, Predicted Range: [7.00, 7.41], bootstrapped prediction: [7.2121954], in Range: True
# Input: 2 - 3 - -5, Actual: 4.00, Predicted Range: [3.50, 4.07], bootstrapped prediction: [3.8271909], in Range: True
# Input: -2 - -3 - -3, Actual: 4.00, Predicted Range: [3.85, 4.42], bootstrapped prediction: [4.114172], in Range: True
# Input: 0 - -5 - -3, Actual: 8.00, Predicted Range: [7.65, 8.19], bootstrapped prediction: [7.91213], in Range: True
# Input: -4 + 3 + 3, Actual: 2.00, Predicted Range: [1.89, 2.37], bootstrapped prediction: [2.1477103], in Range: True
# Input: 0 + -4 - 0, Actual: -4.00, Predicted Range: [-4.33, -3.92], bootstrapped prediction: [-4.099822], in Range: True
# Input: 0 + 0 - 3, Actual: -3.00, Predicted Range: [-3.08, -2.85], bootstrapped prediction: [-2.965529], in Range: True
# Input: 2 + 4 - 4, Actual: 2.00, Predicted Range: [1.44, 2.25], bootstrapped prediction: [1.8874829], in Range: True
# Input: 0 - 4 - -4, Actual: 0.00, Predicted Range: [-0.18, 0.61], bootstrapped prediction: [0.09145687], in Range: True
# Input: -1 - -5 + -3, Actual: 1.00, Predicted Range: [0.73, 1.14], bootstrapped prediction: [0.9113635], in Range: True
# Input: 0 + -5 + 1, Actual: -4.00, Predicted Range: [-4.19, -3.60], bootstrapped prediction: [-3.9191468], in Range: True
# Input: -5 + 0 + 4, Actual: -1.00, Predicted Range: [-1.36, -0.64], bootstrapped prediction: [-0.9668854], in Range: True
# Input: 4 - -4 + -2, Actual: 6.00, Predicted Range: [5.71, 6.26], bootstrapped prediction: [5.9521723], in Range: True
# Input: -4 + 4 + -5, Actual: -5.00, Predicted Range: [-5.47, -4.51], bootstrapped prediction: [-4.9701934], in Range: True
# Input: 0 + -3 + -1, Actual: -4.00, Predicted Range: [-4.18, -3.82], bootstrapped prediction: [-3.9857311], in Range: True
# Input: 2 - -1 - 1, Actual: 2.00, Predicted Range: [1.69, 2.18], bootstrapped prediction: [1.9426887], in Range: True
# Input: 3 - -1 + -4, Actual: 0.00, Predicted Range: [-0.29, 0.32], bootstrapped prediction: [-0.02365395], in Range: True
# Input: -4 - 1 + 3, Actual: -2.00, Predicted Range: [-2.11, -1.65], bootstrapped prediction: [-1.895045], in Range: True
# Input: 3 + -5 - -2, Actual: 0.00, Predicted Range: [-0.30, 0.45], bootstrapped prediction: [0.05500423], in Range: True
# Input: 4 + -4 + 1, Actual: 1.00, Predicted Range: [0.88, 1.24], bootstrapped prediction: [1.0468905], in Range: True
# Input: -5 + -4 + 3, Actual: -6.00, Predicted Range: [-6.52, -5.75], bootstrapped prediction: [-6.0580816], in Range: True
# Input: -4 - 4 + 0, Actual: -8.00, Predicted Range: [-8.22, -7.68], bootstrapped prediction: [-7.9645805], in Range: True
# Input: -1 + -3 - -1, Actual: -3.00, Predicted Range: [-3.37, -2.93], bootstrapped prediction: [-3.095615], in Range: True
# Input: 2 + -3 - 4, Actual: -5.00, Predicted Range: [-5.19, -4.76], bootstrapped prediction: [-4.958297], in Range: True
# Input: -2 - -3 + -3, Actual: -2.00, Predicted Range: [-2.30, -1.90], bootstrapped prediction: [-2.0928848], in Range: True
# Input: 0 - 1 + 3, Actual: 2.00, Predicted Range: [1.84, 2.60], bootstrapped prediction: [2.154981], in Range: True
# Input: 2 - 2 + -3, Actual: -3.00, Predicted Range: [-3.30, -2.83], bootstrapped prediction: [-3.0726504], in Range: True
# Input: 0 - -4 - 1, Actual: 3.00, Predicted Range: [2.88, 3.39], bootstrapped prediction: [3.130239], in Range: True
# Input: 2 + 2 + 2, Actual: 6.00, Predicted Range: [5.97, 6.27], bootstrapped prediction: [6.1314635], in Range: True
# Input: 3 + 3 - 3, Actual: 3.00, Predicted Range: [2.77, 3.27], bootstrapped prediction: [3.0666363], in Range: True
# Input: -2 - 3 - -5, Actual: 0.00, Predicted Range: [-0.73, 0.15], bootstrapped prediction: [-0.18687963], in Range: True
# Input: 1 - 2 + 4, Actual: 3.00, Predicted Range: [2.60, 3.19], bootstrapped prediction: [2.8684428], in Range: True
# Input: 4 + -3 + -3, Actual: -2.00, Predicted Range: [-2.12, -1.68], bootstrapped prediction: [-1.9333824], in Range: True
# Input: -5 + 0 + 0, Actual: -5.00, Predicted Range: [-5.29, -4.90], bootstrapped prediction: [-5.049313], in Range: True
# Input: -4 - -1 - -3, Actual: 0.00, Predicted Range: [-0.11, 0.39], bootstrapped prediction: [0.08918937], in Range: True
# Input: 0 - -3 + 2, Actual: 5.00, Predicted Range: [4.89, 5.52], bootstrapped prediction: [5.134819], in Range: True
# Input: -4 - 2 - -3, Actual: -3.00, Predicted Range: [-3.09, -2.66], bootstrapped prediction: [-2.9062371], in Range: True
# Input: 0 - 0 - 3, Actual: -3.00, Predicted Range: [-3.40, -2.83], bootstrapped prediction: [-3.0926614], in Range: True
# Input: 2 - 2 - -5, Actual: 5.00, Predicted Range: [4.66, 5.18], bootstrapped prediction: [4.909473], in Range: True
# Input: -5 + 4 + 0, Actual: -1.00, Predicted Range: [-1.38, -0.75], bootstrapped prediction: [-1.1134408], in Range: True
# Input: 4 - 1 + 2, Actual: 5.00, Predicted Range: [4.62, 5.40], bootstrapped prediction: [5.0814633], in Range: True
# Input: -1 - 3 - 3, Actual: -7.00, Predicted Range: [-7.58, -6.96], bootstrapped prediction: [-7.1974006], in Range: True
# Input: -2 + 4 + -1, Actual: 1.00, Predicted Range: [0.62, 1.25], bootstrapped prediction: [0.9202816], in Range: True
# Input: 3 + 3 - 2, Actual: 4.00, Predicted Range: [3.87, 4.21], bootstrapped prediction: [4.0298743], in Range: True
# Input: 3 + 4 + 0, Actual: 7.00, Predicted Range: [6.66, 7.07], bootstrapped prediction: [6.8974695], in Range: True
# Input: 3 + -2 - -1, Actual: 2.00, Predicted Range: [1.60, 2.41], bootstrapped prediction: [2.0362236], in Range: True
# Input: 4 + -3 + 1, Actual: 2.00, Predicted Range: [1.88, 2.34], bootstrapped prediction: [2.0995731], in Range: True
# Input: 1 - 4 - 0, Actual: -3.00, Predicted Range: [-3.43, -2.81], bootstrapped prediction: [-3.0580184], in Range: True
# Input: -3 - -2 + 4, Actual: 3.00, Predicted Range: [2.64, 3.38], bootstrapped prediction: [3.0087047], in Range: True
# Input: 1 + 4 + -3, Actual: 2.00, Predicted Range: [1.54, 2.17], bootstrapped prediction: [1.8588588], in Range: True
# Input: 3 + -1 + 0, Actual: 2.00, Predicted Range: [1.78, 2.33], bootstrapped prediction: [2.009871], in Range: True
# Input: -3 - 1 + -4, Actual: -8.00, Predicted Range: [-8.21, -7.86], bootstrapped prediction: [-8.050782], in Range: True
# Input: -3 - 4 + 2, Actual: -5.00, Predicted Range: [-5.44, -4.51], bootstrapped prediction: [-4.97413], in Range: True
# Input: -2 + 1 - 2, Actual: -3.00, Predicted Range: [-3.16, -2.53], bootstrapped prediction: [-2.8562746], in Range: True
# Input: -4 + 4 - -1, Actual: 1.00, Predicted Range: [0.45, 1.41], bootstrapped prediction: [0.88791865], in Range: True
# Input: -4 + -3 + -2, Actual: -9.00, Predicted Range: [-9.21, -8.71], bootstrapped prediction: [-8.996345], in Range: True
# Input: -2 - -1 - 1, Actual: -2.00, Predicted Range: [-2.46, -1.72], bootstrapped prediction: [-2.0324674], in Range: True
# Input: -5 + 3 + -2, Actual: -4.00, Predicted Range: [-4.10, -3.64], bootstrapped prediction: [-3.8999572], in Range: True
# Input: -3 + 1 - -3, Actual: 1.00, Predicted Range: [0.94, 1.53], bootstrapped prediction: [1.1536199], in Range: True
# Input: -2 + -3 + 2, Actual: -3.00, Predicted Range: [-3.31, -2.94], bootstrapped prediction: [-3.092176], in Range: True
# Input: 0 + -5 + 3, Actual: -2.00, Predicted Range: [-2.10, -1.61], bootstrapped prediction: [-1.8457559], in Range: True
# Input: -1 + -1 - 4, Actual: -6.00, Predicted Range: [-6.36, -5.68], bootstrapped prediction: [-5.9214087], in Range: True
# Input: 4 + 3 + 3, Actual: 10.00, Predicted Range: [9.77, 10.24], bootstrapped prediction: [10.009901], in Range: True
# Input: -2 - -2 + -4, Actual: -4.00, Predicted Range: [-4.35, -3.88], bootstrapped prediction: [-4.0834417], in Range: True
# Input: -1 + -4 - 4, Actual: -9.00, Predicted Range: [-9.32, -8.64], bootstrapped prediction: [-8.936857], in Range: True
# Input: 2 + -5 + 0, Actual: -3.00, Predicted Range: [-3.25, -2.74], bootstrapped prediction: [-2.9657795], in Range: True
# Input: -3 + 4 + 0, Actual: 1.00, Predicted Range: [0.71, 1.19], bootstrapped prediction: [0.95611113], in Range: True
# Input: -1 - -4 + -4, Actual: -1.00, Predicted Range: [-1.25, -0.88], bootstrapped prediction: [-1.0656908], in Range: True
# Input: -3 - 4 - 1, Actual: -8.00, Predicted Range: [-8.23, -7.59], bootstrapped prediction: [-7.9553757], in Range: True
# Input: 3 + 4 + -3, Actual: 4.00, Predicted Range: [3.58, 4.13], bootstrapped prediction: [3.915615], in Range: True
# Input: -1 - -3 - 0, Actual: 2.00, Predicted Range: [1.88, 2.43], bootstrapped prediction: [2.1203494], in Range: True
# Input: 0 + -5 - 4, Actual: -9.00, Predicted Range: [-9.04, -8.48], bootstrapped prediction: [-8.769651], in Range: True
# Input: 1 - 1 + -4, Actual: -4.00, Predicted Range: [-4.45, -3.94], bootstrapped prediction: [-4.159464], in Range: True
# Input: 3 - -1 + 2, Actual: 6.00, Predicted Range: [5.91, 6.42], bootstrapped prediction: [6.1968284], in Range: True
# Input: 0 - 0 - 1, Actual: -1.00, Predicted Range: [-1.43, -0.92], bootstrapped prediction: [-1.1681776], in Range: True
# Input: -5 + -4 + 0, Actual: -9.00, Predicted Range: [-9.12, -8.51], bootstrapped prediction: [-8.84821], in Range: True
# Input: 3 + -2 - 2, Actual: -1.00, Predicted Range: [-1.25, -0.80], bootstrapped prediction: [-1.027111], in Range: True
# Input: -2 + 4 - 1, Actual: 1.00, Predicted Range: [0.69, 1.22], bootstrapped prediction: [1.0133759], in Range: True
# Input: -3 - -4 - -1, Actual: 2.00, Predicted Range: [1.82, 2.33], bootstrapped prediction: [2.0324683], in Range: True
# Input: -5 + -1 + 3, Actual: -3.00, Predicted Range: [-3.13, -2.59], bootstrapped prediction: [-2.860138], in Range: True
# Input: 4 + -1 + -1, Actual: 2.00, Predicted Range: [1.85, 2.30], bootstrapped prediction: [2.0339828], in Range: True
# Input: 4 - 4 - 4, Actual: -4.00, Predicted Range: [-3.81, -3.10], bootstrapped prediction: [-3.4371612], in Range: False
# Input: -5 - -4 - -4, Actual: 3.00, Predicted Range: [2.63, 3.20], bootstrapped prediction: [2.9544778], in Range: True
# Input: -2 + 1 - -3, Actual: 2.00, Predicted Range: [1.94, 2.50], bootstrapped prediction: [2.2047648], in Range: True
# Input: -4 + -4 + 3, Actual: -5.00, Predicted Range: [-5.37, -4.90], bootstrapped prediction: [-5.060796], in Range: True
# Input: -3 - 3 + 0, Actual: -6.00, Predicted Range: [-6.29, -5.81], bootstrapped prediction: [-6.064046], in Range: True
# Input: -4 - -1 - -2, Actual: -1.00, Predicted Range: [-1.22, -0.78], bootstrapped prediction: [-0.9910244], in Range: True
# Input: 0 - 2 + -3, Actual: -5.00, Predicted Range: [-5.25, -4.89], bootstrapped prediction: [-5.087718], in Range: True
# Input: -4 + 1 - 0, Actual: -3.00, Predicted Range: [-3.29, -2.54], bootstrapped prediction: [-2.9648194], in Range: True
# Input: -4 + 0 - 2, Actual: -6.00, Predicted Range: [-6.34, -5.78], bootstrapped prediction: [-6.024866], in Range: True
# Input: 0 + -5 - -5, Actual: 0.00, Predicted Range: [-0.16, 0.36], bootstrapped prediction: [0.11779596], in Range: True
# Input: -1 - -3 + -3, Actual: -1.00, Predicted Range: [-1.25, -0.83], bootstrapped prediction: [-1.084349], in Range: True
# Input: 0 - 1 + -3, Actual: -4.00, Predicted Range: [-4.38, -3.91], bootstrapped prediction: [-4.1971726], in Range: True
# Input: -3 - 4 - 0, Actual: -7.00, Predicted Range: [-7.35, -6.82], bootstrapped prediction: [-7.0467024], in Range: True
# Input: 4 + 1 + 4, Actual: 9.00, Predicted Range: [8.56, 9.17], bootstrapped prediction: [8.870184], in Range: True
# Input: -4 - 3 + 1, Actual: -6.00, Predicted Range: [-6.19, -5.77], bootstrapped prediction: [-6.0157156], in Range: True
# Input: -4 + -3 + -1, Actual: -8.00, Predicted Range: [-8.12, -7.84], bootstrapped prediction: [-7.967183], in Range: True
# Input: -2 - -3 + 3, Actual: 4.00, Predicted Range: [3.86, 4.43], bootstrapped prediction: [4.1061964], in Range: True
# Input: 3 + 0 + 2, Actual: 5.00, Predicted Range: [4.76, 5.43], bootstrapped prediction: [5.064993], in Range: True
# Input: -1 - 1 - -5, Actual: 3.00, Predicted Range: [2.40, 3.29], bootstrapped prediction: [2.7849166], in Range: True
# Input: -3 - 0 + 0, Actual: -3.00, Predicted Range: [-3.32, -2.80], bootstrapped prediction: [-3.0779746], in Range: True
# Input: 2 - 2 + 4, Actual: 4.00, Predicted Range: [3.70, 4.06], bootstrapped prediction: [3.8529525], in Range: True
# Input: 0 + 3 - -4, Actual: 7.00, Predicted Range: [6.76, 7.40], bootstrapped prediction: [7.1295967], in Range: True
# Input: -4 - -5 + -2, Actual: -1.00, Predicted Range: [-1.33, -0.65], bootstrapped prediction: [-1.0067719], in Range: True
# Input: 2 - 1 - -1, Actual: 2.00, Predicted Range: [1.81, 2.28], bootstrapped prediction: [2.0313928], in Range: True
# Input: -2 - 1 - 1, Actual: -4.00, Predicted Range: [-4.33, -3.61], bootstrapped prediction: [-3.9938653], in Range: True
# Input: 2 - 1 + -1, Actual: 0.00, Predicted Range: [-0.45, 0.53], bootstrapped prediction: [-0.0889387], in Range: True
# Input: -2 - -5 - -2, Actual: 5.00, Predicted Range: [4.57, 5.25], bootstrapped prediction: [4.900495], in Range: True
# Input: 1 + 1 - 4, Actual: -2.00, Predicted Range: [-2.19, -1.74], bootstrapped prediction: [-1.9311945], in Range: True
# Input: -1 + 1 - 0, Actual: 0.00, Predicted Range: [-0.27, 0.21], bootstrapped prediction: [-0.00810144], in Range: True
# Input: -1 + 3 - -5, Actual: 7.00, Predicted Range: [6.48, 7.10], bootstrapped prediction: [6.8582435], in Range: True
# Input: -4 + 2 + 2, Actual: 0.00, Predicted Range: [-0.17, 0.38], bootstrapped prediction: [0.10871883], in Range: True
# Input: -1 + 3 - 3, Actual: -1.00, Predicted Range: [-1.13, -0.56], bootstrapped prediction: [-0.94396526], in Range: True
# Input: -3 - 2 - 3, Actual: -8.00, Predicted Range: [-8.54, -7.92], bootstrapped prediction: [-8.158873], in Range: True
# Input: 2 - 3 + 2, Actual: 1.00, Predicted Range: [0.90, 1.24], bootstrapped prediction: [1.0681138], in Range: True
# Input: 4 + -3 - 0, Actual: 1.00, Predicted Range: [0.66, 1.36], bootstrapped prediction: [1.0245174], in Range: True
# Input: -1 + -4 - 0, Actual: -5.00, Predicted Range: [-5.33, -4.90], bootstrapped prediction: [-5.1125097], in Range: True
# Input: 1 + 1 - -5, Actual: 7.00, Predicted Range: [6.56, 7.34], bootstrapped prediction: [6.971952], in Range: True
# Input: 0 + 2 + -2, Actual: 0.00, Predicted Range: [-0.27, 0.15], bootstrapped prediction: [-0.02898384], in Range: True
# Input: -2 + -4 + 2, Actual: -4.00, Predicted Range: [-4.26, -3.90], bootstrapped prediction: [-4.094056], in Range: True
# Input: -2 + -5 + -3, Actual: -10.00, Predicted Range: [-10.12, -9.82], bootstrapped prediction: [-9.952954], in Range: True
# Amount out of bounds: 41, Amount of expressions: 1457, Percentage in bounds: 97.18599862731641%

# %%
print(f"Amount out of bounds: {outOfBounds}, Amount of expressions: {len(x_test)}, Percentage in bounds: {(1-(outOfBounds/len(x_test)))*100}")
# Out:
# Amount out of bounds: 41, Amount of expressions: 1457, Percentage in bounds: 97.18599862731641

# %%
out_meanPredictions = []
for i in range(len(out_x_test)):
  calc = 0
  for j in range(n_bootstrap):
    calc += out_predictions[j][i]
  out_meanPredictions.append(calc/n_bootstrap)


# Calculate the lower and upper bounds of the prediction range
out_lower_bound = np.percentile(out_predictions, 5, axis=0)
out_upper_bound = np.percentile(out_predictions, 95, axis=0)


out_inRange = []
out_outOfBounds = 0
for i in range(len(out_y_test)):
  if out_y_test[i] >= out_lower_bound[i][0] and out_y_test[i] <= out_upper_bound[i][0]:
    out_inRange.append(True)
  else:
    out_inRange.append(False)
    out_outOfBounds += 1


print("Prediction Range (5th to 95th percentile):")
for i in range(len(out_x_test)):
  print(f"Input: {outsideExpr[i]}, Actual: {out_y_test[i]:.2f}, Predicted Range: [{out_lower_bound[i][0]:.2f}, {out_upper_bound[i][0]:.2f}], bootstrapped prediction: {out_meanPredictions[i]}, in Range: {out_inRange[i]}")

print(f"Amount out of bounds: {out_outOfBounds}, Amount of expressions: {len(out_x_test)}, Percentage in bounds: {(1-(out_outOfBounds/len(out_x_test)))*100}%")
# Out:
# Prediction Range (5th to 95th percentile):
# Input: 5 - -6 - -6, Actual: 17.00, Predicted Range: [15.12, 16.07], bootstrapped prediction: [15.631552], in Range: False
# Input: 5 - 6 - -8, Actual: 7.00, Predicted Range: [5.25, 7.64], bootstrapped prediction: [6.2218075], in Range: True
# Input: 7 + 5 + 8, Actual: 20.00, Predicted Range: [12.12, 16.67], bootstrapped prediction: [13.856171], in Range: False
# Input: 6 + 5 - 7, Actual: 4.00, Predicted Range: [2.44, 6.06], bootstrapped prediction: [4.046463], in Range: True
# Input: 6 - 5 + -8, Actual: -7.00, Predicted Range: [-4.71, -1.14], bootstrapped prediction: [-3.0746121], in Range: False
# Input: 8 + 6 - 8, Actual: 6.00, Predicted Range: [3.23, 8.27], bootstrapped prediction: [5.6016817], in Range: True
# Input: 7 - -7 - 8, Actual: 6.00, Predicted Range: [4.64, 9.07], bootstrapped prediction: [6.1614237], in Range: True
# Input: 5 - 8 - 8, Actual: -11.00, Predicted Range: [-8.89, -1.98], bootstrapped prediction: [-5.3738627], in Range: False
# Input: -5 + 6 - 8, Actual: -7.00, Predicted Range: [-9.14, -5.27], bootstrapped prediction: [-7.3013563], in Range: True
# Input: 6 - 8 - -5, Actual: 3.00, Predicted Range: [2.08, 5.74], bootstrapped prediction: [3.5759583], in Range: True
# Input: -5 - -5 + -8, Actual: -8.00, Predicted Range: [-6.56, -4.35], bootstrapped prediction: [-5.714875], in Range: False
# Input: -6 + 7 + -7, Actual: -6.00, Predicted Range: [-9.12, -4.44], bootstrapped prediction: [-6.5005927], in Range: True
# Input: 6 + -7 - 5, Actual: -6.00, Predicted Range: [-4.92, -1.74], bootstrapped prediction: [-3.351499], in Range: False
# Input: 8 + 7 - 8, Actual: 7.00, Predicted Range: [3.09, 8.49], bootstrapped prediction: [5.8319197], in Range: True
# Input: 8 - -8 - -5, Actual: 21.00, Predicted Range: [15.72, 19.70], bootstrapped prediction: [18.151186], in Range: False
# Input: 7 + -7 + 6, Actual: 6.00, Predicted Range: [4.85, 7.28], bootstrapped prediction: [6.1077237], in Range: True
# Input: -6 - 7 + -5, Actual: -18.00, Predicted Range: [-16.65, -12.87], bootstrapped prediction: [-15.005598], in Range: False
# Input: -5 - -7 + 5, Actual: 7.00, Predicted Range: [4.33, 5.69], bootstrapped prediction: [4.895334], in Range: False
# Input: 5 + 6 - 6, Actual: 5.00, Predicted Range: [2.37, 5.76], bootstrapped prediction: [4.1867127], in Range: True
# Input: 5 - 5 + 6, Actual: 6.00, Predicted Range: [3.86, 6.48], bootstrapped prediction: [4.9608636], in Range: True
# Input: 5 + -6 + 8, Actual: 7.00, Predicted Range: [3.26, 6.86], bootstrapped prediction: [4.8922453], in Range: False
# Input: -8 - -7 + -6, Actual: -7.00, Predicted Range: [-8.77, -5.63], bootstrapped prediction: [-6.695842], in Range: True
# Input: 5 - -7 + -6, Actual: 6.00, Predicted Range: [4.97, 7.54], bootstrapped prediction: [6.441488], in Range: True
# Input: -6 - -7 + -8, Actual: -7.00, Predicted Range: [-6.42, -3.88], bootstrapped prediction: [-5.2476606], in Range: False
# Input: 6 + -6 - -7, Actual: 7.00, Predicted Range: [6.15, 8.02], bootstrapped prediction: [7.2607026], in Range: True
# Input: 8 + -6 - -7, Actual: 9.00, Predicted Range: [7.99, 10.30], bootstrapped prediction: [9.293338], in Range: True
# Input: 8 + -8 - 7, Actual: -7.00, Predicted Range: [-4.22, 0.49], bootstrapped prediction: [-1.867377], in Range: False
# Input: -7 - -8 + -7, Actual: -6.00, Predicted Range: [-7.83, -3.77], bootstrapped prediction: [-5.2785063], in Range: True
# Input: -8 + -6 + -7, Actual: -21.00, Predicted Range: [-18.54, -16.60], bootstrapped prediction: [-17.60536], in Range: False
# Input: -8 + 8 - 5, Actual: -5.00, Predicted Range: [-10.21, -5.63], bootstrapped prediction: [-7.852922], in Range: False
# Input: -5 - 7 - 6, Actual: -18.00, Predicted Range: [-16.07, -12.79], bootstrapped prediction: [-14.37029], in Range: False
# Input: 5 - 8 - -7, Actual: 4.00, Predicted Range: [2.73, 6.02], bootstrapped prediction: [4.154536], in Range: True
# Input: -6 + 7 - -7, Actual: 8.00, Predicted Range: [1.88, 5.03], bootstrapped prediction: [3.2252135], in Range: False
# Input: 5 - 8 + -6, Actual: -9.00, Predicted Range: [-7.47, -3.15], bootstrapped prediction: [-5.4524007], in Range: False
# Input: 6 - 6 - 7, Actual: -7.00, Predicted Range: [-5.41, -0.86], bootstrapped prediction: [-3.4201195], in Range: False
# Input: 7 - 7 + -7, Actual: -7.00, Predicted Range: [-4.99, -0.83], bootstrapped prediction: [-3.0844014], in Range: False
# Input: -6 - 6 - 5, Actual: -17.00, Predicted Range: [-15.63, -13.90], bootstrapped prediction: [-14.626903], in Range: False
# Input: 5 - -7 + -7, Actual: 5.00, Predicted Range: [4.99, 7.38], bootstrapped prediction: [6.1947546], in Range: True
# Input: 5 + 7 + 7, Actual: 19.00, Predicted Range: [9.77, 14.34], bootstrapped prediction: [12.223227], in Range: False
# Input: -5 + -5 - 7, Actual: -17.00, Predicted Range: [-16.07, -12.73], bootstrapped prediction: [-14.436856], in Range: False
# Input: 5 + -8 - 5, Actual: -8.00, Predicted Range: [-6.18, -2.30], bootstrapped prediction: [-4.2522793], in Range: False
# Input: 6 - -5 - -6, Actual: 17.00, Predicted Range: [15.44, 15.95], bootstrapped prediction: [15.659462], in Range: False
# Input: -7 - -7 - 5, Actual: -5.00, Predicted Range: [-7.28, -4.33], bootstrapped prediction: [-5.502953], in Range: True
# Input: -6 + 7 - -8, Actual: 9.00, Predicted Range: [1.99, 5.10], bootstrapped prediction: [3.486232], in Range: False
# Input: -5 - -5 - -6, Actual: 6.00, Predicted Range: [4.34, 5.64], bootstrapped prediction: [5.075656], in Range: False
# Input: -6 + 7 + -5, Actual: -4.00, Predicted Range: [-7.58, -3.75], bootstrapped prediction: [-5.473484], in Range: True
# Input: -7 + 6 - 5, Actual: -6.00, Predicted Range: [-8.29, -5.88], bootstrapped prediction: [-7.179181], in Range: True
# Input: -5 + 7 - -7, Actual: 9.00, Predicted Range: [2.88, 5.97], bootstrapped prediction: [4.198685], in Range: False
# Input: -8 - -7 + 8, Actual: 7.00, Predicted Range: [-0.54, 3.11], bootstrapped prediction: [1.2148111], in Range: False
# Input: 5 + -7 + -6, Actual: -8.00, Predicted Range: [-6.07, -2.95], bootstrapped prediction: [-4.450385], in Range: False
# Input: -8 - 7 - 5, Actual: -20.00, Predicted Range: [-17.92, -15.00], bootstrapped prediction: [-16.460228], in Range: False
# Input: -7 - 5 - -5, Actual: -7.00, Predicted Range: [-7.47, -5.03], bootstrapped prediction: [-6.5544014], in Range: True
# Input: 7 + 7 + 7, Actual: 21.00, Predicted Range: [11.77, 16.34], bootstrapped prediction: [14.031154], in Range: False
# Input: 8 - -7 + -6, Actual: 9.00, Predicted Range: [7.76, 10.94], bootstrapped prediction: [9.476598], in Range: True
# Input: -8 - -6 - 8, Actual: -10.00, Predicted Range: [-11.58, -6.79], bootstrapped prediction: [-9.346691], in Range: True
# Input: 8 - 5 + -5, Actual: -2.00, Predicted Range: [-1.73, 0.60], bootstrapped prediction: [-0.56968826], in Range: False
# Input: 7 - -7 - 6, Actual: 8.00, Predicted Range: [6.80, 9.52], bootstrapped prediction: [7.6292357], in Range: True
# Input: -8 + -5 + 7, Actual: -6.00, Predicted Range: [-9.44, -6.10], bootstrapped prediction: [-7.7536926], in Range: False
# Input: 8 + 8 - 5, Actual: 11.00, Predicted Range: [5.54, 10.51], bootstrapped prediction: [7.759288], in Range: False
# Input: -5 - 7 + 7, Actual: -5.00, Predicted Range: [-8.47, -4.30], bootstrapped prediction: [-6.1606092], in Range: True
# Input: 5 - -6 - -5, Actual: 16.00, Predicted Range: [14.35, 15.48], bootstrapped prediction: [15.069242], in Range: False
# Input: 5 - -6 + -7, Actual: 4.00, Predicted Range: [4.64, 6.21], bootstrapped prediction: [5.36781], in Range: False
# Input: 6 - 6 - 5, Actual: -5.00, Predicted Range: [-4.15, -0.77], bootstrapped prediction: [-2.4582314], in Range: False
# Input: -5 - -6 + 6, Actual: 7.00, Predicted Range: [3.43, 5.13], bootstrapped prediction: [4.3788056], in Range: False
# Input: 7 + -7 - -7, Actual: 7.00, Predicted Range: [7.06, 9.19], bootstrapped prediction: [8.074488], in Range: False
# Input: 5 + 7 + 5, Actual: 17.00, Predicted Range: [10.79, 14.14], bootstrapped prediction: [12.43568], in Range: False
# Input: -7 + -6 + 7, Actual: -6.00, Predicted Range: [-8.71, -5.65], bootstrapped prediction: [-7.112699], in Range: True
# Input: -7 + 7 - -7, Actual: 7.00, Predicted Range: [0.97, 4.00], bootstrapped prediction: [2.254285], in Range: False
# Input: 7 - -8 + -8, Actual: 7.00, Predicted Range: [6.80, 10.61], bootstrapped prediction: [8.884195], in Range: True
# Input: 8 - -8 - -6, Actual: 22.00, Predicted Range: [16.72, 20.28], bootstrapped prediction: [18.913227], in Range: False
# Input: -8 + -6 - 5, Actual: -19.00, Predicted Range: [-18.05, -16.02], bootstrapped prediction: [-17.028055], in Range: False
# Input: -6 + 5 + 7, Actual: 6.00, Predicted Range: [0.07, 2.49], bootstrapped prediction: [1.3597877], in Range: False
# Input: 6 + -8 - 7, Actual: -9.00, Predicted Range: [-6.17, -1.38], bootstrapped prediction: [-3.8308797], in Range: False
# Input: -7 + 7 - 6, Actual: -6.00, Predicted Range: [-9.50, -5.68], bootstrapped prediction: [-7.694738], in Range: True
# Input: 7 + 5 - 7, Actual: 5.00, Predicted Range: [3.36, 7.03], bootstrapped prediction: [4.9961667], in Range: True
# Input: -8 + -6 - -5, Actual: -9.00, Predicted Range: [-8.83, -7.87], bootstrapped prediction: [-8.42915], in Range: False
# Input: 6 - -8 - -5, Actual: 19.00, Predicted Range: [14.59, 18.23], bootstrapped prediction: [16.765873], in Range: False
# Input: 7 - 7 - -7, Actual: 7.00, Predicted Range: [5.24, 8.08], bootstrapped prediction: [6.71762], in Range: True
# Input: -6 - 8 + -7, Actual: -21.00, Predicted Range: [-17.66, -13.10], bootstrapped prediction: [-15.662082], in Range: False
# Input: 6 + -8 - 6, Actual: -8.00, Predicted Range: [-5.70, -1.35], bootstrapped prediction: [-3.5763977], in Range: False
# Input: 8 + 5 - -5, Actual: 18.00, Predicted Range: [14.29, 16.08], bootstrapped prediction: [15.270192], in Range: False
# Input: -6 + -8 - 6, Actual: -20.00, Predicted Range: [-17.67, -13.79], bootstrapped prediction: [-15.552562], in Range: False
# Input: 5 - -5 + 6, Actual: 16.00, Predicted Range: [12.85, 14.02], bootstrapped prediction: [13.535492], in Range: False
# Input: 8 - -5 - 5, Actual: 8.00, Predicted Range: [6.70, 8.88], bootstrapped prediction: [7.659102], in Range: True
# Input: 6 + -5 + -8, Actual: -7.00, Predicted Range: [-4.16, -1.58], bootstrapped prediction: [-2.9353907], in Range: False
# Input: -8 - -7 - -7, Actual: 6.00, Predicted Range: [2.39, 4.78], bootstrapped prediction: [3.3932328], in Range: False
# Input: 8 + 8 - -7, Actual: 23.00, Predicted Range: [13.80, 18.07], bootstrapped prediction: [15.906075], in Range: False
# Input: -5 + -8 + -6, Actual: -19.00, Predicted Range: [-16.61, -12.74], bootstrapped prediction: [-14.563189], in Range: False
# Input: 6 + 5 - -5, Actual: 16.00, Predicted Range: [13.28, 14.58], bootstrapped prediction: [13.928172], in Range: False
# Input: -8 - -5 + 6, Actual: 3.00, Predicted Range: [-0.70, 1.66], bootstrapped prediction: [0.47902814], in Range: False
# Input: 5 - -6 + 6, Actual: 17.00, Predicted Range: [13.37, 14.71], bootstrapped prediction: [14.118776], in Range: False
# Input: 7 + 7 - 8, Actual: 6.00, Predicted Range: [2.09, 7.67], bootstrapped prediction: [4.8788586], in Range: True
# Input: -8 + 5 - 8, Actual: -11.00, Predicted Range: [-12.30, -8.99], bootstrapped prediction: [-10.580181], in Range: True
# Input: 7 - 5 - 7, Actual: -5.00, Predicted Range: [-3.72, 0.18], bootstrapped prediction: [-2.1228118], in Range: False
# Input: -8 - -8 - -7, Actual: 7.00, Predicted Range: [2.11, 5.35], bootstrapped prediction: [3.8086886], in Range: False
# Input: 7 + -7 - -8, Actual: 8.00, Predicted Range: [7.14, 9.84], bootstrapped prediction: [8.768236], in Range: True
# Input: 6 - -8 - -8, Actual: 22.00, Predicted Range: [16.51, 19.41], bootstrapped prediction: [18.160732], in Range: False
# Input: 7 - -5 + -5, Actual: 7.00, Predicted Range: [6.13, 7.76], bootstrapped prediction: [7.1089363], in Range: True
# Input: -8 - -7 - -6, Actual: 5.00, Predicted Range: [1.85, 4.23], bootstrapped prediction: [2.9762175], in Range: False
# Input: -7 - 6 + -8, Actual: -21.00, Predicted Range: [-17.03, -14.23], bootstrapped prediction: [-15.932652], in Range: False
# Input: 6 - 8 + 5, Actual: 3.00, Predicted Range: [0.18, 5.53], bootstrapped prediction: [3.1131103], in Range: True
# Input: -5 - -6 + 7, Actual: 8.00, Predicted Range: [2.95, 5.31], bootstrapped prediction: [4.1480827], in Range: False
# Input: 7 + 5 - 5, Actual: 7.00, Predicted Range: [5.43, 7.24], bootstrapped prediction: [6.4763803], in Range: True
# Input: 7 - -5 + -7, Actual: 5.00, Predicted Range: [5.73, 7.30], bootstrapped prediction: [6.6079636], in Range: False
# Input: 8 + -6 - 6, Actual: -4.00, Predicted Range: [-3.00, -0.37], bootstrapped prediction: [-1.6738024], in Range: False
# Input: -6 + 6 + 8, Actual: 8.00, Predicted Range: [-0.55, 2.64], bootstrapped prediction: [1.070348], in Range: False
# Input: -8 + -7 - -7, Actual: -8.00, Predicted Range: [-7.78, -6.64], bootstrapped prediction: [-7.1209183], in Range: False
# Input: -6 + 8 - -7, Actual: 9.00, Predicted Range: [1.40, 5.58], bootstrapped prediction: [3.0538104], in Range: False
# Input: -8 + 7 - -7, Actual: 6.00, Predicted Range: [0.05, 2.86], bootstrapped prediction: [1.2269323], in Range: False
# Input: -6 + 7 + -6, Actual: -5.00, Predicted Range: [-8.53, -4.22], bootstrapped prediction: [-6.08044], in Range: True
# Input: 7 - 8 + -5, Actual: -6.00, Predicted Range: [-5.27, -0.07], bootstrapped prediction: [-2.7951856], in Range: False
# Input: 7 + -5 - 7, Actual: -5.00, Predicted Range: [-3.88, -1.54], bootstrapped prediction: [-2.743236], in Range: False
# Input: -8 - 7 + -6, Actual: -21.00, Predicted Range: [-18.77, -14.47], bootstrapped prediction: [-16.91203], in Range: False
# Input: -5 - -5 - -8, Actual: 8.00, Predicted Range: [4.32, 6.83], bootstrapped prediction: [5.5696936], in Range: False
# Input: -8 - 6 - -5, Actual: -9.00, Predicted Range: [-9.49, -5.78], bootstrapped prediction: [-8.190354], in Range: True
# Input: -6 - -6 + 6, Actual: 6.00, Predicted Range: [2.30, 4.24], bootstrapped prediction: [3.3010147], in Range: False
# Input: -7 - 5 - -6, Actual: -6.00, Predicted Range: [-6.35, -4.43], bootstrapped prediction: [-5.725333], in Range: True
# Input: -8 + 8 - -8, Actual: 8.00, Predicted Range: [-0.22, 3.70], bootstrapped prediction: [1.4054794], in Range: False
# Input: -8 - 7 + 7, Actual: -8.00, Predicted Range: [-11.98, -7.44], bootstrapped prediction: [-9.296182], in Range: True
# Input: 8 + 6 + -5, Actual: 9.00, Predicted Range: [6.04, 9.05], bootstrapped prediction: [7.5647783], in Range: True
# Input: 8 + 5 + -8, Actual: 5.00, Predicted Range: [3.66, 8.36], bootstrapped prediction: [5.9457617], in Range: True
# Input: -7 - 6 - 7, Actual: -20.00, Predicted Range: [-17.56, -15.05], bootstrapped prediction: [-16.26066], in Range: False
# Input: 5 - 6 + 5, Actual: 4.00, Predicted Range: [2.22, 5.01], bootstrapped prediction: [3.6168456], in Range: True
# Input: 6 + -7 - -7, Actual: 6.00, Predicted Range: [5.90, 8.20], bootstrapped prediction: [7.015329], in Range: True
# Input: 6 + -6 - -8, Actual: 8.00, Predicted Range: [6.21, 9.16], bootstrapped prediction: [7.9387197], in Range: True
# Input: 6 - -7 - -6, Actual: 19.00, Predicted Range: [15.89, 17.81], bootstrapped prediction: [17.02566], in Range: False
# Input: -5 - -5 + 6, Actual: 6.00, Predicted Range: [2.89, 4.66], bootstrapped prediction: [3.8059018], in Range: False
# Input: -6 + -6 - -6, Actual: -6.00, Predicted Range: [-6.16, -5.32], bootstrapped prediction: [-5.7044954], in Range: True
# Input: -5 - -5 + -6, Actual: -6.00, Predicted Range: [-6.16, -4.86], bootstrapped prediction: [-5.4197564], in Range: True
# Input: -7 + 5 + -6, Actual: -8.00, Predicted Range: [-9.22, -6.77], bootstrapped prediction: [-7.7838736], in Range: True
# Input: -8 - 5 - 7, Actual: -20.00, Predicted Range: [-17.71, -15.46], bootstrapped prediction: [-16.695553], in Range: False
# Input: 7 - -8 + -5, Actual: 10.00, Predicted Range: [6.83, 11.33], bootstrapped prediction: [9.6146755], in Range: True
# Input: 8 + -7 - -7, Actual: 8.00, Predicted Range: [8.10, 10.39], bootstrapped prediction: [9.108386], in Range: False
# Input: -5 + 8 + 8, Actual: 11.00, Predicted Range: [-0.76, 4.43], bootstrapped prediction: [1.8740017], in Range: False
# Input: 6 - 5 - 7, Actual: -6.00, Predicted Range: [-4.74, -0.83], bootstrapped prediction: [-3.173777], in Range: False
# Input: 8 - 6 + -6, Actual: -4.00, Predicted Range: [-3.21, 0.24], bootstrapped prediction: [-1.4954712], in Range: False
# Input: 6 - 7 + 5, Actual: 4.00, Predicted Range: [1.70, 5.62], bootstrapped prediction: [3.8491], in Range: True
# Input: -5 + -5 - 8, Actual: -18.00, Predicted Range: [-16.86, -12.33], bootstrapped prediction: [-14.554129], in Range: False
# Input: -8 - 7 - -6, Actual: -9.00, Predicted Range: [-9.47, -5.05], bootstrapped prediction: [-8.011661], in Range: True
# Input: -5 - -7 - 8, Actual: -6.00, Predicted Range: [-7.91, -2.82], bootstrapped prediction: [-5.507585], in Range: True
# Input: -5 - -5 - 6, Actual: -6.00, Predicted Range: [-6.82, -4.50], bootstrapped prediction: [-5.63325], in Range: True
# Input: 7 - 6 + -7, Actual: -6.00, Predicted Range: [-4.34, -0.59], bootstrapped prediction: [-2.60279], in Range: False
# Input: 7 - -5 + 7, Actual: 19.00, Predicted Range: [13.78, 15.89], bootstrapped prediction: [14.821043], in Range: False
# Input: -6 - 5 - -6, Actual: -5.00, Predicted Range: [-5.44, -3.70], bootstrapped prediction: [-4.7912536], in Range: True
# Input: -5 - -7 - 5, Actual: -3.00, Predicted Range: [-4.91, -2.39], bootstrapped prediction: [-3.4208426], in Range: True
# Input: -5 + -5 + 7, Actual: -3.00, Predicted Range: [-6.10, -2.75], bootstrapped prediction: [-4.520076], in Range: True
# Input: 5 - -8 + 5, Actual: 18.00, Predicted Range: [13.79, 16.06], bootstrapped prediction: [14.846582], in Range: False
# Input: -8 - 5 + -6, Actual: -19.00, Predicted Range: [-17.52, -15.32], bootstrapped prediction: [-16.427622], in Range: False
# Input: 8 + 7 - 6, Actual: 9.00, Predicted Range: [4.95, 9.06], bootstrapped prediction: [7.1299706], in Range: True
# Input: 5 + 8 + 8, Actual: 21.00, Predicted Range: [8.30, 14.65], bootstrapped prediction: [11.700236], in Range: False
# Input: 8 - 6 + 5, Actual: 7.00, Predicted Range: [5.12, 8.11], bootstrapped prediction: [6.5333824], in Range: True
# Input: 7 + -8 - -8, Actual: 7.00, Predicted Range: [6.89, 10.25], bootstrapped prediction: [8.6121855], in Range: True
# Input: 5 + 5 + 7, Actual: 17.00, Predicted Range: [10.96, 14.63], bootstrapped prediction: [12.410551], in Range: False
# Input: 5 - -8 - -8, Actual: 21.00, Predicted Range: [15.49, 18.44], bootstrapped prediction: [17.19748], in Range: False
# Input: 7 + 5 + 5, Actual: 17.00, Predicted Range: [13.62, 15.35], bootstrapped prediction: [14.219816], in Range: False
# Input: -8 - 7 + -8, Actual: -23.00, Predicted Range: [-18.25, -14.94], bootstrapped prediction: [-16.97878], in Range: False
# Input: -5 + 5 + -5, Actual: -5.00, Predicted Range: [-6.43, -4.48], bootstrapped prediction: [-5.3005133], in Range: True
# Input: -5 - 5 - 5, Actual: -15.00, Predicted Range: [-14.12, -12.94], bootstrapped prediction: [-13.470154], in Range: False
# Input: -5 - 5 - -8, Actual: -2.00, Predicted Range: [-3.67, -1.80], bootstrapped prediction: [-2.7590623], in Range: True
# Input: -8 + 8 - 8, Actual: -8.00, Predicted Range: [-12.48, -6.83], bootstrapped prediction: [-9.800959], in Range: True
# Input: 8 - 6 + -7, Actual: -5.00, Predicted Range: [-3.51, 0.60], bootstrapped prediction: [-1.4701228], in Range: False
# Input: -6 + -8 - 8, Actual: -22.00, Predicted Range: [-18.27, -13.33], bootstrapped prediction: [-15.945223], in Range: False
# Input: 8 - 5 + -7, Actual: -4.00, Predicted Range: [-2.90, 0.86], bootstrapped prediction: [-0.96331704], in Range: False
# Input: 5 - -8 - 8, Actual: 5.00, Predicted Range: [3.11, 7.91], bootstrapped prediction: [4.919588], in Range: True
# Input: -8 - -8 - 8, Actual: -8.00, Predicted Range: [-10.76, -4.95], bootstrapped prediction: [-7.8858137], in Range: True
# Input: 5 - 7 + 7, Actual: 5.00, Predicted Range: [1.33, 6.07], bootstrapped prediction: [3.6199088], in Range: True
# Input: 8 - 5 - -7, Actual: 10.00, Predicted Range: [8.34, 10.03], bootstrapped prediction: [9.220856], in Range: True
# Input: -6 - 5 + 7, Actual: -4.00, Predicted Range: [-7.49, -4.10], bootstrapped prediction: [-5.8284307], in Range: False
# Input: -6 - -5 + -5, Actual: -6.00, Predicted Range: [-6.67, -5.68], bootstrapped prediction: [-6.037596], in Range: True
# Input: 6 + -8 + -7, Actual: -9.00, Predicted Range: [-4.91, -0.82], bootstrapped prediction: [-2.8351645], in Range: False
# Input: 6 - 6 + 7, Actual: 7.00, Predicted Range: [3.64, 7.79], bootstrapped prediction: [5.4112587], in Range: True
# Input: 6 - 6 + -5, Actual: -5.00, Predicted Range: [-4.27, -2.07], bootstrapped prediction: [-3.3233483], in Range: False
# Input: -6 - 5 - 6, Actual: -17.00, Predicted Range: [-15.45, -13.98], bootstrapped prediction: [-14.723724], in Range: False
# Input: -5 - 8 + 7, Actual: -6.00, Predicted Range: [-9.60, -4.26], bootstrapped prediction: [-6.8039985], in Range: True
# Input: -8 - -6 + 5, Actual: 3.00, Predicted Range: [0.72, 1.60], bootstrapped prediction: [1.1269032], in Range: False
# Input: 7 + 5 - -8, Actual: 20.00, Predicted Range: [13.90, 17.05], bootstrapped prediction: [15.32704], in Range: False
# Input: -7 - -8 - -7, Actual: 8.00, Predicted Range: [3.17, 6.27], bootstrapped prediction: [4.841161], in Range: False
# Input: 6 + -7 - -8, Actual: 7.00, Predicted Range: [5.99, 8.87], bootstrapped prediction: [7.707587], in Range: True
# Input: 7 - 7 - 8, Actual: -8.00, Predicted Range: [-5.79, 0.27], bootstrapped prediction: [-3.0520837], in Range: False
# Input: -6 + 6 - 7, Actual: -7.00, Predicted Range: [-9.10, -5.78], bootstrapped prediction: [-7.634742], in Range: True
# Input: 7 + -8 - -5, Actual: 4.00, Predicted Range: [4.30, 8.00], bootstrapped prediction: [6.333962], in Range: False
# Input: -6 + 5 - -7, Actual: 6.00, Predicted Range: [2.63, 4.34], bootstrapped prediction: [3.4564013], in Range: False
# Input: -7 - -6 - -8, Actual: 7.00, Predicted Range: [2.92, 4.89], bootstrapped prediction: [4.100417], in Range: False
# Input: 7 + 7 - 7, Actual: 7.00, Predicted Range: [3.10, 7.75], bootstrapped prediction: [5.5846124], in Range: True
# Input: 7 - -7 + 7, Actual: 21.00, Predicted Range: [14.83, 16.93], bootstrapped prediction: [15.883003], in Range: False
# Input: -6 - -8 + 6, Actual: 8.00, Predicted Range: [2.85, 5.46], bootstrapped prediction: [4.0514426], in Range: False
# Input: 6 + -7 - 8, Actual: -9.00, Predicted Range: [-6.38, -2.24], bootstrapped prediction: [-4.1246996], in Range: False
# Input: 7 - 6 + 8, Actual: 9.00, Predicted Range: [4.41, 9.46], bootstrapped prediction: [6.5377975], in Range: True
# Input: -7 - 6 + -6, Actual: -19.00, Predicted Range: [-17.27, -14.23], bootstrapped prediction: [-15.930914], in Range: False
# Input: 8 + -6 - 7, Actual: -5.00, Predicted Range: [-3.54, -0.46], bootstrapped prediction: [-1.9483122], in Range: False
# Input: 8 + -5 - 8, Actual: -5.00, Predicted Range: [-3.60, -0.46], bootstrapped prediction: [-2.1446767], in Range: False
# Input: -7 + -8 - 7, Actual: -22.00, Predicted Range: [-18.73, -14.57], bootstrapped prediction: [-16.781973], in Range: False
# Input: 6 - -6 - -5, Actual: 17.00, Predicted Range: [15.06, 16.38], bootstrapped prediction: [15.835352], in Range: False
# Input: 5 - -6 + 5, Actual: 16.00, Predicted Range: [13.76, 14.58], bootstrapped prediction: [14.233269], in Range: False
# Input: 6 - -8 + 5, Actual: 19.00, Predicted Range: [14.61, 16.83], bootstrapped prediction: [15.6888685], in Range: False
# Input: -7 - 8 + 7, Actual: -8.00, Predicted Range: [-12.00, -6.21], bootstrapped prediction: [-8.845438], in Range: True
# Input: -7 - -7 - 8, Actual: -8.00, Predicted Range: [-10.03, -4.74], bootstrapped prediction: [-7.549328], in Range: True
# Input: 8 - 6 - 7, Actual: -5.00, Predicted Range: [-3.36, 1.22], bootstrapped prediction: [-1.3598975], in Range: False
# Input: 6 - -7 + -6, Actual: 7.00, Predicted Range: [5.94, 8.70], bootstrapped prediction: [7.4908166], in Range: True
# Input: -6 - -5 + 8, Actual: 7.00, Predicted Range: [0.57, 4.49], bootstrapped prediction: [2.3110301], in Range: False
# Input: -7 - 7 - -8, Actual: -6.00, Predicted Range: [-7.00, -3.68], bootstrapped prediction: [-5.7491198], in Range: True
# Input: -7 + 6 + -7, Actual: -8.00, Predicted Range: [-10.16, -6.11], bootstrapped prediction: [-7.798607], in Range: True
# Input: -8 + 8 - -7, Actual: 7.00, Predicted Range: [-0.66, 3.53], bootstrapped prediction: [1.0170069], in Range: False
# Input: 5 - 5 - -5, Actual: 5.00, Predicted Range: [4.39, 5.58], bootstrapped prediction: [4.980534], in Range: True
# Input: -7 - 5 - 7, Actual: -19.00, Predicted Range: [-16.88, -14.70], bootstrapped prediction: [-15.885547], in Range: False
# Input: 8 + -6 - -6, Actual: 8.00, Predicted Range: [7.67, 9.56], bootstrapped prediction: [8.551562], in Range: True
# Input: 8 - 5 - 8, Actual: -5.00, Predicted Range: [-3.35, 1.20], bootstrapped prediction: [-1.5298777], in Range: False
# Input: 8 - 6 - -5, Actual: 7.00, Predicted Range: [5.67, 8.06], bootstrapped prediction: [6.9663773], in Range: True
# Input: -6 + -7 - -7, Actual: -6.00, Predicted Range: [-5.86, -4.61], bootstrapped prediction: [-5.254353], in Range: False
# Input: -7 + -8 + 7, Actual: -8.00, Predicted Range: [-9.96, -6.19], bootstrapped prediction: [-7.7606964], in Range: True
# Input: -7 + 8 - -6, Actual: 7.00, Predicted Range: [-0.26, 4.40], bootstrapped prediction: [1.5777586], in Range: False
# Input: -7 + 7 + 8, Actual: 8.00, Predicted Range: [-2.15, 1.85], bootstrapped prediction: [0.04085108], in Range: False
# Input: 6 - 8 - 7, Actual: -9.00, Predicted Range: [-7.15, -1.00], bootstrapped prediction: [-3.9047675], in Range: False
# Input: 6 + 5 + -6, Actual: 5.00, Predicted Range: [3.18, 5.96], bootstrapped prediction: [4.7554297], in Range: True
# Input: 8 - -7 + 8, Actual: 23.00, Predicted Range: [15.14, 17.84], bootstrapped prediction: [16.387897], in Range: False
# Input: -7 - -6 + 6, Actual: 5.00, Predicted Range: [1.24, 3.19], bootstrapped prediction: [2.2347517], in Range: False
# Input: 8 - -6 - -5, Actual: 19.00, Predicted Range: [16.23, 17.87], bootstrapped prediction: [17.110153], in Range: False
# Input: 5 + 7 + -7, Actual: 5.00, Predicted Range: [1.72, 5.55], bootstrapped prediction: [3.7445617], in Range: True
# Input: 8 - 5 + -8, Actual: -5.00, Predicted Range: [-3.08, 1.16], bootstrapped prediction: [-0.8841609], in Range: False
# Input: 8 - -7 + -7, Actual: 8.00, Predicted Range: [7.73, 10.68], bootstrapped prediction: [9.269926], in Range: True
# Input: -6 + 8 + -5, Actual: -3.00, Predicted Range: [-7.75, -2.82], bootstrapped prediction: [-5.2568655], in Range: True
# Input: 6 - -7 - -7, Actual: 20.00, Predicted Range: [16.46, 18.24], bootstrapped prediction: [17.402462], in Range: False
# Input: 5 + 8 + -5, Actual: 8.00, Predicted Range: [2.68, 7.46], bootstrapped prediction: [5.0026007], in Range: False
# Input: -5 + -8 - -5, Actual: -8.00, Predicted Range: [-7.93, -4.61], bootstrapped prediction: [-5.954207], in Range: False
# Input: 6 + 7 + 8, Actual: 21.00, Predicted Range: [10.21, 15.84], bootstrapped prediction: [12.94827], in Range: False
# Input: -6 - -5 - 6, Actual: -7.00, Predicted Range: [-7.99, -5.51], bootstrapped prediction: [-6.7312827], in Range: True
# Input: -6 + -5 - -6, Actual: -5.00, Predicted Range: [-5.64, -4.59], bootstrapped prediction: [-5.1152678], in Range: True
# Input: 6 - -7 - 6, Actual: 7.00, Predicted Range: [5.81, 8.48], bootstrapped prediction: [6.7279205], in Range: True
# Input: -8 - 8 + -5, Actual: -21.00, Predicted Range: [-19.16, -13.76], bootstrapped prediction: [-16.87208], in Range: False
# Input: -7 - 5 - -8, Actual: -4.00, Predicted Range: [-5.59, -3.18], bootstrapped prediction: [-4.507024], in Range: True
# Input: 8 - -5 + 5, Actual: 18.00, Predicted Range: [14.97, 16.34], bootstrapped prediction: [15.553945], in Range: False
# Input: -5 - 5 - -6, Actual: -4.00, Predicted Range: [-4.55, -2.94], bootstrapped prediction: [-3.8774571], in Range: True
# Input: 7 + -7 - 6, Actual: -6.00, Predicted Range: [-4.24, -1.01], bootstrapped prediction: [-2.6710298], in Range: False
# Input: -6 + -6 - 8, Actual: -20.00, Predicted Range: [-18.29, -13.47], bootstrapped prediction: [-15.81458], in Range: False
# Input: 6 + -5 + 5, Actual: 6.00, Predicted Range: [4.91, 6.38], bootstrapped prediction: [5.613622], in Range: True
# Input: -6 - -8 + -8, Actual: -6.00, Predicted Range: [-6.54, -2.77], bootstrapped prediction: [-4.4734488], in Range: True
# Input: -5 + -8 - 7, Actual: -20.00, Predicted Range: [-16.98, -12.66], bootstrapped prediction: [-14.799751], in Range: False
# Input: -7 - 7 + -7, Actual: -21.00, Predicted Range: [-17.71, -14.25], bootstrapped prediction: [-16.215935], in Range: False
# Input: -5 + 5 + -8, Actual: -8.00, Predicted Range: [-8.75, -4.85], bootstrapped prediction: [-6.7409773], in Range: True
# Input: -8 + 5 + 8, Actual: 5.00, Predicted Range: [-2.58, 0.24], bootstrapped prediction: [-1.1852715], in Range: False
# Input: -7 - 5 - -7, Actual: -5.00, Predicted Range: [-5.88, -3.80], bootstrapped prediction: [-5.046822], in Range: True
# Input: -6 - 6 - -6, Actual: -6.00, Predicted Range: [-6.34, -3.59], bootstrapped prediction: [-5.492193], in Range: True
# Input: 5 + 6 + 8, Actual: 19.00, Predicted Range: [10.02, 14.94], bootstrapped prediction: [12.14439], in Range: False
# Input: 6 - 6 - -8, Actual: 8.00, Predicted Range: [6.10, 8.67], bootstrapped prediction: [7.1451745], in Range: True
# Input: -8 - -7 + -8, Actual: -9.00, Predicted Range: [-8.65, -5.99], bootstrapped prediction: [-7.245828], in Range: False
# Input: 7 + -7 - 8, Actual: -8.00, Predicted Range: [-5.44, -1.17], bootstrapped prediction: [-3.152972], in Range: False
# Input: -7 - 5 + -8, Actual: -20.00, Predicted Range: [-16.35, -14.02], bootstrapped prediction: [-15.470711], in Range: False
# Input: 8 + -6 + -6, Actual: -4.00, Predicted Range: [-2.10, 0.83], bootstrapped prediction: [-0.97771585], in Range: False
# Input: -5 - -7 - -8, Actual: 10.00, Predicted Range: [5.62, 7.76], bootstrapped prediction: [6.749013], in Range: False
# Input: 7 - -8 + 6, Actual: 21.00, Predicted Range: [15.65, 17.59], bootstrapped prediction: [16.402534], in Range: False
# Input: -8 - 5 - 8, Actual: -21.00, Predicted Range: [-18.48, -15.27], bootstrapped prediction: [-16.990477], in Range: False
# Input: -6 + 5 + 5, Actual: 4.00, Predicted Range: [0.43, 2.59], bootstrapped prediction: [1.789295], in Range: False
# Input: -8 + -5 - 8, Actual: -21.00, Predicted Range: [-19.68, -15.16], bootstrapped prediction: [-17.39256], in Range: False
# Input: -8 - 7 - 6, Actual: -21.00, Predicted Range: [-18.58, -15.90], bootstrapped prediction: [-16.988697], in Range: False
# Input: 8 - -6 - 6, Actual: 8.00, Predicted Range: [6.66, 9.65], bootstrapped prediction: [7.7601027], in Range: True
# Input: -6 + -8 + 7, Actual: -7.00, Predicted Range: [-8.87, -5.14], bootstrapped prediction: [-6.706607], in Range: True
# Input: 6 + -5 - 5, Actual: -4.00, Predicted Range: [-3.80, -2.31], bootstrapped prediction: [-3.0749826], in Range: False
# Input: 6 - 6 + -6, Actual: -6.00, Predicted Range: [-5.26, -2.19], bootstrapped prediction: [-3.773241], in Range: False
# Input: 5 + 5 - -5, Actual: 15.00, Predicted Range: [12.61, 13.68], bootstrapped prediction: [13.167387], in Range: False
# Input: -7 - -6 - -7, Actual: 6.00, Predicted Range: [2.95, 4.86], bootstrapped prediction: [3.9373946], in Range: False
# Input: -7 + 5 - -5, Actual: 3.00, Predicted Range: [0.96, 2.22], bootstrapped prediction: [1.5780971], in Range: False
# Input: 7 - 8 + -7, Actual: -8.00, Predicted Range: [-5.63, -0.94], bootstrapped prediction: [-3.4627357], in Range: False
# Input: -7 + -6 + -6, Actual: -19.00, Predicted Range: [-17.48, -15.93], bootstrapped prediction: [-16.823784], in Range: False
# Input: 5 + 5 - -7, Actual: 17.00, Predicted Range: [12.98, 15.01], bootstrapped prediction: [13.800337], in Range: False
# Input: -5 - 8 - 5, Actual: -18.00, Predicted Range: [-15.78, -12.15], bootstrapped prediction: [-13.943883], in Range: False
# Input: -6 - 8 + 7, Actual: -7.00, Predicted Range: [-10.78, -5.21], bootstrapped prediction: [-7.81227], in Range: True
# Input: 7 - 5 - -6, Actual: 8.00, Predicted Range: [6.79, 8.43], bootstrapped prediction: [7.73104], in Range: True
# Input: 7 - 7 - 7, Actual: -7.00, Predicted Range: [-5.16, 0.28], bootstrapped prediction: [-2.5701854], in Range: False
# Input: -6 - -5 - 7, Actual: -8.00, Predicted Range: [-9.09, -5.55], bootstrapped prediction: [-7.436498], in Range: True
# Input: 8 - -7 + -5, Actual: 10.00, Predicted Range: [7.72, 11.27], bootstrapped prediction: [9.78195], in Range: True
# Input: 7 - -5 + 6, Actual: 18.00, Predicted Range: [14.26, 15.91], bootstrapped prediction: [14.991449], in Range: False
# Input: 6 - 6 + -7, Actual: -7.00, Predicted Range: [-5.27, -1.74], bootstrapped prediction: [-3.725741], in Range: False
# Input: 5 + -5 - 6, Actual: -6.00, Predicted Range: [-5.19, -3.59], bootstrapped prediction: [-4.417694], in Range: False
# Input: -6 + 6 + -8, Actual: -8.00, Predicted Range: [-9.73, -5.09], bootstrapped prediction: [-7.2280936], in Range: True
# Input: 6 - -5 + -6, Actual: 5.00, Predicted Range: [5.00, 6.32], bootstrapped prediction: [5.7131515], in Range: False
# Input: -7 + -7 - -8, Actual: -6.00, Predicted Range: [-6.22, -4.67], bootstrapped prediction: [-5.4572473], in Range: True
# Input: 7 + 6 + -6, Actual: 7.00, Predicted Range: [4.02, 7.51], bootstrapped prediction: [5.982812], in Range: True
# Input: -7 - -5 - -5, Actual: 3.00, Predicted Range: [1.77, 3.15], bootstrapped prediction: [2.443658], in Range: True
# Input: -8 + 7 - 5, Actual: -6.00, Predicted Range: [-9.73, -6.10], bootstrapped prediction: [-7.924796], in Range: False
# Input: 5 - -5 - 6, Actual: 4.00, Predicted Range: [3.32, 5.58], bootstrapped prediction: [4.2810364], in Range: True
# Input: 6 + -7 - -5, Actual: 4.00, Predicted Range: [4.18, 6.55], bootstrapped prediction: [5.3659472], in Range: False
# Input: -7 - -5 - 8, Actual: -10.00, Predicted Range: [-11.18, -6.56], bootstrapped prediction: [-9.056452], in Range: True
# Input: -5 + -5 + -5, Actual: -15.00, Predicted Range: [-15.01, -14.27], bootstrapped prediction: [-14.682149], in Range: True
# Input: -8 - 7 + -7, Actual: -22.00, Predicted Range: [-18.55, -14.82], bootstrapped prediction: [-16.997717], in Range: False
# Input: 8 - -7 - 5, Actual: 10.00, Predicted Range: [8.50, 11.05], bootstrapped prediction: [9.264203], in Range: True
# Input: 5 - -8 - -7, Actual: 20.00, Predicted Range: [15.17, 18.17], bootstrapped prediction: [16.945707], in Range: False
# Input: 6 + 8 + -5, Actual: 9.00, Predicted Range: [3.34, 8.55], bootstrapped prediction: [5.963076], in Range: False
# Input: 5 - -7 - -5, Actual: 17.00, Predicted Range: [14.18, 16.37], bootstrapped prediction: [15.559154], in Range: False
# Input: -8 - 5 + 8, Actual: -5.00, Predicted Range: [-9.67, -5.24], bootstrapped prediction: [-7.718066], in Range: False
# Input: 5 - -7 + -5, Actual: 7.00, Predicted Range: [5.14, 7.88], bootstrapped prediction: [6.8831635], in Range: True
# Input: -7 - -5 - 7, Actual: -9.00, Predicted Range: [-10.15, -6.65], bootstrapped prediction: [-8.452998], in Range: True
# Input: 7 - -7 + -8, Actual: 6.00, Predicted Range: [6.78, 9.40], bootstrapped prediction: [8.042127], in Range: False
# Input: 7 + 7 + -6, Actual: 8.00, Predicted Range: [3.69, 8.10], bootstrapped prediction: [6.176046], in Range: True
# Input: -5 - -8 - -8, Actual: 11.00, Predicted Range: [5.68, 8.58], bootstrapped prediction: [7.220308], in Range: False
# Input: -7 - 7 - 8, Actual: -22.00, Predicted Range: [-18.75, -14.94], bootstrapped prediction: [-16.869728], in Range: False
# Input: 5 + -8 + 6, Actual: 3.00, Predicted Range: [2.42, 5.22], bootstrapped prediction: [3.9251144], in Range: True
# Input: 8 - -7 - -6, Actual: 21.00, Predicted Range: [17.09, 19.36], bootstrapped prediction: [18.413078], in Range: False
# Input: -7 + -5 - -8, Actual: -4.00, Predicted Range: [-5.97, -3.61], bootstrapped prediction: [-4.65084], in Range: True
# Input: -6 + 6 - -6, Actual: 6.00, Predicted Range: [2.10, 4.28], bootstrapped prediction: [3.0458932], in Range: False
# Input: 6 - 7 + 8, Actual: 7.00, Predicted Range: [2.38, 7.94], bootstrapped prediction: [4.791116], in Range: True
# Input: 8 - -7 + 6, Actual: 21.00, Predicted Range: [15.91, 17.25], bootstrapped prediction: [16.698301], in Range: False
# Input: -7 - -7 - -6, Actual: 6.00, Predicted Range: [2.97, 5.19], bootstrapped prediction: [4.0719132], in Range: False
# Input: -6 - 5 + 8, Actual: -3.00, Predicted Range: [-7.54, -3.34], bootstrapped prediction: [-5.774863], in Range: False
# Input: -7 - -6 - -5, Actual: 4.00, Predicted Range: [2.49, 3.96], bootstrapped prediction: [3.0920937], in Range: False
# Input: 5 + -5 - -8, Actual: 8.00, Predicted Range: [5.69, 8.54], bootstrapped prediction: [7.304217], in Range: True
# Input: 7 + -6 - 6, Actual: -5.00, Predicted Range: [-3.95, -1.27], bootstrapped prediction: [-2.6244328], in Range: False
# Input: -7 + -8 - 5, Actual: -20.00, Predicted Range: [-17.87, -14.70], bootstrapped prediction: [-16.092709], in Range: False
# Input: -5 + -5 - -5, Actual: -5.00, Predicted Range: [-5.26, -4.72], bootstrapped prediction: [-4.9743013], in Range: True
# Input: -5 - -8 - 8, Actual: -5.00, Predicted Range: [-7.72, -2.10], bootstrapped prediction: [-4.7757573], in Range: True
# Input: 5 + -5 - 5, Actual: -5.00, Predicted Range: [-4.78, -3.43], bootstrapped prediction: [-4.1322055], in Range: False
# Input: 8 - 6 - -7, Actual: 9.00, Predicted Range: [7.11, 9.52], bootstrapped prediction: [8.451697], in Range: True
# Input: 8 - 6 - 8, Actual: -6.00, Predicted Range: [-4.11, 1.21], bootstrapped prediction: [-1.859264], in Range: False
# Input: 8 + -6 + 8, Actual: 10.00, Predicted Range: [5.77, 9.63], bootstrapped prediction: [7.47687], in Range: False
# Input: -6 - 6 - 6, Actual: -18.00, Predicted Range: [-16.25, -14.06], bootstrapped prediction: [-15.055273], in Range: False
# Input: -7 - 8 - -6, Actual: -9.00, Predicted Range: [-9.11, -3.95], bootstrapped prediction: [-7.671192], in Range: True
# Input: 6 - 7 - 6, Actual: -7.00, Predicted Range: [-5.63, -0.93], bootstrapped prediction: [-3.1870677], in Range: False
# Input: -5 - -8 + 8, Actual: 11.00, Predicted Range: [3.27, 6.29], bootstrapped prediction: [4.814204], in Range: False
# Input: -5 - -8 - 5, Actual: -2.00, Predicted Range: [-4.71, -1.43], bootstrapped prediction: [-2.6939244], in Range: True
# Input: 5 + -5 - -7, Actual: 7.00, Predicted Range: [5.55, 7.63], bootstrapped prediction: [6.7024674], in Range: True
# Input: 8 + -5 - -6, Actual: 9.00, Predicted Range: [8.24, 9.94], bootstrapped prediction: [9.060757], in Range: True
# Input: 8 - 5 + 7, Actual: 10.00, Predicted Range: [6.45, 10.05], bootstrapped prediction: [8.035247], in Range: True
# Input: 5 - -8 - -6, Actual: 19.00, Predicted Range: [14.51, 17.80], bootstrapped prediction: [16.51621], in Range: False
# Input: -5 - -5 + -5, Actual: -5.00, Predicted Range: [-5.55, -4.68], bootstrapped prediction: [-5.027671], in Range: True
# Input: -8 - 5 + 5, Actual: -8.00, Predicted Range: [-10.12, -7.74], bootstrapped prediction: [-8.687472], in Range: True
# Input: 7 + 5 - -5, Actual: 17.00, Predicted Range: [13.77, 15.36], bootstrapped prediction: [14.629484], in Range: False
# Input: 6 + 7 + -7, Actual: 6.00, Predicted Range: [2.57, 6.69], bootstrapped prediction: [4.7399282], in Range: True
# Input: -7 - 6 - 6, Actual: -19.00, Predicted Range: [-17.08, -15.09], bootstrapped prediction: [-15.929382], in Range: False
# Input: -6 - -8 - 7, Actual: -5.00, Predicted Range: [-7.71, -3.13], bootstrapped prediction: [-5.164357], in Range: True
# Input: -5 + 5 + 7, Actual: 7.00, Predicted Range: [1.22, 3.57], bootstrapped prediction: [2.4099479], in Range: False
# Input: 8 - -8 - -7, Actual: 23.00, Predicted Range: [17.78, 20.77], bootstrapped prediction: [19.454454], in Range: False
# Input: -7 + 8 - 7, Actual: -6.00, Predicted Range: [-10.72, -5.60], bootstrapped prediction: [-8.258658], in Range: True
# Input: 7 - -6 - 6, Actual: 7.00, Predicted Range: [5.89, 8.68], bootstrapped prediction: [6.8978133], in Range: True
# Input: 7 - -8 - 8, Actual: 7.00, Predicted Range: [5.14, 9.75], bootstrapped prediction: [6.8119783], in Range: True
# Input: -5 - -8 - -6, Actual: 9.00, Predicted Range: [4.57, 7.70], bootstrapped prediction: [6.480456], in Range: False
# Input: -8 + -6 + 7, Actual: -7.00, Predicted Range: [-9.82, -6.63], bootstrapped prediction: [-8.184191], in Range: True
# Input: 7 + 6 - 8, Actual: 5.00, Predicted Range: [2.33, 7.31], bootstrapped prediction: [4.661847], in Range: True
# Input: -6 - 8 + -6, Actual: -20.00, Predicted Range: [-17.68, -12.87], bootstrapped prediction: [-15.528587], in Range: False
# Input: 7 - -7 - -6, Actual: 20.00, Predicted Range: [16.55, 18.62], bootstrapped prediction: [17.756641], in Range: False
# Input: 5 - 6 + -8, Actual: -9.00, Predicted Range: [-6.06, -2.38], bootstrapped prediction: [-4.6530724], in Range: False
# Input: 8 + -7 + 5, Actual: 6.00, Predicted Range: [5.36, 8.35], bootstrapped prediction: [6.6392493], in Range: True
# Input: -6 - 8 - -6, Actual: -8.00, Predicted Range: [-8.26, -3.09], bootstrapped prediction: [-6.7666717], in Range: True
# Input: 8 - 8 - 8, Actual: -8.00, Predicted Range: [-5.56, 1.31], bootstrapped prediction: [-2.2053382], in Range: False
# Input: 7 + 8 - 5, Actual: 10.00, Predicted Range: [4.46, 9.50], bootstrapped prediction: [6.832591], in Range: False
# Input: -8 - -8 - 5, Actual: -5.00, Predicted Range: [-8.13, -4.31], bootstrapped prediction: [-5.7549205], in Range: True
# Input: 6 - -6 + 6, Actual: 18.00, Predicted Range: [14.11, 15.46], bootstrapped prediction: [14.901187], in Range: False
# Input: -5 - -6 + -7, Actual: -6.00, Predicted Range: [-5.74, -3.89], bootstrapped prediction: [-4.827662], in Range: False
# Input: -7 - 6 - 5, Actual: -18.00, Predicted Range: [-16.44, -14.63], bootstrapped prediction: [-15.409999], in Range: False
# Input: -5 + -8 + -8, Actual: -21.00, Predicted Range: [-16.52, -13.06], bootstrapped prediction: [-14.393977], in Range: False
# Input: 6 + 8 - 6, Actual: 8.00, Predicted Range: [2.41, 8.07], bootstrapped prediction: [5.282687], in Range: True
# Input: 8 + -7 - -8, Actual: 9.00, Predicted Range: [8.32, 11.07], bootstrapped prediction: [9.807927], in Range: True
# Input: 5 + -6 + 6, Actual: 5.00, Predicted Range: [3.77, 5.40], bootstrapped prediction: [4.547578], in Range: True
# Input: 5 - 8 - -6, Actual: 3.00, Predicted Range: [2.16, 5.44], bootstrapped prediction: [3.4472797], in Range: True
# Input: -5 + -6 + -6, Actual: -17.00, Predicted Range: [-16.07, -14.18], bootstrapped prediction: [-15.063947], in Range: False
# Input: -6 - -7 - -5, Actual: 6.00, Predicted Range: [3.44, 5.61], bootstrapped prediction: [4.5951524], in Range: False
# Input: 7 - 6 - 6, Actual: -5.00, Predicted Range: [-3.68, 0.22], bootstrapped prediction: [-1.8755608], in Range: False
# Input: 8 - -8 + 8, Actual: 24.00, Predicted Range: [15.47, 18.39], bootstrapped prediction: [16.846672], in Range: False
# Input: -7 + 7 + -6, Actual: -6.00, Predicted Range: [-9.55, -5.10], bootstrapped prediction: [-6.9703093], in Range: True
# Input: 6 + 6 + -8, Actual: 4.00, Predicted Range: [2.07, 6.46], bootstrapped prediction: [4.191922], in Range: True
# Input: -7 + -8 - 8, Actual: -23.00, Predicted Range: [-19.24, -14.28], bootstrapped prediction: [-16.887032], in Range: False
# Input: -5 + -7 + -5, Actual: -17.00, Predicted Range: [-16.23, -13.46], bootstrapped prediction: [-14.736252], in Range: False
# Input: 8 - -8 - 5, Actual: 11.00, Predicted Range: [8.62, 11.98], bootstrapped prediction: [9.946734], in Range: True
# Input: 5 + -5 + -7, Actual: -7.00, Predicted Range: [-5.15, -3.23], bootstrapped prediction: [-4.325942], in Range: False
# Input: -5 + 8 + -5, Actual: -2.00, Predicted Range: [-6.61, -1.89], bootstrapped prediction: [-4.330397], in Range: True
# Input: -6 - 7 + -8, Actual: -21.00, Predicted Range: [-16.81, -13.63], bootstrapped prediction: [-15.444151], in Range: False
# Input: -6 + 8 - 5, Actual: -3.00, Predicted Range: [-8.14, -3.86], bootstrapped prediction: [-5.901299], in Range: False
# Input: -7 + -5 + 7, Actual: -5.00, Predicted Range: [-8.34, -4.98], bootstrapped prediction: [-6.675618], in Range: True
# Input: -7 - 7 + 6, Actual: -8.00, Predicted Range: [-11.25, -6.57], bootstrapped prediction: [-8.65345], in Range: True
# Input: 5 - -8 + -5, Actual: 8.00, Predicted Range: [5.09, 9.16], bootstrapped prediction: [7.669113], in Range: True
# Input: 8 + -5 + 6, Actual: 9.00, Predicted Range: [6.51, 8.77], bootstrapped prediction: [7.6020966], in Range: False
# Input: 5 - -5 + 8, Actual: 18.00, Predicted Range: [11.46, 14.19], bootstrapped prediction: [12.930229], in Range: False
# Input: 6 + 5 + 7, Actual: 18.00, Predicted Range: [11.85, 15.52], bootstrapped prediction: [13.285456], in Range: False
# Input: 6 - 7 - -6, Actual: 5.00, Predicted Range: [3.81, 6.52], bootstrapped prediction: [5.1233034], in Range: True
# Input: -5 - -6 + 5, Actual: 6.00, Predicted Range: [3.78, 4.90], bootstrapped prediction: [4.4579706], in Range: False
# Input: 8 - -5 + 6, Actual: 19.00, Predicted Range: [14.88, 16.71], bootstrapped prediction: [15.623436], in Range: False
# Input: -6 - 5 - -8, Actual: -3.00, Predicted Range: [-4.68, -2.50], bootstrapped prediction: [-3.6478355], in Range: True
# Input: -6 - 5 - -5, Actual: -6.00, Predicted Range: [-6.25, -4.29], bootstrapped prediction: [-5.606642], in Range: True
# Input: -6 - -7 - 7, Actual: -6.00, Predicted Range: [-7.96, -3.86], bootstrapped prediction: [-5.86485], in Range: True
# Input: 5 + -8 + 8, Actual: 5.00, Predicted Range: [2.22, 5.98], bootstrapped prediction: [4.4020877], in Range: True
# Input: -7 - 6 - -6, Actual: -7.00, Predicted Range: [-7.53, -4.43], bootstrapped prediction: [-6.452811], in Range: True
# Input: -5 + 8 - 8, Actual: -5.00, Predicted Range: [-9.71, -3.84], bootstrapped prediction: [-6.942878], in Range: True
# Input: -7 - -5 + 8, Actual: 6.00, Predicted Range: [-0.65, 3.38], bootstrapped prediction: [1.2176485], in Range: False
# Input: -6 + -6 + 5, Actual: -7.00, Predicted Range: [-7.63, -6.60], bootstrapped prediction: [-6.9683967], in Range: True
# Input: 6 - 5 - -8, Actual: 9.00, Predicted Range: [7.13, 9.31], bootstrapped prediction: [7.963435], in Range: True
# Input: -8 + -7 + 5, Actual: -10.00, Predicted Range: [-10.42, -8.75], bootstrapped prediction: [-9.444396], in Range: True
# Input: 8 + 7 + 6, Actual: 21.00, Predicted Range: [13.28, 16.73], bootstrapped prediction: [14.825129], in Range: False
# Input: -5 + -7 - -6, Actual: -6.00, Predicted Range: [-5.87, -4.48], bootstrapped prediction: [-5.030079], in Range: False
# Input: 8 + -7 - 5, Actual: -4.00, Predicted Range: [-3.04, 0.19], bootstrapped prediction: [-1.2928607], in Range: False
# Input: -8 - -8 + -6, Actual: -6.00, Predicted Range: [-8.65, -4.40], bootstrapped prediction: [-5.8432536], in Range: True
# Input: -8 - -5 - 5, Actual: -8.00, Predicted Range: [-8.99, -7.31], bootstrapped prediction: [-8.090212], in Range: True
# Input: -6 + -7 - 7, Actual: -20.00, Predicted Range: [-17.64, -13.88], bootstrapped prediction: [-15.815175], in Range: False
# Input: -5 - -6 - -6, Actual: 7.00, Predicted Range: [5.21, 6.44], bootstrapped prediction: [5.7059717], in Range: False
# Input: 8 + 7 - -8, Actual: 23.00, Predicted Range: [14.74, 18.05], bootstrapped prediction: [16.271885], in Range: False
# Input: -5 + 7 - -8, Actual: 10.00, Predicted Range: [2.84, 6.00], bootstrapped prediction: [4.4531765], in Range: False
# Input: 6 - -8 - -7, Actual: 21.00, Predicted Range: [16.14, 19.16], bootstrapped prediction: [17.913761], in Range: False
# Input: -5 + -5 + -8, Actual: -18.00, Predicted Range: [-15.46, -13.62], bootstrapped prediction: [-14.378424], in Range: False
# Input: -6 + -6 - -5, Actual: -7.00, Predicted Range: [-6.88, -6.12], bootstrapped prediction: [-6.5279374], in Range: False
# Input: -5 - 7 + -7, Actual: -19.00, Predicted Range: [-16.03, -12.91], bootstrapped prediction: [-14.658859], in Range: False
# ...
# Input: -5 + -7 + -8, Actual: -20.00, Predicted Range: [-16.40, -13.49], bootstrapped prediction: [-14.661281], in Range: False
# Input: -7 - -7 - -7, Actual: 7.00, Predicted Range: [3.48, 5.69], bootstrapped prediction: [4.4505343], in Range: False
# Input: 5 + -6 - 8, Actual: -9.00, Predicted Range: [-6.74, -3.46], bootstrapped prediction: [-5.0939574], in Range: False
# Input: 7 - 5 - 8, Actual: -6.00, Predicted Range: [-4.40, 0.25], bootstrapped prediction: [-2.5745006], in Range: False
# Input: 7 + -7 + -6, Actual: -6.00, Predicted Range: [-3.62, -0.43], bootstrapped prediction: [-2.0394917], in Range: False
# Input: -6 + -7 - 5, Actual: -18.00, Predicted Range: [-16.72, -14.37], bootstrapped prediction: [-15.392675], in Range: False
# Input: 6 - -6 - -6, Actual: 18.00, Predicted Range: [15.90, 16.88], bootstrapped prediction: [16.407322], in Range: False
# Input: 5 - 5 + 7, Actual: 7.00, Predicted Range: [3.79, 7.18], bootstrapped prediction: [5.234079], in Range: True
# Input: 6 - -8 + 6, Actual: 20.00, Predicted Range: [14.81, 16.97], bootstrapped prediction: [15.638875], in Range: False
# Input: 7 - 7 + 8, Actual: 8.00, Predicted Range: [3.38, 8.98], bootstrapped prediction: [5.763353], in Range: True
# Input: 6 - 8 + -8, Actual: -10.00, Predicted Range: [-6.37, -1.69], bootstrapped prediction: [-4.407725], in Range: False
# Input: -8 - -6 - -8, Actual: 6.00, Predicted Range: [1.73, 3.81], bootstrapped prediction: [3.1126237], in Range: False
# Input: -7 - -7 - -5, Actual: 5.00, Predicted Range: [2.30, 4.66], bootstrapped prediction: [3.533549], in Range: False
# Input: 6 - -6 + 5, Actual: 17.00, Predicted Range: [14.48, 15.40], bootstrapped prediction: [14.968966], in Range: False
# Input: 5 - 8 + -5, Actual: -8.00, Predicted Range: [-7.04, -2.42], bootstrapped prediction: [-4.9978395], in Range: False
# Input: -8 - -5 + 8, Actual: 5.00, Predicted Range: [-1.90, 2.41], bootstrapped prediction: [0.05918317], in Range: False
# Input: 8 + -8 + 7, Actual: 7.00, Predicted Range: [5.26, 8.53], bootstrapped prediction: [7.09027], in Range: True
# Input: -8 - -7 + 7, Actual: 6.00, Predicted Range: [0.06, 2.76], bootstrapped prediction: [1.4327784], in Range: False
# Input: -8 - -7 - 6, Actual: -7.00, Predicted Range: [-9.18, -5.87], bootstrapped prediction: [-7.2329216], in Range: True
# Input: 5 + 5 - -8, Actual: 18.00, Predicted Range: [12.71, 15.48], bootstrapped prediction: [13.906184], in Range: False
# Input: 7 - 8 + -8, Actual: -9.00, Predicted Range: [-5.44, -0.64], bootstrapped prediction: [-3.384112], in Range: False
# Input: -8 + -5 - 6, Actual: -19.00, Predicted Range: [-18.28, -15.59], bootstrapped prediction: [-16.948154], in Range: False
# Input: 6 + 6 - -7, Actual: 19.00, Predicted Range: [13.78, 15.87], bootstrapped prediction: [14.607498], in Range: False
# Input: -5 + 7 + 5, Actual: 7.00, Predicted Range: [0.21, 4.46], bootstrapped prediction: [2.4713027], in Range: False
# Input: -6 + -8 - -8, Actual: -6.00, Predicted Range: [-6.05, -3.78], bootstrapped prediction: [-4.7674932], in Range: True
# Input: 5 - -6 + -6, Actual: 5.00, Predicted Range: [4.82, 6.39], bootstrapped prediction: [5.5904155], in Range: True
# Input: -7 + 8 + 7, Actual: 8.00, Predicted Range: [-2.82, 2.88], bootstrapped prediction: [0.2156945], in Range: False
# Input: 5 - 6 - -5, Actual: 4.00, Predicted Range: [3.37, 5.01], bootstrapped prediction: [4.1042147], in Range: True
# Input: 8 + -8 + 5, Actual: 5.00, Predicted Range: [4.69, 8.49], bootstrapped prediction: [6.456632], in Range: True
# Input: 8 - -5 - 8, Actual: 5.00, Predicted Range: [3.66, 8.07], bootstrapped prediction: [5.5690894], in Range: True
# Input: 8 + 7 - -7, Actual: 22.00, Predicted Range: [14.45, 17.82], bootstrapped prediction: [16.084635], in Range: False
# Input: 7 - -8 - -8, Actual: 23.00, Predicted Range: [17.45, 20.30], bootstrapped prediction: [19.031183], in Range: False
# Input: 8 - -5 + -8, Actual: 5.00, Predicted Range: [6.19, 8.65], bootstrapped prediction: [7.546894], in Range: False
# Input: -8 + -6 - 8, Actual: -22.00, Predicted Range: [-20.23, -15.30], bootstrapped prediction: [-17.6984], in Range: False
# Input: -5 - -7 - -6, Actual: 8.00, Predicted Range: [5.09, 7.07], bootstrapped prediction: [6.1432643], in Range: False
# Input: 8 + -8 + -6, Actual: -6.00, Predicted Range: [-2.94, 1.50], bootstrapped prediction: [-0.51819843], in Range: False
# Input: 8 - 6 + -5, Actual: -3.00, Predicted Range: [-2.62, 0.58], bootstrapped prediction: [-1.0945323], in Range: False
# Input: -6 - 7 + 8, Actual: -5.00, Predicted Range: [-9.44, -4.95], bootstrapped prediction: [-7.084105], in Range: True
# Input: -8 + -8 + -7, Actual: -23.00, Predicted Range: [-18.79, -15.84], bootstrapped prediction: [-17.310719], in Range: False
# Input: -7 - -5 + -7, Actual: -9.00, Predicted Range: [-8.35, -6.56], bootstrapped prediction: [-7.5883355], in Range: False
# Input: 6 - -6 + -5, Actual: 7.00, Predicted Range: [6.07, 7.84], bootstrapped prediction: [7.050338], in Range: True
# Input: -8 - -5 + -7, Actual: -10.00, Predicted Range: [-9.35, -7.51], bootstrapped prediction: [-8.530527], in Range: False
# Input: 8 + -8 - -5, Actual: 5.00, Predicted Range: [5.07, 8.97], bootstrapped prediction: [7.3201547], in Range: False
# Input: 6 + 7 - -5, Actual: 18.00, Predicted Range: [12.34, 15.10], bootstrapped prediction: [13.714383], in Range: False
# Input: 5 + 6 - 7, Actual: 4.00, Predicted Range: [1.39, 5.55], bootstrapped prediction: [3.4551682], in Range: True
# Input: -7 + -8 - -8, Actual: -7.00, Predicted Range: [-6.81, -4.89], bootstrapped prediction: [-5.6982484], in Range: False
# Input: -6 + -5 - -8, Actual: -3.00, Predicted Range: [-5.10, -2.69], bootstrapped prediction: [-3.7139878], in Range: True
# Input: -5 + -7 - 8, Actual: -20.00, Predicted Range: [-17.25, -12.61], bootstrapped prediction: [-14.9318285], in Range: False
# Input: -8 + 6 + -8, Actual: -10.00, Predicted Range: [-11.50, -6.92], bootstrapped prediction: [-9.061174], in Range: True
# Input: 6 + -6 + -8, Actual: -8.00, Predicted Range: [-4.65, -1.74], bootstrapped prediction: [-3.236134], in Range: False
# Input: 8 - -5 + -5, Actual: 8.00, Predicted Range: [6.88, 8.83], bootstrapped prediction: [8.063059], in Range: True
# Input: -5 - -8 - -7, Actual: 10.00, Predicted Range: [5.24, 8.20], bootstrapped prediction: [6.890732], in Range: False
# Input: 8 - 7 + 5, Actual: 6.00, Predicted Range: [3.86, 7.45], bootstrapped prediction: [5.8013725], in Range: True
# Input: -6 - 8 + -5, Actual: -19.00, Predicted Range: [-17.24, -12.43], bootstrapped prediction: [-15.187551], in Range: False
# Input: 7 - 8 - 5, Actual: -6.00, Predicted Range: [-4.81, 1.23], bootstrapped prediction: [-2.0082712], in Range: False
# Input: 8 + -7 - 8, Actual: -7.00, Predicted Range: [-4.48, -0.19], bootstrapped prediction: [-2.2182548], in Range: False
# Input: -5 + 5 + 6, Actual: 6.00, Predicted Range: [1.62, 3.58], bootstrapped prediction: [2.7715983], in Range: False
# Input: -5 + 6 - 6, Actual: -5.00, Predicted Range: [-7.14, -4.34], bootstrapped prediction: [-5.904472], in Range: True
# Input: 7 - 8 - 8, Actual: -9.00, Predicted Range: [-6.64, 0.31], bootstrapped prediction: [-3.2264225], in Range: False
# Input: -7 + -8 - 6, Actual: -21.00, Predicted Range: [-18.47, -14.76], bootstrapped prediction: [-16.507856], in Range: False
# Input: 8 - 8 - -6, Actual: 6.00, Predicted Range: [4.02, 8.42], bootstrapped prediction: [6.2313185], in Range: True
# Input: 7 - -7 + 5, Actual: 19.00, Predicted Range: [15.39, 16.73], bootstrapped prediction: [16.112497], in Range: False
# Input: -7 - 5 - 6, Actual: -18.00, Predicted Range: [-16.23, -14.79], bootstrapped prediction: [-15.54465], in Range: False
# Input: -8 + 8 - -6, Actual: 6.00, Predicted Range: [-1.47, 3.38], bootstrapped prediction: [0.5195858], in Range: False
# Input: -8 + 8 + 7, Actual: 7.00, Predicted Range: [-3.94, 1.83], bootstrapped prediction: [-0.8411126], in Range: False
# Input: 6 - -7 + 8, Actual: 21.00, Predicted Range: [13.71, 16.33], bootstrapped prediction: [14.829809], in Range: False
# Input: 6 + 7 - -8, Actual: 21.00, Predicted Range: [13.77, 16.21], bootstrapped prediction: [14.652525], in Range: False
# Input: 6 - -5 + -5, Actual: 6.00, Predicted Range: [5.25, 6.64], bootstrapped prediction: [6.085845], in Range: True
# Input: 8 + -5 + 8, Actual: 11.00, Predicted Range: [6.42, 9.89], bootstrapped prediction: [7.797445], in Range: False
# Input: -7 + -5 - -7, Actual: -5.00, Predicted Range: [-6.20, -4.57], bootstrapped prediction: [-5.2977395], in Range: True
# Input: -5 + 6 + 6, Actual: 7.00, Predicted Range: [0.99, 4.13], bootstrapped prediction: [2.761321], in Range: False
# Input: -6 - 7 - 6, Actual: -19.00, Predicted Range: [-16.91, -13.87], bootstrapped prediction: [-15.286044], in Range: False
# Input: -8 + 6 - -7, Actual: 5.00, Predicted Range: [0.58, 2.35], bootstrapped prediction: [1.3833863], in Range: False
# Input: 6 - -6 - 6, Actual: 6.00, Predicted Range: [5.11, 7.59], bootstrapped prediction: [5.98435], in Range: True
# Input: 8 + 8 - 7, Actual: 9.00, Predicted Range: [3.57, 9.26], bootstrapped prediction: [6.5485764], in Range: True
# Input: -5 - -6 - 6, Actual: -5.00, Predicted Range: [-6.20, -3.69], bootstrapped prediction: [-4.8725076], in Range: True
# Input: 7 - -6 - -5, Actual: 18.00, Predicted Range: [15.67, 17.24], bootstrapped prediction: [16.534063], in Range: False
# Input: 7 + -6 + -6, Actual: -5.00, Predicted Range: [-3.37, -0.65], bootstrapped prediction: [-2.227908], in Range: False
# Input: 6 + 8 - -6, Actual: 20.00, Predicted Range: [12.11, 15.60], bootstrapped prediction: [13.890448], in Range: False
# Input: -5 - 5 + -7, Actual: -17.00, Predicted Range: [-14.85, -13.19], bootstrapped prediction: [-14.039843], in Range: False
# Input: -8 - -6 - 5, Actual: -7.00, Predicted Range: [-8.50, -6.35], bootstrapped prediction: [-7.265568], in Range: True
# Input: -8 + -8 + 5, Actual: -11.00, Predicted Range: [-11.06, -8.30], bootstrapped prediction: [-9.626874], in Range: True
# Input: 5 - -7 + 6, Actual: 18.00, Predicted Range: [13.79, 15.39], bootstrapped prediction: [14.495506], in Range: False
# Input: -8 + -7 - 5, Actual: -20.00, Predicted Range: [-18.11, -16.31], bootstrapped prediction: [-17.110693], in Range: False
# Input: -6 + 5 + -6, Actual: -7.00, Predicted Range: [-8.32, -5.83], bootstrapped prediction: [-6.8471193], in Range: True
# Input: -6 - -6 + -6, Actual: -6.00, Predicted Range: [-6.70, -4.95], bootstrapped prediction: [-5.597223], in Range: True
# Input: 8 + 6 + -8, Actual: 6.00, Predicted Range: [3.63, 8.76], bootstrapped prediction: [6.1721168], in Range: True
# Input: 7 + -5 - -6, Actual: 8.00, Predicted Range: [7.32, 8.81], bootstrapped prediction: [8.064736], in Range: True
# Input: -8 - 5 - -5, Actual: -8.00, Predicted Range: [-8.73, -5.79], bootstrapped prediction: [-7.4833055], in Range: True
# Input: -7 + 5 - -6, Actual: 4.00, Predicted Range: [1.59, 2.68], bootstrapped prediction: [2.0907865], in Range: False
# Input: 7 + 7 + 8, Actual: 22.00, Predicted Range: [11.11, 16.77], bootstrapped prediction: [13.82825], in Range: False
# Input: -7 - -6 - 6, Actual: -7.00, Predicted Range: [-8.31, -5.64], bootstrapped prediction: [-6.9752655], in Range: True
# Input: 8 + 8 + 6, Actual: 22.00, Predicted Range: [12.46, 17.00], bootstrapped prediction: [14.616992], in Range: False
# Input: 6 + -7 - -6, Actual: 5.00, Predicted Range: [5.30, 7.47], bootstrapped prediction: [6.2461977], in Range: False
# Input: -7 + 7 - 5, Actual: -5.00, Predicted Range: [-8.74, -5.06], bootstrapped prediction: [-6.9426003], in Range: False
# Input: -7 - -6 - -6, Actual: 5.00, Predicted Range: [2.95, 4.58], bootstrapped prediction: [3.6082826], in Range: False
# Input: -7 - 6 - -8, Actual: -5.00, Predicted Range: [-6.17, -3.45], bootstrapped prediction: [-5.1608696], in Range: True
# Input: 6 + -8 + 7, Actual: 5.00, Predicted Range: [3.42, 6.52], bootstrapped prediction: [5.214475], in Range: True
# Input: 7 + 6 + 8, Actual: 21.00, Predicted Range: [11.82, 16.74], bootstrapped prediction: [13.929219], in Range: False
# Input: -8 + -7 - -6, Actual: -9.00, Predicted Range: [-8.69, -7.57], bootstrapped prediction: [-7.906761], in Range: False
# Input: -7 + 6 - -6, Actual: 5.00, Predicted Range: [1.18, 3.16], bootstrapped prediction: [2.0303211], in Range: False
# Input: -7 + -6 - 8, Actual: -21.00, Predicted Range: [-19.27, -14.39], bootstrapped prediction: [-16.747583], in Range: False
# Input: -7 - -5 - -8, Actual: 6.00, Predicted Range: [2.04, 4.60], bootstrapped prediction: [3.4956524], in Range: False
# Input: -7 + -6 + 5, Actual: -8.00, Predicted Range: [-8.78, -7.56], bootstrapped prediction: [-8.011958], in Range: True
# Input: 8 - 8 - -5, Actual: 5.00, Predicted Range: [3.27, 7.81], bootstrapped prediction: [5.421816], in Range: True
# Input: 8 - -6 + 5, Actual: 19.00, Predicted Range: [15.66, 17.10], bootstrapped prediction: [16.238708], in Range: False
# Input: 7 - -8 - -6, Actual: 21.00, Predicted Range: [16.17, 19.52], bootstrapped prediction: [18.2196], in Range: False
# Input: 6 - 8 + 8, Actual: 6.00, Predicted Range: [1.05, 7.37], bootstrapped prediction: [4.11867], in Range: True
# Input: 7 - 6 + -6, Actual: -5.00, Predicted Range: [-4.12, -1.01], bootstrapped prediction: [-2.6375961], in Range: False
# Input: 7 + -8 + -6, Actual: -7.00, Predicted Range: [-4.07, 0.29], bootstrapped prediction: [-1.6975273], in Range: False
# Input: -7 + -8 - -6, Actual: -9.00, Predicted Range: [-8.51, -6.41], bootstrapped prediction: [-7.1442175], in Range: False
# Input: 5 + -8 + -5, Actual: -8.00, Predicted Range: [-6.34, -2.04], bootstrapped prediction: [-3.8657212], in Range: False
# Input: -8 + 8 + -6, Actual: -6.00, Predicted Range: [-10.67, -5.34], bootstrapped prediction: [-7.634581], in Range: True
# Input: 6 + 8 + 7, Actual: 21.00, Predicted Range: [9.95, 15.50], bootstrapped prediction: [12.844492], in Range: False
# Input: 5 + 8 - 6, Actual: 7.00, Predicted Range: [1.32, 7.13], bootstrapped prediction: [4.3498015], in Range: True
# Input: 6 - -5 + -8, Actual: 3.00, Predicted Range: [4.35, 6.25], bootstrapped prediction: [5.4257674], in Range: False
# Input: -6 + -7 + 5, Actual: -8.00, Predicted Range: [-8.39, -6.58], bootstrapped prediction: [-7.4269953], in Range: True
# Input: 7 - 6 - -7, Actual: 8.00, Predicted Range: [6.37, 8.61], bootstrapped prediction: [7.5357666], in Range: True
# Input: -7 - 5 + 8, Actual: -4.00, Predicted Range: [-8.57, -4.32], bootstrapped prediction: [-6.747782], in Range: False
# Input: -7 - 8 + -8, Actual: -23.00, Predicted Range: [-18.25, -13.96], bootstrapped prediction: [-16.458828], in Range: False
# Input: 5 - 6 - 7, Actual: -8.00, Predicted Range: [-6.51, -1.90], bootstrapped prediction: [-4.4560847], in Range: False
# Input: -8 + 6 + 7, Actual: 5.00, Predicted Range: [-2.44, 0.66], bootstrapped prediction: [-0.60729396], in Range: False
# Input: -7 - 7 + 8, Actual: -6.00, Predicted Range: [-10.59, -5.94], bootstrapped prediction: [-8.096934], in Range: True
# Input: -8 + -7 + -7, Actual: -22.00, Predicted Range: [-18.73, -16.43], bootstrapped prediction: [-17.581861], in Range: False
# Input: 5 + -6 + 5, Actual: 4.00, Predicted Range: [3.36, 4.84], bootstrapped prediction: [4.085342], in Range: True
# Input: -7 + -7 - -5, Actual: -9.00, Predicted Range: [-8.56, -7.02], bootstrapped prediction: [-7.760316], in Range: False
# Input: -6 - -7 + -6, Actual: -5.00, Predicted Range: [-6.71, -3.70], bootstrapped prediction: [-4.7880535], in Range: True
# Input: -6 - -5 - -7, Actual: 6.00, Predicted Range: [3.21, 5.15], bootstrapped prediction: [4.2814703], in Range: False
# Input: 8 - 7 - -5, Actual: 6.00, Predicted Range: [4.47, 7.85], bootstrapped prediction: [6.169938], in Range: True
# Input: 6 - -5 - -7, Actual: 18.00, Predicted Range: [15.30, 16.49], bootstrapped prediction: [15.915331], in Range: False
# Input: -6 - 7 - 7, Actual: -20.00, Predicted Range: [-17.45, -13.91], bootstrapped prediction: [-15.654554], in Range: False
# Amount out of bounds: 1185, Amount of expressions: 2048, Percentage in bounds: 42.138671875%

# %%
long_meanPredictions = []
for i in range(len(long_x_test)):
  calc = 0
  for j in range(n_bootstrap):
    calc += long_predictions[j][i]
  long_meanPredictions.append(calc/n_bootstrap)


# Calculate the lower and upper bounds of the prediction range
long_lower_bound = np.percentile(long_predictions, 5, axis=0)
long_upper_bound = np.percentile(long_predictions, 95, axis=0)


long_inRange = []
long_outOfBounds = 0
for i in range(len(long_y_test)):
  if long_y_test[i] >= long_lower_bound[i][0] and long_y_test[i] <= long_upper_bound[i][0]:
    long_inRange.append(True)
  else:
    long_inRange.append(False)
    long_outOfBounds += 1


print("Prediction Range (5th to 95th percentile):")
for i in range(len(long_x_test)):
  print(f"Input: {longer_Exps[i]}, Actual: {long_y_test[i]:.2f}, Predicted Range: [{long_lower_bound[i][0]:.2f}, {long_upper_bound[i][0]:.2f}], bootstrapped prediction: {long_meanPredictions[i]}, in Range: {long_inRange[i]}")

print(f"Amount out of bounds: {long_outOfBounds}, Amount of expressions: {len(long_x_test)}, Percentage in bounds: {(1-(long_outOfBounds/len(long_x_test)))*100}%")
# Out:
# Prediction Range (5th to 95th percentile):
# Input: -2 - -1, Actual: -1.00, Predicted Range: [-2.26, 0.23], bootstrapped prediction: [-0.9487203], in Range: True
# Input: -3 - -1, Actual: -2.00, Predicted Range: [-3.32, -0.63], bootstrapped prediction: [-1.9058596], in Range: True
# Input: 1 + -4, Actual: -3.00, Predicted Range: [-4.97, -2.05], bootstrapped prediction: [-3.4720871], in Range: True
# Input: 3 - 0, Actual: 3.00, Predicted Range: [1.75, 4.54], bootstrapped prediction: [3.063953], in Range: True
# Input: 0 + -3, Actual: -3.00, Predicted Range: [-4.89, -2.17], bootstrapped prediction: [-3.4569378], in Range: True
# Input: 4 + 3, Actual: 7.00, Predicted Range: [6.26, 8.15], bootstrapped prediction: [7.3778267], in Range: True
# Input: -2 + -3, Actual: -5.00, Predicted Range: [-6.95, -4.25], bootstrapped prediction: [-5.5644965], in Range: True
# Input: -1 - 2, Actual: -3.00, Predicted Range: [-4.55, -1.69], bootstrapped prediction: [-3.1837103], in Range: True
# Input: 2 - -5, Actual: 7.00, Predicted Range: [6.05, 8.58], bootstrapped prediction: [7.431268], in Range: True
# Input: 5 - 0, Actual: 5.00, Predicted Range: [3.59, 6.42], bootstrapped prediction: [5.079768], in Range: True
# Input: 5 - 1, Actual: 4.00, Predicted Range: [2.80, 5.78], bootstrapped prediction: [4.0891743], in Range: True
# Input: 3 - 2, Actual: 1.00, Predicted Range: [-0.67, 2.61], bootstrapped prediction: [0.86612236], in Range: True
# Input: 5 - 2, Actual: 3.00, Predicted Range: [1.80, 4.73], bootstrapped prediction: [3.01947], in Range: True
# Input: 1 - -5, Actual: 6.00, Predicted Range: [5.18, 7.47], bootstrapped prediction: [6.4848785], in Range: True
# Input: -4 + 0, Actual: -4.00, Predicted Range: [-5.38, -2.57], bootstrapped prediction: [-3.952959], in Range: True
# Input: -4 - -2, Actual: -2.00, Predicted Range: [-3.10, -0.64], bootstrapped prediction: [-1.7924343], in Range: True
# Input: 4 + 0, Actual: 4.00, Predicted Range: [2.70, 5.37], bootstrapped prediction: [4.186589], in Range: True
# Input: 2 + 0, Actual: 2.00, Predicted Range: [0.91, 3.20], bootstrapped prediction: [2.1271806], in Range: True
# Input: -4 + 5, Actual: 1.00, Predicted Range: [-1.09, 2.06], bootstrapped prediction: [0.6972381], in Range: True
# Input: 0 + 0, Actual: 0.00, Predicted Range: [-1.17, 1.12], bootstrapped prediction: [0.03097271], in Range: True
# Input: 4 + -5, Actual: -1.00, Predicted Range: [-3.23, 0.09], bootstrapped prediction: [-1.5450356], in Range: True
# Input: 4 + -1, Actual: 3.00, Predicted Range: [1.59, 4.31], bootstrapped prediction: [3.0826747], in Range: True
# Input: 0 + -2, Actual: -2.00, Predicted Range: [-3.75, -1.04], bootstrapped prediction: [-2.3339372], in Range: True
# Input: 1 + 0, Actual: 1.00, Predicted Range: [-0.19, 2.14], bootstrapped prediction: [1.0705211], in Range: True
# Input: -2 - 2, Actual: -4.00, Predicted Range: [-5.60, -2.76], bootstrapped prediction: [-4.1712976], in Range: True
# Input: 3 - 5, Actual: -2.00, Predicted Range: [-3.22, -0.85], bootstrapped prediction: [-2.0665421], in Range: True
# Input: -2 - 5, Actual: -7.00, Predicted Range: [-8.48, -5.95], bootstrapped prediction: [-7.260704], in Range: True
# Input: 2 - 3, Actual: -1.00, Predicted Range: [-2.86, 0.04], bootstrapped prediction: [-1.4030344], in Range: True
# Input: -3 + 3, Actual: 0.00, Predicted Range: [-0.85, 1.77], bootstrapped prediction: [0.6638173], in Range: True
# Input: -5 + -3, Actual: -8.00, Predicted Range: [-9.85, -6.88], bootstrapped prediction: [-8.341572], in Range: True
# Input: 3 + -5, Actual: -2.00, Predicted Range: [-4.26, -0.99], bootstrapped prediction: [-2.5450482], in Range: True
# Input: 1 - 1, Actual: 0.00, Predicted Range: [-1.30, 1.48], bootstrapped prediction: [-0.08808158], in Range: True
# Input: -5 + 4, Actual: -1.00, Predicted Range: [-2.30, 0.43], bootstrapped prediction: [-0.7553363], in Range: True
# Input: 4 - 4, Actual: 0.00, Predicted Range: [-1.45, 1.27], bootstrapped prediction: [-0.18919478], in Range: True
# Input: 4 - -3, Actual: 7.00, Predicted Range: [6.06, 8.51], bootstrapped prediction: [7.258428], in Range: True
# Input: 2 + -5, Actual: -3.00, Predicted Range: [-5.16, -1.98], bootstrapped prediction: [-3.5184472], in Range: True
# Input: 3 - -2, Actual: 5.00, Predicted Range: [3.83, 6.42], bootstrapped prediction: [5.148217], in Range: True
# Input: 2 - -1, Actual: 3.00, Predicted Range: [2.04, 4.32], bootstrapped prediction: [3.08418], in Range: True
# Input: -3 - -5, Actual: 2.00, Predicted Range: [1.20, 3.24], bootstrapped prediction: [2.316156], in Range: True
# Input: 4 + 5, Actual: 9.00, Predicted Range: [7.56, 9.91], bootstrapped prediction: [8.77363], in Range: True
# Input: 0 - 1, Actual: -1.00, Predicted Range: [-2.27, 0.42], bootstrapped prediction: [-1.0852545], in Range: True
# Input: -3 + -5, Actual: -8.00, Predicted Range: [-10.13, -7.26], bootstrapped prediction: [-8.7107115], in Range: True
# Input: 1 + 5, Actual: 6.00, Predicted Range: [4.61, 7.30], bootstrapped prediction: [5.907831], in Range: True
# Input: -5 - -4, Actual: -1.00, Predicted Range: [-1.72, 0.39], bootstrapped prediction: [-0.5047475], in Range: True
# Input: -2 + -5, Actual: -7.00, Predicted Range: [-9.11, -6.35], bootstrapped prediction: [-7.739164], in Range: True
# Input: -2 - -2, Actual: 0.00, Predicted Range: [-1.03, 1.31], bootstrapped prediction: [0.146657], in Range: True
# Input: -2 + 3, Actual: 1.00, Predicted Range: [0.19, 2.76], bootstrapped prediction: [1.6357676], in Range: True
# Input: -5 + 1, Actual: -4.00, Predicted Range: [-5.19, -2.38], bootstrapped prediction: [-3.682169], in Range: True
# Input: -2 - -1, Actual: -1.00, Predicted Range: [-2.26, 0.23], bootstrapped prediction: [-0.9487203], in Range: True
# Input: -4 + 1, Actual: -3.00, Predicted Range: [-3.99, -1.43], bootstrapped prediction: [-2.6610353], in Range: True
# Input: 4 + 1, Actual: 5.00, Predicted Range: [3.94, 6.38], bootstrapped prediction: [5.2986565], in Range: True
# Input: -2 - -5, Actual: 3.00, Predicted Range: [2.26, 4.37], bootstrapped prediction: [3.3739095], in Range: True
# Input: -5 - -2, Actual: -3.00, Predicted Range: [-4.21, -1.58], bootstrapped prediction: [-2.8062723], in Range: True
# Input: -2 - 1, Actual: -3.00, Predicted Range: [-4.21, -1.73], bootstrapped prediction: [-3.0175567], in Range: True
# Input: 3 + 4, Actual: 7.00, Predicted Range: [6.41, 8.39], bootstrapped prediction: [7.415227], in Range: True
# Input: -1 - 5, Actual: -6.00, Predicted Range: [-7.39, -4.89], bootstrapped prediction: [-6.2065034], in Range: True
# Input: -3 + 0, Actual: -3.00, Predicted Range: [-4.24, -1.78], bootstrapped prediction: [-2.993578], in Range: True
# Input: -5 + -3, Actual: -8.00, Predicted Range: [-9.85, -6.88], bootstrapped prediction: [-8.341572], in Range: True
# Input: -1 - 1, Actual: -2.00, Predicted Range: [-3.15, -0.63], bootstrapped prediction: [-2.0390382], in Range: True
# Input: 1 - 3, Actual: -2.00, Predicted Range: [-3.75, -0.91], bootstrapped prediction: [-2.4071074], in Range: True
# Input: -5 + 3, Actual: -2.00, Predicted Range: [-3.04, -0.40], bootstrapped prediction: [-1.5000414], in Range: True
# Input: 2 - 2, Actual: 0.00, Predicted Range: [-1.66, 1.44], bootstrapped prediction: [-0.22185263], in Range: True
# Input: 2 - 2, Actual: 0.00, Predicted Range: [-1.66, 1.44], bootstrapped prediction: [-0.22185263], in Range: True
# Input: -3 + 3, Actual: 0.00, Predicted Range: [-0.85, 1.77], bootstrapped prediction: [0.6638175], in Range: True
# Input: -2 + 5, Actual: 3.00, Predicted Range: [1.29, 4.26], bootstrapped prediction: [2.8343492], in Range: True
# Input: 0 + 5, Actual: 5.00, Predicted Range: [3.40, 6.34], bootstrapped prediction: [4.881943], in Range: True
# Input: 5 + -5, Actual: 0.00, Predicted Range: [-2.22, 1.28], bootstrapped prediction: [-0.5029952], in Range: True
# Input: -3 + 3, Actual: 0.00, Predicted Range: [-0.85, 1.77], bootstrapped prediction: [0.6638173], in Range: True
# Input: -3 + 5, Actual: 2.00, Predicted Range: [0.11, 3.17], bootstrapped prediction: [1.7913563], in Range: True
# Input: 4 - -2, Actual: 6.00, Predicted Range: [4.63, 7.54], bootstrapped prediction: [6.095175], in Range: True
# Input: -1 + 1, Actual: 0.00, Predicted Range: [-0.84, 1.32], bootstrapped prediction: [0.24704643], in Range: True
# Input: 3 + 2, Actual: 5.00, Predicted Range: [4.34, 6.27], bootstrapped prediction: [5.4342637], in Range: True
# Input: -4 - 2, Actual: -6.00, Predicted Range: [-7.79, -4.96], bootstrapped prediction: [-6.3709135], in Range: True
# Input: 2 + -3, Actual: -1.00, Predicted Range: [-2.83, -0.04], bootstrapped prediction: [-1.3120178], in Range: True
# Input: 3 - 1, Actual: 2.00, Predicted Range: [0.68, 3.77], bootstrapped prediction: [2.0065036], in Range: True
# Input: -5 - 4, Actual: -9.00, Predicted Range: [-10.98, -8.31], bootstrapped prediction: [-9.536092], in Range: True
# Input: -1 - 3, Actual: -4.00, Predicted Range: [-5.77, -2.87], bootstrapped prediction: [-4.4032817], in Range: True
# Input: 4 + 2, Actual: 6.00, Predicted Range: [5.16, 7.17], bootstrapped prediction: [6.3662996], in Range: True
# Input: 5 - -3, Actual: 8.00, Predicted Range: [6.83, 9.54], bootstrapped prediction: [8.152201], in Range: True
# Input: -1 - -2, Actual: 1.00, Predicted Range: [0.07, 2.39], bootstrapped prediction: [1.1708928], in Range: True
# Input: -5 + 4, Actual: -1.00, Predicted Range: [-2.30, 0.43], bootstrapped prediction: [-0.7553363], in Range: True
# Input: 1 + -2, Actual: -1.00, Predicted Range: [-2.67, -0.03], bootstrapped prediction: [-1.2299974], in Range: True
# Input: 0 + 3, Actual: 3.00, Predicted Range: [2.29, 4.66], bootstrapped prediction: [3.5871105], in Range: True
# Input: 5 - -4, Actual: 9.00, Predicted Range: [7.90, 10.44], bootstrapped prediction: [9.259418], in Range: True
# Input: 5 + 4, Actual: 9.00, Predicted Range: [7.86, 9.91], bootstrapped prediction: [9.097952], in Range: True
# Input: -1 + 1, Actual: 0.00, Predicted Range: [-0.84, 1.32], bootstrapped prediction: [0.24704643], in Range: True
# Input: -3 - 1, Actual: -4.00, Predicted Range: [-5.39, -2.84], bootstrapped prediction: [-4.086943], in Range: True
# Input: -1 - 0, Actual: -1.00, Predicted Range: [-2.13, 0.21], bootstrapped prediction: [-0.994775], in Range: True
# Input: 0 + 5, Actual: 5.00, Predicted Range: [3.40, 6.34], bootstrapped prediction: [4.881943], in Range: True
# Input: -2 - 2, Actual: -4.00, Predicted Range: [-5.60, -2.76], bootstrapped prediction: [-4.1712976], in Range: True
# Input: 3 - 3, Actual: 0.00, Predicted Range: [-1.80, 1.20], bootstrapped prediction: [-0.30873495], in Range: True
# Input: 5 - -2, Actual: 7.00, Predicted Range: [5.47, 8.55], bootstrapped prediction: [7.0393906], in Range: True
# Input: 0 - 1, Actual: -1.00, Predicted Range: [-2.27, 0.42], bootstrapped prediction: [-1.0852545], in Range: True
# Input: -2 - 4, Actual: -6.00, Predicted Range: [-7.79, -5.09], bootstrapped prediction: [-6.5193167], in Range: True
# Input: 2 + 2, Actual: 4.00, Predicted Range: [3.36, 5.28], bootstrapped prediction: [4.46478], in Range: True
# Input: 4 - -3, Actual: 7.00, Predicted Range: [6.06, 8.51], bootstrapped prediction: [7.258429], in Range: True
# Input: -1 - 4, Actual: -5.00, Predicted Range: [-6.77, -3.97], bootstrapped prediction: [-5.4893923], in Range: True
# Input: 2 + 0, Actual: 2.00, Predicted Range: [0.91, 3.20], bootstrapped prediction: [2.1271806], in Range: True
# Input: -2 + -2, Actual: -4.00, Predicted Range: [-5.62, -3.09], bootstrapped prediction: [-4.3491], in Range: True
# Input: -2 - 1, Actual: -3.00, Predicted Range: [-4.21, -1.73], bootstrapped prediction: [-3.0175567], in Range: True
# Input: -1 - 2 - 1, Actual: -4.00, Predicted Range: [-4.36, -3.86], bootstrapped prediction: [-4.114698], in Range: True
# Input: 2 + -2 - 0, Actual: 0.00, Predicted Range: [-0.31, 0.31], bootstrapped prediction: [-0.04898772], in Range: True
# Input: -3 + 2 + 1, Actual: 0.00, Predicted Range: [-0.23, 0.20], bootstrapped prediction: [-0.00210322], in Range: True
# Input: 4 + 5 - -5, Actual: 14.00, Predicted Range: [11.87, 12.76], bootstrapped prediction: [12.369978], in Range: False
# Input: 4 + -4 - 2, Actual: -2.00, Predicted Range: [-2.44, -1.79], bootstrapped prediction: [-2.060793], in Range: True
# Input: -1 - -1 - 5, Actual: -5.00, Predicted Range: [-5.28, -4.33], bootstrapped prediction: [-4.9357386], in Range: True
# Input: -2 + -5 + 0, Actual: -7.00, Predicted Range: [-7.24, -6.71], bootstrapped prediction: [-6.986103], in Range: True
# Input: -2 - -3 - 3, Actual: -2.00, Predicted Range: [-2.09, -1.60], bootstrapped prediction: [-1.9115474], in Range: True
# Input: -3 - -4 - -5, Actual: 6.00, Predicted Range: [5.61, 6.06], bootstrapped prediction: [5.8398347], in Range: True
# Input: 5 + -4 + -5, Actual: -4.00, Predicted Range: [-4.12, -3.03], bootstrapped prediction: [-3.6557503], in Range: True
# Input: -5 - -1 - 3, Actual: -7.00, Predicted Range: [-7.17, -6.76], bootstrapped prediction: [-6.970954], in Range: True
# Input: 0 - -2 + -3, Actual: -1.00, Predicted Range: [-1.34, -0.95], bootstrapped prediction: [-1.1337965], in Range: True
# Input: 2 + -5 - 5, Actual: -8.00, Predicted Range: [-7.54, -6.87], bootstrapped prediction: [-7.156283], in Range: False
# Input: -1 - -1 - -1, Actual: 1.00, Predicted Range: [0.66, 1.42], bootstrapped prediction: [1.0443171], in Range: True
# Input: 2 - 2 - -2, Actual: 2.00, Predicted Range: [1.75, 2.06], bootstrapped prediction: [1.9519831], in Range: True
# Input: 3 - -5 + -1, Actual: 7.00, Predicted Range: [6.60, 7.21], bootstrapped prediction: [6.8969636], in Range: True
# Input: -1 - 3 + 3, Actual: -1.00, Predicted Range: [-1.12, -0.64], bootstrapped prediction: [-0.88983536], in Range: True
# Input: 5 - -3 - -2, Actual: 10.00, Predicted Range: [9.27, 9.95], bootstrapped prediction: [9.640402], in Range: False
# Input: -4 - -1 - 2, Actual: -5.00, Predicted Range: [-5.22, -4.78], bootstrapped prediction: [-4.962123], in Range: True
# Input: -5 + 1 - -5, Actual: 1.00, Predicted Range: [0.52, 1.19], bootstrapped prediction: [0.8509284], in Range: True
# Input: 5 + -4 + -4, Actual: -3.00, Predicted Range: [-3.09, -2.54], bootstrapped prediction: [-2.8664014], in Range: True
# Input: -4 - 5 - 1, Actual: -10.00, Predicted Range: [-9.99, -9.00], bootstrapped prediction: [-9.519039], in Range: False
# Input: 0 + 0 + 3, Actual: 3.00, Predicted Range: [2.82, 3.33], bootstrapped prediction: [3.07799], in Range: True
# Input: 2 - 2 - -1, Actual: 1.00, Predicted Range: [0.57, 1.27], bootstrapped prediction: [1.009634], in Range: True
# Input: 3 - -4 + 0, Actual: 7.00, Predicted Range: [6.64, 7.26], bootstrapped prediction: [6.9826365], in Range: True
# Input: 1 - -2 + 1, Actual: 4.00, Predicted Range: [3.83, 4.33], bootstrapped prediction: [4.0666904], in Range: True
# Input: -4 + -2 + -4, Actual: -10.00, Predicted Range: [-10.18, -9.88], bootstrapped prediction: [-10.036248], in Range: True
# Input: 4 - -5 + -3, Actual: 6.00, Predicted Range: [5.68, 6.37], bootstrapped prediction: [5.980611], in Range: True
# Input: -5 + -1 - 1, Actual: -7.00, Predicted Range: [-7.11, -6.29], bootstrapped prediction: [-6.7858567], in Range: True
# Input: 3 - 2 - 0, Actual: 1.00, Predicted Range: [0.61, 1.18], bootstrapped prediction: [0.9623335], in Range: True
# Input: -3 - 2 - -2, Actual: -3.00, Predicted Range: [-3.34, -2.76], bootstrapped prediction: [-3.0442033], in Range: True
# Input: -1 + 3 + 3, Actual: 5.00, Predicted Range: [4.89, 5.29], bootstrapped prediction: [5.130495], in Range: True
# Input: 2 - -4 - -3, Actual: 9.00, Predicted Range: [8.92, 9.24], bootstrapped prediction: [9.076773], in Range: True
# Input: 2 + -1 + 2, Actual: 3.00, Predicted Range: [2.91, 3.24], bootstrapped prediction: [3.0637991], in Range: True
# Input: 0 + -1 - -5, Actual: 4.00, Predicted Range: [3.77, 4.18], bootstrapped prediction: [3.9640622], in Range: True
# Input: -5 + -3 - 0, Actual: -8.00, Predicted Range: [-8.18, -7.71], bootstrapped prediction: [-7.9201994], in Range: True
# Input: 0 + 1 + -4, Actual: -3.00, Predicted Range: [-3.19, -2.86], bootstrapped prediction: [-3.048819], in Range: True
# Input: -2 + 1 - -2, Actual: 1.00, Predicted Range: [0.81, 1.27], bootstrapped prediction: [1.0348916], in Range: True
# Input: -2 + 2 - 2, Actual: -2.00, Predicted Range: [-2.10, -1.44], bootstrapped prediction: [-1.8524183], in Range: True
# Input: 3 + -2 - 2, Actual: -1.00, Predicted Range: [-1.25, -0.80], bootstrapped prediction: [-1.027111], in Range: True
# Input: 0 - 0 - -2, Actual: 2.00, Predicted Range: [1.68, 2.41], bootstrapped prediction: [2.088773], in Range: True
# Input: 3 - 1 - 5, Actual: -3.00, Predicted Range: [-3.25, -1.97], bootstrapped prediction: [-2.6264386], in Range: True
# Input: 0 + -4 - 0, Actual: -4.00, Predicted Range: [-4.33, -3.92], bootstrapped prediction: [-4.099822], in Range: True
# Input: 5 - -5 + 5, Actual: 15.00, Predicted Range: [13.23, 14.00], bootstrapped prediction: [13.642782], in Range: False
# Input: -1 + -3 - 1, Actual: -5.00, Predicted Range: [-5.25, -4.92], bootstrapped prediction: [-5.072874], in Range: True
# Input: -1 + 4 + -5, Actual: -2.00, Predicted Range: [-2.45, -1.64], bootstrapped prediction: [-2.1085238], in Range: True
# Input: 2 + 3 + -3, Actual: 2.00, Predicted Range: [1.79, 2.58], bootstrapped prediction: [2.1040196], in Range: True
# Input: 0 + 4 - -2, Actual: 6.00, Predicted Range: [5.77, 6.14], bootstrapped prediction: [5.97927], in Range: True
# Input: -3 - 0 + 5, Actual: 2.00, Predicted Range: [1.07, 2.08], bootstrapped prediction: [1.5957315], in Range: True
# Input: 3 + -3 + 3, Actual: 3.00, Predicted Range: [2.81, 3.34], bootstrapped prediction: [3.0617769], in Range: True
# Input: -3 - -5 + 3, Actual: 5.00, Predicted Range: [4.72, 5.26], bootstrapped prediction: [4.976326], in Range: True
# Input: -4 - 4 - 2, Actual: -10.00, Predicted Range: [-10.02, -9.51], bootstrapped prediction: [-9.801972], in Range: True
# Input: 3 + 3 - 0, Actual: 6.00, Predicted Range: [5.82, 6.41], bootstrapped prediction: [6.080905], in Range: True
# Input: 1 - -1 - 5, Actual: -3.00, Predicted Range: [-3.40, -2.12], bootstrapped prediction: [-2.8283036], in Range: True
# Input: -5 + 3 - -1, Actual: -1.00, Predicted Range: [-1.26, -0.82], bootstrapped prediction: [-1.043524], in Range: True
# Input: -1 - 5 + -4, Actual: -10.00, Predicted Range: [-9.89, -8.85], bootstrapped prediction: [-9.391992], in Range: False
# Input: 1 + 1 - -1, Actual: 3.00, Predicted Range: [2.71, 3.21], bootstrapped prediction: [3.021896], in Range: True
# Input: 0 - 1 + -2, Actual: -3.00, Predicted Range: [-3.31, -2.81], bootstrapped prediction: [-3.0619454], in Range: True
# Input: -3 - -2 + -4, Actual: -5.00, Predicted Range: [-5.32, -4.90], bootstrapped prediction: [-5.0910883], in Range: True
# Input: 5 - 3 + 1, Actual: 3.00, Predicted Range: [2.63, 3.44], bootstrapped prediction: [3.0287385], in Range: True
# Input: 0 - -5 - 1, Actual: 4.00, Predicted Range: [3.78, 4.37], bootstrapped prediction: [4.1054215], in Range: True
# Input: -4 + 2 + 5, Actual: 3.00, Predicted Range: [1.62, 2.68], bootstrapped prediction: [2.2580705], in Range: False
# Input: 5 - 5 + -2, Actual: -2.00, Predicted Range: [-2.29, -0.68], bootstrapped prediction: [-1.4935892], in Range: True
# Input: 1 + 5 + -4, Actual: 2.00, Predicted Range: [0.59, 1.97], bootstrapped prediction: [1.2096536], in Range: False
# Input: 1 + -4 - 4, Actual: -7.00, Predicted Range: [-7.14, -6.78], bootstrapped prediction: [-6.9305725], in Range: True
# Input: 3 + -1 - 1, Actual: 1.00, Predicted Range: [0.75, 1.41], bootstrapped prediction: [1.0347388], in Range: True
# Input: -5 - 3 + -1, Actual: -9.00, Predicted Range: [-9.15, -8.63], bootstrapped prediction: [-8.876365], in Range: True
# Input: 0 + 5 - 2, Actual: 3.00, Predicted Range: [1.96, 2.83], bootstrapped prediction: [2.4519942], in Range: False
# Input: -2 - 4 - -4, Actual: -2.00, Predicted Range: [-2.27, -1.54], bootstrapped prediction: [-1.9403899], in Range: True
# Input: -1 + 0 + 0, Actual: -1.00, Predicted Range: [-1.14, -0.75], bootstrapped prediction: [-0.95913637], in Range: True
# Input: 0 + 5 + -3, Actual: 2.00, Predicted Range: [0.66, 1.91], bootstrapped prediction: [1.2832096], in Range: False
# Input: 3 + -3 + -4, Actual: -4.00, Predicted Range: [-4.40, -3.92], bootstrapped prediction: [-4.126712], in Range: True
# Input: 1 - 4 - -5, Actual: 2.00, Predicted Range: [1.46, 2.29], bootstrapped prediction: [1.9751208], in Range: True
# Input: 0 + 5 - 0, Actual: 5.00, Predicted Range: [4.17, 4.77], bootstrapped prediction: [4.5286145], in Range: False
# Input: -5 + -2 + -3, Actual: -10.00, Predicted Range: [-10.08, -9.77], bootstrapped prediction: [-9.943436], in Range: True
# Input: 0 + -2 - -5, Actual: 3.00, Predicted Range: [2.79, 3.17], bootstrapped prediction: [2.966691], in Range: True
# Input: -1 + 3 - 2, Actual: 0.00, Predicted Range: [-0.08, 0.57], bootstrapped prediction: [0.14450288], in Range: True
# Input: 2 + 2 - 4, Actual: 0.00, Predicted Range: [-0.20, 0.38], bootstrapped prediction: [0.12488602], in Range: True
# Input: 1 + 1 + 2, Actual: 4.00, Predicted Range: [3.75, 4.45], bootstrapped prediction: [4.1165586], in Range: True
# Input: -3 + 2 - 0, Actual: -1.00, Predicted Range: [-1.13, -0.51], bootstrapped prediction: [-0.85801566], in Range: True
# Input: -2 + 5 - 4, Actual: -1.00, Predicted Range: [-2.13, -1.01], bootstrapped prediction: [-1.6403763], in Range: False
# Input: 3 - 4 - 4, Actual: -5.00, Predicted Range: [-4.85, -4.20], bootstrapped prediction: [-4.5446844], in Range: False
# Input: -1 - -2 + -4, Actual: -3.00, Predicted Range: [-3.36, -2.80], bootstrapped prediction: [-3.0620694], in Range: True
# Input: 1 - -5 + -1, Actual: 5.00, Predicted Range: [4.72, 5.33], bootstrapped prediction: [5.0142636], in Range: True
# Input: -4 - 2 + -2, Actual: -8.00, Predicted Range: [-8.11, -7.61], bootstrapped prediction: [-7.849736], in Range: True
# Input: 3 + 5 - 0, Actual: 8.00, Predicted Range: [7.05, 7.79], bootstrapped prediction: [7.467139], in Range: False
# Input: -3 + -5 - 5, Actual: -13.00, Predicted Range: [-12.62, -11.50], bootstrapped prediction: [-12.168613], in Range: False
# Input: 0 - -4 - -2, Actual: 6.00, Predicted Range: [5.83, 6.24], bootstrapped prediction: [6.0519967], in Range: True
# Input: 3 + -1 - -3, Actual: 5.00, Predicted Range: [4.90, 5.32], bootstrapped prediction: [5.0766973], in Range: True
# Input: -5 - 2 + 5, Actual: -2.00, Predicted Range: [-3.17, -1.94], bootstrapped prediction: [-2.4324896], in Range: True
# Input: -5 + 5 - 1, Actual: -1.00, Predicted Range: [-2.54, -1.01], bootstrapped prediction: [-1.7244833], in Range: False
# Input: 1 - -3 - 0, Actual: 4.00, Predicted Range: [3.79, 4.34], bootstrapped prediction: [4.1075206], in Range: True
# Input: 2 - -5 + 3, Actual: 10.00, Predicted Range: [9.39, 10.16], bootstrapped prediction: [9.798831], in Range: True
# Input: 5 - 3 + 3, Actual: 5.00, Predicted Range: [4.66, 5.37], bootstrapped prediction: [5.0503683], in Range: True
# Input: 5 - 0 + -5, Actual: 0.00, Predicted Range: [0.04, 0.82], bootstrapped prediction: [0.3834625], in Range: False
# Input: 5 - 4 + 1, Actual: 2.00, Predicted Range: [1.60, 2.73], bootstrapped prediction: [2.16805], in Range: True
# Input: 4 - -3 - -3, Actual: 10.00, Predicted Range: [9.76, 10.08], bootstrapped prediction: [9.943364], in Range: True
# Input: 3 + -5 + 2, Actual: 0.00, Predicted Range: [-0.16, 0.71], bootstrapped prediction: [0.21548414], in Range: True
# Input: -1 + -2 + 3, Actual: 0.00, Predicted Range: [-0.11, 0.26], bootstrapped prediction: [0.0648819], in Range: True
# Input: 3 + -1 - 5, Actual: -3.00, Predicted Range: [-3.26, -2.25], bootstrapped prediction: [-2.7029078], in Range: True
# Input: 3 + 4 - 3 + 2, Actual: 6.00, Predicted Range: [-2.39, 6.42], bootstrapped prediction: [2.505982], in Range: True
# Input: -5 - 4 - -2 - 3, Actual: -10.00, Predicted Range: [-12.67, -0.58], bootstrapped prediction: [-6.268781], in Range: True
# Input: -3 + 4 + 4 + 5, Actual: 10.00, Predicted Range: [-10.22, 9.46], bootstrapped prediction: [0.19092616], in Range: False
# Input: -1 + -2 + 0 - -3, Actual: 0.00, Predicted Range: [-11.44, 5.28], bootstrapped prediction: [-4.2069616], in Range: True
# Input: 4 - -1 - 0 - -2, Actual: 7.00, Predicted Range: [0.35, 7.39], bootstrapped prediction: [4.445394], in Range: True
# Input: -3 + 1 + 0 - -5, Actual: 3.00, Predicted Range: [-10.32, 11.17], bootstrapped prediction: [-1.9801569], in Range: True
# Input: -1 + 0 + -5 + -2, Actual: -8.00, Predicted Range: [-12.08, 0.62], bootstrapped prediction: [-6.2061925], in Range: True
# Input: -2 - -4 - 2 - -3, Actual: 3.00, Predicted Range: [-5.44, 3.53], bootstrapped prediction: [-1.2105345], in Range: True
# Input: -5 - 5 + 2 - -3, Actual: -5.00, Predicted Range: [-13.05, 3.04], bootstrapped prediction: [-5.9942036], in Range: True
# Input: 5 - 5 - -2 - -2, Actual: 4.00, Predicted Range: [-3.71, 9.72], bootstrapped prediction: [2.719413], in Range: True
# Input: 5 - 3 - -5 + -5, Actual: 2.00, Predicted Range: [-6.18, 13.04], bootstrapped prediction: [4.4635515], in Range: True
# Input: -1 - 0 - 0 + -5, Actual: -6.00, Predicted Range: [-5.79, 9.85], bootstrapped prediction: [0.34236854], in Range: False
# Input: 4 - 2 - 2 - -3, Actual: 3.00, Predicted Range: [-2.91, 8.71], bootstrapped prediction: [2.544693], in Range: True
# Input: -1 - -2 - -5 + -1, Actual: 5.00, Predicted Range: [0.78, 6.85], bootstrapped prediction: [4.600327], in Range: True
# Input: -4 - -4 + 1 - -5, Actual: 6.00, Predicted Range: [-9.83, 5.20], bootstrapped prediction: [-2.2844605], in Range: False
# Input: -1 - 1 - 3 + -5, Actual: -10.00, Predicted Range: [-5.95, 10.29], bootstrapped prediction: [-0.47233582], in Range: False
# Input: -4 + 0 - 1 + -4, Actual: -9.00, Predicted Range: [-8.31, 8.05], bootstrapped prediction: [-2.4014668], in Range: False
# Input: 3 - 5 + -3 + -1, Actual: -6.00, Predicted Range: [-7.22, 0.20], bootstrapped prediction: [-4.68201], in Range: True
# Input: -1 - -4 - 0 - -2, Actual: 5.00, Predicted Range: [-2.28, 4.84], bootstrapped prediction: [1.3514138], in Range: False
# Input: -1 + 2 - -1 - -3, Actual: 5.00, Predicted Range: [-3.18, 10.23], bootstrapped prediction: [3.2616215], in Range: True
# Input: 1 - -3 + 5 - 4, Actual: 5.00, Predicted Range: [4.87, 14.57], bootstrapped prediction: [8.331398], in Range: True
# Input: 4 - -2 - -2 - 2, Actual: 6.00, Predicted Range: [6.07, 11.33], bootstrapped prediction: [8.127816], in Range: False
# Input: -3 + 5 + -4 + -2, Actual: -4.00, Predicted Range: [-6.32, 4.26], bootstrapped prediction: [-2.2139802], in Range: True
# Input: 3 + -4 + 3 - 5, Actual: -3.00, Predicted Range: [-2.70, 15.22], bootstrapped prediction: [4.7498255], in Range: False
# Input: 0 + -2 - 1 + 3, Actual: 0.00, Predicted Range: [-8.42, 4.14], bootstrapped prediction: [-2.0490336], in Range: True
# Input: 0 + 5 - -2 + -2, Actual: 5.00, Predicted Range: [1.84, 11.02], bootstrapped prediction: [6.6499534], in Range: True
# Input: -3 + 5 + 5 - -1, Actual: 8.00, Predicted Range: [2.15, 9.61], bootstrapped prediction: [5.1729326], in Range: True
# Input: -3 - -4 + -4 + 2, Actual: -1.00, Predicted Range: [-1.32, 3.27], bootstrapped prediction: [0.7326868], in Range: True
# Input: 2 - -1 + -4 + -2, Actual: -3.00, Predicted Range: [-5.50, 0.97], bootstrapped prediction: [-2.8268142], in Range: True
# Input: 1 - 0 - 1 + -4, Actual: -4.00, Predicted Range: [-4.04, 9.33], bootstrapped prediction: [1.1731347], in Range: True
# Input: 2 - -4 - 2 - 1, Actual: 3.00, Predicted Range: [3.27, 5.64], bootstrapped prediction: [4.290412], in Range: False
# Input: -3 + -2 + 1 - 3, Actual: -7.00, Predicted Range: [-8.48, 3.35], bootstrapped prediction: [-3.278164], in Range: True
# Input: 1 + -5 + -2 - 3, Actual: -9.00, Predicted Range: [-6.40, 4.72], bootstrapped prediction: [-2.1770139], in Range: False
# Input: -2 + -1 + -4 + -2, Actual: -9.00, Predicted Range: [-13.38, -0.53], bootstrapped prediction: [-7.6841593], in Range: True
# Input: -2 + 4 - 0 - 3, Actual: -1.00, Predicted Range: [-5.90, 7.77], bootstrapped prediction: [0.57723963], in Range: True
# Input: -5 + 0 - 5 - -5, Actual: -5.00, Predicted Range: [-12.35, 7.79], bootstrapped prediction: [-3.3724294], in Range: True
# Input: 3 - 5 + -1 - -5, Actual: 2.00, Predicted Range: [-10.55, 11.11], bootstrapped prediction: [-1.1543031], in Range: True
# Input: 2 + -5 - 0 + -3, Actual: -6.00, Predicted Range: [-8.92, 4.78], bootstrapped prediction: [-2.5173612], in Range: True
# Input: -1 - 1 - -3 - 5, Actual: -4.00, Predicted Range: [-2.92, 13.18], bootstrapped prediction: [3.5114136], in Range: False
# Input: 2 - -4 - 1 - -5, Actual: 10.00, Predicted Range: [-2.82, 9.41], bootstrapped prediction: [2.8069916], in Range: False
# Input: -4 - -5 - -5 + 1, Actual: 7.00, Predicted Range: [4.85, 7.17], bootstrapped prediction: [6.224655], in Range: True
# Input: 0 - 0 - -1 + 4, Actual: 5.00, Predicted Range: [-1.18, 10.42], bootstrapped prediction: [3.2186108], in Range: True
# Input: 1 + 3 - -3 - 0, Actual: 7.00, Predicted Range: [6.05, 8.90], bootstrapped prediction: [7.479291], in Range: True
# Input: -3 + -5 + -2 - -4, Actual: -6.00, Predicted Range: [-18.19, 0.29], bootstrapped prediction: [-10.033442], in Range: True
# Input: 3 + 5 - -3 + -2, Actual: 9.00, Predicted Range: [4.69, 13.80], bootstrapped prediction: [9.540934], in Range: True
# Input: -1 - 3 - 5 + -2, Actual: -11.00, Predicted Range: [-10.13, -0.81], bootstrapped prediction: [-6.5444627], in Range: False
# Input: 2 - 1 + -5 - 0, Actual: -4.00, Predicted Range: [-6.41, -3.94], bootstrapped prediction: [-5.1491446], in Range: True
# Input: -1 + 3 + 3 + 3, Actual: 8.00, Predicted Range: [-3.60, 8.67], bootstrapped prediction: [2.9892116], in Range: True
# Input: -4 + 5 - -5 + -2, Actual: 4.00, Predicted Range: [-2.03, 8.62], bootstrapped prediction: [4.020419], in Range: True
# Input: -1 - 0 + -4 - -2, Actual: -3.00, Predicted Range: [-10.15, -3.62], bootstrapped prediction: [-7.249685], in Range: False
# Input: 2 + 5 - -1 - -3, Actual: 11.00, Predicted Range: [1.97, 14.29], bootstrapped prediction: [8.131853], in Range: True
# Input: 1 + -3 + 2 + -4, Actual: -4.00, Predicted Range: [-10.60, 9.79], bootstrapped prediction: [-0.66802204], in Range: True
# Input: -3 - 1 + 4 + -4, Actual: -4.00, Predicted Range: [-7.80, 9.84], bootstrapped prediction: [0.1183033], in Range: True
# Input: -2 + -1 - -5 + 1, Actual: 3.00, Predicted Range: [0.85, 3.34], bootstrapped prediction: [2.3111122], in Range: True
# Input: 1 + -5 - 5 + 5, Actual: -4.00, Predicted Range: [-9.64, 7.69], bootstrapped prediction: [-2.3993134], in Range: True
# Input: -4 + -1 - -1 + -2, Actual: -6.00, Predicted Range: [-8.44, 2.28], bootstrapped prediction: [-3.651319], in Range: True
# Input: 5 + 4 - -4 + -2, Actual: 11.00, Predicted Range: [5.34, 15.11], bootstrapped prediction: [10.913553], in Range: True
# Input: 5 + 3 + -3 + 3, Actual: 8.00, Predicted Range: [-2.13, 12.05], bootstrapped prediction: [6.5069237], in Range: True
# Input: 2 + 0 - 4 + 5, Actual: 3.00, Predicted Range: [-11.21, 10.22], bootstrapped prediction: [-0.29802924], in Range: True
# Input: 3 - 4 + -3 - 4, Actual: -8.00, Predicted Range: [-6.98, 6.16], bootstrapped prediction: [-0.06817522], in Range: False
# Input: 4 - 4 + 2 + 4, Actual: 6.00, Predicted Range: [-2.77, 8.09], bootstrapped prediction: [3.2066383], in Range: True
# Input: -4 - -2 - -4 + 2, Actual: 4.00, Predicted Range: [0.33, 5.71], bootstrapped prediction: [2.8977494], in Range: True
# Input: -3 - 1 + -5 + 0, Actual: -9.00, Predicted Range: [-9.59, -7.64], bootstrapped prediction: [-8.73688], in Range: True
# Input: -3 + -3 + -1 - -3, Actual: -4.00, Predicted Range: [-14.99, 1.37], bootstrapped prediction: [-7.919214], in Range: True
# Input: -2 + -3 - 1 - -3, Actual: -3.00, Predicted Range: [-11.05, 2.92], bootstrapped prediction: [-4.573911], in Range: True
# Input: 4 - -4 - 3 + -5, Actual: 0.00, Predicted Range: [-2.29, 11.71], bootstrapped prediction: [3.2347298], in Range: True
# Input: -5 - 4 + -3 - -3, Actual: -9.00, Predicted Range: [-14.27, -2.22], bootstrapped prediction: [-9.688703], in Range: True
# Input: -1 + -4 - 5 + -5, Actual: -15.00, Predicted Range: [-14.27, 7.02], bootstrapped prediction: [-4.285225], in Range: False
# Input: 5 - -3 + 1 - 5, Actual: 4.00, Predicted Range: [6.91, 19.37], bootstrapped prediction: [11.07197], in Range: False
# Input: 1 + -1 + -3 + 1, Actual: -2.00, Predicted Range: [-3.61, -0.65], bootstrapped prediction: [-1.9310671], in Range: True
# Input: -3 + -1 - -2 + 1, Actual: -1.00, Predicted Range: [-3.93, -0.76], bootstrapped prediction: [-1.970019], in Range: True
# Input: -5 + 2 + -3 - 0, Actual: -6.00, Predicted Range: [-7.75, -4.76], bootstrapped prediction: [-6.336197], in Range: True
# Input: 1 + -2 - 1 - 5, Actual: -7.00, Predicted Range: [-7.97, 12.12], bootstrapped prediction: [0.41368288], in Range: True
# Input: -4 + -5 - 0 - -1, Actual: -8.00, Predicted Range: [-12.06, -5.15], bootstrapped prediction: [-9.157797], in Range: True
# Input: -5 - -3 + 5 + 3, Actual: 6.00, Predicted Range: [-0.87, 8.02], bootstrapped prediction: [2.5546448], in Range: True
# Input: 3 + 0 + -5 + 4, Actual: 2.00, Predicted Range: [-4.16, 11.75], bootstrapped prediction: [3.6347115], in Range: True
# Input: -4 + -1 - -1 - -5, Actual: 1.00, Predicted Range: [-9.58, 8.34], bootstrapped prediction: [-2.316017], in Range: True
# Input: -3 - -1 + -1 - 4, Actual: -7.00, Predicted Range: [-4.17, 7.51], bootstrapped prediction: [0.5035752], in Range: False
# Input: -1 + 2 - 2 + -3, Actual: -4.00, Predicted Range: [-3.67, 9.79], bootstrapped prediction: [1.5365425], in Range: False
# Input: 5 - -5 - 3 + -1, Actual: 6.00, Predicted Range: [2.95, 8.78], bootstrapped prediction: [5.570115], in Range: True
# Input: 3 - 3 + -2 + -4, Actual: -6.00, Predicted Range: [-9.09, 8.08], bootstrapped prediction: [-1.8264679], in Range: True
# Input: -4 - -5 - -2 - 5, Actual: -2.00, Predicted Range: [-0.37, 13.41], bootstrapped prediction: [5.3492994], in Range: False
# Input: 0 - 0 + -1 + -4, Actual: -5.00, Predicted Range: [-7.23, 7.21], bootstrapped prediction: [-1.7672291], in Range: True
# Input: -4 - -2 - -5 - -1, Actual: 4.00, Predicted Range: [-2.45, 3.56], bootstrapped prediction: [0.8071948], in Range: False
# Input: 3 + -3 - -1 - 0, Actual: 1.00, Predicted Range: [-1.03, 2.93], bootstrapped prediction: [0.6169126], in Range: True
# Input: -3 + 4 - -5 - -3, Actual: 9.00, Predicted Range: [-4.68, 9.97], bootstrapped prediction: [3.2070224], in Range: True
# Input: 0 - -2 + 3 - -4, Actual: 9.00, Predicted Range: [-4.67, 10.19], bootstrapped prediction: [2.8473294], in Range: True
# Input: 1 + -3 + 0 - 2, Actual: -4.00, Predicted Range: [-5.42, 2.49], bootstrapped prediction: [-1.3391336], in Range: True
# Input: -5 - 0 + -5 - -1, Actual: -9.00, Predicted Range: [-12.94, -9.31], bootstrapped prediction: [-11.335765], in Range: False
# Input: 3 - -1 + -5 + -5, Actual: -6.00, Predicted Range: [-8.22, 5.67], bootstrapped prediction: [-2.0765684], in Range: True
# Input: 1 - -1 - -2 + 5, Actual: 9.00, Predicted Range: [0.91, 15.61], bootstrapped prediction: [6.627719], in Range: True
# Input: 2 + 2 + -2 + -4, Actual: -2.00, Predicted Range: [-7.77, 11.90], bootstrapped prediction: [0.6889938], in Range: True
# Input: 1 + -3 + 3 + 5, Actual: 6.00, Predicted Range: [-4.30, 13.15], bootstrapped prediction: [3.5445702], in Range: True
# Input: 4 - 5 - 2 + -3, Actual: -6.00, Predicted Range: [-5.64, 8.78], bootstrapped prediction: [0.32999957], in Range: False
# Input: -4 - -2 - 5 - -5, Actual: -2.00, Predicted Range: [-9.66, 5.51], bootstrapped prediction: [-2.9835727], in Range: True
# Input: -2 + 4 - 2 - 3, Actual: -3.00, Predicted Range: [-7.14, 4.98], bootstrapped prediction: [-0.9887185], in Range: True
# Input: -4 - -4 - 4 - -3, Actual: -1.00, Predicted Range: [-8.52, 0.36], bootstrapped prediction: [-4.074643], in Range: True
# Input: 4 + 4 + 2 + 4, Actual: 14.00, Predicted Range: [-2.68, 15.07], bootstrapped prediction: [7.226331], in Range: True
# Input: -2 + 5 - 0 - -3, Actual: 6.00, Predicted Range: [-0.50, 11.81], bootstrapped prediction: [4.9409695], in Range: True
# Input: -1 - -4 - -1 + 1, Actual: 5.00, Predicted Range: [3.34, 4.99], bootstrapped prediction: [4.2332983], in Range: False
# Input: -2 - 5 - 3 - 5 - 0, Actual: -15.00, Predicted Range: [-14.38, 3.95], bootstrapped prediction: [-5.737867], in Range: False
# Input: 3 - -5 - -5 - -2 + -2, Actual: 13.00, Predicted Range: [0.72, 10.52], bootstrapped prediction: [6.545779], in Range: False
# Input: 1 + 3 + 4 + 4 + 3, Actual: 15.00, Predicted Range: [-7.14, 10.65], bootstrapped prediction: [1.8973663], in Range: False
# Input: -2 - -3 + 3 + 0 + -5, Actual: -1.00, Predicted Range: [-3.27, 12.83], bootstrapped prediction: [4.965724], in Range: True
# Input: 1 - 2 - 5 - 1 + 5, Actual: -2.00, Predicted Range: [-10.34, -0.33], bootstrapped prediction: [-5.304884], in Range: True
# Input: 3 + -4 + -3 + -1 - -2, Actual: -3.00, Predicted Range: [-10.39, 2.49], bootstrapped prediction: [-4.5374727], in Range: True
# Input: 2 - 5 + -5 - -2 + 5, Actual: -1.00, Predicted Range: [-9.60, 2.65], bootstrapped prediction: [-3.7956948], in Range: True
# Input: -1 + -3 - -4 + -2 + -4, Actual: -6.00, Predicted Range: [-7.53, 7.70], bootstrapped prediction: [-0.29098505], in Range: True
# Input: 0 + 2 - -4 + -2 - 5, Actual: -1.00, Predicted Range: [-2.45, 9.98], bootstrapped prediction: [3.5827885], in Range: True
# Input: -5 - -3 - 0 + -4 + -5, Actual: -11.00, Predicted Range: [-7.22, 9.67], bootstrapped prediction: [0.10245979], in Range: False
# Input: 0 - -3 - 3 + -4 - -4, Actual: 0.00, Predicted Range: [-5.05, 11.68], bootstrapped prediction: [2.2499158], in Range: True
# Input: -4 - -4 + 1 + 1 - -4, Actual: 6.00, Predicted Range: [-4.22, 10.04], bootstrapped prediction: [2.760553], in Range: True
# Input: 1 - 2 - -4 + 0 + 0, Actual: 3.00, Predicted Range: [0.27, 4.62], bootstrapped prediction: [2.6162374], in Range: True
# Input: 4 - 4 - 0 + 4 + -5, Actual: -1.00, Predicted Range: [-4.44, 10.80], bootstrapped prediction: [2.4586785], in Range: True
# Input: -5 - -2 + -4 + 1 - 1, Actual: -7.00, Predicted Range: [-5.50, -3.50], bootstrapped prediction: [-4.8141546], in Range: False
# Input: -3 + -4 + -5 + 4 + 3, Actual: -5.00, Predicted Range: [-10.56, 5.29], bootstrapped prediction: [-3.4176273], in Range: True
# Input: -2 + 4 - 1 - 0 + 0, Actual: 1.00, Predicted Range: [-0.17, 4.22], bootstrapped prediction: [1.8496227], in Range: True
# Input: 5 - 0 + -3 - -3 + 4, Actual: 9.00, Predicted Range: [-3.05, 6.38], bootstrapped prediction: [1.3987393], in Range: False
# Input: 1 - -3 + 1 - 1 + 3, Actual: 7.00, Predicted Range: [1.24, 5.91], bootstrapped prediction: [3.5349135], in Range: False
# Input: 0 + 1 + 4 + 1 - 1, Actual: 5.00, Predicted Range: [2.21, 6.75], bootstrapped prediction: [4.3768377], in Range: True
# Input: -3 + -1 + 2 + -4 + -5, Actual: -11.00, Predicted Range: [-10.76, 11.93], bootstrapped prediction: [0.09004097], in Range: False
# Input: 1 + 0 - -4 + -2 + -4, Actual: -1.00, Predicted Range: [-4.81, 9.95], bootstrapped prediction: [3.0908942], in Range: True
# Input: -3 - 0 + -2 - -5 - 0, Actual: 0.00, Predicted Range: [-10.89, 4.28], bootstrapped prediction: [-4.8482695], in Range: True
# Input: -3 + -2 + -2 + 0 - 1, Actual: -8.00, Predicted Range: [-8.16, -5.83], bootstrapped prediction: [-7.039407], in Range: True
# Input: -4 - 0 - 0 - -2 + 1, Actual: -1.00, Predicted Range: [-7.83, 0.43], bootstrapped prediction: [-3.6661773], in Range: True
# Input: 2 - -4 - -1 + 2 + 2, Actual: 11.00, Predicted Range: [3.87, 11.76], bootstrapped prediction: [7.18292], in Range: True
# Input: -1 - 0 + -1 + 5 - -1, Actual: 4.00, Predicted Range: [-1.85, 12.61], bootstrapped prediction: [3.4061294], in Range: True
# Input: -2 + -3 - 1 - 1 + -3, Actual: -10.00, Predicted Range: [-7.44, 3.17], bootstrapped prediction: [-2.8359637], in Range: False
# Input: 3 - 0 - 2 + -2 - 0, Actual: -1.00, Predicted Range: [-2.84, 7.38], bootstrapped prediction: [1.5411041], in Range: True
# Input: -4 - 5 - 1 - 5 + -2, Actual: -17.00, Predicted Range: [-16.15, 0.40], bootstrapped prediction: [-6.5127387], in Range: False
# Input: 3 + -4 + 1 - 1 + 2, Actual: 1.00, Predicted Range: [-4.00, 2.15], bootstrapped prediction: [-0.50692767], in Range: True
# Input: -4 + -1 - -1 + 0 + -1, Actual: -5.00, Predicted Range: [-5.95, 0.50], bootstrapped prediction: [-3.2473953], in Range: True
# Input: -2 - 5 - 2 + 4 - -3, Actual: -2.00, Predicted Range: [-12.34, 3.70], bootstrapped prediction: [-4.921055], in Range: True
# Input: -5 + -3 - 2 - -2 + 1, Actual: -7.00, Predicted Range: [-12.40, -2.43], bootstrapped prediction: [-8.387146], in Range: True
# Input: 1 - 5 + -5 - -2 + -1, Actual: -8.00, Predicted Range: [-13.03, -0.82], bootstrapped prediction: [-7.948541], in Range: True
# Input: -4 - 2 - 5 - 5 - -4, Actual: -12.00, Predicted Range: [-11.15, 3.48], bootstrapped prediction: [-4.052257], in Range: False
# Input: 5 - -1 - -5 - 2 - -3, Actual: 12.00, Predicted Range: [4.65, 13.18], bootstrapped prediction: [9.466563], in Range: True
# Input: -2 - -1 + 3 - 4 + 5, Actual: 3.00, Predicted Range: [-5.29, 4.85], bootstrapped prediction: [-0.0967629], in Range: True
# Input: 5 - 0 + 2 + 1 - -2, Actual: 10.00, Predicted Range: [4.42, 10.85], bootstrapped prediction: [7.610636], in Range: True
# Input: -1 - -1 - -5 + 2 - -1, Actual: 8.00, Predicted Range: [4.76, 9.33], bootstrapped prediction: [6.4547224], in Range: True
# Input: -3 + -2 - 1 - -1 + -1, Actual: -6.00, Predicted Range: [-8.21, 1.22], bootstrapped prediction: [-4.1921506], in Range: True
# Input: -1 - 1 + 5 - -4 - -4, Actual: 11.00, Predicted Range: [-7.62, 13.43], bootstrapped prediction: [2.5699105], in Range: True
# Input: -2 + 1 + -5 + 4 + 5, Actual: 3.00, Predicted Range: [-9.07, 5.90], bootstrapped prediction: [-1.6997869], in Range: True
# Input: 0 + 1 + 2 - -2 - 5, Actual: 0.00, Predicted Range: [-6.19, 5.39], bootstrapped prediction: [0.3363684], in Range: True
# Input: -5 - 0 - -3 + 1 - -4, Actual: 3.00, Predicted Range: [-7.36, 3.45], bootstrapped prediction: [-1.1654832], in Range: True
# Input: 2 + 5 - -5 + 4 + 4, Actual: 20.00, Predicted Range: [-2.19, 18.19], bootstrapped prediction: [7.01033], in Range: False
# Input: -5 + -3 - -3 - -4 - 4, Actual: -5.00, Predicted Range: [-15.06, 3.92], bootstrapped prediction: [-6.91379], in Range: True
# Input: -1 - 0 - -2 - 1 + 5, Actual: 5.00, Predicted Range: [-5.52, 5.51], bootstrapped prediction: [1.1668389], in Range: True
# Input: -3 + -4 + 4 - -1 + -2, Actual: -4.00, Predicted Range: [-6.55, 5.02], bootstrapped prediction: [-1.3640299], in Range: True
# Input: -2 - -3 + -2 - 0 - 3, Actual: -4.00, Predicted Range: [-5.21, 0.75], bootstrapped prediction: [-1.7387642], in Range: True
# Input: -2 + 0 - -4 + 0 - 1, Actual: 1.00, Predicted Range: [0.03, 3.86], bootstrapped prediction: [1.8648793], in Range: True
# Input: -2 - 5 + 5 - 5 + -4, Actual: -11.00, Predicted Range: [-9.13, 7.39], bootstrapped prediction: [-0.8485907], in Range: False
# Input: -1 - 4 + 4 + 0 - 0, Actual: -1.00, Predicted Range: [-2.38, 1.97], bootstrapped prediction: [-0.10160206], in Range: True
# Input: -2 + -4 + -5 - -4 + -1, Actual: -8.00, Predicted Range: [-19.92, 2.77], bootstrapped prediction: [-10.374557], in Range: True
# Input: 3 + -2 - 1 + 4 + 2, Actual: 6.00, Predicted Range: [-6.70, 9.40], bootstrapped prediction: [1.1883881], in Range: True
# Input: -3 - 2 + -4 + -2 + 3, Actual: -8.00, Predicted Range: [-12.33, -2.47], bootstrapped prediction: [-7.9429617], in Range: True
# Input: -3 - 5 + 4 + 0 - -4, Actual: 0.00, Predicted Range: [-8.33, 6.05], bootstrapped prediction: [-1.741874], in Range: True
# Input: -5 - 5 + 1 - -4 + -5, Actual: -10.00, Predicted Range: [-15.66, 7.74], bootstrapped prediction: [-5.2552586], in Range: True
# Input: -2 - 5 - -1 - 4 + -5, Actual: -15.00, Predicted Range: [-11.75, 4.64], bootstrapped prediction: [-3.811847], in Range: False
# Input: 1 + -4 - 5 + 5 + -4, Actual: -7.00, Predicted Range: [-10.87, 12.69], bootstrapped prediction: [0.39279756], in Range: True
# Input: 2 + 3 - 5 + -5 - 5, Actual: -10.00, Predicted Range: [-10.23, 11.21], bootstrapped prediction: [1.4896293], in Range: True
# Input: 1 - -3 + -2 - -3 - 3, Actual: 2.00, Predicted Range: [-6.16, 3.41], bootstrapped prediction: [-1.2814019], in Range: True
# Input: -5 - -5 - -2 - 1 - 1, Actual: 0.00, Predicted Range: [-0.01, 3.12], bootstrapped prediction: [1.6724007], in Range: True
# Input: 0 + 5 - -1 + -2 - 2, Actual: 2.00, Predicted Range: [1.51, 10.81], bootstrapped prediction: [5.5997725], in Range: True
# Input: 1 + 5 - -5 - -4 - -1, Actual: 16.00, Predicted Range: [-4.11, 14.31], bootstrapped prediction: [5.459143], in Range: False
# Input: 2 - 5 - -1 + -1 - -5, Actual: 2.00, Predicted Range: [-8.15, 8.15], bootstrapped prediction: [0.04312899], in Range: True
# Input: 2 + -1 + -3 - 4 + 0, Actual: -6.00, Predicted Range: [-6.76, 10.54], bootstrapped prediction: [1.4073995], in Range: True
# Input: -1 + 4 + 5 + -4 - -3, Actual: 7.00, Predicted Range: [-4.64, 16.11], bootstrapped prediction: [5.672557], in Range: True
# Input: -2 + -1 - 0 + 5 + 1, Actual: 3.00, Predicted Range: [-9.65, 10.28], bootstrapped prediction: [-1.0219206], in Range: True
# Input: -3 + -3 - 0 - 2 + 0, Actual: -8.00, Predicted Range: [-8.46, -1.97], bootstrapped prediction: [-5.423675], in Range: True
# Input: 4 + -3 - -1 + 2 - 0, Actual: 4.00, Predicted Range: [-2.02, 6.51], bootstrapped prediction: [2.4410644], in Range: True
# Input: 3 - 5 + 4 + 4 - 3, Actual: 3.00, Predicted Range: [-4.40, 9.68], bootstrapped prediction: [1.9083433], in Range: True
# Input: -2 + -4 + -5 - -4 - -4, Actual: -3.00, Predicted Range: [-20.46, 6.26], bootstrapped prediction: [-8.656681], in Range: True
# Input: -5 - -4 - 0 + 1 + 1, Actual: 1.00, Predicted Range: [-2.13, 0.97], bootstrapped prediction: [-0.8753797], in Range: False
# Input: -2 - -1 - 5 - -3 + 2, Actual: -1.00, Predicted Range: [-9.58, -0.77], bootstrapped prediction: [-4.5409822], in Range: True
# Input: 4 + 1 - 3 - 4 - -1, Actual: -1.00, Predicted Range: [-5.83, 11.01], bootstrapped prediction: [3.135209], in Range: True
# Input: -1 + 1 + 3 - 1 - -5, Actual: 7.00, Predicted Range: [0.59, 12.69], bootstrapped prediction: [5.1644936], in Range: True
# Input: 4 + 0 - 3 + 1 + 3, Actual: 5.00, Predicted Range: [-4.59, 3.40], bootstrapped prediction: [-0.46647802], in Range: False
# Input: -3 - 3 - 3 + 2 - 1, Actual: -8.00, Predicted Range: [-11.71, -3.63], bootstrapped prediction: [-7.875777], in Range: True
# Input: -2 + -2 + 0 - 4 + -1, Actual: -9.00, Predicted Range: [-8.32, 7.86], bootstrapped prediction: [-1.0566521], in Range: False
# Input: -3 + 3 - 0 + -3 + 2, Actual: -1.00, Predicted Range: [-5.26, 8.40], bootstrapped prediction: [0.57716805], in Range: True
# Input: 2 - -1 + -1 + -4 + 5, Actual: 3.00, Predicted Range: [-5.38, 6.48], bootstrapped prediction: [0.72606623], in Range: True
# Input: -2 - 5 + -5 - 2 - -5, Actual: -9.00, Predicted Range: [-16.46, 1.52], bootstrapped prediction: [-7.7233224], in Range: True
# Input: 3 + -2 - 1 + 0 + 3, Actual: 3.00, Predicted Range: [-3.71, 2.06], bootstrapped prediction: [-0.57229215], in Range: False
# Input: -4 + 5 + 5 + 1 + 5, Actual: 12.00, Predicted Range: [-6.24, 2.62], bootstrapped prediction: [-2.9167874], in Range: False
# Input: 5 - 3 + -1 - 2 + 1, Actual: 0.00, Predicted Range: [-2.41, 4.09], bootstrapped prediction: [1.2887831], in Range: True
# Input: -4 + 1 + 0 - 1 + -2, Actual: -6.00, Predicted Range: [-5.12, 3.07], bootstrapped prediction: [-1.8850456], in Range: False
# Input: -4 + 5 + 2 + -1 + 5, Actual: 7.00, Predicted Range: [-6.98, 3.34], bootstrapped prediction: [-2.3003244], in Range: False
# Input: 3 + 4 + 2 + 4 - 4, Actual: 9.00, Predicted Range: [-5.08, 14.45], bootstrapped prediction: [4.191512], in Range: True
# Input: 5 - 4 - 2 - 4 - -2, Actual: -3.00, Predicted Range: [-5.61, 8.67], bootstrapped prediction: [1.8891084], in Range: True
# Input: -3 + -4 + -5 + 4 + 3, Actual: -5.00, Predicted Range: [-10.56, 5.29], bootstrapped prediction: [-3.4176273], in Range: True
# Input: -5 - 3 + 2 - -2 - 1, Actual: -5.00, Predicted Range: [-8.84, 2.12], bootstrapped prediction: [-4.562313], in Range: True
# Input: -5 + 0 + -5 - 4 + -5, Actual: -19.00, Predicted Range: [-12.11, 7.45], bootstrapped prediction: [-4.2805676], in Range: False
# ...
# Input: -2 - -4 + 3 - 2 + 5 + -4 + 0, Actual: 4.00, Predicted Range: [-2.50, 11.54], bootstrapped prediction: [4.3054013], in Range: True
# Input: 5 + -4 - 2 + -5 - -2 + -4 - -5, Actual: -3.00, Predicted Range: [-9.87, 13.46], bootstrapped prediction: [3.0666702], in Range: True
# Input: 0 + 0 + -2 - -2 - 0 - -1 - 4, Actual: -3.00, Predicted Range: [-6.54, 9.08], bootstrapped prediction: [-0.49495754], in Range: True
# Input: -2 - 2 + -3 - 4 - -2 + 0 + 4, Actual: -5.00, Predicted Range: [-9.46, 8.13], bootstrapped prediction: [-0.85678005], in Range: True
# Input: -2 - -4 - -1 + 3 - -3 - -5 - -3, Actual: 17.00, Predicted Range: [-6.19, 12.83], bootstrapped prediction: [4.497916], in Range: False
# Input: 2 + -3 + -4 + -5 + 4 + -1 + 0, Actual: -7.00, Predicted Range: [-13.22, 10.19], bootstrapped prediction: [-3.424831], in Range: True
# Input: -4 + -4 - -1 + -2 - -4 - -2 + 3, Actual: 0.00, Predicted Range: [-9.79, 9.41], bootstrapped prediction: [-0.20615058], in Range: True
# Input: -4 - -5 - -2 + -2 + -3 + -4 + 4, Actual: -2.00, Predicted Range: [-6.14, 11.03], bootstrapped prediction: [4.0305643], in Range: True
# Input: -2 - 1 + 2 + -4 - -4 - 2 - -2, Actual: -1.00, Predicted Range: [-10.55, 9.34], bootstrapped prediction: [-0.9233845], in Range: True
# Input: 3 - -2 + -5 + 0 + 5 + -1 - -4, Actual: 8.00, Predicted Range: [-6.40, 9.18], bootstrapped prediction: [1.169921], in Range: True
# Input: 1 - -1 - -4 + 5 + 4 - -1 + 3, Actual: 19.00, Predicted Range: [2.92, 17.37], bootstrapped prediction: [8.287652], in Range: False
# Input: 2 - 0 + -5 - 1 - -1 - 3 - -3 - 0, Actual: -3.00, Predicted Range: [-13.24, 1.42], bootstrapped prediction: [-5.785784], in Range: True
# Input: -2 + -5 + 0 - 5 + 1 - 3 + 1 - 3, Actual: -16.00, Predicted Range: [-11.35, 12.92], bootstrapped prediction: [-2.5080395], in Range: False
# Input: 4 - 3 - 2 + -3 + -3 + -1 + 4 + -5, Actual: -9.00, Predicted Range: [-0.24, 10.44], bootstrapped prediction: [5.3572435], in Range: False
# Input: 2 + 5 - -4 + 0 - -2 + 5 - -4 - 1, Actual: 21.00, Predicted Range: [-4.38, 11.41], bootstrapped prediction: [4.8064585], in Range: False
# Input: -5 + -2 - 0 - 2 + 3 + -4 + -4 + 0, Actual: -14.00, Predicted Range: [-10.54, 6.77], bootstrapped prediction: [-4.93283], in Range: False
# Input: 5 - -5 + 1 + -1 - -3 + 1 + 0 + 0, Actual: 14.00, Predicted Range: [1.76, 13.38], bootstrapped prediction: [7.4659414], in Range: False
# Input: 1 - 2 - -4 - 0 - -1 - -5 + -5 - 3, Actual: 1.00, Predicted Range: [-16.63, 11.97], bootstrapped prediction: [1.944164], in Range: True
# Input: -2 - 4 + 5 - -4 - -4 + -5 + -5 - 1, Actual: -4.00, Predicted Range: [-7.06, 14.99], bootstrapped prediction: [5.180508], in Range: True
# Input: -2 + -2 - 4 + -5 - 4 - 4 + 1 - 1, Actual: -21.00, Predicted Range: [-16.60, 6.71], bootstrapped prediction: [-6.6460295], in Range: False
# Input: 0 - 2 + 3 + -2 + 4 - 0 - 2 + 4, Actual: 5.00, Predicted Range: [-10.20, 5.33], bootstrapped prediction: [-3.647335], in Range: True
# Input: 0 + -1 + 3 + 1 - 3 + 3 + 0 - 0, Actual: 3.00, Predicted Range: [-7.55, 3.29], bootstrapped prediction: [-1.6550583], in Range: True
# Input: -2 - -4 + -5 - -4 + 0 - -2 + -1 + 4, Actual: 6.00, Predicted Range: [-15.31, 4.16], bootstrapped prediction: [-3.6611571], in Range: False
# Input: -5 - 5 - -1 + -2 + 4 + 2 - -2 - -1, Actual: -2.00, Predicted Range: [-13.47, 3.24], bootstrapped prediction: [-4.7078505], in Range: True
# Input: -1 + -3 + -1 - 1 - -1 - 5 - 2 + -4, Actual: -16.00, Predicted Range: [-14.21, 4.48], bootstrapped prediction: [-5.502174], in Range: False
# Input: -5 - 0 + -5 + 0 - 2 - 3 + 0 - 0, Actual: -15.00, Predicted Range: [-12.92, -0.67], bootstrapped prediction: [-7.7034044], in Range: False
# Input: -5 + -3 + 3 - 5 - -1 + 5 + -1 + -1, Actual: -6.00, Predicted Range: [-15.78, 4.90], bootstrapped prediction: [-5.9016743], in Range: True
# Input: 4 - -1 + -3 - 3 + -4 - 3 + 1 - -5, Actual: -2.00, Predicted Range: [-7.83, 9.78], bootstrapped prediction: [2.7964554], in Range: True
# Input: 2 + 4 + -5 + 2 + 0 - 2 + 2 + 1, Actual: 4.00, Predicted Range: [-4.14, 6.54], bootstrapped prediction: [0.85358346], in Range: True
# Input: 1 + 0 - 5 + 0 - 1 + 1 - 2 - 5, Actual: -11.00, Predicted Range: [-9.97, 0.92], bootstrapped prediction: [-4.8618484], in Range: False
# Input: 0 - 5 + 1 - 2 + 4 + -2 - 4 - 3, Actual: -11.00, Predicted Range: [-11.06, 2.81], bootstrapped prediction: [-3.278169], in Range: True
# Input: 0 - -5 - 5 + -1 + 4 - 2 - -1 - -2, Actual: 4.00, Predicted Range: [-12.27, 7.36], bootstrapped prediction: [-2.851207], in Range: True
# Input: 0 - -1 - 3 + -5 + 3 - 5 - -1 + 5, Actual: -3.00, Predicted Range: [-13.70, 11.32], bootstrapped prediction: [-1.5623531], in Range: True
# Input: 2 + 3 - 5 + 2 + 1 - -1 + -4 - 2, Actual: -2.00, Predicted Range: [-6.43, 2.53], bootstrapped prediction: [-1.7299936], in Range: True
# Input: -1 - 5 + -5 + 1 + -3 + -4 - -4 - -1, Actual: -12.00, Predicted Range: [-11.77, 8.31], bootstrapped prediction: [-1.9528608], in Range: False
# Input: 2 - 4 + 4 - -1 + 3 - 4 + -1 + 3, Actual: 4.00, Predicted Range: [-9.28, 3.48], bootstrapped prediction: [-3.8215632], in Range: False
# Input: -2 - -1 + 3 - -1 + -2 - 5 + 0 - 1, Actual: -5.00, Predicted Range: [-8.56, 4.15], bootstrapped prediction: [-2.3333213], in Range: True
# Input: 0 + -5 + -4 + -3 - 4 + -4 - 5 - 5, Actual: -30.00, Predicted Range: [-10.84, 12.40], bootstrapped prediction: [-0.706641], in Range: False
# Input: -1 + 0 + -5 + -3 - -2 + 5 - -2 - 5, Actual: -5.00, Predicted Range: [-15.41, 7.76], bootstrapped prediction: [-4.0070696], in Range: True
# Input: 0 - -3 - -4 + -3 + -5 - -3 + 3 - 5, Actual: 0.00, Predicted Range: [-8.62, 15.30], bootstrapped prediction: [6.7855554], in Range: True
# Input: 5 + 3 + 1 + 1 - -1 - -5 + -2 + -4, Actual: 10.00, Predicted Range: [-0.97, 21.26], bootstrapped prediction: [9.789362], in Range: True
# Input: -4 - -5 - 3 - -5 - 1 + -1 + 3 + -1, Actual: 3.00, Predicted Range: [-13.45, 3.43], bootstrapped prediction: [-3.6885943], in Range: True
# Input: -4 - -2 - 3 - -4 - -5 + 2 - -4 + -2, Actual: 8.00, Predicted Range: [-11.68, 7.58], bootstrapped prediction: [-3.0589843], in Range: False
# Input: -4 - 2 + -2 - -2 + -2 + 4 + 3 + -4, Actual: -5.00, Predicted Range: [-19.19, 5.84], bootstrapped prediction: [-8.418189], in Range: True
# Input: 5 - -3 + -4 + 5 - 2 + 3 + 0 + -3, Actual: 7.00, Predicted Range: [4.68, 19.69], bootstrapped prediction: [11.695188], in Range: True
# Input: 1 - 3 - 5 + -3 + -4 + 5 + 0 + -4, Actual: -13.00, Predicted Range: [-15.41, 9.73], bootstrapped prediction: [-4.009913], in Range: True
# Input: -3 + -3 + -5 + 3 - 5 - 2 + 4 - 2, Actual: -13.00, Predicted Range: [-11.03, 3.57], bootstrapped prediction: [-2.403478], in Range: False
# Input: -2 + -4 - 5 + -3 - 5 - 1 - 2 - 4, Actual: -26.00, Predicted Range: [-17.01, -0.62], bootstrapped prediction: [-7.997163], in Range: False
# Input: 2 - -1 + 2 - -5 + -1 + 3 - 4 - -3, Actual: 11.00, Predicted Range: [-9.93, 9.14], bootstrapped prediction: [-0.20166035], in Range: False
# Input: 2 + 1 - 4 - -4 - 5 - -2 + -4 + 1, Actual: -3.00, Predicted Range: [-13.32, 11.67], bootstrapped prediction: [0.96642286], in Range: True
# Input: 3 - 3 + -3 + 4 + 5 - -4 + 4 - -2, Actual: 16.00, Predicted Range: [-4.49, 21.61], bootstrapped prediction: [8.09038], in Range: True
# Input: 0 + -1 + 2 + 4 + 3 + 3 - 3 + 0, Actual: 8.00, Predicted Range: [-6.08, 7.30], bootstrapped prediction: [0.23271346], in Range: False
# Input: -2 - 5 - 4 + -1 + 1 + 5 + -2 - 5, Actual: -13.00, Predicted Range: [-16.01, -2.98], bootstrapped prediction: [-9.79946], in Range: True
# Input: -4 - 2 - -3 + -1 + -5 + -1 - 4 - 5, Actual: -19.00, Predicted Range: [-9.55, 8.08], bootstrapped prediction: [-0.25047094], in Range: False
# Input: 5 + -4 + 4 + -3 + -1 - 4 + 2 - -3, Actual: 2.00, Predicted Range: [-9.99, 10.34], bootstrapped prediction: [1.539005], in Range: True
# Input: -5 - -3 + 5 + -3 - 2 - -3 + 2 - -3, Actual: 6.00, Predicted Range: [-4.06, 6.16], bootstrapped prediction: [0.9168104], in Range: True
# Input: 1 + -4 - 2 + -2 - 5 + 5 - -2 + 4, Actual: -1.00, Predicted Range: [-15.44, 10.43], bootstrapped prediction: [-1.8245819], in Range: True
# Input: -1 - -5 - 1 - 5 - 4 + -1 - 4 - -4, Actual: -7.00, Predicted Range: [-4.21, 27.21], bootstrapped prediction: [8.253363], in Range: False
# Input: 3 - 3 - -2 + -1 - -1 - -2 + 1 - -1, Actual: 6.00, Predicted Range: [-0.10, 7.93], bootstrapped prediction: [3.4148202], in Range: True
# Input: 3 + 1 - -2 - 4 + 0 + -5 + 3 - 0, Actual: 0.00, Predicted Range: [-3.21, 19.95], bootstrapped prediction: [9.060846], in Range: True
# Input: 2 + -1 - 1 - -1 + -2 - 1 - 4 + 4, Actual: -2.00, Predicted Range: [-3.61, 12.10], bootstrapped prediction: [3.4023597], in Range: True
# Input: 4 - 0 + -1 + 2 - 1 - -1 + 4 - 1, Actual: 8.00, Predicted Range: [-0.02, 12.85], bootstrapped prediction: [6.767517], in Range: True
# Input: 4 + 2 + -4 - -2 + 4 - 3 - 0 - 0, Actual: 5.00, Predicted Range: [-6.60, 9.57], bootstrapped prediction: [0.43789536], in Range: True
# Input: 4 + 4 - 3 + 3 + 5 - 3 + 4 + -1, Actual: 13.00, Predicted Range: [-7.37, 6.88], bootstrapped prediction: [0.41960916], in Range: False
# Input: 0 + -5 + 2 - -2 - 1 - 0 + -2 - -3, Actual: -1.00, Predicted Range: [-19.54, 0.38], bootstrapped prediction: [-5.802256], in Range: True
# Input: -1 + -4 + 3 - -3 - -1 - -1 + -3 + 3, Actual: 3.00, Predicted Range: [-12.34, 12.71], bootstrapped prediction: [-0.44242033], in Range: True
# Input: -1 - -3 - 3 - 1 - 1 - 2 - -5 + -2, Actual: -2.00, Predicted Range: [-11.19, 4.49], bootstrapped prediction: [-2.56642], in Range: True
# Input: -1 + -5 + -4 - 1 - -1 + 5 - -5 + 0, Actual: 0.00, Predicted Range: [-20.03, 1.32], bootstrapped prediction: [-8.490384], in Range: True
# Input: -5 - 0 + 3 + -2 + 3 + 0 + 1 + -5, Actual: -5.00, Predicted Range: [-9.78, 5.36], bootstrapped prediction: [-2.5718818], in Range: True
# Input: -1 + 4 - 0 - 3 + -2 + 5 - -4 - -3, Actual: 10.00, Predicted Range: [-10.22, 6.90], bootstrapped prediction: [-0.79024816], in Range: False
# Input: 5 + 5 - -2 - 4 - 1 + -1 - -5 + 0, Actual: 11.00, Predicted Range: [-2.81, 13.82], bootstrapped prediction: [6.723651], in Range: True
# Input: 5 - 2 + -4 + 3 - -4 + 2 + 0 + -2, Actual: 6.00, Predicted Range: [-3.64, 9.86], bootstrapped prediction: [3.2390885], in Range: True
# Input: -1 - 5 + -5 + 3 - -5 + 1 + -4 - -5, Actual: -1.00, Predicted Range: [-16.33, 5.67], bootstrapped prediction: [-3.8580139], in Range: True
# Input: -1 - -2 + -1 + 4 - -4 - 3 - -3 - -4, Actual: 12.00, Predicted Range: [-11.86, 11.10], bootstrapped prediction: [0.46046194], in Range: False
# Input: -3 - -1 + 4 - 2 + -2 - -5 + -1 - -5, Actual: 7.00, Predicted Range: [-3.84, 19.33], bootstrapped prediction: [7.2996397], in Range: True
# Input: 5 - -1 - -2 - -1 - 3 + -4 - -3 + -4, Actual: 1.00, Predicted Range: [-4.18, 11.01], bootstrapped prediction: [3.5243924], in Range: True
# Input: -5 - 2 + -1 - 4 + -1 + 3 + 2 - -5, Actual: -3.00, Predicted Range: [-8.66, 3.97], bootstrapped prediction: [-3.0794005], in Range: True
# Input: -5 - 2 - -5 + -2 + -4 + 5 - 5 - -3, Actual: -5.00, Predicted Range: [-21.43, 6.47], bootstrapped prediction: [-6.7405767], in Range: True
# Input: -2 + 3 - -1 + 3 - 5 + 2 + -1 + -5, Actual: -4.00, Predicted Range: [-6.50, 11.19], bootstrapped prediction: [2.0926013], in Range: True
# Input: 0 + 2 - -4 + 0 - 5 - 4 + 0 + -5, Actual: -8.00, Predicted Range: [-8.31, 15.15], bootstrapped prediction: [2.341637], in Range: True
# Input: 1 - -1 - 4 + 5 - -1 + -5 - -1 + -3, Actual: -3.00, Predicted Range: [-2.96, 17.64], bootstrapped prediction: [7.2486863], in Range: False
# Input: -5 + -4 + 3 - -2 - 3 + 0 - 4 + 3, Actual: -8.00, Predicted Range: [-12.32, -0.43], bootstrapped prediction: [-6.505727], in Range: True
# Input: 1 + 3 - -1 - -4 - -4 + -2 - -1 + 5, Actual: 17.00, Predicted Range: [-10.49, 15.58], bootstrapped prediction: [5.3592386], in Range: False
# Input: -5 - 4 - 3 - 2 + 0 + 3 - 1 + -5, Actual: -17.00, Predicted Range: [-10.12, 0.90], bootstrapped prediction: [-6.445567], in Range: False
# Input: -1 + -4 + 0 - -4 + -5 + 1 + -2 + 2, Actual: -5.00, Predicted Range: [-16.43, 11.06], bootstrapped prediction: [-2.20587], in Range: True
# Input: 2 - -5 + 3 - -4 - 5 - -3 - -4 + 2, Actual: 18.00, Predicted Range: [-10.12, 12.05], bootstrapped prediction: [2.5891483], in Range: False
# Input: 0 - -3 - 3 - 4 - -5 - -2 - -3 - 2, Actual: 4.00, Predicted Range: [-3.42, 15.51], bootstrapped prediction: [4.4955416], in Range: True
# Input: 3 - -2 + -4 + 4 + 1 - 3 + 4 - 4, Actual: 3.00, Predicted Range: [-3.69, 18.42], bootstrapped prediction: [6.256789], in Range: True
# Input: 0 - -4 - 3 + 1 + -1 + 3 - -1 + -5, Actual: 0.00, Predicted Range: [-13.82, 2.57], bootstrapped prediction: [-1.9850582], in Range: True
# Input: -3 + -2 + -4 - -3 + 2 + 3 - 4 + -2, Actual: -7.00, Predicted Range: [-16.47, 1.43], bootstrapped prediction: [-8.034296], in Range: True
# Input: -1 + 3 + 3 + 4 - 4 - -3 + 0 + 2, Actual: 10.00, Predicted Range: [-6.60, 10.87], bootstrapped prediction: [1.6619751], in Range: True
# Input: -3 - -5 - 3 - 3 + -4 - 2 - 4 + -5, Actual: -19.00, Predicted Range: [-8.96, 13.17], bootstrapped prediction: [1.3141739], in Range: False
# Input: 2 + 0 + 4 + -3 - -2 + 5 + -4 - -4, Actual: 10.00, Predicted Range: [-19.98, 12.58], bootstrapped prediction: [-0.26136056], in Range: True
# Input: -2 - -5 - 1 + 2 - -3 + 1 - 5 - 2, Actual: 1.00, Predicted Range: [-5.60, 12.77], bootstrapped prediction: [5.1919026], in Range: True
# Input: -1 + 0 + 4 - -5 + 3 + -3 - -4 + -2, Actual: 10.00, Predicted Range: [-16.35, 13.29], bootstrapped prediction: [2.2459693], in Range: True
# Input: -5 + -5 - -2 + 2 + 2 - 3 + 3 - 2, Actual: -6.00, Predicted Range: [-10.72, 3.51], bootstrapped prediction: [-4.481969], in Range: True
# Input: -5 + 3 - 3 - -5 + 0 - -1 + 1 - -2, Actual: 4.00, Predicted Range: [-9.65, 9.83], bootstrapped prediction: [0.585482], in Range: True
# Input: 2 + -4 + 0 - 2 + 5 - -2 + -2 - 2, Actual: -1.00, Predicted Range: [-7.12, 1.70], bootstrapped prediction: [-2.598763], in Range: True
# Input: 2 + -3 - -4 + 3 - 3 + 2 + -3 - -1, Actual: 3.00, Predicted Range: [-4.21, 11.70], bootstrapped prediction: [2.8978047], in Range: True
# Input: 3 - -3 + 2 + 2 + 3 + -1 + 3 + 2, Actual: 17.00, Predicted Range: [3.12, 12.58], bootstrapped prediction: [7.5364904], in Range: False
# Input: -2 + 0 - -3 + -3 - -5 - -5 + -2 + 1, Actual: 7.00, Predicted Range: [-9.56, 12.43], bootstrapped prediction: [3.300963], in Range: True
# Input: 0 - -2 + 4 - -1 - 0 + 0 + -2 + -2, Actual: 3.00, Predicted Range: [-5.20, 10.57], bootstrapped prediction: [4.5951147], in Range: True
# Input: -4 - -4 + 1 - -5 - 3 - 3 + -1 + 0, Actual: -1.00, Predicted Range: [-15.13, 7.18], bootstrapped prediction: [-4.2920218], in Range: True
# Input: -4 + -5 + -5 - -1 + -1 + 1 + 5 - -5, Actual: -3.00, Predicted Range: [-14.45, 0.76], bootstrapped prediction: [-7.7220755], in Range: True
# Input: 3 + -1 - 1 - 2 - -5 - -2 - 0 + -5, Actual: 1.00, Predicted Range: [-9.46, 17.08], bootstrapped prediction: [4.3458433], in Range: True
# Input: -3 + 0 + -1 + -4 - -5 - 3 + 2 + 4, Actual: 0.00, Predicted Range: [-19.86, 9.55], bootstrapped prediction: [-3.0062008], in Range: True
# Input: -2 - -3 + 5 - 3 - -5 - -2 + -3 - 0, Actual: 7.00, Predicted Range: [0.21, 17.58], bootstrapped prediction: [7.392235], in Range: True
# Input: -5 + -2 + -5 - -3 + -2 + 0 - -4 - -1, Actual: -6.00, Predicted Range: [-20.33, 0.35], bootstrapped prediction: [-10.28716], in Range: True
# Input: -5 + 5 + -4 + 3 + -1 - 4 - -3 + -5, Actual: -8.00, Predicted Range: [-16.11, 8.36], bootstrapped prediction: [-4.716497], in Range: True
# Input: 4 - -2 + 5 - -1 - -2 + -4 - -2 - 3, Actual: 9.00, Predicted Range: [1.73, 16.62], bootstrapped prediction: [9.32493], in Range: True
# Input: 4 + 1 - -3 + 1 + -5 - -2 - 3 - -3, Actual: 6.00, Predicted Range: [-1.59, 16.18], bootstrapped prediction: [7.189453], in Range: True
# Amount out of bounds: 153, Amount of expressions: 700, Percentage in bounds: 78.14285714285714%

# %%
# Visualize the predictions and the range for a few samples
plt.figure(figsize=(10, 6))
# Calculate the positive error values for the lower and upper bounds
yerr_lower = abs(y_test[:11] - lower_bound[:11, 0])
yerr_upper = abs(upper_bound[:11, 0] - y_test[:11])
plt.errorbar(range(len(y_test[:11])), y_test[:11], yerr=[yerr_lower, yerr_upper], fmt='o', label='Actual with 90% Prediction Range')
plt.xlabel("Test Sample Index")
plt.ylabel("Value")
plt.title("Actual Values and 90% Prediction Range for Test Set (Bootstrap)")
plt.legend()
plt.show()

# %%
def absSum(x):
  expressions = x
  p = []
  for i in range(len(expressions)):
    components = []
    components = expressions[i].split(" ")
    p.append(abs(int(components[0])) + abs(int(components[2])) + abs(int(components[4])))
  return p
print(absSum(expressions_not_in_x))
# Out:
# [8, 7, 6, 11, 12, 11, 6, 8, 12, 12, 3, 5, 8, 8, 8, 10, 9, 8, 6, 12, 8, 7, 10, 6, 10, 7, 5, 3, 8, 9, 8, 12, 10, 5, 8, 11, 6, 9, 7, 7, 8, 6, 9, 7, 11, 2, 5, 10, 9, 2, 8, 4, 5, 5, 5, 4, 12, 7, 11, 8, 7, 6, 5, 8, 6, 5, 3, 13, 12, 11, 10, 6, 8, 6, 7, 6, 8, 12, 9, 5, 6, 5, 8, 3, 9, 3, 10, 8, 9, 2, 5, 8, 5, 5, 10, 6, 2, 8, 6, 5, 3, 8, 5, 5, 10, 11, 2, 7, 6, 9, 11, 6, 4, 7, 6, 4, 6, 3, 9, 10, 6, 5, 8, 5, 4, 7, 4, 5, 10, 9, 7, 6, 7, 11, 3, 8, 11, 11, 7, 7, 4, 7, 11, 14, 11, 8, 8, 9, 6, 4, 6, 11, 8, 9, 8, 1, 8, 9, 11, 7, 10, 7, 14, 4, 5, 12, 8, 7, 6, 5, 8, 3, 2, 9, 12, 12, 7, 11, 6, 9, 9, 9, 6, 9, 9, 5, 13, 6, 6, 10, 8, 9, 6, 7, 7, 10, 6, 6, 5, 5, 8, 10, 11, 5, 7, 8, 7, 6, 2, 8, 6, 11, 9, 8, 1, 10, 4, 4, 6, 13, 6, 7, 11, 8, 7, 8, 11, 14, 6, 6, 7, 7, 9, 6, 11, 8, 12, 4, 6, 5, 9, 11, 10, 6, 4, 8, 3, 7, 5, 11, 7, 6, 6, 6, 8, 6, 8, 4, 9, 7, 9, 9, 9, 7, 5, 9, 7, 8, 8, 3, 7, 4, 7, 4, 7, 7, 9, 8, 5, 9, 9, 9, 8, 10, 4, 10, 6, 8, 12, 10, 7, 4, 8, 12, 8, 8, 7, 10, 4, 6, 4, 6, 9, 6, 7, 6, 8, 10, 6, 11, 7, 10, 12, 6, 11, 9, 11, 13, 5, 8, 8, 7, 9, 8, 10, 10, 3, 11, 3, 10, 5, 6, 6, 10, 7, 5, 6, 7, 3, 12, 13, 8, 10, 7, 8, 7, 5, 10, 7, 9, 2, 6, 10, 11, 11, 6, 9, 7, 7, 7, 5, 9, 8, 5, 7, 8, 6, 10, 7, 8, 8, 9, 7, 6, 9, 12, 8, 4, 8, 9, 11, 8, 4, 3, 9, 3, 9, 10, 3, 12, 9, 5, 8, 7, 10, 10, 1, 6, 8, 6, 7, 11, 12, 8, 7, 7, 4, 6, 7, 11, 4, 9, 5, 11, 8, 12, 9, 7, 4, 10, 5, 3, 7, 12, 4, 9, 11, 4, 4, 5, 7, 5, 10, 1, 9, 10, 9, 5, 12, 4, 6, 7, 6, 7, 10, 11, 9, 12, 9, 6, 10, 7, 7, 8, 10, 4, 9, 8, 12, 11, 4, 9, 11, 7, 11, 2, 9, 4, 10, 6, 6, 8, 9, 10, 4, 8, 10, 8, 3, 8, 5, 3, 9, 8, 7, 4, 3, 11, 9, 11, 8, 13, 7, 4, 8, 10, 10, 8, 9, 3, 6, 9, 12, 10, 8, 11, 6, 7, 7, 10, 10, 7, 9, 7, 6, 7, 3, 7, 9, 9, 10, 4, 10, 11, 4, 8, 4, 2, 5, 3, 8, 7, 4, 8, 8, 5, 10, 7, 5, 10, 7, 9, 7, 6, 4, 2, 5, 10, 9, 8, 8, 6, 12, 6, 5, 10, 10, 12, 10, 9, 12, 6, 9, 7, 9, 10, 5, 8, 6, 7, 10, 9, 7, 3, 7, 8, 9, 13, 8, 8, 9, 11, 6, 8, 4, 7, 6, 8, 7, 6, 7, 8, 5, 5, 10, 6, 5, 10, 4, 4, 4, 2, 5, 9, 5, 3, 8, 8, 6, 9, 10, 12, 9, 6, 7, 9, 7, 8, 8, 5, 6, 10, 9, 7, 6, 12, 12, 11, 5, 7, 6, 4, 10, 6, 9, 4, 3, 7, 9, 1, 9, 5, 11, 3, 5, 6, 11, 5, 7, 6, 11, 6, 4, 4, 9, 10, 11, 8, 10, 13, 10, 9, 9, 9, 6, 6, 5, 7, 6, 4, 14, 5, 8, 11, 6, 3, 7, 9, 5, 7, 8, 11, 9, 13, 10, 6, 4, 7, 12, 10, 3, 8, 10, 10, 4, 6, 13, 14, 5, 8, 5, 8, 7, 2, 5, 9, 6, 8, 12, 9, 8, 6, 2, 8, 6, 9, 8, 8, 7, 7, 6, 8, 8, 5, 11, 7, 9, 3, 11, 7, 5, 2, 3, 7, 5, 7, 7, 7, 7, 5, 10, 7, 7, 11, 9, 10, 7, 8, 9, 5, 7, 11, 7, 9, 6, 5, 3, 11, 7, 3, 10, 10, 11, 9, 5, 10, 9, 7, 8, 6, 7, 6, 5, 4, 5, 6, 9, 3, 5, 5, 1, 11, 8, 10, 9, 9, 6, 13, 8, 13, 7, 6, 10, 11, 12, 6, 10, 8, 7, 7, 7, 6, 4, 6, 15, 11, 4, 10, 6, 5, 9, 10, 8, 3, 12, 6, 7, 10, 8, 3, 10, 9, 6, 9, 11, 6, 10, 4, 10, 8, 3, 9, 8, 2, 6, 8, 5, 6, 11, 7, 6, 5, 5, 7, 9, 10, 8, 7, 10, 7, 11, 8, 5, 8, 5, 8, 8, 11, 10, 6, 8, 10, 7, 10, 9, 1, 8, 7, 5, 8, 5, 9, 5, 4, 11, 7, 5, 11, 5, 6, 11, 12, 7, 4, 8, 7, 8, 4, 7, 8, 4, 9, 7, 9, 8, 10, 10, 5, 4, 5, 6, 7, 4, 10, 8, 4, 7, 5, 8, 3, 8, 8, 9, 6, 7, 11, 9, 4, 5, 11, 6, 10, 7, 10, 3, 10, 7, 8, 5, 8, 9, 6, 7, 14, 3, 8, 13, 5, 7, 11, 7, 8, 6, 7, 2, 13, 7, 11, 4, 12, 6, 8, 12, 7, 9, 4, 8, 7, 11, 8, 10, 3, 4, 7, 6, 7, 3, 7, 4, 12, 11, 6, 8, 6, 8, 4, 9, 5, 13, 8, 9, 7, 10, 10, 8, 7, 7, 10, 10, 7, 6, 7, 3, 9, 8, 4, 6, 6, 10, 8, 6, 9, 7, 5, 6, 9, 5, 6, 7, 8, 6, 8, 8, 1, 10, 5, 4, 8, 8, 6, 5, 5, 10, 8, 10, 6, 5, 6, 8, 6, 5, 9, 6, 7, 5, 10, 10, 10, 13, 6, 3, 8, 8, 6, 9, 6, 11, 3, 6, 6, 6, 11, 5, 6, 5, 7, 3, 3, 10, 10, 7, 11, 5, 7, 7, 6, 5, 4, 11, 7, 9, 10, 4, 6, 7, 10, 12, 8, 9, 4, 4, 6, 5, 7, 9, 9, 10, 11, 5, 5, 10, 8, 8, 4, 8, 4, 7, 4, 8, 9, 6, 5, 7, 12, 6, 5, 7, 7, 11, 8, 11, 8, 7, 8, 10, 6, 12, 1, 8, 8, 11, 12, 8, 6, 14, 4, 12, 7, 7, 10, 9, 5, 2, 11, 9, 9, 4, 14, 4, 2, 6, 9, 9, 7, 4, 10, 4, 5, 10, 11, 11, 13, 6, 8, 9, 7, 7, 8, 6, 9, 4, 7, 8, 6, 7, 9, 8, 8, 6, 4, 7, 7, 4, 5, 9, 3, 7, 13, 6, 4, 7, 6, 7, 12, 7, 6, 5, 11, 9, 6, 9, 8, 5, 7, 10, 8, 5, 11, 5, 2, 5, 8, 11, 10, 4, 5, 10, 7, 4, 7, 8, 13, 8, 8, 8, 8, 7, 7, 9, 5, 9, 8, 4, 5, 10, 7, 9, 10, 10, 7, 5, 11, 11, 7, 3, 8, 8, 7, 7 ...

# %%
deviation = []
relativeError = []
out_deviation = []
out_relativeError = []

for i in range(len(y_test)):
  deviation.append(abs(y_test[i]-meanPredictions[i]))
print(deviation)
for i in range(len(y_test)):
  if y_test[i] != 0:
    relativeError.append(deviation[i]/abs(y_test[i]))
  else:
    relativeError.append(deviation[i])
print(relativeError)
avDeviation = np.mean(deviation)
print(np.mean(deviation))

for i in range(len(out_y_test)):
  out_deviation.append(abs(out_y_test[i]-out_meanPredictions[i]))
print(out_deviation)
out_avDeviation = np.mean(out_deviation)
print(np.mean(out_deviation))

for i in range(len(out_y_test)):
  if out_y_test[i] != 0:
    out_relativeError.append(out_deviation[i]/abs(out_y_test[i]))
  else:
    out_relativeError.append(out_deviation[i])
# Out:
# [array([0.16586435], dtype=float32), array([0.09752989], dtype=float32), array([0.1854372], dtype=float32), array([0.16286564], dtype=float32), array([0.00593519], dtype=float32), array([0.04812527], dtype=float32), array([0.01870728], dtype=float32), array([0.01466882], dtype=float32), array([0.15381813], dtype=float32), array([0.06290913], dtype=float32), array([0.00289488], dtype=float32), array([0.04761624], dtype=float32), array([0.07459188], dtype=float32), array([0.08048916], dtype=float32), array([0.01647091], dtype=float32), array([0.03373623], dtype=float32), array([0.19674575], dtype=float32), array([0.10003376], dtype=float32), array([0.05479288], dtype=float32), array([0.01865244], dtype=float32), array([0.0442642], dtype=float32), array([0.0786984], dtype=float32), array([0.12484834], dtype=float32), array([0.11842155], dtype=float32), array([0.20903206], dtype=float32), array([0.12489843], dtype=float32), array([0.06379914], dtype=float32), array([0.16425312], dtype=float32), array([0.00856709], dtype=float32), array([0.08569539], dtype=float32), array([0.01696062], dtype=float32), array([0.19391823], dtype=float32), array([0.07336617], dtype=float32), array([0.00055933], dtype=float32), array([0.11260233], dtype=float32), array([0.00103378], dtype=float32), array([0.09949446], dtype=float32), array([0.04125023], dtype=float32), array([0.06178331], dtype=float32), array([0.01734924], dtype=float32), array([0.22663641], dtype=float32), array([0.10542154], dtype=float32), array([0.11865234], dtype=float32), array([0.06314993], dtype=float32), array([0.10518718], dtype=float32), array([0.03967027], dtype=float32), array([0.07520598], dtype=float32), array([0.13311815], dtype=float32), array([0.00898552], dtype=float32), array([0.00132203], dtype=float32), array([0.01209414], dtype=float32), array([0.02286005], dtype=float32), array([0.13696909], dtype=float32), array([0.07367086], dtype=float32), array([0.02349567], dtype=float32), array([0.06847501], dtype=float32), array([0.16051614], dtype=float32), array([0.02813101], dtype=float32), array([0.06707096], dtype=float32), array([0.11517966], dtype=float32), array([0.05026007], dtype=float32), array([0.04461813], dtype=float32), array([0.096591], dtype=float32), array([0.27968073], dtype=float32), array([0.01439047], dtype=float32), array([0.13655472], dtype=float32), array([0.06573606], dtype=float32), array([0.37806225], dtype=float32), array([0.26034164], dtype=float32), array([0.0155735], dtype=float32), array([0.00599337], dtype=float32), array([0.08601785], dtype=float32), array([0.08285451], dtype=float32), array([0.12855864], dtype=float32), array([0.07483602], dtype=float32), array([0.04744387], dtype=float32), array([0.03350234], dtype=float32), array([0.13928294], dtype=float32), array([0.05955791], dtype=float32), array([0.02262688], dtype=float32), array([0.07151038], dtype=float32), array([0.02802706], dtype=float32), array([0.01767683], dtype=float32), array([0.06839705], dtype=float32), array([0.10445547], dtype=float32), array([0.02726877], dtype=float32), array([0.02712274], dtype=float32), array([0.00834894], dtype=float32), array([0.13769484], dtype=float32), array([0.09358764], dtype=float32), array([0.11081624], dtype=float32), array([0.1678555], dtype=float32), array([0.03521669], dtype=float32), array([0.03977549], dtype=float32), array([0.04334497], dtype=float32), array([0.14758205], dtype=float32), array([0.04951247], dtype=float32), array([0.00645733], dtype=float32), array([0.01185989], dtype=float32), array([0.03638363], dtype=float32), array([0.10955119], dtype=float32), array([0.21285383], dtype=float32), array([0.0203495], dtype=float32), array([0.03490847], dtype=float32), array([0.06733012], dtype=float32), array([0.17463899], dtype=float32), array([0.01426351], dtype=float32), array([0.036973], dtype=float32), array([0.15877151], dtype=float32), array([0.04651451], dtype=float32), array([0.31721115], dtype=float32), array([0.0729 ...
# [array([0.08293217], dtype=float32), array([0.01950598], dtype=float32), array([0.0463593], dtype=float32), array([0.03257313], dtype=float32), array([0.0014838], dtype=float32), array([0.00437502], dtype=float32), array([0.00311788], dtype=float32), array([0.00733441], dtype=float32), array([0.03845453], dtype=float32), array([0.01572728], dtype=float32), array([0.00096496], dtype=float32), array([0.04761624], dtype=float32), array([0.03729594], dtype=float32), array([0.01006114], dtype=float32), array([0.00205886], dtype=float32), array([0.01686811], dtype=float32), array([0.19674575], dtype=float32), array([0.02500844], dtype=float32), array([0.02739644], dtype=float32), array([0.00466311], dtype=float32), array([0.0221321], dtype=float32), array([0.0262328], dtype=float32), array([0.12484834], dtype=float32), array([0.05921078], dtype=float32), array([0.02090321], dtype=float32), array([0.01784263], dtype=float32), array([0.02126638], dtype=float32), array([0.16425312], dtype=float32), array([0.00214177], dtype=float32), array([0.08569539], dtype=float32), array([0.00282677], dtype=float32), array([0.09695911], dtype=float32), array([0.03668308], dtype=float32), array([0.00018644], dtype=float32), array([0.11260233], dtype=float32), array([0.00020676], dtype=float32), array([0.04974723], dtype=float32), array([0.00458336], dtype=float32), array([0.02059444], dtype=float32), array([0.00247846], dtype=float32), array([0.03777273], dtype=float32), array([0.02635539], dtype=float32), array([0.01318359], dtype=float32), array([0.00902142], dtype=float32), array([0.03506239], dtype=float32), array([0.03967027], dtype=float32), array([0.07520598], dtype=float32), array([0.02218636], dtype=float32), array([0.00099839], dtype=float32), array([0.00066102], dtype=float32), array([0.00604707], dtype=float32), array([0.01143003], dtype=float32), array([0.04565636], dtype=float32), array([0.02455696], dtype=float32), array([0.00469913], dtype=float32), array([0.0342375], dtype=float32), array([0.08025807], dtype=float32), array([0.0056262], dtype=float32), array([0.01341419], dtype=float32), array([0.05758983], dtype=float32), array([0.00718001], dtype=float32), array([0.00743636], dtype=float32), array([0.096591], dtype=float32), array([0.03496009], dtype=float32), array([0.00239841], dtype=float32), array([0.02731094], dtype=float32), array([0.02191202], dtype=float32), array([0.02908171], dtype=float32), array([0.02169514], dtype=float32), array([0.00141577], dtype=float32), array([0.00149834], dtype=float32), array([0.04300892], dtype=float32), array([0.04142725], dtype=float32), array([0.03213966], dtype=float32), array([0.02494534], dtype=float32), array([0.00790731], dtype=float32), array([0.01675117], dtype=float32), array([0.06964147], dtype=float32), array([0.00661755], dtype=float32), array([0.00452538], dtype=float32), array([0.07151038], dtype=float32), array([0.00560541], dtype=float32), array([0.00883842], dtype=float32), array([0.02279902], dtype=float32), array([0.01492221], dtype=float32), array([0.02726877], dtype=float32), array([0.01356137], dtype=float32), array([0.00208724], dtype=float32), array([0.02753897], dtype=float32), array([0.04679382], dtype=float32), array([0.03693875], dtype=float32), array([0.08392775], dtype=float32), array([0.03521669], dtype=float32), array([0.03977549], dtype=float32), array([0.00541812], dtype=float32), array([0.07379103], dtype=float32), array([0.04951247], dtype=float32), array([0.00107622], dtype=float32), array([0.00296497], dtype=float32), array([0.01212788], dtype=float32), array([0.03651707], dtype=float32), array([0.21285383], dtype=float32), array([0.0040699], dtype=float32), array([0.03490847], dtype=float32), array([0.01683253], dtype=float32), array([0.058213], dtype=float32), array([0.00713176], dtype=float32), array([0.01232433], dtype=float32), array([0.02646192], dtype=float32), array([0.00516828], dtype=float32), array([0.03524568], dtype=float32), array([0.03648 ...
# 0.08591679
# [array([1.3684483], dtype=float32), array([0.7781925], dtype=float32), array([6.1438293], dtype=float32), array([0.04646301], dtype=float32), array([3.9253879], dtype=float32), array([0.3983183], dtype=float32), array([0.16142368], dtype=float32), array([5.6261373], dtype=float32), array([0.30135632], dtype=float32), array([0.57595825], dtype=float32), array([2.2851248], dtype=float32), array([0.5005927], dtype=float32), array([2.648501], dtype=float32), array([1.1680803], dtype=float32), array([2.848814], dtype=float32), array([0.10772371], dtype=float32), array([2.994402], dtype=float32), array([2.1046662], dtype=float32), array([0.81328726], dtype=float32), array([1.0391364], dtype=float32), array([2.1077547], dtype=float32), array([0.3041582], dtype=float32), array([0.4414878], dtype=float32), array([1.7523394], dtype=float32), array([0.2607026], dtype=float32), array([0.29333782], dtype=float32), array([5.1326227], dtype=float32), array([0.7214937], dtype=float32), array([3.39464], dtype=float32), array([2.852922], dtype=float32), array([3.6297102], dtype=float32), array([0.15453577], dtype=float32), array([4.7747865], dtype=float32), array([3.5475993], dtype=float32), array([3.5798805], dtype=float32), array([3.9155986], dtype=float32), array([2.3730974], dtype=float32), array([1.1947546], dtype=float32), array([6.7767735], dtype=float32), array([2.5631437], dtype=float32), array([3.7477207], dtype=float32), array([1.340538], dtype=float32), array([0.50295305], dtype=float32), array([5.513768], dtype=float32), array([0.92434406], dtype=float32), array([1.473484], dtype=float32), array([1.1791811], dtype=float32), array([4.801315], dtype=float32), array([5.7851887], dtype=float32), array([3.549615], dtype=float32), array([3.539772], dtype=float32), array([0.4455986], dtype=float32), array([6.9688463], dtype=float32), array([0.4765978], dtype=float32), array([0.65330887], dtype=float32), array([1.4303117], dtype=float32), array([0.37076426], dtype=float32), array([1.7536926], dtype=float32), array([3.2407122], dtype=float32), array([1.1606092], dtype=float32), array([0.9307585], dtype=float32), array([1.3678098], dtype=float32), array([2.5417686], dtype=float32), array([2.6211944], dtype=float32), array([1.0744877], dtype=float32), array([4.5643196], dtype=float32), array([1.112699], dtype=float32), array([4.745715], dtype=float32), array([1.8841953], dtype=float32), array([3.086773], dtype=float32), array([1.9719448], dtype=float32), array([4.640212], dtype=float32), array([5.1691203], dtype=float32), array([1.6947379], dtype=float32), array([0.00383329], dtype=float32), array([0.5708504], dtype=float32), array([2.234127], dtype=float32), array([0.2823801], dtype=float32), array([5.3379183], dtype=float32), array([4.423602], dtype=float32), array([2.7298079], dtype=float32), array([4.4474382], dtype=float32), array([2.464508], dtype=float32), array([0.34089804], dtype=float32), array([4.0646095], dtype=float32), array([2.6067672], dtype=float32), array([7.0939255], dtype=float32), array([4.4368114], dtype=float32), array([2.071828], dtype=float32), array([2.5209718], dtype=float32), array([2.8812237], dtype=float32), array([1.1211414], dtype=float32), array([0.41981888], dtype=float32), array([2.8771882], dtype=float32), array([3.1913114], dtype=float32), array([0.76823616], dtype=float32), array([3.8392677], dtype=float32), array([0.10893631], dtype=float32), array([2.0237825], dtype=float32), array([5.0673475], dtype=float32), array([0.1131103], dtype=float32), array([3.8519173], dtype=float32), array([0.52361965], dtype=float32), array([1.6079636], dtype=float32), array([2.3261976], dtype=float32), array([6.929652], dtype=float32), array([0.8790817], dtype=float32), array([5.94619], dtype=float32), array([4.7730675], dtype=float32), array([1.08044], dtype=float32), array([3.2048144], dtype=float32), array([2.256764], dtype=float32), array([4.0879707], dtype=float32), array([2.4303064], dtype=float32), array([0.80964565 ...
# 2.391634

# %%
import seaborn as sns

paired_data = sorted(zip(absSum(expressions_not_in_x), deviation))

# Unpack the sorted paired_data into separate lists for plotting
sorted_abs_sum = [item[0] for item in paired_data]
sorted_deviation = [item[1] for item in paired_data]

plt.figure(figsize=(10, 6))
# Use the unpacked lists for regplot
sns.regplot(x=sorted_abs_sum, y=sorted_deviation, order = 5, x_jitter=0.1, color = "red", scatter_kws ={"color": None}, label="data points")

x_values = np.arange(1,16)
y_values = np.full_like(x_values, avDeviation, dtype=np.float32)
plt.plot(x_values, y_values, color='green', linestyle='--', label='hypothesis')

plt.xlabel("Absolute Sum of Components (absSum)")
plt.ylabel("error")
plt.title("Deviation vs. Absolute Sum of Components for Test Set")
plt.legend(["data points", "polynomial regression with order 5", "confidence interval 95%", "hypothesis"])
plt.savefig("fig1.png")
plt.show()

# %%
paired_data = sorted(zip(absSum(expressions_not_in_x), relativeError))

# Separate the sorted absSum and relativeError values
sorted_abs_sum = [item[0] for item in paired_data]
sorted_relative_error = [item[1] for item in paired_data]

plt.figure(figsize=(10, 6))
# Use the unpacked lists for regplot
sns.regplot(x=sorted_abs_sum, y=sorted_relative_error, order = 5, x_jitter=0.1, color = "red", scatter_kws ={"color": None}, label="data points")

x_values = np.arange(1,16)
y_values = np.full_like(x_values, np.mean(relativeError), dtype=np.float32)
plt.plot(x_values, y_values, color='green', linestyle='--', label='hypothesis')

print(np.mean(relativeError))
plt.xlabel("Absolute Sum of Components (absSum)")
plt.ylabel("Relative Error") # Changed label to reflect relativeError
plt.title("Relative Error vs. Absolute Sum of Components for Test Set")
plt.legend(["data points", "polynomial regression with order 5", "confidence interval 95%", "hypothesis"])
plt.savefig("fig2.png")
plt.show()
# Out:
# 0.033052616

# %%
paired_data = sorted(zip(y_test, deviation))

# Separate the sorted absSum and relativeError values
sorted_abs_sum = [item[0] for item in paired_data]
sorted_relative_error = [item[1] for item in paired_data]

plt.figure(figsize=(10, 6))
# Use the unpacked lists for regplot
sns.regplot(x=sorted_abs_sum, y=sorted_relative_error, order = 5, x_jitter=0.1, color = "red", scatter_kws ={"color": None}, label="data points")


plt.xlabel("actual value of the expression")
plt.ylabel("error") # Changed label to reflect relativeError
plt.title("error vs. actual value of the expressions")
plt.legend(["data points", "polynomial regression with order 5", "confidence interval 95%"])
plt.savefig("fig3.png")
plt.show()

# %%
paired_data = sorted(zip(y_test, relativeError))

# Separate the sorted absSum and relativeError values
sorted_abs_sum = [item[0] for item in paired_data]
sorted_relative_error = [item[1] for item in paired_data]

plt.figure(figsize=(10, 6))
# Use the unpacked lists for regplot
sns.regplot(x=sorted_abs_sum, y=sorted_relative_error, order = 5, x_jitter=0.1, color = "red", scatter_kws ={"color": None}, label="data points")

print(np.mean(relativeError))
plt.xlabel("actual value of the expression")
plt.ylabel("Relative Error") # Changed label to reflect relativeError
plt.title("Relative Error vs. actual value of the expressions")
plt.legend(["data points", "polynomial regression with order 5", "confidence interval 95%"])
plt.savefig("fig4.png")
plt.show()
# Out:
# 0.033052616

# %%
most_Expr =outsideExpr + expressions_not_in_x
most_deviation = out_deviation + deviation
most_absSum = absSum(outsideExpr) + absSum(expressions_not_in_x)

paired_data = sorted(zip(most_absSum, most_deviation))

# Separate the sorted absSum and relativeError values
sorted_abs_sum = [item[0] for item in paired_data]
sorted_relative_error = [item[1] for item in paired_data]

plt.figure(figsize=(10, 6))
# Use the unpacked lists for regplot
sns.regplot(x=sorted_abs_sum, y=sorted_relative_error, order = 5, x_jitter=0.1, color = "red", scatter_kws ={"color": None}, label="data points")


# Define the x-coordinate for the vertical line
vertical_line_x = 15

# Define the y-range for the vertical line (adjust as needed)
# You can use the range of your data's y-values or a specific range
# For example, to cover the range of your plotted data:
min_y = min(plt.gca().get_ylim()) # Get the current y-axis limits
max_y = max(plt.gca().get_ylim())
vertical_line_y = np.linspace(min_y, max_y, 100) # Create a range of y values

plt.plot(np.full_like(vertical_line_y, vertical_line_x), vertical_line_y, color='black', linestyle='--', label='training range limit')


plt.xlabel("Absolute Sum of Components (absSum)")
plt.ylabel("Deviation (abs(Actual - Mean Prediction))")
plt.title("Deviation vs. Absolute Sum of Components for Test Set")
plt.legend(["data points", "polynomial regression with order 5", "confidence interval 95%", "training range limit"])
plt.savefig("fig5.png")
plt.show()

# %%
most_Expr =outsideExpr + expressions_not_in_x
most_deviation = out_deviation + deviation
most_y = out_y_test + y_test

paired_data = sorted(zip(most_y, most_deviation))

sorted_abs_sum = [item[0] for item in paired_data]
sorted_relative_error = [item[1] for item in paired_data]

plt.figure(figsize=(10, 6))
# Use the unpacked lists for regplot
sns.regplot(x=sorted_abs_sum, y=sorted_relative_error, order = 5, x_jitter=0.1, color = "red", scatter_kws ={"color": None}, label="data points")

plt.xlabel("Actual y values")
plt.ylabel("error")
plt.title("Deviation vs. y test")
plt.legend(["data points", "polynomial regression with order 5", "confidence interval 95%"])
plt.savefig("fig6.png")
plt.show()

# %%
most_Expr =outsideExpr + expressions_not_in_x
most_deviation = out_relativeError + relativeError
most_y = out_y_test + y_test
avRelError = np.mean(most_deviation)

print(avRelError)
paired_data = sorted(zip(most_y, most_deviation))

sorted_abs_sum = [item[0] for item in paired_data]
sorted_relative_error = [item[1] for item in paired_data]

plt.figure(figsize=(10, 6))
# Use the unpacked lists for regplot
sns.regplot(x=sorted_abs_sum, y=sorted_relative_error, order = 5, x_jitter=0.1, color = "red", scatter_kws ={"color": None}, label="data points")

plt.xlabel("Actual y values")
plt.ylabel("relative Errors")
plt.title("relative Errors vs. y test")
plt.legend(["data points", "polynomial regression with order 5", "confidence interval 95%"])
plt.savefig("fig7.png")
plt.show()
# Out:
# 0.17343152

# %%
most_Expr =outsideExpr + expressions_not_in_x
most_deviation = out_relativeError + relativeError
most_absSum = absSum(outsideExpr) + absSum(expressions_not_in_x)

paired_data = sorted(zip(most_absSum, most_deviation))

sorted_abs_sum = [item[0] for item in paired_data]
sorted_relative_error = [item[1] for item in paired_data]

plt.figure(figsize=(10, 6))
# Use the unpacked lists for regplot
sns.regplot(x=sorted_abs_sum, y=sorted_relative_error, order = 5, x_jitter=0.1, color = "red", scatter_kws ={"color": None}, label="data points")


# Define the x-coordinate for the vertical line
vertical_line_x = 15

# Define the y-range for the vertical line (adjust as needed)
# You can use the range of your data's y-values or a specific range
# For example, to cover the range of your plotted data:
min_y = min(plt.gca().get_ylim()) # Get the current y-axis limits
max_y = max(plt.gca().get_ylim())
vertical_line_y = np.linspace(min_y, max_y, 100) # Create a range of y values

plt.plot(np.full_like(vertical_line_y, vertical_line_x), vertical_line_y, color='black', linestyle='--', label='training range limit')


plt.xlabel("Absolute Sum of Components (absSum)")
plt.ylabel("relative Errors")
plt.title("relative Errors vs. Absolute Sum of Components for Test Set")
plt.legend(["data points", "polynomial regression with order 5", "confidence interval 95%", "training range limit"])
plt.savefig("fig8.png")
plt.show()

# %%
long_deviation = []
for i in range(len(long_meanPredictions)): long_deviation.append(abs(long_meanPredictions[i] - long_y_test[i]))
print(len(long_deviation))
print(np.mean(long_deviation))

repeated_integers = []
for i in range(minNums, maxNums + 1):
  repeated_integers.extend([i] * amountNums)
print(len(long_deviation))
repeated_integers = np.array(repeated_integers)

long_coef = np.polyfit(repeated_integers, long_deviation, 5)


plt.figure(figsize=(10, 6))
plt.scatter(repeated_integers, long_deviation,  label = "data points")
plt.plot(repeated_integers, np.polyval(long_coef, repeated_integers), color='red', label=("trend-line (fitted polynomial)"))
plt.xlabel("Number of Terms")
plt.ylabel("Deviation (abs(Actual - Mean Prediction))")
plt.title("Deviation vs. Number of Terms for Test Set")
plt.legend()
plt.show()
# Out:
# 700
# 3.5349352
# 700

# %%
long_deviations = np.array(long_deviation)
long_deviations = long_deviations.reshape(maxNums-minNums+1,amountNums)
long_meanDeviations = []
for i in range(len(long_deviations)):
  long_meanDeviations.append(np.mean(long_deviations[i]))
print(long_meanDeviations)
print(out_deviation)
placeholder = absSum(outsideExpr)
print(placeholder)
paired = []
for i in range(len(out_deviation)):
  paired.append([out_deviation[i], placeholder[i]])
print(len(paired))
paired_sorted = sorted(paired, key=lambda item: item[1])
print(paired_sorted)

from collections import defaultdict

# Group deviations by placeholder value
grouped_deviations = defaultdict(list)
for deviation, placeholder_value in paired_sorted:
    grouped_deviations[placeholder_value].append(deviation)

# Calculate the mean deviation for each placeholder value
mean_deviations_by_placeholder = {}
for placeholder_value, deviations in grouped_deviations.items():
    mean_deviations_by_placeholder[placeholder_value] = np.mean(deviations)

print("Mean deviation for each placeholder value:")
for placeholder_value, mean_deviation in mean_deviations_by_placeholder.items():
    print(f"Placeholder value {placeholder_value}: {mean_deviation}")


print((avDeviation)**2)
print((long_meanDeviations[2])**2)
print((mean_deviations_by_placeholder[22])**2)
# Out:
# [np.float32(0.2694385), np.float32(0.2068527), np.float32(3.2527866), np.float32(4.2224584), np.float32(4.6298914), np.float32(5.9632683), np.float32(6.199849)]
# [array([1.3684483], dtype=float32), array([0.7781925], dtype=float32), array([6.1438293], dtype=float32), array([0.04646301], dtype=float32), array([3.9253879], dtype=float32), array([0.3983183], dtype=float32), array([0.16142368], dtype=float32), array([5.6261373], dtype=float32), array([0.30135632], dtype=float32), array([0.57595825], dtype=float32), array([2.2851248], dtype=float32), array([0.5005927], dtype=float32), array([2.648501], dtype=float32), array([1.1680803], dtype=float32), array([2.848814], dtype=float32), array([0.10772371], dtype=float32), array([2.994402], dtype=float32), array([2.1046662], dtype=float32), array([0.81328726], dtype=float32), array([1.0391364], dtype=float32), array([2.1077547], dtype=float32), array([0.3041582], dtype=float32), array([0.4414878], dtype=float32), array([1.7523394], dtype=float32), array([0.2607026], dtype=float32), array([0.29333782], dtype=float32), array([5.1326227], dtype=float32), array([0.7214937], dtype=float32), array([3.39464], dtype=float32), array([2.852922], dtype=float32), array([3.6297102], dtype=float32), array([0.15453577], dtype=float32), array([4.7747865], dtype=float32), array([3.5475993], dtype=float32), array([3.5798805], dtype=float32), array([3.9155986], dtype=float32), array([2.3730974], dtype=float32), array([1.1947546], dtype=float32), array([6.7767735], dtype=float32), array([2.5631437], dtype=float32), array([3.7477207], dtype=float32), array([1.340538], dtype=float32), array([0.50295305], dtype=float32), array([5.513768], dtype=float32), array([0.92434406], dtype=float32), array([1.473484], dtype=float32), array([1.1791811], dtype=float32), array([4.801315], dtype=float32), array([5.7851887], dtype=float32), array([3.549615], dtype=float32), array([3.539772], dtype=float32), array([0.4455986], dtype=float32), array([6.9688463], dtype=float32), array([0.4765978], dtype=float32), array([0.65330887], dtype=float32), array([1.4303117], dtype=float32), array([0.37076426], dtype=float32), array([1.7536926], dtype=float32), array([3.2407122], dtype=float32), array([1.1606092], dtype=float32), array([0.9307585], dtype=float32), array([1.3678098], dtype=float32), array([2.5417686], dtype=float32), array([2.6211944], dtype=float32), array([1.0744877], dtype=float32), array([4.5643196], dtype=float32), array([1.112699], dtype=float32), array([4.745715], dtype=float32), array([1.8841953], dtype=float32), array([3.086773], dtype=float32), array([1.9719448], dtype=float32), array([4.640212], dtype=float32), array([5.1691203], dtype=float32), array([1.6947379], dtype=float32), array([0.00383329], dtype=float32), array([0.5708504], dtype=float32), array([2.234127], dtype=float32), array([0.2823801], dtype=float32), array([5.3379183], dtype=float32), array([4.423602], dtype=float32), array([2.7298079], dtype=float32), array([4.4474382], dtype=float32), array([2.464508], dtype=float32), array([0.34089804], dtype=float32), array([4.0646095], dtype=float32), array([2.6067672], dtype=float32), array([7.0939255], dtype=float32), array([4.4368114], dtype=float32), array([2.071828], dtype=float32), array([2.5209718], dtype=float32), array([2.8812237], dtype=float32), array([1.1211414], dtype=float32), array([0.41981888], dtype=float32), array([2.8771882], dtype=float32), array([3.1913114], dtype=float32), array([0.76823616], dtype=float32), array([3.8392677], dtype=float32), array([0.10893631], dtype=float32), array([2.0237825], dtype=float32), array([5.0673475], dtype=float32), array([0.1131103], dtype=float32), array([3.8519173], dtype=float32), array([0.52361965], dtype=float32), array([1.6079636], dtype=float32), array([2.3261976], dtype=float32), array([6.929652], dtype=float32), array([0.8790817], dtype=float32), array([5.94619], dtype=float32), array([4.7730675], dtype=float32), array([1.08044], dtype=float32), array([3.2048144], dtype=float32), array([2.256764], dtype=float32), array([4.0879707], dtype=float32), array([2.4303064], dtype=float32), array([0.80964565 ...
# [17, 19, 20, 18, 19, 22, 22, 21, 19, 19, 18, 20, 18, 23, 21, 20, 18, 17, 17, 16, 19, 21, 18, 21, 19, 21, 23, 22, 21, 21, 18, 20, 20, 19, 19, 21, 17, 19, 19, 17, 18, 17, 19, 21, 16, 18, 18, 19, 23, 18, 20, 17, 21, 21, 22, 18, 20, 20, 21, 19, 16, 18, 17, 17, 21, 17, 20, 21, 23, 22, 19, 18, 21, 20, 19, 19, 19, 21, 21, 20, 18, 20, 16, 18, 19, 22, 23, 19, 16, 19, 17, 22, 21, 19, 23, 22, 22, 17, 21, 21, 19, 18, 17, 19, 20, 20, 22, 21, 22, 19, 20, 19, 21, 18, 19, 18, 18, 24, 22, 19, 21, 20, 16, 20, 20, 19, 16, 18, 16, 18, 20, 20, 22, 21, 18, 20, 18, 18, 21, 20, 16, 20, 19, 17, 17, 17, 18, 19, 21, 21, 19, 23, 17, 21, 17, 23, 15, 15, 18, 24, 21, 22, 20, 21, 24, 19, 20, 18, 16, 21, 19, 17, 17, 20, 19, 20, 22, 21, 22, 19, 20, 18, 21, 21, 21, 20, 21, 21, 19, 21, 21, 22, 17, 16, 19, 22, 22, 21, 19, 19, 22, 20, 23, 15, 19, 20, 21, 19, 20, 22, 21, 22, 21, 17, 23, 19, 19, 19, 21, 22, 19, 20, 18, 18, 21, 17, 17, 19, 21, 20, 18, 16, 20, 20, 16, 22, 20, 21, 18, 21, 19, 18, 19, 20, 23, 22, 20, 20, 20, 21, 21, 16, 21, 21, 20, 21, 16, 18, 15, 20, 17, 22, 19, 17, 18, 21, 18, 21, 18, 20, 18, 19, 16, 20, 17, 22, 19, 17, 20, 16, 18, 20, 15, 22, 20, 20, 19, 17, 21, 17, 19, 22, 20, 21, 22, 19, 21, 20, 18, 21, 21, 20, 19, 18, 18, 19, 20, 15, 21, 15, 21, 22, 22, 18, 21, 19, 21, 18, 17, 19, 20, 19, 15, 18, 17, 20, 19, 21, 17, 23, 22, 19, 23, 19, 21, 21, 20, 20, 19, 20, 20, 24, 20, 21, 18, 18, 18, 21, 20, 23, 17, 19, 17, 18, 19, 24, 20, 20, 23, 17, 21, 17, 18, 21, 19, 19, 20, 18, 19, 18, 18, 19, 16, 19, 19, 16, 20, 21, 19, 21, 20, 17, 19, 20, 21, 18, 20, 22, 18, 20, 17, 23, 20, 21, 18, 17, 19, 20, 21, 22, 20, 19, 19, 19, 20, 20, 19, 18, 21, 21, 22, 18, 20, 17, 17, 16, 16, 21, 21, 21, 20, 22, 18, 17, 17, 21, 20, 22, 18, 18, 16, 18, 21, 17, 22, 20, 22, 22, 19, 21, 22, 23, 19, 17, 22, 21, 19, 19, 16, 20, 19, 21, 20, 20, 23, 22, 19, 20, 20, 20, 20, 18, 17, 24, 18, 19, 21, 21, 21, 18, 24, 17, 21, 21, 22, 17, 19, 18, 20, 22, 20, 22, 19, 17, 20, 20, 19, 22, 19, 18, 17, 19, 18, 19, 20, 20, 20, 19, 21, 19, 19, 17, 19, 19, 18, 19, 19, 17, 19, 17, 21, 15, 19, 18, 21, 20, 20, 18, 23, 21, 23, 21, 21, 22, 19, 18, 16, 21, 18, 16, 18, 18, 18, 21, 17, 20, 18, 15, 18, 18, 22, 19, 17, 18, 17, 21, 18, 17, 20, 21, 16, 19, 21, 17, 19, 21, 21, 19, 22, 19, 19, 18, 17, 17, 18, 18, 21, 20, 18, 17, 18, 20, 19, 18, 18, 18, 18, 19, 18, 19, 22, 24, 19, 16, 19, 21, 21, 20, 20, 17, 16, 19, 20, 19, 21, 20, 20, 20, 19, 18, 18, 16, 18, 22, 17, 20, 23, 20, 17, 20, 21, 18, 19, 20, 19, 21, 23, 19, 20, 21, 16, 18, 19, 20, 21, 18, 17, 19, 18, 23, 20, 19, 18, 19, 23, 21, 20, 18, 17, 16, 18, 19, 20, 22, 18, 19, 23, 16, 17, 21, 22, 20, 22, 22, 20, 20, 20, 20, 21, 19, 22, 20, 19, 20, 20, 17, 19, 20, 22, 18, 20, 15, 16, 19, 17, 21, 19, 18, 21, 20, 22, 23, 20, 17, 18, 21, 17, 21, 19, 21, 18, 18, 20, 18, 17, 21, 21, 16, 21, 17, 18, 19, 22, 21, 18, 17, 19, 20, 18, 22, 20, 20, 22, 15, 21, 21, 20, 19, 18, 19, 17, 20, 20, 17, 19, 19, 19, 24, 17, 20, 18, 21, 20, 21, 18, 22, 19, 19, 21, 18, 19, 18, 18, 17, 22, 18, 19, 20, 21, 19, 18, 19, 22, 23, 20, 18, 17, 15, 20, 20, 19, 20, 20, 20, 19, 20, 19, 21, 23, 20, 19, 20, 19, 22, 20, 21, 18, 22, 16, 19, 20, 20, 19, 17, 23, 20, 19, 18, 18, 17, 22, 18, 17, 21, 16, 20, 24, 18, 15, 23, 19, 24, 23, 20, 22, 22, 19, 20, 18, 23, 17, 20, 20, 20, 18, 18, 19, 21, 18, 19, 21, 21, 22, 19, 19, 17, 18, 21, 16, 20, 20, 21, 18, 19, 23, 19, 19, 20, 18, 20, 19, 19, 20, 21, 23, 21, 17, 19, 18, 19, 22, 17, 22, 22, 18, 22, 20, 21, 20, 18, 21, 18, 18, 21, 16, 16, 20, 20, 23, 19, 19, 19, 18, 20, 19, 18, 19, 21, 16, 17, 18, 21, 20, 16, 20, 19, 16, 18, 19, 20, 19, 20, 20, 20, 20, 21, 22, 23, 19, 23, 23, 23, 17, 20, 18, 20, 21, 19, 20, 22, 21, 17, 20, 16, 24, 16, 22, 20, 17, 16, 18, 17, 24, 22, 21, 19, 22, 16, 24, 22, 22, 22, 20, 24, 20, 18, 17, 20, 20, 19, 21, 20, 16, 20, 19, 20, 19, 20, 18, 16, 22, 19, 20, 19, 19, 20, 21, 22, 21, 23, 18, 18, 20, 21, 17, 19, 22, 23, 17, 18, 20, 21, 19, 19, 17, 19, 19, 21, 24, 21, 20, 20, 21, 19, 23, 22, 20, 16, 19, 16, 21, 16, 23, 19, 23, 16, 21, 17, 17, 15, ...
# 2048
# [[array([0.30051327], dtype=float32), 15], [array([1.5298462], dtype=float32), 15], [array([0.01946592], dtype=float32), 15], [array([1.832613], dtype=float32), 15], [array([0.31785107], dtype=float32), 15], [array([0.02569866], dtype=float32), 15], [array([0.8677945], dtype=float32), 15], [array([0.02767086], dtype=float32), 15], [array([0.07882071], dtype=float32), 15], [array([1.1526341], dtype=float32), 15], [array([0.5588455], dtype=float32), 15], [array([0.88679314], dtype=float32), 15], [array([0.40213633], dtype=float32), 15], [array([2.159521], dtype=float32), 15], [array([0.5623083], dtype=float32), 15], [array([0.45976496], dtype=float32), 15], [array([0.49440718], dtype=float32), 15], [array([0.34581995], dtype=float32), 15], [array([0.23454809], dtype=float32), 15], [array([0.34099674], dtype=float32), 15], [array([0.5770998], dtype=float32), 15], [array([1.3572178], dtype=float32), 15], [array([1.7135525], dtype=float32), 15], [array([0.04809475], dtype=float32), 15], [array([0.9948945], dtype=float32), 15], [array([0.63094616], dtype=float32), 15], [array([0.35665417], dtype=float32), 15], [array([0.0505271], dtype=float32), 15], [array([0.36614275], dtype=float32), 15], [array([1.2772796], dtype=float32), 15], [array([2.11068], dtype=float32), 15], [array([1.1784897], dtype=float32), 15], [array([1.0391364], dtype=float32), 16], [array([0.92434406], dtype=float32), 16], [array([0.9307585], dtype=float32), 16], [array([2.464508], dtype=float32), 16], [array([2.071828], dtype=float32), 16], [array([0.3831544], dtype=float32), 16], [array([2.1940982], dtype=float32), 16], [array([0.5802436], dtype=float32), 16], [array([0.36674976], dtype=float32), 16], [array([0.03759623], dtype=float32), 16], [array([1.7667313], dtype=float32), 16], [array([0.12254286], dtype=float32), 16], [array([0.3863778], dtype=float32), 16], [array([2.210705], dtype=float32), 16], [array([0.92501736], dtype=float32), 16], [array([1.5823059], dtype=float32), 16], [array([0.28103638], dtype=float32), 16], [array([1.5420294], dtype=float32), 16], [array([0.39335823], dtype=float32), 16], [array([3.2153707], dtype=float32), 16], [array([0.90259933], dtype=float32), 16], [array([1.2146003], dtype=float32), 16], [array([1.1105571], dtype=float32), 16], [array([0.6110587], dtype=float32), 16], [array([1.9046192], dtype=float32), 16], [array([0.63971424], dtype=float32), 16], [array([2.4120712], dtype=float32), 16], [array([0.4314003], dtype=float32), 16], [array([0.83448505], dtype=float32), 16], [array([1.1321621], dtype=float32), 16], [array([0.01549006], dtype=float32), 16], [array([1.655901], dtype=float32), 16], [array([0.44890308], dtype=float32), 16], [array([1.3398414], dtype=float32), 16], [array([0.80924296], dtype=float32), 16], [array([0.37736034], dtype=float32), 16], [array([1.1978893], dtype=float32), 16], [array([0.29306316], dtype=float32), 16], [array([1.7845662], dtype=float32), 16], [array([2.8911152], dtype=float32), 16], [array([3.3243465], dtype=float32), 16], [array([0.08321428], dtype=float32), 16], [array([1.3440542], dtype=float32), 16], [array([1.6210265], dtype=float32), 16], [array([1.533359], dtype=float32), 16], [array([0.5097575], dtype=float32), 16], [array([3.2735186], dtype=float32), 16], [array([0.9814682], dtype=float32), 16], [array([2.4442806], dtype=float32), 16], [array([2.4587388], dtype=float32), 16], [array([0.13207293], dtype=float32), 16], [array([0.7272968], dtype=float32), 16], [array([0.05072689], dtype=float32), 16], [array([0.14663744], dtype=float32), 16], [array([1.819881], dtype=float32), 16], [array([0.8675418], dtype=float32), 16], [array([0.24244833], dtype=float32), 16], [array([1.7014875], dtype=float32), 16], [array([0.1857872], dtype=float32), 16], [array([0.2075448], dtype=float32), 16], [array([0.62267685], dtype=float32), 16], [array([1.0387521], dtype=float32), 16], [array([0.18967104], dtype=float32), 16], [array([1.071228], dtype=float32), 16], [array([0.99252796], dtype=float32) ...
# Mean deviation for each placeholder value:
# Placeholder value 15: 0.7268633842468262
# Placeholder value 16: 1.0704818964004517
# Placeholder value 17: 1.47052001953125
# Placeholder value 18: 1.8993371725082397
# Placeholder value 19: 2.247554063796997
# Placeholder value 20: 2.5961825847625732
# Placeholder value 21: 2.9409685134887695
# Placeholder value 22: 3.2182674407958984
# Placeholder value 23: 3.5302021503448486
# Placeholder value 24: 3.875049352645874
# 0.0073816944
# 10.580621
# 10.357245

# %% [markdown]
# About 20 absSum of the numbers in a expression is the same mean deviation as 4 numbers instead of 3.

# %% [markdown]
# benchmark for a model has to scale with:
# *   MSE inside number range
# *   MSE outside number range
# *   MSE for longer expressions
#
# the results of this FNN will be used as baseline.
#
#
# MSE inside number range: 1457 expressions in x_test: 0.007094925
#
# MSE outside number range: Placeholder value 22: 9.788455
#
# Deviation for longer expressions: Deviation for expressions with 4 numbers: 9.551048
#
#
# all 3 Values will be weighed equally as important.

# %%
model_config = model.get_config()
print(model_config)
import pprint
pprint.pprint(model_config)
# Out:
# {'name': 'sequential', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'layers': [{'module': 'keras.layers', 'class_name': 'InputLayer', 'config': {'batch_shape': (None, 15), 'dtype': 'float32', 'sparse': False, 'name': 'input_layer'}, 'registered_name': None}, {'module': 'keras.layers', 'class_name': 'Dense', 'config': {'name': 'dense', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'units': 30, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': None, 'bias_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}, 'registered_name': None, 'build_config': {'input_shape': (None, 15)}}, {'module': 'keras.layers', 'class_name': 'PReLU', 'config': {'name': 'p_re_lu', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'alpha_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'alpha_regularizer': None, 'alpha_constraint': None, 'shared_axes': None}, 'registered_name': None, 'build_config': {'input_shape': (None, 30)}}, {'module': 'keras.layers', 'class_name': 'Dense', 'config': {'name': 'dense_1', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'units': 30, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': None, 'bias_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}, 'registered_name': None, 'build_config': {'input_shape': (None, 30)}}, {'module': 'keras.layers', 'class_name': 'PReLU', 'config': {'name': 'p_re_lu_1', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'alpha_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'alpha_regularizer': None, 'alpha_constraint': None, 'shared_axes': None}, 'registered_name': None, 'build_config': {'input_shape': (None, 30)}}, {'module': 'keras.layers', 'class_name': 'Dense', 'config': {'name': 'dense_2', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'units': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': None, 'bias_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}, 'registered_name': None, 'build_config': {'input_shape': (None, 30)}}], 'build_input_shape': (None, 15)}
# {'build_input_shape': (None, 15),
#  'dtype': {'class_name': 'DTypePolicy',
#            'config': {'name': 'float32'},
#            'module': 'keras',
#            'registered_name': None},
#  'layers': [{'class_name': 'InputLayer',
#              'config': {'batch_shape': (None, 15),
#                         'dtype': 'float32',
#                         'name': 'input_layer',
#                         'sparse': False},
#              'module': 'keras.layers',
#              'registered_name': None},
#             {'build_config': {'input_shape': (None, 15)},
#              'class_name': 'Dense',
#              'config': {'activation': 'linear',
#                         'bias_constraint': None,
#                         'bias_initializer': {'class_name': 'Zeros',
#                                              'config': {},
#                                              'module': 'keras.initializers',
#                                              'registered_name': None},
#                         'bias_regularizer': None,
#                         'dtype': {'class_name': 'DTypePolicy',
#                                   'config': {'name': 'float32'},
#                                   'module': 'keras',
#                                   'registered_name': None},
#                         'kernel_constraint': None,
#                         'kernel_initializer': {'class_name': 'GlorotUniform',
#                                                'config': {'seed': None},
#                                                'module': 'keras.initializers',
#                                                'registered_name': None},
#                         'kernel_regularizer': None,
#                         'name': 'dense',
#                         'trainable': True,
#                         'units': 30,
#                         'use_bias': True},
#              'module': 'keras.layers',
#              'registered_name': None},
#             {'build_config': {'input_shape': (None, 30)},
#              'class_name': 'PReLU',
#              'config': {'alpha_constraint': None,
#                         'alpha_initializer': {'class_name': 'Zeros',
#                                               'config': {},
#                                               'module': 'keras.initializers',
#                                               'registered_name': None},
#                         'alpha_regularizer': None,
#                         'dtype': {'class_name': 'DTypePolicy',
#                                   'config': {'name': 'float32'},
#                                   'module': 'keras',
#                                   'registered_name': None},
#                         'name': 'p_re_lu',
#                         'shared_axes': None,
#                         'trainable': True},
#              'module': 'keras.layers',
#              'registered_name': None},
#             {'build_config': {'input_shape': (None, 30)},
#              'class_name': 'Dense',
#              'config': {'activation': 'linear',
#                         'bias_constraint': None,
#                         'bias_initializer': {'class_name': 'Zeros',
#                                              'config': {},
#                                              'module': 'keras.initializers',
#                                              'registered_name': None},
#                         'bias_regularizer': None,
#                         'dtype': {'class_name': 'DTypePolicy',
#                                   'config': {'name': 'float32'},
#                                   'module': 'keras',
#                                   'registered_name': None},
#                         'kernel_constraint': None,
#                         'kernel_initializer': {'class_name': 'GlorotUniform',
#                                                'config': {'seed': None},
#                                                'module': 'keras.initializers',
#                                                'registered_name': None},
#                         'kernel_regularizer': None,
#                         'name': 'dense_1',
#                         'trainable': True,
#                         'units': 30,
#                         'use_bias': True},
#              'module': 'keras.layers',
#              'registered_name': None},
#             {'build_config': {'input_shape': (None, 30)},
#              'class_name': 'PReLU',
#              'config': {'alpha_constraint': None,
#                         'alpha_initializer': {'class_name': 'Zeros',
#                                               'config': {},
#                                               'module': 'keras.initializers',
#                                               'registered_name': None},
#                         'alpha_regularizer': None,
#                         'dtype': {'class_name': 'DTypePolicy',
#                                   'config': {'name': 'float32'},
#                                   'module': 'keras',
#                                   'registered_name': None},
#                         'name': 'p_re_lu_1',
#                         'shared_axes': None,
#                         'trainable': True},
#              'module': 'keras.layers',
#              'registered_name': None},
#             {'build_config': {'input_shape': (None, 30)},
#              'class_name': 'Dense',
#              'config': {'activation': 'linear',
#                         'bias_constraint': None,
#                         'bias_initializer': {'class_name': 'Zeros',
#                                              'config': {},
#                                              'module': 'keras.initializers',
#                                              'registered_name': None},
#                         'bias_regularizer': None,
#                         'dtype': {'class_name': 'DTypePolicy',
#                                   'config': {'name': 'float32'},
#                                   'module': 'keras',
#                                   'registered_name': None},
#                         'kernel_constraint': None,
#                         'kernel_initializer': {'class_name': 'GlorotUniform',
#                                                'config': {'seed': None},
#                                                'module': 'keras.initializers',
#                                                'registered_name': None},
#                         'kernel_regularizer': None,
#                         'name': 'dense_2',
#                         'trainable': True,
#                         'units': 1,
#                         'use_bias': True},
#              'module': 'keras.layers',
#              'registered_name': None}],
#  'name': 'sequential',
#  'trainable': True}

# %%
base_layers = model_config['layers']
input_layer = base_layers[0]
output_layer = base_layers[-1]
hidden_layer = [base_layers[1], base_layers[2]]
base_layers[1]
# Out:
# {'module': 'keras.layers',
#  'class_name': 'Dense',
#  'config': {'name': 'dense',
#   'trainable': True,
#   'dtype': {'module': 'keras',
#    'class_name': 'DTypePolicy',
#    'config': {'name': 'float32'},
#    'registered_name': None},
#   'units': 30,
#   'activation': 'linear',
#   'use_bias': True,
#   'kernel_initializer': {'module': 'keras.initializers',
#    'class_name': 'GlorotUniform',
#    'config': {'seed': None},
#    'registered_name': None},
#   'bias_initializer': {'module': 'keras.initializers',
#    'class_name': 'Zeros',
#    'config': {},
#    'registered_name': None},
#   'kernel_regularizer': None,
#   'bias_regularizer': None,
#   'kernel_constraint': None,
#   'bias_constraint': None},
#  'registered_name': None,
#  'build_config': {'input_shape': (None, 15)}}

# %%
def build_model(input_shape, num_hidden_layers, units_per_layer):
  lil_model = keras.Sequential()
  lil_model.add(keras.Input(shape=input_shape))
  lil_model.add(layers.Flatten())
  for i in range(num_hidden_layers):
    lil_model.add(layers.Dense(units_per_layer, kernel_regularizer=regularizers.l2(0.01))),
    lil_model.add(PReLU())
  lil_model.add(layers.Dense(1, activation='linear'))
  lil_model.compile(optimizer="adam", loss="mse", metrics=["mae", "mse"])
  return lil_model

# %%
diff_x_train, diff_x_val, diff_y_train, diff_y_val = \
    train_test_split(diff_x, diff_y, train_size=0.75)
diff_x_train, diff_x_val, diff_y_train, diff_y_val = \
    np.array(diff_x_train), np.array(diff_x_val), np.array(diff_y_train), np.array(diff_y_val)

# %%
different_models = []
max_layers = 5
min_Neurons = 5
max_Neurons = 55
small_n_bootstrap = 5
input_shape = diff_x[0].shape
Neuron_step = 5

print(input_shape)


diff_predictions = []
diff_out_predictions = []
diff_long_predictions = []

counter = 0
max_counter = ((max_Neurons-min_Neurons)/Neuron_step + 1)*(max_layers+1)*small_n_bootstrap
for i in range(max_layers+1):
  for j in range(min_Neurons, max_Neurons+1,5):
    for p in range(small_n_bootstrap):
      sample_indices = np.random.choice(len(diff_x_train), size=len(diff_x_train), replace=True)
      x_train_bootstrap = diff_x_train[sample_indices]
      y_train_bootstrap = np.array(diff_y_train)[sample_indices]
      bootstrap_train_dataset = tf.data.Dataset.from_tensor_slices((x_train_bootstrap, y_train_bootstrap)).batch(32)

      this_model = build_model(input_shape, i, j)
      different_models.append(this_model)

      this_model.fit(
          bootstrap_train_dataset,
          epochs=50,  # Reduced epochs for quicker example, adjust as needed
          verbose=0, # Suppress output
          callbacks=[early_stopping]
      )
      diff_predictions.append(this_model.predict(diff_x_test))
      diff_out_predictions.append(this_model.predict(diff_out_x_test))
      diff_long_predictions.append(this_model.predict(diff_long_x_test))
      counter += 1
      print(f"counter: {counter} / {max_counter}")
      print(f"percentage: {counter/max_counter*100:.2f}%")

diff_predictions = np.array(diff_predictions)
diff_out_predictions = np.array(diff_out_predictions)
diff_long_predictions = np.array(diff_long_predictions)

print(len(different_models))
# Out:
# (15, 2)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# counter: 1 / 330.0
# percentage: 0.30%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 2 / 330.0
# percentage: 0.61%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 3 / 330.0
# percentage: 0.91%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 4 / 330.0
# percentage: 1.21%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 5 / 330.0
# percentage: 1.52%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 6 / 330.0
# percentage: 1.82%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 7 / 330.0
# percentage: 2.12%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 8 / 330.0
# percentage: 2.42%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# counter: 9 / 330.0
# percentage: 2.73%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 10 / 330.0
# percentage: 3.03%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 11 / 330.0
# percentage: 3.33%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# counter: 12 / 330.0
# percentage: 3.64%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 13 / 330.0
# percentage: 3.94%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 14 / 330.0
# percentage: 4.24%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 15 / 330.0
# percentage: 4.55%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 16 / 330.0
# percentage: 4.85%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# counter: 17 / 330.0
# percentage: 5.15%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 18 / 330.0
# percentage: 5.45%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 19 / 330.0
# percentage: 5.76%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 20 / 330.0
# percentage: 6.06%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 21 / 330.0
# percentage: 6.36%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 22 / 330.0
# percentage: 6.67%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 23 / 330.0
# percentage: 6.97%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# counter: 24 / 330.0
# percentage: 7.27%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 25 / 330.0
# percentage: 7.58%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 26 / 330.0
# percentage: 7.88%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 27 / 330.0
# percentage: 8.18%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 28 / 330.0
# percentage: 8.48%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 29 / 330.0
# percentage: 8.79%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 30 / 330.0
# percentage: 9.09%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 31 / 330.0
# percentage: 9.39%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 32 / 330.0
# percentage: 9.70%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 33 / 330.0
# percentage: 10.00%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 34 / 330.0
# percentage: 10.30%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 35 / 330.0
# percentage: 10.61%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 36 / 330.0
# percentage: 10.91%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 37 / 330.0
# percentage: 11.21%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 38 / 330.0
# percentage: 11.52%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 39 / 330.0
# percentage: 11.82%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 40 / 330.0
# percentage: 12.12%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 41 / 330.0
# percentage: 12.42%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 42 / 330.0
# percentage: 12.73%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 43 / 330.0
# percentage: 13.03%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 44 / 330.0
# percentage: 13.33%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 45 / 330.0
# percentage: 13.64%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 46 / 330.0
# percentage: 13.94%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 47 / 330.0
# percentage: 14.24%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 48 / 330.0
# percentage: 14.55%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 49 / 330.0
# percentage: 14.85%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 50 / 330.0
# percentage: 15.15%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 51 / 330.0
# percentage: 15.45%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 52 / 330.0
# percentage: 15.76%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 53 / 330.0
# percentage: 16.06%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 54 / 330.0
# percentage: 16.36%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 55 / 330.0
# percentage: 16.67%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 56 / 330.0
# percentage: 16.97%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 57 / 330.0
# percentage: 17.27%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 58 / 330.0
# percentage: 17.58%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 59 / 330.0
# percentage: 17.88%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 60 / 330.0
# percentage: 18.18%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 61 / 330.0
# percentage: 18.48%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 62 / 330.0
# percentage: 18.79%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# counter: 63 / 330.0
# percentage: 19.09%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 64 / 330.0
# percentage: 19.39%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 65 / 330.0
# percentage: 19.70%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# counter: 66 / 330.0
# percentage: 20.00%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 67 / 330.0
# percentage: 20.30%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 68 / 330.0
# percentage: 20.61%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# counter: 69 / 330.0
# percentage: 20.91%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 70 / 330.0
# percentage: 21.21%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 71 / 330.0
# percentage: 21.52%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 72 / 330.0
# percentage: 21.82%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 73 / 330.0
# percentage: 22.12%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 74 / 330.0
# percentage: 22.42%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# counter: 75 / 330.0
# percentage: 22.73%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 76 / 330.0
# percentage: 23.03%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 77 / 330.0
# percentage: 23.33%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 78 / 330.0
# percentage: 23.64%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 79 / 330.0
# percentage: 23.94%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 80 / 330.0
# percentage: 24.24%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 81 / 330.0
# percentage: 24.55%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# counter: 82 / 330.0
# percentage: 24.85%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 83 / 330.0
# percentage: 25.15%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 84 / 330.0
# percentage: 25.45%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 85 / 330.0
# percentage: 25.76%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 86 / 330.0
# percentage: 26.06%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 87 / 330.0
# percentage: 26.36%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 88 / 330.0
# percentage: 26.67%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# counter: 89 / 330.0
# percentage: 26.97%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 90 / 330.0
# percentage: 27.27%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 91 / 330.0
# percentage: 27.58%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 92 / 330.0
# percentage: 27.88%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 93 / 330.0
# percentage: 28.18%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 94 / 330.0
# percentage: 28.48%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 95 / 330.0
# percentage: 28.79%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 96 / 330.0
# percentage: 29.09%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 97 / 330.0
# percentage: 29.39%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 98 / 330.0
# percentage: 29.70%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 99 / 330.0
# percentage: 30.00%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 100 / 330.0
# percentage: 30.30%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 101 / 330.0
# percentage: 30.61%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 102 / 330.0
# percentage: 30.91%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 103 / 330.0
# percentage: 31.21%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 104 / 330.0
# percentage: 31.52%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 105 / 330.0
# percentage: 31.82%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 106 / 330.0
# percentage: 32.12%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 107 / 330.0
# percentage: 32.42%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 108 / 330.0
# percentage: 32.73%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 109 / 330.0
# percentage: 33.03%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 110 / 330.0
# percentage: 33.33%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 111 / 330.0
# percentage: 33.64%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 112 / 330.0
# percentage: 33.94%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 113 / 330.0
# percentage: 34.24%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 114 / 330.0
# percentage: 34.55%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 115 / 330.0
# percentage: 34.85%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 116 / 330.0
# percentage: 35.15%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 117 / 330.0
# percentage: 35.45%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 118 / 330.0
# percentage: 35.76%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 119 / 330.0
# percentage: 36.06%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 120 / 330.0
# percentage: 36.36%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 121 / 330.0
# percentage: 36.67%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 122 / 330.0
# percentage: 36.97%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 123 / 330.0
# percentage: 37.27%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 124 / 330.0
# percentage: 37.58%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 125 / 330.0
# percentage: 37.88%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 126 / 330.0
# percentage: 38.18%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 127 / 330.0
# percentage: 38.48%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 128 / 330.0
# percentage: 38.79%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 129 / 330.0
# percentage: 39.09%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# counter: 130 / 330.0
# percentage: 39.39%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 131 / 330.0
# percentage: 39.70%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 132 / 330.0
# percentage: 40.00%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 133 / 330.0
# percentage: 40.30%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 134 / 330.0
# percentage: 40.61%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 135 / 330.0
# percentage: 40.91%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 136 / 330.0
# percentage: 41.21%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 137 / 330.0
# percentage: 41.52%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 138 / 330.0
# percentage: 41.82%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 139 / 330.0
# percentage: 42.12%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 140 / 330.0
# percentage: 42.42%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 141 / 330.0
# percentage: 42.73%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 142 / 330.0
# percentage: 43.03%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 143 / 330.0
# percentage: 43.33%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 144 / 330.0
# percentage: 43.64%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 145 / 330.0
# percentage: 43.94%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 146 / 330.0
# percentage: 44.24%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 147 / 330.0
# percentage: 44.55%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 148 / 330.0
# percentage: 44.85%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 149 / 330.0
# percentage: 45.15%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 150 / 330.0
# percentage: 45.45%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 151 / 330.0
# percentage: 45.76%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 152 / 330.0
# percentage: 46.06%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 153 / 330.0
# percentage: 46.36%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 154 / 330.0
# percentage: 46.67%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 155 / 330.0
# percentage: 46.97%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 156 / 330.0
# percentage: 47.27%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 157 / 330.0
# percentage: 47.58%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 158 / 330.0
# percentage: 47.88%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 159 / 330.0
# percentage: 48.18%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 160 / 330.0
# percentage: 48.48%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 161 / 330.0
# percentage: 48.79%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 162 / 330.0
# percentage: 49.09%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 163 / 330.0
# percentage: 49.39%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 164 / 330.0
# percentage: 49.70%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 165 / 330.0
# percentage: 50.00%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 166 / 330.0
# percentage: 50.30%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 167 / 330.0
# percentage: 50.61%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 168 / 330.0
# percentage: 50.91%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 169 / 330.0
# percentage: 51.21%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 170 / 330.0
# percentage: 51.52%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 171 / 330.0
# percentage: 51.82%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 172 / 330.0
# percentage: 52.12%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 173 / 330.0
# percentage: 52.42%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 174 / 330.0
# percentage: 52.73%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 175 / 330.0
# percentage: 53.03%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 176 / 330.0
# percentage: 53.33%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 177 / 330.0
# percentage: 53.64%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 178 / 330.0
# percentage: 53.94%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 179 / 330.0
# percentage: 54.24%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 180 / 330.0
# percentage: 54.55%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 181 / 330.0
# percentage: 54.85%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 182 / 330.0
# percentage: 55.15%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 183 / 330.0
# percentage: 55.45%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 184 / 330.0
# percentage: 55.76%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 185 / 330.0
# percentage: 56.06%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 186 / 330.0
# percentage: 56.36%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 187 / 330.0
# percentage: 56.67%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 188 / 330.0
# percentage: 56.97%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 189 / 330.0
# percentage: 57.27%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 190 / 330.0
# percentage: 57.58%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 191 / 330.0
# percentage: 57.88%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 192 / 330.0
# percentage: 58.18%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 193 / 330.0
# percentage: 58.48%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 194 / 330.0
# percentage: 58.79%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# counter: 195 / 330.0
# percentage: 59.09%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 196 / 330.0
# percentage: 59.39%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 197 / 330.0
# percentage: 59.70%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 198 / 330.0
# percentage: 60.00%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 199 / 330.0
# percentage: 60.30%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 200 / 330.0
# percentage: 60.61%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 201 / 330.0
# percentage: 60.91%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 202 / 330.0
# percentage: 61.21%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 203 / 330.0
# percentage: 61.52%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 204 / 330.0
# percentage: 61.82%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 205 / 330.0
# percentage: 62.12%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 206 / 330.0
# percentage: 62.42%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 207 / 330.0
# percentage: 62.73%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 208 / 330.0
# percentage: 63.03%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 209 / 330.0
# percentage: 63.33%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 210 / 330.0
# percentage: 63.64%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 211 / 330.0
# percentage: 63.94%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 212 / 330.0
# percentage: 64.24%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 213 / 330.0
# percentage: 64.55%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 214 / 330.0
# percentage: 64.85%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 215 / 330.0
# percentage: 65.15%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 216 / 330.0
# percentage: 65.45%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 217 / 330.0
# percentage: 65.76%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 218 / 330.0
# percentage: 66.06%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 219 / 330.0
# percentage: 66.36%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 220 / 330.0
# percentage: 66.67%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 221 / 330.0
# percentage: 66.97%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 222 / 330.0
# percentage: 67.27%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 223 / 330.0
# percentage: 67.58%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 224 / 330.0
# percentage: 67.88%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 225 / 330.0
# percentage: 68.18%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 226 / 330.0
# percentage: 68.48%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 227 / 330.0
# percentage: 68.79%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# counter: 228 / 330.0
# percentage: 69.09%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 229 / 330.0
# percentage: 69.39%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 230 / 330.0
# percentage: 69.70%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 231 / 330.0
# percentage: 70.00%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 232 / 330.0
# percentage: 70.30%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 233 / 330.0
# percentage: 70.61%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 234 / 330.0
# percentage: 70.91%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 235 / 330.0
# percentage: 71.21%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 236 / 330.0
# percentage: 71.52%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 237 / 330.0
# percentage: 71.82%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 238 / 330.0
# percentage: 72.12%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 239 / 330.0
# percentage: 72.42%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 240 / 330.0
# percentage: 72.73%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 241 / 330.0
# percentage: 73.03%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 242 / 330.0
# percentage: 73.33%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 243 / 330.0
# percentage: 73.64%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 244 / 330.0
# percentage: 73.94%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 245 / 330.0
# percentage: 74.24%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 246 / 330.0
# percentage: 74.55%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 247 / 330.0
# percentage: 74.85%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 248 / 330.0
# percentage: 75.15%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 249 / 330.0
# percentage: 75.45%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 250 / 330.0
# percentage: 75.76%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 251 / 330.0
# percentage: 76.06%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 252 / 330.0
# percentage: 76.36%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 253 / 330.0
# percentage: 76.67%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 254 / 330.0
# percentage: 76.97%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 255 / 330.0
# percentage: 77.27%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 256 / 330.0
# percentage: 77.58%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 257 / 330.0
# percentage: 77.88%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 258 / 330.0
# percentage: 78.18%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 259 / 330.0
# percentage: 78.48%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 260 / 330.0
# percentage: 78.79%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# counter: 261 / 330.0
# percentage: 79.09%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 262 / 330.0
# percentage: 79.39%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 263 / 330.0
# percentage: 79.70%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 264 / 330.0
# percentage: 80.00%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 265 / 330.0
# percentage: 80.30%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 266 / 330.0
# percentage: 80.61%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 267 / 330.0
# percentage: 80.91%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 268 / 330.0
# percentage: 81.21%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 269 / 330.0
# percentage: 81.52%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 270 / 330.0
# percentage: 81.82%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 271 / 330.0
# percentage: 82.12%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# counter: 272 / 330.0
# percentage: 82.42%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 273 / 330.0
# percentage: 82.73%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 274 / 330.0
# percentage: 83.03%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 275 / 330.0
# percentage: 83.33%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 276 / 330.0
# percentage: 83.64%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 277 / 330.0
# percentage: 83.94%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 278 / 330.0
# percentage: 84.24%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 279 / 330.0
# percentage: 84.55%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 280 / 330.0
# percentage: 84.85%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 281 / 330.0
# percentage: 85.15%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 282 / 330.0
# percentage: 85.45%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 283 / 330.0
# percentage: 85.76%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# counter: 284 / 330.0
# percentage: 86.06%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# counter: 285 / 330.0
# percentage: 86.36%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 286 / 330.0
# percentage: 86.67%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# counter: 287 / 330.0
# percentage: 86.97%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# counter: 288 / 330.0
# percentage: 87.27%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# counter: 289 / 330.0
# percentage: 87.58%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 290 / 330.0
# percentage: 87.88%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# counter: 291 / 330.0
# percentage: 88.18%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 292 / 330.0
# percentage: 88.48%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 293 / 330.0
# percentage: 88.79%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 294 / 330.0
# percentage: 89.09%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 295 / 330.0
# percentage: 89.39%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 296 / 330.0
# percentage: 89.70%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 297 / 330.0
# percentage: 90.00%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 298 / 330.0
# percentage: 90.30%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 299 / 330.0
# percentage: 90.61%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 300 / 330.0
# percentage: 90.91%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 301 / 330.0
# percentage: 91.21%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 302 / 330.0
# percentage: 91.52%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# counter: 303 / 330.0
# percentage: 91.82%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 304 / 330.0
# percentage: 92.12%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 305 / 330.0
# percentage: 92.42%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# counter: 306 / 330.0
# percentage: 92.73%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# counter: 307 / 330.0
# percentage: 93.03%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 308 / 330.0
# percentage: 93.33%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 309 / 330.0
# percentage: 93.64%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 310 / 330.0
# percentage: 93.94%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 311 / 330.0
# percentage: 94.24%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 312 / 330.0
# percentage: 94.55%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 313 / 330.0
# percentage: 94.85%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 314 / 330.0
# percentage: 95.15%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 315 / 330.0
# percentage: 95.45%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 316 / 330.0
# percentage: 95.76%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 317 / 330.0
# percentage: 96.06%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 318 / 330.0
# percentage: 96.36%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 319 / 330.0
# percentage: 96.67%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 320 / 330.0
# percentage: 96.97%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# counter: 321 / 330.0
# percentage: 97.27%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 322 / 330.0
# percentage: 97.58%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 323 / 330.0
# percentage: 97.88%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 324 / 330.0
# percentage: 98.18%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 325 / 330.0
# percentage: 98.48%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 326 / 330.0
# percentage: 98.79%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# counter: 327 / 330.0
# percentage: 99.09%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# counter: 328 / 330.0
# percentage: 99.39%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 329 / 330.0
# percentage: 99.70%
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# counter: 330 / 330.0
# percentage: 100.00%
# 330

# %%
diff_predictions.shape
# Out:
# (330, 1457, 1)

# %%
diff_meanPredictions = []
num_models = diff_predictions.shape[0] // small_n_bootstrap # 66
print(num_models)
num_test_samples = diff_predictions.shape[1] # 1457
print(num_test_samples)

for model_index in range(num_models):
  model_predictions = diff_predictions[model_index * small_n_bootstrap : (model_index + 1) * small_n_bootstrap]
  # model_predictions now contains the 5 prediction sets for this specific model
  mean_prediction_for_model = np.mean(model_predictions, axis=0) # Average across the bootstrap axis
  diff_meanPredictions.append(mean_prediction_for_model)

diff_meanPredictions = np.array(diff_meanPredictions)
# diff_meanPredictions should now have shape (66, 1457, 1)
print(diff_meanPredictions.shape)
# Out:
# 66
# 1457
# (66, 1457, 1)

# %%
diff_deviation = []
#diff_out_deviation = []

for j in range(diff_meanPredictions.shape[0]):
  calc = 0
  for i in range(len(y_test)):
    calc += abs(y_test[i]-diff_meanPredictions[j][i])
  diff_deviation.append(calc/len(y_test))
print(diff_deviation)

'''
for i in range(len(out_y_test)):
  out_deviation.append(abs(out_y_test[i]-out_meanPredictions[i]))
print(out_deviation)
out_avDeviation = np.mean(out_deviation)
print(np.mean(out_deviation))
'''
# Out:
# [array([3.3319602], dtype=float32), array([3.332797], dtype=float32), array([3.3367424], dtype=float32), array([3.3375106], dtype=float32), array([3.3376245], dtype=float32), array([3.3329566], dtype=float32), array([3.335464], dtype=float32), array([3.333034], dtype=float32), array([3.335366], dtype=float32), array([3.340086], dtype=float32), array([3.3338008], dtype=float32), array([0.82027715], dtype=float32), array([0.31416428], dtype=float32), array([0.27597472], dtype=float32), array([0.2278199], dtype=float32), array([0.19761814], dtype=float32), array([0.19953491], dtype=float32), array([0.15491016], dtype=float32), array([0.15021117], dtype=float32), array([0.14278269], dtype=float32), array([0.1587454], dtype=float32), array([0.13748029], dtype=float32), array([0.38196546], dtype=float32), array([0.1010857], dtype=float32), array([0.10771385], dtype=float32), array([0.13712047], dtype=float32), array([0.10850938], dtype=float32), array([0.11502956], dtype=float32), array([0.11536271], dtype=float32), array([0.11847164], dtype=float32), array([0.12431059], dtype=float32), array([0.12545493], dtype=float32), array([0.10584927], dtype=float32), array([0.5028388], dtype=float32), array([0.10305285], dtype=float32), array([0.10087302], dtype=float32), array([0.12037638], dtype=float32), array([0.10267193], dtype=float32), array([0.11964142], dtype=float32), array([0.13312489], dtype=float32), array([0.1204228], dtype=float32), array([0.11315814], dtype=float32), array([0.1473598], dtype=float32), array([0.12056988], dtype=float32), array([0.03393004], dtype=float32), array([0.11248131], dtype=float32), array([0.13942014], dtype=float32), array([0.12800649], dtype=float32), array([0.1475611], dtype=float32), array([0.12951055], dtype=float32), array([0.11398221], dtype=float32), array([0.1261267], dtype=float32), array([0.15320982], dtype=float32), array([0.1320054], dtype=float32), array([0.12700099], dtype=float32), array([0.08459224], dtype=float32), array([0.09548686], dtype=float32), array([0.1302786], dtype=float32), array([0.13730472], dtype=float32), array([0.14983806], dtype=float32), array([0.13108534], dtype=float32), array([0.12527516], dtype=float32), array([0.12681535], dtype=float32), array([0.12414978], dtype=float32), array([0.12699881], dtype=float32), array([0.14567836], dtype=float32)]
# '\nfor i in range(len(out_y_test)):\n  out_deviation.append(abs(out_y_test[i]-out_meanPredictions[i]))\nprint(out_deviation)\nout_avDeviation = np.mean(out_deviation)\nprint(np.mean(out_deviation))\n'

# %%
# prompt: plot diff_deviation on a graph

plt.figure(figsize=(10, 6))
plt.plot(diff_deviation)
plt.xlabel("Model Index")
plt.ylabel("Mean Absolute Deviation on Test Set")
plt.title("Mean Absolute Deviation for Different Models")
plt.show()

# %%
diff_out_meanPredictions = []
num_models = diff_out_predictions.shape[0] // small_n_bootstrap # 36
num_test_samples = diff_out_predictions.shape[1] # 1457

for model_index in range(num_models):
  model_predictions = diff_out_predictions[model_index * small_n_bootstrap : (model_index + 1) * small_n_bootstrap]
  # model_predictions now contains the 5 prediction sets for this specific model
  mean_prediction_for_model = np.mean(model_predictions, axis=0) # Average across the bootstrap axis
  diff_out_meanPredictions.append(mean_prediction_for_model)

diff_out_meanPredictions = np.array(diff_out_meanPredictions)
# diff_meanPredictions should now have shape (36, 1457)
print(diff_out_meanPredictions.shape)
# Out:
# (66, 2048, 1)

# %%
diff_out_deviation = []
#diff_out_deviation = []
indices_with_placeholder_22 = [i for i, val in enumerate(placeholder) if val == 22]
print(indices_with_placeholder_22)
for j in range(diff_out_meanPredictions.shape[0]):
  calc = 0
  for i in indices_with_placeholder_22:
    calc += abs(out_y_test[i]-diff_out_meanPredictions[j][i])
  diff_out_deviation.append(calc/len(indices_with_placeholder_22))
print(diff_out_deviation)

plt.figure(figsize=(10, 6))
plt.plot(diff_out_deviation[6:])
plt.xlabel("Model Index")
plt.ylabel("Mean Absolute Deviation for Placeholder 22")
plt.title("Mean Absolute Deviation for Placeholder 22 for Different Models")
plt.show()
# Out:
# [5, 6, 27, 54, 69, 85, 91, 95, 96, 106, 108, 118, 132, 161, 176, 178, 191, 195, 196, 200, 209, 211, 219, 235, 245, 261, 275, 283, 291, 294, 311, 312, 330, 387, 399, 410, 421, 427, 434, 436, 437, 440, 444, 455, 474, 479, 481, 487, 523, 540, 558, 580, 603, 643, 650, 652, 653, 660, 668, 680, 702, 709, 712, 735, 744, 752, 773, 777, 790, 804, 805, 822, 850, 852, 853, 855, 896, 909, 916, 923, 926, 929, 930, 931, 950, 957, 966, 985, 1007, 1013, 1022, 1028, 1029, 1032, 1052, 1076, 1083, 1093, 1097, 1109, 1141, 1143, 1162, 1168, 1176, 1184, 1196, 1203, 1221, 1234, 1243, 1277, 1278, 1285, 1300, 1307, 1310, 1333, 1336, 1338, 1341, 1348, 1359, 1378, 1380, 1381, 1382, 1399, 1404, 1415, 1422, 1424, 1429, 1454, 1465, 1470, 1476, 1487, 1524, 1525, 1534, 1537, 1551, 1554, 1566, 1616, 1632, 1633, 1646, 1648, 1656, 1661, 1693, 1701, 1719, 1725, 1734, 1748, 1764, 1774, 1775, 1792, 1806, 1830, 1832, 1849, 1858, 1859, 1876, 1879, 1880, 1901, 1903, 1926, 1927, 1928, 1934, 1941, 1943, 1947, 1950, 1952, 1965, 1977, 1980, 2003, 2007, 2009, 2024, 2029, 2039, 2040]
# [array([7.9036326], dtype=float32), array([7.904951], dtype=float32), array([7.9165597], dtype=float32), array([7.9168906], dtype=float32), array([7.9417186], dtype=float32), array([7.9141707], dtype=float32), array([7.9300733], dtype=float32), array([7.912743], dtype=float32), array([7.9237995], dtype=float32), array([7.9316697], dtype=float32), array([7.9279504], dtype=float32), array([5.1676745], dtype=float32), array([4.223927], dtype=float32), array([3.9731102], dtype=float32), array([3.9143715], dtype=float32), array([3.8331842], dtype=float32), array([3.7732198], dtype=float32), array([3.7164907], dtype=float32), array([3.7583787], dtype=float32), array([3.6986268], dtype=float32), array([3.6679008], dtype=float32), array([3.6996136], dtype=float32), array([3.9983075], dtype=float32), array([3.697501], dtype=float32), array([3.6657116], dtype=float32), array([3.806097], dtype=float32), array([3.745331], dtype=float32), array([3.736148], dtype=float32), array([3.7148082], dtype=float32), array([3.7419598], dtype=float32), array([3.71523], dtype=float32), array([3.6765692], dtype=float32), array([3.5942256], dtype=float32), array([4.69203], dtype=float32), array([3.7497594], dtype=float32), array([4.0843306], dtype=float32), array([3.5787632], dtype=float32), array([3.7553537], dtype=float32), array([3.8795502], dtype=float32), array([3.8572905], dtype=float32), array([3.8224528], dtype=float32), array([3.7894113], dtype=float32), array([3.788948], dtype=float32), array([3.737525], dtype=float32), array([3.5589893], dtype=float32), array([3.5972147], dtype=float32), array([3.6336544], dtype=float32), array([3.7317219], dtype=float32), array([3.7727907], dtype=float32), array([3.859464], dtype=float32), array([3.6739254], dtype=float32), array([3.8478544], dtype=float32), array([3.6756334], dtype=float32), array([3.6474535], dtype=float32), array([3.7418184], dtype=float32), array([3.0986376], dtype=float32), array([3.8566673], dtype=float32), array([3.9408112], dtype=float32), array([3.8065455], dtype=float32), array([3.7352726], dtype=float32), array([3.572324], dtype=float32), array([3.8877392], dtype=float32), array([3.840576], dtype=float32), array([3.801636], dtype=float32), array([3.7939742], dtype=float32), array([3.8361533], dtype=float32)]

# %%
diff_out_relError = []
for j in range(diff_out_meanPredictions.shape[0]):
  calc = 0
  for i in range(diff_out_meanPredictions.shape[1]):
    calc += abs((out_y_test[i]-diff_out_meanPredictions[j][i])/out_y_test[i])
  diff_out_relError.append(calc/diff_out_meanPredictions.shape[1])

diff_relError = []
for j in range(diff_meanPredictions.shape[0]):
  calc = 0
  for i in range(diff_meanPredictions.shape[1]):
    if y_test[i] == 0:
      calc += y_test[i]-diff_meanPredictions[j][i]
      continue
    calc += abs((y_test[i]-diff_meanPredictions[j][i])/y_test[i])
  diff_relError.append(calc/diff_meanPredictions.shape[1])

diff_relErrors = (np.array(diff_out_relError) + np.array(diff_relError))/2.0
diff_avRelError = np.mean(diff_relErrors)
print(diff_avRelError)
print(len(diff_relErrors))
# Out:
# 0.3085776
# 66

# %%
diff_long_meanPredictions = []
num_models = diff_long_predictions.shape[0] // small_n_bootstrap # 36
num_test_samples = diff_long_predictions.shape[1] # 1457

for model_index in range(num_models):
  model_predictions = diff_long_predictions[model_index * small_n_bootstrap : (model_index + 1) * small_n_bootstrap]
  # model_predictions now contains the 5 prediction sets for this specific model
  mean_prediction_for_model = np.mean(model_predictions, axis=0) # Average across the bootstrap axis
  diff_long_meanPredictions.append(mean_prediction_for_model)

diff_long_meanPredictions = np.array(diff_long_meanPredictions)
# diff_meanPredictions should now have shape (36, 1457)
print(diff_long_meanPredictions.shape)
# Out:
# (66, 700, 1)

# %%
print(np.arange(100,200,1))
diff_long_deviations = []

for j in range(diff_long_meanPredictions.shape[0]):
  calc = 0
  for i in range(200,300):
    calc += abs(long_y_test[i]-diff_long_meanPredictions[j][i])
  diff_long_deviations.append(calc/100)
print(len(diff_long_deviations))
# Out:
# [100 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116 117
#  118 119 120 121 122 123 124 125 126 127 128 129 130 131 132 133 134 135
#  136 137 138 139 140 141 142 143 144 145 146 147 148 149 150 151 152 153
#  154 155 156 157 158 159 160 161 162 163 164 165 166 167 168 169 170 171
#  172 173 174 175 176 177 178 179 180 181 182 183 184 185 186 187 188 189
#  190 191 192 193 194 195 196 197 198 199]
# 66

# %%
# prompt: plot of diff_long_deviations

plt.figure(figsize=(10, 6))
plt.plot(diff_long_deviations)
plt.xlabel("Model Index")
plt.ylabel("Mean Absolute Deviation for Expressions with 4 Terms")
plt.title("Mean Absolute Deviation for Expressions with 4 Terms for Different Models")
plt.show()

# %%
import seaborn as sns
num_neurons = (max_Neurons - min_Neurons) // Neuron_step + 1
diff_deviation_reshaped = np.array(diff_deviation).reshape(max_layers + 1, num_neurons)
plt.figure(figsize=(8, 6)) # Optional: Adjust figure size
sns.heatmap(diff_deviation_reshaped, annot=True, fmt=".2f", cmap="plasma",
            xticklabels=np.arange(min_Neurons, max_Neurons + 1, Neuron_step),
            yticklabels=np.arange(max_layers + 1))
plt.title('Simple Heatmap')
plt.show()

# %%
print((avDeviation)**2)
print((long_meanDeviations[2])**2)
print((mean_deviations_by_placeholder[22])**2)

baseline_deviation = (avDeviation)**2
baeline_out_deviation = (mean_deviations_by_placeholder[22])**2
baseline_long_deviation = (long_meanDeviations[2])**2
baseline_relError = (avRelError)**2
print(baseline_relError)

benchmark = []
for i in range(len(diff_deviation)):
  calc = 0
  calc += baseline_deviation / (diff_deviation[i]**2)
  calc += baeline_out_deviation / (diff_out_deviation[i]**2)
  calc += baseline_long_deviation / (diff_long_deviations[i]**2)
  calc += baseline_relError / (diff_relErrors[i]**2)
  benchmark.append(calc/4)
print(benchmark)


benchmark_array = np.array(benchmark).reshape(max_layers + 1, num_neurons)
# Out:
# 0.0073816944
# 10.580621
# 10.357245
# [array([0.15410879], dtype=float32), array([0.15904471], dtype=float32), array([0.15228708], dtype=float32), array([0.15384673], dtype=float32), array([0.15499066], dtype=float32), array([0.15562822], dtype=float32), array([0.15643838], dtype=float32), array([0.1553534], dtype=float32), array([0.15737452], dtype=float32), array([0.15266076], dtype=float32), array([0.15586755], dtype=float32), array([0.3660523], dtype=float32), array([0.56789184], dtype=float32), array([0.6540078], dtype=float32), array([0.6321076], dtype=float32), array([0.67710364], dtype=float32), array([0.6742671], dtype=float32), array([0.7526541], dtype=float32), array([0.7534745], dtype=float32), array([0.76148546], dtype=float32), array([0.74546754], dtype=float32), array([0.77682674], dtype=float32), array([0.43449676], dtype=float32), array([0.8165573], dtype=float32), array([0.8379771], dtype=float32), array([0.744511], dtype=float32), array([0.8267605], dtype=float32), array([0.8205761], dtype=float32), array([0.8331201], dtype=float32), array([0.7383386], dtype=float32), array([0.75565326], dtype=float32), array([0.74827945], dtype=float32), array([0.86232364], dtype=float32), array([0.2957401], dtype=float32), array([0.8448611], dtype=float32), array([0.7487454], dtype=float32), array([0.75025666], dtype=float32), array([0.8153486], dtype=float32), array([0.7307167], dtype=float32), array([0.6644813], dtype=float32), array([0.74807996], dtype=float32), array([0.8055145], dtype=float32), array([0.7050233], dtype=float32), array([0.73115504], dtype=float32), array([2.2203352], dtype=float32), array([0.78772926], dtype=float32), array([0.7258045], dtype=float32), array([0.7430711], dtype=float32), array([0.718616], dtype=float32), array([0.7153848], dtype=float32), array([0.71296823], dtype=float32), array([0.71904373], dtype=float32), array([0.68077195], dtype=float32), array([0.7377631], dtype=float32), array([0.7407297], dtype=float32), array([0.9587972], dtype=float32), array([0.7242938], dtype=float32), array([0.69070816], dtype=float32), array([0.66805005], dtype=float32), array([0.68366146], dtype=float32), array([0.71845144], dtype=float32), array([0.68095064], dtype=float32), array([0.72279555], dtype=float32), array([0.74049526], dtype=float32), array([0.7630397], dtype=float32), array([0.6977461], dtype=float32)]

# %%
# Create a new array to include the means
# Add a column for row means and a row for column means (and a corner for the overall mean)
extended_benchmark_array = np.zeros((max_layers + 2, num_neurons + 1))

Neurons_means = np.mean(benchmark_array, axis=0)
Layers_means = np.mean(benchmark_array, axis=1)

# Copy the original benchmark data
extended_benchmark_array[:max_layers + 1, :num_neurons] = benchmark_array

# Add the row means
extended_benchmark_array[:max_layers + 1, num_neurons] = Layers_means

# Add the column means
extended_benchmark_array[max_layers + 1, :num_neurons] = Neurons_means

# Calculate and add the overall mean
overall_mean = np.mean(benchmark_array)
extended_benchmark_array[max_layers + 1, num_neurons] = overall_mean


# Create updated tick labels for the heatmap
xticklabels_extended = list(np.arange(min_Neurons, max_Neurons + 1, Neuron_step)) + ['Row Mean']
yticklabels_extended = list(np.arange(max_layers + 1)) + ['Column Mean']


plt.figure(figsize=(14, 10)) # Adjust figure size for the extra row/column
ax = sns.heatmap(extended_benchmark_array, annot=True, fmt=".2f", cmap="inferno",
            xticklabels=xticklabels_extended,
            yticklabels=yticklabels_extended)
ymin, ymax = ax.get_ylim()
xmin, xmax = ax.get_xlim()
ax.hlines(y=6, xmin=xmin, xmax=xmax, colors='lightblue', lw=2, linestyle='-')
ax.vlines(x=11, ymin=ymin, ymax=ymax, colors='lightblue', lw=2, linestyle='-')
plt.ylabel('Number of Layers')
plt.xlabel('Number of Neurons per Layer')
plt.title('Heatmap of the Benchmarks with Row and Column Means')
plt.savefig("bigHeatmap.png")
plt.show()
