# %%
import sys
import os
import keras_tuner
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Layer, Dropout
from tensorflow.keras import layers
from tensorflow.keras.layers import PReLU


# Get the absolute path of the current script's directory
current_dir = os.path.dirname(os.path.abspath("transformer0.ipynb"))

# Get the absolute path of the parent directory (project_folder)
parent_dir = os.path.dirname(current_dir)

# Add the parent directory to the Python path
sys.path.append(parent_dir)

from FNN1_1 import baseline_deviation, baeline_out_deviation, baseline_long_deviation, baseline_relError, absSum
baseline_out_deviation = baeline_out_deviation

from GetXY import x_train, y_train, x_val, y_val, x_test, y_test, out_x_test, out_y_test, long_x_test, long_y_test, outsideExpr, absSum
# Out:
# C:\Users\A_118784\Desktop\matura_github\myenv\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/attr_value.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\A_118784\Desktop\matura_github\myenv\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\A_118784\Desktop\matura_github\myenv\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/resource_handle.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\A_118784\Desktop\matura_github\myenv\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor_shape.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\A_118784\Desktop\matura_github\myenv\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/types.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\A_118784\Desktop\matura_github\myenv\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/full_type.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\A_118784\Desktop\matura_github\myenv\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/function.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\A_118784\Desktop\matura_github\myenv\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/node_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\A_118784\Desktop\matura_github\myenv\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/op_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\A_118784\Desktop\matura_github\myenv\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\A_118784\Desktop\matura_github\myenv\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/graph_debug_info.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\A_118784\Desktop\matura_github\myenv\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/versions.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\A_118784\Desktop\matura_github\myenv\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\A_118784\Desktop\matura_github\myenv\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at xla/tsl/protobuf/coordination_config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\A_118784\Desktop\matura_github\myenv\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/cost_graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\A_118784\Desktop\matura_github\myenv\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/step_stats.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\A_118784\Desktop\matura_github\myenv\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/allocation_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\A_118784\Desktop\matura_github\myenv\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\A_118784\Desktop\matura_github\myenv\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/cluster.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\A_118784\Desktop\matura_github\myenv\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/debug.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# Epoch 1/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 19.5265 - val_loss: 16.5290
# Epoch 2/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 16.1948 - val_loss: 15.6147
# Epoch 3/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.0879 - val_loss: 14.4413
# Epoch 4/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.7485 - val_loss: 12.9068
# Epoch 5/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.9233 - val_loss: 10.6544
# Epoch 6/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.4318 - val_loss: 7.8020
# Epoch 7/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4791 - val_loss: 4.8345
# Epoch 8/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6322 - val_loss: 2.4014
# Epoch 9/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7399 - val_loss: 1.2128
# Epoch 10/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0342 - val_loss: 0.8405
# Epoch 11/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7966 - val_loss: 0.6774
# Epoch 12/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6625 - val_loss: 0.5688
# Epoch 13/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5629 - val_loss: 0.4901
# Epoch 14/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4865 - val_loss: 0.4322
# Epoch 15/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4279 - val_loss: 0.3883
# Epoch 16/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3815 - val_loss: 0.3551
# Epoch 17/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3454 - val_loss: 0.3302
# Epoch 18/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3155 - val_loss: 0.3077
# Epoch 19/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2872 - val_loss: 0.2816
# Epoch 20/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2583 - val_loss: 0.2575
# Epoch 21/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2314 - val_loss: 0.2318
# Epoch 22/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2094 - val_loss: 0.2156
# Epoch 23/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1914 - val_loss: 0.1995
# Epoch 24/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1755 - val_loss: 0.1840
# Epoch 25/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1612 - val_loss: 0.1709
# Epoch 26/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1486 - val_loss: 0.1595
# Epoch 27/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1373 - val_loss: 0.1491
# Epoch 28/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1268 - val_loss: 0.1388
# Epoch 29/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1173 - val_loss: 0.1291
# Epoch 30/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1084 - val_loss: 0.1201
# Epoch 31/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1004 - val_loss: 0.1121
# Epoch 32/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0930 - val_loss: 0.1040
# Epoch 33/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0863 - val_loss: 0.0962
# Epoch 34/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0802 - val_loss: 0.0895
# Epoch 35/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0745 - val_loss: 0.0835
# Epoch 36/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0695 - val_loss: 0.0774
# Epoch 37/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0645 - val_loss: 0.0725
# Epoch 38/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0603 - val_loss: 0.0671
# Epoch 39/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0562 - val_loss: 0.0631
# Epoch 40/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0528 - val_loss: 0.0589
# Epoch 41/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0493 - val_loss: 0.0554
# Epoch 42/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0464 - val_loss: 0.0518
# Epoch 43/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0434 - val_loss: 0.0483
# Epoch 44/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0410 - val_loss: 0.0455
# Epoch 45/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0385 - val_loss: 0.0429
# Epoch 46/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0363 - val_loss: 0.0405
# Epoch 47/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0343 - val_loss: 0.0384
# Epoch 48/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0324 - val_loss: 0.0366
# Epoch 49/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0307 - val_loss: 0.0351
# Epoch 50/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0292 - val_loss: 0.0333
# Epoch 51/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0276 - val_loss: 0.0317
# Epoch 52/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0263 - val_loss: 0.0303
# Epoch 53/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0251 - val_loss: 0.0288
# Epoch 54/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0239 - val_loss: 0.0274
# Epoch 55/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0229 - val_loss: 0.0260
# Epoch 56/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0219 - val_loss: 0.0247
# Epoch 57/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0210 - val_loss: 0.0236
# Epoch 58/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0203 - val_loss: 0.0225
# Epoch 59/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0196 - val_loss: 0.0215
# Epoch 60/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0190 - val_loss: 0.0207
# Epoch 61/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0185 - val_loss: 0.0199
# Epoch 62/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0180 - val_loss: 0.0192
# Epoch 63/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - val_loss: 0.0185
# Epoch 64/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0171 - val_loss: 0.0179
# Epoch 65/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0166 - val_loss: 0.0174
# Epoch 66/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0162 - val_loss: 0.0169
# Epoch 67/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0158 - val_loss: 0.0165
# Epoch 68/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0155 - val_loss: 0.0162
# Epoch 69/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0152 - val_loss: 0.0160
# Epoch 70/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0149 - val_loss: 0.0158
# Epoch 71/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0146 - val_loss: 0.0155
# Epoch 72/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0142 - val_loss: 0.0152
# Epoch 73/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0136 - val_loss: 0.0146
# Epoch 74/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0132 - val_loss: 0.0143
# Epoch 75/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0128 - val_loss: 0.0139
# Epoch 76/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0124 - val_loss: 0.0138
# Epoch 77/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0120 - val_loss: 0.0134
# Epoch 78/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0115 - val_loss: 0.0131
# Epoch 79/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0113 - val_loss: 0.0130
# Epoch 80/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0109 - val_loss: 0.0126
# Epoch 81/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0106 - val_loss: 0.0126
# Epoch 82/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0105 - val_loss: 0.0126
# Epoch 83/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0103 - val_loss: 0.0123
# Epoch 84/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0101 - val_loss: 0.0124
# Epoch 85/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0099 - val_loss: 0.0123
# Epoch 86/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0099 - val_loss: 0.0124
# Epoch 87/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0097 - val_loss: 0.0125
# Epoch 88/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0097 - val_loss: 0.0124
# Epoch 89/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0097 - val_loss: 0.0126
# Epoch 90/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0097 - val_loss: 0.0128
# Epoch 91/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0096 - val_loss: 0.0125
# Epoch 92/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0095 - val_loss: 0.0126
# Epoch 93/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0094 - val_loss: 0.0125
# Epoch 94/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0093 - val_loss: 0.0124
# Epoch 95/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0092 - val_loss: 0.0125
# Epoch 96/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0091 - val_loss: 0.0123
# Epoch 97/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0089 - val_loss: 0.0123
# Epoch 98/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0089 - val_loss: 0.0123
# Epoch 99/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0087 - val_loss: 0.0124
# Epoch 100/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0086 - val_loss: 0.0118
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 21.5979 - val_loss: 17.2954
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 16.4201 - val_loss: 15.9226
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.9099 - val_loss: 14.3746
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13.0318 - val_loss: 12.2114
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 10.5147 - val_loss: 9.3709
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.4099 - val_loss: 6.0950
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3546 - val_loss: 3.3711
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1970 - val_loss: 1.7193
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1669 - val_loss: 1.0685
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8194 - val_loss: 0.8228
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6542 - val_loss: 0.6727
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5376 - val_loss: 0.5643
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4467 - val_loss: 0.4702
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3716 - val_loss: 0.3965
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3178 - val_loss: 0.3432
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2779 - val_loss: 0.3025
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2430 - val_loss: 0.2643
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2141 - val_loss: 0.2331
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1894 - val_loss: 0.2073
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1678 - val_loss: 0.1858
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1506 - val_loss: 0.1679
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1357 - val_loss: 0.1528
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1230 - val_loss: 0.1411
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1117 - val_loss: 0.1312
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1016 - val_loss: 0.1228
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0931 - val_loss: 0.1129
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0863 - val_loss: 0.1040
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0803 - val_loss: 0.0969
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0754 - val_loss: 0.0910
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0707 - val_loss: 0.0853
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0665 - val_loss: 0.0810
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0628 - val_loss: 0.0766
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0588 - val_loss: 0.0738
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0554 - val_loss: 0.0701
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0521 - val_loss: 0.0663
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0493 - val_loss: 0.0633
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0467 - val_loss: 0.0607
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0444 - val_loss: 0.0581
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0423 - val_loss: 0.0557
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0404 - val_loss: 0.0536
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0384 - val_loss: 0.0513
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0365 - val_loss: 0.0489
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0347 - val_loss: 0.0467
# Epoch 44/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0330 - val_loss: 0.0446
# Epoch 45/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0317 - val_loss: 0.0430
# Epoch 46/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0304 - val_loss: 0.0415
# Epoch 47/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0290 - val_loss: 0.0405
# Epoch 48/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0275 - val_loss: 0.0378
# Epoch 49/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0263 - val_loss: 0.0366
# Epoch 50/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0252 - val_loss: 0.0354
# C:\Users\A_118784\Desktop\matura_github\matura\matura\FNN1_1.py:246: RuntimeWarning: divide by zero encountered in divide
#   relativeError = np.where(np.array(y_test) != 0, deviation.flatten() / np.abs(np.array(y_test)), deviation.flatten())
# -2 + 0 + -4
# 2543
# -6.0
#
# Expressions not in x:
# -4 + 1 + -4
# True
# 1457
# -7.0
# 15
# -4.0
# [-5.   1.   1.   0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5
#   0.5]

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=10,
    min_delta=0.001,
    restore_best_weights=True,
    monitor='val_loss',
    mode = "min"
)

# %%
batch_size = 32
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(len(x_train)).batch(batch_size)
val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val)).batch(batch_size)

print(len(x_train), len(y_train))
print(len(x_val), len(y_val))
print(len(x_test), len(y_test))
print(len(out_x_test), len(out_y_test))
print(len(long_x_test), len(long_y_test))
# Out:
# 1907 1907
# 636 636
# 1457 1457
# 2048 2048
# 700 700

# %%
input_shape = x_train[0].shape
from tensorflow.keras import backend as K

def build_model(hp, input_shape):
    K.clear_session()
    num_neurons = hp.Int("num_neurons", 1, 512)
    num_layers = hp.Int("num_layers", 1, 16)
    dropoutTF = hp.Boolean("dropoutT/F")
    lil_model = keras.Sequential()
    lil_model.add(keras.Input(shape=input_shape))
    lil_model.add(layers.Flatten())
    for i in range(num_layers):
        lil_model.add(layers.Dense(num_neurons)),
        lil_model.add(PReLU())
        if dropoutTF == True:
            lil_model.add(layers.Dropout(0.1))
    lil_model.add(layers.Dense(1, activation='linear'))
    lil_model.compile(optimizer="adam", loss="mse")
    return lil_model
build_model(keras_tuner.HyperParameters(), input_shape)
# Out:
# WARNING:tensorflow:From C:\Users\A_118784\Desktop\matura_github\myenv\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
# <Sequential name=sequential, built=True>

# %%
tuner = keras_tuner.BayesianOptimization(
    hypermodel=lambda hp: build_model(hp, input_shape),    objective="val_loss",
    max_trials=100,
    executions_per_trial=1,
    overwrite=False,
    directory="FNNTuner",
    project_name="tuner",
)
# Out:
# Reloading Tuner from FNNTuner\tuner\tuner0.json

# %%
num_epochs = 100
tuner.search(train_dataset, epochs = num_epochs, validation_data = (val_dataset), verbose = 1, callbacks = [])

# %%
best_hps = tuner.get_best_hyperparameters()[0]
best_model = build_model(best_hps, input_shape)
best_model.summary()
tuner.results_summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 15)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 345)                 │           5,520 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ p_re_lu (PReLU)                      │ (None, 345)                 │             345 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             346 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 6,211 (24.26 KB)
#  Trainable params: 6,211 (24.26 KB)
#  Non-trainable params: 0 (0.00 B)
# Results summary
# Results in FNNTuner\tuner
# Showing 10 best trials
# Objective(name="val_loss", direction="min")
#
# Trial 025 summary
# Hyperparameters:
# num_neurons: 345
# num_layers: 1
# dropoutT/F: False
# Score: 0.0012616724707186222
#
# Trial 000 summary
# Hyperparameters:
# num_neurons: 348
# num_layers: 1
# dropoutT/F: False
# Score: 0.001294966321438551
#
# Trial 056 summary
# Hyperparameters:
# num_neurons: 439
# num_layers: 4
# dropoutT/F: False
# Score: 0.0025118887424468994
#
# Trial 020 summary
# Hyperparameters:
# num_neurons: 16
# num_layers: 1
# dropoutT/F: False
# Score: 0.002628110349178314
#
# Trial 026 summary
# Hyperparameters:
# num_neurons: 289
# num_layers: 2
# dropoutT/F: False
# Score: 0.002691656118258834
#
# Trial 042 summary
# Hyperparameters:
# num_neurons: 435
# num_layers: 4
# dropoutT/F: False
# Score: 0.0027040746062994003
#
# Trial 094 summary
# Hyperparameters:
# num_neurons: 440
# num_layers: 4
# dropoutT/F: False
# Score: 0.002829659730195999
#
# Trial 064 summary
# Hyperparameters:
# num_neurons: 440
# num_layers: 4
# dropoutT/F: False
# Score: 0.0029272951651364565
#
# Trial 044 summary
# Hyperparameters:
# num_neurons: 435
# num_layers: 4
# dropoutT/F: False
# Score: 0.003144865622743964
#
# Trial 008 summary
# Hyperparameters:
# num_neurons: 200
# num_layers: 2
# dropoutT/F: False
# Score: 0.0031737370882183313

# %%
x_test_dataset = tf.data.Dataset.from_tensor_slices(x_test).batch(batch_size)
out_x_test_dataset = tf.data.Dataset.from_tensor_slices(out_x_test).batch(batch_size)
long_x_test_dataset = tf.data.Dataset.from_tensor_slices(long_x_test).batch(batch_size)

# %%
best_model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=200,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 18.4901 - val_loss: 15.8258
# Epoch 2/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.6584 - val_loss: 13.7557
# Epoch 3/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.2252 - val_loss: 10.7682
# Epoch 4/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.8918 - val_loss: 7.1233
# Epoch 5/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1725 - val_loss: 3.5573
# Epoch 6/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3880 - val_loss: 1.5160
# Epoch 7/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1094 - val_loss: 0.8039
# Epoch 8/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6908 - val_loss: 0.5966
# Epoch 9/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5052 - val_loss: 0.4490
# Epoch 10/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3771 - val_loss: 0.3460
# Epoch 11/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2923 - val_loss: 0.2669
# Epoch 12/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2263 - val_loss: 0.2038
# Epoch 13/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1720 - val_loss: 0.1619
# Epoch 14/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1377 - val_loss: 0.1307
# Epoch 15/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1119 - val_loss: 0.1090
# Epoch 16/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0917 - val_loss: 0.0870
# Epoch 17/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0743 - val_loss: 0.0774
# Epoch 18/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0620 - val_loss: 0.0640
# Epoch 19/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0514 - val_loss: 0.0523
# Epoch 20/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0444 - val_loss: 0.0476
# Epoch 21/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0403 - val_loss: 0.0388
# Epoch 22/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0325 - val_loss: 0.0356
# Epoch 23/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0280 - val_loss: 0.0298
# Epoch 24/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0241 - val_loss: 0.0268
# Epoch 25/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0210 - val_loss: 0.0243
# Epoch 26/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - val_loss: 0.0211
# Epoch 27/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0163 - val_loss: 0.0228
# Epoch 28/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0141 - val_loss: 0.0189
# Epoch 29/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0129 - val_loss: 0.0151
# Epoch 30/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0112 - val_loss: 0.0138
# Epoch 31/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0103 - val_loss: 0.0139
# Epoch 32/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0095 - val_loss: 0.0128
# Epoch 33/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0086 - val_loss: 0.0114
# Epoch 34/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0074 - val_loss: 0.0096
# Epoch 35/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0068 - val_loss: 0.0088
# Epoch 36/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0064 - val_loss: 0.0090
# Epoch 37/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0060 - val_loss: 0.0083
# Epoch 38/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0056 - val_loss: 0.0077
# Epoch 39/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049 - val_loss: 0.0065
# Epoch 40/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0045 - val_loss: 0.0061
# Epoch 41/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - val_loss: 0.0065
# Epoch 42/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0038 - val_loss: 0.0059
# Epoch 43/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0038 - val_loss: 0.0052
# Epoch 44/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0033 - val_loss: 0.0051
# Epoch 45/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0033 - val_loss: 0.0043
# Epoch 46/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - val_loss: 0.0046
# Epoch 47/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - val_loss: 0.0042
# Epoch 48/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - val_loss: 0.0040
# Epoch 49/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - val_loss: 0.0039
# Epoch 50/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - val_loss: 0.0036
# Epoch 51/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0021 - val_loss: 0.0037
# Epoch 52/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 53/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0020 - val_loss: 0.0032
# Epoch 54/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 55/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 56/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 57/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 58/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 59/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 60/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012 - val_loss: 0.0023
# Epoch 61/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 62/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - val_loss: 0.0020

# %%
predsInRange = best_model.predict(x_test_dataset)
predsOutRange = best_model.predict(out_x_test_dataset)
predsLongRange = best_model.predict(long_x_test_dataset)
# Out:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
import numpy as np

reldiffInRange = []
diffInRange = []
safe_y_test = np.where(np.isclose(y_test,0.0), 1.0, y_test)

for i in range(len(y_test)):
    diffInRange.append(abs(y_test[i] - predsInRange[i]))
    reldiffInRange.append(abs(y_test[i] - predsInRange[i])/abs(safe_y_test[i]))
print(len(diffInRange))
print("MAE in Range: ", np.mean(diffInRange))
print("MRE in Range: ", np.mean(reldiffInRange))

diffLongRange = []
for i in range(200, 300):
    diffLongRange.append(np.array(np.abs(long_y_test[i]) - np.array(predsInRange[i])))
    
NEEDdiffLongRange = []
for i in range(len(long_y_test)):
    NEEDdiffLongRange.append(np.array(np.abs(long_y_test[i]) - np.array(predsInRange[i])))
print("MAE longer Expressions: ", np.mean(NEEDdiffLongRange))

diffOutRange = []
for i in range(len(out_y_test)):
    diffOutRange.append(abs(out_y_test[i] - predsOutRange[i]))
safe_out_y_test = np.where(out_y_test == 0, 1, out_y_test)
diff_out_relError = []
for i in range(len(out_y_test)):
    diff_out_relError.append(abs(diffOutRange[i] / safe_out_y_test[i]))
print("MAE out Range: ", np.mean(diffOutRange))
print("MRE out Range: ", np.mean(diff_out_relError))
# Out:
# 1457
# MAE in Range:  0.03932453
# MRE in Range:  0.015499097314507344
# MAE longer Expressions:  6.315194652413484
# MAE out Range:  2.238441
# MRE out Range:  0.2544133458195641

# %%
placeholder = absSum(outsideExpr)
diffOutRange = []
indices_with_placeholder_22 = [i for i, val in enumerate(placeholder) if val == 22] 

for i in indices_with_placeholder_22:
    diffOutRange.append(np.abs(out_y_test[i]-predsOutRange[i]))

# %%
meanDiff_InRange = np.mean(diffInRange)
meanDiff_OutRange = np.mean(diffOutRange)
meanDiff_LongRange = np.mean(diffLongRange)
meanDiff_OutRelRange = np.mean(diff_out_relError)

# %%
benchmark = 0
benchmark += baseline_deviation / (meanDiff_InRange**2) / 4
print(baseline_deviation / (meanDiff_InRange**2) / 4)

benchmark += baseline_out_deviation / (meanDiff_OutRange**2) / 4
print(baseline_out_deviation / (meanDiff_OutRange**2) / 4)

benchmark += baseline_long_deviation / (meanDiff_LongRange**2) / 4
print(baseline_long_deviation / (meanDiff_LongRange**2) / 4)

benchmark += baseline_relError / (meanDiff_OutRelRange**2) / 4
print(baseline_relError / (meanDiff_OutRelRange**2) / 4)

print(f"Benchmark: {benchmark}")
# Out:
# 3.1411024118014486
# 0.34368733678605856
# 0.20548974117629884
# 0.187848954872932
# Benchmark: 3.8781284446367383
