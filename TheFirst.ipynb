# %% [markdown]
# <a href="https://colab.research.google.com/github/AntonStantan/matura/blob/main/TheFirst.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
np.random.seed(42)

x1 = np.random.rand(4000)*10
x2 = np.random.rand(4000)*10
x3 = np.random.rand(4000)*10

x1_int = x1.astype(int) - 5
x2_int = x2.astype(int) - 5
x3_int = x3.astype(int) - 5

x1_str = x1_int.astype(str)
x2_str = x2_int.astype(str)
x3_str = x3_int.astype(str)

unique_expressions = set()

for i in range(len(x1)):
  n = np.random.rand(1)
  if n < 0.25:
    opp1 = " + "
    opp2 = " + "
  elif n > 0.25 and n < 0.5:
    opp1 = " + "
    opp2 = " - "
  elif n > 0.75:
    opp1 = " - "
    opp2 = " + "
  else:
    opp1 = " - "
    opp2 = " - "
  unique_expressions.add(x1_str[i] + opp1 + x2_str[i] + opp2 + x3_str[i])

x = list(unique_expressions) # Convert the set back to a list
print(x)
print(len(x))
# Out:
# ['-5 + 3 - 2', '1 - 4 - -1', '0 + 2 - 3', '-2 - 4 + 4', '4 + -1 - -5', '1 + 0 + 0', '2 - 2 + -1', '-3 + 4 + 3', '-1 - 2 + 3', '-2 + 1 + 0', '-2 + -4 + -4', '-1 + 0 - 1', '-4 + -3 + 3', '-3 - -3 + -3', '2 - 4 + 0', '4 - -2 + -1', '-1 + -3 + -4', '1 + -5 + 2', '-5 + -2 + 1', '0 + -2 + 4', '2 + 0 + -5', '-4 + -3 + 1', '-4 + -5 + 1', '-4 - 4 + -1', '-4 + -4 - -4', '4 + 1 + 2', '2 - 1 + 3', '-5 - -5 + -3', '-1 + 3 - -1', '-5 + -2 + -2', '0 - 1 + 0', '-4 + 2 + 3', '-5 + 1 - 1', '-3 - -4 - 1', '-1 - -1 - 2', '-3 + 0 - -2', '-4 + -1 + -3', '0 - -1 + 3', '-2 + 3 + -4', '-3 + -1 + 2', '3 + -5 + -5', '4 - 4 + 4', '-3 + -5 + 3', '2 + -4 - 1', '2 + 0 - 0', '-4 - 1 - 0', '-2 + 2 - 3', '3 - 4 + -5', '-2 + -3 + -5', '4 + 0 + 1', '0 + -2 - 2', '2 + 3 + 2', '2 + -4 - 0', '1 - 3 - 1', '-5 - 0 - 1', '-1 - -3 + 3', '-3 - -1 + -5', '-1 - 1 + -1', '1 + 3 + -4', '-4 + 2 - 0', '-5 + -5 + 4', '2 - 1 + 2', '-3 - -1 + 3', '3 - 4 - -5', '3 + -4 - -1', '-3 - -5 - -1', '-4 + 0 + 0', '1 - 3 + -1', '-1 + 3 + -2', '-2 - -5 - 3', '-2 + 2 - -3', '4 - 4 - 1', '4 - -5 - 0', '-5 - -4 - 3', '4 - -2 + 2', '3 + 3 - -5', '4 + -3 - -5', '4 + 1 - -5', '-2 + -2 + 2', '-5 + -5 + 3', '2 + -4 + -2', '-2 + -5 - 0', '0 + 4 - -5', '-2 - 3 + -5', '-3 + -3 - 0', '-1 + -3 + -5', '-3 + 3 + 2', '2 + 4 + -3', '-1 - 0 - -4', '1 - -5 + 3', '-5 - 4 + -5', '-1 + 4 + 3', '3 - 4 - -1', '4 - 2 + -1', '-1 - 0 + -1', '-4 + -4 - 2', '-3 - 1 - -2', '-3 + 1 - 4', '0 - -5 + -4', '-1 - -5 - 2', '3 - -5 + -2', '1 + 1 - 1', '-5 + 0 + -5', '-5 + -5 + -2', '1 + 3 + 2', '1 + -3 + 4', '2 - 1 + -4', '-1 + 4 + -3', '0 - -4 + -2', '-2 - -2 - 2', '3 - -1 + 4', '-4 - 0 + -4', '0 + -4 + 1', '-5 - -3 - -4', '2 + -5 + -1', '-4 + 3 - -4', '2 - 2 + 2', '3 - 3 - -4', '-2 + 2 - -2', '4 - -1 + 1', '3 + 0 + 3', '-1 - -1 - -1', '2 + 0 + 1', '-4 + 3 - 4', '-2 + 0 - -4', '-4 - 1 - -3', '-2 + 4 + 3', '0 - -1 - 4', '-1 - 4 - -1', '-3 + -4 - -4', '-2 - 4 - 1', '3 + -5 + -1', '3 + -3 - 0', '-5 + -3 + 2', '2 + -1 + 0', '-3 - 0 + 2', '-1 + -4 - -2', '-1 - 3 - -4', '1 - -1 - 0', '0 + -5 + -1', '-4 - -4 + 2', '-3 - 3 + -2', '1 - 4 + -3', '4 + -2 + -4', '-1 + 1 - -4', '0 + 1 + -1', '-3 + 1 + 0', '3 + 1 + -5', '-2 + -3 - 2', '3 - 1 + -5', '4 - 3 + -2', '-1 - -3 - -1', '1 + -2 + 0', '0 + -3 + -5', '-5 + 4 + 4', '-3 + 3 - -2', '4 - -4 - -3', '0 - 4 - 4', '-4 + 1 - -4', '1 + 3 - 3', '-1 - -4 + -3', '-5 + -5 - 1', '-2 - 1 + 1', '0 - 3 + 2', '-3 - 1 - -4', '3 + 0 + -3', '1 - -2 + -1', '4 + -3 - 1', '-4 + 1 - -5', '-2 - -5 + 3', '-3 + -1 - 2', '2 + -1 + -5', '0 + 1 - -1', '1 + 3 + 0', '0 - -1 - 1', '3 - 0 - 0', '0 + -1 - 1', '-4 + -5 + -3', '3 - -5 + 4', '-5 + 3 + -4', '-3 + 0 - 3', '3 + 0 - 1', '-5 - -4 + -2', '3 - -5 - 1', '0 - -4 + 4', '3 + -1 - 0', '3 + -2 - 1', '4 - -3 - 3', '1 + -2 - -3', '-1 - -4 - 2', '2 + -2 - 0', '-5 + -2 - 3', '4 + -4 + 0', '-1 + -1 + -5', '-2 + -4 + 1', '4 + -1 - 3', '-1 - -1 + -2', '-1 - -3 - 1', '3 + -2 + -3', '-4 + 1 - 4', '2 - -2 + -3', '-4 + -4 + 1', '3 - 4 + -2', '0 + 4 - 3', '4 - 3 + -1', '-2 - 1 + -2', '0 + 2 - -4', '-2 - 4 + -5', '0 - -5 - 0', '4 - -1 + -1', '4 - -5 - -2', '-5 - 3 + -1', '-3 - -5 - 2', '0 - -2 + 1', '4 - 3 + 3', '0 - 0 + 3', '-1 - 0 - 1', '3 - 0 - -4', '1 + -2 - -5', '-3 - -1 - 2', '-2 + 3 - -3', '1 - 1 + -1', '-3 + -5 + 4', '-2 - 4 + 1', '-4 + -4 - -1', '-1 - -1 - -4', '4 + 3 + -4', '3 - -4 + 2', '-2 + -2 - 3', '-4 - -3 + -5', '-2 - 1 - 2', '-3 - 3 - -1', '-4 + -5 + 3', '-3 + 4 + 4', '-4 + 1 + 2', '1 + 0 + 1', '-4 + -3 + 2', '2 + 0 - 4', '1 + -1 - -3', '0 - 2 - 3', '3 - 3 - -5', '-3 - -1 + -3', '0 - 1 + -4', '0 + 4 - -3', '3 + 0 + -2', '-2 - -3 - 3', '-4 + -5 - 0', '-5 - -3 + -3', '1 - -2 - 3', '2 + 0 - -5', '-4 - -2 + 2', '-1 - 3 + 4', '0 - 0 + -3', '4 + -3 - -3', '3 - -2 - -1', '-4 + -5 + 2', '2 + -2 - 4', '-5 - 2 + -1', '2 + -4 + -3', '-5 + 4 + -1', '3 - -2 + -5', '0 + -3 - 4', '3 + -3 + -3', '2 - 2 - 4', '1 + 0 - 0', '-2 + 3 - -4', '1 - -1 - -4', '3 - 1 - -5', '0 + 2 - 4', '-4 - 0 + 4', '1 + 1 + -4', '-3 - -4 - -4', '-2 - -1 - 3', '0 - 2 + -5', '3 - -4 - 2', '-5 - -3 + 3', '-3 ...
# 2543

# %%
y = []

for expression in x:
  result = float(eval(expression))
  y.append(result)

print(y)
# Out:
# [-4.0, -2.0, -1.0, -2.0, 8.0, 1.0, -1.0, 4.0, 0.0, -1.0, -10.0, -2.0, -4.0, -3.0, -2.0, 5.0, -8.0, -2.0, -6.0, 2.0, -3.0, -6.0, -8.0, -9.0, -4.0, 7.0, 4.0, -3.0, 3.0, -9.0, -1.0, 1.0, -5.0, 0.0, -2.0, -1.0, -8.0, 4.0, -3.0, -2.0, -7.0, 4.0, -5.0, -3.0, 2.0, -5.0, -3.0, -6.0, -10.0, 5.0, -4.0, 7.0, -2.0, -3.0, -6.0, 5.0, -7.0, -3.0, 0.0, -2.0, -6.0, 3.0, 1.0, 4.0, 0.0, 3.0, -4.0, -3.0, 0.0, 0.0, 3.0, -1.0, 9.0, -4.0, 8.0, 11.0, 6.0, 10.0, -2.0, -7.0, -4.0, -7.0, 9.0, -10.0, -6.0, -9.0, 2.0, 3.0, 3.0, 9.0, -14.0, 6.0, 0.0, 1.0, -2.0, -10.0, -2.0, -6.0, 1.0, 2.0, 6.0, 1.0, -10.0, -12.0, 6.0, 2.0, -3.0, 0.0, 2.0, -2.0, 8.0, -8.0, -3.0, 2.0, -4.0, 3.0, 2.0, 4.0, 2.0, 6.0, 6.0, 1.0, 3.0, -5.0, 2.0, -2.0, 5.0, -3.0, -4.0, -3.0, -7.0, -3.0, 0.0, -6.0, 1.0, -1.0, -3.0, 0.0, 2.0, -6.0, 2.0, -8.0, -6.0, -2.0, 4.0, 0.0, -2.0, -1.0, -7.0, -3.0, -1.0, 3.0, -1.0, -8.0, 3.0, 2.0, 11.0, -8.0, 1.0, 1.0, 0.0, -11.0, -2.0, -1.0, 0.0, 0.0, 2.0, 0.0, 2.0, 6.0, -6.0, -4.0, 2.0, 4.0, 0.0, 3.0, -2.0, -12.0, 12.0, -6.0, -6.0, 2.0, -3.0, 7.0, 8.0, 2.0, 0.0, 4.0, 2.0, 1.0, 0.0, -10.0, 0.0, -7.0, -5.0, 0.0, -2.0, 1.0, -2.0, -7.0, 1.0, -7.0, -3.0, 1.0, 0.0, -5.0, 6.0, -11.0, 5.0, 4.0, 11.0, -9.0, 0.0, 3.0, 4.0, 3.0, -2.0, 7.0, 4.0, -4.0, 4.0, -1.0, -4.0, -5.0, -7.0, 4.0, 3.0, 9.0, -7.0, -6.0, -5.0, -5.0, -6.0, 5.0, -1.0, 2.0, -5.0, -2.0, 3.0, -5.0, 5.0, -5.0, -5.0, 7.0, 1.0, -2.0, -9.0, -5.0, 0.0, 7.0, 0.0, 0.0, -3.0, 4.0, 6.0, -7.0, -4.0, -8.0, -5.0, -2.0, 0.0, -7.0, -3.0, -4.0, 1.0, 5.0, 6.0, 7.0, -2.0, 0.0, -2.0, 5.0, -4.0, -7.0, 5.0, 1.0, -2.0, 0.0, -9.0, -5.0, 1.0, 1.0, -1.0, -9.0, -4.0, -1.0, 1.0, -1.0, 3.0, 2.0, -7.0, -5.0, 1.0, 0.0, 0.0, -6.0, 3.0, -3.0, 9.0, -4.0, -7.0, -12.0, 2.0, -6.0, -10.0, -1.0, 9.0, -4.0, -2.0, 0.0, 2.0, 0.0, 1.0, 10.0, 5.0, 1.0, -4.0, 5.0, 7.0, 13.0, -3.0, -3.0, 3.0, 0.0, 1.0, 3.0, 0.0, 8.0, -6.0, -6.0, 6.0, -3.0, 1.0, -2.0, -3.0, -5.0, 8.0, 0.0, 10.0, -5.0, -6.0, -5.0, -6.0, -1.0, 9.0, 7.0, -1.0, -5.0, -7.0, -6.0, -3.0, -2.0, -2.0, -2.0, -4.0, -6.0, 1.0, -3.0, -11.0, 7.0, 0.0, -6.0, -8.0, -6.0, 0.0, 9.0, 0.0, 0.0, -3.0, -2.0, 0.0, -5.0, -6.0, 8.0, -3.0, -5.0, -9.0, -1.0, -3.0, -4.0, -6.0, -1.0, 5.0, 1.0, 9.0, -7.0, 0.0, -7.0, -5.0, -2.0, 6.0, 1.0, 11.0, -6.0, 2.0, -6.0, -3.0, 11.0, 2.0, 7.0, 3.0, -2.0, 2.0, 2.0, -1.0, -1.0, 2.0, -11.0, 4.0, -11.0, -5.0, -1.0, -5.0, -2.0, -9.0, -10.0, 0.0, 0.0, 0.0, 1.0, -2.0, 10.0, -1.0, -3.0, -7.0, -1.0, -5.0, 5.0, -10.0, -5.0, 3.0, 6.0, -8.0, 7.0, 3.0, -3.0, -1.0, 2.0, 0.0, 5.0, -1.0, 2.0, -2.0, -1.0, -3.0, -5.0, 3.0, 1.0, -1.0, -5.0, -9.0, 1.0, -5.0, -2.0, -4.0, 9.0, 6.0, -8.0, 6.0, 1.0, 9.0, -2.0, 7.0, -4.0, 0.0, -9.0, -4.0, 2.0, 7.0, -7.0, -1.0, -2.0, 1.0, 8.0, -7.0, -3.0, -3.0, 2.0, -4.0, -3.0, 2.0, -8.0, -4.0, -4.0, -6.0, -3.0, 2.0, 0.0, 4.0, 2.0, -6.0, -13.0, -7.0, 11.0, 0.0, -4.0, 2.0, -7.0, -2.0, -2.0, 1.0, -1.0, 5.0, 9.0, -1.0, 0.0, 11.0, 8.0, -5.0, 12.0, 6.0, 5.0, -4.0, -5.0, 4.0, -5.0, 1.0, -2.0, -2.0, 3.0, -6.0, 8.0, -3.0, -3.0, 1.0, 1.0, 6.0, -10.0, -3.0, -1.0, 1.0, -5.0, 0.0, -2.0, -4.0, -1.0, -6.0, 3.0, 4.0, 2.0, -3.0, -1.0, 1.0, -10.0, 0.0, -9.0, 0.0, 2.0, 1.0, -8.0, -2.0, -2.0, -2.0, 13.0, -1.0, -10.0, -5.0, 5.0, 2.0, -8.0, -6.0, -10.0, 7.0, -3.0, 9.0, 7.0, -3.0, 10.0, -4.0, 0.0, -4.0, -5.0, 12.0, -1.0, 11.0, 0.0, -8.0, -10.0, -3.0, -2.0, -3.0, 5.0, 7.0, -1.0, 1.0, -12.0, 2.0, 0.0, -2.0, -6.0, 4.0, 2.0, -4.0, 4.0, -6.0, -1.0, -3.0, -4.0, 1.0, 10.0, 2.0, 5.0, -5.0, 11.0, -4.0, 0.0, 1.0, -7.0, 0.0, -4.0, 3.0, 11.0, -6.0, 3.0, 6.0, -2.0, -2.0, -4.0, 1.0, 9.0, -3.0, -4.0, -2.0, 3.0, 6.0, -2.0, 9.0, -11.0, -3.0, 4.0, 3.0, -2.0, -1.0, -7.0, 1.0, 3.0, -2.0, -4.0, 0.0, 0.0, 3.0, 3.0, 0.0, 0.0, -3.0, 7.0, -3.0, 5.0, -7.0, 0.0, -2.0, -1.0, -4.0, -1.0, 7.0, 5.0, -4.0, 4.0, -4.0, -7.0, -7.0, -4.0, 3.0, -12.0, -9.0, -6.0, 3.0, 8.0, 1.0, -5.0, -3.0, -3.0, -3.0, -4.0, 5.0, -4.0, -1.0, 1.0, -3.0, 1.0, -6.0, -4.0, -4.0, -11.0, 2.0, 0.0, 2.0, 7.0, 0.0, 5.0, -1.0, -9.0, 4.0, 0.0, 4.0, -3.0, 6.0, 2.0, -6.0, -4.0, -3.0, -2.0, 3.0, 3.0, -7.0, -3.0, 4.0, 9.0, 2.0, 6.0, -5.0, 8.0, -5.0, 3.0, 1. ...

# %%
def tokenizer(input_list): # Changed parameter name to avoid confusion with global x
  #tokenizer by hand
  #tokens = (len(input_list), 5)
  # Create a copy of the input list to avoid modifying the original
  tokenized_x = [expression.split(" ") for expression in input_list]


  for i in range(len(tokenized_x)):
    for j in range(len(tokenized_x[i])):
      if j % 2 == 0:  # Check if the index is even
        tokenized_x[i][j] = np.float32(tokenized_x[i][j])
      else:  # The index is uneven, it's an operator
        if tokenized_x[i][j] == "+":
          tokenized_x[i][j] = np.float32(1)
        else:
          tokenized_x[i][j] = np.float32(0)
    padding_count = 15 - len(tokenized_x[i])
    for _ in range(padding_count): # Use a throwaway variable
      tokenized_x[i].append(np.float32(0.5))
  tokenized_x = np.array(tokenized_x)
  return tokenized_x
x = tokenizer(x)

# %%
# Generate all possible expressions
all_possible_expressions = set()
for num1 in range(-5, 5): # Range -5 to 4
    for num2 in range(-5, 5): # Range -5 to 4
        for num3 in range(-5, 5): # Range -5 to 4
            for op1 in [" + ", " - "]:
                for op2 in [" + ", " - "]:
                    expression = str(num1) + op1 + str(num2) + op2 + str(num3)
                    all_possible_expressions.add(expression)

# Find expressions not in x
expressions_not_in_x = all_possible_expressions - unique_expressions
expressions_not_in_x = list(expressions_not_in_x)
print("\nExpressions not in x:")
print(list(expressions_not_in_x)) # Convert back to a list for printing
if len(expressions_not_in_x)+len(x) == 4000: print(True)
print(len(expressions_not_in_x))
# Out:
# Expressions not in x:
# ['-3 + 3 - -4', '-4 - 1 - -2', '1 + -3 - 1', '0 - -3 - 4', '4 + -1 + -1', '4 + 3 + 3', '-5 - 2 - 4', '-2 + -3 - 0', '-1 - 4 + -1', '-4 + -2 + 0', '1 - 3 - 2', '-4 - -5 - -5', '-1 - -5 - 0', '4 - -3 + 1', '3 + -5 + 3', '3 + 0 - -2', '1 + -5 + -5', '2 - 4 - 0', '-1 - -4 + 2', '-4 - 1 + 2', '1 - 3 - -3', '2 + 4 + -5', '-3 - 2 + 1', '-1 + 0 - 0', '-5 - 2 + 1', '4 - 2 + 3', '0 - -5 + 4', '4 - 3 + -5', '0 + 3 + -3', '3 + 0 + 2', '-1 - 2 + -2', '-4 + 4 - -2', '-3 - -4 - -1', '-3 + 1 - -3', '3 - -5 - -1', '0 - -5 + 3', '-2 - -4 + 2', '2 + 1 + 1', '4 + 4 + -2', '-1 - 3 - 3', '4 - 3 - -1', '-4 - -1 - -3', '-1 - -2 + 3', '-5 + -4 - -2', '-2 + -1 - -4', '-1 - -5 - -1', '-3 + -1 - -3', '1 + 2 - 0', '3 + 1 - 4', '-1 + 3 + -3', '-2 + -4 + 2', '0 + -3 - -4', '-2 + 2 + 3', '0 + 3 - -3', '-1 - 3 - -5', '-3 - 2 - -1', '4 - 2 - -1', '-3 - -2 + -4', '-2 + -2 + 1', '-5 - -5 + 1', '-2 + 2 - 1', '1 + -4 - -1', '-1 - -1 - 0', '-3 - -1 - -2', '2 + 0 - 1', '2 + 1 + -1', '2 + 4 - -4', '1 - 3 - -4', '-3 - 3 - -4', '-1 + -1 + -3', '1 + -5 - -2', '-4 - 2 + -2', '-4 + 3 + 0', '-1 - -2 + -3', '-4 + 0 + 1', '-3 - 1 + 4', '-5 + 0 + -2', '-2 - -3 - 1', '-3 + -2 - -3', '-3 - 3 - 2', '2 + 1 + -5', '2 + -4 - -5', '2 - 2 - 0', '2 - -4 + 3', '3 + -3 + -2', '4 + 3 + -3', '1 - -1 - -1', '-5 - 1 + 1', '2 + 1 - 4', '0 + -4 - 3', '-1 + 0 + 3', '0 - -1 + 2', '1 + -4 + -1', '-5 + 0 - -4', '-1 - -2 - -2', '2 - 2 + 0', '1 - 1 + 0', '-2 + -5 + 4', '2 + 2 - -1', '0 - 4 - -4', '4 - 2 - 3', '-3 - -5 + 4', '3 + -1 - -1', '-2 + 3 + -5', '0 - -4 - 1', '-3 + 2 + -5', '-1 - 4 + 0', '1 - -5 - -5', '-4 - -1 - 2', '2 + -4 - -2', '-4 - -2 + -2', '-2 - 3 - -5', '-2 - -5 + 0', '0 + 0 + -5', '-4 + 2 + -3', '-5 - 3 - 0', '-2 + -4 - 1', '3 + 4 + -5', '3 + -4 - -3', '2 - 4 + -1', '2 - -1 - -5', '2 + 4 + 0', '-4 - 0 - -1', '-1 - -1 - 1', '-2 + -1 + 1', '1 - -4 - 4', '-5 + 0 - 0', '1 + 4 + 0', '2 - 3 - -5', '2 - 2 - -5', '2 - 4 - 3', '-2 + 2 - 2', '0 - -1 + -2', '3 + 3 + 4', '-4 + 4 + 4', '1 - -4 + 3', '4 + 3 - -2', '2 - -5 - -4', '0 + -2 - -5', '3 + 3 + 3', '-1 + -3 - -2', '3 - 1 + -4', '2 + 1 + -4', '4 - -2 + 4', '-4 - 0 - 0', '3 + 2 + -3', '-1 + 2 - -1', '-1 + 0 - -2', '-3 + -5 + -1', '0 + -2 - -3', '-2 - -4 - 1', '2 - 1 - -3', '-2 - 2 + 0', '-4 - 2 + -4', '-5 + -1 - -5', '0 - 3 - -2', '-3 - 3 - -5', '0 + -1 - 4', '2 + -2 + -5', '-3 + -4 - -1', '-4 - -3 + 3', '3 + 4 + -3', '4 + -4 - 2', '0 - 1 - 4', '-5 - -1 + -1', '-2 + 0 - -3', '2 - 1 - 4', '-2 + -4 + -5', '0 - -3 + 0', '4 - -2 + 1', '-4 - -1 - 4', '-2 - 4 - -5', '-5 - 3 + -4', '-3 - 1 + -2', '-3 - -3 - 1', '2 + 3 - -1', '-1 + 2 + -2', '-3 - 2 - 4', '-5 + -4 + 3', '-1 - -4 + -2', '-4 - 1 + -5', '-5 + -2 - -5', '-4 - 3 + -2', '2 - 0 + -5', '-2 - -5 - -5', '-4 + 4 - -3', '1 + -5 - 3', '1 - -2 - -5', '0 - 0 - -4', '4 - 0 + -5', '3 + 4 - 0', '-4 + -2 + -1', '-5 + 4 + 0', '2 - -5 - 3', '1 + 1 + -5', '-5 + -3 - 2', '-3 - 0 - 2', '-2 - -4 + 1', '0 - 0 + 4', '0 - -5 + -3', '-5 - 4 + -2', '0 - -3 + 4', '4 - -2 - -3', '-5 + -3 + 3', '2 - 4 - -3', '-2 + 1 + -1', '2 + -3 + -2', '-1 + 3 - 0', '2 - 2 + -3', '4 + 4 - -5', '3 + -3 + -4', '3 + 2 - -3', '4 + 1 + -1', '-2 + 1 - -1', '2 - -5 - 2', '-2 - -5 + -3', '4 - 1 - -4', '1 - 3 + 0', '-4 - -5 + -1', '-2 - -1 - 1', '-1 + -5 + -3', '0 + 0 - 4', '-3 + 4 + 0', '-1 + 2 - 2', '-4 - -3 + -3', '-2 + 4 - 2', '2 + -3 + -5', '-1 - -3 + -4', '-4 - 0 - -4', '-1 + 1 + -2', '2 - -2 + 1', '1 + 3 - -5', '0 + -5 - 4', '-2 - -1 - 0', '0 - -1 + 4', '-2 + 2 + -3', '-1 - -3 - -3', '4 - 0 + 0', '3 - 1 + -1', '2 - -2 + -2', '4 + -2 + 0', '-1 - -4 + -4', '-2 - 1 + 0', '-5 + -4 + 4', '0 + 2 + -2', '-3 + 4 - -2', '1 - -1 + 1', '2 + 4 - -5', '-5 - -2 - -3', '-5 + 1 - 4', '2 + -2 + -3', '0 - -5 + -2', '-2 - -1 + 4', '-4 - -4 - -2', '-1 + 0 + 0', '2 + 2 - -2', '-4 - 0 + 0', '-1 - 0 - 4', '-4 - 3 + 0', '-5 + -4 + 2', '4 + -4 + 1', '-4 + 3 + 2', '-3 - -5 + 1', '-3 + -1 - 3', '1 + 4 + 3', '4 - -2 - 2', '-1 - 1 + -3', '-2 - 0 - -1', '-4 + 4 + -5', '1 - -2 + 0', '-2 + -1 - 2', '4 + 0 - -1', '-5 + 0 + 4', '3 - 3 + 3', '-3 + 2 + 0', '-3 - -2 ...
# True
# 1457

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.layers import PReLU

tf.random.set_seed(42)


x_train, x_val, y_train, y_val = \
    train_test_split(x, y, train_size=0.75)
x_train, x_val, y_train, y_val = \
    np.array(x_train), np.array(x_val), np.array(y_train), np.array(y_val)



model = keras.Sequential([
    keras.Input(shape=(len(x[0]),)),
    layers.Dense(32),
    PReLU(),
    layers.Dense(32),
    PReLU(),
    layers.Dense(1,  activation = "linear")
])

model.compile(optimizer = "adam", loss = "mse", metrics = ["mae", "mse"])

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
# Convert numpy arrays to TensorFlow Datasets
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train)).batch(32) # Use a batch size, e.g., 32
val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val)).batch(32) # Use the same batch size


history = model.fit(
    train_dataset, # Pass the TensorFlow Dataset
    validation_data=val_dataset, # Pass the TensorFlow Dataset
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['mse', 'val_mse']].plot()
plt.xlabel("Epoch")
plt.ylabel("Mean Squared Error")
plt.title("Training and Validation MSE per Epoch")
plt.show()
# Out:
# Epoch 1/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 22.4770 - mae: 3.7812 - mse: 22.4770 - val_loss: 19.9098 - val_mae: 3.6101 - val_mse: 19.9098
# Epoch 2/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 16.8670 - mae: 3.3310 - mse: 16.8670 - val_loss: 17.1284 - val_mae: 3.3672 - val_mse: 17.1284
# Epoch 3/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14.7070 - mae: 3.1197 - mse: 14.7070 - val_loss: 15.1548 - val_mae: 3.1333 - val_mse: 15.1548
# Epoch 4/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12.7025 - mae: 2.8759 - mse: 12.7025 - val_loss: 12.4227 - val_mae: 2.7938 - val_mse: 12.4227
# Epoch 5/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.9892 - mae: 2.5064 - mse: 9.9892 - val_loss: 8.8296 - val_mae: 2.2910 - val_mse: 8.8296
# Epoch 6/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6149 - mae: 1.9773 - mse: 6.6149 - val_loss: 5.0206 - val_mae: 1.6539 - val_mse: 5.0206
# Epoch 7/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4418 - mae: 1.3681 - mse: 3.4418 - val_loss: 2.4215 - val_mae: 1.1378 - val_mse: 2.4215
# Epoch 8/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6021 - mae: 0.9227 - mse: 1.6021 - val_loss: 1.3358 - val_mae: 0.8500 - val_mse: 1.3358
# Epoch 9/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9646 - mae: 0.7370 - mse: 0.9646 - val_loss: 0.9766 - val_mae: 0.7392 - val_mse: 0.9766
# Epoch 10/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7405 - mae: 0.6598 - mse: 0.7405 - val_loss: 0.8009 - val_mae: 0.6724 - val_mse: 0.8009
# Epoch 11/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6141 - mae: 0.6042 - mse: 0.6141 - val_loss: 0.6734 - val_mae: 0.6183 - val_mse: 0.6734
# Epoch 12/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5177 - mae: 0.5539 - mse: 0.5177 - val_loss: 0.5649 - val_mae: 0.5730 - val_mse: 0.5649
# Epoch 13/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4393 - mae: 0.5102 - mse: 0.4393 - val_loss: 0.4773 - val_mae: 0.5273 - val_mse: 0.4773
# Epoch 14/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3750 - mae: 0.4728 - mse: 0.3750 - val_loss: 0.4072 - val_mae: 0.4875 - val_mse: 0.4072
# Epoch 15/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3225 - mae: 0.4386 - mse: 0.3225 - val_loss: 0.3533 - val_mae: 0.4549 - val_mse: 0.3533
# Epoch 16/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2797 - mae: 0.4090 - mse: 0.2797 - val_loss: 0.3112 - val_mae: 0.4262 - val_mse: 0.3112
# Epoch 17/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2456 - mae: 0.3847 - mse: 0.2456 - val_loss: 0.2767 - val_mae: 0.4026 - val_mse: 0.2767
# Epoch 18/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2196 - mae: 0.3666 - mse: 0.2196 - val_loss: 0.2493 - val_mae: 0.3818 - val_mse: 0.2493
# Epoch 19/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1979 - mae: 0.3504 - mse: 0.1979 - val_loss: 0.2248 - val_mae: 0.3625 - val_mse: 0.2248
# Epoch 20/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1786 - mae: 0.3347 - mse: 0.1786 - val_loss: 0.2061 - val_mae: 0.3468 - val_mse: 0.2061
# Epoch 21/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1611 - mae: 0.3195 - mse: 0.1611 - val_loss: 0.1868 - val_mae: 0.3302 - val_mse: 0.1868
# Epoch 22/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1441 - mae: 0.3033 - mse: 0.1441 - val_loss: 0.1676 - val_mae: 0.3136 - val_mse: 0.1676
# Epoch 23/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1298 - mae: 0.2883 - mse: 0.1298 - val_loss: 0.1522 - val_mae: 0.2996 - val_mse: 0.1522
# Epoch 24/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1176 - mae: 0.2741 - mse: 0.1176 - val_loss: 0.1379 - val_mae: 0.2858 - val_mse: 0.1379
# Epoch 25/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1063 - mae: 0.2605 - mse: 0.1063 - val_loss: 0.1251 - val_mae: 0.2722 - val_mse: 0.1251
# Epoch 26/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0964 - mae: 0.2481 - mse: 0.0964 - val_loss: 0.1138 - val_mae: 0.2600 - val_mse: 0.1138
# Epoch 27/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0882 - mae: 0.2375 - mse: 0.0882 - val_loss: 0.1043 - val_mae: 0.2494 - val_mse: 0.1043
# Epoch 28/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0813 - mae: 0.2285 - mse: 0.0813 - val_loss: 0.0955 - val_mae: 0.2388 - val_mse: 0.0955
# Epoch 29/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0752 - mae: 0.2199 - mse: 0.0752 - val_loss: 0.0878 - val_mae: 0.2292 - val_mse: 0.0878
# Epoch 30/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0701 - mae: 0.2122 - mse: 0.0701 - val_loss: 0.0811 - val_mae: 0.2201 - val_mse: 0.0811
# Epoch 31/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0660 - mae: 0.2055 - mse: 0.0660 - val_loss: 0.0762 - val_mae: 0.2135 - val_mse: 0.0762
# Epoch 32/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0628 - mae: 0.2004 - mse: 0.0628 - val_loss: 0.0716 - val_mae: 0.2068 - val_mse: 0.0716
# Epoch 33/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0600 - mae: 0.1958 - mse: 0.0600 - val_loss: 0.0675 - val_mae: 0.2003 - val_mse: 0.0675
# Epoch 34/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0573 - mae: 0.1909 - mse: 0.0573 - val_loss: 0.0638 - val_mae: 0.1946 - val_mse: 0.0638
# Epoch 35/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0550 - mae: 0.1866 - mse: 0.0550 - val_loss: 0.0609 - val_mae: 0.1897 - val_mse: 0.0609
# Epoch 36/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0529 - mae: 0.1832 - mse: 0.0529 - val_loss: 0.0583 - val_mae: 0.1852 - val_mse: 0.0583
# Epoch 37/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0505 - mae: 0.1792 - mse: 0.0505 - val_loss: 0.0562 - val_mae: 0.1813 - val_mse: 0.0562
# Epoch 38/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0483 - mae: 0.1759 - mse: 0.0483 - val_loss: 0.0540 - val_mae: 0.1780 - val_mse: 0.0540
# Epoch 39/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0461 - mae: 0.1724 - mse: 0.0461 - val_loss: 0.0525 - val_mae: 0.1757 - val_mse: 0.0525
# Epoch 40/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0443 - mae: 0.1694 - mse: 0.0443 - val_loss: 0.0510 - val_mae: 0.1732 - val_mse: 0.0510
# Epoch 41/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0425 - mae: 0.1660 - mse: 0.0425 - val_loss: 0.0501 - val_mae: 0.1716 - val_mse: 0.0501
# Epoch 42/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0409 - mae: 0.1629 - mse: 0.0409 - val_loss: 0.0487 - val_mae: 0.1693 - val_mse: 0.0487
# Epoch 43/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0394 - mae: 0.1597 - mse: 0.0394 - val_loss: 0.0481 - val_mae: 0.1683 - val_mse: 0.0481
# Epoch 44/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0381 - mae: 0.1571 - mse: 0.0381 - val_loss: 0.0468 - val_mae: 0.1661 - val_mse: 0.0468
# Epoch 45/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0366 - mae: 0.1538 - mse: 0.0366 - val_loss: 0.0459 - val_mae: 0.1647 - val_mse: 0.0459
# Epoch 46/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0354 - mae: 0.1514 - mse: 0.0354 - val_loss: 0.0451 - val_mae: 0.1636 - val_mse: 0.0451
# Epoch 47/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0344 - mae: 0.1487 - mse: 0.0344 - val_loss: 0.0442 - val_mae: 0.1622 - val_mse: 0.0442
# Epoch 48/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0333 - mae: 0.1462 - mse: 0.0333 - val_loss: 0.0437 - val_mae: 0.1618 - val_mse: 0.0437
# Epoch 49/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0324 - mae: 0.1440 - mse: 0.0324 - val_loss: 0.0428 - val_mae: 0.1604 - val_mse: 0.0428
# Epoch 50/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0315 - mae: 0.1416 - mse: 0.0315 - val_loss: 0.0421 - val_mae: 0.1594 - val_mse: 0.0421
# Epoch 51/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0305 - mae: 0.1391 - mse: 0.0305 - val_loss: 0.0411 - val_mae: 0.1580 - val_mse: 0.0411
# Epoch 52/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0295 - mae: 0.1368 - mse: 0.0295 - val_loss: 0.0403 - val_mae: 0.1568 - val_mse: 0.0403
# Epoch 53/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0285 - mae: 0.1343 - mse: 0.0285 - val_loss: 0.0401 - val_mae: 0.1569 - val_mse: 0.0401
# Epoch 54/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0276 - mae: 0.1321 - mse: 0.0276 - val_loss: 0.0393 - val_mae: 0.1558 - val_mse: 0.0393
# Epoch 55/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0268 - mae: 0.1301 - mse: 0.0268 - val_loss: 0.0386 - val_mae: 0.1546 - val_mse: 0.0386
# Epoch 56/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0260 - mae: 0.1280 - mse: 0.0260 - val_loss: 0.0378 - val_mae: 0.1532 - val_mse: 0.0378
# Epoch 57/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0251 - mae: 0.1258 - mse: 0.0251 - val_loss: 0.0368 - val_mae: 0.1513 - val_mse: 0.0368
# Epoch 58/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0243 - mae: 0.1236 - mse: 0.0243 - val_loss: 0.0361 - val_mae: 0.1500 - val_mse: 0.0361
# Epoch 59/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0235 - mae: 0.1217 - mse: 0.0235 - val_loss: 0.0356 - val_mae: 0.1491 - val_mse: 0.0356
# Epoch 60/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0227 - mae: 0.1198 - mse: 0.0227 - val_loss: 0.0348 - val_mae: 0.1475 - val_mse: 0.0348
# Epoch 61/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0220 - mae: 0.1179 - mse: 0.0220 - val_loss: 0.0339 - val_mae: 0.1457 - val_mse: 0.0339
# Epoch 62/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0213 - mae: 0.1161 - mse: 0.0213 - val_loss: 0.0330 - val_mae: 0.1435 - val_mse: 0.0330
# Epoch 63/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0208 - mae: 0.1146 - mse: 0.0208 - val_loss: 0.0320 - val_mae: 0.1411 - val_mse: 0.0320
# Epoch 64/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0201 - mae: 0.1127 - mse: 0.0201 - val_loss: 0.0312 - val_mae: 0.1393 - val_mse: 0.0312
# Epoch 65/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0196 - mae: 0.1111 - mse: 0.0196 - val_loss: 0.0300 - val_mae: 0.1367 - val_mse: 0.0300
# Epoch 66/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0189 - mae: 0.1092 - mse: 0.0189 - val_loss: 0.0294 - val_mae: 0.1356 - val_mse: 0.0294
# Epoch 67/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0185 - mae: 0.1077 - mse: 0.0185 - val_loss: 0.0290 - val_mae: 0.1346 - val_mse: 0.0290
# Epoch 68/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0181 - mae: 0.1064 - mse: 0.0181 - val_loss: 0.0285 - val_mae: 0.1336 - val_mse: 0.0285
# Epoch 69/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0176 - mae: 0.1053 - mse: 0.0176 - val_loss: 0.0278 - val_mae: 0.1320 - val_mse: 0.0278
# Epoch 70/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0172 - mae: 0.1040 - mse: 0.0172 - val_loss: 0.0274 - val_mae: 0.1310 - val_mse: 0.0274
# Epoch 71/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0168 - mae: 0.1028 - mse: 0.0168 - val_loss: 0.0272 - val_mae: 0.1306 - val_mse: 0.0272
# Epoch 72/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0165 - mae: 0.1021 - mse: 0.0165 - val_loss: 0.0268 - val_mae: 0.1297 - val_mse: 0.0268
# Epoch 73/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0162 - mae: 0.1011 - mse: 0.0162 - val_loss: 0.0269 - val_mae: 0.1302 - val_mse: 0.0269
# Epoch 74/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0159 - mae: 0.1004 - mse: 0.0159 - val_loss: 0.0265 - val_mae: 0.1296 - val_mse: 0.0265
# Epoch 75/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0157 - mae: 0.0997 - mse: 0.0157 - val_loss: 0.0263 - val_mae: 0.1295 - val_mse: 0.0263
# Epoch 76/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0155 - mae: 0.0991 - mse: 0.0155 - val_loss: 0.0264 - val_mae: 0.1300 - val_mse: 0.0264
# Epoch 77/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0154 - mae: 0.0988 - mse: 0.0154 - val_loss: 0.0267 - val_mae: 0.1306 - val_mse: 0.0267
# Epoch 78/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0153 - mae: 0.0987 - mse: 0.0153 - val_loss: 0.0271 - val_mae: 0.1318 - val_mse: 0.0271
# Epoch 79/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0153 - mae: 0.0986 - mse: 0.0153 - val_loss: 0.0272 - val_mae: 0.1322 - val_mse: 0.0272
# Epoch 80/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0154 - mae: 0.0985 - mse: 0.0154 - val_loss: 0.0275 - val_mae: 0.1334 - val_mse: 0.0275

# %%
model.predict(tokenizer(["1 + 1 + 1"]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# array([[2.9099107]], dtype=float32)

# %%
y_test = []
for i in expressions_not_in_x:
  result = float(eval(i))
  y_test.append(result)
x_test = tokenizer(expressions_not_in_x)
print(y_test[0])
x_test = np.array(x_test)
store = model.predict(x_test)
print(len(store))
differences = []
for i in range(len(store)):
  differences.append(abs(store[i] - y_test[i]))
print(np.mean(differences))
plt.figure(figsize=(10, 6))
plt.plot(differences)
plt.axhline(y = np.mean(differences), color='r', linestyle='-', label='Mean Difference') # Plot a horizontal line at the mean difference
plt.xlabel("Test Sample Index")
plt.ylabel("Absolute Difference (Predicted - Actual)")
plt.title("Absolute Differences Between Predicted and Actual Values for Test Set")
plt.show()
# Out:
# 4.0
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1457
# 0.12721205

# %%
#a list of expressions outside the number range
outsideExpr = set()
range1= range(5, 9)
range2= range(-8, -4)
comboRange = list(range1) + list(range2)
for num1 in comboRange:
    for num2 in comboRange:
        for num3 in comboRange:
            for op1 in [" + ", " - "]:
                for op2 in [" + ", " - "]:
                    expression = str(num1) + op1 + str(num2) + op2 + str(num3)
                    outsideExpr.add(expression)

outsideExpr = list(outsideExpr)
print(len(tokenizer(outsideExpr)[0]))

out_x_test = tokenizer(outsideExpr)
out_y_test = []
for i in outsideExpr:
  result = float(eval(i))
  out_y_test.append(result)
# Out:
# 15

# %%
minNums = 2
maxNums = 8
amountNums = 100
num_terms = np.arange(minNums-1,maxNums)
longer_Exps = []
for j in num_terms:
  for p in range(amountNums):
    longer_Exp = ""
    for i in range(j):
      longer_Exp += str(np.random.randint(-5,6))
      longer_Exp += np.random.choice([" + ", " - "])
    longer_Exp += str(np.random.randint(-5,6))
    longer_Exps.append(longer_Exp)
print(longer_Exps)

longer_Exps = list(longer_Exps)
long_x_test = tokenizer(longer_Exps)
long_y_test = []
for i in longer_Exps:
  result = float(eval(i))
  long_y_test.append(result)
print(long_y_test[0])
print(long_x_test[0])
# Out:
# ['-2 - -1', '-3 - -1', '1 + -4', '3 - 0', '0 + -3', '4 + 3', '-2 + -3', '-1 - 2', '2 - -5', '5 - 0', '5 - 1', '3 - 2', '5 - 2', '1 - -5', '-4 + 0', '-4 - -2', '4 + 0', '2 + 0', '-4 + 5', '0 + 0', '4 + -5', '4 + -1', '0 + -2', '1 + 0', '-2 - 2', '3 - 5', '-2 - 5', '2 - 3', '-3 + 3', '-5 + -3', '3 + -5', '1 - 1', '-5 + 4', '4 - 4', '4 - -3', '2 + -5', '3 - -2', '2 - -1', '-3 - -5', '4 + 5', '0 - 1', '-3 + -5', '1 + 5', '-5 - -4', '-2 + -5', '-2 - -2', '-2 + 3', '-5 + 1', '-2 - -1', '-4 + 1', '4 + 1', '-2 - -5', '-5 - -2', '-2 - 1', '3 + 4', '-1 - 5', '-3 + 0', '-5 + -3', '-1 - 1', '1 - 3', '-5 + 3', '2 - 2', '2 - 2', '-3 + 3', '-2 + 5', '0 + 5', '5 + -5', '-3 + 3', '-3 + 5', '4 - -2', '-1 + 1', '3 + 2', '-4 - 2', '2 + -3', '3 - 1', '-5 - 4', '-1 - 3', '4 + 2', '5 - -3', '-1 - -2', '-5 + 4', '1 + -2', '0 + 3', '5 - -4', '5 + 4', '-1 + 1', '-3 - 1', '-1 - 0', '0 + 5', '-2 - 2', '3 - 3', '5 - -2', '0 - 1', '-2 - 4', '2 + 2', '4 - -3', '-1 - 4', '2 + 0', '-2 + -2', '-2 - 1', '-1 - 2 - 1', '2 + -2 - 0', '-3 + 2 + 1', '4 + 5 - -5', '4 + -4 - 2', '-1 - -1 - 5', '-2 + -5 + 0', '-2 - -3 - 3', '-3 - -4 - -5', '5 + -4 + -5', '-5 - -1 - 3', '0 - -2 + -3', '2 + -5 - 5', '-1 - -1 - -1', '2 - 2 - -2', '3 - -5 + -1', '-1 - 3 + 3', '5 - -3 - -2', '-4 - -1 - 2', '-5 + 1 - -5', '5 + -4 + -4', '-4 - 5 - 1', '0 + 0 + 3', '2 - 2 - -1', '3 - -4 + 0', '1 - -2 + 1', '-4 + -2 + -4', '4 - -5 + -3', '-5 + -1 - 1', '3 - 2 - 0', '-3 - 2 - -2', '-1 + 3 + 3', '2 - -4 - -3', '2 + -1 + 2', '0 + -1 - -5', '-5 + -3 - 0', '0 + 1 + -4', '-2 + 1 - -2', '-2 + 2 - 2', '3 + -2 - 2', '0 - 0 - -2', '3 - 1 - 5', '0 + -4 - 0', '5 - -5 + 5', '-1 + -3 - 1', '-1 + 4 + -5', '2 + 3 + -3', '0 + 4 - -2', '-3 - 0 + 5', '3 + -3 + 3', '-3 - -5 + 3', '-4 - 4 - 2', '3 + 3 - 0', '1 - -1 - 5', '-5 + 3 - -1', '-1 - 5 + -4', '1 + 1 - -1', '0 - 1 + -2', '-3 - -2 + -4', '5 - 3 + 1', '0 - -5 - 1', '-4 + 2 + 5', '5 - 5 + -2', '1 + 5 + -4', '1 + -4 - 4', '3 + -1 - 1', '-5 - 3 + -1', '0 + 5 - 2', '-2 - 4 - -4', '-1 + 0 + 0', '0 + 5 + -3', '3 + -3 + -4', '1 - 4 - -5', '0 + 5 - 0', '-5 + -2 + -3', '0 + -2 - -5', '-1 + 3 - 2', '2 + 2 - 4', '1 + 1 + 2', '-3 + 2 - 0', '-2 + 5 - 4', '3 - 4 - 4', '-1 - -2 + -4', '1 - -5 + -1', '-4 - 2 + -2', '3 + 5 - 0', '-3 + -5 - 5', '0 - -4 - -2', '3 + -1 - -3', '-5 - 2 + 5', '-5 + 5 - 1', '1 - -3 - 0', '2 - -5 + 3', '5 - 3 + 3', '5 - 0 + -5', '5 - 4 + 1', '4 - -3 - -3', '3 + -5 + 2', '-1 + -2 + 3', '3 + -1 - 5', '3 + 4 - 3 + 2', '-5 - 4 - -2 - 3', '-3 + 4 + 4 + 5', '-1 + -2 + 0 - -3', '4 - -1 - 0 - -2', '-3 + 1 + 0 - -5', '-1 + 0 + -5 + -2', '-2 - -4 - 2 - -3', '-5 - 5 + 2 - -3', '5 - 5 - -2 - -2', '5 - 3 - -5 + -5', '-1 - 0 - 0 + -5', '4 - 2 - 2 - -3', '-1 - -2 - -5 + -1', '-4 - -4 + 1 - -5', '-1 - 1 - 3 + -5', '-4 + 0 - 1 + -4', '3 - 5 + -3 + -1', '-1 - -4 - 0 - -2', '-1 + 2 - -1 - -3', '1 - -3 + 5 - 4', '4 - -2 - -2 - 2', '-3 + 5 + -4 + -2', '3 + -4 + 3 - 5', '0 + -2 - 1 + 3', '0 + 5 - -2 + -2', '-3 + 5 + 5 - -1', '-3 - -4 + -4 + 2', '2 - -1 + -4 + -2', '1 - 0 - 1 + -4', '2 - -4 - 2 - 1', '-3 + -2 + 1 - 3', '1 + -5 + -2 - 3', '-2 + -1 + -4 + -2', '-2 + 4 - 0 - 3', '-5 + 0 - 5 - -5', '3 - 5 + -1 - -5', '2 + -5 - 0 + -3', '-1 - 1 - -3 - 5', '2 - -4 - 1 - -5', '-4 - -5 - -5 + 1', '0 - 0 - -1 + 4', '1 + 3 - -3 - 0', '-3 + -5 + -2 - -4', '3 + 5 - -3 + -2', '-1 - 3 - 5 + -2', '2 - 1 + -5 - 0', '-1 + 3 + 3 + 3', '-4 + 5 - -5 + -2', '-1 - 0 + -4 - -2', '2 + 5 - -1 - -3', '1 + -3 + 2 + -4', '-3 - 1 + 4 + -4', '-2 + -1 - -5 + 1', '1 + -5 - 5 + 5', '-4 + -1 - -1 + -2', '5 + 4 - -4 + -2', '5 + 3 + -3 + 3', '2 + 0 - 4 + 5', '3 - 4 + -3 - 4', '4 - 4 + 2 + 4', '-4 - -2 - -4 + 2', '-3 - 1 + -5 + 0', '-3 + -3 + -1 - -3', '-2 + -3 - 1 - -3', '4 - -4 - 3 + -5', '-5 - 4 + -3 - -3', '-1 + -4 - 5 + -5', '5 - -3 + 1 - 5', '1 + -1 + -3 + 1', '-3 + -1 - -2 + 1', '-5 + 2 + -3 - 0', '1 + -2 - 1 - 5', '-4 + -5 - 0 - -1', '-5 - -3 + 5 + 3', '3 + 0 + -5 + 4', '-4 + -1 - -1 - -5', '-3 - -1 + -1 - 4', '-1 + 2 - 2 + -3', '5 - -5 - 3 + -1', '3 - 3 + -2 + -4', '-4 - -5 - -2 - 5', '0 - 0 + -1 + -4 ...
# -1.0
# [-2.   0.  -1.   0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5
#   0.5]

# %%
# prompt: bootstrap the model 10 times and calculate a range for predictions

n_bootstrap = 10
predictions = []
out_predictions = []
long_predictions = []

for _ in range(n_bootstrap):
  # Create bootstrap sample
  sample_indices = np.random.choice(len(x_train), size=len(x_train), replace=True)
  x_train_bootstrap = x_train[sample_indices]
  y_train_bootstrap = np.array(y_train)[sample_indices]

  # Re-compile and train the model
  bootstrap_model = keras.models.clone_model(model)
  bootstrap_model.compile(optimizer="adam", loss="mse", metrics=["mae", "mse"])

  bootstrap_train_dataset = tf.data.Dataset.from_tensor_slices((x_train_bootstrap, y_train_bootstrap)).batch(32)
  bootstrap_model.fit(
      bootstrap_train_dataset,
      epochs=50,  # Reduced epochs for quicker example, adjust as needed
      verbose=0, # Suppress output
      callbacks=[early_stopping]
  )

  # Make predictions on the test set
  predictions.append(bootstrap_model.predict(x_test))
  out_predictions.append(bootstrap_model.predict(out_x_test))
  long_predictions.append(bootstrap_model.predict(long_x_test))

# Convert predictions to a numpy array for easier processing
predictions = np.array(predictions)
out_predictions = np.array(out_predictions)
long_predictions = np.array(long_predictions)

#calculate the mean thingy
meanPredictions = []
for i in range(len(expressions_not_in_x)):
  calc = 0
  for j in range(n_bootstrap):
    calc += predictions[j][i]
  meanPredictions.append(calc/n_bootstrap)


# Calculate the lower and upper bounds of the prediction range
lower_bound = np.percentile(predictions, 5, axis=0)
upper_bound = np.percentile(predictions, 95, axis=0)

inRange = []
outOfBounds = 0
for i in range(len(x_test)):
  if y_test[i] >= lower_bound[i][0] and y_test[i] <= upper_bound[i][0]:
    inRange.append(True)
  else:
    inRange.append(False)
    outOfBounds += 1


print("Prediction Range (5th to 95th percentile):")
for i in range(len(x_test)):
  print(f"Input: {expressions_not_in_x[i]}, Actual: {y_test[i]:.2f}, Predicted Range: [{lower_bound[i][0]:.2f}, {upper_bound[i][0]:.2f}], bootstrapped prediction: {meanPredictions[i]}, in Range: {inRange[i]}")

print(f"Amount out of bounds: {outOfBounds}, Amount of expressions: {len(x_test)}, Percentage in bounds: {(1-(outOfBounds/len(x_test)))*100}%")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 5s 130ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Prediction Range (5th to 95th percentile):
# Input: -3 + 3 - -4, Actual: 4.00, Predicted Range: [3.88, 4.27], bootstrapped prediction: [4.0585947], in Range: True
# Input: -4 - 1 - -2, Actual: -3.00, Predicted Range: [-3.28, -2.75], bootstrapped prediction: [-3.0627224], in Range: True
# Input: 1 + -3 - 1, Actual: -3.00, Predicted Range: [-3.29, -2.67], bootstrapped prediction: [-2.9761992], in Range: True
# Input: 0 - -3 - 4, Actual: -1.00, Predicted Range: [-1.40, -0.81], bootstrapped prediction: [-1.0167946], in Range: True
# Input: 4 + -1 + -1, Actual: 2.00, Predicted Range: [1.75, 2.48], bootstrapped prediction: [2.0811], in Range: True
# Input: 4 + 3 + 3, Actual: 10.00, Predicted Range: [9.82, 10.39], bootstrapped prediction: [10.09795], in Range: True
# Input: -5 - 2 - 4, Actual: -11.00, Predicted Range: [-11.05, -10.27], bootstrapped prediction: [-10.717534], in Range: True
# Input: -2 + -3 - 0, Actual: -5.00, Predicted Range: [-5.35, -4.73], bootstrapped prediction: [-5.003982], in Range: True
# Input: -1 - 4 + -1, Actual: -6.00, Predicted Range: [-6.18, -5.79], bootstrapped prediction: [-5.972089], in Range: True
# Input: -4 + -2 + 0, Actual: -6.00, Predicted Range: [-6.22, -5.71], bootstrapped prediction: [-5.975491], in Range: True
# Input: 1 - 3 - 2, Actual: -4.00, Predicted Range: [-4.46, -3.89], bootstrapped prediction: [-4.1155953], in Range: True
# Input: -4 - -5 - -5, Actual: 6.00, Predicted Range: [5.27, 6.05], bootstrapped prediction: [5.6350994], in Range: True
# Input: -1 - -5 - 0, Actual: 4.00, Predicted Range: [3.43, 4.31], bootstrapped prediction: [3.9364219], in Range: True
# Input: 4 - -3 + 1, Actual: 8.00, Predicted Range: [7.42, 8.24], bootstrapped prediction: [7.89277], in Range: True
# Input: 3 + -5 + 3, Actual: 1.00, Predicted Range: [0.86, 1.59], bootstrapped prediction: [1.1862005], in Range: True
# Input: 3 + 0 - -2, Actual: 5.00, Predicted Range: [4.71, 5.11], bootstrapped prediction: [4.905896], in Range: True
# Input: 1 + -5 + -5, Actual: -9.00, Predicted Range: [-8.97, -8.39], bootstrapped prediction: [-8.71149], in Range: False
# Input: 2 - 4 - 0, Actual: -2.00, Predicted Range: [-2.37, -1.72], bootstrapped prediction: [-2.0175502], in Range: True
# Input: -1 - -4 + 2, Actual: 5.00, Predicted Range: [4.82, 5.34], bootstrapped prediction: [5.121198], in Range: True
# Input: -4 - 1 + 2, Actual: -3.00, Predicted Range: [-3.26, -2.77], bootstrapped prediction: [-3.0531032], in Range: True
# Input: 1 - 3 - -3, Actual: 1.00, Predicted Range: [0.53, 1.09], bootstrapped prediction: [0.8708445], in Range: True
# Input: 2 + 4 + -5, Actual: 1.00, Predicted Range: [0.50, 1.36], bootstrapped prediction: [1.0228256], in Range: True
# Input: -3 - 2 + 1, Actual: -4.00, Predicted Range: [-4.19, -3.78], bootstrapped prediction: [-3.9757152], in Range: True
# Input: -1 + 0 - 0, Actual: -1.00, Predicted Range: [-1.38, -0.89], bootstrapped prediction: [-1.1416146], in Range: True
# Input: -5 - 2 + 1, Actual: -6.00, Predicted Range: [-6.26, -5.71], bootstrapped prediction: [-6.0437126], in Range: True
# Input: 4 - 2 + 3, Actual: 5.00, Predicted Range: [4.55, 5.18], bootstrapped prediction: [4.920887], in Range: True
# Input: 0 - -5 + 4, Actual: 9.00, Predicted Range: [8.51, 9.12], bootstrapped prediction: [8.826216], in Range: True
# Input: 4 - 3 + -5, Actual: -4.00, Predicted Range: [-3.93, -3.33], bootstrapped prediction: [-3.6848557], in Range: False
# Input: 0 + 3 + -3, Actual: 0.00, Predicted Range: [-0.37, 0.14], bootstrapped prediction: [-0.09778772], in Range: True
# Input: 3 + 0 + 2, Actual: 5.00, Predicted Range: [4.73, 5.27], bootstrapped prediction: [4.992483], in Range: True
# Input: -1 - 2 + -2, Actual: -5.00, Predicted Range: [-5.34, -4.94], bootstrapped prediction: [-5.12533], in Range: True
# Input: -4 + 4 - -2, Actual: 2.00, Predicted Range: [1.49, 2.36], bootstrapped prediction: [1.8446324], in Range: True
# Input: -3 - -4 - -1, Actual: 2.00, Predicted Range: [1.80, 2.10], bootstrapped prediction: [1.9782894], in Range: True
# Input: -3 + 1 - -3, Actual: 1.00, Predicted Range: [0.86, 1.21], bootstrapped prediction: [1.0505579], in Range: True
# Input: 3 - -5 - -1, Actual: 9.00, Predicted Range: [8.47, 9.13], bootstrapped prediction: [8.842046], in Range: True
# Input: 0 - -5 + 3, Actual: 8.00, Predicted Range: [7.57, 8.44], bootstrapped prediction: [7.9603186], in Range: True
# Input: -2 - -4 + 2, Actual: 4.00, Predicted Range: [3.81, 4.38], bootstrapped prediction: [4.0945406], in Range: True
# Input: 2 + 1 + 1, Actual: 4.00, Predicted Range: [3.74, 4.29], bootstrapped prediction: [3.996179], in Range: True
# Input: 4 + 4 + -2, Actual: 6.00, Predicted Range: [5.58, 6.25], bootstrapped prediction: [5.886672], in Range: True
# Input: -1 - 3 - 3, Actual: -7.00, Predicted Range: [-7.63, -6.97], bootstrapped prediction: [-7.174568], in Range: True
# Input: 4 - 3 - -1, Actual: 2.00, Predicted Range: [1.64, 2.21], bootstrapped prediction: [1.9531736], in Range: True
# Input: -4 - -1 - -3, Actual: 0.00, Predicted Range: [-0.27, 0.18], bootstrapped prediction: [-0.07983556], in Range: True
# Input: -1 - -2 + 3, Actual: 4.00, Predicted Range: [3.75, 4.40], bootstrapped prediction: [4.115559], in Range: True
# Input: -5 + -4 - -2, Actual: -7.00, Predicted Range: [-7.28, -6.82], bootstrapped prediction: [-7.0416565], in Range: True
# Input: -2 + -1 - -4, Actual: 1.00, Predicted Range: [0.71, 1.31], bootstrapped prediction: [1.0209765], in Range: True
# Input: -1 - -5 - -1, Actual: 5.00, Predicted Range: [4.51, 5.14], bootstrapped prediction: [4.860591], in Range: True
# Input: -3 + -1 - -3, Actual: -1.00, Predicted Range: [-1.35, -0.80], bootstrapped prediction: [-1.0394336], in Range: True
# Input: 1 + 2 - 0, Actual: 3.00, Predicted Range: [2.74, 3.21], bootstrapped prediction: [3.0160272], in Range: True
# Input: 3 + 1 - 4, Actual: 0.00, Predicted Range: [-0.33, 0.20], bootstrapped prediction: [-0.03394974], in Range: True
# Input: -1 + 3 + -3, Actual: -1.00, Predicted Range: [-1.44, -0.79], bootstrapped prediction: [-1.0467321], in Range: True
# Input: -2 + -4 + 2, Actual: -4.00, Predicted Range: [-4.45, -3.77], bootstrapped prediction: [-4.047362], in Range: True
# Input: 0 + -3 - -4, Actual: 1.00, Predicted Range: [0.73, 1.15], bootstrapped prediction: [0.9591983], in Range: True
# Input: -2 + 2 + 3, Actual: 3.00, Predicted Range: [2.90, 3.48], bootstrapped prediction: [3.1273901], in Range: True
# Input: 0 + 3 - -3, Actual: 6.00, Predicted Range: [6.02, 6.45], bootstrapped prediction: [6.204352], in Range: False
# Input: -1 - 3 - -5, Actual: 1.00, Predicted Range: [0.66, 1.25], bootstrapped prediction: [0.9358042], in Range: True
# Input: -3 - 2 - -1, Actual: -4.00, Predicted Range: [-4.31, -3.65], bootstrapped prediction: [-4.006777], in Range: True
# Input: 4 - 2 - -1, Actual: 3.00, Predicted Range: [2.68, 3.15], bootstrapped prediction: [2.9252758], in Range: True
# Input: -3 - -2 + -4, Actual: -5.00, Predicted Range: [-5.38, -4.70], bootstrapped prediction: [-5.1060615], in Range: True
# Input: -2 + -2 + 1, Actual: -3.00, Predicted Range: [-3.28, -2.77], bootstrapped prediction: [-3.080623], in Range: True
# Input: -5 - -5 + 1, Actual: 1.00, Predicted Range: [0.71, 1.21], bootstrapped prediction: [0.9575518], in Range: True
# Input: -2 + 2 - 1, Actual: -1.00, Predicted Range: [-1.16, -0.63], bootstrapped prediction: [-0.83691084], in Range: True
# Input: 1 + -4 - -1, Actual: -2.00, Predicted Range: [-2.31, -1.90], bootstrapped prediction: [-2.0961003], in Range: True
# Input: -1 - -1 - 0, Actual: 0.00, Predicted Range: [-0.19, 0.23], bootstrapped prediction: [0.03130718], in Range: True
# Input: -3 - -1 - -2, Actual: 0.00, Predicted Range: [-0.26, 0.27], bootstrapped prediction: [-0.05961195], in Range: True
# Input: 2 + 0 - 1, Actual: 1.00, Predicted Range: [0.72, 1.18], bootstrapped prediction: [0.92258406], in Range: True
# Input: 2 + 1 + -1, Actual: 2.00, Predicted Range: [1.74, 2.35], bootstrapped prediction: [2.07723], in Range: True
# Input: 2 + 4 - -4, Actual: 10.00, Predicted Range: [9.67, 9.91], bootstrapped prediction: [9.816123], in Range: False
# Input: 1 - 3 - -4, Actual: 2.00, Predicted Range: [1.71, 2.05], bootstrapped prediction: [1.8534505], in Range: True
# Input: -3 - 3 - -4, Actual: -2.00, Predicted Range: [-2.12, -1.72], bootstrapped prediction: [-1.9563377], in Range: True
# Input: -1 + -1 + -3, Actual: -5.00, Predicted Range: [-5.31, -4.71], bootstrapped prediction: [-4.9916677], in Range: True
# Input: 1 + -5 - -2, Actual: -2.00, Predicted Range: [-2.37, -1.58], bootstrapped prediction: [-1.9584357], in Range: True
# Input: -4 - 2 + -2, Actual: -8.00, Predicted Range: [-8.18, -7.86], bootstrapped prediction: [-8.047208], in Range: True
# Input: -4 + 3 + 0, Actual: -1.00, Predicted Range: [-1.30, -0.74], bootstrapped prediction: [-1.0362816], in Range: True
# Input: -1 - -2 + -3, Actual: -2.00, Predicted Range: [-2.28, -1.83], bootstrapped prediction: [-2.0656462], in Range: True
# Input: -4 + 0 + 1, Actual: -3.00, Predicted Range: [-3.12, -2.79], bootstrapped prediction: [-2.9976265], in Range: True
# Input: -3 - 1 + 4, Actual: 0.00, Predicted Range: [-0.28, 0.27], bootstrapped prediction: [0.01288143], in Range: True
# Input: -5 + 0 + -2, Actual: -7.00, Predicted Range: [-7.21, -6.65], bootstrapped prediction: [-6.909115], in Range: True
# Input: -2 - -3 - 1, Actual: 0.00, Predicted Range: [-0.18, 0.44], bootstrapped prediction: [0.07911159], in Range: True
# Input: -3 + -2 - -3, Actual: -2.00, Predicted Range: [-2.34, -1.74], bootstrapped prediction: [-1.9870784], in Range: True
# Input: -3 - 3 - 2, Actual: -8.00, Predicted Range: [-8.49, -7.88], bootstrapped prediction: [-8.172651], in Range: True
# Input: 2 + 1 + -5, Actual: -2.00, Predicted Range: [-2.25, -1.72], bootstrapped prediction: [-1.9716479], in Range: True
# Input: 2 + -4 - -5, Actual: 3.00, Predicted Range: [2.53, 3.19], bootstrapped prediction: [2.8356233], in Range: True
# Input: 2 - 2 - 0, Actual: 0.00, Predicted Range: [-0.23, 0.21], bootstrapped prediction: [-0.00427112], in Range: True
# Input: 2 - -4 + 3, Actual: 9.00, Predicted Range: [8.96, 9.39], bootstrapped prediction: [9.170355], in Range: True
# Input: 3 + -3 + -2, Actual: -2.00, Predicted Range: [-2.58, -1.81], bootstrapped prediction: [-2.0619314], in Range: True
# Input: 4 + 3 + -3, Actual: 4.00, Predicted Range: [3.66, 4.26], bootstrapped prediction: [3.966278], in Range: True
# Input: 1 - -1 - -1, Actual: 3.00, Predicted Range: [2.85, 3.33], bootstrapped prediction: [3.0729232], in Range: True
# Input: -5 - 1 + 1, Actual: -5.00, Predicted Range: [-5.36, -4.71], bootstrapped prediction: [-5.0189314], in Range: True
# Input: 2 + 1 - 4, Actual: -1.00, Predicted Range: [-1.31, -0.66], bootstrapped prediction: [-1.0257413], in Range: True
# Input: 0 + -4 - 3, Actual: -7.00, Predicted Range: [-7.27, -6.85], bootstrapped prediction: [-7.0655456], in Range: True
# Input: -1 + 0 + 3, Actual: 2.00, Predicted Range: [1.82, 2.24], bootstrapped prediction: [2.047274], in Range: True
# Input: 0 - -1 + 2, Actual: 3.00, Predicted Range: [2.69, 3.36], bootstrapped prediction: [3.0057893], in Range: True
# Input: 1 + -4 + -1, Actual: -4.00, Predicted Range: [-4.26, -3.85], bootstrapped prediction: [-4.0674815], in Range: True
# Input: -5 + 0 - -4, Actual: -1.00, Predicted Range: [-1.35, -0.80], bootstrapped prediction: [-1.0668297], in Range: True
# Input: -1 - -2 - -2, Actual: 3.00, Predicted Range: [2.74, 3.07], bootstrapped prediction: [2.9653528], in Range: True
# Input: 2 - 2 + 0, Actual: 0.00, Predicted Range: [-0.23, 0.17], bootstrapped prediction: [-0.04319348], in Range: True
# Input: 1 - 1 + 0, Actual: 0.00, Predicted Range: [-0.32, 0.24], bootstrapped prediction: [-0.03059584], in Range: True
# Input: -2 + -5 + 4, Actual: -3.00, Predicted Range: [-3.24, -2.84], bootstrapped prediction: [-3.0007584], in Range: True
# Input: 2 + 2 - -1, Actual: 5.00, Predicted Range: [4.85, 5.25], bootstrapped prediction: [5.0024786], in Range: True
# Input: 0 - 4 - -4, Actual: 0.00, Predicted Range: [-0.21, 0.19], bootstrapped prediction: [-0.01592162], in Range: True
# Input: 4 - 2 - 3, Actual: -1.00, Predicted Range: [-1.39, -0.93], bootstrapped prediction: [-1.0999912], in Range: True
# Input: -3 - -5 + 4, Actual: 6.00, Predicted Range: [5.47, 6.09], bootstrapped prediction: [5.8324747], in Range: True
# Input: 3 + -1 - -1, Actual: 3.00, Predicted Range: [2.81, 3.40], bootstrapped prediction: [3.0848606], in Range: True
# Input: -2 + 3 + -5, Actual: -4.00, Predicted Range: [-4.08, -3.57], bootstrapped prediction: [-3.8733432], in Range: True
# Input: 0 - -4 - 1, Actual: 3.00, Predicted Range: [2.87, 3.39], bootstrapped prediction: [3.163039], in Range: True
# Input: -3 + 2 + -5, Actual: -6.00, Predicted Range: [-6.11, -5.68], bootstrapped prediction: [-5.8996224], in Range: True
# Input: -1 - 4 + 0, Actual: -5.00, Predicted Range: [-5.24, -4.81], bootstrapped prediction: [-5.044436], in Range: True
# Input: 1 - -5 - -5, Actual: 11.00, Predicted Range: [10.30, 10.93], bootstrapped prediction: [10.695536], in Range: False
# Input: -4 - -1 - 2, Actual: -5.00, Predicted Range: [-5.35, -4.77], bootstrapped prediction: [-5.0909743], in Range: True
# Input: 2 + -4 - -2, Actual: 0.00, Predicted Range: [-0.30, 0.06], bootstrapped prediction: [-0.10154669], in Range: True
# Input: -4 - -2 + -2, Actual: -4.00, Predicted Range: [-4.26, -4.03], bootstrapped prediction: [-4.1495767], in Range: False
# Input: -2 - 3 - -5, Actual: 0.00, Predicted Range: [-0.25, 0.26], bootstrapped prediction: [-0.00885944], in Range: True
# Input: -2 - -5 + 0, Actual: 3.00, Predicted Range: [2.81, 3.21], bootstrapped prediction: [2.9869266], in Range: True
# Input: 0 + 0 + -5, Actual: -5.00, Predicted Range: [-5.19, -4.71], bootstrapped prediction: [-4.9247375], in Range: True
# Input: -4 + 2 + -3, Actual: -5.00, Predicted Range: [-5.36, -5.06], bootstrapped prediction: [-5.1316605], in Range: False
# Input: -5 - 3 - 0, Actual: -8.00, Predicted Range: [-8.24, -7.63], bootstrapped prediction: [-7.949988], in Range: True
# Input: -2 + -4 - 1, Actual: -7.00, Predicted Range: [-7.32, -6.61], bootstrapped prediction: [-7.0262537], in Range: True
# Input: 3 + 4 + -5, Actual: 2.00, Predicted Range: [1.54, 2.37], bootstrapped prediction: [2.074458], in Range: True
# Input: 3 + -4 - -3, Actual: 2.00, Predicted Range: [1.69, 2.17], bootstrapped prediction: [1.9249852], in Range: True
# Input: 2 - 4 + -1, Actual: -3.00, Predicted Range: [-3.28, -2.69], bootstrapped prediction: [-2.9783778], in Range: True
# Input: 2 - -1 - -5, Actual: 8.00, Predicted Range: [7.75, 8.29], bootstrapped prediction: [8.004513], in Range: True
# Input: 2 + 4 + 0, Actual: 6.00, Predicted Range: [5.61, 6.16], bootstrapped prediction: [5.8376207], in Range: True
# Input: -4 - 0 - -1, Actual: -3.00, Predicted Range: [-3.22, -2.91], bootstrapped prediction: [-3.0925193], in Range: True
# Input: -1 - -1 - 1, Actual: -1.00, Predicted Range: [-1.39, -0.78], bootstrapped prediction: [-1.0286742], in Range: True
# Input: -2 + -1 + 1, Actual: -2.00, Predicted Range: [-2.18, -1.70], bootstrapped prediction: [-2.019032], in Range: True
# Input: 1 - -4 - 4, Actual: 1.00, Predicted Range: [0.76, 1.40], bootstrapped prediction: [1.121196], in Range: True
# Input: -5 + 0 - 0, Actual: -5.00, Predicted Range: [-5.22, -4.66], bootstrapped prediction: [-4.8858004], in Range: True
# Input: 1 + 4 + 0, Actual: 5.00, Predicted Range: [4.49, 5.20], bootstrapped prediction: [4.8449755], in Range: True
# Input: 2 - 3 - -5, Actual: 4.00, Predicted Range: [3.60, 4.12], bootstrapped prediction: [3.8603916], in Range: True
# Input: 2 - 2 - -5, Actual: 5.00, Predicted Range: [4.51, 5.17], bootstrapped prediction: [4.876666], in Range: True
# Input: 2 - 4 - 3, Actual: -5.00, Predicted Range: [-5.19, -4.75], bootstrapped prediction: [-4.978421], in Range: True
# Input: -2 + 2 - 2, Actual: -2.00, Predicted Range: [-2.07, -1.70], bootstrapped prediction: [-1.8269609], in Range: True
# Input: 0 - -1 + -2, Actual: -1.00, Predicted Range: [-1.27, -0.77], bootstrapped prediction: [-1.0235317], in Range: True
# Input: 3 + 3 + 4, Actual: 10.00, Predicted Range: [9.76, 10.19], bootstrapped prediction: [9.971794], in Range: True
# Input: -4 + 4 + 4, Actual: 4.00, Predicted Range: [3.47, 4.02], bootstrapped prediction: [3.6986382], in Range: True
# Input: 1 - -4 + 3, Actual: 8.00, Predicted Range: [7.88, 8.54], bootstrapped prediction: [8.187765], in Range: True
# Input: 4 + 3 - -2, Actual: 9.00, Predicted Range: [8.67, 9.28], bootstrapped prediction: [8.956034], in Range: True
# Input: 2 - -5 - -4, Actual: 11.00, Predicted Range: [10.43, 11.03], bootstrapped prediction: [10.8154125], in Range: True
# Input: 0 + -2 - -5, Actual: 3.00, Predicted Range: [2.67, 3.19], bootstrapped prediction: [2.9895759], in Range: True
# Input: 3 + 3 + 3, Actual: 9.00, Predicted Range: [8.87, 9.46], bootstrapped prediction: [9.147929], in Range: True
# Input: -1 + -3 - -2, Actual: -2.00, Predicted Range: [-2.27, -1.90], bootstrapped prediction: [-2.0607877], in Range: True
# Input: 3 - 1 + -4, Actual: -2.00, Predicted Range: [-2.25, -1.80], bootstrapped prediction: [-2.0168955], in Range: True
# Input: 2 + 1 + -4, Actual: -1.00, Predicted Range: [-1.22, -0.76], bootstrapped prediction: [-0.9969595], in Range: True
# Input: 4 - -2 + 4, Actual: 10.00, Predicted Range: [9.61, 10.16], bootstrapped prediction: [9.930538], in Range: True
# Input: -4 - 0 - 0, Actual: -4.00, Predicted Range: [-4.17, -3.86], bootstrapped prediction: [-4.031382], in Range: True
# Input: 3 + 2 + -3, Actual: 2.00, Predicted Range: [1.66, 2.31], bootstrapped prediction: [1.9226192], in Range: True
# Input: -1 + 2 - -1, Actual: 2.00, Predicted Range: [1.79, 2.28], bootstrapped prediction: [2.0494378], in Range: True
# Input: -1 + 0 - -2, Actual: 1.00, Predicted Range: [0.58, 1.27], bootstrapped prediction: [0.9624365], in Range: True
# Input: -3 + -5 + -1, Actual: -9.00, Predicted Range: [-9.08, -8.64], bootstrapped prediction: [-8.827456], in Range: True
# Input: 0 + -2 - -3, Actual: 1.00, Predicted Range: [0.71, 1.27], bootstrapped prediction: [1.0410511], in Range: True
# Input: -2 - -4 - 1, Actual: 1.00, Predicted Range: [0.84, 1.44], bootstrapped prediction: [1.120525], in Range: True
# Input: 2 - 1 - -3, Actual: 4.00, Predicted Range: [3.84, 4.11], bootstrapped prediction: [3.9780922], in Range: True
# Input: -2 - 2 + 0, Actual: -4.00, Predicted Range: [-4.22, -3.83], bootstrapped prediction: [-3.9901097], in Range: True
# Input: -4 - 2 + -4, Actual: -10.00, Predicted Range: [-10.13, -9.79], bootstrapped prediction: [-9.98226], in Range: True
# Input: -5 + -1 - -5, Actual: -1.00, Predicted Range: [-1.59, -0.84], bootstrapped prediction: [-1.2104113], in Range: True
# Input: 0 - 3 - -2, Actual: -1.00, Predicted Range: [-1.36, -0.80], bootstrapped prediction: [-1.1044868], in Range: True
# Input: -3 - 3 - -5, Actual: -1.00, Predicted Range: [-1.23, -0.65], bootstrapped prediction: [-0.99582565], in Range: True
# Input: 0 + -1 - 4, Actual: -5.00, Predicted Range: [-5.22, -4.77], bootstrapped prediction: [-5.001863], in Range: True
# Input: 2 + -2 + -5, Actual: -5.00, Predicted Range: [-5.27, -4.90], bootstrapped prediction: [-5.0495076], in Range: True
# Input: -3 + -4 - -1, Actual: -6.00, Predicted Range: [-6.46, -5.91], bootstrapped prediction: [-6.126957], in Range: True
# Input: -4 - -3 + 3, Actual: 2.00, Predicted Range: [1.82, 2.34], bootstrapped prediction: [2.0167155], in Range: True
# Input: 3 + 4 + -3, Actual: 4.00, Predicted Range: [3.47, 4.06], bootstrapped prediction: [3.8271472], in Range: True
# Input: 4 + -4 - 2, Actual: -2.00, Predicted Range: [-2.36, -1.92], bootstrapped prediction: [-2.1036372], in Range: True
# Input: 0 - 1 - 4, Actual: -5.00, Predicted Range: [-5.10, -4.67], bootstrapped prediction: [-4.911731], in Range: True
# Input: -5 - -1 + -1, Actual: -5.00, Predicted Range: [-5.42, -4.69], bootstrapped prediction: [-5.058091], in Range: True
# Input: -2 + 0 - -3, Actual: 1.00, Predicted Range: [0.69, 1.21], bootstrapped prediction: [0.95778143], in Range: True
# Input: 2 - 1 - 4, Actual: -3.00, Predicted Range: [-3.02, -2.57], bootstrapped prediction: [-2.8389366], in Range: True
# Input: -2 + -4 + -5, Actual: -11.00, Predicted Range: [-11.20, -10.34], bootstrapped prediction: [-10.821549], in Range: True
# Input: 0 - -3 + 0, Actual: 3.00, Predicted Range: [2.70, 3.27], bootstrapped prediction: [2.958039], in Range: True
# Input: 4 - -2 + 1, Actual: 7.00, Predicted Range: [6.66, 7.18], bootstrapped prediction: [6.9358416], in Range: True
# Input: -4 - -1 - 4, Actual: -7.00, Predicted Range: [-7.24, -6.72], bootstrapped prediction: [-7.009777], in Range: True
# Input: -2 - 4 - -5, Actual: -1.00, Predicted Range: [-1.10, -0.62], bootstrapped prediction: [-0.90902025], in Range: True
# Input: -5 - 3 + -4, Actual: -12.00, Predicted Range: [-12.00, -11.69], bootstrapped prediction: [-11.822437], in Range: True
# Input: -3 - 1 + -2, Actual: -6.00, Predicted Range: [-6.21, -5.80], bootstrapped prediction: [-6.0566945], in Range: True
# Input: -3 - -3 - 1, Actual: -1.00, Predicted Range: [-1.19, -0.57], bootstrapped prediction: [-0.9408697], in Range: True
# Input: 2 + 3 - -1, Actual: 6.00, Predicted Range: [5.71, 6.29], bootstrapped prediction: [6.007726], in Range: True
# Input: -1 + 2 + -2, Actual: -1.00, Predicted Range: [-1.20, -0.83], bootstrapped prediction: [-1.0217761], in Range: True
# Input: -3 - 2 - 4, Actual: -9.00, Predicted Range: [-9.15, -8.76], bootstrapped prediction: [-8.969906], in Range: True
# Input: -5 + -4 + 3, Actual: -6.00, Predicted Range: [-6.46, -5.80], bootstrapped prediction: [-6.035522], in Range: True
# Input: -1 - -4 + -2, Actual: 1.00, Predicted Range: [0.95, 1.19], bootstrapped prediction: [1.0788724], in Range: True
# Input: -4 - 1 + -5, Actual: -10.00, Predicted Range: [-10.23, -9.68], bootstrapped prediction: [-9.9591465], in Range: True
# Input: -5 + -2 - -5, Actual: -2.00, Predicted Range: [-2.58, -1.73], bootstrapped prediction: [-2.1886075], in Range: True
# Input: -4 - 3 + -2, Actual: -9.00, Predicted Range: [-9.15, -8.90], bootstrapped prediction: [-8.995456], in Range: True
# Input: 2 - 0 + -5, Actual: -3.00, Predicted Range: [-3.09, -2.72], bootstrapped prediction: [-2.8871732], in Range: True
# Input: -2 - -5 - -5, Actual: 8.00, Predicted Range: [7.48, 8.05], bootstrapped prediction: [7.741338], in Range: True
# Input: -4 + 4 - -3, Actual: 3.00, Predicted Range: [2.63, 3.30], bootstrapped prediction: [2.93712], in Range: True
# Input: 1 + -5 - 3, Actual: -7.00, Predicted Range: [-7.21, -6.65], bootstrapped prediction: [-6.937646], in Range: True
# Input: 1 - -2 - -5, Actual: 8.00, Predicted Range: [7.78, 8.18], bootstrapped prediction: [7.95355], in Range: True
# Input: 0 - 0 - -4, Actual: 4.00, Predicted Range: [3.88, 4.45], bootstrapped prediction: [4.120458], in Range: True
# Input: 4 - 0 + -5, Actual: -1.00, Predicted Range: [-1.30, -0.52], bootstrapped prediction: [-0.8580537], in Range: True
# Input: 3 + 4 - 0, Actual: 7.00, Predicted Range: [6.73, 7.34], bootstrapped prediction: [6.992144], in Range: True
# Input: -4 + -2 + -1, Actual: -7.00, Predicted Range: [-7.15, -6.67], bootstrapped prediction: [-6.9897895], in Range: True
# Input: -5 + 4 + 0, Actual: -1.00, Predicted Range: [-1.64, -0.93], bootstrapped prediction: [-1.2880237], in Range: True
# Input: 2 - -5 - 3, Actual: 4.00, Predicted Range: [3.82, 4.24], bootstrapped prediction: [3.9891174], in Range: True
# Input: 1 + 1 + -5, Actual: -3.00, Predicted Range: [-3.31, -2.73], bootstrapped prediction: [-2.9768603], in Range: True
# Input: -5 + -3 - 2, Actual: -10.00, Predicted Range: [-10.18, -9.77], bootstrapped prediction: [-9.986141], in Range: True
# Input: -3 - 0 - 2, Actual: -5.00, Predicted Range: [-5.41, -4.81], bootstrapped prediction: [-5.0839596], in Range: True
# Input: -2 - -4 + 1, Actual: 3.00, Predicted Range: [2.91, 3.24], bootstrapped prediction: [3.0684915], in Range: True
# Input: 0 - 0 + 4, Actual: 4.00, Predicted Range: [3.61, 4.24], bootstrapped prediction: [3.940168], in Range: True
# Input: 0 - -5 + -3, Actual: 2.00, Predicted Range: [1.81, 2.16], bootstrapped prediction: [1.9503918], in Range: True
# Input: -5 - 4 + -2, Actual: -11.00, Predicted Range: [-11.00, -10.59], bootstrapped prediction: [-10.831324], in Range: False
# Input: 0 - -3 + 4, Actual: 7.00, Predicted Range: [6.84, 7.25], bootstrapped prediction: [7.04539], in Range: True
# Input: 4 - -2 - -3, Actual: 9.00, Predicted Range: [8.81, 9.16], bootstrapped prediction: [9.000779], in Range: True
# Input: -5 + -3 + 3, Actual: -5.00, Predicted Range: [-5.34, -4.82], bootstrapped prediction: [-5.019329], in Range: True
# Input: 2 - 4 - -3, Actual: 1.00, Predicted Range: [0.50, 1.18], bootstrapped prediction: [0.9565794], in Range: True
# Input: -2 + 1 + -1, Actual: -2.00, Predicted Range: [-2.27, -1.93], bootstrapped prediction: [-2.0466828], in Range: True
# Input: 2 + -3 + -2, Actual: -3.00, Predicted Range: [-3.53, -2.87], bootstrapped prediction: [-3.0616167], in Range: True
# Input: -1 + 3 - 0, Actual: 2.00, Predicted Range: [1.80, 2.23], bootstrapped prediction: [2.0362184], in Range: True
# Input: 2 - 2 + -3, Actual: -3.00, Predicted Range: [-3.37, -2.81], bootstrapped prediction: [-3.1515033], in Range: True
# Input: 4 + 4 - -5, Actual: 13.00, Predicted Range: [11.84, 12.90], bootstrapped prediction: [12.408754], in Range: False
# Input: 3 + -3 + -4, Actual: -4.00, Predicted Range: [-4.51, -3.88], bootstrapped prediction: [-4.1707907], in Range: True
# Input: 3 + 2 - -3, Actual: 8.00, Predicted Range: [7.85, 8.26], bootstrapped prediction: [8.038249], in Range: True
# Input: 4 + 1 + -1, Actual: 4.00, Predicted Range: [3.62, 4.36], bootstrapped prediction: [4.023028], in Range: True
# Input: -2 + 1 - -1, Actual: 0.00, Predicted Range: [-0.34, 0.14], bootstrapped prediction: [-0.01816083], in Range: True
# Input: 2 - -5 - 2, Actual: 5.00, Predicted Range: [4.73, 5.23], bootstrapped prediction: [5.0014915], in Range: True
# Input: -2 - -5 + -3, Actual: 0.00, Predicted Range: [-0.23, 0.15], bootstrapped prediction: [-0.04721166], in Range: True
# Input: 4 - 1 - -4, Actual: 7.00, Predicted Range: [6.71, 7.21], bootstrapped prediction: [6.916936], in Range: True
# Input: 1 - 3 + 0, Actual: -2.00, Predicted Range: [-2.41, -1.91], bootstrapped prediction: [-2.076018], in Range: True
# Input: -4 - -5 + -1, Actual: 0.00, Predicted Range: [-0.28, 0.29], bootstrapped prediction: [-0.02478128], in Range: True
# Input: -2 - -1 - 1, Actual: -2.00, Predicted Range: [-2.47, -1.67], bootstrapped prediction: [-2.038881], in Range: True
# Input: -1 + -5 + -3, Actual: -9.00, Predicted Range: [-9.18, -8.61], bootstrapped prediction: [-8.886478], in Range: True
# Input: 0 + 0 - 4, Actual: -4.00, Predicted Range: [-4.20, -3.66], bootstrapped prediction: [-3.9554565], in Range: True
# Input: -3 + 4 + 0, Actual: 1.00, Predicted Range: [0.67, 1.16], bootstrapped prediction: [0.92271423], in Range: True
# Input: -1 + 2 - 2, Actual: -1.00, Predicted Range: [-1.08, -0.67], bootstrapped prediction: [-0.83810997], in Range: True
# Input: -4 - -3 + -3, Actual: -4.00, Predicted Range: [-4.31, -3.90], bootstrapped prediction: [-4.103755], in Range: True
# Input: -2 + 4 - 2, Actual: 0.00, Predicted Range: [-0.28, 0.51], bootstrapped prediction: [0.08785357], in Range: True
# ...
# Input: -3 - 4 - -1, Actual: -6.00, Predicted Range: [-6.25, -5.72], bootstrapped prediction: [-6.0047493], in Range: True
# Input: -2 - 3 - -1, Actual: -4.00, Predicted Range: [-4.26, -3.79], bootstrapped prediction: [-4.0540166], in Range: True
# Input: 1 - 2 - -2, Actual: 1.00, Predicted Range: [0.51, 1.09], bootstrapped prediction: [0.8423446], in Range: True
# Input: -5 - -4 - 4, Actual: -5.00, Predicted Range: [-5.28, -4.61], bootstrapped prediction: [-4.9753237], in Range: True
# Input: 1 + -4 - -3, Actual: 0.00, Predicted Range: [-0.39, 0.25], bootstrapped prediction: [-0.08541798], in Range: True
# Input: 4 - 2 + 1, Actual: 3.00, Predicted Range: [2.87, 3.19], bootstrapped prediction: [2.9867735], in Range: True
# Input: -1 - -4 + 3, Actual: 6.00, Predicted Range: [5.89, 6.39], bootstrapped prediction: [6.1271367], in Range: True
# Input: 1 + 4 - 0, Actual: 5.00, Predicted Range: [4.57, 5.27], bootstrapped prediction: [4.9733067], in Range: True
# Input: -2 + -3 - 3, Actual: -8.00, Predicted Range: [-8.32, -7.84], bootstrapped prediction: [-8.136213], in Range: True
# Input: 4 - 3 + -3, Actual: -2.00, Predicted Range: [-2.41, -1.54], bootstrapped prediction: [-1.9428356], in Range: True
# Input: 1 - -2 - -3, Actual: 6.00, Predicted Range: [5.83, 6.27], bootstrapped prediction: [5.999011], in Range: True
# Input: -4 - 1 - 1, Actual: -6.00, Predicted Range: [-6.28, -5.82], bootstrapped prediction: [-6.06369], in Range: True
# Input: -1 - 3 + 0, Actual: -4.00, Predicted Range: [-4.22, -3.90], bootstrapped prediction: [-4.060001], in Range: True
# Input: -3 + -5 + 0, Actual: -8.00, Predicted Range: [-8.05, -7.64], bootstrapped prediction: [-7.827268], in Range: True
# Input: -2 - -1 + -4, Actual: -5.00, Predicted Range: [-5.25, -4.77], bootstrapped prediction: [-5.043264], in Range: True
# Input: 2 + 1 - -5, Actual: 8.00, Predicted Range: [7.45, 8.32], bootstrapped prediction: [7.9299264], in Range: True
# Input: 1 - -3 + -4, Actual: 0.00, Predicted Range: [-0.38, 0.16], bootstrapped prediction: [-0.04112913], in Range: True
# Input: 0 - 2 - 2, Actual: -4.00, Predicted Range: [-4.68, -3.80], bootstrapped prediction: [-4.2254], in Range: True
# Input: -4 - 0 - 3, Actual: -7.00, Predicted Range: [-7.37, -6.81], bootstrapped prediction: [-7.09301], in Range: True
# Input: 2 + 2 - 0, Actual: 4.00, Predicted Range: [3.73, 4.37], bootstrapped prediction: [4.0158987], in Range: True
# Input: -3 - -1 - -5, Actual: 3.00, Predicted Range: [2.59, 3.10], bootstrapped prediction: [2.8958712], in Range: True
# Input: 1 - -2 + -4, Actual: -1.00, Predicted Range: [-1.38, -0.89], bootstrapped prediction: [-1.0895901], in Range: True
# Input: -1 + -4 + -2, Actual: -7.00, Predicted Range: [-7.31, -6.79], bootstrapped prediction: [-7.0605116], in Range: True
# Input: -4 - -3 + 4, Actual: 3.00, Predicted Range: [2.61, 3.13], bootstrapped prediction: [2.8898058], in Range: True
# Input: 4 + -3 + 2, Actual: 3.00, Predicted Range: [2.56, 3.30], bootstrapped prediction: [2.9679425], in Range: True
# Input: -4 - -4 - 3, Actual: -3.00, Predicted Range: [-3.24, -2.75], bootstrapped prediction: [-2.993751], in Range: True
# Input: 1 - -5 + 2, Actual: 8.00, Predicted Range: [7.76, 8.22], bootstrapped prediction: [7.990983], in Range: True
# Input: -5 - 2 + 4, Actual: -3.00, Predicted Range: [-3.47, -2.90], bootstrapped prediction: [-3.1354802], in Range: True
# Input: -5 - 4 + 2, Actual: -7.00, Predicted Range: [-7.20, -6.71], bootstrapped prediction: [-6.890712], in Range: True
# Input: -2 + -3 - -3, Actual: -2.00, Predicted Range: [-2.31, -1.75], bootstrapped prediction: [-2.055213], in Range: True
# Input: 4 - 2 - 0, Actual: 2.00, Predicted Range: [1.83, 2.23], bootstrapped prediction: [2.0179658], in Range: True
# Input: -3 - -1 - 4, Actual: -6.00, Predicted Range: [-6.26, -5.62], bootstrapped prediction: [-6.02177], in Range: True
# Input: 0 - 4 + -3, Actual: -7.00, Predicted Range: [-7.22, -6.60], bootstrapped prediction: [-7.0107284], in Range: True
# Input: 3 + 3 + -3, Actual: 3.00, Predicted Range: [2.71, 3.19], bootstrapped prediction: [2.948688], in Range: True
# Input: 3 + 1 + 0, Actual: 4.00, Predicted Range: [3.71, 4.41], bootstrapped prediction: [4.051805], in Range: True
# Input: -2 + -1 - -3, Actual: 0.00, Predicted Range: [-0.28, 0.24], bootstrapped prediction: [-0.01628399], in Range: True
# Input: -3 - 4 - 1, Actual: -8.00, Predicted Range: [-8.21, -7.58], bootstrapped prediction: [-7.9622765], in Range: True
# Input: -4 + -1 + -2, Actual: -7.00, Predicted Range: [-7.09, -6.73], bootstrapped prediction: [-6.904666], in Range: True
# Input: 4 - 4 + 0, Actual: 0.00, Predicted Range: [-0.14, 0.48], bootstrapped prediction: [0.12380062], in Range: True
# Input: 2 - -1 + -4, Actual: -1.00, Predicted Range: [-1.33, -0.93], bootstrapped prediction: [-1.1028223], in Range: True
# Input: 3 - 0 - 3, Actual: 0.00, Predicted Range: [-0.07, 0.36], bootstrapped prediction: [0.13478324], in Range: True
# Input: 3 - -2 + 3, Actual: 8.00, Predicted Range: [8.01, 8.39], bootstrapped prediction: [8.160913], in Range: False
# Input: -2 - 4 + -4, Actual: -10.00, Predicted Range: [-10.04, -9.60], bootstrapped prediction: [-9.855887], in Range: True
# Input: 2 + -5 + 0, Actual: -3.00, Predicted Range: [-3.16, -2.79], bootstrapped prediction: [-2.97984], in Range: True
# Input: -2 + 4 + -1, Actual: 1.00, Predicted Range: [0.60, 1.21], bootstrapped prediction: [0.90680933], in Range: True
# Input: 3 + -3 + 2, Actual: 2.00, Predicted Range: [1.65, 2.34], bootstrapped prediction: [2.0171053], in Range: True
# Input: 3 - 1 + -3, Actual: -1.00, Predicted Range: [-1.30, -0.78], bootstrapped prediction: [-1.0452675], in Range: True
# Input: -3 - -1 - 1, Actual: -3.00, Predicted Range: [-3.45, -2.81], bootstrapped prediction: [-3.060671], in Range: True
# Input: -4 + 2 + -5, Actual: -7.00, Predicted Range: [-7.07, -6.76], bootstrapped prediction: [-6.9152703], in Range: True
# Input: 1 - -3 - -3, Actual: 7.00, Predicted Range: [6.89, 7.13], bootstrapped prediction: [7.0094743], in Range: True
# Input: 4 - 2 + -4, Actual: -2.00, Predicted Range: [-2.39, -1.78], bootstrapped prediction: [-2.0536034], in Range: True
# Input: 1 - -4 + 4, Actual: 9.00, Predicted Range: [8.77, 9.25], bootstrapped prediction: [9.033595], in Range: True
# Input: 2 + 3 - 3, Actual: 2.00, Predicted Range: [1.62, 2.22], bootstrapped prediction: [1.9595045], in Range: True
# Input: 4 - 1 + 4, Actual: 7.00, Predicted Range: [6.49, 7.06], bootstrapped prediction: [6.8051515], in Range: True
# Input: 2 + 1 - 1, Actual: 2.00, Predicted Range: [1.78, 2.06], bootstrapped prediction: [1.8996723], in Range: True
# Input: 4 - 1 + -1, Actual: 2.00, Predicted Range: [1.77, 2.31], bootstrapped prediction: [1.9762796], in Range: True
# Input: 4 - 1 + 2, Actual: 5.00, Predicted Range: [4.86, 5.34], bootstrapped prediction: [5.070595], in Range: True
# Input: 2 - 0 - 4, Actual: -2.00, Predicted Range: [-1.95, -1.45], bootstrapped prediction: [-1.7609209], in Range: False
# Input: -4 + -5 + -5, Actual: -14.00, Predicted Range: [-13.84, -12.91], bootstrapped prediction: [-13.491663], in Range: False
# Input: -2 + 0 + -1, Actual: -3.00, Predicted Range: [-3.17, -2.82], bootstrapped prediction: [-3.0196643], in Range: True
# Input: 1 - -4 - -2, Actual: 7.00, Predicted Range: [6.77, 7.08], bootstrapped prediction: [6.9683504], in Range: True
# Input: 4 - 1 + -5, Actual: -2.00, Predicted Range: [-2.39, -1.58], bootstrapped prediction: [-1.8632736], in Range: True
# Input: -5 - 4 + -4, Actual: -13.00, Predicted Range: [-12.82, -12.21], bootstrapped prediction: [-12.51094], in Range: False
# Input: -5 + 4 - 4, Actual: -5.00, Predicted Range: [-5.50, -4.60], bootstrapped prediction: [-5.0234847], in Range: True
# Input: 3 + -1 - 4, Actual: -2.00, Predicted Range: [-2.23, -1.75], bootstrapped prediction: [-1.9578445], in Range: True
# Input: 0 - 3 + -4, Actual: -7.00, Predicted Range: [-7.36, -7.06], bootstrapped prediction: [-7.210084], in Range: False
# Input: -3 - 4 + 2, Actual: -5.00, Predicted Range: [-5.13, -4.56], bootstrapped prediction: [-4.848329], in Range: True
# Input: 3 + 3 + -5, Actual: 1.00, Predicted Range: [0.79, 1.41], bootstrapped prediction: [1.1277382], in Range: True
# Input: 4 + -4 + -5, Actual: -5.00, Predicted Range: [-5.29, -4.73], bootstrapped prediction: [-4.95003], in Range: True
# Input: 1 - -5 - -1, Actual: 7.00, Predicted Range: [6.49, 7.30], bootstrapped prediction: [6.8708], in Range: True
# Input: -3 - 2 + -2, Actual: -7.00, Predicted Range: [-7.15, -6.86], bootstrapped prediction: [-7.025692], in Range: True
# Input: 2 - -2 + 2, Actual: 6.00, Predicted Range: [5.82, 6.45], bootstrapped prediction: [6.1259737], in Range: True
# Input: -1 - -4 - 3, Actual: 0.00, Predicted Range: [-0.37, 0.10], bootstrapped prediction: [-0.06741901], in Range: True
# Input: -3 + 1 + -1, Actual: -3.00, Predicted Range: [-3.19, -2.79], bootstrapped prediction: [-3.019534], in Range: True
# Input: -5 + -4 - 1, Actual: -10.00, Predicted Range: [-10.14, -9.74], bootstrapped prediction: [-9.931467], in Range: True
# Input: 0 - 4 + 2, Actual: -2.00, Predicted Range: [-2.17, -1.78], bootstrapped prediction: [-1.9769981], in Range: True
# Input: 0 + 0 + -3, Actual: -3.00, Predicted Range: [-3.38, -2.84], bootstrapped prediction: [-3.0595644], in Range: True
# Input: 4 + 0 + 0, Actual: 4.00, Predicted Range: [3.87, 4.15], bootstrapped prediction: [3.989186], in Range: True
# Input: 1 - 2 + -1, Actual: -2.00, Predicted Range: [-2.41, -1.93], bootstrapped prediction: [-2.1734195], in Range: True
# Input: 4 - 3 + -4, Actual: -3.00, Predicted Range: [-3.22, -2.71], bootstrapped prediction: [-2.9113388], in Range: True
# Input: 3 - 0 + 2, Actual: 5.00, Predicted Range: [4.76, 5.43], bootstrapped prediction: [5.114885], in Range: True
# Input: -2 + 1 - 0, Actual: -1.00, Predicted Range: [-1.27, -0.81], bootstrapped prediction: [-1.0362394], in Range: True
# Input: -4 - 3 + 4, Actual: -3.00, Predicted Range: [-3.37, -2.82], bootstrapped prediction: [-3.0616355], in Range: True
# Input: -5 + -4 + -5, Actual: -14.00, Predicted Range: [-14.01, -13.04], bootstrapped prediction: [-13.626195], in Range: True
# Input: -1 + 1 - 4, Actual: -4.00, Predicted Range: [-4.24, -3.75], bootstrapped prediction: [-3.9573045], in Range: True
# Input: -3 + 3 + -4, Actual: -4.00, Predicted Range: [-4.25, -3.72], bootstrapped prediction: [-3.9993007], in Range: True
# Input: 2 + 3 - -2, Actual: 7.00, Predicted Range: [6.74, 7.22], bootstrapped prediction: [7.065356], in Range: True
# Input: 2 + -3 - 2, Actual: -3.00, Predicted Range: [-3.41, -2.85], bootstrapped prediction: [-3.0945125], in Range: True
# Input: 4 + -2 + 2, Actual: 4.00, Predicted Range: [3.71, 4.39], bootstrapped prediction: [4.030983], in Range: True
# Input: 0 - -5 - -3, Actual: 8.00, Predicted Range: [7.56, 8.19], bootstrapped prediction: [7.9027305], in Range: True
# Input: 3 + -1 + -2, Actual: 0.00, Predicted Range: [-0.22, 0.26], bootstrapped prediction: [0.07264573], in Range: True
# Input: -4 + -4 + -3, Actual: -11.00, Predicted Range: [-11.42, -10.79], bootstrapped prediction: [-11.090592], in Range: True
# Input: -5 - 0 + 2, Actual: -3.00, Predicted Range: [-3.36, -2.66], bootstrapped prediction: [-2.9954245], in Range: True
# Input: 4 - -1 + 2, Actual: 7.00, Predicted Range: [6.66, 7.30], bootstrapped prediction: [7.0689583], in Range: True
# Input: 3 + -2 - 2, Actual: -1.00, Predicted Range: [-1.31, -0.76], bootstrapped prediction: [-1.0326025], in Range: True
# Input: 3 - -3 + -1, Actual: 5.00, Predicted Range: [4.97, 5.32], bootstrapped prediction: [5.1153502], in Range: True
# Input: 2 + 4 + -4, Actual: 2.00, Predicted Range: [1.45, 2.13], bootstrapped prediction: [1.8570347], in Range: True
# Input: 2 - -5 + 4, Actual: 11.00, Predicted Range: [10.44, 11.09], bootstrapped prediction: [10.77926], in Range: True
# Input: 3 + 1 + 3, Actual: 7.00, Predicted Range: [6.83, 7.16], bootstrapped prediction: [6.99875], in Range: True
# Input: -3 - -5 - 0, Actual: 2.00, Predicted Range: [1.45, 2.16], bootstrapped prediction: [1.860397], in Range: True
# Input: 1 - -1 + 2, Actual: 4.00, Predicted Range: [3.58, 4.45], bootstrapped prediction: [4.028344], in Range: True
# Input: -4 + 3 + -2, Actual: -3.00, Predicted Range: [-3.07, -2.91], bootstrapped prediction: [-3.0166926], in Range: True
# Input: 2 + -4 + 2, Actual: 0.00, Predicted Range: [-0.34, 0.23], bootstrapped prediction: [-0.01932908], in Range: True
# Input: -1 - 3 - 2, Actual: -6.00, Predicted Range: [-6.42, -5.87], bootstrapped prediction: [-6.1358347], in Range: True
# Input: 3 - 3 + -2, Actual: -2.00, Predicted Range: [-2.39, -1.77], bootstrapped prediction: [-2.0450165], in Range: True
# Input: -3 - -3 - 2, Actual: -2.00, Predicted Range: [-2.19, -1.52], bootstrapped prediction: [-1.9201609], in Range: True
# Input: -1 - -5 - -2, Actual: 6.00, Predicted Range: [5.61, 6.23], bootstrapped prediction: [5.9363985], in Range: True
# Input: 1 - 0 + -3, Actual: -2.00, Predicted Range: [-2.22, -1.86], bootstrapped prediction: [-2.010176], in Range: True
# Input: 1 + -3 - -4, Actual: 2.00, Predicted Range: [1.63, 2.09], bootstrapped prediction: [1.8772938], in Range: True
# Input: -4 + -2 + -3, Actual: -9.00, Predicted Range: [-9.32, -8.84], bootstrapped prediction: [-9.040879], in Range: True
# Input: 2 + -5 - 2, Actual: -5.00, Predicted Range: [-5.15, -4.71], bootstrapped prediction: [-4.963707], in Range: True
# Input: 2 + -2 + 0, Actual: 0.00, Predicted Range: [-0.05, 0.17], bootstrapped prediction: [0.07712145], in Range: True
# Input: -2 - -2 + 2, Actual: 2.00, Predicted Range: [1.84, 2.31], bootstrapped prediction: [2.020167], in Range: True
# Input: -1 - -1 - 4, Actual: -4.00, Predicted Range: [-4.26, -3.70], bootstrapped prediction: [-3.987278], in Range: True
# Input: -2 + 4 - 0, Actual: 2.00, Predicted Range: [1.83, 2.25], bootstrapped prediction: [2.015228], in Range: True
# Input: -1 + 4 + -4, Actual: -1.00, Predicted Range: [-1.45, -0.98], bootstrapped prediction: [-1.183496], in Range: True
# Input: 0 + 1 + 2, Actual: 3.00, Predicted Range: [2.83, 3.27], bootstrapped prediction: [3.0716166], in Range: True
# Input: 3 - -5 - -4, Actual: 12.00, Predicted Range: [11.47, 12.02], bootstrapped prediction: [11.789505], in Range: True
# Input: 3 + -3 + 3, Actual: 3.00, Predicted Range: [2.76, 3.47], bootstrapped prediction: [3.1164377], in Range: True
# Input: 1 - 1 + 1, Actual: 1.00, Predicted Range: [0.61, 1.17], bootstrapped prediction: [0.9570875], in Range: True
# Input: 2 + -4 - 4, Actual: -6.00, Predicted Range: [-5.98, -5.62], bootstrapped prediction: [-5.819974], in Range: False
# Input: -4 + 2 - 2, Actual: -4.00, Predicted Range: [-4.18, -3.53], bootstrapped prediction: [-3.873663], in Range: True
# Input: 2 - 2 - 3, Actual: -3.00, Predicted Range: [-3.47, -2.75], bootstrapped prediction: [-3.135044], in Range: True
# Input: 2 - 0 + 1, Actual: 3.00, Predicted Range: [2.84, 3.49], bootstrapped prediction: [3.0778909], in Range: True
# Input: 1 + 3 + 4, Actual: 8.00, Predicted Range: [7.77, 8.22], bootstrapped prediction: [7.975711], in Range: True
# Input: 3 - -2 + -2, Actual: 3.00, Predicted Range: [2.77, 3.21], bootstrapped prediction: [3.0157347], in Range: True
# Input: 0 - -4 + 0, Actual: 4.00, Predicted Range: [3.75, 4.36], bootstrapped prediction: [4.007434], in Range: True
# Input: -4 + -3 - 2, Actual: -9.00, Predicted Range: [-9.22, -8.92], bootstrapped prediction: [-9.074024], in Range: True
# Input: 0 + -2 + -3, Actual: -5.00, Predicted Range: [-5.46, -4.70], bootstrapped prediction: [-5.0270014], in Range: True
# Input: 2 - -5 - 0, Actual: 7.00, Predicted Range: [6.39, 7.29], bootstrapped prediction: [6.911847], in Range: True
# Input: -5 - 1 - -1, Actual: -5.00, Predicted Range: [-5.28, -4.70], bootstrapped prediction: [-4.991879], in Range: True
# Input: -1 - -3 + -3, Actual: -1.00, Predicted Range: [-1.34, -0.84], bootstrapped prediction: [-1.0367237], in Range: True
# Input: 2 + -3 - -3, Actual: 2.00, Predicted Range: [1.68, 2.21], bootstrapped prediction: [1.9070038], in Range: True
# Amount out of bounds: 50, Amount of expressions: 1457, Percentage in bounds: 96.56829100892244%

# %%
print(f"Amount out of bounds: {outOfBounds}, Amount of expressions: {len(x_test)}, Percentage in bounds: {(1-(outOfBounds/len(x_test)))*100}")
# Out:
# Amount out of bounds: 50, Amount of expressions: 1457, Percentage in bounds: 96.56829100892244

# %%
out_meanPredictions = []
for i in range(len(out_x_test)):
  calc = 0
  for j in range(n_bootstrap):
    calc += out_predictions[j][i]
  out_meanPredictions.append(calc/n_bootstrap)


# Calculate the lower and upper bounds of the prediction range
out_lower_bound = np.percentile(out_predictions, 5, axis=0)
out_upper_bound = np.percentile(out_predictions, 95, axis=0)


out_inRange = []
out_outOfBounds = 0
for i in range(len(out_y_test)):
  if out_y_test[i] >= out_lower_bound[i][0] and out_y_test[i] <= out_upper_bound[i][0]:
    out_inRange.append(True)
  else:
    out_inRange.append(False)
    out_outOfBounds += 1


print("Prediction Range (5th to 95th percentile):")
for i in range(len(out_x_test)):
  print(f"Input: {outsideExpr[i]}, Actual: {out_y_test[i]:.2f}, Predicted Range: [{out_lower_bound[i][0]:.2f}, {out_upper_bound[i][0]:.2f}], bootstrapped prediction: {out_meanPredictions[i]}, in Range: {out_inRange[i]}")

print(f"Amount out of bounds: {out_outOfBounds}, Amount of expressions: {len(out_x_test)}, Percentage in bounds: {(1-(out_outOfBounds/len(out_x_test)))*100}%")
# Out:
# Prediction Range (5th to 95th percentile):
# Input: -5 - -5 - -7, Actual: 7.00, Predicted Range: [4.12, 6.26], bootstrapped prediction: [5.3022127], in Range: False
# Input: -7 + -5 - -5, Actual: -7.00, Predicted Range: [-7.34, -6.17], bootstrapped prediction: [-6.748221], in Range: True
# Input: 5 + 7 + -5, Actual: 7.00, Predicted Range: [3.76, 6.76], bootstrapped prediction: [5.1000595], in Range: False
# Input: -7 - 7 + -7, Actual: -21.00, Predicted Range: [-17.65, -15.57], bootstrapped prediction: [-16.490255], in Range: False
# Input: 7 - 6 + -7, Actual: -6.00, Predicted Range: [-3.05, -0.37], bootstrapped prediction: [-1.7697117], in Range: False
# Input: 8 - -5 - -8, Actual: 21.00, Predicted Range: [16.16, 20.22], bootstrapped prediction: [18.12183], in Range: False
# Input: -7 - 5 - -8, Actual: -4.00, Predicted Range: [-6.11, -2.92], bootstrapped prediction: [-4.4997], in Range: True
# Input: -7 - -8 - -6, Actual: 7.00, Predicted Range: [2.08, 5.66], bootstrapped prediction: [3.866425], in Range: False
# Input: 6 + -8 + 5, Actual: 3.00, Predicted Range: [3.04, 4.75], bootstrapped prediction: [3.921452], in Range: False
# Input: 8 + -6 - 8, Actual: -6.00, Predicted Range: [-2.94, 1.08], bootstrapped prediction: [-1.1507759], in Range: False
# Input: -8 + 6 - 5, Actual: -7.00, Predicted Range: [-9.57, -6.51], bootstrapped prediction: [-7.9557686], in Range: True
# Input: -7 - 6 + 8, Actual: -5.00, Predicted Range: [-8.84, -6.13], bootstrapped prediction: [-7.454876], in Range: False
# Input: 7 - 6 + 6, Actual: 7.00, Predicted Range: [4.46, 7.08], bootstrapped prediction: [5.8665557], in Range: True
# Input: -5 + 7 - -5, Actual: 7.00, Predicted Range: [2.46, 4.72], bootstrapped prediction: [3.2561245], in Range: False
# Input: -5 + 8 + -8, Actual: -5.00, Predicted Range: [-8.13, -4.48], bootstrapped prediction: [-6.441214], in Range: True
# Input: -5 - -6 - -5, Actual: 6.00, Predicted Range: [4.30, 5.58], bootstrapped prediction: [4.9977202], in Range: False
# Input: 8 + 5 - -5, Actual: 18.00, Predicted Range: [15.54, 16.68], bootstrapped prediction: [16.07122], in Range: False
# Input: 6 - -5 - 6, Actual: 5.00, Predicted Range: [4.46, 6.69], bootstrapped prediction: [5.616083], in Range: True
# Input: 8 - -6 - -7, Actual: 21.00, Predicted Range: [16.28, 19.72], bootstrapped prediction: [18.170834], in Range: False
# Input: -5 - -6 - -7, Actual: 8.00, Predicted Range: [4.28, 6.82], bootstrapped prediction: [5.754358], in Range: False
# Input: -6 - -5 + -6, Actual: -7.00, Predicted Range: [-7.12, -5.82], bootstrapped prediction: [-6.52247], in Range: True
# Input: -7 - -8 - 6, Actual: -5.00, Predicted Range: [-7.00, -3.50], bootstrapped prediction: [-5.3746853], in Range: True
# Input: -8 + -7 - 7, Actual: -22.00, Predicted Range: [-18.76, -16.26], bootstrapped prediction: [-17.552101], in Range: False
# Input: -8 - -5 + -8, Actual: -11.00, Predicted Range: [-10.37, -7.39], bootstrapped prediction: [-9.032603], in Range: False
# Input: -6 - 6 + 6, Actual: -6.00, Predicted Range: [-8.02, -5.55], bootstrapped prediction: [-6.7739654], in Range: True
# Input: -7 + -8 + 7, Actual: -8.00, Predicted Range: [-9.50, -6.72], bootstrapped prediction: [-7.9879827], in Range: True
# Input: -7 - 5 - 7, Actual: -19.00, Predicted Range: [-16.69, -13.84], bootstrapped prediction: [-15.6141815], in Range: False
# Input: -5 - 6 + -7, Actual: -18.00, Predicted Range: [-15.25, -13.78], bootstrapped prediction: [-14.460066], in Range: False
# Input: 5 + -8 + 5, Actual: 2.00, Predicted Range: [2.07, 3.68], bootstrapped prediction: [2.9735055], in Range: False
# Input: 8 - -7 - 5, Actual: 10.00, Predicted Range: [8.56, 10.17], bootstrapped prediction: [9.457417], in Range: True
# Input: 8 - -6 - -8, Actual: 22.00, Predicted Range: [16.14, 20.59], bootstrapped prediction: [18.495403], in Range: False
# Input: 7 - -6 + 5, Actual: 18.00, Predicted Range: [15.11, 16.04], bootstrapped prediction: [15.568796], in Range: False
# Input: 8 - -8 - -6, Actual: 22.00, Predicted Range: [16.72, 20.49], bootstrapped prediction: [18.279646], in Range: False
# Input: 7 + -8 + -6, Actual: -7.00, Predicted Range: [-4.35, -0.65], bootstrapped prediction: [-2.6486516], in Range: False
# Input: -6 + 7 - 7, Actual: -6.00, Predicted Range: [-9.16, -5.16], bootstrapped prediction: [-7.2296915], in Range: True
# Input: -5 + 7 + -5, Actual: -3.00, Predicted Range: [-6.85, -4.12], bootstrapped prediction: [-5.292539], in Range: False
# Input: 8 - -8 - 6, Actual: 10.00, Predicted Range: [8.34, 10.74], bootstrapped prediction: [9.456335], in Range: True
# Input: -8 - 7 - 6, Actual: -21.00, Predicted Range: [-18.57, -15.25], bootstrapped prediction: [-17.085423], in Range: False
# Input: -6 - 6 - -6, Actual: -6.00, Predicted Range: [-6.58, -4.33], bootstrapped prediction: [-5.59258], in Range: True
# Input: 7 + 6 - 7, Actual: 6.00, Predicted Range: [4.69, 7.95], bootstrapped prediction: [5.7750635], in Range: True
# Input: 5 + -5 - 5, Actual: -5.00, Predicted Range: [-4.49, -3.17], bootstrapped prediction: [-3.8136272], in Range: False
# Input: -7 + 6 + -8, Actual: -9.00, Predicted Range: [-10.29, -7.31], bootstrapped prediction: [-8.694117], in Range: True
# Input: -7 - -6 - 5, Actual: -6.00, Predicted Range: [-6.88, -4.74], bootstrapped prediction: [-5.971063], in Range: True
# Input: -6 + -7 - 5, Actual: -18.00, Predicted Range: [-16.31, -14.64], bootstrapped prediction: [-15.447126], in Range: False
# Input: -8 + -5 - -5, Actual: -8.00, Predicted Range: [-8.39, -6.87], bootstrapped prediction: [-7.689884], in Range: True
# Input: -7 + 5 + -7, Actual: -9.00, Predicted Range: [-10.15, -7.84], bootstrapped prediction: [-8.76215], in Range: True
# Input: -6 - -8 + -6, Actual: -4.00, Predicted Range: [-5.77, -2.50], bootstrapped prediction: [-4.2667007], in Range: True
# Input: 5 + 7 - 8, Actual: 4.00, Predicted Range: [1.65, 5.70], bootstrapped prediction: [3.3346837], in Range: True
# Input: -6 - 6 + 5, Actual: -7.00, Predicted Range: [-8.08, -6.27], bootstrapped prediction: [-7.1424017], in Range: True
# Input: -8 + 7 - 8, Actual: -9.00, Predicted Range: [-11.65, -7.08], bootstrapped prediction: [-9.6850605], in Range: True
# Input: -8 - 7 - -6, Actual: -9.00, Predicted Range: [-9.74, -6.68], bootstrapped prediction: [-8.380446], in Range: True
# Input: 5 + -7 + -8, Actual: -10.00, Predicted Range: [-6.02, -3.21], bootstrapped prediction: [-4.9190307], in Range: False
# Input: -7 - -5 + -5, Actual: -7.00, Predicted Range: [-7.65, -6.32], bootstrapped prediction: [-6.950395], in Range: True
# Input: -6 - 6 - -5, Actual: -7.00, Predicted Range: [-7.39, -5.45], bootstrapped prediction: [-6.5357795], in Range: True
# Input: 7 + 5 + -6, Actual: 6.00, Predicted Range: [5.28, 7.51], bootstrapped prediction: [6.229945], in Range: True
# Input: -8 - 5 + 7, Actual: -6.00, Predicted Range: [-8.83, -6.56], bootstrapped prediction: [-7.7779627], in Range: False
# Input: 5 + -7 + 7, Actual: 5.00, Predicted Range: [3.27, 6.07], bootstrapped prediction: [4.3359184], in Range: True
# Input: -5 + -7 + -7, Actual: -19.00, Predicted Range: [-15.81, -13.22], bootstrapped prediction: [-14.72304], in Range: False
# Input: -6 - 5 + -5, Actual: -16.00, Predicted Range: [-15.06, -14.10], bootstrapped prediction: [-14.602186], in Range: False
# Input: -7 + -7 + 5, Actual: -9.00, Predicted Range: [-8.99, -7.91], bootstrapped prediction: [-8.463581], in Range: False
# Input: 5 + -7 - 8, Actual: -10.00, Predicted Range: [-5.95, -2.96], bootstrapped prediction: [-4.781308], in Range: False
# Input: -8 + 7 + -8, Actual: -9.00, Predicted Range: [-11.30, -7.55], bootstrapped prediction: [-9.407019], in Range: True
# Input: -6 - 5 + 8, Actual: -3.00, Predicted Range: [-6.77, -4.48], bootstrapped prediction: [-5.7002726], in Range: False
# Input: 8 - 7 + -5, Actual: -4.00, Predicted Range: [-2.19, 1.24], bootstrapped prediction: [-0.5678333], in Range: False
# Input: -7 + -6 - -7, Actual: -6.00, Predicted Range: [-7.32, -4.52], bootstrapped prediction: [-5.7064486], in Range: True
# Input: -7 - 8 + 5, Actual: -10.00, Predicted Range: [-11.20, -7.69], bootstrapped prediction: [-9.53462], in Range: True
# Input: -6 + 8 - -7, Actual: 9.00, Predicted Range: [1.24, 4.90], bootstrapped prediction: [2.8320947], in Range: False
# Input: -6 - 5 + 6, Actual: -5.00, Predicted Range: [-6.89, -5.07], bootstrapped prediction: [-6.023982], in Range: False
# Input: 6 + 7 + -7, Actual: 6.00, Predicted Range: [3.62, 7.43], bootstrapped prediction: [5.267395], in Range: True
# Input: 7 + -6 + -8, Actual: -7.00, Predicted Range: [-3.83, -0.98], bootstrapped prediction: [-2.6527748], in Range: False
# Input: -7 - -6 + 8, Actual: 7.00, Predicted Range: [0.33, 3.96], bootstrapped prediction: [1.9257587], in Range: False
# Input: -8 + 7 + 5, Actual: 4.00, Predicted Range: [-2.80, 1.61], bootstrapped prediction: [-0.9087559], in Range: False
# Input: 8 - -8 + 6, Actual: 22.00, Predicted Range: [16.24, 18.11], bootstrapped prediction: [17.15104], in Range: False
# Input: -7 - -5 - 6, Actual: -8.00, Predicted Range: [-8.68, -6.25], bootstrapped prediction: [-7.557701], in Range: True
# Input: 8 - 5 - -7, Actual: 10.00, Predicted Range: [8.19, 10.36], bootstrapped prediction: [9.638205], in Range: True
# Input: 7 + 6 - 5, Actual: 8.00, Predicted Range: [5.45, 8.44], bootstrapped prediction: [6.828042], in Range: True
# Input: 5 + -5 + 8, Actual: 8.00, Predicted Range: [4.56, 8.12], bootstrapped prediction: [6.084466], in Range: True
# Input: 6 + -7 - 5, Actual: -6.00, Predicted Range: [-4.12, -2.87], bootstrapped prediction: [-3.5605996], in Range: False
# Input: -5 + 5 - -7, Actual: 7.00, Predicted Range: [2.91, 5.26], bootstrapped prediction: [4.2502346], in Range: False
# Input: 6 + -6 + -5, Actual: -5.00, Predicted Range: [-4.65, -2.68], bootstrapped prediction: [-3.7490869], in Range: False
# Input: 7 + -7 + 5, Actual: 5.00, Predicted Range: [4.15, 6.32], bootstrapped prediction: [5.214955], in Range: True
# Input: -5 + -8 + 5, Actual: -8.00, Predicted Range: [-7.39, -6.30], bootstrapped prediction: [-6.973737], in Range: False
# Input: 6 - -7 + -6, Actual: 7.00, Predicted Range: [5.94, 8.57], bootstrapped prediction: [7.097375], in Range: True
# Input: 6 + 8 - 8, Actual: 6.00, Predicted Range: [2.35, 7.15], bootstrapped prediction: [4.4020877], in Range: True
# Input: 6 - 5 - 8, Actual: -7.00, Predicted Range: [-4.50, -0.73], bootstrapped prediction: [-2.7989948], in Range: False
# Input: 6 - -8 + -6, Actual: 8.00, Predicted Range: [6.21, 9.73], bootstrapped prediction: [7.783713], in Range: True
# Input: 7 - -6 - -5, Actual: 18.00, Predicted Range: [15.59, 17.41], bootstrapped prediction: [16.415434], in Range: False
# Input: -6 - 5 - 7, Actual: -18.00, Predicted Range: [-15.80, -13.00], bootstrapped prediction: [-14.703619], in Range: False
# Input: -8 - -8 - -7, Actual: 7.00, Predicted Range: [0.97, 5.45], bootstrapped prediction: [3.248921], in Range: False
# Input: -7 + -5 + 5, Actual: -7.00, Predicted Range: [-8.02, -6.69], bootstrapped prediction: [-7.3617773], in Range: True
# Input: -6 + 7 + 7, Actual: 8.00, Predicted Range: [-0.70, 3.52], bootstrapped prediction: [1.1441185], in Range: False
# Input: -8 + 8 + 8, Actual: 8.00, Predicted Range: [-3.83, 1.87], bootstrapped prediction: [-1.3088405], in Range: False
# Input: 5 + 6 + 5, Actual: 16.00, Predicted Range: [11.82, 14.15], bootstrapped prediction: [12.691466], in Range: False
# Input: -8 + -6 + -6, Actual: -20.00, Predicted Range: [-18.70, -15.66], bootstrapped prediction: [-17.211636], in Range: False
# Input: 7 - 6 - -7, Actual: 8.00, Predicted Range: [6.51, 8.97], bootstrapped prediction: [7.996208], in Range: True
# Input: -7 + -6 + 5, Actual: -8.00, Predicted Range: [-8.74, -7.53], bootstrapped prediction: [-8.0224285], in Range: True
# Input: 6 + 7 - 7, Actual: 6.00, Predicted Range: [3.29, 7.16], bootstrapped prediction: [4.9187593], in Range: True
# Input: 8 + 8 - -7, Actual: 23.00, Predicted Range: [14.89, 18.58], bootstrapped prediction: [16.585846], in Range: False
# Input: -6 - 7 + 5, Actual: -8.00, Predicted Range: [-9.14, -6.44], bootstrapped prediction: [-7.8387504], in Range: True
# Input: -6 - -7 - -8, Actual: 9.00, Predicted Range: [3.20, 7.12], bootstrapped prediction: [5.3987975], in Range: False
# Input: 7 + 6 - -6, Actual: 19.00, Predicted Range: [14.80, 16.69], bootstrapped prediction: [15.667969], in Range: False
# Input: -5 - -6 + -5, Actual: -4.00, Predicted Range: [-4.69, -3.56], bootstrapped prediction: [-4.146944], in Range: True
# Input: 8 + 8 - 6, Actual: 10.00, Predicted Range: [4.91, 9.66], bootstrapped prediction: [7.2210436], in Range: False
# Input: -5 - -7 + 8, Actual: 10.00, Predicted Range: [2.93, 6.38], bootstrapped prediction: [4.411777], in Range: False
# Input: 5 + -5 - 8, Actual: -8.00, Predicted Range: [-5.37, -2.33], bootstrapped prediction: [-4.0991154], in Range: False
# Input: 7 - 7 - 5, Actual: -5.00, Predicted Range: [-3.24, -0.94], bootstrapped prediction: [-2.2248101], in Range: False
# Input: 8 + -7 - -5, Actual: 6.00, Predicted Range: [6.08, 8.93], bootstrapped prediction: [7.246812], in Range: False
# Input: -5 + -8 - 7, Actual: -20.00, Predicted Range: [-16.11, -13.19], bootstrapped prediction: [-14.894969], in Range: False
# Input: 7 - 5 + 7, Actual: 9.00, Predicted Range: [5.90, 8.29], bootstrapped prediction: [6.850276], in Range: False
# Input: 5 + 6 - -5, Actual: 16.00, Predicted Range: [12.77, 14.09], bootstrapped prediction: [13.360324], in Range: False
# Input: 6 + 7 - -7, Actual: 20.00, Predicted Range: [13.54, 16.35], bootstrapped prediction: [14.934761], in Range: False
# Input: -8 + -8 + 8, Actual: -8.00, Predicted Range: [-10.49, -6.91], bootstrapped prediction: [-8.527408], in Range: True
# Input: -5 + -8 - -5, Actual: -8.00, Predicted Range: [-7.31, -5.09], bootstrapped prediction: [-6.181888], in Range: False
# Input: 8 - -6 + -6, Actual: 8.00, Predicted Range: [7.43, 10.26], bootstrapped prediction: [8.498007], in Range: True
# Input: 6 + 5 + -7, Actual: 4.00, Predicted Range: [4.03, 6.10], bootstrapped prediction: [4.7383757], in Range: False
# Input: -5 + 8 + 6, Actual: 9.00, Predicted Range: [-0.21, 4.31], bootstrapped prediction: [1.8130871], in Range: False
# Input: 6 - -6 - 6, Actual: 6.00, Predicted Range: [5.36, 7.45], bootstrapped prediction: [6.3779764], in Range: True
# Input: 5 - 5 + -6, Actual: -6.00, Predicted Range: [-4.73, -3.03], bootstrapped prediction: [-3.8886726], in Range: False
# Input: 5 - 8 - 8, Actual: -11.00, Predicted Range: [-6.84, -2.69], bootstrapped prediction: [-5.022971], in Range: False
# Input: 6 + 6 + -7, Actual: 5.00, Predicted Range: [3.88, 6.85], bootstrapped prediction: [5.042281], in Range: True
# Input: -6 - -6 - 6, Actual: -6.00, Predicted Range: [-6.89, -4.27], bootstrapped prediction: [-5.702628], in Range: True
# Input: -5 + -7 + -5, Actual: -17.00, Predicted Range: [-15.90, -13.10], bootstrapped prediction: [-14.675505], in Range: False
# Input: -6 - -6 + -6, Actual: -6.00, Predicted Range: [-6.49, -4.74], bootstrapped prediction: [-5.6775885], in Range: True
# Input: -6 + -7 + -6, Actual: -19.00, Predicted Range: [-17.06, -13.97], bootstrapped prediction: [-15.677096], in Range: False
# Input: 8 + -7 + 7, Actual: 8.00, Predicted Range: [6.06, 9.22], bootstrapped prediction: [7.1829133], in Range: True
# Input: 6 + 6 - 5, Actual: 7.00, Predicted Range: [4.66, 7.44], bootstrapped prediction: [5.9549284], in Range: True
# Input: 5 - -7 - -6, Actual: 18.00, Predicted Range: [14.10, 16.94], bootstrapped prediction: [15.499084], in Range: False
# Input: -8 + -5 + -7, Actual: -20.00, Predicted Range: [-18.03, -15.36], bootstrapped prediction: [-16.893257], in Range: False
# Input: 5 - -8 + -6, Actual: 7.00, Predicted Range: [5.18, 8.50], bootstrapped prediction: [6.6921663], in Range: True
# Input: 6 - -5 - -5, Actual: 16.00, Predicted Range: [14.61, 15.70], bootstrapped prediction: [15.258181], in Range: False
# Input: -5 - 5 + 5, Actual: -5.00, Predicted Range: [-6.07, -4.81], bootstrapped prediction: [-5.419893], in Range: True
# Input: -5 - 6 - 7, Actual: -18.00, Predicted Range: [-15.46, -12.41], bootstrapped prediction: [-14.1640215], in Range: False
# Input: 7 + 8 - -8, Actual: 23.00, Predicted Range: [14.04, 17.82], bootstrapped prediction: [15.975967], in Range: False
# Input: -5 - 5 + -5, Actual: -15.00, Predicted Range: [-14.09, -13.37], bootstrapped prediction: [-13.7330265], in Range: False
# Input: -6 - 8 + -5, Actual: -19.00, Predicted Range: [-17.12, -13.90], bootstrapped prediction: [-15.549238], in Range: False
# Input: -8 + -6 - -8, Actual: -6.00, Predicted Range: [-8.01, -4.41], bootstrapped prediction: [-5.9013023], in Range: True
# Input: -7 - 8 - -5, Actual: -10.00, Predicted Range: [-10.17, -7.24], bootstrapped prediction: [-8.96704], in Range: True
# Input: -5 + -7 + -8, Actual: -20.00, Predicted Range: [-15.88, -12.80], bootstrapped prediction: [-14.457835], in Range: False
# Input: 7 - 6 + -8, Actual: -7.00, Predicted Range: [-3.41, 0.17], bootstrapped prediction: [-1.7143142], in Range: False
# Input: -7 + 8 - 6, Actual: -5.00, Predicted Range: [-10.10, -4.46], bootstrapped prediction: [-7.412181], in Range: True
# Input: -5 - 8 - 6, Actual: -19.00, Predicted Range: [-16.51, -12.99], bootstrapped prediction: [-14.733259], in Range: False
# Input: 7 + -6 - 6, Actual: -5.00, Predicted Range: [-3.06, -0.93], bootstrapped prediction: [-2.1951275], in Range: False
# Input: 5 + 5 + 6, Actual: 16.00, Predicted Range: [11.89, 13.58], bootstrapped prediction: [12.71758], in Range: False
# Input: -5 - 6 + 5, Actual: -6.00, Predicted Range: [-7.17, -5.32], bootstrapped prediction: [-6.182947], in Range: True
# Input: 6 + 6 - -8, Actual: 20.00, Predicted Range: [14.13, 16.66], bootstrapped prediction: [15.372676], in Range: False
# Input: -7 - -5 - 8, Actual: -10.00, Predicted Range: [-10.49, -7.12], bootstrapped prediction: [-8.738564], in Range: True
# Input: 5 + 5 - -7, Actual: 17.00, Predicted Range: [13.46, 15.06], bootstrapped prediction: [14.253156], in Range: False
# Input: 5 + 7 + -6, Actual: 6.00, Predicted Range: [3.04, 6.36], bootstrapped prediction: [4.504644], in Range: True
# Input: 5 + 6 + 7, Actual: 18.00, Predicted Range: [11.17, 14.15], bootstrapped prediction: [12.501667], in Range: False
# Input: 6 - 5 + -6, Actual: -5.00, Predicted Range: [-3.59, -1.55], bootstrapped prediction: [-2.640658], in Range: False
# Input: -6 - 5 - -8, Actual: -3.00, Predicted Range: [-5.13, -1.93], bootstrapped prediction: [-3.5025144], in Range: True
# Input: -6 - 8 - -6, Actual: -8.00, Predicted Range: [-8.39, -5.18], bootstrapped prediction: [-6.991591], in Range: True
# Input: -5 - 5 + -7, Actual: -17.00, Predicted Range: [-14.75, -13.53], bootstrapped prediction: [-14.154561], in Range: False
# Input: 6 - 6 + -5, Actual: -5.00, Predicted Range: [-3.81, -1.93], bootstrapped prediction: [-2.7240677], in Range: False
# Input: 8 + -8 + 7, Actual: 7.00, Predicted Range: [5.52, 8.67], bootstrapped prediction: [6.784925], in Range: True
# Input: 5 + -5 + -5, Actual: -5.00, Predicted Range: [-4.93, -4.17], bootstrapped prediction: [-4.5814843], in Range: False
# Input: 8 + 5 - -8, Actual: 21.00, Predicted Range: [16.05, 18.87], bootstrapped prediction: [17.294933], in Range: False
# Input: 5 + 5 - -8, Actual: 18.00, Predicted Range: [13.49, 15.52], bootstrapped prediction: [14.439099], in Range: False
# Input: 6 + -7 - 6, Actual: -7.00, Predicted Range: [-4.35, -2.67], bootstrapped prediction: [-3.6468213], in Range: False
# Input: 6 + -6 + -8, Actual: -8.00, Predicted Range: [-4.85, -2.17], bootstrapped prediction: [-3.7514014], in Range: False
# Input: 7 - 7 + 8, Actual: 8.00, Predicted Range: [4.25, 7.69], bootstrapped prediction: [5.725711], in Range: False
# Input: -5 + -8 + -7, Actual: -20.00, Predicted Range: [-16.12, -12.59], bootstrapped prediction: [-14.693876], in Range: False
# Input: 8 - -5 - -7, Actual: 20.00, Predicted Range: [16.19, 19.37], bootstrapped prediction: [17.7821], in Range: False
# Input: -5 + 5 + -5, Actual: -5.00, Predicted Range: [-6.22, -5.09], bootstrapped prediction: [-5.60952], in Range: False
# Input: -7 + 5 - -6, Actual: 4.00, Predicted Range: [0.74, 2.94], bootstrapped prediction: [1.8524758], in Range: False
# Input: -5 + -7 - 6, Actual: -18.00, Predicted Range: [-15.82, -13.80], bootstrapped prediction: [-14.82533], in Range: False
# Input: 6 + -7 - -6, Actual: 5.00, Predicted Range: [4.92, 7.55], bootstrapped prediction: [5.9498596], in Range: True
# Input: 8 + -6 + -7, Actual: -5.00, Predicted Range: [-2.51, 0.12], bootstrapped prediction: [-1.5629241], in Range: False
# Input: -6 - -8 + -7, Actual: -5.00, Predicted Range: [-6.27, -2.34], bootstrapped prediction: [-4.6105356], in Range: True
# Input: -5 + 6 + 8, Actual: 9.00, Predicted Range: [0.80, 3.91], bootstrapped prediction: [2.2617764], in Range: False
# Input: 5 + 8 + 8, Actual: 21.00, Predicted Range: [9.80, 13.99], bootstrapped prediction: [11.800922], in Range: False
# Input: 8 + -7 - 7, Actual: -6.00, Predicted Range: [-2.60, 0.30], bootstrapped prediction: [-1.5161382], in Range: False
# Input: 5 - -5 - -6, Actual: 16.00, Predicted Range: [13.77, 15.55], bootstrapped prediction: [14.811422], in Range: False
# Input: 8 + 7 + -8, Actual: 7.00, Predicted Range: [5.26, 9.72], bootstrapped prediction: [7.2013435], in Range: True
# Input: 8 + 8 - 7, Actual: 9.00, Predicted Range: [4.62, 9.54], bootstrapped prediction: [6.8220186], in Range: True
# Input: 7 + 5 - -7, Actual: 19.00, Predicted Range: [15.33, 17.26], bootstrapped prediction: [16.110342], in Range: False
# Input: 7 + -5 - 8, Actual: -6.00, Predicted Range: [-3.55, 0.11], bootstrapped prediction: [-1.8991547], in Range: False
# Input: -8 - 5 - -8, Actual: -5.00, Predicted Range: [-7.01, -4.02], bootstrapped prediction: [-5.50794], in Range: True
# Input: 7 - -5 + 6, Actual: 18.00, Predicted Range: [14.47, 15.83], bootstrapped prediction: [15.14487], in Range: False
# Input: -5 + -6 + -6, Actual: -17.00, Predicted Range: [-15.64, -13.64], bootstrapped prediction: [-14.779333], in Range: False
# Input: -8 - -6 + 6, Actual: 4.00, Predicted Range: [0.39, 2.32], bootstrapped prediction: [1.3876787], in Range: False
# Input: -6 + 8 + -5, Actual: -3.00, Predicted Range: [-8.04, -4.79], bootstrapped prediction: [-6.2411427], in Range: False
# Input: 5 - -5 + -5, Actual: 5.00, Predicted Range: [4.86, 5.57], bootstrapped prediction: [5.1282144], in Range: True
# Input: -6 + 5 - 8, Actual: -9.00, Predicted Range: [-9.68, -6.23], bootstrapped prediction: [-8.131635], in Range: True
# Input: 8 - 6 + -8, Actual: -6.00, Predicted Range: [-2.33, 1.59], bootstrapped prediction: [-0.49099892], in Range: False
# Input: -7 - 8 + 7, Actual: -8.00, Predicted Range: [-10.94, -6.67], bootstrapped prediction: [-8.856728], in Range: True
# Input: -8 + 6 + -8, Actual: -10.00, Predicted Range: [-11.47, -8.19], bootstrapped prediction: [-9.666751], in Range: True
# Input: 6 - -5 + -5, Actual: 6.00, Predicted Range: [5.67, 6.97], bootstrapped prediction: [6.1893816], in Range: True
# Input: -8 + 7 - -6, Actual: 5.00, Predicted Range: [-0.87, 2.45], bootstrapped prediction: [0.5505689], in Range: False
# Input: -7 - -8 + -8, Actual: -7.00, Predicted Range: [-7.75, -3.02], bootstrapped prediction: [-5.83327], in Range: True
# Input: -6 - -8 + 7, Actual: 9.00, Predicted Range: [2.30, 5.77], bootstrapped prediction: [3.9546852], in Range: False
# Input: 5 + 8 - -8, Actual: 21.00, Predicted Range: [11.98, 15.61], bootstrapped prediction: [13.949265], in Range: False
# Input: -5 - 7 - 7, Actual: -19.00, Predicted Range: [-15.92, -12.71], bootstrapped prediction: [-14.5350895], in Range: False
# Input: -5 + -6 - 5, Actual: -16.00, Predicted Range: [-15.15, -14.25], bootstrapped prediction: [-14.633352], in Range: False
# Input: 6 + 8 - 6, Actual: 8.00, Predicted Range: [3.10, 7.66], bootstrapped prediction: [5.410239], in Range: False
# Input: -5 + -5 - -5, Actual: -5.00, Predicted Range: [-5.17, -4.65], bootstrapped prediction: [-4.873472], in Range: True
# Input: -6 - 5 - 8, Actual: -19.00, Predicted Range: [-16.17, -12.67], bootstrapped prediction: [-14.754176], in Range: False
# Input: -5 + 6 - 5, Actual: -4.00, Predicted Range: [-6.47, -3.67], bootstrapped prediction: [-5.0175514], in Range: True
# Input: -5 - 7 - -7, Actual: -5.00, Predicted Range: [-5.99, -2.98], bootstrapped prediction: [-4.596924], in Range: True
# Input: -5 - -7 + -7, Actual: -5.00, Predicted Range: [-5.45, -2.50], bootstrapped prediction: [-4.277432], in Range: True
# Input: -7 - 6 - 6, Actual: -19.00, Predicted Range: [-16.96, -14.41], bootstrapped prediction: [-15.8294935], in Range: False
# Input: 6 - 8 + 7, Actual: 5.00, Predicted Range: [2.57, 5.52], bootstrapped prediction: [3.9674172], in Range: True
# Input: 5 + -5 + 5, Actual: 5.00, Predicted Range: [4.19, 5.53], bootstrapped prediction: [4.802759], in Range: True
# Input: -7 + 7 - -7, Actual: 7.00, Predicted Range: [0.34, 3.79], bootstrapped prediction: [2.0456295], in Range: False
# Input: 7 + -6 + -5, Actual: -4.00, Predicted Range: [-3.63, -1.13], bootstrapped prediction: [-2.5112224], in Range: False
# Input: -5 + -8 - 6, Actual: -19.00, Predicted Range: [-15.82, -13.31], bootstrapped prediction: [-14.674248], in Range: False
# Input: -6 + -6 - -6, Actual: -6.00, Predicted Range: [-6.61, -4.69], bootstrapped prediction: [-5.5355606], in Range: True
# Input: -7 - 5 - -5, Actual: -7.00, Predicted Range: [-7.31, -6.08], bootstrapped prediction: [-6.729238], in Range: True
# Input: -8 - 7 + 8, Actual: -7.00, Predicted Range: [-10.77, -7.45], bootstrapped prediction: [-9.066471], in Range: False
# Input: -7 - -6 + -5, Actual: -6.00, Predicted Range: [-7.03, -5.32], bootstrapped prediction: [-6.125618], in Range: True
# Input: 5 - -6 + -7, Actual: 4.00, Predicted Range: [3.73, 5.97], bootstrapped prediction: [4.7475157], in Range: True
# Input: 5 + -6 - 7, Actual: -8.00, Predicted Range: [-5.21, -2.94], bootstrapped prediction: [-4.3957324], in Range: False
# Input: 8 + 5 - 6, Actual: 7.00, Predicted Range: [5.95, 8.43], bootstrapped prediction: [6.8420057], in Range: True
# Input: 5 - 6 - 8, Actual: -9.00, Predicted Range: [-5.71, -2.14], bootstrapped prediction: [-4.231196], in Range: False
# Input: -5 - -5 + 8, Actual: 8.00, Predicted Range: [1.63, 5.24], bootstrapped prediction: [3.4241366], in Range: False
# Input: 7 - -6 - 8, Actual: 5.00, Predicted Range: [4.33, 8.07], bootstrapped prediction: [6.2671366], in Range: True
# Input: -5 + -7 + 8, Actual: -4.00, Predicted Range: [-7.08, -3.37], bootstrapped prediction: [-5.268801], in Range: True
# Input: 6 + -6 + 6, Actual: 6.00, Predicted Range: [4.73, 6.83], bootstrapped prediction: [5.4816437], in Range: True
# Input: 7 - -5 - -7, Actual: 19.00, Predicted Range: [15.34, 18.46], bootstrapped prediction: [16.93397], in Range: False
# Input: -7 + 7 + 7, Actual: 7.00, Predicted Range: [-1.83, 2.70], bootstrapped prediction: [0.12377696], in Range: False
# Input: 8 - -7 + -6, Actual: 9.00, Predicted Range: [7.90, 11.54], bootstrapped prediction: [9.25781], in Range: True
# Input: 5 + -5 - -6, Actual: 6.00, Predicted Range: [5.36, 7.20], bootstrapped prediction: [6.033818], in Range: True
# Input: -6 - 6 - 5, Actual: -17.00, Predicted Range: [-15.73, -13.52], bootstrapped prediction: [-14.684741], in Range: False
# Input: -6 - -6 - -6, Actual: 6.00, Predicted Range: [3.21, 5.27], bootstrapped prediction: [4.388091], in Range: False
# Input: -6 + 8 + -6, Actual: -4.00, Predicted Range: [-8.55, -5.29], bootstrapped prediction: [-6.759101], in Range: False
# Input: 6 - 6 - 5, Actual: -5.00, Predicted Range: [-3.71, -1.63], bootstrapped prediction: [-2.839703], in Range: False
# Input: -5 + 5 - -5, Actual: 5.00, Predicted Range: [3.11, 4.23], bootstrapped prediction: [3.6592185], in Range: False
# Input: 6 + 5 + 6, Actual: 17.00, Predicted Range: [12.75, 14.36], bootstrapped prediction: [13.537466], in Range: False
# Input: -8 + 5 + 8, Actual: 5.00, Predicted Range: [-2.50, 1.06], bootstrapped prediction: [-0.7668308], in Range: False
# Input: -5 - 7 - 5, Actual: -17.00, Predicted Range: [-15.55, -12.78], bootstrapped prediction: [-14.118395], in Range: False
# Input: -7 - 8 - 8, Actual: -23.00, Predicted Range: [-18.87, -14.64], bootstrapped prediction: [-16.941471], in Range: False
# Input: -7 + 7 + -7, Actual: -7.00, Predicted Range: [-9.81, -6.63], bootstrapped prediction: [-8.204402], in Range: True
# Input: 6 + 6 + -8, Actual: 4.00, Predicted Range: [3.39, 6.64], bootstrapped prediction: [4.7027674], in Range: True
# Input: -8 + -7 + 5, Actual: -10.00, Predicted Range: [-9.99, -8.82], bootstrapped prediction: [-9.35279], in Range: False
# Input: -7 - -6 + -8, Actual: -9.00, Predicted Range: [-8.81, -5.29], bootstrapped prediction: [-7.314902], in Range: False
# Input: 8 + -8 - -5, Actual: 5.00, Predicted Range: [5.47, 9.05], bootstrapped prediction: [7.0083556], in Range: False
# Input: 8 - 5 + -5, Actual: -2.00, Predicted Range: [-1.21, 1.58], bootstrapped prediction: [0.1363636], in Range: False
# Input: -7 - 7 + -5, Actual: -19.00, Predicted Range: [-17.33, -14.96], bootstrapped prediction: [-16.2461], in Range: False
# Input: 8 + 7 + -6, Actual: 9.00, Predicted Range: [6.03, 9.87], bootstrapped prediction: [7.842665], in Range: True
# Input: 5 + -5 - -5, Actual: 5.00, Predicted Range: [4.74, 5.99], bootstrapped prediction: [5.212805], in Range: True
# Input: 6 - 5 + 7, Actual: 8.00, Predicted Range: [5.09, 7.34], bootstrapped prediction: [5.9731746], in Range: False
# Input: 8 - -8 + -7, Actual: 9.00, Predicted Range: [7.57, 12.02], bootstrapped prediction: [9.490073], in Range: True
# Input: -7 - -8 + -5, Actual: -4.00, Predicted Range: [-6.36, -3.29], bootstrapped prediction: [-4.79552], in Range: True
# Input: -6 + 5 + 6, Actual: 5.00, Predicted Range: [0.61, 2.95], bootstrapped prediction: [1.7381023], in Range: False
# Input: 6 + -5 - 8, Actual: -7.00, Predicted Range: [-4.38, -1.07], bootstrapped prediction: [-2.9824812], in Range: False
# Input: 6 - 6 + 6, Actual: 6.00, Predicted Range: [3.78, 6.14], bootstrapped prediction: [4.99051], in Range: True
# Input: 8 + -6 - -6, Actual: 8.00, Predicted Range: [7.47, 10.54], bootstrapped prediction: [8.571541], in Range: True
# Input: 8 + 6 + 5, Actual: 19.00, Predicted Range: [14.28, 16.41], bootstrapped prediction: [15.116406], in Range: False
# Input: 7 + -6 - -8, Actual: 9.00, Predicted Range: [7.13, 11.05], bootstrapped prediction: [8.762033], in Range: True
# Input: 5 + 5 - -5, Actual: 15.00, Predicted Range: [12.99, 13.95], bootstrapped prediction: [13.513087], in Range: False
# Input: -6 + 8 + 6, Actual: 8.00, Predicted Range: [-1.29, 3.44], bootstrapped prediction: [0.79903466], in Range: False
# Input: -8 + -6 - 6, Actual: -20.00, Predicted Range: [-18.00, -16.60], bootstrapped prediction: [-17.29003], in Range: False
# Input: -5 - -6 - 7, Actual: -6.00, Predicted Range: [-6.90, -3.85], bootstrapped prediction: [-5.4006166], in Range: True
# Input: -6 + 5 + -6, Actual: -7.00, Predicted Range: [-8.27, -6.62], bootstrapped prediction: [-7.3009787], in Range: True
# Input: -6 + -5 + -8, Actual: -19.00, Predicted Range: [-16.01, -13.32], bootstrapped prediction: [-14.812523], in Range: False
# Input: 7 - 8 - -5, Actual: 4.00, Predicted Range: [4.23, 7.21], bootstrapped prediction: [5.427247], in Range: False
# Input: 5 - -5 - 5, Actual: 5.00, Predicted Range: [4.53, 6.06], bootstrapped prediction: [5.2850084], in Range: True
# Input: -6 - 5 - 5, Actual: -16.00, Predicted Range: [-15.00, -13.39], bootstrapped prediction: [-14.257243], in Range: False
# Input: 7 - 8 + -5, Actual: -6.00, Predicted Range: [-4.00, -0.02], bootstrapped prediction: [-2.1276834], in Range: False
# Input: -8 + 7 + 8, Actual: 7.00, Predicted Range: [-3.34, 1.52], bootstrapped prediction: [-1.0217334], in Range: False
# Input: -5 - 6 + -5, Actual: -16.00, Predicted Range: [-14.54, -13.43], bootstrapped prediction: [-14.017183], in Range: False
# Input: -8 - -5 + 6, Actual: 3.00, Predicted Range: [-0.22, 1.92], bootstrapped prediction: [0.8800212], in Range: False
# Input: 5 + 7 - -6, Actual: 18.00, Predicted Range: [12.50, 14.80], bootstrapped prediction: [13.595942], in Range: False
# Input: 5 - 6 - 6, Actual: -7.00, Predicted Range: [-4.89, -2.48], bootstrapped prediction: [-4.001757], in Range: False
# Input: -7 - -6 + -6, Actual: -7.00, Predicted Range: [-7.65, -5.55], bootstrapped prediction: [-6.663934], in Range: True
# Input: -6 - 8 - 7, Actual: -21.00, Predicted Range: [-17.50, -13.87], bootstrapped prediction: [-15.867197], in Range: False
# Input: -5 + 5 - -8, Actual: 8.00, Predicted Range: [2.81, 5.29], bootstrapped prediction: [4.4253163], in Range: False
# Input: -7 + 7 - 5, Actual: -5.00, Predicted Range: [-8.93, -4.60], bootstrapped prediction: [-6.787613], in Range: True
# Input: -6 + 6 + 6, Actual: 6.00, Predicted Range: [0.15, 3.35], bootstrapped prediction: [1.5088713], in Range: False
# Input: -8 - -7 - 8, Actual: -9.00, Predicted Range: [-10.30, -5.62], bootstrapped prediction: [-8.179365], in Range: True
# Input: 6 - 5 - -6, Actual: 7.00, Predicted Range: [6.17, 7.69], bootstrapped prediction: [7.0145645], in Range: True
# Input: -7 - 6 - -5, Actual: -8.00, Predicted Range: [-8.42, -6.43], bootstrapped prediction: [-7.5535674], in Range: True
# Input: 8 - -7 - -5, Actual: 20.00, Predicted Range: [16.41, 19.26], bootstrapped prediction: [17.437593], in Range: False
# Input: -7 + -8 - -6, Actual: -9.00, Predicted Range: [-8.88, -5.86], bootstrapped prediction: [-7.229619], in Range: False
# Input: -6 - 7 + 7, Actual: -6.00, Predicted Range: [-9.02, -5.59], bootstrapped prediction: [-7.250581], in Range: True
# Input: 8 + 8 + 7, Actual: 23.00, Predicted Range: [12.99, 16.41], bootstrapped prediction: [14.638548], in Range: False
# Input: 8 - -5 + -7, Actual: 6.00, Predicted Range: [5.99, 8.56], bootstrapped prediction: [7.2076707], in Range: True
# Input: -8 - -6 - 7, Actual: -9.00, Predicted Range: [-9.96, -6.37], bootstrapped prediction: [-8.342864], in Range: True
# Input: -8 + -7 + 8, Actual: -7.00, Predicted Range: [-9.91, -6.51], bootstrapped prediction: [-8.215649], in Range: True
# Input: 7 + -8 + 6, Actual: 5.00, Predicted Range: [4.40, 6.78], bootstrapped prediction: [5.421717], in Range: True
# Input: -8 + -7 + 7, Actual: -8.00, Predicted Range: [-9.97, -7.25], bootstrapped prediction: [-8.556872], in Range: True
# Input: -6 - -7 + -6, Actual: -5.00, Predicted Range: [-6.02, -3.62], bootstrapped prediction: [-4.921639], in Range: True
# Input: 7 + 7 - -6, Actual: 20.00, Predicted Range: [14.41, 16.94], bootstrapped prediction: [15.498668], in Range: False
# Input: 6 + 7 + 7, Actual: 20.00, Predicted Range: [11.68, 14.83], bootstrapped prediction: [13.157651], in Range: False
# Input: -5 + 5 + 8, Actual: 8.00, Predicted Range: [1.15, 3.95], bootstrapped prediction: [2.4348443], in Range: False
# Input: -7 + -7 + -6, Actual: -20.00, Predicted Range: [-18.10, -14.84], bootstrapped prediction: [-16.525148], in Range: False
# Input: 8 - 5 - -8, Actual: 11.00, Predicted Range: [8.67, 11.48], bootstrapped prediction: [10.256266], in Range: True
# Input: -7 - 7 - -5, Actual: -9.00, Predicted Range: [-9.22, -6.90], bootstrapped prediction: [-8.326899], in Range: True
# Input: -7 + 5 + 6, Actual: 4.00, Predicted Range: [-0.60, 1.98], bootstrapped prediction: [0.6472154], in Range: False
# Input: 8 - 7 + 6, Actual: 7.00, Predicted Range: [4.91, 7.41], bootstrapped prediction: [6.2148542], in Range: True
# Input: 5 - 8 + 5, Actual: 2.00, Predicted Range: [0.69, 3.96], bootstrapped prediction: [2.1832614], in Range: True
# Input: -6 - -8 - 5, Actual: -3.00, Predicted Range: [-5.32, -2.13], bootstrapped prediction: [-3.68471], in Range: True
# Input: 8 + 5 - -7, Actual: 20.00, Predicted Range: [16.11, 18.29], bootstrapped prediction: [16.996572], in Range: False
# Input: -8 + 5 - 5, Actual: -8.00, Predicted Range: [-9.12, -7.24], bootstrapped prediction: [-8.234417], in Range: True
# Input: 5 - -7 + -6, Actual: 6.00, Predicted Range: [4.95, 7.22], bootstrapped prediction: [5.9718447], in Range: True
# Input: 7 + 6 - 6, Actual: 7.00, Predicted Range: [4.99, 8.16], bootstrapped prediction: [6.2650805], in Range: True
# Input: -6 - -8 - 6, Actual: -4.00, Predicted Range: [-6.01, -2.51], bootstrapped prediction: [-4.378524], in Range: True
# Input: 6 + -7 + -6, Actual: -7.00, Predicted Range: [-4.99, -2.55], bootstrapped prediction: [-3.966425], in Range: False
# Input: -8 - 6 + -8, Actual: -22.00, Predicted Range: [-18.19, -16.15], bootstrapped prediction: [-17.11152], in Range: False
# Input: 7 + 7 + 7, Actual: 21.00, Predicted Range: [12.67, 15.70], bootstrapped prediction: [14.042677], in Range: False
# Input: 6 - -7 + -8, Actual: 5.00, Predicted Range: [4.56, 8.39], bootstrapped prediction: [6.229043], in Range: True
# Input: 7 + 8 + -8, Actual: 7.00, Predicted Range: [4.13, 9.06], bootstrapped prediction: [6.264376], in Range: True
# Input: -8 - 7 - -8, Actual: -7.00, Predicted Range: [-8.72, -4.62], bootstrapped prediction: [-6.8107862], in Range: True
# Input: 5 + -5 + 7, Actual: 7.00, Predicted Range: [4.48, 7.23], bootstrapped prediction: [5.732032], in Range: True
# Input: 6 + 8 - -8, Actual: 22.00, Predicted Range: [13.06, 16.73], bootstrapped prediction: [15.004044], in Range: False
# Input: 7 + 5 - -6, Actual: 18.00, Predicted Range: [15.10, 16.68], bootstrapped prediction: [15.776891], in Range: False
# Input: -6 - 7 + -7, Actual: -20.00, Predicted Range: [-16.60, -14.68], bootstrapped prediction: [-15.588495], in Range: False
# Input: -8 + -8 + -6, Actual: -22.00, Predicted Range: [-19.37, -15.14], bootstrapped prediction: [-17.314981], in Range: False
# Input: -5 - 8 + -7, Actual: -20.00, Predicted Range: [-16.02, -13.46], bootstrapped prediction: [-14.841444], in Range: False
# Input: 6 - -5 - -6, Actual: 17.00, Predicted Range: [14.58, 16.54], bootstrapped prediction: [15.721741], in Range: False
# Input: -8 - -7 + 8, Actual: 7.00, Predicted Range: [-0.21, 3.29], bootstrapped prediction: [1.3581713], in Range: False
# Input: 8 - -5 + 8, Actual: 21.00, Predicted Range: [14.46, 17.56], bootstrapped prediction: [15.939966], in Range: False
# Input: 5 - 8 - -8, Actual: 5.00, Predicted Range: [3.35, 6.86], bootstrapped prediction: [5.1233516], in Range: True
# Input: -7 + -8 - 6, Actual: -21.00, Predicted Range: [-17.65, -15.05], bootstrapped prediction: [-16.438717], in Range: False
# Input: 5 + 6 - 6, Actual: 5.00, Predicted Range: [3.06, 6.01], bootstrapped prediction: [4.3597937], in Range: True
# Input: 7 + 7 + -5, Actual: 9.00, Predicted Range: [5.96, 9.13], bootstrapped prediction: [7.364403], in Range: True
# Input: 6 + -5 + -8, Actual: -7.00, Predicted Range: [-4.43, -2.20], bootstrapped prediction: [-3.445872], in Range: False
# Input: 6 + 7 + -5, Actual: 8.00, Predicted Range: [5.00, 8.01], bootstrapped prediction: [6.258071], in Range: True
# Input: -6 - -7 - 5, Actual: -4.00, Predicted Range: [-5.47, -3.15], bootstrapped prediction: [-4.2696486], in Range: True
# Input: -5 + 8 - 7, Actual: -4.00, Predicted Range: [-8.52, -3.64], bootstrapped prediction: [-6.134269], in Range: True
# Input: -6 + 5 + 7, Actual: 6.00, Predicted Range: [0.32, 3.04], bootstrapped prediction: [1.5802438], in Range: False
# Input: -7 - 8 + -7, Actual: -22.00, Predicted Range: [-18.04, -15.28], bootstrapped prediction: [-16.67862], in Range: False
# Input: -7 - -5 - -5, Actual: 3.00, Predicted Range: [1.82, 3.20], bootstrapped prediction: [2.481003], in Range: True
# Input: -8 - -6 - -7, Actual: 5.00, Predicted Range: [0.96, 4.06], bootstrapped prediction: [2.665486], in Range: False
# Input: 5 - -5 + 7, Actual: 17.00, Predicted Range: [12.79, 14.47], bootstrapped prediction: [13.674673], in Range: False
# Input: -7 - 8 + 8, Actual: -7.00, Predicted Range: [-10.90, -6.60], bootstrapped prediction: [-8.75037], in Range: True
# Input: 8 - -5 - 8, Actual: 5.00, Predicted Range: [4.51, 7.97], bootstrapped prediction: [6.4032974], in Range: True
# Input: 5 + 7 + 7, Actual: 19.00, Predicted Range: [10.67, 13.99], bootstrapped prediction: [12.259186], in Range: False
# Input: 5 - -6 + -6, Actual: 5.00, Predicted Range: [4.57, 6.11], bootstrapped prediction: [5.191556], in Range: True
# Input: -8 - -8 + -7, Actual: -7.00, Predicted Range: [-8.39, -3.97], bootstrapped prediction: [-6.514486], in Range: True
# Input: -5 + -8 + -8, Actual: -21.00, Predicted Range: [-15.92, -12.63], bootstrapped prediction: [-14.500015], in Range: False
# Input: 5 - 6 + 7, Actual: 6.00, Predicted Range: [3.21, 5.67], bootstrapped prediction: [4.2685013], in Range: False
# Input: -6 - -5 - 7, Actual: -8.00, Predicted Range: [-8.69, -5.85], bootstrapped prediction: [-7.234072], in Range: True
# Input: 7 + 6 - -5, Actual: 18.00, Predicted Range: [14.55, 15.95], bootstrapped prediction: [15.208891], in Range: False
# Input: -8 - -7 - -7, Actual: 6.00, Predicted Range: [0.94, 4.68], bootstrapped prediction: [2.9970524], in Range: False
# Input: -8 + -7 + -6, Actual: -21.00, Predicted Range: [-19.12, -15.60], bootstrapped prediction: [-17.323431], in Range: False
# Input: -8 - 8 + -7, Actual: -23.00, Predicted Range: [-19.17, -16.21], bootstrapped prediction: [-17.621058], in Range: False
# Input: -8 + -8 - 8, Actual: -24.00, Predicted Range: [-19.27, -15.61], bootstrapped prediction: [-17.680557], in Range: False
# Input: -8 + -8 - -5, Actual: -11.00, Predicted Range: [-10.43, -7.87], bootstrapped prediction: [-9.003023], in Range: False
# Input: 5 + 8 + 7, Actual: 20.00, Predicted Range: [9.92, 13.94], bootstrapped prediction: [11.894428], in Range: False
# Input: -7 - 7 - 5, Actual: -19.00, Predicted Range: [-17.46, -14.49], bootstrapped prediction: [-15.96459], in Range: False
# Input: 8 + -6 + 8, Actual: 10.00, Predicted Range: [6.80, 10.83], bootstrapped prediction: [8.292667], in Range: True
# Input: -8 + -8 + -7, Actual: -23.00, Predicted Range: [-19.24, -15.16], bootstrapped prediction: [-17.300747], in Range: False
# Input: 8 - -8 + 5, Actual: 21.00, Predicted Range: [15.68, 17.90], bootstrapped prediction: [16.816055], in Range: False
# Input: 8 + -5 + -8, Actual: -5.00, Predicted Range: [-2.32, 0.53], bootstrapped prediction: [-1.1719105], in Range: False
# Input: 6 - 6 + -6, Actual: -6.00, Predicted Range: [-4.09, -2.02], bootstrapped prediction: [-2.9709532], in Range: False
# Input: -6 + 6 + 7, Actual: 7.00, Predicted Range: [-0.21, 3.14], bootstrapped prediction: [1.406474], in Range: False
# Input: 8 + -6 + -5, Actual: -3.00, Predicted Range: [-2.68, 0.50], bootstrapped prediction: [-1.2617693], in Range: False
# Input: 8 + -5 + 6, Actual: 9.00, Predicted Range: [6.80, 9.83], bootstrapped prediction: [8.12311], in Range: True
# Input: -8 - 6 + 6, Actual: -8.00, Predicted Range: [-9.85, -7.53], bootstrapped prediction: [-8.71291], in Range: True
# Input: 7 + -8 - -6, Actual: 5.00, Predicted Range: [5.24, 8.78], bootstrapped prediction: [6.7215905], in Range: False
# Input: -7 + -8 + -5, Actual: -20.00, Predicted Range: [-18.30, -14.38], bootstrapped prediction: [-16.382645], in Range: False
# Input: -6 + -5 + -6, Actual: -17.00, Predicted Range: [-16.08, -14.15], bootstrapped prediction: [-15.328631], in Range: False
# Input: -5 - -6 - -8, Actual: 9.00, Predicted Range: [4.15, 7.41], bootstrapped prediction: [6.034152], in Range: False
# Input: -5 + -6 + 8, Actual: -3.00, Predicted Range: [-6.52, -2.95], bootstrapped prediction: [-4.785441], in Range: True
# Input: 7 - -8 - -7, Actual: 22.00, Predicted Range: [15.72, 20.25], bootstrapped prediction: [17.832546], in Range: False
# Input: -7 - -7 + 7, Actual: 7.00, Predicted Range: [1.27, 4.07], bootstrapped prediction: [2.619496], in Range: False
# Input: -8 - 6 + -5, Actual: -19.00, Predicted Range: [-17.70, -15.61], bootstrapped prediction: [-16.749176], in Range: False
# Input: 6 + -5 - 7, Actual: -6.00, Predicted Range: [-3.89, -1.38], bootstrapped prediction: [-2.887829], in Range: False
# Input: 5 + 6 + -7, Actual: 4.00, Predicted Range: [2.65, 5.64], bootstrapped prediction: [3.8966897], in Range: True
# Input: -6 + 5 - 5, Actual: -6.00, Predicted Range: [-7.24, -5.33], bootstrapped prediction: [-6.2676177], in Range: True
# Input: -5 - -8 - -7, Actual: 10.00, Predicted Range: [4.61, 8.44], bootstrapped prediction: [6.457546], in Range: False
# Input: 8 + 6 - -7, Actual: 21.00, Predicted Range: [15.76, 18.30], bootstrapped prediction: [16.927212], in Range: False
# Input: 5 - -5 - -8, Actual: 18.00, Predicted Range: [13.57, 17.21], bootstrapped prediction: [15.352274], in Range: False
# Input: -5 + 7 - 6, Actual: -4.00, Predicted Range: [-7.52, -3.64], bootstrapped prediction: [-5.583383], in Range: True
# Input: -6 + -8 - -7, Actual: -7.00, Predicted Range: [-7.25, -3.71], bootstrapped prediction: [-5.4799337], in Range: True
# Input: 7 + 8 + 6, Actual: 21.00, Predicted Range: [12.22, 15.52], bootstrapped prediction: [13.754797], in Range: False
# Input: 7 - 8 + 8, Actual: 7.00, Predicted Range: [3.56, 7.11], bootstrapped prediction: [5.127867], in Range: True
# Input: -7 - -8 - 5, Actual: -4.00, Predicted Range: [-6.29, -3.12], bootstrapped prediction: [-4.6712465], in Range: True
# Input: -5 - 7 + -5, Actual: -17.00, Predicted Range: [-15.33, -13.30], bootstrapped prediction: [-14.319227], in Range: False
# Input: -5 - -8 + -5, Actual: -2.00, Predicted Range: [-4.29, -1.28], bootstrapped prediction: [-2.7268238], in Range: True
# Input: 5 + -6 + -8, Actual: -9.00, Predicted Range: [-5.95, -3.31], bootstrapped prediction: [-4.795359], in Range: False
# Input: -8 - -6 - 8, Actual: -10.00, Predicted Range: [-10.86, -6.75], bootstrapped prediction: [-8.929484], in Range: True
# Input: 8 - 5 + -6, Actual: -3.00, Predicted Range: [-1.44, 1.39], bootstrapped prediction: [-0.15310499], in Range: False
# Input: -7 + 7 + -5, Actual: -5.00, Predicted Range: [-8.82, -6.04], bootstrapped prediction: [-7.3173456], in Range: False
# Input: -5 + 7 + 6, Actual: 8.00, Predicted Range: [0.69, 4.35], bootstrapped prediction: [2.2170653], in Range: False
# Input: 8 - -7 - 6, Actual: 9.00, Predicted Range: [7.60, 9.99], bootstrapped prediction: [8.868456], in Range: True
# Input: -7 + 8 + -6, Actual: -5.00, Predicted Range: [-9.55, -6.13], bootstrapped prediction: [-7.743885], in Range: False
# Input: -5 + -7 + 6, Actual: -6.00, Predicted Range: [-7.20, -5.21], bootstrapped prediction: [-6.189625], in Range: True
# Input: -7 + -5 - 8, Actual: -20.00, Predicted Range: [-17.52, -14.10], bootstrapped prediction: [-16.267704], in Range: False
# Input: 6 - -8 - -7, Actual: 21.00, Predicted Range: [14.91, 19.28], bootstrapped prediction: [16.957468], in Range: False
# Input: -8 - 7 - 7, Actual: -22.00, Predicted Range: [-18.96, -15.44], bootstrapped prediction: [-17.329697], in Range: False
# Input: -6 + -6 + 7, Actual: -5.00, Predicted Range: [-7.61, -4.81], bootstrapped prediction: [-6.218857], in Range: True
# Input: 5 + 7 + 5, Actual: 17.00, Predicted Range: [11.13, 13.81], bootstrapped prediction: [12.286657], in Range: False
# Input: -6 + 7 + 6, Actual: 7.00, Predicted Range: [-0.39, 3.51], bootstrapped prediction: [1.1962874], in Range: False
# Input: 8 + -7 - -8, Actual: 9.00, Predicted Range: [7.48, 11.90], bootstrapped prediction: [9.376333], in Range: True
# Input: 8 - 8 - 6, Actual: -6.00, Predicted Range: [-3.13, 0.00], bootstrapped prediction: [-1.713773], in Range: False
# Input: 6 + 7 + -8, Actual: 5.00, Predicted Range: [3.21, 7.28], bootstrapped prediction: [4.937503], in Range: True
# Input: 5 + 7 - 6, Actual: 6.00, Predicted Range: [2.62, 6.34], bootstrapped prediction: [4.458371], in Range: True
# Input: 8 + -8 + -7, Actual: -7.00, Predicted Range: [-3.07, 0.66], bootstrapped prediction: [-1.5691], in Range: False
# Input: -7 + -6 - -5, Actual: -8.00, Predicted Range: [-8.20, -6.75], bootstrapped prediction: [-7.33395], in Range: True
# Input: 6 - 8 + -6, Actual: -8.00, Predicted Range: [-5.28, -1.86], bootstrapped prediction: [-3.5622685], in Range: False
# Input: 5 + 8 - 7, Actual: 6.00, Predicted Range: [1.52, 6.29], bootstrapped prediction: [3.8995812], in Range: True
# Input: 7 - 6 - -5, Actual: 6.00, Predicted Range: [5.58, 7.56], bootstrapped prediction: [6.642676], in Range: True
# Input: -6 + -5 - -7, Actual: -4.00, Predicted Range: [-5.32, -3.25], bootstrapped prediction: [-4.1770267], in Range: True
# Input: -8 + 6 - 7, Actual: -9.00, Predicted Range: [-10.80, -7.14], bootstrapped prediction: [-9.256401], in Range: True
# Input: -8 + -5 + 8, Actual: -5.00, Predicted Range: [-8.89, -5.49], bootstrapped prediction: [-7.297494], in Range: False
# ...
# Input: -5 + -6 - -5, Actual: -6.00, Predicted Range: [-6.07, -4.90], bootstrapped prediction: [-5.4401436], in Range: True
# Input: 6 + -8 - 5, Actual: -7.00, Predicted Range: [-4.25, -3.03], bootstrapped prediction: [-3.5684676], in Range: False
# Input: 5 - -7 + -8, Actual: 4.00, Predicted Range: [3.70, 7.37], bootstrapped prediction: [5.219879], in Range: True
# Input: -8 - -7 + 7, Actual: 6.00, Predicted Range: [0.29, 3.03], bootstrapped prediction: [1.6057484], in Range: False
# Input: -8 - 5 + -8, Actual: -21.00, Predicted Range: [-17.66, -15.80], bootstrapped prediction: [-16.793118], in Range: False
# Input: 8 - 5 - 8, Actual: -5.00, Predicted Range: [-2.44, 1.56], bootstrapped prediction: [-0.83707416], in Range: False
# Input: 7 - -7 + -5, Actual: 9.00, Predicted Range: [7.42, 11.03], bootstrapped prediction: [8.936472], in Range: True
# Input: 6 + 5 - 6, Actual: 5.00, Predicted Range: [4.29, 6.48], bootstrapped prediction: [5.0637226], in Range: True
# Input: -6 + 7 + 8, Actual: 9.00, Predicted Range: [-0.95, 3.22], bootstrapped prediction: [1.0151907], in Range: False
# Input: -7 + -7 + -7, Actual: -21.00, Predicted Range: [-17.95, -14.79], bootstrapped prediction: [-16.444622], in Range: False
# Input: -6 - -7 - -5, Actual: 6.00, Predicted Range: [3.04, 5.23], bootstrapped prediction: [4.20895], in Range: False
# Input: 6 - -6 - -7, Actual: 19.00, Predicted Range: [14.57, 17.94], bootstrapped prediction: [16.431297], in Range: False
# Input: -6 - -5 - 6, Actual: -7.00, Predicted Range: [-7.73, -5.36], bootstrapped prediction: [-6.6053443], in Range: True
# Input: 7 + 7 - -8, Actual: 22.00, Predicted Range: [14.50, 17.76], bootstrapped prediction: [16.139362], in Range: False
# Input: 5 - -8 - -6, Actual: 19.00, Predicted Range: [14.15, 17.66], bootstrapped prediction: [15.685171], in Range: False
# Input: -5 - -7 + -5, Actual: -3.00, Predicted Range: [-4.33, -2.40], bootstrapped prediction: [-3.3965116], in Range: True
# Input: -6 + -6 - 7, Actual: -19.00, Predicted Range: [-17.01, -14.16], bootstrapped prediction: [-15.753824], in Range: False
# Input: -8 - 6 - -8, Actual: -6.00, Predicted Range: [-7.76, -4.47], bootstrapped prediction: [-6.135747], in Range: True
# Input: -7 - 6 + 5, Actual: -8.00, Predicted Range: [-9.03, -7.25], bootstrapped prediction: [-8.130968], in Range: True
# Input: -6 - -6 - -5, Actual: 5.00, Predicted Range: [3.08, 4.60], bootstrapped prediction: [3.9343479], in Range: False
# Input: -6 - -5 - 8, Actual: -9.00, Predicted Range: [-9.63, -6.35], bootstrapped prediction: [-7.8450003], in Range: True
# Input: -5 - 7 + -8, Actual: -20.00, Predicted Range: [-15.63, -13.52], bootstrapped prediction: [-14.624916], in Range: False
# Input: 8 - 7 + -6, Actual: -5.00, Predicted Range: [-2.52, 1.07], bootstrapped prediction: [-0.78490955], in Range: False
# Input: 8 - 7 - 6, Actual: -5.00, Predicted Range: [-2.39, 0.38], bootstrapped prediction: [-1.3032732], in Range: False
# Input: 8 + 6 + -6, Actual: 8.00, Predicted Range: [6.19, 9.24], bootstrapped prediction: [7.596634], in Range: True
# Input: 7 - -7 - 8, Actual: 6.00, Predicted Range: [5.04, 8.90], bootstrapped prediction: [6.9852114], in Range: True
# Input: 8 + 8 + 5, Actual: 21.00, Predicted Range: [13.23, 16.18], bootstrapped prediction: [14.541776], in Range: False
# Input: -6 - -6 + 5, Actual: 5.00, Predicted Range: [2.69, 4.08], bootstrapped prediction: [3.487761], in Range: False
# Input: 7 - -8 - -6, Actual: 21.00, Predicted Range: [15.91, 19.65], bootstrapped prediction: [17.476341], in Range: False
# Input: -7 - 7 - 8, Actual: -22.00, Predicted Range: [-18.47, -14.33], bootstrapped prediction: [-16.592884], in Range: False
# Input: 6 - -5 - 8, Actual: 3.00, Predicted Range: [2.74, 5.92], bootstrapped prediction: [4.432985], in Range: True
# Input: 7 - -7 - 5, Actual: 9.00, Predicted Range: [7.89, 9.22], bootstrapped prediction: [8.57391], in Range: True
# Input: -6 - -5 - -6, Actual: 5.00, Predicted Range: [3.11, 4.82], bootstrapped prediction: [3.9541974], in Range: False
# Input: 8 - 6 - -8, Actual: 10.00, Predicted Range: [7.73, 10.68], bootstrapped prediction: [9.576776], in Range: True
# Input: 8 - 7 + 8, Actual: 9.00, Predicted Range: [5.14, 8.69], bootstrapped prediction: [6.650935], in Range: False
# Input: 6 - 7 + -7, Actual: -8.00, Predicted Range: [-4.63, -2.15], bootstrapped prediction: [-3.3452785], in Range: False
# Input: -8 - 8 - -5, Actual: -11.00, Predicted Range: [-11.15, -8.27], bootstrapped prediction: [-10.002829], in Range: True
# Input: -6 - -6 + -8, Actual: -8.00, Predicted Range: [-7.67, -4.55], bootstrapped prediction: [-6.360658], in Range: False
# Input: 8 - 6 - 6, Actual: -4.00, Predicted Range: [-1.90, 0.75], bootstrapped prediction: [-0.9559903], in Range: False
# Input: 6 + 6 + 5, Actual: 17.00, Predicted Range: [12.80, 14.99], bootstrapped prediction: [13.581617], in Range: False
# Input: -6 + 6 + 5, Actual: 5.00, Predicted Range: [0.34, 3.26], bootstrapped prediction: [1.532526], in Range: False
# Input: 7 + 6 - 8, Actual: 5.00, Predicted Range: [3.89, 7.49], bootstrapped prediction: [5.244117], in Range: True
# Input: 7 + -7 + 8, Actual: 8.00, Predicted Range: [5.32, 8.97], bootstrapped prediction: [6.6473923], in Range: True
# Input: -5 + -5 - 6, Actual: -16.00, Predicted Range: [-14.99, -13.29], bootstrapped prediction: [-14.322766], in Range: False
# Input: 5 - -7 - -7, Actual: 19.00, Predicted Range: [14.02, 17.64], bootstrapped prediction: [15.851239], in Range: False
# Input: 5 - -5 - 8, Actual: 2.00, Predicted Range: [1.78, 4.88], bootstrapped prediction: [3.4201653], in Range: True
# Input: 7 - -7 - -8, Actual: 22.00, Predicted Range: [15.34, 20.33], bootstrapped prediction: [17.942947], in Range: False
# Input: 8 - 8 - -7, Actual: 7.00, Predicted Range: [5.68, 9.59], bootstrapped prediction: [7.8280396], in Range: True
# Input: -5 - 5 + 7, Actual: -3.00, Predicted Range: [-5.72, -3.79], bootstrapped prediction: [-4.804721], in Range: False
# Input: -8 + 8 - -6, Actual: 6.00, Predicted Range: [-1.11, 2.60], bootstrapped prediction: [0.28628764], in Range: False
# Input: 7 - 7 + -6, Actual: -6.00, Predicted Range: [-3.52, -0.65], bootstrapped prediction: [-2.0106325], in Range: False
# Input: -7 - -8 + 5, Actual: 6.00, Predicted Range: [1.13, 4.42], bootstrapped prediction: [2.977429], in Range: False
# Input: -8 - -8 + 5, Actual: 5.00, Predicted Range: [0.09, 3.34], bootstrapped prediction: [1.92591], in Range: False
# Input: 6 - 5 - -5, Actual: 6.00, Predicted Range: [5.62, 6.72], bootstrapped prediction: [6.2457886], in Range: True
# Input: -6 + 5 + -7, Actual: -8.00, Predicted Range: [-9.00, -6.87], bootstrapped prediction: [-7.7806406], in Range: True
# Input: -8 - 8 - 7, Actual: -23.00, Predicted Range: [-19.55, -15.52], bootstrapped prediction: [-17.705038], in Range: False
# Input: 8 + 6 - 5, Actual: 9.00, Predicted Range: [6.19, 9.35], bootstrapped prediction: [7.6671667], in Range: True
# Input: 7 + 7 - 5, Actual: 9.00, Predicted Range: [5.08, 8.73], bootstrapped prediction: [6.9294877], in Range: False
# Input: 6 - -7 - -6, Actual: 19.00, Predicted Range: [14.93, 17.87], bootstrapped prediction: [16.397585], in Range: False
# Input: 8 - -6 + -5, Actual: 9.00, Predicted Range: [8.20, 11.27], bootstrapped prediction: [9.22309], in Range: True
# Input: 7 - -8 - 7, Actual: 8.00, Predicted Range: [6.72, 9.70], bootstrapped prediction: [8.084322], in Range: True
# Input: -6 - -8 + 8, Actual: 10.00, Predicted Range: [2.03, 5.92], bootstrapped prediction: [3.7722576], in Range: False
# Input: -8 + -7 - -7, Actual: -8.00, Predicted Range: [-9.21, -5.66], bootstrapped prediction: [-7.103995], in Range: True
# Input: 8 - -7 + -5, Actual: 10.00, Predicted Range: [8.32, 12.35], bootstrapped prediction: [9.929414], in Range: True
# Input: -6 + -8 + 5, Actual: -9.00, Predicted Range: [-8.32, -7.20], bootstrapped prediction: [-7.922136], in Range: False
# Input: 7 + 5 - -8, Actual: 20.00, Predicted Range: [15.38, 17.76], bootstrapped prediction: [16.403078], in Range: False
# Input: -5 + -7 - 8, Actual: -20.00, Predicted Range: [-16.67, -13.06], bootstrapped prediction: [-14.980988], in Range: False
# Input: -5 + -5 + 6, Actual: -4.00, Predicted Range: [-5.85, -4.09], bootstrapped prediction: [-4.937049], in Range: False
# Input: -8 - -7 + -8, Actual: -9.00, Predicted Range: [-9.51, -4.93], bootstrapped prediction: [-7.542712], in Range: True
# Input: 8 - 5 + -8, Actual: -5.00, Predicted Range: [-1.83, 1.72], bootstrapped prediction: [-0.1714819], in Range: False
# Input: -8 + 6 + 6, Actual: 4.00, Predicted Range: [-2.14, 1.42], bootstrapped prediction: [-0.6353518], in Range: False
# Input: -6 - -8 + -5, Actual: -3.00, Predicted Range: [-5.32, -2.29], bootstrapped prediction: [-3.767348], in Range: True
# Input: 5 - 5 - -6, Actual: 6.00, Predicted Range: [5.31, 6.69], bootstrapped prediction: [6.001896], in Range: True
# Input: 7 + -5 - -6, Actual: 8.00, Predicted Range: [7.19, 9.56], bootstrapped prediction: [8.0759945], in Range: True
# Input: 6 + -5 + 5, Actual: 6.00, Predicted Range: [5.08, 6.60], bootstrapped prediction: [5.749713], in Range: True
# Input: 5 + -7 - 7, Actual: -9.00, Predicted Range: [-5.35, -3.36], bootstrapped prediction: [-4.696068], in Range: False
# Input: -7 + -5 - -6, Actual: -6.00, Predicted Range: [-6.88, -5.04], bootstrapped prediction: [-5.898835], in Range: True
# Input: -6 + -8 - 8, Actual: -22.00, Predicted Range: [-17.44, -13.72], bootstrapped prediction: [-15.93572], in Range: False
# Input: -8 + 6 - 6, Actual: -8.00, Predicted Range: [-10.26, -6.88], bootstrapped prediction: [-8.649157], in Range: True
# Input: -8 + -6 - -7, Actual: -7.00, Predicted Range: [-8.50, -5.30], bootstrapped prediction: [-6.619895], in Range: True
# Input: 7 - -5 - 6, Actual: 6.00, Predicted Range: [5.27, 7.66], bootstrapped prediction: [6.520179], in Range: True
# Input: -5 + 8 + -6, Actual: -3.00, Predicted Range: [-7.66, -4.22], bootstrapped prediction: [-5.804242], in Range: False
# Input: -6 - 7 + -6, Actual: -19.00, Predicted Range: [-16.58, -14.50], bootstrapped prediction: [-15.505826], in Range: False
# Input: 6 - -7 + 8, Actual: 21.00, Predicted Range: [14.24, 16.66], bootstrapped prediction: [15.453137], in Range: False
# Input: -5 - 7 - -8, Actual: -4.00, Predicted Range: [-5.63, -2.36], bootstrapped prediction: [-4.0204706], in Range: True
# Input: -7 + 6 + 8, Actual: 7.00, Predicted Range: [-1.65, 2.28], bootstrapped prediction: [0.20124571], in Range: False
# Input: -7 - 7 + 6, Actual: -8.00, Predicted Range: [-9.98, -6.75], bootstrapped prediction: [-8.405449], in Range: True
# Input: 8 + -5 + -6, Actual: -3.00, Predicted Range: [-1.92, 0.00], bootstrapped prediction: [-1.1621325], in Range: False
# Input: -8 - -6 + 8, Actual: 6.00, Predicted Range: [-0.67, 2.93], bootstrapped prediction: [0.9669367], in Range: False
# Input: 6 - -6 - -6, Actual: 18.00, Predicted Range: [14.72, 17.19], bootstrapped prediction: [16.087132], in Range: False
# Input: -7 - 8 - -6, Actual: -9.00, Predicted Range: [-9.46, -6.01], bootstrapped prediction: [-8.019255], in Range: True
# Input: 6 - -8 + -7, Actual: 7.00, Predicted Range: [5.57, 9.24], bootstrapped prediction: [7.270734], in Range: True
# Input: -8 + -8 - 6, Actual: -22.00, Predicted Range: [-18.46, -15.99], bootstrapped prediction: [-17.322159], in Range: False
# Input: 6 + -7 - 7, Actual: -8.00, Predicted Range: [-4.43, -2.14], bootstrapped prediction: [-3.6408296], in Range: False
# Input: 7 + -5 - -8, Actual: 10.00, Predicted Range: [7.97, 11.33], bootstrapped prediction: [9.281008], in Range: True
# Input: 5 + 8 - -6, Actual: 19.00, Predicted Range: [12.03, 14.82], bootstrapped prediction: [13.303805], in Range: False
# Input: 8 + 6 + 7, Actual: 21.00, Predicted Range: [13.70, 16.48], bootstrapped prediction: [15.011225], in Range: False
# Input: -7 - -7 + -8, Actual: -8.00, Predicted Range: [-8.34, -4.14], bootstrapped prediction: [-6.548857], in Range: True
# Input: -8 - 8 - -8, Actual: -8.00, Predicted Range: [-9.74, -4.71], bootstrapped prediction: [-7.4302664], in Range: True
# Input: 7 + 5 + -5, Actual: 7.00, Predicted Range: [5.99, 7.77], bootstrapped prediction: [6.838289], in Range: True
# Input: -6 + 6 - 7, Actual: -7.00, Predicted Range: [-8.72, -5.56], bootstrapped prediction: [-7.36427], in Range: True
# Input: 6 + -8 - 7, Actual: -9.00, Predicted Range: [-4.63, -2.69], bootstrapped prediction: [-3.7454288], in Range: False
# Input: 7 - 7 + 5, Actual: 5.00, Predicted Range: [3.90, 6.01], bootstrapped prediction: [4.8846436], in Range: True
# Input: 8 - -6 + 5, Actual: 19.00, Predicted Range: [15.56, 16.80], bootstrapped prediction: [16.199993], in Range: False
# Input: 5 + -7 + -5, Actual: -7.00, Predicted Range: [-6.34, -3.72], bootstrapped prediction: [-4.967133], in Range: False
# Input: 5 + -6 - 5, Actual: -6.00, Predicted Range: [-4.91, -3.73], bootstrapped prediction: [-4.354272], in Range: False
# Input: 8 + 8 - -8, Actual: 24.00, Predicted Range: [14.88, 18.90], bootstrapped prediction: [16.894007], in Range: False
# Input: 7 + -5 + -8, Actual: -6.00, Predicted Range: [-3.38, -0.95], bootstrapped prediction: [-2.3593812], in Range: False
# Input: 8 - 5 - -5, Actual: 8.00, Predicted Range: [7.25, 9.04], bootstrapped prediction: [8.313214], in Range: True
# Input: -6 + -8 + 8, Actual: -6.00, Predicted Range: [-8.58, -4.87], bootstrapped prediction: [-6.605626], in Range: True
# Input: 7 + 5 - -5, Actual: 17.00, Predicted Range: [14.66, 15.82], bootstrapped prediction: [15.241191], in Range: False
# Input: -5 - 8 - -6, Actual: -7.00, Predicted Range: [-7.46, -4.33], bootstrapped prediction: [-5.9952826], in Range: True
# Input: -5 + -8 + -5, Actual: -18.00, Predicted Range: [-16.41, -12.76], bootstrapped prediction: [-14.70759], in Range: False
# Input: 7 + -8 - -5, Actual: 4.00, Predicted Range: [4.61, 7.61], bootstrapped prediction: [5.9495134], in Range: False
# Input: 5 + -5 + 6, Actual: 6.00, Predicted Range: [4.33, 6.35], bootstrapped prediction: [5.2952495], in Range: True
# Input: 5 - 7 + -8, Actual: -10.00, Predicted Range: [-6.01, -3.26], bootstrapped prediction: [-4.6435347], in Range: False
# Input: 6 - 8 - -5, Actual: 3.00, Predicted Range: [3.13, 6.07], bootstrapped prediction: [4.342966], in Range: False
# Input: -5 - 8 + 6, Actual: -7.00, Predicted Range: [-9.00, -4.97], bootstrapped prediction: [-7.126107], in Range: True
# Input: 5 + 5 - 5, Actual: 5.00, Predicted Range: [4.04, 5.80], bootstrapped prediction: [4.757967], in Range: True
# Input: 7 - 8 - -6, Actual: 5.00, Predicted Range: [4.69, 8.01], bootstrapped prediction: [6.1647444], in Range: True
# Input: 5 - 5 + -5, Actual: -5.00, Predicted Range: [-4.32, -3.07], bootstrapped prediction: [-3.6211839], in Range: False
# Input: -7 - 8 + -5, Actual: -20.00, Predicted Range: [-18.12, -14.76], bootstrapped prediction: [-16.508081], in Range: False
# Input: -5 - 6 - 6, Actual: -17.00, Predicted Range: [-14.91, -12.66], bootstrapped prediction: [-14.00705], in Range: False
# Input: -5 + -8 - -7, Actual: -6.00, Predicted Range: [-6.12, -2.71], bootstrapped prediction: [-4.5016947], in Range: True
# Input: 5 + 8 + -5, Actual: 8.00, Predicted Range: [3.37, 7.24], bootstrapped prediction: [5.164319], in Range: False
# Input: 8 - -8 + -5, Actual: 11.00, Predicted Range: [8.38, 13.28], bootstrapped prediction: [10.538649], in Range: True
# Input: -7 - 6 + -8, Actual: -21.00, Predicted Range: [-17.18, -15.30], bootstrapped prediction: [-16.223125], in Range: False
# Input: 6 + 6 - 7, Actual: 5.00, Predicted Range: [3.66, 6.78], bootstrapped prediction: [4.7988067], in Range: True
# Input: 6 - 7 + 6, Actual: 5.00, Predicted Range: [3.17, 5.58], bootstrapped prediction: [4.344191], in Range: True
# Input: 8 + 7 - -7, Actual: 22.00, Predicted Range: [15.26, 18.41], bootstrapped prediction: [16.771036], in Range: False
# Input: 7 + 8 - -7, Actual: 22.00, Predicted Range: [13.93, 17.48], bootstrapped prediction: [15.62618], in Range: False
# Input: -8 + -7 + 6, Actual: -9.00, Predicted Range: [-9.98, -8.01], bootstrapped prediction: [-8.923498], in Range: True
# Amount out of bounds: 1196, Amount of expressions: 2048, Percentage in bounds: 41.6015625%

# %%
long_meanPredictions = []
for i in range(len(long_x_test)):
  calc = 0
  for j in range(n_bootstrap):
    calc += long_predictions[j][i]
  long_meanPredictions.append(calc/n_bootstrap)


# Calculate the lower and upper bounds of the prediction range
long_lower_bound = np.percentile(long_predictions, 5, axis=0)
long_upper_bound = np.percentile(long_predictions, 95, axis=0)


long_inRange = []
long_outOfBounds = 0
for i in range(len(long_y_test)):
  if long_y_test[i] >= long_lower_bound[i][0] and long_y_test[i] <= long_upper_bound[i][0]:
    long_inRange.append(True)
  else:
    long_inRange.append(False)
    long_outOfBounds += 1


print("Prediction Range (5th to 95th percentile):")
for i in range(len(long_x_test)):
  print(f"Input: {longer_Exps[i]}, Actual: {long_y_test[i]:.2f}, Predicted Range: [{long_lower_bound[i][0]:.2f}, {long_upper_bound[i][0]:.2f}], bootstrapped prediction: {long_meanPredictions[i]}, in Range: {long_inRange[i]}")

print(f"Amount out of bounds: {long_outOfBounds}, Amount of expressions: {len(long_x_test)}, Percentage in bounds: {(1-(long_outOfBounds/len(long_x_test)))*100}%")
# Out:
# Prediction Range (5th to 95th percentile):
# Input: -2 - -1, Actual: -1.00, Predicted Range: [-2.25, 0.00], bootstrapped prediction: [-1.1935728], in Range: True
# Input: -3 - -1, Actual: -2.00, Predicted Range: [-3.23, -1.02], bootstrapped prediction: [-2.2060018], in Range: True
# Input: 1 + -4, Actual: -3.00, Predicted Range: [-4.42, -2.52], bootstrapped prediction: [-3.683969], in Range: True
# Input: 3 - 0, Actual: 3.00, Predicted Range: [2.00, 4.20], bootstrapped prediction: [2.9671173], in Range: True
# Input: 0 + -3, Actual: -3.00, Predicted Range: [-4.34, -2.49], bootstrapped prediction: [-3.5342083], in Range: True
# Input: 4 + 3, Actual: 7.00, Predicted Range: [6.52, 8.50], bootstrapped prediction: [7.341419], in Range: True
# Input: -2 + -3, Actual: -5.00, Predicted Range: [-6.27, -4.36], bootstrapped prediction: [-5.5379286], in Range: True
# Input: -1 - 2, Actual: -3.00, Predicted Range: [-4.42, -2.85], bootstrapped prediction: [-3.5701241], in Range: True
# Input: 2 - -5, Actual: 7.00, Predicted Range: [6.33, 8.66], bootstrapped prediction: [7.454325], in Range: True
# Input: 5 - 0, Actual: 5.00, Predicted Range: [4.08, 6.10], bootstrapped prediction: [4.8391623], in Range: True
# Input: 5 - 1, Actual: 4.00, Predicted Range: [2.98, 4.98], bootstrapped prediction: [3.6592746], in Range: True
# Input: 3 - 2, Actual: 1.00, Predicted Range: [-0.35, 1.61], bootstrapped prediction: [0.58383036], in Range: True
# Input: 5 - 2, Actual: 3.00, Predicted Range: [1.79, 3.79], bootstrapped prediction: [2.6041782], in Range: True
# Input: 1 - -5, Actual: 6.00, Predicted Range: [5.34, 7.74], bootstrapped prediction: [6.4469476], in Range: True
# Input: -4 + 0, Actual: -4.00, Predicted Range: [-4.92, -3.17], bootstrapped prediction: [-4.1071615], in Range: True
# Input: -4 - -2, Actual: -2.00, Predicted Range: [-3.12, -0.62], bootstrapped prediction: [-1.9707445], in Range: True
# Input: 4 + 0, Actual: 4.00, Predicted Range: [2.96, 4.93], bootstrapped prediction: [3.9134393], in Range: True
# Input: 2 + 0, Actual: 2.00, Predicted Range: [1.23, 3.11], bootstrapped prediction: [2.0087068], in Range: True
# Input: -4 + 5, Actual: 1.00, Predicted Range: [-0.70, 2.28], bootstrapped prediction: [0.6215193], in Range: True
# Input: 0 + 0, Actual: 0.00, Predicted Range: [-0.66, 1.16], bootstrapped prediction: [0.02981352], in Range: True
# Input: 4 + -5, Actual: -1.00, Predicted Range: [-2.34, -0.27], bootstrapped prediction: [-1.588926], in Range: True
# Input: 4 + -1, Actual: 3.00, Predicted Range: [1.97, 3.90], bootstrapped prediction: [2.8523462], in Range: True
# Input: 0 + -2, Actual: -2.00, Predicted Range: [-3.13, -1.31], bootstrapped prediction: [-2.3077376], in Range: True
# Input: 1 + 0, Actual: 1.00, Predicted Range: [0.31, 2.18], bootstrapped prediction: [1.056285], in Range: True
# Input: -2 - 2, Actual: -4.00, Predicted Range: [-5.71, -3.92], bootstrapped prediction: [-4.6204834], in Range: True
# Input: 3 - 5, Actual: -2.00, Predicted Range: [-3.68, -1.14], bootstrapped prediction: [-2.3589225], in Range: True
# Input: -2 - 5, Actual: -7.00, Predicted Range: [-8.38, -6.29], bootstrapped prediction: [-7.336641], in Range: True
# Input: 2 - 3, Actual: -1.00, Predicted Range: [-2.58, -0.76], bootstrapped prediction: [-1.6038477], in Range: True
# Input: -3 + 3, Actual: 0.00, Predicted Range: [-0.81, 1.88], bootstrapped prediction: [0.29667184], in Range: True
# Input: -5 + -3, Actual: -8.00, Predicted Range: [-9.37, -7.27], bootstrapped prediction: [-8.467699], in Range: True
# Input: 3 + -5, Actual: -2.00, Predicted Range: [-3.40, -1.31], bootstrapped prediction: [-2.645857], in Range: True
# Input: 1 - 1, Actual: 0.00, Predicted Range: [-1.18, 0.71], bootstrapped prediction: [-0.35962743], in Range: True
# Input: -5 + 4, Actual: -1.00, Predicted Range: [-1.88, 0.61], bootstrapped prediction: [-0.88633937], in Range: True
# Input: 4 - 4, Actual: 0.00, Predicted Range: [-1.61, 0.65], bootstrapped prediction: [-0.42936397], in Range: True
# Input: 4 - -3, Actual: 7.00, Predicted Range: [6.10, 8.41], bootstrapped prediction: [7.295382], in Range: True
# Input: 2 + -5, Actual: -3.00, Predicted Range: [-4.44, -2.40], bootstrapped prediction: [-3.700817], in Range: True
# Input: 3 - -2, Actual: 5.00, Predicted Range: [3.84, 6.46], bootstrapped prediction: [5.2251306], in Range: True
# Input: 2 - -1, Actual: 3.00, Predicted Range: [1.76, 4.27], bootstrapped prediction: [3.0018086], in Range: True
# Input: -3 - -5, Actual: 2.00, Predicted Range: [1.53, 4.12], bootstrapped prediction: [2.5388455], in Range: True
# Input: 4 + 5, Actual: 9.00, Predicted Range: [7.54, 9.83], bootstrapped prediction: [8.70599], in Range: True
# Input: 0 - 1, Actual: -1.00, Predicted Range: [-2.25, -0.48], bootstrapped prediction: [-1.411387], in Range: True
# Input: -3 + -5, Actual: -8.00, Predicted Range: [-9.60, -7.14], bootstrapped prediction: [-8.6454], in Range: True
# Input: 1 + 5, Actual: 6.00, Predicted Range: [4.23, 6.93], bootstrapped prediction: [5.6773977], in Range: True
# Input: -5 - -4, Actual: -1.00, Predicted Range: [-1.81, 1.20], bootstrapped prediction: [-0.61251175], in Range: True
# Input: -2 + -5, Actual: -7.00, Predicted Range: [-8.63, -6.38], bootstrapped prediction: [-7.7048044], in Range: True
# Input: -2 - -2, Actual: 0.00, Predicted Range: [-1.04, 1.45], bootstrapped prediction: [0.07131469], in Range: True
# Input: -2 + 3, Actual: 1.00, Predicted Range: [0.15, 2.94], bootstrapped prediction: [1.3287936], in Range: True
# Input: -5 + 1, Actual: -4.00, Predicted Range: [-4.82, -3.09], bootstrapped prediction: [-4.0040646], in Range: True
# Input: -2 - -1, Actual: -1.00, Predicted Range: [-2.25, 0.00], bootstrapped prediction: [-1.1935728], in Range: True
# Input: -4 + 1, Actual: -3.00, Predicted Range: [-3.93, -1.91], bootstrapped prediction: [-3.0594096], in Range: True
# Input: 4 + 1, Actual: 5.00, Predicted Range: [3.96, 6.25], bootstrapped prediction: [4.9769373], in Range: True
# Input: -2 - -5, Actual: 3.00, Predicted Range: [2.47, 5.03], bootstrapped prediction: [3.5316455], in Range: True
# Input: -5 - -2, Actual: -3.00, Predicted Range: [-4.08, -1.56], bootstrapped prediction: [-2.9074707], in Range: True
# Input: -2 - 1, Actual: -3.00, Predicted Range: [-4.45, -2.64], bootstrapped prediction: [-3.4361699], in Range: True
# Input: 3 + 4, Actual: 7.00, Predicted Range: [6.46, 8.50], bootstrapped prediction: [7.370561], in Range: True
# Input: -1 - 5, Actual: -6.00, Predicted Range: [-7.46, -5.34], bootstrapped prediction: [-6.3587174], in Range: True
# Input: -3 + 0, Actual: -3.00, Predicted Range: [-3.89, -2.06], bootstrapped prediction: [-3.0822916], in Range: True
# Input: -5 + -3, Actual: -8.00, Predicted Range: [-9.37, -7.27], bootstrapped prediction: [-8.467699], in Range: True
# Input: -1 - 1, Actual: -2.00, Predicted Range: [-3.37, -1.53], bootstrapped prediction: [-2.4094973], in Range: True
# Input: 1 - 3, Actual: -2.00, Predicted Range: [-3.55, -2.12], bootstrapped prediction: [-2.675458], in Range: False
# Input: -5 + 3, Actual: -2.00, Predicted Range: [-2.82, -0.54], bootstrapped prediction: [-1.8382804], in Range: True
# Input: 2 - 2, Actual: 0.00, Predicted Range: [-1.38, 0.34], bootstrapped prediction: [-0.5266441], in Range: True
# Input: 2 - 2, Actual: 0.00, Predicted Range: [-1.38, 0.34], bootstrapped prediction: [-0.5266441], in Range: True
# Input: -3 + 3, Actual: 0.00, Predicted Range: [-0.81, 1.88], bootstrapped prediction: [0.29667184], in Range: True
# Input: -2 + 5, Actual: 3.00, Predicted Range: [1.28, 4.37], bootstrapped prediction: [2.7044673], in Range: True
# Input: 0 + 5, Actual: 5.00, Predicted Range: [3.20, 6.23], bootstrapped prediction: [4.738881], in Range: True
# Input: 5 + -5, Actual: 0.00, Predicted Range: [-1.33, 0.73], bootstrapped prediction: [-0.55069685], in Range: True
# Input: -3 + 3, Actual: 0.00, Predicted Range: [-0.81, 1.88], bootstrapped prediction: [0.29667184], in Range: True
# Input: -3 + 5, Actual: 2.00, Predicted Range: [0.30, 3.41], bootstrapped prediction: [1.6792027], in Range: True
# Input: 4 - -2, Actual: 6.00, Predicted Range: [4.71, 7.34], bootstrapped prediction: [6.147738], in Range: True
# Input: -1 + 1, Actual: 0.00, Predicted Range: [-0.80, 1.52], bootstrapped prediction: [0.08731618], in Range: True
# Input: 3 + 2, Actual: 5.00, Predicted Range: [4.36, 6.45], bootstrapped prediction: [5.215593], in Range: True
# Input: -4 - 2, Actual: -6.00, Predicted Range: [-7.77, -5.94], bootstrapped prediction: [-6.670787], in Range: True
# Input: 2 + -3, Actual: -1.00, Predicted Range: [-2.27, -0.25], bootstrapped prediction: [-1.4577783], in Range: True
# Input: 3 - 1, Actual: 2.00, Predicted Range: [0.99, 2.96], bootstrapped prediction: [1.7745867], in Range: True
# Input: -5 - 4, Actual: -9.00, Predicted Range: [-10.39, -8.92], bootstrapped prediction: [-9.581741], in Range: True
# Input: -1 - 3, Actual: -4.00, Predicted Range: [-5.46, -4.00], bootstrapped prediction: [-4.6518126], in Range: True
# Input: 4 + 2, Actual: 6.00, Predicted Range: [5.38, 7.40], bootstrapped prediction: [6.167163], in Range: True
# Input: 5 - -3, Actual: 8.00, Predicted Range: [6.90, 9.12], bootstrapped prediction: [8.143431], in Range: True
# Input: -1 - -2, Actual: 1.00, Predicted Range: [-0.09, 2.48], bootstrapped prediction: [1.0587686], in Range: True
# Input: -5 + 4, Actual: -1.00, Predicted Range: [-1.88, 0.61], bootstrapped prediction: [-0.88633937], in Range: True
# Input: 1 + -2, Actual: -1.00, Predicted Range: [-2.07, -0.20], bootstrapped prediction: [-1.2332456], in Range: True
# Input: 0 + 3, Actual: 3.00, Predicted Range: [2.20, 4.76], bootstrapped prediction: [3.3490918], in Range: True
# Input: 5 - -4, Actual: 9.00, Predicted Range: [8.12, 10.09], bootstrapped prediction: [9.231462], in Range: True
# Input: 5 + 4, Actual: 9.00, Predicted Range: [8.35, 10.39], bootstrapped prediction: [9.209012], in Range: True
# Input: -1 + 1, Actual: 0.00, Predicted Range: [-0.80, 1.52], bootstrapped prediction: [0.08731618], in Range: True
# Input: -3 - 1, Actual: -4.00, Predicted Range: [-5.49, -3.61], bootstrapped prediction: [-4.485873], in Range: True
# Input: -1 - 0, Actual: -1.00, Predicted Range: [-2.33, -0.35], bootstrapped prediction: [-1.2769176], in Range: True
# Input: 0 + 5, Actual: 5.00, Predicted Range: [3.20, 6.23], bootstrapped prediction: [4.738881], in Range: True
# Input: -2 - 2, Actual: -4.00, Predicted Range: [-5.71, -3.92], bootstrapped prediction: [-4.6204834], in Range: True
# Input: 3 - 3, Actual: 0.00, Predicted Range: [-1.55, 0.47], bootstrapped prediction: [-0.5012941], in Range: True
# Input: 5 - -2, Actual: 7.00, Predicted Range: [5.65, 8.08], bootstrapped prediction: [7.021322], in Range: True
# Input: 0 - 1, Actual: -1.00, Predicted Range: [-2.25, -0.48], bootstrapped prediction: [-1.411387], in Range: True
# Input: -2 - 4, Actual: -6.00, Predicted Range: [-7.48, -5.97], bootstrapped prediction: [-6.5807266], in Range: True
# Input: 2 + 2, Actual: 4.00, Predicted Range: [3.30, 5.53], bootstrapped prediction: [4.2133975], in Range: True
# Input: 4 - -3, Actual: 7.00, Predicted Range: [6.10, 8.41], bootstrapped prediction: [7.295382], in Range: True
# Input: -1 - 4, Actual: -5.00, Predicted Range: [-6.49, -4.97], bootstrapped prediction: [-5.569087], in Range: True
# Input: 2 + 0, Actual: 2.00, Predicted Range: [1.23, 3.11], bootstrapped prediction: [2.0087068], in Range: True
# Input: -2 + -2, Actual: -4.00, Predicted Range: [-5.18, -3.20], bootstrapped prediction: [-4.3795357], in Range: True
# Input: -2 - 1, Actual: -3.00, Predicted Range: [-4.45, -2.64], bootstrapped prediction: [-3.4361699], in Range: True
# Input: -1 - 2 - 1, Actual: -4.00, Predicted Range: [-4.28, -3.79], bootstrapped prediction: [-4.0481744], in Range: True
# Input: 2 + -2 - 0, Actual: 0.00, Predicted Range: [-0.14, 0.48], bootstrapped prediction: [0.15432055], in Range: True
# Input: -3 + 2 + 1, Actual: 0.00, Predicted Range: [-0.10, 0.27], bootstrapped prediction: [0.07657973], in Range: True
# Input: 4 + 5 - -5, Actual: 14.00, Predicted Range: [12.13, 12.97], bootstrapped prediction: [12.600206], in Range: False
# Input: 4 + -4 - 2, Actual: -2.00, Predicted Range: [-2.36, -1.92], bootstrapped prediction: [-2.1036372], in Range: True
# Input: -1 - -1 - 5, Actual: -5.00, Predicted Range: [-5.09, -4.36], bootstrapped prediction: [-4.686261], in Range: True
# Input: -2 + -5 + 0, Actual: -7.00, Predicted Range: [-7.15, -6.68], bootstrapped prediction: [-6.8930197], in Range: True
# Input: -2 - -3 - 3, Actual: -2.00, Predicted Range: [-2.20, -1.72], bootstrapped prediction: [-2.001408], in Range: True
# Input: -3 - -4 - -5, Actual: 6.00, Predicted Range: [5.59, 6.11], bootstrapped prediction: [5.8614426], in Range: True
# Input: 5 + -4 + -5, Actual: -4.00, Predicted Range: [-4.33, -3.39], bootstrapped prediction: [-3.8419423], in Range: True
# Input: -5 - -1 - 3, Actual: -7.00, Predicted Range: [-7.47, -6.77], bootstrapped prediction: [-7.112709], in Range: True
# Input: 0 - -2 + -3, Actual: -1.00, Predicted Range: [-1.22, -0.94], bootstrapped prediction: [-1.0556495], in Range: True
# Input: 2 + -5 - 5, Actual: -8.00, Predicted Range: [-7.33, -6.45], bootstrapped prediction: [-6.942743], in Range: False
# Input: -1 - -1 - -1, Actual: 1.00, Predicted Range: [0.89, 1.29], bootstrapped prediction: [1.0430343], in Range: True
# Input: 2 - 2 - -2, Actual: 2.00, Predicted Range: [1.47, 2.01], bootstrapped prediction: [1.8599806], in Range: True
# Input: 3 - -5 + -1, Actual: 7.00, Predicted Range: [6.83, 7.22], bootstrapped prediction: [6.9974794], in Range: True
# Input: -1 - 3 + 3, Actual: -1.00, Predicted Range: [-1.22, -0.64], bootstrapped prediction: [-0.9180802], in Range: True
# Input: 5 - -3 - -2, Actual: 10.00, Predicted Range: [9.57, 10.00], bootstrapped prediction: [9.78858], in Range: False
# Input: -4 - -1 - 2, Actual: -5.00, Predicted Range: [-5.35, -4.77], bootstrapped prediction: [-5.0909743], in Range: True
# Input: -5 + 1 - -5, Actual: 1.00, Predicted Range: [0.65, 1.21], bootstrapped prediction: [0.87834454], in Range: True
# Input: 5 + -4 + -4, Actual: -3.00, Predicted Range: [-3.44, -2.77], bootstrapped prediction: [-3.033586], in Range: True
# Input: -4 - 5 - 1, Actual: -10.00, Predicted Range: [-10.15, -8.75], bootstrapped prediction: [-9.585069], in Range: True
# Input: 0 + 0 + 3, Actual: 3.00, Predicted Range: [2.89, 3.23], bootstrapped prediction: [3.0334363], in Range: True
# Input: 2 - 2 - -1, Actual: 1.00, Predicted Range: [0.71, 1.04], bootstrapped prediction: [0.9041461], in Range: True
# Input: 3 - -4 + 0, Actual: 7.00, Predicted Range: [6.76, 7.37], bootstrapped prediction: [7.09057], in Range: True
# Input: 1 - -2 + 1, Actual: 4.00, Predicted Range: [3.75, 4.33], bootstrapped prediction: [4.030843], in Range: True
# Input: -4 + -2 + -4, Actual: -10.00, Predicted Range: [-10.20, -9.82], bootstrapped prediction: [-10.015382], in Range: True
# Input: 4 - -5 + -3, Actual: 6.00, Predicted Range: [5.94, 6.36], bootstrapped prediction: [6.1527896], in Range: True
# Input: -5 + -1 - 1, Actual: -7.00, Predicted Range: [-7.19, -6.54], bootstrapped prediction: [-6.855211], in Range: True
# Input: 3 - 2 - 0, Actual: 1.00, Predicted Range: [0.88, 1.23], bootstrapped prediction: [1.0421759], in Range: True
# Input: -3 - 2 - -2, Actual: -3.00, Predicted Range: [-3.35, -2.69], bootstrapped prediction: [-3.0481713], in Range: True
# Input: -1 + 3 + 3, Actual: 5.00, Predicted Range: [4.94, 5.43], bootstrapped prediction: [5.111804], in Range: True
# Input: 2 - -4 - -3, Actual: 9.00, Predicted Range: [8.73, 9.16], bootstrapped prediction: [8.964993], in Range: True
# Input: 2 + -1 + 2, Actual: 3.00, Predicted Range: [2.79, 3.25], bootstrapped prediction: [3.033012], in Range: True
# Input: 0 + -1 - -5, Actual: 4.00, Predicted Range: [3.77, 4.29], bootstrapped prediction: [4.0052443], in Range: True
# Input: -5 + -3 - 0, Actual: -8.00, Predicted Range: [-8.30, -7.75], bootstrapped prediction: [-7.9800506], in Range: True
# Input: 0 + 1 + -4, Actual: -3.00, Predicted Range: [-3.29, -2.87], bootstrapped prediction: [-3.0780597], in Range: True
# Input: -2 + 1 - -2, Actual: 1.00, Predicted Range: [0.80, 1.22], bootstrapped prediction: [1.0563645], in Range: True
# Input: -2 + 2 - 2, Actual: -2.00, Predicted Range: [-2.07, -1.70], bootstrapped prediction: [-1.8269609], in Range: True
# Input: 3 + -2 - 2, Actual: -1.00, Predicted Range: [-1.31, -0.76], bootstrapped prediction: [-1.0326025], in Range: True
# Input: 0 - 0 - -2, Actual: 2.00, Predicted Range: [1.79, 2.41], bootstrapped prediction: [2.0907362], in Range: True
# Input: 3 - 1 - 5, Actual: -3.00, Predicted Range: [-2.67, -1.78], bootstrapped prediction: [-2.2645178], in Range: False
# Input: 0 + -4 - 0, Actual: -4.00, Predicted Range: [-4.33, -3.77], bootstrapped prediction: [-4.0449677], in Range: True
# Input: 5 - -5 + 5, Actual: 15.00, Predicted Range: [13.37, 13.90], bootstrapped prediction: [13.669942], in Range: False
# Input: -1 + -3 - 1, Actual: -5.00, Predicted Range: [-5.33, -4.76], bootstrapped prediction: [-5.027559], in Range: True
# Input: -1 + 4 + -5, Actual: -2.00, Predicted Range: [-2.43, -1.85], bootstrapped prediction: [-2.0502865], in Range: True
# Input: 2 + 3 + -3, Actual: 2.00, Predicted Range: [1.68, 2.13], bootstrapped prediction: [1.9176527], in Range: True
# Input: 0 + 4 - -2, Actual: 6.00, Predicted Range: [5.56, 6.27], bootstrapped prediction: [5.926694], in Range: True
# Input: -3 - 0 + 5, Actual: 2.00, Predicted Range: [1.04, 1.98], bootstrapped prediction: [1.602772], in Range: False
# Input: 3 + -3 + 3, Actual: 3.00, Predicted Range: [2.76, 3.47], bootstrapped prediction: [3.1164377], in Range: True
# Input: -3 - -5 + 3, Actual: 5.00, Predicted Range: [4.69, 5.18], bootstrapped prediction: [4.9716916], in Range: True
# Input: -4 - 4 - 2, Actual: -10.00, Predicted Range: [-10.35, -9.78], bootstrapped prediction: [-9.99443], in Range: True
# Input: 3 + 3 - 0, Actual: 6.00, Predicted Range: [5.89, 6.22], bootstrapped prediction: [6.040268], in Range: True
# Input: 1 - -1 - 5, Actual: -3.00, Predicted Range: [-3.02, -2.26], bootstrapped prediction: [-2.6355379], in Range: True
# Input: -5 + 3 - -1, Actual: -1.00, Predicted Range: [-1.66, -0.77], bootstrapped prediction: [-1.1752024], in Range: True
# Input: -1 - 5 + -4, Actual: -10.00, Predicted Range: [-9.80, -8.97], bootstrapped prediction: [-9.449743], in Range: False
# Input: 1 + 1 - -1, Actual: 3.00, Predicted Range: [2.72, 3.35], bootstrapped prediction: [3.0132458], in Range: True
# Input: 0 - 1 + -2, Actual: -3.00, Predicted Range: [-3.28, -2.90], bootstrapped prediction: [-3.0730712], in Range: True
# Input: -3 - -2 + -4, Actual: -5.00, Predicted Range: [-5.38, -4.70], bootstrapped prediction: [-5.1060615], in Range: True
# Input: 5 - 3 + 1, Actual: 3.00, Predicted Range: [2.63, 3.16], bootstrapped prediction: [2.8884554], in Range: True
# Input: 0 - -5 - 1, Actual: 4.00, Predicted Range: [3.63, 4.41], bootstrapped prediction: [3.9792285], in Range: True
# Input: -4 + 2 + 5, Actual: 3.00, Predicted Range: [2.17, 2.98], bootstrapped prediction: [2.469345], in Range: False
# Input: 5 - 5 + -2, Actual: -2.00, Predicted Range: [-1.89, -0.53], bootstrapped prediction: [-1.3444995], in Range: False
# Input: 1 + 5 + -4, Actual: 2.00, Predicted Range: [0.61, 1.70], bootstrapped prediction: [1.1079767], in Range: False
# Input: 1 + -4 - 4, Actual: -7.00, Predicted Range: [-7.14, -6.67], bootstrapped prediction: [-6.884454], in Range: True
# Input: 3 + -1 - 1, Actual: 1.00, Predicted Range: [0.68, 1.34], bootstrapped prediction: [1.0854049], in Range: True
# Input: -5 - 3 + -1, Actual: -9.00, Predicted Range: [-9.31, -8.73], bootstrapped prediction: [-8.986677], in Range: True
# Input: 0 + 5 - 2, Actual: 3.00, Predicted Range: [2.09, 3.15], bootstrapped prediction: [2.6340399], in Range: True
# Input: -2 - 4 - -4, Actual: -2.00, Predicted Range: [-2.15, -1.33], bootstrapped prediction: [-1.8564265], in Range: True
# Input: -1 + 0 + 0, Actual: -1.00, Predicted Range: [-1.10, -0.74], bootstrapped prediction: [-0.9214264], in Range: True
# Input: 0 + 5 + -3, Actual: 2.00, Predicted Range: [0.38, 1.46], bootstrapped prediction: [1.0025742], in Range: False
# Input: 3 + -3 + -4, Actual: -4.00, Predicted Range: [-4.51, -3.88], bootstrapped prediction: [-4.1707907], in Range: True
# Input: 1 - 4 - -5, Actual: 2.00, Predicted Range: [1.53, 2.14], bootstrapped prediction: [1.8313481], in Range: True
# Input: 0 + 5 - 0, Actual: 5.00, Predicted Range: [4.09, 5.09], bootstrapped prediction: [4.5957804], in Range: True
# Input: -5 + -2 + -3, Actual: -10.00, Predicted Range: [-10.31, -9.71], bootstrapped prediction: [-9.985651], in Range: True
# Input: 0 + -2 - -5, Actual: 3.00, Predicted Range: [2.67, 3.19], bootstrapped prediction: [2.9895759], in Range: True
# Input: -1 + 3 - 2, Actual: 0.00, Predicted Range: [-0.14, 0.40], bootstrapped prediction: [0.18545689], in Range: True
# Input: 2 + 2 - 4, Actual: 0.00, Predicted Range: [-0.20, 0.23], bootstrapped prediction: [-0.02704171], in Range: True
# Input: 1 + 1 + 2, Actual: 4.00, Predicted Range: [3.84, 4.33], bootstrapped prediction: [4.073848], in Range: True
# Input: -3 + 2 - 0, Actual: -1.00, Predicted Range: [-1.24, -0.78], bootstrapped prediction: [-0.9522605], in Range: True
# Input: -2 + 5 - 4, Actual: -1.00, Predicted Range: [-2.18, -1.03], bootstrapped prediction: [-1.4762007], in Range: False
# Input: 3 - 4 - 4, Actual: -5.00, Predicted Range: [-4.96, -4.23], bootstrapped prediction: [-4.69601], in Range: False
# Input: -1 - -2 + -4, Actual: -3.00, Predicted Range: [-3.28, -2.86], bootstrapped prediction: [-3.0504832], in Range: True
# Input: 1 - -5 + -1, Actual: 5.00, Predicted Range: [4.73, 5.08], bootstrapped prediction: [4.9357753], in Range: True
# Input: -4 - 2 + -2, Actual: -8.00, Predicted Range: [-8.18, -7.86], bootstrapped prediction: [-8.047208], in Range: True
# Input: 3 + 5 - 0, Actual: 8.00, Predicted Range: [6.99, 7.96], bootstrapped prediction: [7.4956803], in Range: False
# Input: -3 + -5 - 5, Actual: -13.00, Predicted Range: [-12.67, -11.75], bootstrapped prediction: [-12.251645], in Range: False
# Input: 0 - -4 - -2, Actual: 6.00, Predicted Range: [5.73, 6.18], bootstrapped prediction: [6.0038223], in Range: True
# Input: 3 + -1 - -3, Actual: 5.00, Predicted Range: [4.60, 5.18], bootstrapped prediction: [4.9273825], in Range: True
# Input: -5 - 2 + 5, Actual: -2.00, Predicted Range: [-3.01, -2.00], bootstrapped prediction: [-2.4932458], in Range: True
# Input: -5 + 5 - 1, Actual: -1.00, Predicted Range: [-2.07, -0.76], bootstrapped prediction: [-1.4912034], in Range: True
# Input: 1 - -3 - 0, Actual: 4.00, Predicted Range: [3.90, 4.25], bootstrapped prediction: [4.074321], in Range: True
# Input: 2 - -5 + 3, Actual: 10.00, Predicted Range: [9.61, 10.24], bootstrapped prediction: [9.946511], in Range: True
# Input: 5 - 3 + 3, Actual: 5.00, Predicted Range: [4.46, 4.92], bootstrapped prediction: [4.710688], in Range: False
# Input: 5 - 0 + -5, Actual: 0.00, Predicted Range: [-0.49, 0.71], bootstrapped prediction: [0.21749727], in Range: True
# Input: 5 - 4 + 1, Actual: 2.00, Predicted Range: [1.64, 2.54], bootstrapped prediction: [2.0500631], in Range: True
# Input: 4 - -3 - -3, Actual: 10.00, Predicted Range: [9.84, 10.21], bootstrapped prediction: [10.017252], in Range: True
# Input: 3 + -5 + 2, Actual: 0.00, Predicted Range: [-0.25, 0.43], bootstrapped prediction: [0.05486656], in Range: True
# Input: -1 + -2 + 3, Actual: 0.00, Predicted Range: [-0.21, 0.18], bootstrapped prediction: [0.03596461], in Range: True
# Input: 3 + -1 - 5, Actual: -3.00, Predicted Range: [-3.11, -2.08], bootstrapped prediction: [-2.5872028], in Range: True
# Input: 3 + 4 - 3 + 2, Actual: 6.00, Predicted Range: [-0.18, 5.38], bootstrapped prediction: [2.8234355], in Range: False
# Input: -5 - 4 - -2 - 3, Actual: -10.00, Predicted Range: [-12.65, -4.14], bootstrapped prediction: [-6.923397], in Range: True
# Input: -3 + 4 + 4 + 5, Actual: 10.00, Predicted Range: [-9.09, 3.62], bootstrapped prediction: [-1.7941109], in Range: False
# Input: -1 + -2 + 0 - -3, Actual: 0.00, Predicted Range: [-6.34, -0.49], bootstrapped prediction: [-3.2633252], in Range: False
# Input: 4 - -1 - 0 - -2, Actual: 7.00, Predicted Range: [2.26, 6.98], bootstrapped prediction: [4.4723115], in Range: False
# Input: -3 + 1 + 0 - -5, Actual: 3.00, Predicted Range: [-6.21, 3.94], bootstrapped prediction: [-0.58547366], in Range: True
# Input: -1 + 0 + -5 + -2, Actual: -8.00, Predicted Range: [-10.62, -0.50], bootstrapped prediction: [-5.693131], in Range: True
# Input: -2 - -4 - 2 - -3, Actual: 3.00, Predicted Range: [-4.58, 3.99], bootstrapped prediction: [0.0904768], in Range: True
# Input: -5 - 5 + 2 - -3, Actual: -5.00, Predicted Range: [-7.76, -0.71], bootstrapped prediction: [-4.2432137], in Range: True
# Input: 5 - 5 - -2 - -2, Actual: 4.00, Predicted Range: [-0.65, 7.38], bootstrapped prediction: [2.598767], in Range: True
# Input: 5 - 3 - -5 + -5, Actual: 2.00, Predicted Range: [-5.14, 14.61], bootstrapped prediction: [4.0700617], in Range: True
# Input: -1 - 0 - 0 + -5, Actual: -6.00, Predicted Range: [-5.17, 5.95], bootstrapped prediction: [0.6057671], in Range: False
# Input: 4 - 2 - 2 - -3, Actual: 3.00, Predicted Range: [-0.48, 6.43], bootstrapped prediction: [2.20252], in Range: True
# Input: -1 - -2 - -5 + -1, Actual: 5.00, Predicted Range: [2.10, 9.18], bootstrapped prediction: [5.5102725], in Range: True
# Input: -4 - -4 + 1 - -5, Actual: 6.00, Predicted Range: [-5.87, 4.57], bootstrapped prediction: [-0.31747714], in Range: False
# Input: -1 - 1 - 3 + -5, Actual: -10.00, Predicted Range: [-4.64, 4.36], bootstrapped prediction: [-0.53568], in Range: False
# Input: -4 + 0 - 1 + -4, Actual: -9.00, Predicted Range: [-7.32, -0.17], bootstrapped prediction: [-3.1845582], in Range: False
# Input: 3 - 5 + -3 + -1, Actual: -6.00, Predicted Range: [-6.60, -1.37], bootstrapped prediction: [-4.39043], in Range: True
# Input: -1 - -4 - 0 - -2, Actual: 5.00, Predicted Range: [-1.39, 5.03], bootstrapped prediction: [2.4289963], in Range: True
# Input: -1 + 2 - -1 - -3, Actual: 5.00, Predicted Range: [-1.89, 5.28], bootstrapped prediction: [2.1099625], in Range: True
# Input: 1 - -3 + 5 - 4, Actual: 5.00, Predicted Range: [0.68, 8.07], bootstrapped prediction: [4.4989834], in Range: True
# Input: 4 - -2 - -2 - 2, Actual: 6.00, Predicted Range: [4.89, 10.50], bootstrapped prediction: [7.9390383], in Range: True
# Input: -3 + 5 + -4 + -2, Actual: -4.00, Predicted Range: [-7.41, 2.78], bootstrapped prediction: [-2.150776], in Range: True
# Input: 3 + -4 + 3 - 5, Actual: -3.00, Predicted Range: [-2.56, 5.36], bootstrapped prediction: [1.9042299], in Range: False
# Input: 0 + -2 - 1 + 3, Actual: 0.00, Predicted Range: [-5.13, 1.97], bootstrapped prediction: [-2.1689632], in Range: True
# Input: 0 + 5 - -2 + -2, Actual: 5.00, Predicted Range: [2.04, 10.00], bootstrapped prediction: [5.339392], in Range: True
# Input: -3 + 5 + 5 - -1, Actual: 8.00, Predicted Range: [4.60, 8.38], bootstrapped prediction: [6.4833465], in Range: True
# Input: -3 - -4 + -4 + 2, Actual: -1.00, Predicted Range: [-3.74, 0.98], bootstrapped prediction: [-1.642306], in Range: True
# Input: 2 - -1 + -4 + -2, Actual: -3.00, Predicted Range: [-6.61, 2.11], bootstrapped prediction: [-1.6977562], in Range: True
# Input: 1 - 0 - 1 + -4, Actual: -4.00, Predicted Range: [-2.36, 5.43], bootstrapped prediction: [1.4178493], in Range: False
# Input: 2 - -4 - 2 - 1, Actual: 3.00, Predicted Range: [2.52, 4.87], bootstrapped prediction: [3.929956], in Range: True
# Input: -3 + -2 + 1 - 3, Actual: -7.00, Predicted Range: [-5.49, -1.76], bootstrapped prediction: [-3.602599], in Range: False
# Input: 1 + -5 + -2 - 3, Actual: -9.00, Predicted Range: [-6.21, -0.32], bootstrapped prediction: [-3.7116776], in Range: False
# Input: -2 + -1 + -4 + -2, Actual: -9.00, Predicted Range: [-10.83, -2.28], bootstrapped prediction: [-6.8791857], in Range: True
# Input: -2 + 4 - 0 - 3, Actual: -1.00, Predicted Range: [-4.38, 2.59], bootstrapped prediction: [0.22122094], in Range: True
# Input: -5 + 0 - 5 - -5, Actual: -5.00, Predicted Range: [-8.81, 0.23], bootstrapped prediction: [-5.0967913], in Range: True
# Input: 3 - 5 + -1 - -5, Actual: 2.00, Predicted Range: [-5.44, 6.82], bootstrapped prediction: [0.47722548], in Range: True
# Input: 2 + -5 - 0 + -3, Actual: -6.00, Predicted Range: [-7.35, 1.35], bootstrapped prediction: [-3.0490556], in Range: True
# Input: -1 - 1 - -3 - 5, Actual: -4.00, Predicted Range: [-4.89, 7.15], bootstrapped prediction: [1.7713501], in Range: True
# Input: 2 - -4 - 1 - -5, Actual: 10.00, Predicted Range: [-1.63, 9.42], bootstrapped prediction: [3.1648192], in Range: False
# Input: -4 - -5 - -5 + 1, Actual: 7.00, Predicted Range: [5.03, 7.49], bootstrapped prediction: [6.1242075], in Range: True
# Input: 0 - 0 - -1 + 4, Actual: 5.00, Predicted Range: [-2.62, 6.14], bootstrapped prediction: [2.0234747], in Range: True
# Input: 1 + 3 - -3 - 0, Actual: 7.00, Predicted Range: [6.17, 7.82], bootstrapped prediction: [7.0425925], in Range: True
# Input: -3 + -5 + -2 - -4, Actual: -6.00, Predicted Range: [-13.63, -5.40], bootstrapped prediction: [-9.349559], in Range: True
# Input: 3 + 5 - -3 + -2, Actual: 9.00, Predicted Range: [4.64, 12.94], bootstrapped prediction: [8.565881], in Range: True
# Input: -1 - 3 - 5 + -2, Actual: -11.00, Predicted Range: [-8.95, -2.11], bootstrapped prediction: [-6.2303624], in Range: False
# Input: 2 - 1 + -5 - 0, Actual: -4.00, Predicted Range: [-5.34, -3.66], bootstrapped prediction: [-4.7010508], in Range: True
# Input: -1 + 3 + 3 + 3, Actual: 8.00, Predicted Range: [-1.15, 4.78], bootstrapped prediction: [1.8720509], in Range: False
# Input: -4 + 5 - -5 + -2, Actual: 4.00, Predicted Range: [-1.76, 7.88], bootstrapped prediction: [2.8700113], in Range: True
# Input: -1 - 0 + -4 - -2, Actual: -3.00, Predicted Range: [-9.57, -3.36], bootstrapped prediction: [-5.833028], in Range: False
# Input: 2 + 5 - -1 - -3, Actual: 11.00, Predicted Range: [3.03, 11.69], bootstrapped prediction: [7.32215], in Range: True
# Input: 1 + -3 + 2 + -4, Actual: -4.00, Predicted Range: [-3.59, 3.39], bootstrapped prediction: [0.35201284], in Range: False
# Input: -3 - 1 + 4 + -4, Actual: -4.00, Predicted Range: [-1.48, 4.92], bootstrapped prediction: [1.9631466], in Range: False
# Input: -2 + -1 - -5 + 1, Actual: 3.00, Predicted Range: [1.36, 3.57], bootstrapped prediction: [2.5574877], in Range: True
# Input: 1 + -5 - 5 + 5, Actual: -4.00, Predicted Range: [-11.97, 0.54], bootstrapped prediction: [-5.565009], in Range: True
# Input: -4 + -1 - -1 + -2, Actual: -6.00, Predicted Range: [-6.84, -2.24], bootstrapped prediction: [-4.247891], in Range: True
# Input: 5 + 4 - -4 + -2, Actual: 11.00, Predicted Range: [6.02, 14.61], bootstrapped prediction: [10.485066], in Range: True
# Input: 5 + 3 + -3 + 3, Actual: 8.00, Predicted Range: [2.13, 8.38], bootstrapped prediction: [5.560639], in Range: True
# Input: 2 + 0 - 4 + 5, Actual: 3.00, Predicted Range: [-9.11, 4.30], bootstrapped prediction: [-1.4943805], in Range: True
# Input: 3 - 4 + -3 - 4, Actual: -8.00, Predicted Range: [-6.33, 2.19], bootstrapped prediction: [-1.9039495], in Range: False
# Input: 4 - 4 + 2 + 4, Actual: 6.00, Predicted Range: [-3.88, 4.31], bootstrapped prediction: [0.9011677], in Range: False
# Input: -4 - -2 - -4 + 2, Actual: 4.00, Predicted Range: [0.61, 5.37], bootstrapped prediction: [2.4208426], in Range: True
# Input: -3 - 1 + -5 + 0, Actual: -9.00, Predicted Range: [-9.93, -7.42], bootstrapped prediction: [-8.718379], in Range: True
# Input: -3 + -3 + -1 - -3, Actual: -4.00, Predicted Range: [-9.93, -5.06], bootstrapped prediction: [-7.2000556], in Range: False
# Input: -2 + -3 - 1 - -3, Actual: -3.00, Predicted Range: [-8.71, -2.45], bootstrapped prediction: [-5.677742], in Range: True
# Input: 4 - -4 - 3 + -5, Actual: 0.00, Predicted Range: [-1.31, 11.64], bootstrapped prediction: [4.531693], in Range: True
# Input: -5 - 4 + -3 - -3, Actual: -9.00, Predicted Range: [-12.63, -5.91], bootstrapped prediction: [-9.565952], in Range: True
# Input: -1 + -4 - 5 + -5, Actual: -15.00, Predicted Range: [-9.77, 2.51], bootstrapped prediction: [-5.4708185], in Range: False
# Input: 5 - -3 + 1 - 5, Actual: 4.00, Predicted Range: [2.33, 13.55], bootstrapped prediction: [7.173027], in Range: True
# Input: 1 + -1 + -3 + 1, Actual: -2.00, Predicted Range: [-3.63, -1.41], bootstrapped prediction: [-2.403993], in Range: True
# Input: -3 + -1 - -2 + 1, Actual: -1.00, Predicted Range: [-2.78, -0.70], bootstrapped prediction: [-1.6520201], in Range: True
# Input: -5 + 2 + -3 - 0, Actual: -6.00, Predicted Range: [-7.36, -4.90], bootstrapped prediction: [-6.158572], in Range: True
# Input: 1 + -2 - 1 - 5, Actual: -7.00, Predicted Range: [-5.67, 5.79], bootstrapped prediction: [-0.41723108], in Range: False
# Input: -4 + -5 - 0 - -1, Actual: -8.00, Predicted Range: [-11.92, -8.13], bootstrapped prediction: [-9.664717], in Range: False
# Input: -5 - -3 + 5 + 3, Actual: 6.00, Predicted Range: [-3.29, 1.78], bootstrapped prediction: [-0.67353517], in Range: False
# Input: 3 + 0 + -5 + 4, Actual: 2.00, Predicted Range: [-3.78, 6.61], bootstrapped prediction: [1.5429676], in Range: True
# Input: -4 + -1 - -1 - -5, Actual: 1.00, Predicted Range: [-8.16, 0.45], bootstrapped prediction: [-4.018681], in Range: False
# Input: -3 - -1 + -1 - 4, Actual: -7.00, Predicted Range: [-4.93, 0.24], bootstrapped prediction: [-3.2220273], in Range: False
# Input: -1 + 2 - 2 + -3, Actual: -4.00, Predicted Range: [-2.69, 4.56], bootstrapped prediction: [1.1530354], in Range: False
# Input: 5 - -5 - 3 + -1, Actual: 6.00, Predicted Range: [5.25, 10.18], bootstrapped prediction: [6.956239], in Range: True
# Input: 3 - 3 + -2 + -4, Actual: -6.00, Predicted Range: [-6.64, 5.50], bootstrapped prediction: [-0.66712683], in Range: True
# Input: -4 - -5 - -2 - 5, Actual: -2.00, Predicted Range: [-2.86, 9.57], bootstrapped prediction: [2.528962], in Range: True
# Input: 0 - 0 + -1 + -4, Actual: -5.00, Predicted Range: [-5.99, 4.51], bootstrapped prediction: [-0.12799442], in Range: True
# Input: -4 - -2 - -5 - -1, Actual: 4.00, Predicted Range: [-1.32, 4.94], bootstrapped prediction: [1.8395315], in Range: True
# Input: 3 + -3 - -1 - 0, Actual: 1.00, Predicted Range: [-1.35, 0.95], bootstrapped prediction: [0.00881672], in Range: False
# Input: -3 + 4 - -5 - -3, Actual: 9.00, Predicted Range: [-4.19, 8.98], bootstrapped prediction: [2.9105675], in Range: False
# Input: 0 - -2 + 3 - -4, Actual: 9.00, Predicted Range: [-0.57, 8.53], bootstrapped prediction: [5.4504395], in Range: False
# Input: 1 + -3 + 0 - 2, Actual: -4.00, Predicted Range: [-2.74, -0.35], bootstrapped prediction: [-1.542657], in Range: False
# Input: -5 - 0 + -5 - -1, Actual: -9.00, Predicted Range: [-12.37, -8.80], bootstrapped prediction: [-10.295125], in Range: True
# Input: 3 - -1 + -5 + -5, Actual: -6.00, Predicted Range: [-9.58, 9.04], bootstrapped prediction: [-0.684883], in Range: True
# Input: 1 - -1 - -2 + 5, Actual: 9.00, Predicted Range: [-0.81, 11.43], bootstrapped prediction: [5.38275], in Range: True
# Input: 2 + 2 + -2 + -4, Actual: -2.00, Predicted Range: [-3.85, 9.90], bootstrapped prediction: [2.4643567], in Range: True
# Input: 1 + -3 + 3 + 5, Actual: 6.00, Predicted Range: [-3.89, 3.23], bootstrapped prediction: [0.46515685], in Range: False
# Input: 4 - 5 - 2 + -3, Actual: -6.00, Predicted Range: [-3.32, 7.34], bootstrapped prediction: [0.41339985], in Range: False
# Input: -4 - -2 - 5 - -5, Actual: -2.00, Predicted Range: [-8.18, 1.46], bootstrapped prediction: [-2.8724904], in Range: True
# Input: -2 + 4 - 2 - 3, Actual: -3.00, Predicted Range: [-5.91, 0.24], bootstrapped prediction: [-1.6588738], in Range: True
# Input: -4 - -4 - 4 - -3, Actual: -1.00, Predicted Range: [-7.97, 1.35], bootstrapped prediction: [-2.8271184], in Range: True
# Input: 4 + 4 + 2 + 4, Actual: 14.00, Predicted Range: [1.73, 10.87], bootstrapped prediction: [6.288388], in Range: False
# Input: -2 + 5 - 0 - -3, Actual: 6.00, Predicted Range: [0.01, 7.85], bootstrapped prediction: [4.0331845], in Range: True
# Input: -1 - -4 - -1 + 1, Actual: 5.00, Predicted Range: [3.29, 5.38], bootstrapped prediction: [4.370185], in Range: True
# Input: -2 - 5 - 3 - 5 - 0, Actual: -15.00, Predicted Range: [-17.70, -4.93], bootstrapped prediction: [-9.019439], in Range: True
# Input: 3 - -5 - -5 - -2 + -2, Actual: 13.00, Predicted Range: [1.12, 13.90], bootstrapped prediction: [7.1680436], in Range: True
# Input: 1 + 3 + 4 + 4 + 3, Actual: 15.00, Predicted Range: [-1.08, 5.13], bootstrapped prediction: [2.658653], in Range: False
# Input: -2 - -3 + 3 + 0 + -5, Actual: -1.00, Predicted Range: [-4.15, 10.76], bootstrapped prediction: [2.8533974], in Range: True
# Input: 1 - 2 - 5 - 1 + 5, Actual: -2.00, Predicted Range: [-7.92, 2.97], bootstrapped prediction: [-1.9199502], in Range: True
# Input: 3 + -4 + -3 + -1 - -2, Actual: -3.00, Predicted Range: [-10.64, -1.59], bootstrapped prediction: [-5.5157766], in Range: True
# Input: 2 - 5 + -5 - -2 + 5, Actual: -1.00, Predicted Range: [-6.78, 1.31], bootstrapped prediction: [-2.641822], in Range: True
# Input: -1 + -3 - -4 + -2 + -4, Actual: -6.00, Predicted Range: [-10.65, 5.11], bootstrapped prediction: [-2.212565], in Range: True
# Input: 0 + 2 - -4 + -2 - 5, Actual: -1.00, Predicted Range: [1.39, 11.04], bootstrapped prediction: [6.2887073], in Range: False
# Input: -5 - -3 - 0 + -4 + -5, Actual: -11.00, Predicted Range: [-11.28, 6.56], bootstrapped prediction: [-1.8080628], in Range: True
# Input: 0 - -3 - 3 + -4 - -4, Actual: 0.00, Predicted Range: [-7.93, 9.72], bootstrapped prediction: [0.9065527], in Range: True
# Input: -4 - -4 + 1 + 1 - -4, Actual: 6.00, Predicted Range: [-4.99, 8.02], bootstrapped prediction: [1.113611], in Range: True
# Input: 1 - 2 - -4 + 0 + 0, Actual: 3.00, Predicted Range: [1.11, 5.09], bootstrapped prediction: [3.016903], in Range: True
# Input: 4 - 4 - 0 + 4 + -5, Actual: -1.00, Predicted Range: [-5.85, 13.09], bootstrapped prediction: [3.1634145], in Range: True
# Input: -5 - -2 + -4 + 1 - 1, Actual: -7.00, Predicted Range: [-7.78, -4.81], bootstrapped prediction: [-6.5277467], in Range: True
# Input: -3 + -4 + -5 + 4 + 3, Actual: -5.00, Predicted Range: [-9.11, 0.74], bootstrapped prediction: [-3.680762], in Range: True
# Input: -2 + 4 - 1 - 0 + 0, Actual: 1.00, Predicted Range: [0.27, 2.27], bootstrapped prediction: [1.2964057], in Range: True
# Input: 5 - 0 + -3 - -3 + 4, Actual: 9.00, Predicted Range: [-2.04, 11.90], bootstrapped prediction: [4.3743644], in Range: True
# Input: 1 - -3 + 1 - 1 + 3, Actual: 7.00, Predicted Range: [0.95, 10.76], bootstrapped prediction: [4.703573], in Range: True
# Input: 0 + 1 + 4 + 1 - 1, Actual: 5.00, Predicted Range: [2.90, 5.37], bootstrapped prediction: [4.1086473], in Range: True
# Input: -3 + -1 + 2 + -4 + -5, Actual: -11.00, Predicted Range: [-9.73, 6.00], bootstrapped prediction: [-2.2532458], in Range: False
# Input: 1 + 0 - -4 + -2 + -4, Actual: -1.00, Predicted Range: [-6.45, 8.61], bootstrapped prediction: [1.7930771], in Range: True
# Input: -3 - 0 + -2 - -5 - 0, Actual: 0.00, Predicted Range: [-9.41, 3.66], bootstrapped prediction: [-3.0813134], in Range: True
# Input: -3 + -2 + -2 + 0 - 1, Actual: -8.00, Predicted Range: [-8.15, -6.23], bootstrapped prediction: [-6.9789224], in Range: True
# Input: -4 - 0 - 0 - -2 + 1, Actual: -1.00, Predicted Range: [-4.94, 0.13], bootstrapped prediction: [-3.0148456], in Range: True
# Input: 2 - -4 - -1 + 2 + 2, Actual: 11.00, Predicted Range: [5.48, 8.90], bootstrapped prediction: [7.4899607], in Range: False
# Input: -1 - 0 + -1 + 5 - -1, Actual: 4.00, Predicted Range: [-5.09, 3.80], bootstrapped prediction: [-0.7450849], in Range: False
# Input: -2 + -3 - 1 - 1 + -3, Actual: -10.00, Predicted Range: [-9.41, -1.10], bootstrapped prediction: [-6.257451], in Range: False
# Input: 3 - 0 - 2 + -2 - 0, Actual: -1.00, Predicted Range: [-0.70, 4.68], bootstrapped prediction: [1.7487751], in Range: False
# Input: -4 - 5 - 1 - 5 + -2, Actual: -17.00, Predicted Range: [-19.18, -3.29], bootstrapped prediction: [-9.101995], in Range: True
# Input: 3 + -4 + 1 - 1 + 2, Actual: 1.00, Predicted Range: [-0.44, 4.32], bootstrapped prediction: [1.9555542], in Range: True
# Input: -4 + -1 - -1 + 0 + -1, Actual: -5.00, Predicted Range: [-6.33, -1.76], bootstrapped prediction: [-4.0653024], in Range: True
# Input: -2 - 5 - 2 + 4 - -3, Actual: -2.00, Predicted Range: [-16.14, 1.80], bootstrapped prediction: [-6.734642], in Range: True
# Input: -5 + -3 - 2 - -2 + 1, Actual: -7.00, Predicted Range: [-10.44, -6.96], bootstrapped prediction: [-9.006122], in Range: True
# Input: 1 - 5 + -5 - -2 + -1, Actual: -8.00, Predicted Range: [-12.57, -3.22], bootstrapped prediction: [-7.9689646], in Range: True
# Input: -4 - 2 - 5 - 5 - -4, Actual: -12.00, Predicted Range: [-18.72, -1.09], bootstrapped prediction: [-8.403807], in Range: True
# Input: 5 - -1 - -5 - 2 - -3, Actual: 12.00, Predicted Range: [2.12, 14.65], bootstrapped prediction: [8.879235], in Range: True
# Input: -2 - -1 + 3 - 4 + 5, Actual: 3.00, Predicted Range: [-6.43, 7.78], bootstrapped prediction: [-0.23958571], in Range: True
# Input: 5 - 0 + 2 + 1 - -2, Actual: 10.00, Predicted Range: [4.03, 8.90], bootstrapped prediction: [6.9227266], in Range: False
# Input: -1 - -1 - -5 + 2 - -1, Actual: 8.00, Predicted Range: [1.42, 10.36], bootstrapped prediction: [5.1642017], in Range: True
# Input: -3 + -2 - 1 - -1 + -1, Actual: -6.00, Predicted Range: [-8.27, -5.39], bootstrapped prediction: [-6.9642167], in Range: True
# Input: -1 - 1 + 5 - -4 - -4, Actual: 11.00, Predicted Range: [-2.99, 11.95], bootstrapped prediction: [4.886817], in Range: True
# Input: -2 + 1 + -5 + 4 + 5, Actual: 3.00, Predicted Range: [-7.32, 5.34], bootstrapped prediction: [-1.1590565], in Range: True
# Input: 0 + 1 + 2 - -2 - 5, Actual: 0.00, Predicted Range: [-1.03, 9.92], bootstrapped prediction: [3.6975105], in Range: True
# Input: -5 - 0 - -3 + 1 - -4, Actual: 3.00, Predicted Range: [-6.61, 2.86], bootstrapped prediction: [-1.8710172], in Range: False
# Input: 2 + 5 - -5 + 4 + 4, Actual: 20.00, Predicted Range: [0.06, 15.19], bootstrapped prediction: [7.8459716], in Range: False
# Input: -5 + -3 - -3 - -4 - 4, Actual: -5.00, Predicted Range: [-7.95, 3.45], bootstrapped prediction: [-2.8708985], in Range: True
# Input: -1 - 0 - -2 - 1 + 5, Actual: 5.00, Predicted Range: [-3.23, 8.24], bootstrapped prediction: [2.0602496], in Range: True
# Input: -3 + -4 + 4 - -1 + -2, Actual: -4.00, Predicted Range: [-9.37, 1.43], bootstrapped prediction: [-3.5761104], in Range: True
# Input: -2 - -3 + -2 - 0 - 3, Actual: -4.00, Predicted Range: [-4.85, 5.78], bootstrapped prediction: [-0.58475274], in Range: True
# Input: -2 + 0 - -4 + 0 - 1, Actual: 1.00, Predicted Range: [0.88, 3.40], bootstrapped prediction: [2.1412334], in Range: True
# Input: -2 - 5 + 5 - 5 + -4, Actual: -11.00, Predicted Range: [-15.27, 4.54], bootstrapped prediction: [-3.895975], in Range: True
# Input: -1 - 4 + 4 + 0 - 0, Actual: -1.00, Predicted Range: [-1.30, 0.71], bootstrapped prediction: [-0.25712976], in Range: True
# Input: -2 + -4 + -5 - -4 + -1, Actual: -8.00, Predicted Range: [-15.35, -2.75], bootstrapped prediction: [-10.342024], in Range: True
# Input: 3 + -2 - 1 + 4 + 2, Actual: 6.00, Predicted Range: [-1.64, 6.37], bootstrapped prediction: [2.1848989], in Range: True
# Input: -3 - 2 + -4 + -2 + 3, Actual: -8.00, Predicted Range: [-12.37, -1.57], bootstrapped prediction: [-6.7761946], in Range: True
# Input: -3 - 5 + 4 + 0 - -4, Actual: 0.00, Predicted Range: [-9.80, 4.29], bootstrapped prediction: [-1.9416269], in Range: True
# Input: -5 - 5 + 1 - -4 + -5, Actual: -10.00, Predicted Range: [-13.45, 1.30], bootstrapped prediction: [-4.4231043], in Range: True
# Input: -2 - 5 - -1 - 4 + -5, Actual: -15.00, Predicted Range: [-11.86, 7.21], bootstrapped prediction: [-2.6818805], in Range: False
# Input: 1 + -4 - 5 + 5 + -4, Actual: -7.00, Predicted Range: [-13.33, 4.88], bootstrapped prediction: [-4.175641], in Range: True
# Input: 2 + 3 - 5 + -5 - 5, Actual: -10.00, Predicted Range: [-0.21, 12.89], bootstrapped prediction: [4.9276958], in Range: False
# Input: 1 - -3 + -2 - -3 - 3, Actual: 2.00, Predicted Range: [-3.11, 8.64], bootstrapped prediction: [2.2614532], in Range: True
# Input: -5 - -5 - -2 - 1 - 1, Actual: 0.00, Predicted Range: [-0.99, 3.28], bootstrapped prediction: [1.3427285], in Range: True
# Input: 0 + 5 - -1 + -2 - 2, Actual: 2.00, Predicted Range: [1.11, 9.76], bootstrapped prediction: [5.186038], in Range: True
# Input: 1 + 5 - -5 - -4 - -1, Actual: 16.00, Predicted Range: [-4.21, 12.16], bootstrapped prediction: [5.5400076], in Range: False
# Input: 2 - 5 - -1 + -1 - -5, Actual: 2.00, Predicted Range: [-7.76, 10.60], bootstrapped prediction: [1.3282855], in Range: True
# Input: 2 + -1 + -3 - 4 + 0, Actual: -6.00, Predicted Range: [-2.30, 3.56], bootstrapped prediction: [0.30391893], in Range: False
# Input: -1 + 4 + 5 + -4 - -3, Actual: 7.00, Predicted Range: [1.09, 12.53], bootstrapped prediction: [6.496324], in Range: True
# Input: -2 + -1 - 0 + 5 + 1, Actual: 3.00, Predicted Range: [-7.01, 3.62], bootstrapped prediction: [-1.7302306], in Range: True
# Input: -3 + -3 - 0 - 2 + 0, Actual: -8.00, Predicted Range: [-8.01, -3.29], bootstrapped prediction: [-5.381204], in Range: True
# Input: 4 + -3 - -1 + 2 - 0, Actual: 4.00, Predicted Range: [-0.26, 5.75], bootstrapped prediction: [2.6115956], in Range: True
# Input: 3 - 5 + 4 + 4 - 3, Actual: 3.00, Predicted Range: [-3.28, 4.24], bootstrapped prediction: [0.13045308], in Range: True
# Input: -2 + -4 + -5 - -4 - -4, Actual: -3.00, Predicted Range: [-16.46, -1.66], bootstrapped prediction: [-9.897734], in Range: True
# Input: -5 - -4 - 0 + 1 + 1, Actual: 1.00, Predicted Range: [-1.58, 0.27], bootstrapped prediction: [-0.8094009], in Range: False
# Input: -2 - -1 - 5 - -3 + 2, Actual: -1.00, Predicted Range: [-6.80, 1.01], bootstrapped prediction: [-2.402152], in Range: True
# Input: 4 + 1 - 3 - 4 - -1, Actual: -1.00, Predicted Range: [-4.22, 5.58], bootstrapped prediction: [1.5923431], in Range: True
# Input: -1 + 1 + 3 - 1 - -5, Actual: 7.00, Predicted Range: [-6.76, 7.17], bootstrapped prediction: [1.7342014], in Range: True
# Input: 4 + 0 - 3 + 1 + 3, Actual: 5.00, Predicted Range: [0.26, 4.02], bootstrapped prediction: [2.162949], in Range: False
# Input: -3 - 3 - 3 + 2 - 1, Actual: -8.00, Predicted Range: [-10.97, -6.79], bootstrapped prediction: [-8.694645], in Range: True
# Input: -2 + -2 + 0 - 4 + -1, Actual: -9.00, Predicted Range: [-5.42, -0.66], bootstrapped prediction: [-2.792295], in Range: False
# Input: -3 + 3 - 0 + -3 + 2, Actual: -1.00, Predicted Range: [-3.21, 6.51], bootstrapped prediction: [1.0242933], in Range: True
# Input: 2 - -1 + -1 + -4 + 5, Actual: 3.00, Predicted Range: [-3.28, 12.58], bootstrapped prediction: [4.0224185], in Range: True
# Input: -2 - 5 + -5 - 2 - -5, Actual: -9.00, Predicted Range: [-12.95, 1.48], bootstrapped prediction: [-5.9950666], in Range: True
# Input: 3 + -2 - 1 + 0 + 3, Actual: 3.00, Predicted Range: [-0.19, 5.14], bootstrapped prediction: [2.3914914], in Range: True
# Input: -4 + 5 + 5 + 1 + 5, Actual: 12.00, Predicted Range: [-6.41, 3.37], bootstrapped prediction: [-0.7195715], in Range: False
# Input: 5 - 3 + -1 - 2 + 1, Actual: 0.00, Predicted Range: [-0.64, 2.85], bootstrapped prediction: [1.1800928], in Range: True
# Input: -4 + 1 + 0 - 1 + -2, Actual: -6.00, Predicted Range: [-5.48, -1.32], bootstrapped prediction: [-2.813109], in Range: False
# Input: -4 + 5 + 2 + -1 + 5, Actual: 7.00, Predicted Range: [-6.28, 3.38], bootstrapped prediction: [-0.46353865], in Range: False
# Input: 3 + 4 + 2 + 4 - 4, Actual: 9.00, Predicted Range: [0.64, 8.22], bootstrapped prediction: [4.9603868], in Range: False
# Input: 5 - 4 - 2 - 4 - -2, Actual: -3.00, Predicted Range: [-7.93, 8.50], bootstrapped prediction: [0.43831348], in Range: True
# Input: -3 + -4 + -5 + 4 + 3, Actual: -5.00, Predicted Range: [-9.11, 0.74], bootstrapped prediction: [-3.680762], in Range: True
# Input: -5 - 3 + 2 - -2 - 1, Actual: -5.00, Predicted Range: [-5.18, -0.54], bootstrapped prediction: [-3.0900106], in Range: True
# Input: -5 + 0 + -5 - 4 + -5, Actual: -19.00, Predicted Range: [-11.28, -0.92], bootstrapped prediction: [-5.532302], in Range: False
# ...
# Input: -2 - -4 + 3 - 2 + 5 + -4 + 0, Actual: 4.00, Predicted Range: [-3.81, 13.53], bootstrapped prediction: [3.0929687], in Range: True
# Input: 5 + -4 - 2 + -5 - -2 + -4 - -5, Actual: -3.00, Predicted Range: [-11.24, 9.57], bootstrapped prediction: [0.40429345], in Range: True
# Input: 0 + 0 + -2 - -2 - 0 - -1 - 4, Actual: -3.00, Predicted Range: [-5.03, 1.54], bootstrapped prediction: [-1.6795483], in Range: True
# Input: -2 - 2 + -3 - 4 - -2 + 0 + 4, Actual: -5.00, Predicted Range: [-11.66, 1.25], bootstrapped prediction: [-5.022621], in Range: True
# Input: -2 - -4 - -1 + 3 - -3 - -5 - -3, Actual: 17.00, Predicted Range: [-7.80, 6.62], bootstrapped prediction: [-1.0500647], in Range: False
# Input: 2 + -3 + -4 + -5 + 4 + -1 + 0, Actual: -7.00, Predicted Range: [-9.98, 10.60], bootstrapped prediction: [-0.10490005], in Range: True
# Input: -4 + -4 - -1 + -2 - -4 - -2 + 3, Actual: 0.00, Predicted Range: [-14.08, -2.55], bootstrapped prediction: [-7.5177054], in Range: False
# Input: -4 - -5 - -2 + -2 + -3 + -4 + 4, Actual: -2.00, Predicted Range: [-8.85, 8.49], bootstrapped prediction: [-0.26311064], in Range: True
# Input: -2 - 1 + 2 + -4 - -4 - 2 - -2, Actual: -1.00, Predicted Range: [-6.67, 9.13], bootstrapped prediction: [1.4780493], in Range: True
# Input: 3 - -2 + -5 + 0 + 5 + -1 - -4, Actual: 8.00, Predicted Range: [-4.44, 8.90], bootstrapped prediction: [1.7832174], in Range: True
# Input: 1 - -1 - -4 + 5 + 4 - -1 + 3, Actual: 19.00, Predicted Range: [-3.93, 16.05], bootstrapped prediction: [6.510485], in Range: False
# Input: 2 - 0 + -5 - 1 - -1 - 3 - -3 - 0, Actual: -3.00, Predicted Range: [-10.42, 1.63], bootstrapped prediction: [-3.7639298], in Range: True
# Input: -2 + -5 + 0 - 5 + 1 - 3 + 1 - 3, Actual: -16.00, Predicted Range: [-11.05, 4.17], bootstrapped prediction: [-3.6650422], in Range: False
# Input: 4 - 3 - 2 + -3 + -3 + -1 + 4 + -5, Actual: -9.00, Predicted Range: [-7.19, 8.22], bootstrapped prediction: [1.5529611], in Range: False
# Input: 2 + 5 - -4 + 0 - -2 + 5 - -4 - 1, Actual: 21.00, Predicted Range: [-1.09, 17.09], bootstrapped prediction: [7.163981], in Range: False
# Input: -5 + -2 - 0 - 2 + 3 + -4 + -4 + 0, Actual: -14.00, Predicted Range: [-10.36, 0.62], bootstrapped prediction: [-4.585392], in Range: False
# Input: 5 - -5 + 1 + -1 - -3 + 1 + 0 + 0, Actual: 14.00, Predicted Range: [5.08, 13.74], bootstrapped prediction: [9.072413], in Range: False
# Input: 1 - 2 - -4 - 0 - -1 - -5 + -5 - 3, Actual: 1.00, Predicted Range: [-9.16, 13.38], bootstrapped prediction: [1.8127594], in Range: True
# Input: -2 - 4 + 5 - -4 - -4 + -5 + -5 - 1, Actual: -4.00, Predicted Range: [-5.73, 12.98], bootstrapped prediction: [4.2768545], in Range: True
# Input: -2 + -2 - 4 + -5 - 4 - 4 + 1 - 1, Actual: -21.00, Predicted Range: [-5.51, 5.24], bootstrapped prediction: [-1.0268146], in Range: False
# Input: 0 - 2 + 3 + -2 + 4 - 0 - 2 + 4, Actual: 5.00, Predicted Range: [-7.34, 6.11], bootstrapped prediction: [-0.4903442], in Range: True
# Input: 0 + -1 + 3 + 1 - 3 + 3 + 0 - 0, Actual: 3.00, Predicted Range: [-2.91, 4.94], bootstrapped prediction: [2.0590026], in Range: True
# Input: -2 - -4 + -5 - -4 + 0 - -2 + -1 + 4, Actual: 6.00, Predicted Range: [-13.58, 8.08], bootstrapped prediction: [-2.2268353], in Range: True
# Input: -5 - 5 - -1 + -2 + 4 + 2 - -2 - -1, Actual: -2.00, Predicted Range: [-9.19, 4.43], bootstrapped prediction: [-4.4619474], in Range: True
# Input: -1 + -3 + -1 - 1 - -1 - 5 - 2 + -4, Actual: -16.00, Predicted Range: [-8.57, 7.01], bootstrapped prediction: [-0.6879743], in Range: False
# Input: -5 - 0 + -5 + 0 - 2 - 3 + 0 - 0, Actual: -15.00, Predicted Range: [-15.33, -3.19], bootstrapped prediction: [-7.638124], in Range: True
# Input: -5 + -3 + 3 - 5 - -1 + 5 + -1 + -1, Actual: -6.00, Predicted Range: [-15.73, 4.98], bootstrapped prediction: [-4.570949], in Range: True
# Input: 4 - -1 + -3 - 3 + -4 - 3 + 1 - -5, Actual: -2.00, Predicted Range: [-6.73, 15.04], bootstrapped prediction: [2.7567294], in Range: True
# Input: 2 + 4 + -5 + 2 + 0 - 2 + 2 + 1, Actual: 4.00, Predicted Range: [-3.39, 4.44], bootstrapped prediction: [1.2702614], in Range: True
# Input: 1 + 0 - 5 + 0 - 1 + 1 - 2 - 5, Actual: -11.00, Predicted Range: [-8.62, 6.09], bootstrapped prediction: [-2.1201546], in Range: False
# Input: 0 - 5 + 1 - 2 + 4 + -2 - 4 - 3, Actual: -11.00, Predicted Range: [-14.73, 1.14], bootstrapped prediction: [-5.936448], in Range: True
# Input: 0 - -5 - 5 + -1 + 4 - 2 - -1 - -2, Actual: 4.00, Predicted Range: [-3.23, 12.94], bootstrapped prediction: [3.524715], in Range: True
# Input: 0 - -1 - 3 + -5 + 3 - 5 - -1 + 5, Actual: -3.00, Predicted Range: [-3.93, 14.11], bootstrapped prediction: [2.9306731], in Range: True
# Input: 2 + 3 - 5 + 2 + 1 - -1 + -4 - 2, Actual: -2.00, Predicted Range: [-2.09, 6.41], bootstrapped prediction: [1.6987219], in Range: True
# Input: -1 - 5 + -5 + 1 + -3 + -4 - -4 - -1, Actual: -12.00, Predicted Range: [-13.88, 2.08], bootstrapped prediction: [-5.454204], in Range: True
# Input: 2 - 4 + 4 - -1 + 3 - 4 + -1 + 3, Actual: 4.00, Predicted Range: [-7.00, 6.41], bootstrapped prediction: [-0.4814865], in Range: True
# Input: -2 - -1 + 3 - -1 + -2 - 5 + 0 - 1, Actual: -5.00, Predicted Range: [-4.53, 9.40], bootstrapped prediction: [0.41399422], in Range: False
# Input: 0 + -5 + -4 + -3 - 4 + -4 - 5 - 5, Actual: -30.00, Predicted Range: [-10.25, 14.50], bootstrapped prediction: [2.0888848], in Range: False
# Input: -1 + 0 + -5 + -3 - -2 + 5 - -2 - 5, Actual: -5.00, Predicted Range: [-10.01, 9.87], bootstrapped prediction: [-0.25448623], in Range: True
# Input: 0 - -3 - -4 + -3 + -5 - -3 + 3 - 5, Actual: 0.00, Predicted Range: [-6.67, 14.82], bootstrapped prediction: [3.404225], in Range: True
# Input: 5 + 3 + 1 + 1 - -1 - -5 + -2 + -4, Actual: 10.00, Predicted Range: [-5.55, 9.48], bootstrapped prediction: [4.3439317], in Range: False
# Input: -4 - -5 - 3 - -5 - 1 + -1 + 3 + -1, Actual: 3.00, Predicted Range: [-8.69, 2.63], bootstrapped prediction: [-2.901383], in Range: False
# Input: -4 - -2 - 3 - -4 - -5 + 2 - -4 + -2, Actual: 8.00, Predicted Range: [-15.09, 10.03], bootstrapped prediction: [-1.7505707], in Range: True
# Input: -4 - 2 + -2 - -2 + -2 + 4 + 3 + -4, Actual: -5.00, Predicted Range: [-12.31, 5.57], bootstrapped prediction: [-3.9477334], in Range: True
# Input: 5 - -3 + -4 + 5 - 2 + 3 + 0 + -3, Actual: 7.00, Predicted Range: [-0.04, 15.27], bootstrapped prediction: [9.363768], in Range: True
# Input: 1 - 3 - 5 + -3 + -4 + 5 + 0 + -4, Actual: -13.00, Predicted Range: [-13.38, 15.69], bootstrapped prediction: [0.5193893], in Range: True
# Input: -3 + -3 + -5 + 3 - 5 - 2 + 4 - 2, Actual: -13.00, Predicted Range: [-15.67, 4.12], bootstrapped prediction: [-2.9434714], in Range: True
# Input: -2 + -4 - 5 + -3 - 5 - 1 - 2 - 4, Actual: -26.00, Predicted Range: [-10.55, 3.71], bootstrapped prediction: [-2.6920657], in Range: False
# Input: 2 - -1 + 2 - -5 + -1 + 3 - 4 - -3, Actual: 11.00, Predicted Range: [-3.94, 12.88], bootstrapped prediction: [4.7803793], in Range: True
# Input: 2 + 1 - 4 - -4 - 5 - -2 + -4 + 1, Actual: -3.00, Predicted Range: [-0.94, 10.18], bootstrapped prediction: [3.4944806], in Range: False
# Input: 3 - 3 + -3 + 4 + 5 - -4 + 4 - -2, Actual: 16.00, Predicted Range: [-8.62, 13.19], bootstrapped prediction: [1.8798721], in Range: False
# Input: 0 + -1 + 2 + 4 + 3 + 3 - 3 + 0, Actual: 8.00, Predicted Range: [-5.80, 3.72], bootstrapped prediction: [-0.45334417], in Range: False
# Input: -2 - 5 - 4 + -1 + 1 + 5 + -2 - 5, Actual: -13.00, Predicted Range: [-12.92, -1.46], bootstrapped prediction: [-7.5077987], in Range: False
# Input: -4 - 2 - -3 + -1 + -5 + -1 - 4 - 5, Actual: -19.00, Predicted Range: [-14.61, 4.55], bootstrapped prediction: [-4.3466864], in Range: False
# Input: 5 + -4 + 4 + -3 + -1 - 4 + 2 - -3, Actual: 2.00, Predicted Range: [-2.20, 14.27], bootstrapped prediction: [5.768819], in Range: True
# Input: -5 - -3 + 5 + -3 - 2 - -3 + 2 - -3, Actual: 6.00, Predicted Range: [-6.95, 4.89], bootstrapped prediction: [0.44605413], in Range: False
# Input: 1 + -4 - 2 + -2 - 5 + 5 - -2 + 4, Actual: -1.00, Predicted Range: [-4.26, 12.87], bootstrapped prediction: [4.4793906], in Range: True
# Input: -1 - -5 - 1 - 5 - 4 + -1 - 4 - -4, Actual: -7.00, Predicted Range: [-7.05, 16.27], bootstrapped prediction: [3.1001704], in Range: True
# Input: 3 - 3 - -2 + -1 - -1 - -2 + 1 - -1, Actual: 6.00, Predicted Range: [-0.25, 6.91], bootstrapped prediction: [3.236538], in Range: True
# Input: 3 + 1 - -2 - 4 + 0 + -5 + 3 - 0, Actual: 0.00, Predicted Range: [-5.32, 17.01], bootstrapped prediction: [5.754505], in Range: True
# Input: 2 + -1 - 1 - -1 + -2 - 1 - 4 + 4, Actual: -2.00, Predicted Range: [-9.49, 6.07], bootstrapped prediction: [-1.3595353], in Range: True
# Input: 4 - 0 + -1 + 2 - 1 - -1 + 4 - 1, Actual: 8.00, Predicted Range: [-7.10, 9.29], bootstrapped prediction: [2.9632888], in Range: True
# Input: 4 + 2 + -4 - -2 + 4 - 3 - 0 - 0, Actual: 5.00, Predicted Range: [-1.26, 11.98], bootstrapped prediction: [4.599841], in Range: True
# Input: 4 + 4 - 3 + 3 + 5 - 3 + 4 + -1, Actual: 13.00, Predicted Range: [-6.17, 5.90], bootstrapped prediction: [1.1007686], in Range: False
# Input: 0 + -5 + 2 - -2 - 1 - 0 + -2 - -3, Actual: -1.00, Predicted Range: [-10.59, -0.67], bootstrapped prediction: [-5.4514546], in Range: True
# Input: -1 + -4 + 3 - -3 - -1 - -1 + -3 + 3, Actual: 3.00, Predicted Range: [-8.14, 4.86], bootstrapped prediction: [-1.50721], in Range: True
# Input: -1 - -3 - 3 - 1 - 1 - 2 - -5 + -2, Actual: -2.00, Predicted Range: [-8.22, 9.42], bootstrapped prediction: [0.16184166], in Range: True
# Input: -1 + -5 + -4 - 1 - -1 + 5 - -5 + 0, Actual: 0.00, Predicted Range: [-15.16, 5.45], bootstrapped prediction: [-5.256358], in Range: True
# Input: -5 - 0 + 3 + -2 + 3 + 0 + 1 + -5, Actual: -5.00, Predicted Range: [-5.69, 6.63], bootstrapped prediction: [-1.5208905], in Range: True
# Input: -1 + 4 - 0 - 3 + -2 + 5 - -4 - -3, Actual: 10.00, Predicted Range: [-15.15, 17.33], bootstrapped prediction: [2.998826], in Range: True
# Input: 5 + 5 - -2 - 4 - 1 + -1 - -5 + 0, Actual: 11.00, Predicted Range: [-0.56, 12.97], bootstrapped prediction: [7.310263], in Range: True
# Input: 5 - 2 + -4 + 3 - -4 + 2 + 0 + -2, Actual: 6.00, Predicted Range: [-4.29, 10.72], bootstrapped prediction: [2.606361], in Range: True
# Input: -1 - 5 + -5 + 3 - -5 + 1 + -4 - -5, Actual: -1.00, Predicted Range: [-11.56, 7.53], bootstrapped prediction: [-4.136505], in Range: True
# Input: -1 - -2 + -1 + 4 - -4 - 3 - -3 - -4, Actual: 12.00, Predicted Range: [-12.06, 13.70], bootstrapped prediction: [-0.0120446], in Range: True
# Input: -3 - -1 + 4 - 2 + -2 - -5 + -1 - -5, Actual: 7.00, Predicted Range: [-6.16, 6.79], bootstrapped prediction: [0.67295253], in Range: False
# Input: 5 - -1 - -2 - -1 - 3 + -4 - -3 + -4, Actual: 1.00, Predicted Range: [-5.50, 8.75], bootstrapped prediction: [1.3450596], in Range: True
# Input: -5 - 2 + -1 - 4 + -1 + 3 + 2 - -5, Actual: -3.00, Predicted Range: [-16.29, 4.88], bootstrapped prediction: [-4.40954], in Range: True
# Input: -5 - 2 - -5 + -2 + -4 + 5 - 5 - -3, Actual: -5.00, Predicted Range: [-13.95, 10.33], bootstrapped prediction: [-2.210244], in Range: True
# Input: -2 + 3 - -1 + 3 - 5 + 2 + -1 + -5, Actual: -4.00, Predicted Range: [-10.62, 9.48], bootstrapped prediction: [1.250288], in Range: True
# Input: 0 + 2 - -4 + 0 - 5 - 4 + 0 + -5, Actual: -8.00, Predicted Range: [-2.96, 16.60], bootstrapped prediction: [5.345973], in Range: False
# Input: 1 - -1 - 4 + 5 - -1 + -5 - -1 + -3, Actual: -3.00, Predicted Range: [-6.90, 5.39], bootstrapped prediction: [0.35186815], in Range: True
# Input: -5 + -4 + 3 - -2 - 3 + 0 - 4 + 3, Actual: -8.00, Predicted Range: [-14.92, 0.47], bootstrapped prediction: [-5.279745], in Range: True
# Input: 1 + 3 - -1 - -4 - -4 + -2 - -1 + 5, Actual: 17.00, Predicted Range: [-6.18, 12.20], bootstrapped prediction: [4.1237345], in Range: False
# Input: -5 - 4 - 3 - 2 + 0 + 3 - 1 + -5, Actual: -17.00, Predicted Range: [-19.11, 5.12], bootstrapped prediction: [-4.9419575], in Range: True
# Input: -1 + -4 + 0 - -4 + -5 + 1 + -2 + 2, Actual: -5.00, Predicted Range: [-11.79, 6.26], bootstrapped prediction: [-2.9052272], in Range: True
# Input: 2 - -5 + 3 - -4 - 5 - -3 - -4 + 2, Actual: 18.00, Predicted Range: [-2.21, 10.56], bootstrapped prediction: [4.7478137], in Range: False
# Input: 0 - -3 - 3 - 4 - -5 - -2 - -3 - 2, Actual: 4.00, Predicted Range: [-7.55, 8.56], bootstrapped prediction: [0.84739363], in Range: True
# Input: 3 - -2 + -4 + 4 + 1 - 3 + 4 - 4, Actual: 3.00, Predicted Range: [-8.76, 8.97], bootstrapped prediction: [3.0417836], in Range: True
# Input: 0 - -4 - 3 + 1 + -1 + 3 - -1 + -5, Actual: 0.00, Predicted Range: [-12.22, 12.67], bootstrapped prediction: [2.8115978], in Range: True
# Input: -3 + -2 + -4 - -3 + 2 + 3 - 4 + -2, Actual: -7.00, Predicted Range: [-11.37, 2.81], bootstrapped prediction: [-4.138424], in Range: True
# Input: -1 + 3 + 3 + 4 - 4 - -3 + 0 + 2, Actual: 10.00, Predicted Range: [-4.29, 6.96], bootstrapped prediction: [1.877945], in Range: False
# Input: -3 - -5 - 3 - 3 + -4 - 2 - 4 + -5, Actual: -19.00, Predicted Range: [-15.28, 10.58], bootstrapped prediction: [-0.6341607], in Range: False
# Input: 2 + 0 + 4 + -3 - -2 + 5 + -4 - -4, Actual: 10.00, Predicted Range: [-5.20, 18.77], bootstrapped prediction: [4.7370644], in Range: True
# Input: -2 - -5 - 1 + 2 - -3 + 1 - 5 - 2, Actual: 1.00, Predicted Range: [-9.19, 9.50], bootstrapped prediction: [-0.15889987], in Range: True
# Input: -1 + 0 + 4 - -5 + 3 + -3 - -4 + -2, Actual: 10.00, Predicted Range: [-9.71, 10.99], bootstrapped prediction: [1.065558], in Range: True
# Input: -5 + -5 - -2 + 2 + 2 - 3 + 3 - 2, Actual: -6.00, Predicted Range: [-8.72, 1.62], bootstrapped prediction: [-3.2649167], in Range: True
# Input: -5 + 3 - 3 - -5 + 0 - -1 + 1 - -2, Actual: 4.00, Predicted Range: [-9.09, 5.09], bootstrapped prediction: [-1.8524399], in Range: True
# Input: 2 + -4 + 0 - 2 + 5 - -2 + -2 - 2, Actual: -1.00, Predicted Range: [-3.90, 10.48], bootstrapped prediction: [1.5148791], in Range: True
# Input: 2 + -3 - -4 + 3 - 3 + 2 + -3 - -1, Actual: 3.00, Predicted Range: [0.61, 12.05], bootstrapped prediction: [5.536186], in Range: True
# Input: 3 - -3 + 2 + 2 + 3 + -1 + 3 + 2, Actual: 17.00, Predicted Range: [-2.63, 11.96], bootstrapped prediction: [5.123651], in Range: False
# Input: -2 + 0 - -3 + -3 - -5 - -5 + -2 + 1, Actual: 7.00, Predicted Range: [-11.72, 3.72], bootstrapped prediction: [-2.2101846], in Range: False
# Input: 0 - -2 + 4 - -1 - 0 + 0 + -2 + -2, Actual: 3.00, Predicted Range: [3.69, 8.82], bootstrapped prediction: [6.007847], in Range: False
# Input: -4 - -4 + 1 - -5 - 3 - 3 + -1 + 0, Actual: -1.00, Predicted Range: [-6.00, 10.92], bootstrapped prediction: [2.4288156], in Range: True
# Input: -4 + -5 + -5 - -1 + -1 + 1 + 5 - -5, Actual: -3.00, Predicted Range: [-16.14, 0.84], bootstrapped prediction: [-9.077739], in Range: True
# Input: 3 + -1 - 1 - 2 - -5 - -2 - 0 + -5, Actual: 1.00, Predicted Range: [-8.05, 9.62], bootstrapped prediction: [1.6425855], in Range: True
# Input: -3 + 0 + -1 + -4 - -5 - 3 + 2 + 4, Actual: 0.00, Predicted Range: [-9.86, 4.86], bootstrapped prediction: [-3.1370122], in Range: True
# Input: -2 - -3 + 5 - 3 - -5 - -2 + -3 - 0, Actual: 7.00, Predicted Range: [-6.82, 10.78], bootstrapped prediction: [1.7199322], in Range: True
# Input: -5 + -2 + -5 - -3 + -2 + 0 - -4 - -1, Actual: -6.00, Predicted Range: [-18.31, -3.05], bootstrapped prediction: [-12.218759], in Range: True
# Input: -5 + 5 + -4 + 3 + -1 - 4 - -3 + -5, Actual: -8.00, Predicted Range: [-13.46, 9.46], bootstrapped prediction: [-3.6697288], in Range: True
# Input: 4 - -2 + 5 - -1 - -2 + -4 - -2 - 3, Actual: 9.00, Predicted Range: [-1.80, 16.01], bootstrapped prediction: [8.350754], in Range: True
# Input: 4 + 1 - -3 + 1 + -5 - -2 - 3 - -3, Actual: 6.00, Predicted Range: [-6.75, 15.90], bootstrapped prediction: [5.294336], in Range: True
# Amount out of bounds: 178, Amount of expressions: 700, Percentage in bounds: 74.57142857142858%

# %%
# Visualize the predictions and the range for a few samples
plt.figure(figsize=(10, 6))
# Calculate the positive error values for the lower and upper bounds
yerr_lower = abs(y_test[:11] - lower_bound[:11, 0])
yerr_upper = abs(upper_bound[:11, 0] - y_test[:11])
plt.errorbar(range(len(y_test[:11])), y_test[:11], yerr=[yerr_lower, yerr_upper], fmt='o', label='Actual with 90% Prediction Range')
plt.xlabel("Test Sample Index")
plt.ylabel("Value")
plt.title("Actual Values and 90% Prediction Range for Test Set (Bootstrap)")
plt.legend()
plt.show()

# %%
def absSum(x):
  expressions = x
  p = []
  for i in range(len(expressions)):
    components = []
    components = expressions[i].split(" ")
    p.append(abs(int(components[0])) + abs(int(components[2])) + abs(int(components[4])))
  return p
print(absSum(expressions_not_in_x))
# Out:
# [10, 7, 5, 7, 6, 10, 11, 5, 6, 6, 6, 14, 6, 8, 11, 5, 11, 6, 7, 7, 7, 11, 6, 1, 8, 9, 9, 12, 6, 5, 5, 10, 8, 7, 9, 8, 8, 4, 10, 7, 8, 8, 6, 11, 7, 7, 7, 3, 8, 7, 8, 7, 7, 6, 9, 6, 7, 9, 5, 11, 5, 6, 2, 6, 3, 4, 10, 8, 10, 5, 8, 8, 7, 6, 5, 8, 7, 6, 8, 8, 8, 11, 4, 9, 8, 10, 3, 7, 7, 7, 4, 3, 6, 9, 5, 4, 2, 11, 5, 8, 9, 12, 5, 10, 5, 10, 5, 11, 7, 8, 8, 10, 7, 5, 9, 8, 7, 12, 10, 7, 8, 6, 5, 3, 4, 9, 5, 5, 10, 9, 9, 6, 3, 10, 12, 8, 9, 11, 7, 9, 6, 8, 7, 10, 4, 8, 4, 3, 9, 5, 7, 6, 4, 10, 11, 5, 11, 5, 9, 8, 10, 10, 10, 5, 7, 5, 7, 11, 3, 7, 9, 11, 12, 6, 7, 6, 5, 9, 12, 7, 10, 12, 9, 7, 12, 11, 9, 8, 4, 9, 7, 7, 9, 10, 7, 10, 5, 7, 4, 8, 11, 7, 9, 11, 9, 4, 7, 4, 7, 13, 10, 8, 6, 4, 9, 10, 9, 4, 10, 4, 9, 4, 7, 5, 10, 8, 10, 8, 8, 4, 5, 9, 9, 3, 5, 7, 7, 4, 5, 6, 6, 9, 3, 13, 4, 9, 3, 11, 10, 10, 7, 7, 7, 10, 1, 6, 4, 5, 7, 11, 9, 9, 9, 7, 8, 8, 5, 3, 13, 3, 5, 5, 9, 9, 5, 10, 8, 6, 14, 12, 9, 7, 7, 2, 8, 4, 7, 8, 6, 7, 11, 7, 7, 5, 4, 11, 9, 5, 5, 7, 12, 12, 9, 8, 11, 6, 6, 11, 9, 3, 9, 12, 9, 8, 3, 8, 3, 4, 10, 6, 8, 6, 9, 4, 8, 6, 6, 7, 3, 8, 5, 6, 8, 5, 5, 5, 12, 10, 11, 10, 9, 6, 7, 7, 9, 9, 7, 10, 6, 8, 12, 5, 7, 7, 6, 8, 10, 5, 11, 8, 10, 7, 5, 7, 7, 9, 7, 8, 12, 8, 7, 9, 5, 13, 13, 2, 2, 10, 4, 5, 6, 8, 10, 7, 10, 10, 9, 7, 5, 9, 6, 8, 8, 6, 7, 8, 12, 5, 11, 11, 3, 5, 10, 7, 10, 14, 9, 7, 10, 6, 5, 11, 6, 5, 9, 10, 9, 8, 8, 10, 6, 7, 7, 7, 5, 7, 5, 9, 7, 8, 9, 8, 10, 8, 7, 6, 7, 11, 6, 6, 8, 6, 7, 11, 4, 7, 6, 8, 6, 8, 7, 8, 3, 10, 4, 2, 6, 7, 12, 8, 4, 9, 2, 7, 7, 10, 5, 7, 4, 9, 8, 6, 5, 5, 7, 11, 10, 6, 11, 7, 6, 12, 6, 13, 6, 8, 5, 11, 9, 9, 2, 8, 10, 8, 6, 6, 8, 5, 10, 10, 9, 13, 7, 7, 2, 4, 9, 8, 10, 10, 11, 10, 8, 6, 8, 12, 8, 3, 8, 9, 8, 9, 9, 5, 9, 9, 11, 10, 11, 7, 4, 7, 11, 9, 5, 1, 6, 10, 9, 12, 8, 8, 4, 9, 10, 7, 7, 6, 5, 7, 6, 10, 8, 11, 8, 8, 12, 8, 11, 12, 6, 3, 8, 10, 9, 8, 4, 12, 4, 5, 11, 2, 5, 4, 4, 8, 11, 10, 8, 6, 6, 6, 7, 7, 5, 7, 4, 11, 7, 6, 5, 8, 6, 12, 6, 8, 12, 14, 13, 10, 12, 9, 7, 5, 8, 6, 6, 8, 10, 12, 7, 12, 8, 7, 4, 6, 10, 7, 10, 11, 2, 8, 7, 9, 12, 11, 3, 5, 6, 9, 11, 9, 10, 9, 4, 5, 4, 8, 6, 7, 8, 7, 6, 7, 6, 9, 3, 7, 10, 7, 9, 8, 4, 4, 7, 4, 8, 7, 12, 5, 6, 3, 4, 5, 7, 6, 13, 10, 8, 7, 8, 11, 9, 8, 10, 4, 7, 2, 7, 3, 5, 8, 11, 5, 7, 2, 2, 7, 2, 9, 8, 9, 9, 9, 9, 4, 10, 5, 8, 7, 11, 5, 4, 12, 10, 8, 13, 5, 13, 8, 9, 2, 11, 4, 10, 9, 12, 7, 5, 7, 10, 13, 10, 8, 9, 3, 1, 7, 4, 10, 12, 9, 3, 8, 6, 8, 7, 13, 7, 9, 6, 11, 5, 10, 9, 11, 8, 6, 6, 7, 4, 11, 9, 5, 10, 8, 5, 7, 4, 5, 8, 3, 8, 6, 13, 2, 8, 13, 8, 7, 8, 4, 9, 3, 7, 11, 8, 4, 3, 7, 6, 6, 8, 10, 8, 7, 8, 10, 1, 4, 4, 10, 4, 8, 6, 8, 13, 8, 9, 7, 5, 6, 10, 6, 6, 5, 10, 5, 3, 7, 8, 3, 10, 10, 7, 5, 5, 8, 9, 7, 12, 4, 6, 8, 7, 7, 5, 8, 4, 8, 9, 10, 7, 6, 11, 7, 9, 7, 9, 10, 8, 6, 4, 13, 9, 5, 3, 11, 12, 9, 8, 6, 4, 8, 6, 5, 8, 8, 9, 11, 9, 10, 6, 9, 8, 7, 6, 3, 12, 12, 13, 8, 3, 3, 6, 10, 7, 7, 4, 7, 13, 9, 8, 8, 5, 8, 5, 6, 5, 12, 8, 6, 1, 8, 4, 5, 4, 7, 9, 8, 5, 9, 9, 7, 6, 6, 11, 6, 5, 5, 9, 7, 5, 6, 6, 7, 3, 11, 9, 15, 8, 11, 7, 6, 11, 5, 5, 6, 7, 8, 10, 6, 8, 10, 10, 8, 5, 3, 9, 10, 6, 9, 6, 10, 8, 10, 10, 5, 2, 9, 8, 7, 5, 8, 5, 8, 6, 8, 11, 7, 10, 9, 7, 9, 12, 8, 9, 7, 9, 10, 6, 10, 2, 3, 9, 14, 4, 6, 6, 4, 5, 6, 5, 3, 11, 8, 7, 5, 6, 3, 8, 6, 7, 7, 10, 7, 10, 9, 4, 10, 8, 7, 10, 10, 6, 3, 6, 12, 11, 9, 7, 5, 12, 7, 10, 8, 7, 6, 7, 8, 5, 9, 10, 12, 8, 7, 11, 7, 5, 10, 9, 10, 12, 9, 3, 7, 7, 11, 5, 4, 5, 7, 7, 10, 6, 6, 12, 6, 7, 4, 7, 9, 10, 3, 11, 3, 6, 8, 6, 10, 8, 9, 2, 7, 10, 11, 8, 10, 8, 6, 3, 7, 5, 4, 1, 6, 8, 7, 11, 9, 9, 7, 4, 9, 7, 7, 6, 10, 9, 11, 6, 7, 9, 8, 7, 7, 4, 5, 6, 6, 4, 10, 9, 10, 5, 6, 6, 7, 8, 11, 11, 6, 8, 6, 9, 7, 7, 8, 7, 11, 9, 4, 9, 11, 7, 6, 10, 9, 9, 9, 10, 10, 4, 12, 2, 7, 11, 4, 6, 14, 10, 4, 8, 11, 11, 3, 11, 7, 10, 11, 12, 5, 7, 5, 13, 6, 8, 5, 5, 4, 11, 6, 8, 5, 6, 5, 10, 7, 4, 5, 8, 6, 5, 12, 7, 11, 4, 12, 11, 9, 8, 11, 9, 9, 7, 6, 9, 11, 10, 6, 11, 11, 8, 6, 8, 4, 1, 8, 11, 6, 9, 8, 5, 6, 10, 8, 9, 4, 6, 9, 9, 5, 4, 6, 5, 6, 5, 9, 8, 5, 6, 3, 9, 10, 9, 6, 9, 4, 4, 8, 10, 3, 4, 9, 4, 8, 6, 4, ...

# %%
deviation = []
out_deviation = []

for i in range(len(y_test)):
  deviation.append(abs(y_test[i]-meanPredictions[i]))
print(deviation)
avDeviation = np.mean(deviation)
print(np.mean(deviation))

for i in range(len(out_y_test)):
  out_deviation.append(abs(out_y_test[i]-out_meanPredictions[i]))
print(out_deviation)
out_avDeviation = np.mean(out_deviation)
print(np.mean(out_deviation))
# Out:
# [array([0.0585947], dtype=float32), array([0.06272244], dtype=float32), array([0.02380085], dtype=float32), array([0.01679456], dtype=float32), array([0.08109999], dtype=float32), array([0.09794998], dtype=float32), array([0.28246593], dtype=float32), array([0.00398207], dtype=float32), array([0.02791119], dtype=float32), array([0.02450895], dtype=float32), array([0.11559534], dtype=float32), array([0.3649006], dtype=float32), array([0.06357813], dtype=float32), array([0.10723019], dtype=float32), array([0.1862005], dtype=float32), array([0.09410381], dtype=float32), array([0.28851032], dtype=float32), array([0.01755023], dtype=float32), array([0.12119818], dtype=float32), array([0.05310321], dtype=float32), array([0.12915552], dtype=float32), array([0.0228256], dtype=float32), array([0.02428484], dtype=float32), array([0.14161456], dtype=float32), array([0.04371262], dtype=float32), array([0.07911301], dtype=float32), array([0.17378426], dtype=float32), array([0.3151443], dtype=float32), array([0.09778772], dtype=float32), array([0.00751686], dtype=float32), array([0.12532997], dtype=float32), array([0.15536761], dtype=float32), array([0.02171063], dtype=float32), array([0.05055785], dtype=float32), array([0.15795422], dtype=float32), array([0.03968143], dtype=float32), array([0.0945406], dtype=float32), array([0.0038209], dtype=float32), array([0.11332798], dtype=float32), array([0.17456818], dtype=float32), array([0.04682636], dtype=float32), array([0.07983556], dtype=float32), array([0.1155591], dtype=float32), array([0.04165649], dtype=float32), array([0.02097654], dtype=float32), array([0.13940907], dtype=float32), array([0.0394336], dtype=float32), array([0.01602721], dtype=float32), array([0.03394974], dtype=float32), array([0.04673207], dtype=float32), array([0.04736185], dtype=float32), array([0.0408017], dtype=float32), array([0.12739015], dtype=float32), array([0.2043519], dtype=float32), array([0.06419581], dtype=float32), array([0.00677681], dtype=float32), array([0.0747242], dtype=float32), array([0.10606146], dtype=float32), array([0.08062291], dtype=float32), array([0.04244822], dtype=float32), array([0.16308916], dtype=float32), array([0.09610033], dtype=float32), array([0.03130718], dtype=float32), array([0.05961195], dtype=float32), array([0.07741594], dtype=float32), array([0.07722998], dtype=float32), array([0.18387699], dtype=float32), array([0.14654946], dtype=float32), array([0.04366231], dtype=float32), array([0.00833225], dtype=float32), array([0.04156435], dtype=float32), array([0.04720783], dtype=float32), array([0.03628159], dtype=float32), array([0.06564617], dtype=float32), array([0.00237346], dtype=float32), array([0.01288143], dtype=float32), array([0.09088516], dtype=float32), array([0.07911159], dtype=float32), array([0.01292157], dtype=float32), array([0.17265129], dtype=float32), array([0.02835214], dtype=float32), array([0.16437674], dtype=float32), array([0.00427112], dtype=float32), array([0.17035484], dtype=float32), array([0.06193137], dtype=float32), array([0.03372192], dtype=float32), array([0.07292318], dtype=float32), array([0.01893139], dtype=float32), array([0.02574134], dtype=float32), array([0.06554556], dtype=float32), array([0.04727411], dtype=float32), array([0.00578928], dtype=float32), array([0.06748152], dtype=float32), array([0.06682968], dtype=float32), array([0.03464723], dtype=float32), array([0.04319348], dtype=float32), array([0.03059584], dtype=float32), array([0.00075841], dtype=float32), array([0.0024786], dtype=float32), array([0.01592162], dtype=float32), array([0.0999912], dtype=float32), array([0.16752529], dtype=float32), array([0.08486056], dtype=float32), array([0.12665677], dtype=float32), array([0.16303897], dtype=float32), array([0.10037756], dtype=float32), array([0.04443598], dtype=float32), array([0.30446434], dtype=float32), array([0.09097433], dtype=float32), array([0.10154669], dtype=float32), array([0.14957666], dtype=float32), array([0.00885944 ...
# 0.07652113
# [array([1.6977873], dtype=float32), array([0.25177908], dtype=float32), array([1.8999405], dtype=float32), array([4.5097446], dtype=float32), array([4.2302885], dtype=float32), array([2.87817], dtype=float32), array([0.49970007], dtype=float32), array([3.133575], dtype=float32), array([0.92145205], dtype=float32), array([4.849224], dtype=float32), array([0.9557686], dtype=float32), array([2.454876], dtype=float32), array([1.1334443], dtype=float32), array([3.7438755], dtype=float32), array([1.4412141], dtype=float32), array([1.0022798], dtype=float32), array([1.9287796], dtype=float32), array([0.61608315], dtype=float32), array([2.8291664], dtype=float32), array([2.2456422], dtype=float32), array([0.47753], dtype=float32), array([0.3746853], dtype=float32), array([4.447899], dtype=float32), array([1.9673967], dtype=float32), array([0.77396536], dtype=float32), array([0.01201725], dtype=float32), array([3.3858185], dtype=float32), array([3.5399342], dtype=float32), array([0.9735055], dtype=float32), array([0.54258347], dtype=float32), array([3.5045967], dtype=float32), array([2.4312038], dtype=float32), array([3.720354], dtype=float32), array([4.3513484], dtype=float32), array([1.2296915], dtype=float32), array([2.2925391], dtype=float32), array([0.54366493], dtype=float32), array([3.9145775], dtype=float32), array([0.40742016], dtype=float32), array([0.22493649], dtype=float32), array([1.1863728], dtype=float32), array([0.3058834], dtype=float32), array([0.02893686], dtype=float32), array([2.5528736], dtype=float32), array([0.3101158], dtype=float32), array([0.23785019], dtype=float32), array([0.26670074], dtype=float32), array([0.66531634], dtype=float32), array([0.1424017], dtype=float32), array([0.6850605], dtype=float32), array([0.61955357], dtype=float32), array([5.0809693], dtype=float32), array([0.04960489], dtype=float32), array([0.46422052], dtype=float32), array([0.22994518], dtype=float32), array([1.7779627], dtype=float32), array([0.6640816], dtype=float32), array([4.2769604], dtype=float32), array([1.3978138], dtype=float32), array([0.5364189], dtype=float32), array([5.218692], dtype=float32), array([0.40701866], dtype=float32), array([2.7002726], dtype=float32), array([3.4321666], dtype=float32), array([0.29355145], dtype=float32), array([0.46537971], dtype=float32), array([6.1679053], dtype=float32), array([1.023982], dtype=float32), array([0.732605], dtype=float32), array([4.347225], dtype=float32), array([5.074241], dtype=float32), array([4.908756], dtype=float32), array([4.848961], dtype=float32), array([0.4422989], dtype=float32), array([0.36179543], dtype=float32), array([1.171958], dtype=float32), array([1.915534], dtype=float32), array([2.4394004], dtype=float32), array([2.7497654], dtype=float32), array([1.2509131], dtype=float32), array([0.21495485], dtype=float32), array([1.0262632], dtype=float32), array([0.09737492], dtype=float32), array([1.5979123], dtype=float32), array([4.201005], dtype=float32), array([0.21628714], dtype=float32), array([1.5845661], dtype=float32), array([3.296381], dtype=float32), array([3.751079], dtype=float32), array([0.3617773], dtype=float32), array([6.8558817], dtype=float32), array([9.308841], dtype=float32), array([3.3085337], dtype=float32), array([2.7883644], dtype=float32), array([0.00379181], dtype=float32), array([0.02242851], dtype=float32), array([1.0812407], dtype=float32), array([6.414154], dtype=float32), array([0.16124964], dtype=float32), array([3.6012025], dtype=float32), array([3.3320312], dtype=float32), array([0.14694405], dtype=float32), array([2.7789564], dtype=float32), array([5.588223], dtype=float32), array([3.9008846], dtype=float32), array([2.7751899], dtype=float32), array([1.2468119], dtype=float32), array([5.105031], dtype=float32), array([2.149724], dtype=float32), array([2.639676], dtype=float32), array([5.065239], dtype=float32), array([0.52740765], dtype=float32), array([1.8181119], dtype=float32), array([0.49800682], dtype=float32), array( ...
# 2.3860135

# %%
coef = np.polyfit(absSum(expressions_not_in_x), deviation, 5)


plt.figure(figsize=(10, 6))
plt.scatter(absSum(expressions_not_in_x), deviation,  label = "data points")
sorted_abs_sum = sorted(absSum(expressions_not_in_x))
plt.plot(sorted_abs_sum, np.polyval(coef, sorted_abs_sum), color='red', label=("trend-line (fitted polynomial)"))

x_values = np.arange(1,16)
y_values = np.full_like(x_values, avDeviation, dtype=np.float32)
plt.plot(x_values, y_values, color='green', linestyle='--', label='hypothesis')


plt.xlabel("Absolute Sum of Components (absSum)")
plt.ylabel("Deviation (abs(Actual - Mean Prediction))")
plt.title("Deviation vs. Absolute Sum of Components for Test Set")
plt.legend()
plt.show()

# %%
most_Expr =outsideExpr + expressions_not_in_x
most_deviation = out_deviation + deviation
most_absSum = absSum(outsideExpr) + absSum(expressions_not_in_x)


out_coef = np.polyfit(most_absSum, most_deviation, 5)

plt.figure(figsize=(10, 6))
plt.scatter(most_absSum, most_deviation,  label = "data points")
out_sorted = sorted(most_absSum)
plt.plot(out_sorted, np.polyval(out_coef, out_sorted), color='red', label=("trend-line (fitted polynomial)"))

x_for_vertical_line = np.full_like(y_values, 15, dtype=np.float32)

plt.plot(x_for_vertical_line, y_values, color='black', linestyle='--', label='training range limit')


plt.xlabel("Absolute Sum of Components (absSum)")
plt.ylabel("Deviation (abs(Actual - Mean Prediction))")
plt.title("Deviation vs. Absolute Sum of Components for Test Set")
plt.legend()
plt.show()

# %%
long_deviation = []
for i in range(len(long_meanPredictions)): long_deviation.append(abs(long_meanPredictions[i] - long_y_test[i]))
print(len(long_deviation))
print(np.mean(long_deviation))

repeated_integers = []
for i in range(minNums, maxNums + 1):
  repeated_integers.extend([i] * amountNums)
print(len(long_deviation))
repeated_integers = np.array(repeated_integers)

long_coef = np.polyfit(repeated_integers, long_deviation, 5)


plt.figure(figsize=(10, 6))
plt.scatter(repeated_integers, long_deviation,  label = "data points")
plt.plot(repeated_integers, np.polyval(long_coef, repeated_integers), color='red', label=("trend-line (fitted polynomial)"))
plt.xlabel("Number of Terms")
plt.ylabel("Deviation (abs(Actual - Mean Prediction))")
plt.title("Deviation vs. Number of Terms for Test Set")
plt.legend()
plt.show()
# Out:
# 700
# 3.4115834
# 700

# %%
long_deviations = np.array(long_deviation)
long_deviations = long_deviations.reshape(maxNums-minNums+1,amountNums)
long_meanDeviations = []
for i in range(len(long_deviations)):
  long_meanDeviations.append(np.mean(long_deviations[i]))
print(long_meanDeviations)
print(out_deviation)
placeholder = absSum(outsideExpr)
print(placeholder)
paired = []
for i in range(len(out_deviation)):
  paired.append([out_deviation[i], placeholder[i]])
print(len(paired))
paired_sorted = sorted(paired, key=lambda item: item[1])
print(paired_sorted)

from collections import defaultdict

# Group deviations by placeholder value
grouped_deviations = defaultdict(list)
for deviation, placeholder_value in paired_sorted:
    grouped_deviations[placeholder_value].append(deviation)

# Calculate the mean deviation for each placeholder value
mean_deviations_by_placeholder = {}
for placeholder_value, deviations in grouped_deviations.items():
    mean_deviations_by_placeholder[placeholder_value] = np.mean(deviations)

print("Mean deviation for each placeholder value:")
for placeholder_value, mean_deviation in mean_deviations_by_placeholder.items():
    print(f"Placeholder value {placeholder_value}: {mean_deviation}")


print((avDeviation)**2)
print((long_meanDeviations[2])**2)
print((mean_deviations_by_placeholder[22])**2)
# Out:
# [np.float32(0.3284998), np.float32(0.19944932), np.float32(3.1180964), np.float32(3.7288764), np.float32(4.564462), np.float32(5.615767), np.float32(6.3259325)]
# [array([1.6977873], dtype=float32), array([0.25177908], dtype=float32), array([1.8999405], dtype=float32), array([4.5097446], dtype=float32), array([4.2302885], dtype=float32), array([2.87817], dtype=float32), array([0.49970007], dtype=float32), array([3.133575], dtype=float32), array([0.92145205], dtype=float32), array([4.849224], dtype=float32), array([0.9557686], dtype=float32), array([2.454876], dtype=float32), array([1.1334443], dtype=float32), array([3.7438755], dtype=float32), array([1.4412141], dtype=float32), array([1.0022798], dtype=float32), array([1.9287796], dtype=float32), array([0.61608315], dtype=float32), array([2.8291664], dtype=float32), array([2.2456422], dtype=float32), array([0.47753], dtype=float32), array([0.3746853], dtype=float32), array([4.447899], dtype=float32), array([1.9673967], dtype=float32), array([0.77396536], dtype=float32), array([0.01201725], dtype=float32), array([3.3858185], dtype=float32), array([3.5399342], dtype=float32), array([0.9735055], dtype=float32), array([0.54258347], dtype=float32), array([3.5045967], dtype=float32), array([2.4312038], dtype=float32), array([3.720354], dtype=float32), array([4.3513484], dtype=float32), array([1.2296915], dtype=float32), array([2.2925391], dtype=float32), array([0.54366493], dtype=float32), array([3.9145775], dtype=float32), array([0.40742016], dtype=float32), array([0.22493649], dtype=float32), array([1.1863728], dtype=float32), array([0.3058834], dtype=float32), array([0.02893686], dtype=float32), array([2.5528736], dtype=float32), array([0.3101158], dtype=float32), array([0.23785019], dtype=float32), array([0.26670074], dtype=float32), array([0.66531634], dtype=float32), array([0.1424017], dtype=float32), array([0.6850605], dtype=float32), array([0.61955357], dtype=float32), array([5.0809693], dtype=float32), array([0.04960489], dtype=float32), array([0.46422052], dtype=float32), array([0.22994518], dtype=float32), array([1.7779627], dtype=float32), array([0.6640816], dtype=float32), array([4.2769604], dtype=float32), array([1.3978138], dtype=float32), array([0.5364189], dtype=float32), array([5.218692], dtype=float32), array([0.40701866], dtype=float32), array([2.7002726], dtype=float32), array([3.4321666], dtype=float32), array([0.29355145], dtype=float32), array([0.46537971], dtype=float32), array([6.1679053], dtype=float32), array([1.023982], dtype=float32), array([0.732605], dtype=float32), array([4.347225], dtype=float32), array([5.074241], dtype=float32), array([4.908756], dtype=float32), array([4.848961], dtype=float32), array([0.4422989], dtype=float32), array([0.36179543], dtype=float32), array([1.171958], dtype=float32), array([1.915534], dtype=float32), array([2.4394004], dtype=float32), array([2.7497654], dtype=float32), array([1.2509131], dtype=float32), array([0.21495485], dtype=float32), array([1.0262632], dtype=float32), array([0.09737492], dtype=float32), array([1.5979123], dtype=float32), array([4.201005], dtype=float32), array([0.21628714], dtype=float32), array([1.5845661], dtype=float32), array([3.296381], dtype=float32), array([3.751079], dtype=float32), array([0.3617773], dtype=float32), array([6.8558817], dtype=float32), array([9.308841], dtype=float32), array([3.3085337], dtype=float32), array([2.7883644], dtype=float32), array([0.00379181], dtype=float32), array([0.02242851], dtype=float32), array([1.0812407], dtype=float32), array([6.414154], dtype=float32), array([0.16124964], dtype=float32), array([3.6012025], dtype=float32), array([3.3320312], dtype=float32), array([0.14694405], dtype=float32), array([2.7789564], dtype=float32), array([5.588223], dtype=float32), array([3.9008846], dtype=float32), array([2.7751899], dtype=float32), array([1.2468119], dtype=float32), array([5.105031], dtype=float32), array([2.149724], dtype=float32), array([2.639676], dtype=float32), array([5.065239], dtype=float32), array([0.52740765], dtype=float32), array([1.8181119], dtype=float32), array([0.49800682], dtype=float32), array( ...
# [17, 17, 17, 21, 20, 21, 20, 21, 19, 22, 19, 21, 19, 17, 21, 16, 18, 17, 21, 18, 17, 21, 22, 21, 18, 22, 19, 18, 18, 20, 22, 18, 22, 21, 20, 17, 22, 21, 18, 20, 15, 21, 18, 18, 18, 19, 20, 20, 17, 23, 21, 20, 17, 17, 18, 20, 19, 19, 16, 19, 20, 23, 19, 20, 20, 20, 21, 17, 20, 21, 21, 20, 22, 18, 20, 18, 18, 18, 17, 17, 19, 18, 19, 22, 19, 20, 18, 18, 23, 17, 20, 24, 16, 20, 20, 18, 20, 23, 18, 21, 19, 16, 22, 20, 18, 19, 20, 20, 19, 16, 20, 24, 18, 20, 18, 19, 18, 16, 21, 19, 18, 17, 18, 19, 22, 17, 18, 20, 19, 16, 15, 18, 23, 15, 19, 22, 20, 20, 21, 21, 19, 19, 16, 16, 20, 20, 17, 18, 18, 17, 19, 20, 17, 17, 23, 15, 21, 18, 19, 20, 22, 20, 20, 15, 18, 18, 19, 21, 21, 19, 21, 22, 16, 23, 23, 19, 20, 21, 18, 17, 20, 19, 15, 19, 22, 22, 22, 16, 21, 23, 21, 21, 19, 16, 20, 15, 19, 16, 19, 19, 19, 21, 15, 21, 18, 19, 18, 17, 23, 18, 18, 18, 19, 19, 18, 21, 20, 18, 19, 21, 21, 16, 17, 18, 20, 17, 15, 17, 21, 17, 23, 21, 20, 20, 21, 21, 18, 19, 21, 15, 18, 23, 20, 17, 19, 18, 20, 19, 21, 15, 20, 20, 18, 17, 19, 20, 15, 16, 20, 23, 16, 19, 18, 17, 19, 21, 18, 19, 18, 23, 17, 18, 20, 21, 20, 23, 20, 21, 23, 21, 22, 19, 20, 20, 18, 20, 21, 19, 18, 21, 18, 19, 20, 18, 18, 19, 20, 19, 22, 21, 21, 23, 23, 17, 22, 18, 20, 22, 20, 17, 23, 21, 21, 21, 17, 19, 19, 18, 18, 20, 18, 22, 17, 21, 17, 23, 21, 19, 17, 23, 21, 18, 18, 18, 22, 21, 23, 24, 21, 20, 19, 22, 23, 21, 21, 18, 19, 19, 19, 20, 21, 20, 17, 19, 19, 22, 21, 19, 18, 18, 16, 20, 21, 18, 18, 21, 21, 23, 20, 17, 18, 19, 22, 19, 19, 18, 21, 21, 18, 20, 21, 22, 19, 17, 19, 23, 22, 21, 18, 23, 18, 20, 20, 18, 18, 21, 21, 19, 19, 19, 18, 20, 20, 22, 22, 20, 21, 18, 20, 18, 19, 17, 18, 17, 21, 16, 20, 18, 17, 22, 19, 22, 20, 21, 18, 19, 19, 20, 17, 18, 19, 20, 19, 19, 19, 21, 22, 20, 22, 18, 21, 17, 21, 24, 17, 20, 20, 21, 20, 17, 21, 16, 22, 18, 17, 23, 23, 19, 18, 23, 20, 17, 21, 18, 19, 23, 20, 21, 19, 18, 20, 21, 23, 21, 19, 21, 18, 22, 19, 20, 20, 20, 16, 22, 18, 19, 20, 22, 20, 21, 23, 18, 18, 22, 18, 21, 17, 23, 22, 19, 23, 23, 20, 17, 20, 18, 21, 20, 21, 19, 18, 18, 20, 18, 20, 17, 17, 15, 20, 17, 21, 22, 19, 18, 17, 22, 21, 20, 22, 16, 20, 18, 18, 21, 23, 22, 17, 18, 19, 21, 19, 20, 24, 21, 20, 18, 21, 22, 21, 17, 18, 16, 19, 18, 20, 19, 20, 24, 18, 17, 21, 18, 18, 19, 20, 22, 20, 20, 21, 21, 21, 17, 22, 18, 20, 18, 21, 18, 19, 21, 21, 21, 19, 21, 20, 19, 19, 20, 20, 19, 19, 18, 16, 22, 22, 19, 22, 22, 19, 19, 17, 20, 21, 18, 20, 23, 18, 23, 21, 20, 19, 18, 16, 20, 20, 18, 20, 18, 21, 20, 17, 22, 20, 18, 18, 18, 18, 18, 19, 19, 20, 16, 21, 21, 18, 24, 20, 17, 18, 19, 18, 20, 20, 22, 21, 18, 21, 18, 20, 21, 19, 21, 19, 19, 18, 18, 22, 19, 21, 20, 21, 17, 16, 18, 19, 17, 17, 17, 19, 18, 19, 20, 18, 21, 20, 19, 21, 16, 19, 20, 20, 17, 19, 18, 20, 20, 20, 19, 18, 20, 20, 18, 18, 18, 22, 24, 19, 22, 20, 21, 19, 21, 22, 20, 20, 20, 21, 19, 18, 21, 20, 22, 18, 20, 18, 18, 19, 20, 20, 16, 16, 17, 20, 22, 20, 18, 19, 22, 20, 21, 15, 19, 20, 20, 20, 17, 19, 18, 18, 22, 19, 19, 21, 19, 22, 23, 20, 21, 18, 21, 22, 23, 17, 17, 19, 21, 19, 19, 19, 19, 19, 20, 19, 21, 22, 20, 20, 21, 20, 17, 20, 19, 21, 22, 16, 23, 15, 23, 19, 19, 20, 18, 16, 18, 18, 19, 19, 19, 19, 18, 18, 19, 20, 22, 16, 21, 17, 18, 21, 21, 19, 15, 19, 23, 20, 19, 18, 20, 18, 21, 21, 19, 23, 21, 20, 18, 17, 22, 24, 19, 19, 19, 18, 19, 20, 19, 17, 18, 21, 19, 19, 21, 22, 21, 20, 22, 19, 20, 17, 17, 17, 21, 23, 18, 22, 22, 23, 21, 22, 18, 20, 20, 19, 17, 24, 18, 19, 19, 22, 22, 21, 18, 21, 17, 20, 21, 23, 17, 18, 16, 20, 17, 19, 20, 19, 21, 21, 18, 22, 17, 24, 18, 20, 20, 21, 16, 24, 17, 21, 23, 18, 17, 21, 20, 20, 20, 22, 17, 17, 19, 19, 17, 18, 18, 19, 21, 21, 18, 22, 22, 19, 19, 24, 16, 18, 24, 17, 22, 21, 16, 22, 18, 17, 20, 22, 23, 17, 23, 17, 20, 20, 20, 16, 18, 20, 18, 20, 18, 23, 17, 16, 21, 19, 20, 22, 21, 19, 17, 21, 18, 21, 18, 22, 19, 20, 19, 22, 18, 21, 21, 18, 20, 19, 19, 17, 19, 20, 17, 16, 21, 22, 21, 20, 17, 21, 20, 24, 21, 20, 21, 21, 19, 21, 16, 19, 19, 20, 17, 21, 20, 17, 16, 18, 21, 21, 19, 21, 18, 17, 17, ...
# 2048
# [[array([1.1863728], dtype=float32), 15], [array([0.4198928], dtype=float32), 15], [array([1.2669735], dtype=float32), 15], [array([0.41851568], dtype=float32), 15], [array([0.60951996], dtype=float32), 15], [array([0.12821436], dtype=float32), 15], [array([0.12652779], dtype=float32), 15], [array([0.19724083], dtype=float32), 15], [array([1.3407815], dtype=float32), 15], [array([0.2128048], dtype=float32), 15], [array([1.4869127], dtype=float32), 15], [array([0.28500843], dtype=float32), 15], [array([0.5911684], dtype=float32), 15], [array([0.42687035], dtype=float32), 15], [array([0.27792025], dtype=float32), 15], [array([1.5586071], dtype=float32), 15], [array([1.3300581], dtype=float32), 15], [array([0.8040161], dtype=float32), 15], [array([0.5617914], dtype=float32), 15], [array([0.3172183], dtype=float32), 15], [array([2.1434207], dtype=float32), 15], [array([0.1791668], dtype=float32), 15], [array([0.41112995], dtype=float32), 15], [array([0.19397688], dtype=float32), 15], [array([0.63570213], dtype=float32), 15], [array([1.620903], dtype=float32), 15], [array([2.1395016], dtype=float32), 15], [array([0.01591063], dtype=float32), 15], [array([0.29706383], dtype=float32), 15], [array([1.0277641], dtype=float32), 15], [array([0.242033], dtype=float32), 15], [array([1.3788161], dtype=float32), 15], [array([1.0022798], dtype=float32), 16], [array([1.3978138], dtype=float32), 16], [array([3.3085337], dtype=float32), 16], [array([0.14694405], dtype=float32), 16], [array([2.639676], dtype=float32), 16], [array([2.1113274], dtype=float32), 16], [array([0.7418194], dtype=float32), 16], [array([3.2824202], dtype=float32), 16], [array([0.18294716], dtype=float32), 16], [array([1.1885777], dtype=float32), 16], [array([0.1893816], dtype=float32), 16], [array([1.3666477], dtype=float32), 16], [array([1.0175514], dtype=float32), 16], [array([0.03381777], dtype=float32), 16], [array([1.7427568], dtype=float32), 16], [array([1.9828167], dtype=float32), 16], [array([0.2676177], dtype=float32), 16], [array([0.1487453], dtype=float32), 16], [array([0.662333], dtype=float32), 16], [array([0.9710612], dtype=float32), 16], [array([0.46369815], dtype=float32), 16], [array([2.1400604], dtype=float32), 16], [array([0.14929104], dtype=float32), 16], [array([1.4469216], dtype=float32), 16], [array([1.023325], dtype=float32), 16], [array([1.6145122], dtype=float32), 16], [array([1.4732752], dtype=float32), 16], [array([2.0956216], dtype=float32), 16], [array([3.4196107], dtype=float32), 16], [array([1.9741449], dtype=float32), 16], [array([1.3807325], dtype=float32), 16], [array([2.0267792], dtype=float32), 16], [array([2.390274], dtype=float32), 16], [array([0.19551134], dtype=float32), 16], [array([0.02016497], dtype=float32), 16], [array([0.6901617], dtype=float32), 16], [array([0.5000906], dtype=float32), 16], [array([2.4143434], dtype=float32), 16], [array([0.65955114], dtype=float32), 16], [array([3.226774], dtype=float32), 16], [array([0.79876137], dtype=float32), 16], [array([0.4110837], dtype=float32), 16], [array([0.01460552], dtype=float32), 16], [array([1.0548778], dtype=float32), 16], [array([1.5904007], dtype=float32), 16], [array([1.4069948], dtype=float32), 16], [array([1.0789309], dtype=float32), 16], [array([0.41127014], dtype=float32), 16], [array([0.01083517], dtype=float32), 16], [array([0.49152946], dtype=float32), 16], [array([1.2619233], dtype=float32), 16], [array([0.5942371], dtype=float32), 16], [array([0.02639151], dtype=float32), 16], [array([1.8820019], dtype=float32), 16], [array([0.2184887], dtype=float32), 16], [array([0.32148218], dtype=float32), 16], [array([0.04105616], dtype=float32), 16], [array([2.1907985], dtype=float32), 16], [array([0.03157282], dtype=float32), 16], [array([0.38140297], dtype=float32), 16], [array([1.2022381], dtype=float32), 16], [array([0.28529453], dtype=float32), 16], [array([2.341876], dtype=float32), 16], [array([2.2231617], dtype=float32), 16], [array([1.0470967], dtype=float32), 16] ...
# Mean deviation for each placeholder value:
# Placeholder value 15: 0.744743824005127
# Placeholder value 16: 1.081985354423523
# Placeholder value 17: 1.4797087907791138
# Placeholder value 18: 1.9015090465545654
# Placeholder value 19: 2.2470896244049072
# Placeholder value 20: 2.5880072116851807
# Placeholder value 21: 2.9269630908966064
# Placeholder value 22: 3.1977672576904297
# Placeholder value 23: 3.49888014793396
# Placeholder value 24: 3.846795082092285
# 0.005855483
# 9.722525
# 10.225716

# %% [markdown]
# About 20 absSum of the numbers in a expression is the same mean deviation as 4 numbers instead of 3.

# %% [markdown]
# benchmark for a model has to scale with:
# *   MSE inside number range
# *   MSE outside number range
# *   MSE for longer expressions
#
# the results of this FNN will be used as baseline.
#
#
# MSE inside number range: 1457 expressions in x_test: 0.007094925
#
# MSE outside number range: Placeholder value 22: 9.788455
#
# Deviation for longer expressions: Deviation for expressions with 4 numbers: 9.551048
#
#
# all 3 Values will be weighed equally as important.

# %%
model_config = model.get_config()
print(model_config)
import pprint
pprint.pprint(model_config)
# Out:
# {'name': 'sequential', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'layers': [{'module': 'keras.layers', 'class_name': 'InputLayer', 'config': {'batch_shape': (None, 15), 'dtype': 'float32', 'sparse': False, 'name': 'input_layer'}, 'registered_name': None}, {'module': 'keras.layers', 'class_name': 'Dense', 'config': {'name': 'dense', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'units': 32, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': None, 'bias_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}, 'registered_name': None, 'build_config': {'input_shape': (None, 15)}}, {'module': 'keras.layers', 'class_name': 'PReLU', 'config': {'name': 'p_re_lu', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'alpha_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'alpha_regularizer': None, 'alpha_constraint': None, 'shared_axes': None}, 'registered_name': None, 'build_config': {'input_shape': (None, 32)}}, {'module': 'keras.layers', 'class_name': 'Dense', 'config': {'name': 'dense_1', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'units': 32, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': None, 'bias_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}, 'registered_name': None, 'build_config': {'input_shape': (None, 32)}}, {'module': 'keras.layers', 'class_name': 'PReLU', 'config': {'name': 'p_re_lu_1', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'alpha_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'alpha_regularizer': None, 'alpha_constraint': None, 'shared_axes': None}, 'registered_name': None, 'build_config': {'input_shape': (None, 32)}}, {'module': 'keras.layers', 'class_name': 'Dense', 'config': {'name': 'dense_2', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'units': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': None, 'bias_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}, 'registered_name': None, 'build_config': {'input_shape': (None, 32)}}], 'build_input_shape': (None, 15)}
# {'build_input_shape': (None, 15),
#  'dtype': {'class_name': 'DTypePolicy',
#            'config': {'name': 'float32'},
#            'module': 'keras',
#            'registered_name': None},
#  'layers': [{'class_name': 'InputLayer',
#              'config': {'batch_shape': (None, 15),
#                         'dtype': 'float32',
#                         'name': 'input_layer',
#                         'sparse': False},
#              'module': 'keras.layers',
#              'registered_name': None},
#             {'build_config': {'input_shape': (None, 15)},
#              'class_name': 'Dense',
#              'config': {'activation': 'linear',
#                         'bias_constraint': None,
#                         'bias_initializer': {'class_name': 'Zeros',
#                                              'config': {},
#                                              'module': 'keras.initializers',
#                                              'registered_name': None},
#                         'bias_regularizer': None,
#                         'dtype': {'class_name': 'DTypePolicy',
#                                   'config': {'name': 'float32'},
#                                   'module': 'keras',
#                                   'registered_name': None},
#                         'kernel_constraint': None,
#                         'kernel_initializer': {'class_name': 'GlorotUniform',
#                                                'config': {'seed': None},
#                                                'module': 'keras.initializers',
#                                                'registered_name': None},
#                         'kernel_regularizer': None,
#                         'name': 'dense',
#                         'trainable': True,
#                         'units': 32,
#                         'use_bias': True},
#              'module': 'keras.layers',
#              'registered_name': None},
#             {'build_config': {'input_shape': (None, 32)},
#              'class_name': 'PReLU',
#              'config': {'alpha_constraint': None,
#                         'alpha_initializer': {'class_name': 'Zeros',
#                                               'config': {},
#                                               'module': 'keras.initializers',
#                                               'registered_name': None},
#                         'alpha_regularizer': None,
#                         'dtype': {'class_name': 'DTypePolicy',
#                                   'config': {'name': 'float32'},
#                                   'module': 'keras',
#                                   'registered_name': None},
#                         'name': 'p_re_lu',
#                         'shared_axes': None,
#                         'trainable': True},
#              'module': 'keras.layers',
#              'registered_name': None},
#             {'build_config': {'input_shape': (None, 32)},
#              'class_name': 'Dense',
#              'config': {'activation': 'linear',
#                         'bias_constraint': None,
#                         'bias_initializer': {'class_name': 'Zeros',
#                                              'config': {},
#                                              'module': 'keras.initializers',
#                                              'registered_name': None},
#                         'bias_regularizer': None,
#                         'dtype': {'class_name': 'DTypePolicy',
#                                   'config': {'name': 'float32'},
#                                   'module': 'keras',
#                                   'registered_name': None},
#                         'kernel_constraint': None,
#                         'kernel_initializer': {'class_name': 'GlorotUniform',
#                                                'config': {'seed': None},
#                                                'module': 'keras.initializers',
#                                                'registered_name': None},
#                         'kernel_regularizer': None,
#                         'name': 'dense_1',
#                         'trainable': True,
#                         'units': 32,
#                         'use_bias': True},
#              'module': 'keras.layers',
#              'registered_name': None},
#             {'build_config': {'input_shape': (None, 32)},
#              'class_name': 'PReLU',
#              'config': {'alpha_constraint': None,
#                         'alpha_initializer': {'class_name': 'Zeros',
#                                               'config': {},
#                                               'module': 'keras.initializers',
#                                               'registered_name': None},
#                         'alpha_regularizer': None,
#                         'dtype': {'class_name': 'DTypePolicy',
#                                   'config': {'name': 'float32'},
#                                   'module': 'keras',
#                                   'registered_name': None},
#                         'name': 'p_re_lu_1',
#                         'shared_axes': None,
#                         'trainable': True},
#              'module': 'keras.layers',
#              'registered_name': None},
#             {'build_config': {'input_shape': (None, 32)},
#              'class_name': 'Dense',
#              'config': {'activation': 'linear',
#                         'bias_constraint': None,
#                         'bias_initializer': {'class_name': 'Zeros',
#                                              'config': {},
#                                              'module': 'keras.initializers',
#                                              'registered_name': None},
#                         'bias_regularizer': None,
#                         'dtype': {'class_name': 'DTypePolicy',
#                                   'config': {'name': 'float32'},
#                                   'module': 'keras',
#                                   'registered_name': None},
#                         'kernel_constraint': None,
#                         'kernel_initializer': {'class_name': 'GlorotUniform',
#                                                'config': {'seed': None},
#                                                'module': 'keras.initializers',
#                                                'registered_name': None},
#                         'kernel_regularizer': None,
#                         'name': 'dense_2',
#                         'trainable': True,
#                         'units': 1,
#                         'use_bias': True},
#              'module': 'keras.layers',
#              'registered_name': None}],
#  'name': 'sequential',
#  'trainable': True}

# %%
base_layers = model_config['layers']
input_layer = base_layers[0]
output_layer = base_layers[-1]
hidden_layer = [base_layers[1], base_layers[2]]
base_layers[1]
# Out:
# {'module': 'keras.layers',
#  'class_name': 'Dense',
#  'config': {'name': 'dense',
#   'trainable': True,
#   'dtype': {'module': 'keras',
#    'class_name': 'DTypePolicy',
#    'config': {'name': 'float32'},
#    'registered_name': None},
#   'units': 32,
#   'activation': 'linear',
#   'use_bias': True,
#   'kernel_initializer': {'module': 'keras.initializers',
#    'class_name': 'GlorotUniform',
#    'config': {'seed': None},
#    'registered_name': None},
#   'bias_initializer': {'module': 'keras.initializers',
#    'class_name': 'Zeros',
#    'config': {},
#    'registered_name': None},
#   'kernel_regularizer': None,
#   'bias_regularizer': None,
#   'kernel_constraint': None,
#   'bias_constraint': None},
#  'registered_name': None,
#  'build_config': {'input_shape': (None, 15)}}

# %%
def build_model(input_shape, num_hidden_layers, units_per_layer):
  lil_model = keras.Sequential()
  lil_model.add(keras.Input(shape=input_shape))
  for i in range(num_hidden_layers):
    lil_model.add(layers.Dense(units_per_layer)),
    lil_model.add(PReLU())
  lil_model.add(layers.Dense(1, activation='linear'))
  lil_model.compile(optimizer="adam", loss="mse", metrics=["mae", "mse"])
  return lil_model

# %%
different_models = []
max_layers = 5
min_Neurons = 30
max_Neurons = 35
small_n_bootstrap = 5
input_shape = (len(x[0]),)

print(input_shape)


diff_predictions = []
diff_out_predictions = []
diff_long_predictions = []

for i in range(max_layers+1):
  for j in range(min_Neurons, max_Neurons+1):
    for p in range(small_n_bootstrap):
      sample_indices = np.random.choice(len(x_train), size=len(x_train), replace=True)
      x_train_bootstrap = x_train[sample_indices]
      y_train_bootstrap = np.array(y_train)[sample_indices]
      bootstrap_train_dataset = tf.data.Dataset.from_tensor_slices((x_train_bootstrap, y_train_bootstrap)).batch(32)

      this_model = build_model(input_shape, i, j)
      different_models.append(this_model)

      this_model.fit(
          bootstrap_train_dataset,
          epochs=50,  # Reduced epochs for quicker example, adjust as needed
          verbose=0, # Suppress output
          callbacks=[early_stopping]
      )
      diff_predictions.append(this_model.predict(x_test))
      diff_out_predictions.append(this_model.predict(out_x_test))
      diff_long_predictions.append(this_model.predict(long_x_test))

diff_predictions = np.array(diff_predictions)
diff_out_predictions = np.array(diff_out_predictions)
diff_long_predictions = np.array(diff_long_predictions)

print(len(different_models))
# Out:
# (15,)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 44/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# ...
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae,mse
#   current = self.get_monitor_value(logs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 180

# %%
diff_predictions.shape[1]
# Out:
# 1457

# %%
diff_meanPredictions = []
num_models = diff_predictions.shape[0] // small_n_bootstrap # 36
num_test_samples = diff_predictions.shape[1] # 1457

for model_index in range(num_models):
  model_predictions = diff_predictions[model_index * small_n_bootstrap : (model_index + 1) * small_n_bootstrap]
  # model_predictions now contains the 5 prediction sets for this specific model
  mean_prediction_for_model = np.mean(model_predictions, axis=0) # Average across the bootstrap axis
  diff_meanPredictions.append(mean_prediction_for_model)

diff_meanPredictions = np.array(diff_meanPredictions)
# diff_meanPredictions should now have shape (36, 1457)
print(diff_meanPredictions.shape)
# Out:
# (36, 1457, 1)

# %%
diff_deviation = []
#diff_out_deviation = []

for j in range(diff_meanPredictions.shape[0]):
  calc = 0
  for i in range(len(y_test)):
    calc += abs(y_test[i]-diff_meanPredictions[j][i])
  diff_deviation.append(calc/len(y_test))
print(diff_deviation)

'''
for i in range(len(out_y_test)):
  out_deviation.append(abs(out_y_test[i]-out_meanPredictions[i]))
print(out_deviation)
out_avDeviation = np.mean(out_deviation)
print(np.mean(out_deviation))
'''
# Out:
# [array([3.3337562], dtype=float32), array([3.3373113], dtype=float32), array([3.336834], dtype=float32), array([3.3375247], dtype=float32), array([3.3385282], dtype=float32), array([3.336669], dtype=float32), array([0.18586221], dtype=float32), array([0.18754378], dtype=float32), array([0.17733352], dtype=float32), array([0.16186748], dtype=float32), array([0.18570152], dtype=float32), array([0.17343652], dtype=float32), array([0.10294155], dtype=float32), array([0.08781471], dtype=float32), array([0.08715039], dtype=float32), array([0.07963727], dtype=float32), array([0.09501092], dtype=float32), array([0.0870847], dtype=float32), array([0.09969168], dtype=float32), array([0.11620165], dtype=float32), array([0.11694801], dtype=float32), array([0.10841364], dtype=float32), array([0.1002632], dtype=float32), array([0.10216425], dtype=float32), array([0.10450004], dtype=float32), array([0.1070168], dtype=float32), array([0.10902843], dtype=float32), array([0.10497747], dtype=float32), array([0.11964657], dtype=float32), array([0.10438574], dtype=float32), array([0.11420796], dtype=float32), array([0.12667611], dtype=float32), array([0.11717089], dtype=float32), array([0.13152912], dtype=float32), array([0.12027], dtype=float32), array([0.1308863], dtype=float32)]
# 0.65738845
# '\nfor i in range(len(out_y_test)):\n  out_deviation.append(abs(out_y_test[i]-out_meanPredictions[i]))\nprint(out_deviation)\nout_avDeviation = np.mean(out_deviation)\nprint(np.mean(out_deviation))\n'

# %%
# prompt: plot diff_deviation on a graph

plt.figure(figsize=(10, 6))
plt.plot(diff_deviation[12:19])
plt.xlabel("Model Index")
plt.ylabel("Mean Absolute Deviation on Test Set")
plt.title("Mean Absolute Deviation for Different Models")
plt.show()

# %%
diff_out_meanPredictions = []
num_models = diff_out_predictions.shape[0] // small_n_bootstrap # 36
num_test_samples = diff_out_predictions.shape[1] # 1457

for model_index in range(num_models):
  model_predictions = diff_out_predictions[model_index * small_n_bootstrap : (model_index + 1) * small_n_bootstrap]
  # model_predictions now contains the 5 prediction sets for this specific model
  mean_prediction_for_model = np.mean(model_predictions, axis=0) # Average across the bootstrap axis
  diff_out_meanPredictions.append(mean_prediction_for_model)

diff_out_meanPredictions = np.array(diff_out_meanPredictions)
# diff_meanPredictions should now have shape (36, 1457)
print(diff_out_meanPredictions.shape)
# Out:
# (36, 2048, 1)

# %%
diff_out_deviation = []
#diff_out_deviation = []

for j in range(diff_out_meanPredictions.shape[0]):
  calc = 0
  for i in range(len(out_y_test)):
    calc += abs(out_y_test[i]-diff_out_meanPredictions[j][i])
  diff_out_deviation.append(calc/len(out_y_test))
print(diff_out_deviation)
# Out:
# [array([7.176814], dtype=float32), array([7.1763806], dtype=float32), array([7.167685], dtype=float32), array([7.1791625], dtype=float32), array([7.179753], dtype=float32), array([7.178997], dtype=float32), array([2.785493], dtype=float32), array([2.767653], dtype=float32), array([2.7821555], dtype=float32), array([2.7419276], dtype=float32), array([2.799599], dtype=float32), array([2.7842789], dtype=float32), array([2.462968], dtype=float32), array([2.3692617], dtype=float32), array([2.364655], dtype=float32), array([2.3988595], dtype=float32), array([2.2969549], dtype=float32), array([2.4903197], dtype=float32), array([2.4673269], dtype=float32), array([2.428435], dtype=float32), array([2.5754824], dtype=float32), array([2.4494917], dtype=float32), array([2.3190036], dtype=float32), array([2.315578], dtype=float32), array([2.5663197], dtype=float32), array([2.358925], dtype=float32), array([2.36727], dtype=float32), array([2.4790602], dtype=float32), array([2.514703], dtype=float32), array([2.4413795], dtype=float32), array([2.3608952], dtype=float32), array([2.3855784], dtype=float32), array([2.4354634], dtype=float32), array([2.4031816], dtype=float32), array([2.4384465], dtype=float32), array([2.443959], dtype=float32)]

# %%
diff_long_meanPredictions = []
num_models = diff_long_predictions.shape[0] // small_n_bootstrap # 36
num_test_samples = diff_long_predictions.shape[1] # 1457

for model_index in range(num_models):
  model_predictions = diff_long_predictions[model_index * small_n_bootstrap : (model_index + 1) * small_n_bootstrap]
  # model_predictions now contains the 5 prediction sets for this specific model
  mean_prediction_for_model = np.mean(model_predictions, axis=0) # Average across the bootstrap axis
  diff_long_meanPredictions.append(mean_prediction_for_model)

diff_long_meanPredictions = np.array(diff_long_meanPredictions)
# diff_meanPredictions should now have shape (36, 1457)
print(diff_long_meanPredictions.shape)
# Out:
# (36, 700, 1)
