# %% [markdown]
# <a href="https://colab.research.google.com/github/AntonStantan/matura/blob/main/FNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
np.random.seed(42)

x1 = np.random.rand(4000)*10
x2 = np.random.rand(4000)*10
x3 = np.random.rand(4000)*10

x1_int = x1.astype(int) - 5
x2_int = x2.astype(int) - 5
x3_int = x3.astype(int) - 5

x1_str = x1_int.astype(str)
x2_str = x2_int.astype(str)
x3_str = x3_int.astype(str)

unique_expressions = set()

for i in range(len(x1)):
  n = np.random.rand(1)
  if n < 0.25:
    opp1 = " + "
    opp2 = " + "
  elif n > 0.25 and n < 0.5:
    opp1 = " + "
    opp2 = " - "
  elif n > 0.75:
    opp1 = " - "
    opp2 = " + "
  else:
    opp1 = " - "
    opp2 = " - "
  unique_expressions.add(x1_str[i] + opp1 + x2_str[i] + opp2 + x3_str[i])

x = list(unique_expressions) # Convert the set back to a list
print(x)
print(len(x))
# Out:
# ['0 - 1 - -2', '0 + -3 + -2', '2 + 3 - 0', '1 + 2 - -1', '-5 - 0 - 4', '-4 - 2 + -1', '-1 - -3 - 2', '4 - 0 + 3', '-3 - -5 + 0', '0 + -5 - 3', '3 - -3 - 3', '-4 + -1 + -5', '-3 - -1 + -3', '-4 - 1 - 2', '-3 + -5 - 2', '3 - 2 + -3', '-4 + -5 - -1', '-2 + 4 - 4', '-2 - 1 + -2', '-3 - 3 - 1', '0 - -1 + -1', '0 + -2 + 4', '-4 + -3 + 2', '-3 - -1 + 2', '3 - 4 - -1', '-4 - 3 - -5', '1 + -5 - 0', '-1 + 4 - -1', '2 - 4 + 1', '-3 + 2 + -4', '-3 + 1 - -2', '-2 - -4 + -1', '1 - -5 - 3', '-5 - -1 - -3', '1 + -1 + -1', '4 - 4 - 1', '-3 + 0 + 4', '1 + 0 - 4', '-1 + 4 + 3', '-5 + -5 - -2', '3 - 0 + -5', '0 + -5 - -1', '-5 + 1 - 3', '4 - 4 - 2', '0 + 4 - -3', '-1 - -4 + -1', '3 - -5 + -4', '-2 - -2 - -5', '-5 - 0 - 3', '2 + 3 + -2', '-1 + 0 - -4', '-3 - -4 + 2', '4 + 4 + -3', '-1 + -4 + 4', '3 + -5 - 2', '-1 + -5 - -5', '2 + 0 + -2', '1 - -1 + 0', '-2 + -5 - 1', '0 - -5 + -1', '1 + -2 + -3', '2 + 4 - -3', '-5 - 4 - 3', '4 - -2 - 3', '0 - -2 + 0', '-3 + -3 + -3', '4 - -2 + -1', '3 - -1 - -2', '-5 - 0 + 4', '3 + 0 + 4', '-3 + -1 + 4', '3 + 2 + -1', '-5 - 1 - -4', '-5 + -3 + -2', '-3 - 0 + -1', '-5 + -3 + -1', '-1 + -1 + -4', '0 - -4 + 2', '1 - 1 - -4', '3 + 3 - 1', '-2 - 3 + -4', '-5 - -5 + -3', '-2 - -2 + 0', '1 - 3 + -2', '-3 + 0 - 0', '4 + 4 - -1', '-3 + 0 - -3', '-4 - -2 + 2', '-5 - 1 - -3', '-1 - -5 + -4', '2 + -2 - 4', '2 - -5 + 0', '-5 + 0 + -3', '-2 - 3 + -2', '-5 - 2 - -4', '-5 + 1 - 1', '0 - 4 - 1', '-4 + -1 - 2', '-5 + 3 + -1', '4 + 3 - 4', '-3 + -3 + 0', '-2 + 2 + -5', '4 - 0 - -5', '1 + 3 + -3', '-4 - -5 - 3', '-3 + -2 + -2', '-3 - -3 - 0', '0 + 0 - 1', '1 - -2 + -2', '0 + -1 + -5', '-2 + 4 + -5', '4 - -3 - -4', '3 - -2 - -3', '-4 + -1 - 1', '0 - -2 - -5', '-2 - 2 - -2', '2 - -5 + -4', '-1 + 3 + 4', '-2 + 0 + 1', '-5 - 4 - -2', '2 + -4 - 2', '2 - 0 + 3', '1 - -3 - 1', '-1 + -5 + -5', '3 - 0 + 0', '0 - -5 - -5', '-3 + -2 + -5', '-2 + -3 - -1', '1 - 1 - 1', '2 - 2 - 4', '1 - 1 + 3', '3 - 2 - -4', '-5 - 3 + 3', '-4 + -1 - -4', '-1 + 2 + -4', '0 - -1 - -2', '-2 - -1 + 3', '4 - -1 + 4', '1 - -4 - -4', '-1 + -3 - -5', '-4 + 3 + 1', '-2 + -2 + 2', '3 + -1 - -3', '3 + -1 - -5', '1 + 3 - 2', '2 - 3 + 4', '-4 - 4 - -3', '1 - -2 + -5', '-2 + 3 - -5', '2 + -1 + 1', '-5 - 3 + -1', '3 + 1 + -3', '-5 - -3 + 1', '-4 - -2 + -4', '2 - 2 - -3', '4 + 4 + -4', '-5 + -1 - -4', '0 + 4 + 2', '3 + 2 + 1', '-2 + -3 + -5', '-2 + 0 - -1', '-2 - -4 - 2', '3 - -3 + 1', '-5 + -4 - 4', '1 + -2 - 2', '-4 - 0 - -2', '-3 - 1 - -5', '4 + -1 - 2', '1 - 3 - -2', '-4 - -3 + -1', '2 - -1 - -3', '3 - 3 - -4', '3 - 3 - -1', '-1 - 1 + 2', '-2 + 1 + 1', '3 + -5 - -4', '4 - 2 + 2', '4 - 2 - 4', '2 + -4 - 0', '-3 - 3 - 0', '-4 - -2 - 2', '4 - 2 - 1', '0 - -4 + -5', '0 - 3 + 1', '0 - -3 - 2', '-5 + 3 - 3', '3 - -3 - 2', '-2 + 0 + 3', '3 - 4 + -5', '-3 - 1 - -1', '-2 - -2 - 0', '4 - -1 + -3', '-1 - 4 - 0', '-1 - 1 + -5', '-2 - 2 + -2', '1 + -3 - 4', '2 + 4 + 3', '-3 + -3 - -5', '4 + -3 - 1', '-4 - 2 - -5', '-4 - -3 + 2', '-4 + -5 - -2', '1 + -3 + 1', '4 + 4 - -2', '-2 - 4 - -1', '-3 + -4 - 0', '-5 + 0 + -5', '1 + -2 - -4', '-5 - 2 + 0', '-1 - -2 - 2', '2 - -5 - 4', '-3 - 1 + -3', '1 - -5 - 4', '-2 + 3 - -1', '-1 - -1 - 3', '2 - -4 - 2', '-4 - 0 + -2', '-2 - -3 - 3', '-4 - -5 + -4', '0 - 0 - -5', '3 + -2 + -2', '-5 + 4 - -4', '2 - -2 - -3', '-4 - 4 + 1', '4 - -2 - 4', '1 - 4 + 2', '-1 + -3 - -3', '4 - 0 + -2', '-2 + 2 + -2', '0 + 2 + 0', '3 + -4 - 2', '-2 - -4 - -4', '2 - 3 + -4', '-1 - 3 - -3', '4 + -4 + 2', '1 - -1 - -5', '0 - 1 - 0', '1 + -5 - -5', '-4 + 0 - -3', '-4 + -3 - -3', '-3 + -5 - 4', '-4 - -5 - 2', '0 - 2 + 3', '-5 - -3 - -4', '-1 - 2 - -1', '3 - -3 + -3', '-3 + 1 - -5', '-2 + -4 + -4', '2 - 4 + 4', '3 - 3 + 1', '-1 + -3 - -4', '3 + 1 - -2', '-3 - 2 + 4', '-2 + -4 + -2', '2 - -1 + -3', '-1 + 2 - 0', '1 + -5 - -1', '-5 - -5 + -1', '-3 - -4 + 0', '2 + 0 - -3', '-4 + 3 + -3', '4 + -3 + 3', '-5 + 4 + -2', '-2 + -3 + 1', '1 - 0 - 0', '3 - 3 + -5', '-1 + -4 + 2', '3 - -2 - 1', '4 + -5 - -4', '-1 + -3 + -3', '-5 - 4 + 3', '1 - 1 - -3', '-2 + -4 - -5', '-2 + 2 + 4', '3 - 4 - ...
# 2543

# %%
y = []

for expression in x:
  result = float(eval(expression))
  y.append(result)

print(y)
# Out:
# [1.0, -5.0, 5.0, 4.0, -9.0, -7.0, 0.0, 7.0, 2.0, -8.0, 3.0, -10.0, -5.0, -7.0, -10.0, -2.0, -8.0, -2.0, -5.0, -7.0, 0.0, 2.0, -5.0, 0.0, 0.0, -2.0, -4.0, 4.0, -1.0, -5.0, 0.0, 1.0, 3.0, -1.0, -1.0, -1.0, 1.0, -3.0, 6.0, -8.0, -2.0, -4.0, -7.0, -2.0, 7.0, 2.0, 4.0, 5.0, -8.0, 3.0, 3.0, 3.0, 5.0, -1.0, -4.0, -1.0, 0.0, 2.0, -8.0, 4.0, -4.0, 9.0, -12.0, 3.0, 2.0, -9.0, 5.0, 6.0, -1.0, 7.0, 0.0, 4.0, -2.0, -10.0, -4.0, -9.0, -6.0, 6.0, 4.0, 5.0, -9.0, -3.0, 0.0, -4.0, -3.0, 9.0, 0.0, 0.0, -3.0, 0.0, -4.0, 7.0, -8.0, -7.0, -3.0, -5.0, -5.0, -7.0, -3.0, 3.0, -6.0, -5.0, 9.0, 1.0, -2.0, -7.0, 0.0, -1.0, 1.0, -6.0, -3.0, 11.0, 8.0, -6.0, 7.0, -2.0, 3.0, 6.0, -1.0, -7.0, -4.0, 5.0, 3.0, -11.0, 3.0, 10.0, -10.0, -4.0, -1.0, -4.0, 3.0, 5.0, -5.0, -1.0, -3.0, 3.0, 2.0, 9.0, 9.0, 1.0, 0.0, -2.0, 5.0, 7.0, 2.0, 3.0, -5.0, -2.0, 6.0, 2.0, -9.0, 1.0, -1.0, -6.0, 3.0, 4.0, -2.0, 6.0, 6.0, -10.0, -1.0, 0.0, 7.0, -13.0, -3.0, -2.0, 1.0, 1.0, 0.0, -2.0, 6.0, 4.0, 1.0, 0.0, 0.0, 2.0, 4.0, -2.0, -2.0, -6.0, -4.0, 1.0, -1.0, -2.0, 1.0, -5.0, 4.0, 1.0, -6.0, -3.0, 0.0, 2.0, -5.0, -7.0, -6.0, -6.0, 9.0, -1.0, 0.0, -1.0, 1.0, -7.0, -1.0, 10.0, -5.0, -7.0, -10.0, 3.0, -7.0, -1.0, 3.0, -7.0, 2.0, 2.0, -3.0, 4.0, -6.0, -2.0, -3.0, 5.0, -1.0, 3.0, 7.0, -7.0, 2.0, -1.0, -1.0, 2.0, -2.0, 2.0, -3.0, 6.0, -5.0, -1.0, 2.0, 7.0, -1.0, 1.0, -1.0, -4.0, -12.0, -1.0, 1.0, 2.0, -2.0, 3.0, 3.0, -10.0, 2.0, 1.0, 0.0, 6.0, -1.0, -8.0, 0.0, 1.0, -3.0, -1.0, 1.0, 5.0, -4.0, 4.0, -3.0, -4.0, 1.0, -5.0, -3.0, 4.0, 3.0, -7.0, -6.0, 3.0, -1.0, 4.0, -3.0, 3.0, 2.0, -5.0, -8.0, -6.0, -7.0, -6.0, -5.0, 5.0, 6.0, -3.0, 0.0, 4.0, -5.0, 7.0, -6.0, -4.0, 10.0, 0.0, -8.0, -7.0, 1.0, 2.0, -2.0, -6.0, -2.0, -3.0, -4.0, -4.0, 5.0, -4.0, -3.0, -2.0, 0.0, 9.0, -6.0, -6.0, 0.0, -6.0, -5.0, 3.0, -4.0, 3.0, -2.0, 2.0, 3.0, 0.0, -4.0, -6.0, 3.0, -4.0, -3.0, 3.0, 3.0, -4.0, -2.0, 0.0, -1.0, -7.0, 3.0, -6.0, -4.0, 4.0, 2.0, 3.0, 4.0, -1.0, -5.0, 8.0, 5.0, -2.0, -7.0, 7.0, -1.0, 4.0, 1.0, 5.0, -6.0, -2.0, 4.0, -5.0, -3.0, 3.0, -1.0, 3.0, -9.0, 2.0, -4.0, 2.0, 7.0, 1.0, 11.0, -2.0, 6.0, -5.0, -3.0, 3.0, -1.0, -5.0, -8.0, 3.0, 1.0, -3.0, -4.0, 6.0, -1.0, -8.0, 3.0, 1.0, 1.0, 0.0, 4.0, 2.0, -7.0, 7.0, 1.0, -3.0, -8.0, 3.0, 5.0, 0.0, 5.0, 0.0, -9.0, 3.0, 9.0, -11.0, 9.0, -6.0, -6.0, -7.0, -3.0, -2.0, 0.0, 8.0, 0.0, -8.0, -5.0, -2.0, 10.0, -8.0, -1.0, 0.0, -2.0, 7.0, 1.0, -6.0, 6.0, 4.0, -1.0, -8.0, 0.0, 2.0, -4.0, -3.0, 0.0, -5.0, 3.0, -4.0, -2.0, -6.0, -1.0, 5.0, 2.0, -6.0, 3.0, -3.0, -3.0, 2.0, 5.0, 5.0, 1.0, -3.0, 1.0, -1.0, 7.0, 2.0, 0.0, -6.0, 3.0, 7.0, 1.0, -7.0, -9.0, 10.0, -4.0, -6.0, 3.0, 0.0, -13.0, 0.0, -4.0, -1.0, 11.0, 4.0, 0.0, 2.0, 0.0, 3.0, -2.0, -7.0, -10.0, -5.0, -3.0, 4.0, -11.0, 7.0, 1.0, 2.0, -1.0, -3.0, -6.0, -5.0, 4.0, -7.0, -3.0, 3.0, -6.0, 2.0, 0.0, -10.0, 4.0, 1.0, 4.0, 5.0, -6.0, 2.0, 0.0, -1.0, -3.0, 2.0, -1.0, 7.0, -1.0, 1.0, 0.0, -4.0, 8.0, -1.0, 6.0, -1.0, 4.0, -2.0, 9.0, -2.0, 0.0, 6.0, 0.0, -1.0, 8.0, 3.0, 2.0, -2.0, 4.0, -2.0, -6.0, -4.0, -6.0, 2.0, -2.0, 0.0, -3.0, -9.0, 5.0, -1.0, 5.0, 4.0, -6.0, -2.0, 12.0, -2.0, -1.0, 4.0, -4.0, 8.0, 5.0, -7.0, -6.0, -3.0, 0.0, 6.0, -3.0, 2.0, 6.0, -1.0, -3.0, 3.0, 3.0, 0.0, -7.0, 5.0, 9.0, -3.0, 6.0, 3.0, -3.0, 5.0, 9.0, 7.0, 2.0, -6.0, 4.0, 5.0, 0.0, -6.0, -6.0, 1.0, 0.0, 6.0, 0.0, 2.0, 1.0, -6.0, -1.0, -6.0, -6.0, 7.0, -10.0, 0.0, 10.0, 8.0, -4.0, -1.0, 2.0, -8.0, -3.0, 0.0, -8.0, -8.0, 2.0, -1.0, -8.0, -3.0, -4.0, -4.0, -6.0, -7.0, 1.0, -3.0, -6.0, 0.0, -5.0, -2.0, -4.0, 5.0, 7.0, 6.0, -2.0, 6.0, -1.0, 5.0, -8.0, 4.0, -4.0, 10.0, 9.0, 5.0, -4.0, 0.0, -5.0, -3.0, 9.0, -2.0, -3.0, -1.0, 5.0, 2.0, -8.0, 1.0, 2.0, -4.0, 5.0, 6.0, -1.0, -1.0, -3.0, -12.0, -6.0, -3.0, -9.0, -3.0, 0.0, -7.0, 0.0, -3.0, 0.0, 0.0, -7.0, 11.0, -1.0, 3.0, -7.0, 10.0, 0.0, 1.0, -3.0, 4.0, 0.0, -1.0, 10.0, -9.0, 0.0, 10.0, 0.0, -10.0, 4.0, -8.0, 9.0, -7.0, -7.0, 0.0, 9.0, 2.0, -3.0, -1.0, 3.0, -4.0, -1.0, -7.0, -6.0, -8.0, 0.0, 1.0, 5.0, -15.0, -8.0, -2.0, 4.0, -8.0, 0.0, -4.0, -6.0, -2.0, -4.0, -1.0, 4.0, -2.0, 2.0, 1.0, 2.0, -3.0, 1.0, -5.0, -1.0, 4.0 ...

# %%
'''
def tokenizer(x):
  #tokenizer by hand
  tokens = (len(x), 5)

  for i in range(len(x)):
    x[i] = x[i].split(" ")
    x[i][0] = int(x[i][0])
    x[i][2] = int(x[i][2])
    x[i][4] = int(x[i][4])
    if x[i][1] == "+":
      x[i][1] = 1.0
    else:
      x[i][1] = 0.0
    if x[i][3] == "+":
      x[i][3] = 1.0
    else:
      x[i][3] = 0.0
  print(x[0])
  x = np.array(x, dtype = np.float32)
  print(x[0])
  return x
x = tokenizer(x)
'''
# Out:
# '  \ndef tokenizer(x):  \n  #tokenizer by hand\n  tokens = (len(x), 5)\n\n  for i in range(len(x)):\n    x[i] = x[i].split(" ")\n    x[i][0] = int(x[i][0])\n    x[i][2] = int(x[i][2])\n    x[i][4] = int(x[i][4])\n    if x[i][1] == "+":\n      x[i][1] = 1.0\n    else:\n      x[i][1] = 0.0\n    if x[i][3] == "+":\n      x[i][3] = 1.0\n    else:\n      x[i][3] = 0.0\n  print(x[0])\n  x = np.array(x, dtype = np.float32)\n  print(x[0])\n  return x\nx = tokenizer(x)\n'

# %%
def tokenizer(input_list): # Changed parameter name to avoid confusion with global x
  #tokenizer by hand
  tokens = (len(input_list), 5)
  # Create a copy of the input list to avoid modifying the original
  tokenized_x = [expression.split(" ") for expression in input_list]


  for i in range(len(tokenized_x)):
    tokenized_x[i][0] = int(tokenized_x[i][0])
    tokenized_x[i][2] = int(tokenized_x[i][2])
    tokenized_x[i][4] = int(tokenized_x[i][4])
    if tokenized_x[i][1] == "+":
      tokenized_x[i][1] = 1.0
    else:
      tokenized_x[i][1] = 0.0
    if tokenized_x[i][3] == "+":
      tokenized_x[i][3] = 1.0
    else:
      tokenized_x[i][3] = 0.0
  print(tokenized_x[0])
  tokenized_x = np.array(tokenized_x, dtype = np.float32)
  print(tokenized_x[0])
  return tokenized_x
x = tokenizer(x)
# Out:
# [0, 0.0, 1, 0.0, -2]
# [ 0.  0.  1.  0. -2.]

# %%
# Generate all possible expressions
all_possible_expressions = set()
for num1 in range(-5, 5): # Range -5 to 4
    for num2 in range(-5, 5): # Range -5 to 4
        for num3 in range(-5, 5): # Range -5 to 4
            for op1 in [" + ", " - "]:
                for op2 in [" + ", " - "]:
                    expression = str(num1) + op1 + str(num2) + op2 + str(num3)
                    all_possible_expressions.add(expression)

# Find expressions not in x
expressions_not_in_x = all_possible_expressions - unique_expressions
expressions_not_in_x = list(expressions_not_in_x)
print("\nExpressions not in x:")
print(list(expressions_not_in_x)) # Convert back to a list for printing
if len(expressions_not_in_x)+len(x) == 4000: print(True)
print(len(expressions_not_in_x))
# Out:
# Expressions not in x:
# ['3 + -2 + 3', '-3 - 4 + -5', '3 - -4 - -5', '-2 + -4 - 1', '1 - -1 - -1', '-4 + 4 + -4', '-3 - 3 - -3', '4 - 0 - 3', '-2 - 4 - -4', '1 + -4 - -1', '-3 + 1 - -4', '-1 - 4 + -1', '1 + -3 - 3', '2 - 3 + -2', '-5 + -5 + 0', '3 + 4 - -3', '2 - -2 + 1', '2 - 0 + 0', '2 - -3 - -5', '0 + -1 - 4', '1 - -1 + 1', '-1 - 1 + -2', '-4 - -1 - 2', '-2 + 1 - 2', '1 + -5 + -5', '-3 + 3 - 4', '-2 + -1 - 1', '4 - 1 + -5', '3 - 3 + -4', '2 + 4 - 4', '1 - 0 - -4', '2 + 0 + 4', '-5 - -4 - 1', '3 + 2 - 1', '-2 + -2 + 1', '-1 + 3 - 2', '1 + 0 + -2', '3 - 2 + 3', '4 - 1 + 4', '4 - 3 + -3', '4 - 2 + 3', '3 - -5 + 3', '1 - -1 + 4', '-3 + 0 + 1', '-1 + 1 - 4', '1 + 1 + 3', '4 + -3 + -2', '-4 + 4 - 2', '2 + -2 + -5', '1 + 4 + 3', '-4 - 4 + -5', '3 + 2 + -3', '4 - -2 + -2', '-1 - 3 + 0', '-4 + -5 + 0', '-5 - 1 + -5', '-5 - -1 - 3', '-1 - -3 - -2', '-1 + 4 + 4', '-1 + 4 + -1', '3 + 1 - 3', '-5 - -5 - -2', '-5 + -4 + 4', '2 + -2 - 3', '-2 + -4 + 4', '-1 + -2 + 4', '4 - 4 - 4', '0 - -3 - -1', '-3 + 2 + 0', '4 - 2 + -3', '0 - 0 - -4', '2 + 1 + 4', '-1 - -3 + -3', '-3 - 4 + -1', '-3 + 4 - 3', '-2 - -5 - -5', '-2 + 2 - 1', '4 + 0 - 0', '1 - 2 - -2', '-1 - 3 - 0', '-2 - 4 + -4', '2 + -2 + 3', '-5 - -5 - -3', '3 + 3 + 2', '2 + -1 + 2', '1 - -3 + -3', '-2 + -2 - 1', '1 - 4 - 1', '-2 + -5 + -4', '-2 + -1 - -1', '3 + -4 - 3', '2 - 1 - 2', '3 + 0 + 2', '-2 + -1 - -4', '0 + -3 + -1', '-5 - 4 + 2', '-1 - -2 - 3', '3 + -3 - -2', '0 - 4 - 2', '0 - 1 - 4', '-4 + -5 + -5', '0 - 4 + -3', '0 + 0 + 1', '3 + 0 - -5', '4 + 4 - -5', '0 + 2 + 4', '1 - 3 - -4', '2 - -5 - 0', '2 - -1 - 1', '-1 + -1 - 2', '4 + -2 + -2', '2 + -5 + 0', '-2 - 0 - -5', '2 + -2 + 0', '-2 - -4 - 1', '-1 - -4 - -2', '-3 - -2 + 1', '1 - -5 + -1', '0 + -4 + 0', '4 - -4 + -2', '-5 - -5 + 1', '-4 - 2 - -1', '2 + -5 - -5', '-4 - 0 - 3', '3 + -1 + -2', '-5 + -3 - 2', '4 + 2 + 0', '2 + 2 - 0', '-4 - 1 - -4', '2 - -3 - 4', '-4 + -1 + 0', '-1 + 0 - 0', '2 - -5 + 4', '0 - -4 + 0', '0 + 3 + 2', '1 + 2 + 2', '4 - -5 - 1', '-3 - 0 - -3', '2 + 1 - 4', '0 + -1 - -1', '-4 - -4 - -2', '1 + 1 - -3', '-5 - -3 + -2', '-3 + -4 + -4', '0 - -5 - 1', '4 - 4 - -5', '-4 - -5 - -4', '4 - -4 - 2', '-1 + -2 + 1', '-1 - 3 - 3', '1 + 3 + 4', '3 + 4 - -5', '1 - 2 - 2', '3 - 2 + 4', '-4 + -2 - 0', '3 + -2 + 1', '4 - -2 - -3', '-4 - 2 - 4', '-1 - -4 + 3', '4 + 0 - -1', '-5 + 2 - -5', '3 + 2 + 3', '-4 - 2 - -2', '0 - 1 - 2', '2 + 2 + -3', '-4 - -3 + 3', '4 - -4 + -1', '-2 - 0 + 2', '-4 - 4 + 0', '2 - -3 + -1', '2 + -3 - -3', '4 + -1 + 2', '2 - 0 + 4', '0 - -3 + -5', '-4 - 3 - 2', '-1 + 3 + -5', '-1 + 3 + 2', '4 + -3 - -2', '-4 + 2 - 4', '-1 - 2 + -5', '-3 - 2 - 3', '-5 + -4 - 1', '-2 + -2 + -5', '-5 + -1 - -1', '-2 + 4 - -5', '4 - 1 - -4', '-5 - -5 - 1', '-5 - 2 - -5', '3 - 3 + 3', '-1 - -4 + -4', '-4 + -2 + -2', '-1 - -4 + 2', '-2 - 2 - 3', '0 - -5 - -4', '3 - 0 + 2', '0 - -5 + 3', '-3 - -2 + 0', '4 - 2 + -4', '4 + -1 + 3', '-5 + -2 - -5', '-5 + 1 - -5', '1 - -1 + 2', '-2 - -2 + 2', '1 + -4 + -1', '-5 - 4 - -4', '4 + 4 + 3', '-1 - -1 + -4', '-4 - 0 - 1', '3 - -3 + -1', '-4 + -2 - 3', '-4 - -4 - 2', '-1 - 2 + -1', '0 - 2 - 4', '1 - -4 + 2', '2 + 1 + -4', '-4 + 0 - 0', '3 + -1 - -1', '-3 - 4 + -3', '-2 + -1 + 0', '2 + 0 + -4', '3 + 2 - 0', '4 + -4 - 3', '0 + -3 - -1', '3 + 3 + -5', '-3 + -3 + 2', '-1 + 1 - 0', '-1 - 0 + 0', '-3 - -1 - -2', '-3 - 2 + -3', '2 - -5 - 3', '1 - 0 + 2', '-5 + -3 + -4', '-2 + -4 + -5', '1 - -1 + -2', '-1 + -2 + 2', '2 + -5 - 1', '-5 + -4 + 2', '-4 - -3 - 0', '-5 - -4 - -4', '2 - -5 - -3', '1 - 4 - 0', '3 + 3 - 2', '1 - -4 + 1', '-2 + 4 + 0', '-2 - -5 + 0', '2 + 2 - -1', '-5 - 4 + -3', '0 - -5 + -3', '4 + 4 + -5', '-1 - 3 - -5', '4 + -4 + 1', '-5 + 1 + 2', '1 + -5 - -2', '-5 - -2 - -3', '2 - -1 - 3', '-3 - 1 - -3', '1 - 0 + 0', '-2 + 1 - -3', '-2 - -3 + -3', '-4 - -5 - -2', '4 + -3 + -5', '-1 - -3 - 4', '4 + -5 - -2', '-2 + -5 - -4', '3 + 4 - 4', '-4 + 2 + 2', '-4 - -1 + -1', '3 - 1 + -1', '-1 + 3 - -3', '4 - -1 + 2', '-2 - 3 - -1', '-5 + 4 + -5', '-2 - -1 - 1', '1 - 3 + -3', '2 + -2 + -3', '-1 - -5 + 4', '-5 + 0 + 1 ...
# True
# 1457

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.layers import PReLU




x_train, x_val, y_train, y_val = \
    train_test_split(x, y, train_size=0.75)

model = keras.Sequential([
    keras.Input(shape=(len(x[0]),)),
    layers.Dense(32),
    PReLU(),
    layers.Dense(32),
    PReLU(),
    layers.Dense(1,  activation = "linear")
])

model.compile(optimizer = "adam", loss = "mse", metrics = ["mae", "mse"])

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
# Convert numpy arrays to TensorFlow Datasets
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train)).batch(32) # Use a batch size, e.g., 32
val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val)).batch(32) # Use the same batch size


history = model.fit(
    train_dataset, # Pass the TensorFlow Dataset
    validation_data=val_dataset, # Pass the TensorFlow Dataset
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['mse', 'val_mse']].plot()
plt.xlabel("Epoch")
plt.ylabel("Mean Squared Error")
plt.title("Training and Validation MSE per Epoch")
plt.show()
# Out:
# Epoch 1/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 21.7971 - mae: 3.7584 - mse: 21.7971 - val_loss: 16.7800 - val_mae: 3.3037 - val_mse: 16.7800
# Epoch 2/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.2460 - mae: 3.2836 - mse: 16.2460 - val_loss: 14.9127 - val_mae: 3.1356 - val_mse: 14.9127
# Epoch 3/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.0544 - mae: 3.1536 - mse: 15.0544 - val_loss: 13.3337 - val_mae: 2.9653 - val_mse: 13.3337
# Epoch 4/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.3288 - mae: 2.9515 - mse: 13.3288 - val_loss: 11.0590 - val_mae: 2.6873 - val_mse: 11.0590
# Epoch 5/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.7171 - mae: 2.6191 - mse: 10.7171 - val_loss: 7.9658 - val_mae: 2.2552 - val_mse: 7.9658
# Epoch 6/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.3256 - mae: 2.1231 - mse: 7.3256 - val_loss: 4.7657 - val_mae: 1.7155 - val_mse: 4.7657
# Epoch 7/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.2140 - mae: 1.5616 - mse: 4.2140 - val_loss: 2.5434 - val_mae: 1.2565 - val_mse: 2.5434
# Epoch 8/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.2759 - mae: 1.1410 - mse: 2.2759 - val_loss: 1.5264 - val_mae: 0.9958 - val_mse: 1.5264
# Epoch 9/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.4636 - mae: 0.9270 - mse: 1.4636 - val_loss: 1.1668 - val_mae: 0.8546 - val_mse: 1.1668
# Epoch 10/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1647 - mae: 0.8271 - mse: 1.1647 - val_loss: 1.0070 - val_mae: 0.7809 - val_mse: 1.0070
# Epoch 11/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0073 - mae: 0.7704 - mse: 1.0073 - val_loss: 0.8954 - val_mae: 0.7294 - val_mse: 0.8954
# Epoch 12/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8913 - mae: 0.7248 - mse: 0.8913 - val_loss: 0.8055 - val_mae: 0.6887 - val_mse: 0.8055
# Epoch 13/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7924 - mae: 0.6829 - mse: 0.7924 - val_loss: 0.7273 - val_mae: 0.6557 - val_mse: 0.7273
# Epoch 14/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7063 - mae: 0.6461 - mse: 0.7063 - val_loss: 0.6589 - val_mae: 0.6276 - val_mse: 0.6589
# Epoch 15/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6305 - mae: 0.6121 - mse: 0.6305 - val_loss: 0.5974 - val_mae: 0.6016 - val_mse: 0.5974
# Epoch 16/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5659 - mae: 0.5810 - mse: 0.5659 - val_loss: 0.5437 - val_mae: 0.5779 - val_mse: 0.5437
# Epoch 17/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5085 - mae: 0.5522 - mse: 0.5085 - val_loss: 0.4923 - val_mae: 0.5529 - val_mse: 0.4923
# Epoch 18/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4538 - mae: 0.5230 - mse: 0.4538 - val_loss: 0.4447 - val_mae: 0.5264 - val_mse: 0.4447
# Epoch 19/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4038 - mae: 0.4941 - mse: 0.4038 - val_loss: 0.4026 - val_mae: 0.5012 - val_mse: 0.4026
# Epoch 20/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3585 - mae: 0.4663 - mse: 0.3585 - val_loss: 0.3639 - val_mae: 0.4760 - val_mse: 0.3639
# Epoch 21/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3198 - mae: 0.4408 - mse: 0.3198 - val_loss: 0.3275 - val_mae: 0.4515 - val_mse: 0.3275
# Epoch 22/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2846 - mae: 0.4167 - mse: 0.2846 - val_loss: 0.2958 - val_mae: 0.4291 - val_mse: 0.2958
# Epoch 23/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2542 - mae: 0.3943 - mse: 0.2542 - val_loss: 0.2680 - val_mae: 0.4082 - val_mse: 0.2680
# Epoch 24/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2273 - mae: 0.3735 - mse: 0.2273 - val_loss: 0.2428 - val_mae: 0.3881 - val_mse: 0.2428
# Epoch 25/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2035 - mae: 0.3545 - mse: 0.2035 - val_loss: 0.2201 - val_mae: 0.3693 - val_mse: 0.2201
# Epoch 26/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1826 - mae: 0.3371 - mse: 0.1826 - val_loss: 0.1994 - val_mae: 0.3510 - val_mse: 0.1994
# Epoch 27/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1647 - mae: 0.3205 - mse: 0.1647 - val_loss: 0.1823 - val_mae: 0.3352 - val_mse: 0.1823
# Epoch 28/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1492 - mae: 0.3055 - mse: 0.1492 - val_loss: 0.1672 - val_mae: 0.3207 - val_mse: 0.1672
# Epoch 29/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1353 - mae: 0.2911 - mse: 0.1353 - val_loss: 0.1545 - val_mae: 0.3090 - val_mse: 0.1545
# Epoch 30/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1235 - mae: 0.2779 - mse: 0.1235 - val_loss: 0.1429 - val_mae: 0.2977 - val_mse: 0.1429
# Epoch 31/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1134 - mae: 0.2661 - mse: 0.1134 - val_loss: 0.1330 - val_mae: 0.2876 - val_mse: 0.1330
# Epoch 32/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1046 - mae: 0.2558 - mse: 0.1046 - val_loss: 0.1246 - val_mae: 0.2785 - val_mse: 0.1246
# Epoch 33/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0973 - mae: 0.2475 - mse: 0.0973 - val_loss: 0.1174 - val_mae: 0.2707 - val_mse: 0.1174
# Epoch 34/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0907 - mae: 0.2396 - mse: 0.0907 - val_loss: 0.1111 - val_mae: 0.2642 - val_mse: 0.1111
# Epoch 35/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0850 - mae: 0.2329 - mse: 0.0850 - val_loss: 0.1050 - val_mae: 0.2572 - val_mse: 0.1050
# Epoch 36/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0796 - mae: 0.2254 - mse: 0.0796 - val_loss: 0.0998 - val_mae: 0.2508 - val_mse: 0.0998
# Epoch 37/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0747 - mae: 0.2188 - mse: 0.0747 - val_loss: 0.0950 - val_mae: 0.2446 - val_mse: 0.0950
# Epoch 38/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0702 - mae: 0.2123 - mse: 0.0702 - val_loss: 0.0907 - val_mae: 0.2390 - val_mse: 0.0907
# Epoch 39/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0664 - mae: 0.2064 - mse: 0.0664 - val_loss: 0.0867 - val_mae: 0.2338 - val_mse: 0.0867
# Epoch 40/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0630 - mae: 0.2008 - mse: 0.0630 - val_loss: 0.0832 - val_mae: 0.2291 - val_mse: 0.0832
# Epoch 41/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0599 - mae: 0.1956 - mse: 0.0599 - val_loss: 0.0800 - val_mae: 0.2244 - val_mse: 0.0800
# Epoch 42/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0571 - mae: 0.1907 - mse: 0.0571 - val_loss: 0.0770 - val_mae: 0.2200 - val_mse: 0.0770
# Epoch 43/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0545 - mae: 0.1861 - mse: 0.0545 - val_loss: 0.0743 - val_mae: 0.2160 - val_mse: 0.0743
# Epoch 44/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0521 - mae: 0.1818 - mse: 0.0521 - val_loss: 0.0719 - val_mae: 0.2120 - val_mse: 0.0719
# Epoch 45/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0500 - mae: 0.1781 - mse: 0.0500 - val_loss: 0.0693 - val_mae: 0.2077 - val_mse: 0.0693
# Epoch 46/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0478 - mae: 0.1740 - mse: 0.0478 - val_loss: 0.0671 - val_mae: 0.2039 - val_mse: 0.0671
# Epoch 47/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0459 - mae: 0.1704 - mse: 0.0459 - val_loss: 0.0649 - val_mae: 0.2000 - val_mse: 0.0649
# Epoch 48/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0442 - mae: 0.1672 - mse: 0.0442 - val_loss: 0.0630 - val_mae: 0.1968 - val_mse: 0.0630
# Epoch 49/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0426 - mae: 0.1641 - mse: 0.0426 - val_loss: 0.0613 - val_mae: 0.1938 - val_mse: 0.0613
# Epoch 50/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0412 - mae: 0.1611 - mse: 0.0412 - val_loss: 0.0598 - val_mae: 0.1911 - val_mse: 0.0598
# Epoch 51/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0398 - mae: 0.1582 - mse: 0.0398 - val_loss: 0.0583 - val_mae: 0.1885 - val_mse: 0.0583
# Epoch 52/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0385 - mae: 0.1553 - mse: 0.0385 - val_loss: 0.0569 - val_mae: 0.1858 - val_mse: 0.0569
# Epoch 53/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0374 - mae: 0.1528 - mse: 0.0374 - val_loss: 0.0555 - val_mae: 0.1834 - val_mse: 0.0555
# Epoch 54/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0362 - mae: 0.1503 - mse: 0.0362 - val_loss: 0.0542 - val_mae: 0.1814 - val_mse: 0.0542
# Epoch 55/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0351 - mae: 0.1479 - mse: 0.0351 - val_loss: 0.0530 - val_mae: 0.1795 - val_mse: 0.0530
# Epoch 56/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0342 - mae: 0.1458 - mse: 0.0342 - val_loss: 0.0519 - val_mae: 0.1778 - val_mse: 0.0519
# Epoch 57/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0332 - mae: 0.1436 - mse: 0.0332 - val_loss: 0.0505 - val_mae: 0.1753 - val_mse: 0.0505
# Epoch 58/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0321 - mae: 0.1411 - mse: 0.0321 - val_loss: 0.0493 - val_mae: 0.1731 - val_mse: 0.0493
# Epoch 59/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0310 - mae: 0.1387 - mse: 0.0310 - val_loss: 0.0482 - val_mae: 0.1710 - val_mse: 0.0482
# Epoch 60/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0300 - mae: 0.1365 - mse: 0.0300 - val_loss: 0.0472 - val_mae: 0.1692 - val_mse: 0.0472
# Epoch 61/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0292 - mae: 0.1346 - mse: 0.0292 - val_loss: 0.0462 - val_mae: 0.1675 - val_mse: 0.0462
# Epoch 62/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0284 - mae: 0.1328 - mse: 0.0284 - val_loss: 0.0451 - val_mae: 0.1655 - val_mse: 0.0451
# Epoch 63/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0276 - mae: 0.1311 - mse: 0.0276 - val_loss: 0.0440 - val_mae: 0.1636 - val_mse: 0.0440
# Epoch 64/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0267 - mae: 0.1292 - mse: 0.0267 - val_loss: 0.0431 - val_mae: 0.1619 - val_mse: 0.0431
# Epoch 65/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0259 - mae: 0.1276 - mse: 0.0259 - val_loss: 0.0423 - val_mae: 0.1604 - val_mse: 0.0423
# Epoch 66/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0254 - mae: 0.1263 - mse: 0.0254 - val_loss: 0.0415 - val_mae: 0.1587 - val_mse: 0.0415
# Epoch 67/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0247 - mae: 0.1251 - mse: 0.0247 - val_loss: 0.0407 - val_mae: 0.1572 - val_mse: 0.0407
# Epoch 68/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0241 - mae: 0.1236 - mse: 0.0241 - val_loss: 0.0400 - val_mae: 0.1559 - val_mse: 0.0400
# Epoch 69/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0235 - mae: 0.1223 - mse: 0.0235 - val_loss: 0.0392 - val_mae: 0.1544 - val_mse: 0.0392
# Epoch 70/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0228 - mae: 0.1206 - mse: 0.0228 - val_loss: 0.0386 - val_mae: 0.1534 - val_mse: 0.0386
# Epoch 71/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0223 - mae: 0.1194 - mse: 0.0223 - val_loss: 0.0378 - val_mae: 0.1515 - val_mse: 0.0378
# Epoch 72/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0218 - mae: 0.1181 - mse: 0.0218 - val_loss: 0.0371 - val_mae: 0.1501 - val_mse: 0.0371
# Epoch 73/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0213 - mae: 0.1168 - mse: 0.0213 - val_loss: 0.0364 - val_mae: 0.1489 - val_mse: 0.0364
# Epoch 74/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0209 - mae: 0.1158 - mse: 0.0209 - val_loss: 0.0358 - val_mae: 0.1475 - val_mse: 0.0358
# Epoch 75/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0206 - mae: 0.1150 - mse: 0.0206 - val_loss: 0.0352 - val_mae: 0.1461 - val_mse: 0.0352
# Epoch 76/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0202 - mae: 0.1137 - mse: 0.0202 - val_loss: 0.0345 - val_mae: 0.1446 - val_mse: 0.0345
# Epoch 77/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0197 - mae: 0.1123 - mse: 0.0197 - val_loss: 0.0339 - val_mae: 0.1433 - val_mse: 0.0339
# Epoch 78/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0192 - mae: 0.1106 - mse: 0.0192 - val_loss: 0.0331 - val_mae: 0.1417 - val_mse: 0.0331
# Epoch 79/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0188 - mae: 0.1090 - mse: 0.0188 - val_loss: 0.0325 - val_mae: 0.1402 - val_mse: 0.0325
# Epoch 80/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0184 - mae: 0.1077 - mse: 0.0184 - val_loss: 0.0318 - val_mae: 0.1388 - val_mse: 0.0318
# Epoch 81/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0180 - mae: 0.1064 - mse: 0.0180 - val_loss: 0.0313 - val_mae: 0.1375 - val_mse: 0.0313
# Epoch 82/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0176 - mae: 0.1050 - mse: 0.0176 - val_loss: 0.0306 - val_mae: 0.1358 - val_mse: 0.0306
# Epoch 83/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0172 - mae: 0.1037 - mse: 0.0172 - val_loss: 0.0299 - val_mae: 0.1342 - val_mse: 0.0299
# Epoch 84/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0168 - mae: 0.1023 - mse: 0.0168 - val_loss: 0.0293 - val_mae: 0.1323 - val_mse: 0.0293
# Epoch 85/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0166 - mae: 0.1014 - mse: 0.0166 - val_loss: 0.0287 - val_mae: 0.1311 - val_mse: 0.0287
# Epoch 86/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0161 - mae: 0.0999 - mse: 0.0161 - val_loss: 0.0280 - val_mae: 0.1290 - val_mse: 0.0280
# Epoch 87/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0158 - mae: 0.0988 - mse: 0.0158 - val_loss: 0.0274 - val_mae: 0.1275 - val_mse: 0.0274
# Epoch 88/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0153 - mae: 0.0970 - mse: 0.0153 - val_loss: 0.0269 - val_mae: 0.1259 - val_mse: 0.0269
# Epoch 89/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0151 - mae: 0.0961 - mse: 0.0151 - val_loss: 0.0263 - val_mae: 0.1243 - val_mse: 0.0263
# Epoch 90/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0147 - mae: 0.0947 - mse: 0.0147 - val_loss: 0.0258 - val_mae: 0.1226 - val_mse: 0.0258
# Epoch 91/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0143 - mae: 0.0934 - mse: 0.0143 - val_loss: 0.0253 - val_mae: 0.1209 - val_mse: 0.0253
# Epoch 92/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0139 - mae: 0.0920 - mse: 0.0139 - val_loss: 0.0248 - val_mae: 0.1194 - val_mse: 0.0248
# Epoch 93/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0137 - mae: 0.0910 - mse: 0.0137 - val_loss: 0.0242 - val_mae: 0.1181 - val_mse: 0.0242
# Epoch 94/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0134 - mae: 0.0900 - mse: 0.0134 - val_loss: 0.0239 - val_mae: 0.1172 - val_mse: 0.0239
# Epoch 95/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0131 - mae: 0.0891 - mse: 0.0131 - val_loss: 0.0235 - val_mae: 0.1160 - val_mse: 0.0235
# Epoch 96/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0129 - mae: 0.0885 - mse: 0.0129 - val_loss: 0.0231 - val_mae: 0.1152 - val_mse: 0.0231
# Epoch 97/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0127 - mae: 0.0879 - mse: 0.0127 - val_loss: 0.0228 - val_mae: 0.1143 - val_mse: 0.0228
# Epoch 98/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0125 - mae: 0.0872 - mse: 0.0125 - val_loss: 0.0223 - val_mae: 0.1129 - val_mse: 0.0223
# Epoch 99/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0123 - mae: 0.0864 - mse: 0.0123 - val_loss: 0.0219 - val_mae: 0.1120 - val_mse: 0.0219
# Epoch 100/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0121 - mae: 0.0858 - mse: 0.0121 - val_loss: 0.0216 - val_mae: 0.1109 - val_mse: 0.0216
# Epoch 101/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0119 - mae: 0.0851 - mse: 0.0119 - val_loss: 0.0213 - val_mae: 0.1102 - val_mse: 0.0213
# Epoch 102/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0117 - mae: 0.0844 - mse: 0.0117 - val_loss: 0.0212 - val_mae: 0.1096 - val_mse: 0.0212
# Epoch 103/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0116 - mae: 0.0837 - mse: 0.0116 - val_loss: 0.0211 - val_mae: 0.1092 - val_mse: 0.0211
# Epoch 104/200
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0115 - mae: 0.0834 - mse: 0.0115 - val_loss: 0.0210 - val_mae: 0.1089 - val_mse: 0.0210

# %%
model.predict(np.array([[1, 1, 1, 1, 1]]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# array([[2.9331298]], dtype=float32)

# %%
y_test = []
for i in expressions_not_in_x:
  result = float(eval(i))
  y_test.append(result)
x_test = tokenizer(expressions_not_in_x)
print(y_test[0])

store = model.predict(x_test)
print(len(store))
differences = []
for i in range(len(store)):
  differences.append(abs(store[i] - y_test[i]))
print(np.mean(differences))
plt.figure(figsize=(10, 6))
plt.plot(differences)
plt.axhline(y = np.mean(differences), color='r', linestyle='-', label='Mean Difference') # Plot a horizontal line at the mean difference
plt.xlabel("Test Sample Index")
plt.ylabel("Absolute Difference (Predicted - Actual)")
plt.title("Absolute Differences Between Predicted and Actual Values for Test Set")
plt.show()
# Out:
# [3, 1.0, -2, 1.0, 3]
# [ 3.  1. -2.  1.  3.]
# 4.0
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1457
# 0.10493447

# %%
# prompt: bootstrap the model 10 times and calculate a range for predictions

n_bootstrap = 10
predictions = []

for _ in range(n_bootstrap):
  # Create bootstrap sample
  sample_indices = np.random.choice(len(x_train), size=len(x_train), replace=True)
  x_train_bootstrap = x_train[sample_indices]
  y_train_bootstrap = np.array(y_train)[sample_indices]

  # Re-compile and train the model
  bootstrap_model = keras.models.clone_model(model)
  bootstrap_model.compile(optimizer="adam", loss="mse", metrics=["mae", "mse"])

  bootstrap_train_dataset = tf.data.Dataset.from_tensor_slices((x_train_bootstrap, y_train_bootstrap)).batch(32)
  bootstrap_model.fit(
      bootstrap_train_dataset,
      epochs=50,  # Reduced epochs for quicker example, adjust as needed
      verbose=0 # Suppress output
  )

  # Make predictions on the test set
  predictions.append(bootstrap_model.predict(x_test))

# Convert predictions to a numpy array for easier processing
predictions = np.array(predictions)

#calculate the mean thingy
meanPredictions = []
for i in range(len(expressions_not_in_x)):
  calc = 0
  for j in range(n_bootstrap):
    calc += predictions[j][i]
  meanPredictions.append(calc/n_bootstrap)

# Calculate the lower and upper bounds of the prediction range
lower_bound = np.percentile(predictions, 5, axis=0)
upper_bound = np.percentile(predictions, 95, axis=0)

inRange = []
outOfBounds = 0
for i in range(len(x_test)):
  if y_test[i] >= lower_bound[i][0] and y_test[i] <= upper_bound[i][0]:
    inRange.append(True)
  else:
    inRange.append(False)
    outOfBounds += 1


print("Prediction Range (5th to 95th percentile):")
for i in range(len(x_test)):
  print(f"Input: {expressions_not_in_x[i]}, Actual: {y_test[i]:.2f}, Predicted Range: [{lower_bound[i][0]:.2f}, {upper_bound[i][0]:.2f}], bootstrapped prediction: {meanPredictions[i]}, in Range: {inRange[i]}")

print(f"Amount out of bounds: {outOfBounds}, Amount of expressions: {len(x_test)}, Percentage in bounds: {(1-(outOfBounds/len(x_test)))*100}%")
# Out:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Prediction Range (5th to 95th percentile):
# Input: 3 + -2 + 3, Actual: 4.00, Predicted Range: [3.82, 4.40], bootstrapped prediction: [4.0553637], in Range: True
# Input: -3 - 4 + -5, Actual: -12.00, Predicted Range: [-12.00, -11.45], bootstrapped prediction: [-11.757681], in Range: True
# Input: 3 - -4 - -5, Actual: 12.00, Predicted Range: [11.65, 12.05], bootstrapped prediction: [11.808774], in Range: True
# Input: -2 + -4 - 1, Actual: -7.00, Predicted Range: [-7.35, -6.66], bootstrapped prediction: [-7.104439], in Range: True
# Input: 1 - -1 - -1, Actual: 3.00, Predicted Range: [2.47, 3.53], bootstrapped prediction: [3.0682416], in Range: True
# Input: -4 + 4 + -4, Actual: -4.00, Predicted Range: [-4.36, -3.93], bootstrapped prediction: [-4.127137], in Range: True
# Input: -3 - 3 - -3, Actual: -3.00, Predicted Range: [-3.25, -2.60], bootstrapped prediction: [-2.957325], in Range: True
# Input: 4 - 0 - 3, Actual: 1.00, Predicted Range: [0.52, 1.41], bootstrapped prediction: [0.8907752], in Range: True
# Input: -2 - 4 - -4, Actual: -2.00, Predicted Range: [-2.19, -1.58], bootstrapped prediction: [-1.9245396], in Range: True
# Input: 1 + -4 - -1, Actual: -2.00, Predicted Range: [-2.42, -1.98], bootstrapped prediction: [-2.1790566], in Range: True
# Input: -3 + 1 - -4, Actual: 2.00, Predicted Range: [1.96, 2.35], bootstrapped prediction: [2.0922155], in Range: True
# Input: -1 - 4 + -1, Actual: -6.00, Predicted Range: [-6.26, -5.55], bootstrapped prediction: [-5.919671], in Range: True
# Input: 1 + -3 - 3, Actual: -5.00, Predicted Range: [-5.26, -4.88], bootstrapped prediction: [-5.1178174], in Range: True
# Input: 2 - 3 + -2, Actual: -3.00, Predicted Range: [-3.43, -2.76], bootstrapped prediction: [-3.0493112], in Range: True
# Input: -5 + -5 + 0, Actual: -10.00, Predicted Range: [-10.15, -9.58], bootstrapped prediction: [-9.858854], in Range: True
# Input: 3 + 4 - -3, Actual: 10.00, Predicted Range: [9.63, 10.09], bootstrapped prediction: [9.884242], in Range: True
# Input: 2 - -2 + 1, Actual: 5.00, Predicted Range: [4.71, 5.23], bootstrapped prediction: [5.0213532], in Range: True
# Input: 2 - 0 + 0, Actual: 2.00, Predicted Range: [1.80, 2.40], bootstrapped prediction: [2.0629003], in Range: True
# Input: 2 - -3 - -5, Actual: 10.00, Predicted Range: [9.57, 10.18], bootstrapped prediction: [9.851387], in Range: True
# Input: 0 + -1 - 4, Actual: -5.00, Predicted Range: [-5.16, -4.53], bootstrapped prediction: [-4.8451667], in Range: True
# Input: 1 - -1 + 1, Actual: 3.00, Predicted Range: [2.61, 3.37], bootstrapped prediction: [3.0163841], in Range: True
# Input: -1 - 1 + -2, Actual: -4.00, Predicted Range: [-4.38, -3.78], bootstrapped prediction: [-4.079384], in Range: True
# Input: -4 - -1 - 2, Actual: -5.00, Predicted Range: [-5.29, -4.76], bootstrapped prediction: [-5.0559087], in Range: True
# Input: -2 + 1 - 2, Actual: -3.00, Predicted Range: [-3.14, -2.68], bootstrapped prediction: [-2.9102721], in Range: True
# Input: 1 + -5 + -5, Actual: -9.00, Predicted Range: [-9.08, -8.52], bootstrapped prediction: [-8.793256], in Range: True
# Input: -3 + 3 - 4, Actual: -4.00, Predicted Range: [-4.20, -3.88], bootstrapped prediction: [-4.0090237], in Range: True
# Input: -2 + -1 - 1, Actual: -4.00, Predicted Range: [-4.34, -3.59], bootstrapped prediction: [-3.9908519], in Range: True
# Input: 4 - 1 + -5, Actual: -2.00, Predicted Range: [-2.37, -1.30], bootstrapped prediction: [-1.8568251], in Range: True
# Input: 3 - 3 + -4, Actual: -4.00, Predicted Range: [-4.27, -3.79], bootstrapped prediction: [-4.0498548], in Range: True
# Input: 2 + 4 - 4, Actual: 2.00, Predicted Range: [1.24, 2.15], bootstrapped prediction: [1.6499571], in Range: True
# Input: 1 - 0 - -4, Actual: 5.00, Predicted Range: [4.86, 5.53], bootstrapped prediction: [5.1433325], in Range: True
# Input: 2 + 0 + 4, Actual: 6.00, Predicted Range: [5.78, 6.11], bootstrapped prediction: [5.94539], in Range: True
# Input: -5 - -4 - 1, Actual: -2.00, Predicted Range: [-2.33, -1.42], bootstrapped prediction: [-1.8267219], in Range: True
# Input: 3 + 2 - 1, Actual: 4.00, Predicted Range: [3.86, 4.65], bootstrapped prediction: [4.256639], in Range: True
# Input: -2 + -2 + 1, Actual: -3.00, Predicted Range: [-3.28, -2.74], bootstrapped prediction: [-2.9873152], in Range: True
# Input: -1 + 3 - 2, Actual: 0.00, Predicted Range: [-0.06, 0.68], bootstrapped prediction: [0.29338735], in Range: True
# Input: 1 + 0 + -2, Actual: -1.00, Predicted Range: [-1.43, -0.69], bootstrapped prediction: [-1.0204747], in Range: True
# Input: 3 - 2 + 3, Actual: 4.00, Predicted Range: [4.03, 4.36], bootstrapped prediction: [4.183352], in Range: False
# Input: 4 - 1 + 4, Actual: 7.00, Predicted Range: [6.37, 7.17], bootstrapped prediction: [6.812506], in Range: True
# Input: 4 - 3 + -3, Actual: -2.00, Predicted Range: [-2.08, -1.64], bootstrapped prediction: [-1.9437618], in Range: True
# Input: 4 - 2 + 3, Actual: 5.00, Predicted Range: [4.80, 5.45], bootstrapped prediction: [5.062841], in Range: True
# Input: 3 - -5 + 3, Actual: 11.00, Predicted Range: [10.60, 11.04], bootstrapped prediction: [10.931495], in Range: True
# Input: 1 - -1 + 4, Actual: 6.00, Predicted Range: [5.84, 6.30], bootstrapped prediction: [6.016697], in Range: True
# Input: -3 + 0 + 1, Actual: -2.00, Predicted Range: [-2.31, -1.82], bootstrapped prediction: [-1.9884943], in Range: True
# Input: -1 + 1 - 4, Actual: -4.00, Predicted Range: [-4.20, -3.75], bootstrapped prediction: [-3.993824], in Range: True
# Input: 1 + 1 + 3, Actual: 5.00, Predicted Range: [4.80, 5.46], bootstrapped prediction: [5.152705], in Range: True
# Input: 4 + -3 + -2, Actual: -1.00, Predicted Range: [-1.34, -0.86], bootstrapped prediction: [-1.1294467], in Range: True
# Input: -4 + 4 - 2, Actual: -2.00, Predicted Range: [-2.30, -1.73], bootstrapped prediction: [-1.986594], in Range: True
# Input: 2 + -2 + -5, Actual: -5.00, Predicted Range: [-5.15, -4.82], bootstrapped prediction: [-4.971473], in Range: True
# Input: 1 + 4 + 3, Actual: 8.00, Predicted Range: [7.60, 7.97], bootstrapped prediction: [7.7509537], in Range: False
# Input: -4 - 4 + -5, Actual: -13.00, Predicted Range: [-12.94, -12.24], bootstrapped prediction: [-12.67182], in Range: False
# Input: 3 + 2 + -3, Actual: 2.00, Predicted Range: [1.84, 2.22], bootstrapped prediction: [2.0541198], in Range: True
# Input: 4 - -2 + -2, Actual: 4.00, Predicted Range: [3.72, 4.20], bootstrapped prediction: [3.9658368], in Range: True
# Input: -1 - 3 + 0, Actual: -4.00, Predicted Range: [-4.18, -3.71], bootstrapped prediction: [-3.946611], in Range: True
# Input: -4 + -5 + 0, Actual: -9.00, Predicted Range: [-9.09, -8.71], bootstrapped prediction: [-8.880652], in Range: True
# Input: -5 - 1 + -5, Actual: -11.00, Predicted Range: [-11.10, -10.35], bootstrapped prediction: [-10.803656], in Range: True
# Input: -5 - -1 - 3, Actual: -7.00, Predicted Range: [-7.16, -6.67], bootstrapped prediction: [-6.9380393], in Range: True
# Input: -1 - -3 - -2, Actual: 4.00, Predicted Range: [3.84, 4.45], bootstrapped prediction: [4.1708264], in Range: True
# Input: -1 + 4 + 4, Actual: 7.00, Predicted Range: [6.10, 6.88], bootstrapped prediction: [6.53243], in Range: False
# Input: -1 + 4 + -1, Actual: 2.00, Predicted Range: [1.50, 2.12], bootstrapped prediction: [1.7957909], in Range: True
# Input: 3 + 1 - 3, Actual: 1.00, Predicted Range: [0.86, 1.16], bootstrapped prediction: [1.0048072], in Range: True
# Input: -5 - -5 - -2, Actual: 2.00, Predicted Range: [1.46, 2.16], bootstrapped prediction: [1.7710478], in Range: True
# Input: -5 + -4 + 4, Actual: -5.00, Predicted Range: [-5.35, -4.96], bootstrapped prediction: [-5.1738944], in Range: True
# Input: 2 + -2 - 3, Actual: -3.00, Predicted Range: [-3.33, -2.95], bootstrapped prediction: [-3.152184], in Range: True
# Input: -2 + -4 + 4, Actual: -2.00, Predicted Range: [-2.63, -1.79], bootstrapped prediction: [-2.1962218], in Range: True
# Input: -1 + -2 + 4, Actual: 1.00, Predicted Range: [0.68, 1.17], bootstrapped prediction: [0.9196337], in Range: True
# Input: 4 - 4 - 4, Actual: -4.00, Predicted Range: [-3.69, -3.26], bootstrapped prediction: [-3.4755967], in Range: False
# Input: 0 - -3 - -1, Actual: 4.00, Predicted Range: [4.00, 4.45], bootstrapped prediction: [4.1970844], in Range: True
# Input: -3 + 2 + 0, Actual: -1.00, Predicted Range: [-1.11, -0.88], bootstrapped prediction: [-1.0257051], in Range: True
# Input: 4 - 2 + -3, Actual: -1.00, Predicted Range: [-1.35, -0.71], bootstrapped prediction: [-1.0104326], in Range: True
# Input: 0 - 0 - -4, Actual: 4.00, Predicted Range: [3.94, 4.42], bootstrapped prediction: [4.1670585], in Range: True
# Input: 2 + 1 + 4, Actual: 7.00, Predicted Range: [6.77, 7.16], bootstrapped prediction: [6.9530725], in Range: True
# Input: -1 - -3 + -3, Actual: -1.00, Predicted Range: [-1.29, -0.94], bootstrapped prediction: [-1.080106], in Range: True
# Input: -3 - 4 + -1, Actual: -8.00, Predicted Range: [-8.23, -7.74], bootstrapped prediction: [-7.9538803], in Range: True
# Input: -3 + 4 - 3, Actual: -2.00, Predicted Range: [-2.19, -1.72], bootstrapped prediction: [-1.991512], in Range: True
# Input: -2 - -5 - -5, Actual: 8.00, Predicted Range: [7.58, 7.99], bootstrapped prediction: [7.786171], in Range: False
# Input: -2 + 2 - 1, Actual: -1.00, Predicted Range: [-1.15, -0.43], bootstrapped prediction: [-0.7678534], in Range: True
# Input: 4 + 0 - 0, Actual: 4.00, Predicted Range: [3.49, 4.25], bootstrapped prediction: [3.8622608], in Range: True
# Input: 1 - 2 - -2, Actual: 1.00, Predicted Range: [0.75, 1.13], bootstrapped prediction: [0.9583479], in Range: True
# Input: -1 - 3 - 0, Actual: -4.00, Predicted Range: [-4.57, -3.92], bootstrapped prediction: [-4.198493], in Range: True
# Input: -2 - 4 + -4, Actual: -10.00, Predicted Range: [-10.06, -9.84], bootstrapped prediction: [-9.960268], in Range: True
# Input: 2 + -2 + 3, Actual: 3.00, Predicted Range: [2.73, 3.23], bootstrapped prediction: [3.007953], in Range: True
# Input: -5 - -5 - -3, Actual: 3.00, Predicted Range: [2.61, 3.17], bootstrapped prediction: [2.803496], in Range: True
# Input: 3 + 3 + 2, Actual: 8.00, Predicted Range: [7.74, 8.14], bootstrapped prediction: [7.9309616], in Range: True
# Input: 2 + -1 + 2, Actual: 3.00, Predicted Range: [2.62, 3.27], bootstrapped prediction: [3.0039608], in Range: True
# Input: 1 - -3 + -3, Actual: 1.00, Predicted Range: [0.77, 1.12], bootstrapped prediction: [0.9148986], in Range: True
# Input: -2 + -2 - 1, Actual: -5.00, Predicted Range: [-5.49, -4.70], bootstrapped prediction: [-5.0939016], in Range: True
# Input: 1 - 4 - 1, Actual: -4.00, Predicted Range: [-4.26, -3.80], bootstrapped prediction: [-4.029565], in Range: True
# Input: -2 + -5 + -4, Actual: -11.00, Predicted Range: [-11.34, -10.55], bootstrapped prediction: [-10.868967], in Range: True
# Input: -2 + -1 - -1, Actual: -2.00, Predicted Range: [-2.29, -1.85], bootstrapped prediction: [-2.0788126], in Range: True
# Input: 3 + -4 - 3, Actual: -4.00, Predicted Range: [-4.34, -3.89], bootstrapped prediction: [-4.1193647], in Range: True
# Input: 2 - 1 - 2, Actual: -1.00, Predicted Range: [-1.68, -1.04], bootstrapped prediction: [-1.3333559], in Range: False
# Input: 3 + 0 + 2, Actual: 5.00, Predicted Range: [4.62, 5.22], bootstrapped prediction: [4.998452], in Range: True
# Input: -2 + -1 - -4, Actual: 1.00, Predicted Range: [0.74, 1.34], bootstrapped prediction: [1.0059211], in Range: True
# Input: 0 + -3 + -1, Actual: -4.00, Predicted Range: [-4.23, -3.81], bootstrapped prediction: [-4.078894], in Range: True
# Input: -5 - 4 + 2, Actual: -7.00, Predicted Range: [-7.47, -6.73], bootstrapped prediction: [-7.0405746], in Range: True
# Input: -1 - -2 - 3, Actual: -2.00, Predicted Range: [-2.37, -1.74], bootstrapped prediction: [-1.9981232], in Range: True
# Input: 3 + -3 - -2, Actual: 2.00, Predicted Range: [1.48, 2.22], bootstrapped prediction: [1.8686968], in Range: True
# Input: 0 - 4 - 2, Actual: -6.00, Predicted Range: [-6.17, -5.74], bootstrapped prediction: [-5.937776], in Range: True
# Input: 0 - 1 - 4, Actual: -5.00, Predicted Range: [-5.46, -4.85], bootstrapped prediction: [-5.1032515], in Range: True
# Input: -4 + -5 + -5, Actual: -14.00, Predicted Range: [-13.92, -13.08], bootstrapped prediction: [-13.508377], in Range: False
# Input: 0 - 4 + -3, Actual: -7.00, Predicted Range: [-7.29, -6.67], bootstrapped prediction: [-6.96688], in Range: True
# Input: 0 + 0 + 1, Actual: 1.00, Predicted Range: [0.71, 1.33], bootstrapped prediction: [1.0635709], in Range: True
# Input: 3 + 0 - -5, Actual: 8.00, Predicted Range: [7.66, 8.10], bootstrapped prediction: [7.905328], in Range: True
# Input: 4 + 4 - -5, Actual: 13.00, Predicted Range: [12.04, 12.92], bootstrapped prediction: [12.516809], in Range: False
# Input: 0 + 2 + 4, Actual: 6.00, Predicted Range: [5.67, 6.30], bootstrapped prediction: [5.962166], in Range: True
# Input: 1 - 3 - -4, Actual: 2.00, Predicted Range: [1.79, 2.21], bootstrapped prediction: [1.9923748], in Range: True
# Input: 2 - -5 - 0, Actual: 7.00, Predicted Range: [6.38, 7.30], bootstrapped prediction: [6.929599], in Range: True
# Input: 2 - -1 - 1, Actual: 2.00, Predicted Range: [1.81, 2.20], bootstrapped prediction: [1.9934199], in Range: True
# Input: -1 + -1 - 2, Actual: -4.00, Predicted Range: [-4.43, -3.77], bootstrapped prediction: [-4.0754027], in Range: True
# Input: 4 + -2 + -2, Actual: 0.00, Predicted Range: [-0.24, 0.09], bootstrapped prediction: [-0.0522908], in Range: True
# Input: 2 + -5 + 0, Actual: -3.00, Predicted Range: [-3.32, -2.90], bootstrapped prediction: [-3.0380147], in Range: True
# Input: -2 - 0 - -5, Actual: 3.00, Predicted Range: [2.58, 3.34], bootstrapped prediction: [2.9790885], in Range: True
# Input: 2 + -2 + 0, Actual: 0.00, Predicted Range: [-0.13, 0.24], bootstrapped prediction: [0.08535876], in Range: True
# Input: -2 - -4 - 1, Actual: 1.00, Predicted Range: [0.97, 1.44], bootstrapped prediction: [1.1716969], in Range: True
# Input: -1 - -4 - -2, Actual: 5.00, Predicted Range: [4.68, 5.40], bootstrapped prediction: [5.0835977], in Range: True
# Input: -3 - -2 + 1, Actual: 0.00, Predicted Range: [-0.12, 0.35], bootstrapped prediction: [0.13967858], in Range: True
# Input: 1 - -5 + -1, Actual: 5.00, Predicted Range: [4.81, 5.31], bootstrapped prediction: [5.029477], in Range: True
# Input: 0 + -4 + 0, Actual: -4.00, Predicted Range: [-4.26, -3.90], bootstrapped prediction: [-4.082062], in Range: True
# Input: 4 - -4 + -2, Actual: 6.00, Predicted Range: [5.93, 6.14], bootstrapped prediction: [6.019101], in Range: True
# Input: -5 - -5 + 1, Actual: 1.00, Predicted Range: [0.60, 1.03], bootstrapped prediction: [0.84846574], in Range: True
# Input: -4 - 2 - -1, Actual: -5.00, Predicted Range: [-5.34, -4.84], bootstrapped prediction: [-5.0720587], in Range: True
# Input: 2 + -5 - -5, Actual: 2.00, Predicted Range: [1.79, 2.50], bootstrapped prediction: [2.1229577], in Range: True
# Input: -4 - 0 - 3, Actual: -7.00, Predicted Range: [-7.51, -6.78], bootstrapped prediction: [-7.04504], in Range: True
# Input: 3 + -1 + -2, Actual: 0.00, Predicted Range: [-0.34, 0.21], bootstrapped prediction: [-0.03615325], in Range: True
# Input: -5 + -3 - 2, Actual: -10.00, Predicted Range: [-10.08, -9.55], bootstrapped prediction: [-9.8144245], in Range: True
# Input: 4 + 2 + 0, Actual: 6.00, Predicted Range: [5.51, 6.18], bootstrapped prediction: [5.8932734], in Range: True
# Input: 2 + 2 - 0, Actual: 4.00, Predicted Range: [3.89, 4.30], bootstrapped prediction: [4.088155], in Range: True
# Input: -4 - 1 - -4, Actual: -1.00, Predicted Range: [-1.14, -0.79], bootstrapped prediction: [-0.96947765], in Range: True
# Input: 2 - -3 - 4, Actual: 1.00, Predicted Range: [0.84, 1.50], bootstrapped prediction: [1.1425734], in Range: True
# Input: -4 + -1 + 0, Actual: -5.00, Predicted Range: [-5.25, -4.63], bootstrapped prediction: [-4.939666], in Range: True
# Input: -1 + 0 - 0, Actual: -1.00, Predicted Range: [-1.23, -0.75], bootstrapped prediction: [-1.0117915], in Range: True
# Input: 2 - -5 + 4, Actual: 11.00, Predicted Range: [10.48, 11.13], bootstrapped prediction: [10.78198], in Range: True
# Input: 0 - -4 + 0, Actual: 4.00, Predicted Range: [3.87, 4.15], bootstrapped prediction: [3.9963088], in Range: True
# Input: 0 + 3 + 2, Actual: 5.00, Predicted Range: [4.95, 5.24], bootstrapped prediction: [5.0701933], in Range: True
# Input: 1 + 2 + 2, Actual: 5.00, Predicted Range: [4.70, 5.60], bootstrapped prediction: [5.1406264], in Range: True
# Input: 4 - -5 - 1, Actual: 8.00, Predicted Range: [7.28, 7.95], bootstrapped prediction: [7.732035], in Range: False
# Input: -3 - 0 - -3, Actual: 0.00, Predicted Range: [-0.08, 0.25], bootstrapped prediction: [0.07353982], in Range: True
# Input: 2 + 1 - 4, Actual: -1.00, Predicted Range: [-1.24, -0.79], bootstrapped prediction: [-1.0226648], in Range: True
# Input: 0 + -1 - -1, Actual: 0.00, Predicted Range: [-0.29, 0.27], bootstrapped prediction: [-0.06794532], in Range: True
# Input: -4 - -4 - -2, Actual: 2.00, Predicted Range: [1.83, 2.24], bootstrapped prediction: [1.9945114], in Range: True
# Input: 1 + 1 - -3, Actual: 5.00, Predicted Range: [4.89, 5.43], bootstrapped prediction: [5.104495], in Range: True
# Input: -5 - -3 + -2, Actual: -4.00, Predicted Range: [-4.16, -3.60], bootstrapped prediction: [-3.990123], in Range: True
# Input: -3 + -4 + -4, Actual: -11.00, Predicted Range: [-11.22, -10.89], bootstrapped prediction: [-11.075062], in Range: True
# Input: 0 - -5 - 1, Actual: 4.00, Predicted Range: [3.56, 4.21], bootstrapped prediction: [3.9260955], in Range: True
# Input: 4 - 4 - -5, Actual: 5.00, Predicted Range: [4.61, 5.17], bootstrapped prediction: [4.9182057], in Range: True
# Input: -4 - -5 - -4, Actual: 5.00, Predicted Range: [4.51, 5.08], bootstrapped prediction: [4.830802], in Range: True
# Input: 4 - -4 - 2, Actual: 6.00, Predicted Range: [5.62, 6.19], bootstrapped prediction: [5.921508], in Range: True
# Input: -1 + -2 + 1, Actual: -2.00, Predicted Range: [-2.25, -1.68], bootstrapped prediction: [-1.9737794], in Range: True
# Input: -1 - 3 - 3, Actual: -7.00, Predicted Range: [-7.40, -6.88], bootstrapped prediction: [-7.1283684], in Range: True
# Input: 1 + 3 + 4, Actual: 8.00, Predicted Range: [7.57, 8.11], bootstrapped prediction: [7.8199906], in Range: True
# Input: 3 + 4 - -5, Actual: 12.00, Predicted Range: [11.15, 12.04], bootstrapped prediction: [11.578131], in Range: True
# Input: 1 - 2 - 2, Actual: -3.00, Predicted Range: [-3.59, -3.03], bootstrapped prediction: [-3.2745132], in Range: False
# Input: 3 - 2 + 4, Actual: 5.00, Predicted Range: [4.72, 5.27], bootstrapped prediction: [4.968198], in Range: True
# Input: -4 + -2 - 0, Actual: -6.00, Predicted Range: [-6.36, -5.76], bootstrapped prediction: [-6.097553], in Range: True
# Input: 3 + -2 + 1, Actual: 2.00, Predicted Range: [1.80, 2.30], bootstrapped prediction: [2.0823977], in Range: True
# Input: 4 - -2 - -3, Actual: 9.00, Predicted Range: [8.49, 9.09], bootstrapped prediction: [8.807632], in Range: True
# Input: -4 - 2 - 4, Actual: -10.00, Predicted Range: [-10.15, -9.59], bootstrapped prediction: [-9.8678255], in Range: True
# Input: -1 - -4 + 3, Actual: 6.00, Predicted Range: [5.91, 6.26], bootstrapped prediction: [6.060647], in Range: True
# Input: 4 + 0 - -1, Actual: 5.00, Predicted Range: [4.55, 5.22], bootstrapped prediction: [4.893447], in Range: True
# Input: -5 + 2 - -5, Actual: 2.00, Predicted Range: [1.54, 2.18], bootstrapped prediction: [1.8555887], in Range: True
# Input: 3 + 2 + 3, Actual: 8.00, Predicted Range: [7.74, 8.31], bootstrapped prediction: [8.065948], in Range: True
# Input: -4 - 2 - -2, Actual: -4.00, Predicted Range: [-4.12, -3.89], bootstrapped prediction: [-4.022701], in Range: True
# Input: 0 - 1 - 2, Actual: -3.00, Predicted Range: [-3.74, -3.19], bootstrapped prediction: [-3.3896441], in Range: False
# Input: 2 + 2 + -3, Actual: 1.00, Predicted Range: [0.89, 1.30], bootstrapped prediction: [1.0819204], in Range: True
# Input: -4 - -3 + 3, Actual: 2.00, Predicted Range: [1.94, 2.51], bootstrapped prediction: [2.2076082], in Range: True
# Input: 4 - -4 + -1, Actual: 7.00, Predicted Range: [6.73, 7.25], bootstrapped prediction: [7.051609], in Range: True
# Input: -2 - 0 + 2, Actual: 0.00, Predicted Range: [-0.13, 0.62], bootstrapped prediction: [0.11209097], in Range: True
# Input: -4 - 4 + 0, Actual: -8.00, Predicted Range: [-8.32, -7.72], bootstrapped prediction: [-8.015677], in Range: True
# Input: 2 - -3 + -1, Actual: 4.00, Predicted Range: [3.61, 4.00], bootstrapped prediction: [3.8423386], in Range: False
# Input: 2 + -3 - -3, Actual: 2.00, Predicted Range: [1.53, 2.12], bootstrapped prediction: [1.8390548], in Range: True
# Input: 4 + -1 + 2, Actual: 5.00, Predicted Range: [4.61, 5.41], bootstrapped prediction: [5.002885], in Range: True
# Input: 2 - 0 + 4, Actual: 6.00, Predicted Range: [5.65, 6.18], bootstrapped prediction: [5.958251], in Range: True
# Input: 0 - -3 + -5, Actual: -2.00, Predicted Range: [-2.11, -1.70], bootstrapped prediction: [-1.9567311], in Range: True
# Input: -4 - 3 - 2, Actual: -9.00, Predicted Range: [-9.08, -8.79], bootstrapped prediction: [-8.955877], in Range: True
# Input: -1 + 3 + -5, Actual: -3.00, Predicted Range: [-3.05, -2.77], bootstrapped prediction: [-2.9322202], in Range: True
# Input: -1 + 3 + 2, Actual: 4.00, Predicted Range: [3.92, 4.23], bootstrapped prediction: [4.074937], in Range: True
# Input: 4 + -3 - -2, Actual: 3.00, Predicted Range: [2.76, 3.27], bootstrapped prediction: [3.0372527], in Range: True
# Input: -4 + 2 - 4, Actual: -6.00, Predicted Range: [-6.22, -5.87], bootstrapped prediction: [-6.0468836], in Range: True
# Input: -1 - 2 + -5, Actual: -8.00, Predicted Range: [-8.13, -7.70], bootstrapped prediction: [-7.9474044], in Range: True
# Input: -3 - 2 - 3, Actual: -8.00, Predicted Range: [-8.29, -7.98], bootstrapped prediction: [-8.150315], in Range: True
# Input: -5 + -4 - 1, Actual: -10.00, Predicted Range: [-10.25, -9.57], bootstrapped prediction: [-9.864932], in Range: True
# Input: -2 + -2 + -5, Actual: -9.00, Predicted Range: [-9.24, -8.75], bootstrapped prediction: [-8.990381], in Range: True
# Input: -5 + -1 - -1, Actual: -5.00, Predicted Range: [-5.68, -4.74], bootstrapped prediction: [-5.1129556], in Range: True
# Input: -2 + 4 - -5, Actual: 7.00, Predicted Range: [6.43, 6.96], bootstrapped prediction: [6.690355], in Range: False
# Input: 4 - 1 - -4, Actual: 7.00, Predicted Range: [6.84, 7.46], bootstrapped prediction: [7.0641136], in Range: True
# Input: -5 - -5 - 1, Actual: -1.00, Predicted Range: [-1.49, -0.70], bootstrapped prediction: [-1.0267476], in Range: True
# Input: -5 - 2 - -5, Actual: -2.00, Predicted Range: [-2.37, -1.84], bootstrapped prediction: [-2.1170163], in Range: True
# Input: 3 - 3 + 3, Actual: 3.00, Predicted Range: [2.78, 3.20], bootstrapped prediction: [3.048325], in Range: True
# Input: -1 - -4 + -4, Actual: -1.00, Predicted Range: [-1.43, -0.87], bootstrapped prediction: [-1.1073282], in Range: True
# Input: -4 + -2 + -2, Actual: -8.00, Predicted Range: [-8.22, -7.75], bootstrapped prediction: [-7.9973946], in Range: True
# Input: -1 - -4 + 2, Actual: 5.00, Predicted Range: [4.81, 5.38], bootstrapped prediction: [5.0898333], in Range: True
# Input: -2 - 2 - 3, Actual: -7.00, Predicted Range: [-7.41, -6.99], bootstrapped prediction: [-7.2129936], in Range: True
# Input: 0 - -5 - -4, Actual: 9.00, Predicted Range: [8.56, 9.05], bootstrapped prediction: [8.790903], in Range: True
# Input: 3 - 0 + 2, Actual: 5.00, Predicted Range: [4.96, 5.56], bootstrapped prediction: [5.2541647], in Range: True
# Input: 0 - -5 + 3, Actual: 8.00, Predicted Range: [7.60, 8.16], bootstrapped prediction: [7.9336715], in Range: True
# Input: -3 - -2 + 0, Actual: -1.00, Predicted Range: [-1.14, -0.67], bootstrapped prediction: [-0.9557997], in Range: True
# Input: 4 - 2 + -4, Actual: -2.00, Predicted Range: [-2.29, -1.59], bootstrapped prediction: [-1.9440132], in Range: True
# Input: 4 + -1 + 3, Actual: 6.00, Predicted Range: [5.76, 6.38], bootstrapped prediction: [6.0440817], in Range: True
# Input: -5 + -2 - -5, Actual: -2.00, Predicted Range: [-2.55, -1.59], bootstrapped prediction: [-2.0576465], in Range: True
# Input: -5 + 1 - -5, Actual: 1.00, Predicted Range: [0.64, 1.18], bootstrapped prediction: [0.8766305], in Range: True
# Input: 1 - -1 + 2, Actual: 4.00, Predicted Range: [3.61, 4.56], bootstrapped prediction: [4.1362295], in Range: True
# Input: -2 - -2 + 2, Actual: 2.00, Predicted Range: [1.94, 2.59], bootstrapped prediction: [2.2342706], in Range: True
# Input: 1 + -4 + -1, Actual: -4.00, Predicted Range: [-4.27, -3.91], bootstrapped prediction: [-4.1151767], in Range: True
# Input: -5 - 4 - -4, Actual: -5.00, Predicted Range: [-5.17, -4.64], bootstrapped prediction: [-4.891579], in Range: True
# Input: 4 + 4 + 3, Actual: 11.00, Predicted Range: [10.28, 10.81], bootstrapped prediction: [10.612693], in Range: False
# Input: -1 - -1 + -4, Actual: -4.00, Predicted Range: [-4.50, -3.80], bootstrapped prediction: [-4.1743937], in Range: True
# Input: -4 - 0 - 1, Actual: -5.00, Predicted Range: [-5.32, -4.75], bootstrapped prediction: [-4.9992476], in Range: True
# Input: 3 - -3 + -1, Actual: 5.00, Predicted Range: [4.78, 5.08], bootstrapped prediction: [4.932379], in Range: True
# Input: -4 + -2 - 3, Actual: -9.00, Predicted Range: [-9.03, -8.31], bootstrapped prediction: [-8.756127], in Range: True
# Input: -4 - -4 - 2, Actual: -2.00, Predicted Range: [-2.11, -1.55], bootstrapped prediction: [-1.8005499], in Range: True
# Input: -1 - 2 + -1, Actual: -4.00, Predicted Range: [-4.36, -3.80], bootstrapped prediction: [-4.093968], in Range: True
# Input: 0 - 2 - 4, Actual: -6.00, Predicted Range: [-6.26, -5.58], bootstrapped prediction: [-5.9253306], in Range: True
# Input: 1 - -4 + 2, Actual: 7.00, Predicted Range: [6.89, 7.22], bootstrapped prediction: [7.025344], in Range: True
# Input: 2 + 1 + -4, Actual: -1.00, Predicted Range: [-1.30, -0.90], bootstrapped prediction: [-1.0921724], in Range: True
# Input: -4 + 0 - 0, Actual: -4.00, Predicted Range: [-4.32, -3.79], bootstrapped prediction: [-4.11353], in Range: True
# Input: 3 + -1 - -1, Actual: 3.00, Predicted Range: [2.63, 3.32], bootstrapped prediction: [2.9484525], in Range: True
# Input: -3 - 4 + -3, Actual: -10.00, Predicted Range: [-10.20, -9.69], bootstrapped prediction: [-9.933989], in Range: True
# Input: -2 + -1 + 0, Actual: -3.00, Predicted Range: [-3.13, -2.70], bootstrapped prediction: [-2.9493635], in Range: True
# Input: 2 + 0 + -4, Actual: -2.00, Predicted Range: [-2.26, -1.90], bootstrapped prediction: [-2.0645149], in Range: True
# Input: 3 + 2 - 0, Actual: 5.00, Predicted Range: [4.74, 5.28], bootstrapped prediction: [5.0326085], in Range: True
# Input: 4 + -4 - 3, Actual: -3.00, Predicted Range: [-3.25, -2.77], bootstrapped prediction: [-2.9969249], in Range: True
# Input: 0 + -3 - -1, Actual: -2.00, Predicted Range: [-2.43, -1.98], bootstrapped prediction: [-2.2172472], in Range: True
# Input: 3 + 3 + -5, Actual: 1.00, Predicted Range: [0.76, 1.20], bootstrapped prediction: [0.963896], in Range: True
# Input: -3 + -3 + 2, Actual: -4.00, Predicted Range: [-4.48, -3.78], bootstrapped prediction: [-4.069173], in Range: True
# Input: -1 + 1 - 0, Actual: 0.00, Predicted Range: [-0.13, 0.40], bootstrapped prediction: [0.11293234], in Range: True
# Input: -1 - 0 + 0, Actual: -1.00, Predicted Range: [-1.16, -0.67], bootstrapped prediction: [-0.94421226], in Range: True
# Input: -3 - -1 - -2, Actual: 0.00, Predicted Range: [-0.29, 0.21], bootstrapped prediction: [-0.02253489], in Range: True
# Input: -3 - 2 + -3, Actual: -8.00, Predicted Range: [-8.21, -7.95], bootstrapped prediction: [-8.070771], in Range: True
# Input: 2 - -5 - 3, Actual: 4.00, Predicted Range: [3.60, 4.15], bootstrapped prediction: [3.888389], in Range: True
# Input: 1 - 0 + 2, Actual: 3.00, Predicted Range: [2.93, 3.73], bootstrapped prediction: [3.210689], in Range: True
# Input: -5 + -3 + -4, Actual: -12.00, Predicted Range: [-12.04, -11.71], bootstrapped prediction: [-11.862023], in Range: True
# Input: -2 + -4 + -5, Actual: -11.00, Predicted Range: [-11.21, -10.70], bootstrapped prediction: [-11.011136], in Range: True
# Input: 1 - -1 + -2, Actual: 0.00, Predicted Range: [-0.25, 0.15], bootstrapped prediction: [-0.03698584], in Range: True
# Input: -1 + -2 + 2, Actual: -1.00, Predicted Range: [-1.39, -0.79], bootstrapped prediction: [-0.99583244], in Range: True
# Input: 2 + -5 - 1, Actual: -4.00, Predicted Range: [-4.18, -3.58], bootstrapped prediction: [-3.8585439], in Range: True
# Input: -5 + -4 + 2, Actual: -7.00, Predicted Range: [-7.24, -6.79], bootstrapped prediction: [-7.0053635], in Range: True
# Input: -4 - -3 - 0, Actual: -1.00, Predicted Range: [-1.28, -0.59], bootstrapped prediction: [-0.88559926], in Range: True
# Input: -5 - -4 - -4, Actual: 3.00, Predicted Range: [2.44, 3.17], bootstrapped prediction: [2.824325], in Range: True
# Input: 2 - -5 - -3, Actual: 10.00, Predicted Range: [9.70, 10.17], bootstrapped prediction: [9.901667], in Range: True
# Input: 1 - 4 - 0, Actual: -3.00, Predicted Range: [-3.50, -2.84], bootstrapped prediction: [-3.0773118], in Range: True
# Input: 3 + 3 - 2, Actual: 4.00, Predicted Range: [3.98, 4.53], bootstrapped prediction: [4.2144895], in Range: True
# Input: 1 - -4 + 1, Actual: 6.00, Predicted Range: [5.68, 6.23], bootstrapped prediction: [5.926846], in Range: True
# Input: -2 + 4 + 0, Actual: 2.00, Predicted Range: [1.52, 2.36], bootstrapped prediction: [1.8503866], in Range: True
# Input: -2 - -5 + 0, Actual: 3.00, Predicted Range: [2.68, 3.35], bootstrapped prediction: [2.9883847], in Range: True
# Input: 2 + 2 - -1, Actual: 5.00, Predicted Range: [4.79, 5.27], bootstrapped prediction: [5.040617], in Range: True
# Input: -5 - 4 + -3, Actual: -12.00, Predicted Range: [-12.01, -11.43], bootstrapped prediction: [-11.755366], in Range: True
# Input: 0 - -5 + -3, Actual: 2.00, Predicted Range: [1.73, 2.22], bootstrapped prediction: [1.9967896], in Range: True
# Input: 4 + 4 + -5, Actual: 3.00, Predicted Range: [2.54, 3.39], bootstrapped prediction: [2.9987729], in Range: True
# Input: -1 - 3 - -5, Actual: 1.00, Predicted Range: [0.55, 1.17], bootstrapped prediction: [0.8745929], in Range: True
# Input: 4 + -4 + 1, Actual: 1.00, Predicted Range: [0.65, 1.32], bootstrapped prediction: [0.9725164], in Range: True
# Input: -5 + 1 + 2, Actual: -2.00, Predicted Range: [-2.39, -1.67], bootstrapped prediction: [-1.9893572], in Range: True
# Input: 1 + -5 - -2, Actual: -2.00, Predicted Range: [-2.21, -1.78], bootstrapped prediction: [-1.9891104], in Range: True
# Input: -5 - -2 - -3, Actual: 0.00, Predicted Range: [-0.44, 0.19], bootstrapped prediction: [-0.15717663], in Range: True
# Input: 2 - -1 - 3, Actual: 0.00, Predicted Range: [-0.39, 0.22], bootstrapped prediction: [-0.06677111], in Range: True
# Input: -3 - 1 - -3, Actual: -1.00, Predicted Range: [-1.05, -0.78], bootstrapped prediction: [-0.91919106], in Range: True
# Input: 1 - 0 + 0, Actual: 1.00, Predicted Range: [0.82, 1.31], bootstrapped prediction: [1.0532635], in Range: True
# Input: -2 + 1 - -3, Actual: 2.00, Predicted Range: [1.99, 2.45], bootstrapped prediction: [2.224174], in Range: True
# Input: -2 - -3 + -3, Actual: -2.00, Predicted Range: [-2.35, -1.96], bootstrapped prediction: [-2.1236339], in Range: True
# Input: -4 - -5 - -2, Actual: 3.00, Predicted Range: [2.60, 3.19], bootstrapped prediction: [2.8335512], in Range: True
# Input: 4 + -3 + -5, Actual: -4.00, Predicted Range: [-4.10, -3.62], bootstrapped prediction: [-3.837354], in Range: True
# Input: -1 - -3 - 4, Actual: -2.00, Predicted Range: [-2.04, -1.55], bootstrapped prediction: [-1.8295023], in Range: True
# Input: 4 + -5 - -2, Actual: 1.00, Predicted Range: [0.85, 1.68], bootstrapped prediction: [1.2931875], in Range: True
# Input: -2 + -5 - -4, Actual: -3.00, Predicted Range: [-3.15, -2.65], bootstrapped prediction: [-2.93498], in Range: True
# Input: 3 + 4 - 4, Actual: 3.00, Predicted Range: [2.20, 3.18], bootstrapped prediction: [2.6306279], in Range: True
# Input: -4 + 2 + 2, Actual: 0.00, Predicted Range: [-0.16, 0.52], bootstrapped prediction: [0.12074804], in Range: True
# Input: -4 - -1 + -1, Actual: -4.00, Predicted Range: [-4.42, -3.68], bootstrapped prediction: [-4.0999503], in Range: True
# Input: 3 - 1 + -1, Actual: 1.00, Predicted Range: [0.64, 1.26], bootstrapped prediction: [0.9720318], in Range: True
# Input: -1 + 3 - -3, Actual: 5.00, Predicted Range: [4.92, 5.28], bootstrapped prediction: [5.080916], in Range: True
# Input: 4 - -1 + 2, Actual: 7.00, Predicted Range: [6.95, 7.31], bootstrapped prediction: [7.0877037], in Range: True
# Input: -2 - 3 - -1, Actual: -4.00, Predicted Range: [-4.36, -3.94], bootstrapped prediction: [-4.179485], in Range: True
# Input: -5 + 4 + -5, Actual: -6.00, Predicted Range: [-6.59, -5.73], bootstrapped prediction: [-6.1333], in Range: True
# Input: -2 - -1 - 1, Actual: -2.00, Predicted Range: [-2.66, -1.70], bootstrapped prediction: [-2.145451], in Range: True
# Input: 1 - 3 + -3, Actual: -5.00, Predicted Range: [-5.53, -4.83], bootstrapped prediction: [-5.150583], in Range: True
# Input: 2 + -2 + -3, Actual: -3.00, Predicted Range: [-3.30, -2.84], bootstrapped prediction: [-3.0987244], in Range: True
# Input: -1 - -5 + 4, Actual: 8.00, Predicted Range: [7.46, 7.93], bootstrapped prediction: [7.7212014], in Range: False
# Input: -5 + 0 + 1, Actual: -4.00, Predicted Range: [-4.40, -3.87], bootstrapped prediction: [-4.046577], in Range: True
# Input: 3 + -3 + 2, Actual: 2.00, Predicted Range: [1.70, 2.25], bootstrapped prediction: [2.073882], in Range: True
# Input: 4 - 1 - 3, Actual: 0.00, Predicted Range: [-0.73, 0.26], bootstrapped prediction: [-0.16558465], in Range: True
# Input: -4 - 0 - -1, Actual: -3.00, Predicted Range: [-3.35, -2.77], bootstrapped prediction: [-3.0707512], in Range: True
# Input: -1 - 1 - -1, Actual: -1.00, Predicted Range: [-1.44, -0.86], bootstrapped prediction: [-1.1399084], in Range: True
# Input: 0 + -5 - 4, Actual: -9.00, Predicted Range: [-9.06, -8.27], bootstrapped prediction: [-8.689211], in Range: True
# Input: 2 - 2 - 0, Actual: 0.00, Predicted Range: [-0.40, 0.19], bootstrapped prediction: [-0.07867167], in Range: True
# Input: -3 - -2 + -1, Actual: -2.00, Predicted Range: [-2.30, -1.85], bootstrapped prediction: [-2.0929284], in Range: True
# Input: -2 - -5 + 1, Actual: 4.00, Predicted Range: [3.76, 4.33], bootstrapped prediction: [4.0324583], in Range: True
# Input: -5 + -4 + -2, Actual: -11.00, Predicted Range: [-11.19, -10.89], bootstrapped prediction: [-11.005014], in Range: True
# Input: -5 - 4 + -4, Actual: -13.00, Predicted Range: [-12.97, -12.38], bootstrapped prediction: [-12.723881], in Range: False
# Input: -1 + 1 + -2, Actual: -2.00, Predicted Range: [-2.17, -1.75], bootstrapped prediction: [-1.9979925], in Range: True
# Input: -2 - 1 + -5, Actual: -8.00, Predicted Range: [-8.18, -7.82], bootstrapped prediction: [-8.005797], in Range: True
# Input: 1 - -4 + 3, Actual: 8.00, Predicted Range: [7.83, 8.18], bootstrapped prediction: [8.012407], in Range: True
# Input: 3 + 1 + 3, Actual: 7.00, Predicted Range: [6.83, 7.26], bootstrapped prediction: [7.071377], in Range: True
# Input: 0 - -3 + -4, Actual: -1.00, Predicted Range: [-1.40, -0.87], bootstrapped prediction: [-1.0756843], in Range: True
# Input: -4 + -5 + -1, Actual: -10.00, Predicted Range: [-10.09, -9.76], bootstrapped prediction: [-9.926816], in Range: True
# Input: -3 + 2 + -5, Actual: -6.00, Predicted Range: [-6.19, -5.68], bootstrapped prediction: [-5.98957], in Range: True
# Input: -3 - 4 - 0, Actual: -7.00, Predicted Range: [-7.20, -6.71], bootstrapped prediction: [-7.0017366], in Range: True
# Input: -3 - 0 - 0, Actual: -3.00, Predicted Range: [-3.26, -2.83], bootstrapped prediction: [-3.1152987], in Range: True
# Input: 0 + 3 + 1, Actual: 4.00, Predicted Range: [3.95, 4.23], bootstrapped prediction: [4.051852], in Range: True
# Input: 4 + -4 + -3, Actual: -3.00, Predicted Range: [-3.28, -2.90], bootstrapped prediction: [-3.0969036], in Range: True
# Input: -3 - 3 - 4, Actual: -10.00, Predicted Range: [-10.03, -9.43], bootstrapped prediction: [-9.78136], in Range: True
# Input: -4 + 4 + 3, Actual: 3.00, Predicted Range: [2.86, 3.20], bootstrapped prediction: [2.98913], in Range: True
# Input: -1 + -2 - -1, Actual: -2.00, Predicted Range: [-2.27, -1.75], bootstrapped prediction: [-2.0646172], in Range: True
# Input: 0 + 4 - -4, Actual: 8.00, Predicted Range: [7.56, 8.18], bootstrapped prediction: [7.8540163], in Range: True
# Input: 2 + 2 + -2, Actual: 2.00, Predicted Range: [1.92, 2.30], bootstrapped prediction: [2.1053653], in Range: True
# Input: 2 - -5 - -4, Actual: 11.00, Predicted Range: [10.44, 11.05], bootstrapped prediction: [10.785073], in Range: True
# Input: 0 - -5 - -3, Actual: 8.00, Predicted Range: [7.55, 8.05], bootstrapped prediction: [7.830323], in Range: True
# Input: -5 - 4 - 4, Actual: -13.00, Predicted Range: [-12.64, -12.11], bootstrapped prediction: [-12.482376], in Range: False
# Input: -4 - -3 + -4, Actual: -5.00, Predicted Range: [-5.45, -4.93], bootstrapped prediction: [-5.0810356], in Range: True
# Input: -1 + 3 - -5, Actual: 7.00, Predicted Range: [6.66, 6.98], bootstrapped prediction: [6.812162], in Range: False
# Input: 1 + -2 - 0, Actual: -1.00, Predicted Range: [-1.52, -0.80], bootstrapped prediction: [-1.1983465], in Range: True
# Input: 3 - -3 - -2, Actual: 8.00, Predicted Range: [7.88, 8.24], bootstrapped prediction: [8.091487], in Range: True
# Input: -1 - 2 - -2, Actual: -1.00, Predicted Range: [-1.27, -0.80], bootstrapped prediction: [-1.0235296], in Range: True
# Input: -4 + -4 + 3, Actual: -5.00, Predicted Range: [-5.39, -4.95], bootstrapped prediction: [-5.1285276], in Range: True
# Input: -3 + 0 - -5, Actual: 2.00, Predicted Range: [1.67, 2.09], bootstrapped prediction: [1.9014362], in Range: True
# Input: 3 + 4 + -3, Actual: 4.00, Predicted Range: [3.83, 4.29], bootstrapped prediction: [4.0915866], in Range: True
# Input: -1 + 4 + 1, Actual: 4.00, Predicted Range: [3.51, 4.20], bootstrapped prediction: [3.8611214], in Range: True
# Input: -3 + -1 - -3, Actual: -1.00, Predicted Range: [-1.11, -0.84], bootstrapped prediction: [-0.9720322], in Range: True
# Input: 3 - -5 - -1, Actual: 9.00, Predicted Range: [8.36, 9.06], bootstrapped prediction: [8.783129], in Range: True
# Input: -3 - 4 - 1, Actual: -8.00, Predicted Range: [-8.20, -7.66], bootstrapped prediction: [-7.9449286], in Range: True
# Input: -3 + 4 + 0, Actual: 1.00, Predicted Range: [0.57, 1.34], bootstrapped prediction: [0.8959788], in Range: True
# Input: 3 + -4 + 3, Actual: 2.00, Predicted Range: [1.72, 2.25], bootstrapped prediction: [2.0303977], in Range: True
# Input: 4 + -3 - 0, Actual: 1.00, Predicted Range: [0.52, 1.31], bootstrapped prediction: [0.9147309], in Range: True
# Input: -5 + -3 + 1, Actual: -7.00, Predicted Range: [-7.27, -6.63], bootstrapped prediction: [-6.9478736], in Range: True
# Input: -3 + -1 - 1, Actual: -5.00, Predicted Range: [-5.21, -4.79], bootstrapped prediction: [-4.9962554], in Range: True
# Input: 4 - 4 + -4, Actual: -4.00, Predicted Range: [-3.96, -3.35], bootstrapped prediction: [-3.743072], in Range: False
# Input: 2 + 3 - -5, Actual: 10.00, Predicted Range: [9.45, 9.96], bootstrapped prediction: [9.718714], in Range: False
# Input: 1 + 1 + 0, Actual: 2.00, Predicted Range: [1.83, 2.28], bootstrapped prediction: [2.0749507], in Range: True
# Input: 2 + 0 - -2, Actual: 4.00, Predicted Range: [3.74, 4.35], bootstrapped prediction: [4.04605], in Range: True
# Input: 4 - -5 + 2, Actual: 11.00, Predicted Range: [10.39, 11.18], bootstrapped prediction: [10.863089], in Range: True
# Input: -1 - -2 - -4, Actual: 5.00, Predicted Range: [4.79, 5.31], bootstrapped prediction: [5.067384], in Range: True
# Input: 1 + 3 - -3, Actual: 7.00, Predicted Range: [7.05, 7.41], bootstrapped prediction: [7.1895027], in Range: False
# Input: 2 - 1 + -5, Actual: -4.00, Predicted Range: [-4.27, -3.37], bootstrapped prediction: [-3.9003882], in Range: True
# Input: -2 + -1 - 2, Actual: -5.00, Predicted Range: [-5.40, -4.72], bootstrapped prediction: [-5.000467], in Range: True
# Input: -3 + -4 - -5, Actual: -2.00, Predicted Range: [-2.16, -1.76], bootstrapped prediction: [-2.015455], in Range: True
# Input: 3 - 0 - 4, Actual: -1.00, Predicted Range: [-1.32, -0.74], bootstrapped prediction: [-1.0193999], in Range: True
# Input: 1 - 1 + -5, Actual: -5.00, Predicted Range: [-5.14, -4.44], bootstrapped prediction: [-4.9019203], in Range: True
# Input: 1 + 2 + -5, Actual: -2.00, Predicted Range: [-2.23, -1.91], bootstrapped prediction: [-2.078295], in Range: True
# Input: 0 - -4 + -1, Actual: 3.00, Predicted Range: [2.80, 3.08], bootstrapped prediction: [2.9751413], in Range: True
# Input: 1 - 4 - -5, Actual: 2.00, Predicted Range: [1.56, 2.26], bootstrapped prediction: [1.9856001], in Range: True
# Input: -4 - -4 - 1, Actual: -1.00, Predicted Range: [-1.14, -0.50], bootstrapped prediction: [-0.8417162], in Range: True
# Input: -3 - -1 - 1, Actual: -3.00, Predicted Range: [-3.55, -2.74], bootstrapped prediction: [-3.0814853], in Range: True
# Input: -1 + -2 - 4, Actual: -7.00, Predicted Range: [-7.15, -6.53], bootstrapped prediction: [-6.8164253], in Range: True
# Input: -2 - 3 - -3, Actual: -2.00, Predicted Range: [-2.22, -1.51], bootstrapped prediction: [-1.951528], in Range: True
# Input: -4 - -1 - -4, Actual: 1.00, Predicted Range: [0.62, 1.09], bootstrapped prediction: [0.87682235], in Range: True
# Input: -3 + -3 + -4, Actual: -10.00, Predicted Range: [-10.29, -9.88], bootstrapped prediction: [-10.044574], in Range: True
# Input: 2 + 1 - -5, Actual: 8.00, Predicted Range: [7.54, 8.18], bootstrapped prediction: [7.878434], in Range: True
# Input: 2 - -1 + 2, Actual: 5.00, Predicted Range: [4.81, 5.53], bootstrapped prediction: [5.1611857], in Range: True
# Input: -2 + -5 + 4, Actual: -3.00, Predicted Range: [-3.35, -2.73], bootstrapped prediction: [-3.0241668], in Range: True
# Input: 3 + -2 - -2, Actual: 3.00, Predicted Range: [2.44, 3.30], bootstrapped prediction: [2.881031], in Range: True
# Input: -1 - 3 - 4, Actual: -8.00, Predicted Range: [-8.19, -7.37], bootstrapped prediction: [-7.8023977], in Range: True
# Input: 2 + -4 - -5, Actual: 3.00, Predicted Range: [2.64, 3.22], bootstrapped prediction: [2.9262822], in Range: True
# Input: -1 + -3 + 1, Actual: -3.00, Predicted Range: [-3.25, -2.85], bootstrapped prediction: [-3.0258257], in Range: True
# Input: -1 - 1 + 3, Actual: 1.00, Predicted Range: [0.83, 1.71], bootstrapped prediction: [1.1746824], in Range: True
# Input: -4 - -2 + -1, Actual: -3.00, Predicted Range: [-3.27, -2.82], bootstrapped prediction: [-3.0371137], in Range: True
# Input: -1 + -2 + 3, Actual: 0.00, Predicted Range: [-0.49, 0.26], bootstrapped prediction: [-0.0052491], in Range: True
# Input: 4 + -5 - 0, Actual: -1.00, Predicted Range: [-1.01, -0.38], bootstrapped prediction: [-0.7003058], in Range: True
# Input: 4 + -2 + -3, Actual: -1.00, Predicted Range: [-1.31, -0.78], bootstrapped prediction: [-1.0766162], in Range: True
# Input: -5 - 3 - 0, Actual: -8.00, Predicted Range: [-8.27, -7.48], bootstrapped prediction: [-7.8919716], in Range: True
# Input: 3 - 3 + -2, Actual: -2.00, Predicted Range: [-2.30, -1.82], bootstrapped prediction: [-2.0579839], in Range: True
# Input: 3 - 1 + -4, Actual: -2.00, Predicted Range: [-2.39, -1.77], bootstrapped prediction: [-2.1302009], in Range: True
# Input: -2 - -3 - -2, Actual: 3.00, Predicted Range: [2.71, 3.48], bootstrapped prediction: [3.1124833], in Range: True
# Input: 2 - -2 + -1, Actual: 3.00, Predicted Range: [2.66, 3.00], bootstrapped prediction: [2.8298333], in Range: False
# Input: 4 + -2 + 4, Actual: 6.00, Predicted Range: [5.73, 6.41], bootstrapped prediction: [5.9662156], in Range: True
# Input: 3 + -4 + -2, Actual: -3.00, Predicted Range: [-3.28, -3.02], bootstrapped prediction: [-3.162609], in Range: False
# Input: 3 + 4 + 1, Actual: 8.00, Predicted Range: [7.49, 8.09], bootstrapped prediction: [7.8072677], in Range: True
# Input: -5 + 4 + -3, Actual: -4.00, Predicted Range: [-4.35, -3.84], bootstrapped prediction: [-4.1366234], in Range: True
# Input: 4 + 1 - 3, Actual: 2.00, Predicted Range: [1.87, 2.16], bootstrapped prediction: [2.0020301], in Range: True
# Input: -5 + -2 + -4, Actual: -11.00, Predicted Range: [-11.13, -10.77], bootstrapped prediction: [-10.917208], in Range: True
# Input: -5 - 2 - 4, Actual: -11.00, Predicted Range: [-10.95, -10.50], bootstrapped prediction: [-10.760006], in Range: False
# Input: 3 + -4 + -1, Actual: -2.00, Predicted Range: [-2.28, -2.05], bootstrapped prediction: [-2.1373916], in Range: False
# Input: -4 - 3 - -3, Actual: -4.00, Predicted Range: [-4.15, -3.64], bootstrapped prediction: [-3.9397652], in Range: True
# Input: -3 + -2 + 3, Actual: -2.00, Predicted Range: [-2.23, -1.66], bootstrapped prediction: [-1.9324968], in Range: True
# Input: -1 + 2 - -1, Actual: 2.00, Predicted Range: [1.81, 2.50], bootstrapped prediction: [2.1482472], in Range: True
# Input: -5 - 1 - -1, Actual: -5.00, Predicted Range: [-5.40, -4.71], bootstrapped prediction: [-5.0229497], in Range: True
# Input: -1 + -4 + -2, Actual: -7.00, Predicted Range: [-7.26, -6.74], bootstrapped prediction: [-7.0123224], in Range: True
# Input: 4 - -5 + -5, Actual: 4.00, Predicted Range: [3.88, 4.81], bootstrapped prediction: [4.324633], in Range: True
# Input: 1 - 2 + -1, Actual: -2.00, Predicted Range: [-2.50, -1.80], bootstrapped prediction: [-2.0929182], in Range: True
# Input: -5 + 3 - -5, Actual: 3.00, Predicted Range: [2.54, 3.07], bootstrapped prediction: [2.8516204], in Range: True
# Input: 2 + -3 + 0, Actual: -1.00, Predicted Range: [-1.23, -0.79], bootstrapped prediction: [-1.0315361], in Range: True
# Input: -4 - -3 - -1, Actual: 0.00, Predicted Range: [-0.18, 0.24], bootstrapped prediction: [0.04692911], in Range: True
# Input: 0 + 3 + 4, Actual: 7.00, Predicted Range: [6.58, 7.11], bootstrapped prediction: [6.8431425], in Range: True
# Input: -5 - 1 - 1, Actual: -7.00, Predicted Range: [-7.27, -6.83], bootstrapped prediction: [-7.0004873], in Range: True
# Input: 2 + 1 + -5, Actual: -2.00, Predicted Range: [-2.16, -1.92], bootstrapped prediction: [-2.0348716], in Range: True
# Input: -4 - -3 - 4, Actual: -5.00, Predicted Range: [-5.28, -4.75], bootstrapped prediction: [-5.0470004], in Range: True
# Input: -5 + -2 + -1, Actual: -8.00, Predicted Range: [-8.21, -7.60], bootstrapped prediction: [-7.963759], in Range: True
# Input: -2 - 0 + 0, Actual: -2.00, Predicted Range: [-2.15, -1.72], bootstrapped prediction: [-1.9264796], in Range: True
# Input: -4 + 3 - 3, Actual: -4.00, Predicted Range: [-4.28, -3.73], bootstrapped prediction: [-3.9802067], in Range: True
# Input: 1 - 3 + 0, Actual: -2.00, Predicted Range: [-2.43, -1.85], bootstrapped prediction: [-2.0646565], in Range: True
# Input: -3 + -3 + -2, Actual: -8.00, Predicted Range: [-8.23, -7.87], bootstrapped prediction: [-8.0817375], in Range: True
# Input: -4 + -5 + 4, Actual: -5.00, Predicted Range: [-5.32, -4.89], bootstrapped prediction: [-5.1030326], in Range: True
# Input: 4 + 3 + -2, Actual: 5.00, Predicted Range: [4.95, 5.30], bootstrapped prediction: [5.0957103], in Range: True
# Input: 0 - -2 - -4, Actual: 6.00, Predicted Range: [5.87, 6.48], bootstrapped prediction: [6.128107], in Range: True
# Input: 2 + -1 + -4, Actual: -3.00, Predicted Range: [-3.24, -2.91], bootstrapped prediction: [-3.0397363], in Range: True
# Input: -1 + -1 + -3, Actual: -5.00, Predicted Range: [-5.35, -4.79], bootstrapped prediction: [-5.055359], in Range: True
# Input: -3 + -3 - 4, Actual: -10.00, Predicted Range: [-10.10, -9.40], bootstrapped prediction: [-9.843203], in Range: True
# Input: -5 + 2 + 4, Actual: 1.00, Predicted Range: [0.50, 1.15], bootstrapped prediction: [0.80702955], in Range: True
# Input: -1 - -3 + -4, Actual: -2.00, Predicted Range: [-2.48, -1.94], bootstrapped prediction: [-2.1445], in Range: True
# Input: 3 + 0 - -2, Actual: 5.00, Predicted Range: [4.80, 5.39], bootstrapped prediction: [5.0817604], in Range: True
# ...
# Input: -5 + 0 - -1, Actual: -4.00, Predicted Range: [-4.60, -3.71], bootstrapped prediction: [-4.1673436], in Range: True
# Input: -1 - -3 + 4, Actual: 6.00, Predicted Range: [5.64, 6.26], bootstrapped prediction: [5.968988], in Range: True
# Input: 3 - 3 + -1, Actual: -1.00, Predicted Range: [-1.37, -0.87], bootstrapped prediction: [-1.1350977], in Range: True
# Input: 0 + 1 + 0, Actual: 1.00, Predicted Range: [0.84, 1.40], bootstrapped prediction: [1.0902337], in Range: True
# Input: -4 + 3 - 2, Actual: -3.00, Predicted Range: [-3.20, -2.57], bootstrapped prediction: [-2.869323], in Range: True
# Input: 0 + -3 + 2, Actual: -1.00, Predicted Range: [-1.34, -0.77], bootstrapped prediction: [-0.9638219], in Range: True
# Input: -1 + -1 - 4, Actual: -6.00, Predicted Range: [-6.08, -5.58], bootstrapped prediction: [-5.818244], in Range: True
# Input: -5 + -4 - -1, Actual: -8.00, Predicted Range: [-8.42, -7.58], bootstrapped prediction: [-8.070211], in Range: True
# Input: -5 + -5 - 2, Actual: -12.00, Predicted Range: [-12.07, -11.21], bootstrapped prediction: [-11.584719], in Range: True
# Input: -3 + 4 - 1, Actual: 0.00, Predicted Range: [-0.22, 0.29], bootstrapped prediction: [0.03735835], in Range: True
# Input: -4 + 4 - -1, Actual: 1.00, Predicted Range: [0.35, 1.36], bootstrapped prediction: [0.86676204], in Range: True
# Input: 0 - 1 - -5, Actual: 4.00, Predicted Range: [3.70, 4.29], bootstrapped prediction: [3.9892535], in Range: True
# Input: -1 + 2 - 2, Actual: -1.00, Predicted Range: [-1.15, -0.39], bootstrapped prediction: [-0.77714103], in Range: True
# Input: -2 - -2 + -2, Actual: -2.00, Predicted Range: [-2.41, -1.90], bootstrapped prediction: [-2.1938264], in Range: True
# Input: 2 - 4 - 0, Actual: -2.00, Predicted Range: [-2.41, -1.89], bootstrapped prediction: [-2.0845966], in Range: True
# Input: -4 - 2 + 4, Actual: -2.00, Predicted Range: [-2.59, -1.99], bootstrapped prediction: [-2.2517962], in Range: True
# Input: 4 + 1 + -4, Actual: 1.00, Predicted Range: [0.67, 1.22], bootstrapped prediction: [0.96049726], in Range: True
# Input: -1 - -1 + -3, Actual: -3.00, Predicted Range: [-3.47, -2.88], bootstrapped prediction: [-3.1684535], in Range: True
# Input: -5 - -2 - 1, Actual: -4.00, Predicted Range: [-4.20, -3.63], bootstrapped prediction: [-3.8561835], in Range: True
# Input: -1 - -2 - -2, Actual: 3.00, Predicted Range: [2.83, 3.64], bootstrapped prediction: [3.2755375], in Range: True
# Input: -2 - 2 - -4, Actual: 0.00, Predicted Range: [-0.32, 0.20], bootstrapped prediction: [-0.02628019], in Range: True
# Input: 0 - 1 + 3, Actual: 2.00, Predicted Range: [1.96, 2.54], bootstrapped prediction: [2.22818], in Range: True
# Input: 4 - 2 - 0, Actual: 2.00, Predicted Range: [1.78, 2.22], bootstrapped prediction: [1.9812046], in Range: True
# Input: 0 + 0 + 3, Actual: 3.00, Predicted Range: [2.93, 3.22], bootstrapped prediction: [3.060832], in Range: True
# Input: -4 - 4 - -1, Actual: -7.00, Predicted Range: [-7.25, -6.85], bootstrapped prediction: [-7.056176], in Range: True
# Input: 4 + 0 - -2, Actual: 6.00, Predicted Range: [5.73, 6.29], bootstrapped prediction: [6.0227375], in Range: True
# Input: -4 - 0 - 0, Actual: -4.00, Predicted Range: [-4.40, -3.77], bootstrapped prediction: [-4.0949144], in Range: True
# Input: -3 - -1 + -2, Actual: -4.00, Predicted Range: [-4.46, -3.94], bootstrapped prediction: [-4.1571937], in Range: True
# Input: 0 - -3 + -1, Actual: 2.00, Predicted Range: [1.65, 2.10], bootstrapped prediction: [1.881429], in Range: True
# Input: 3 - -5 - -4, Actual: 12.00, Predicted Range: [11.53, 12.04], bootstrapped prediction: [11.797462], in Range: True
# Input: -4 + -2 - -4, Actual: -2.00, Predicted Range: [-2.26, -1.78], bootstrapped prediction: [-2.0279918], in Range: True
# Input: 2 - -5 - 2, Actual: 5.00, Predicted Range: [4.65, 5.19], bootstrapped prediction: [4.876413], in Range: True
# Input: 1 - 0 + -3, Actual: -2.00, Predicted Range: [-2.34, -1.81], bootstrapped prediction: [-2.060201], in Range: True
# Input: 3 - -4 - 3, Actual: 4.00, Predicted Range: [3.83, 4.31], bootstrapped prediction: [4.0244865], in Range: True
# Input: -3 - 1 + 2, Actual: -2.00, Predicted Range: [-2.19, -1.73], bootstrapped prediction: [-1.938372], in Range: True
# Input: 2 - 0 - -4, Actual: 6.00, Predicted Range: [5.72, 6.56], bootstrapped prediction: [6.129914], in Range: True
# Input: 0 + -4 - -2, Actual: -2.00, Predicted Range: [-2.53, -1.96], bootstrapped prediction: [-2.1754794], in Range: True
# Input: -3 + -1 - 3, Actual: -7.00, Predicted Range: [-7.22, -6.80], bootstrapped prediction: [-6.982768], in Range: True
# Input: 2 - 1 - 4, Actual: -3.00, Predicted Range: [-3.32, -2.68], bootstrapped prediction: [-3.040255], in Range: True
# Input: -5 - 2 + -5, Actual: -12.00, Predicted Range: [-12.02, -11.29], bootstrapped prediction: [-11.721034], in Range: True
# Input: 1 - 1 - 3, Actual: -3.00, Predicted Range: [-3.62, -3.08], bootstrapped prediction: [-3.3462367], in Range: False
# Input: -5 - 3 - -1, Actual: -7.00, Predicted Range: [-7.28, -6.66], bootstrapped prediction: [-6.9886475], in Range: True
# Input: 2 - -3 + -4, Actual: 1.00, Predicted Range: [0.67, 1.05], bootstrapped prediction: [0.9114715], in Range: True
# Input: 4 - 3 - 1, Actual: 0.00, Predicted Range: [-0.27, 0.20], bootstrapped prediction: [-0.01170343], in Range: True
# Input: 2 + 2 + 1, Actual: 5.00, Predicted Range: [4.84, 5.41], bootstrapped prediction: [5.030922], in Range: True
# Input: -5 - -5 - -5, Actual: 5.00, Predicted Range: [4.45, 4.92], bootstrapped prediction: [4.6619215], in Range: False
# Input: -4 - 1 + 4, Actual: -1.00, Predicted Range: [-1.48, -0.89], bootstrapped prediction: [-1.1708263], in Range: True
# Input: 1 - 2 + 0, Actual: -1.00, Predicted Range: [-1.37, -0.80], bootstrapped prediction: [-1.0586382], in Range: True
# Input: 2 + -1 - 2, Actual: -1.00, Predicted Range: [-1.28, -0.86], bootstrapped prediction: [-1.0941019], in Range: True
# Input: -5 + 1 + 3, Actual: -1.00, Predicted Range: [-1.44, -0.65], bootstrapped prediction: [-1.0601128], in Range: True
# Input: -4 - 0 + 0, Actual: -4.00, Predicted Range: [-4.28, -3.65], bootstrapped prediction: [-3.9835918], in Range: True
# Input: 0 - -5 + 4, Actual: 9.00, Predicted Range: [8.44, 8.90], bootstrapped prediction: [8.722221], in Range: False
# Input: 3 - -1 - -5, Actual: 9.00, Predicted Range: [8.66, 9.28], bootstrapped prediction: [8.973315], in Range: True
# Input: 2 - -2 - 3, Actual: 1.00, Predicted Range: [0.68, 1.44], bootstrapped prediction: [1.0202198], in Range: True
# Input: 2 - -2 - -2, Actual: 6.00, Predicted Range: [5.78, 6.41], bootstrapped prediction: [6.121604], in Range: True
# Input: 0 + 4 - 1, Actual: 3.00, Predicted Range: [2.70, 3.61], bootstrapped prediction: [3.0965219], in Range: True
# Input: 1 + -1 - 1, Actual: -1.00, Predicted Range: [-1.44, -0.79], bootstrapped prediction: [-1.1462492], in Range: True
# Input: -4 - 1 + 2, Actual: -3.00, Predicted Range: [-3.16, -2.73], bootstrapped prediction: [-2.9500592], in Range: True
# Input: 2 + 3 + 0, Actual: 5.00, Predicted Range: [4.67, 5.26], bootstrapped prediction: [5.006673], in Range: True
# Input: 0 + -3 + -4, Actual: -7.00, Predicted Range: [-7.31, -6.88], bootstrapped prediction: [-7.0745673], in Range: True
# Input: -3 + 1 - 3, Actual: -5.00, Predicted Range: [-5.26, -4.79], bootstrapped prediction: [-4.989689], in Range: True
# Input: 1 - 4 + 4, Actual: 1.00, Predicted Range: [0.46, 1.18], bootstrapped prediction: [0.8737768], in Range: True
# Input: 0 + -2 - -1, Actual: -1.00, Predicted Range: [-1.41, -0.84], bootstrapped prediction: [-1.1391652], in Range: True
# Input: -5 + 3 - -1, Actual: -1.00, Predicted Range: [-1.33, -0.64], bootstrapped prediction: [-1.0737615], in Range: True
# Input: 1 - 0 - -2, Actual: 3.00, Predicted Range: [2.83, 3.44], bootstrapped prediction: [3.204015], in Range: True
# Input: -2 - 2 + -5, Actual: -9.00, Predicted Range: [-9.27, -8.78], bootstrapped prediction: [-8.989938], in Range: True
# Input: 3 + -2 - -1, Actual: 2.00, Predicted Range: [1.52, 2.29], bootstrapped prediction: [1.9098628], in Range: True
# Input: -5 + 2 + 2, Actual: -1.00, Predicted Range: [-1.26, -0.62], bootstrapped prediction: [-0.98253596], in Range: True
# Input: 2 - 2 + -3, Actual: -3.00, Predicted Range: [-3.35, -2.81], bootstrapped prediction: [-3.107775], in Range: True
# Input: 0 + 4 + -3, Actual: 1.00, Predicted Range: [0.58, 1.31], bootstrapped prediction: [0.8874589], in Range: True
# Input: -2 + 4 - 2, Actual: 0.00, Predicted Range: [-0.08, 0.47], bootstrapped prediction: [0.1451556], in Range: True
# Input: 2 + 4 - 1, Actual: 5.00, Predicted Range: [4.59, 5.43], bootstrapped prediction: [5.064583], in Range: True
# Input: -4 - 1 - 1, Actual: -6.00, Predicted Range: [-6.22, -5.89], bootstrapped prediction: [-6.0513787], in Range: True
# Input: 3 + -3 - -5, Actual: 5.00, Predicted Range: [4.62, 5.22], bootstrapped prediction: [4.9273434], in Range: True
# Input: 2 + -5 - 4, Actual: -7.00, Predicted Range: [-7.02, -6.35], bootstrapped prediction: [-6.7503557], in Range: True
# Input: -2 + -2 - -5, Actual: 1.00, Predicted Range: [0.57, 1.31], bootstrapped prediction: [0.9669422], in Range: True
# Input: -4 - -4 + -3, Actual: -3.00, Predicted Range: [-3.16, -2.82], bootstrapped prediction: [-3.0011685], in Range: True
# Input: 3 - -4 - 4, Actual: 3.00, Predicted Range: [2.86, 3.16], bootstrapped prediction: [3.044293], in Range: True
# Input: -3 - 1 + -4, Actual: -8.00, Predicted Range: [-8.32, -8.02], bootstrapped prediction: [-8.145285], in Range: False
# Input: -5 - -1 + 1, Actual: -3.00, Predicted Range: [-3.39, -2.72], bootstrapped prediction: [-3.0321574], in Range: True
# Input: -4 - -1 - 4, Actual: -7.00, Predicted Range: [-7.28, -6.50], bootstrapped prediction: [-6.9019523], in Range: True
# Input: 2 - 3 - -1, Actual: 0.00, Predicted Range: [-0.40, 0.26], bootstrapped prediction: [-0.05623184], in Range: True
# Input: -3 + -2 - -4, Actual: -1.00, Predicted Range: [-1.25, -0.77], bootstrapped prediction: [-1.0205812], in Range: True
# Input: -2 - -1 + -4, Actual: -5.00, Predicted Range: [-5.35, -4.92], bootstrapped prediction: [-5.161844], in Range: True
# Input: -2 + -5 + -5, Actual: -12.00, Predicted Range: [-12.04, -11.55], bootstrapped prediction: [-11.75665], in Range: True
# Input: -1 + -4 - -3, Actual: -2.00, Predicted Range: [-2.38, -1.95], bootstrapped prediction: [-2.212316], in Range: True
# Input: 2 - -3 + -5, Actual: 0.00, Predicted Range: [-0.19, 0.24], bootstrapped prediction: [0.04485084], in Range: True
# Input: 2 - 4 - 3, Actual: -5.00, Predicted Range: [-5.14, -4.49], bootstrapped prediction: [-4.826319], in Range: True
# Input: -2 + 2 + 3, Actual: 3.00, Predicted Range: [2.93, 3.38], bootstrapped prediction: [3.1459827], in Range: True
# Input: 1 - 4 - 4, Actual: -7.00, Predicted Range: [-6.89, -6.22], bootstrapped prediction: [-6.6393113], in Range: False
# Input: -4 + 1 - 0, Actual: -3.00, Predicted Range: [-3.21, -2.68], bootstrapped prediction: [-2.9746583], in Range: True
# Input: 4 - 0 + -1, Actual: 3.00, Predicted Range: [2.72, 3.15], bootstrapped prediction: [2.9941018], in Range: True
# Input: 2 + 4 - -4, Actual: 10.00, Predicted Range: [9.53, 10.15], bootstrapped prediction: [9.860445], in Range: True
# Input: 1 - -4 - 1, Actual: 4.00, Predicted Range: [3.79, 4.26], bootstrapped prediction: [4.0309663], in Range: True
# Input: -5 - 1 + -4, Actual: -10.00, Predicted Range: [-10.24, -9.66], bootstrapped prediction: [-9.977126], in Range: True
# Input: 2 + 2 + 4, Actual: 8.00, Predicted Range: [7.65, 8.06], bootstrapped prediction: [7.881007], in Range: True
# Input: 0 - 1 - -4, Actual: 3.00, Predicted Range: [2.87, 3.31], bootstrapped prediction: [3.0813432], in Range: True
# Input: -3 - -3 - -2, Actual: 2.00, Predicted Range: [1.90, 2.42], bootstrapped prediction: [2.1235764], in Range: True
# Input: 0 - -4 + -4, Actual: 0.00, Predicted Range: [-0.44, 0.26], bootstrapped prediction: [-0.05866009], in Range: True
# Input: 1 + -3 + -2, Actual: -4.00, Predicted Range: [-4.33, -3.96], bootstrapped prediction: [-4.1113386], in Range: True
# Input: -3 - -5 + 3, Actual: 5.00, Predicted Range: [4.64, 5.10], bootstrapped prediction: [4.9090548], in Range: True
# Input: -1 - 4 + 0, Actual: -5.00, Predicted Range: [-5.06, -4.50], bootstrapped prediction: [-4.8363447], in Range: True
# Input: -1 + 1 - -2, Actual: 2.00, Predicted Range: [1.93, 2.56], bootstrapped prediction: [2.2318738], in Range: True
# Input: 0 - 1 - 1, Actual: -2.00, Predicted Range: [-2.86, -2.01], bootstrapped prediction: [-2.4171412], in Range: False
# Input: -2 - 4 - -5, Actual: -1.00, Predicted Range: [-1.31, -0.71], bootstrapped prediction: [-1.0055896], in Range: True
# Input: 2 + -2 + -2, Actual: -2.00, Predicted Range: [-2.32, -1.95], bootstrapped prediction: [-2.124889], in Range: True
# Input: 0 + 3 - 3, Actual: 0.00, Predicted Range: [-0.28, 0.23], bootstrapped prediction: [0.03750296], in Range: True
# Input: -4 - -1 - -2, Actual: -1.00, Predicted Range: [-1.30, -0.66], bootstrapped prediction: [-0.9956428], in Range: True
# Input: 3 + -4 - -3, Actual: 2.00, Predicted Range: [1.63, 2.16], bootstrapped prediction: [1.8810126], in Range: True
# Input: 0 + -4 - 3, Actual: -7.00, Predicted Range: [-7.20, -6.76], bootstrapped prediction: [-7.051259], in Range: True
# Input: 4 + -2 - -4, Actual: 6.00, Predicted Range: [5.73, 6.16], bootstrapped prediction: [5.982938], in Range: True
# Input: 0 - -5 - -1, Actual: 6.00, Predicted Range: [5.77, 6.28], bootstrapped prediction: [6.067139], in Range: True
# Input: -1 - -4 - 3, Actual: 0.00, Predicted Range: [-0.44, 0.12], bootstrapped prediction: [-0.08616254], in Range: True
# Input: -1 - 2 - 2, Actual: -5.00, Predicted Range: [-5.65, -5.08], bootstrapped prediction: [-5.3118186], in Range: False
# Input: -1 + 4 + -4, Actual: -1.00, Predicted Range: [-1.40, -0.88], bootstrapped prediction: [-1.1356887], in Range: True
# Input: 0 - -5 + -5, Actual: 0.00, Predicted Range: [-0.19, 0.44], bootstrapped prediction: [0.21008801], in Range: True
# Input: -3 - -4 + 4, Actual: 5.00, Predicted Range: [4.81, 5.23], bootstrapped prediction: [5.0046935], in Range: True
# Input: 4 - -3 - -1, Actual: 8.00, Predicted Range: [7.66, 8.39], bootstrapped prediction: [7.9505377], in Range: True
# Input: 2 - 0 - -5, Actual: 7.00, Predicted Range: [6.47, 7.45], bootstrapped prediction: [6.9866815], in Range: True
# Input: 1 + 4 - -1, Actual: 6.00, Predicted Range: [5.69, 6.07], bootstrapped prediction: [5.880138], in Range: True
# Input: -1 - 1 - -3, Actual: 1.00, Predicted Range: [0.89, 1.39], bootstrapped prediction: [1.0929427], in Range: True
# Input: 4 + -3 + -4, Actual: -3.00, Predicted Range: [-3.19, -2.77], bootstrapped prediction: [-3.0196872], in Range: True
# Input: 3 - 4 - 3, Actual: -4.00, Predicted Range: [-4.06, -3.39], bootstrapped prediction: [-3.7342277], in Range: True
# Input: 3 - 4 + -1, Actual: -2.00, Predicted Range: [-2.30, -1.80], bootstrapped prediction: [-2.0699959], in Range: True
# Input: -1 + 2 - -4, Actual: 5.00, Predicted Range: [4.91, 5.35], bootstrapped prediction: [5.1087], in Range: True
# Input: 1 - -3 - -3, Actual: 7.00, Predicted Range: [6.93, 7.38], bootstrapped prediction: [7.115906], in Range: True
# Input: -2 + -2 - -2, Actual: -2.00, Predicted Range: [-2.34, -1.81], bootstrapped prediction: [-2.0906363], in Range: True
# Input: -2 - -5 - 4, Actual: -1.00, Predicted Range: [-1.59, -0.91], bootstrapped prediction: [-1.2099191], in Range: True
# Input: 4 - 0 + 0, Actual: 4.00, Predicted Range: [3.84, 4.36], bootstrapped prediction: [4.087701], in Range: True
# Input: 4 - 2 - 3, Actual: -1.00, Predicted Range: [-1.57, -0.73], bootstrapped prediction: [-1.0943649], in Range: True
# Input: -3 + -4 - -1, Actual: -6.00, Predicted Range: [-6.34, -5.98], bootstrapped prediction: [-6.1575136], in Range: True
# Input: 0 + -3 - -4, Actual: 1.00, Predicted Range: [0.74, 1.24], bootstrapped prediction: [0.90824413], in Range: True
# Input: 4 - 1 + 2, Actual: 5.00, Predicted Range: [4.95, 5.31], bootstrapped prediction: [5.108822], in Range: True
# Amount out of bounds: 90, Amount of expressions: 1457, Percentage in bounds: 93.8229238160604%

# %%
print(f"Amount out of bounds: {outOfBounds}, Amount of expressions: {len(x_test)}, Percentage in bounds: {(1-(outOfBounds/len(x_test)))*100}")
# Out:
# Amount out of bounds: 90, Amount of expressions: 1457, Percentage in bounds: 93.8229238160604

# %%
# Visualize the predictions and the range for a few samples
plt.figure(figsize=(10, 6))
# Calculate the positive error values for the lower and upper bounds
yerr_lower = abs(y_test - lower_bound[:, 0])
yerr_upper = abs(upper_bound[:, 0] - y_test)
plt.errorbar(range(len(y_test)), y_test, yerr=[yerr_lower, yerr_upper], fmt='o', label='Actual with 95% Prediction Range')
plt.xlabel("Test Sample Index")
plt.ylabel("Value")
plt.title("Actual Values and 95% Prediction Range for Test Set (Bootstrap)")
plt.legend()
plt.show()
